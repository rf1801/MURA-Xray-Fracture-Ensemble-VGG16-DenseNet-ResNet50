# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
import tensorflow as tf
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras import layers, models
from keras.layers import concatenate, Dense, Conv2D, MaxPooling2D, Flatten, Activation, BatchNormalization, Dropout, \
    Attention
from keras import *
from keras.applications import MobileNet
from keras.applications import VGG16
from keras.applications.resnet import ResNet50
from keras import backend as K
from keras.layers import Layer
import keras.layers as kl
import pandas as pd
from keras.applications import EfficientNetB0
import keras.applications
import numpy as np
import os
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from sklearn.metrics import cohen_kappa_score
import seaborn as sns
import pickle
import tensorflow_addons as tfa
from sklearn import metrics
from tensorflow.keras.applications.resnet import preprocess_input as preprocess_input_resnet
from tensorflow.keras.applications.densenet import preprocess_input as preprocess_input_densenet
from tensorflow.keras.models import load_model
import os
import glob
# Out:
# c:\Users\raouf\miniconda3\envs\tensorflowgpu\lib\site-packages\tensorflow_addons\utils\tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# c:\Users\raouf\miniconda3\envs\tensorflowgpu\lib\site-packages\tensorflow_addons\utils\ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.12.0 and strictly below 2.15.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.10.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %%
main_save_path = "C:/Users/raouf/Desktop/pfe/history/final/vgg/"
mura_location = "C:/Users/raouf/Desktop/pfe/"
data_path = 'C:/Users/raouf/Desktop/pfe/MURA-v1.1/'
train_path = 'C:/Users/raouf/Desktop/pfe/MURA-v1.1/train'
test_path = 'C:/Users/raouf/Desktop/pfe/MURA-v1.1/valid'

train_file = "C:/Users/raouf/Desktop/pfe/datasets/shoulder_df_train.csv"
val_file = "C:/Users/raouf/Desktop/pfe/datasets/shoulder_df_valid.csv"

test_file = "C:/Users/raouf/Desktop/pfe/MURA-v1.1/valid_image_paths.csv"

target_category = "XR_SHOULDER"
batch_size = 16
num_epochs = 100
fine_tuning_epochs=50
validation_split = 0.2
loss_function = tf.keras.losses.BinaryCrossentropy()
learning_rate = 0.0001
input_shape = (224, 224, 3)
architecture = 'VGG'

include_top = False
# metrics=["accuracy"] #, tf.keras.metrics.Precision(), tf.keras.metrics.Recall()
early_stopping_patience = 15
shuffle = True
class_mode = 'binary'  # 'categorical'
IMAGE_WIDTH = 224
IMAGE_HEIGHT = 224
trainable = False
training = False
dropout = 0.2

# %%
def load_data(file, part):
    train_data = pd.read_csv(file)
    train_data = train_data.rename(columns={train_data.columns[0]: 'image_path'})
    train_data['label'] = 2
    string_to_add = mura_location
    train_data['image_path'] = string_to_add + train_data['image_path'].astype(str)
    for index, row in train_data.iterrows():
        if 'positive' in str(row['image_path']).lower():
            train_data.at[index, 'label'] = "positive"
        else:
            train_data.at[index, 'label'] = "negative"

    if part == 0:
        pass
    else:
        train_data = train_data[train_data['image_path'].str.contains(part)]
    return train_data


class CustomCallback(keras.callbacks.Callback):
    def on_test_end(self, logs=None):
        keys = list(logs.keys())
        print(f"tp          :", logs["tp"])
        print(f"fp          :", logs["fp"])
        print(f"tn          :", logs["tn"])
        print(f"fn          :", logs["fn"])
        print(f"binary_acc  :", logs["binary_acc"])
        print(f"precision   :", logs["precision"])
        print(f"recall      :", logs["recall"])
        print(f"f1_score    :", logs["f1_score"])
        print(f"roc_auc     :", logs["roc_auc"])
        print(f"pr_auc      :", logs["pr_auc"])
        print(f"cohen_kappa :", logs["cohen_kappa"])

class F1Score(tf.keras.metrics.Metric):

    def __init__(self, name="f1_score", **kwargs):
        super().__init__(name=name, **kwargs)
        self.f1 = self.add_weight(name="f1", initializer="zeros")
        self.precision_fn = tf.keras.metrics.Precision()
        self.recall_fn = tf.keras.metrics.Recall()

    def update_state(self, y_true, y_pred, sample_weight=None):
        p = self.precision_fn(y_true, y_pred)
        r = self.recall_fn(y_true, y_pred)
        self.f1.assign(2 * ((p * r) / (p + r + 1e-10)))

    def result(self):
        return self.f1

    def reset_state(self):
        # we also need to reset the state of the precision and recall objects
        self.precision_fn.reset_state()
        self.recall_fn.reset_state()
        self.f1.assign(0)


def save_history(name,history_df):

    history_excel_path = (
            save_path +
            name +
            '_history'
            '.xlsx'
    )

    history_df.to_excel(history_excel_path, index=False)
    print("Training history saved to:", history_excel_path)






def plot_metrics(history: tf.keras.callbacks.History,
                 metrics: list = ["loss", "cohen_kappa", "precision", "recall"],
                 ) -> None:
    plt.rcParams["figure.figsize"] = (18, 15)

    for n, metric in enumerate(metrics):
        name = metric.replace("_", " ").capitalize()
        plt.subplot(2, 2, n + 1)
        plt.plot(
            history.epoch, history.history[metric], linewidth=1.8, label="training"
        )
        plt.plot(
            history.epoch,
            history.history["val_" + metric],
            linestyle="--",
            linewidth=1.8,
            label="validation",
        )
        plt.xlabel("epoch")
        plt.ylabel(name)
        if metric == "loss":
            plt.ylim([0, plt.ylim()[1]])
        elif metric == "cohen_kappa":
            plt.ylim([-1, 1])
        else:
            plt.ylim([0, 1])

        plt.legend()



class CustomCallback(keras.callbacks.Callback):
    def on_test_end(self, logs=None):
        keys = list(logs.keys())
        print(f"tp          :", logs["tp"])
        print(f"fp          :", logs["fp"])
        print(f"tn          :", logs["tn"])
        print(f"fn          :", logs["fn"])
        print(f"binary_acc  :", logs["binary_acc"])
        print(f"precision   :", logs["precision"])
        print(f"recall      :", logs["recall"])
        print(f"f1_score    :", logs["f1_score"])
        print(f"roc_auc     :", logs["roc_auc"])
        print(f"pr_auc      :", logs["pr_auc"])
        print(f"cohen_kappa :", logs["cohen_kappa"])


def save_history(name,history_df):

    # Constructing the file name with metric values
    history_excel_path = (
            save_path +
            name +
            '_history'
            '.xlsx'
    )

    history_df.to_excel(history_excel_path, index=False)
    print("Training history saved to:", history_excel_path)




class F1Score(tf.keras.metrics.Metric):

    def __init__(self, name="f1_score", **kwargs):
        super().__init__(name=name, **kwargs)
        self.f1 = self.add_weight(name="f1", initializer="zeros")
        self.precision_fn = tf.keras.metrics.Precision()
        self.recall_fn = tf.keras.metrics.Recall()

    def update_state(self, y_true, y_pred, sample_weight=None):
        p = self.precision_fn(y_true, y_pred)
        r = self.recall_fn(y_true, y_pred)
        self.f1.assign(2 * ((p * r) / (p + r + 1e-10)))

    def result(self):
        return self.f1

    def reset_state(self):
        # we also need to reset the state of the precision and recall objects
        self.precision_fn.reset_state()
        self.recall_fn.reset_state()
        self.f1.assign(0)

def plot_metrics(history: tf.keras.callbacks.History,
                 metrics: list = ["loss", "cohen_kappa", "precision", "recall"],
                 ) -> None:
    plt.rcParams["figure.figsize"] = (18, 15)

    for n, metric in enumerate(metrics):
        name = metric.replace("_", " ").capitalize()
        plt.subplot(2, 2, n + 1)
        plt.plot(
            history.epoch, history.history[metric], linewidth=1.8, label="training"
        )
        plt.plot(
            history.epoch,
            history.history["val_" + metric],
            linestyle="--",
            linewidth=1.8,
            label="validation",
        )
        plt.xlabel("epoch")
        plt.ylabel(name)
        if metric == "loss":
            plt.ylim([0, plt.ylim()[1]])
        elif metric == "cohen_kappa":
            plt.ylim([-1, 1])
        else:
            plt.ylim([0, 1])

        plt.legend()


def my_func(model, data_generator, threshold=0.5):
    y_pred_prob = model.predict(data_generator)
    y_pred = (y_pred_prob > threshold).astype(int)
    y_true = data_generator.classes
    print("Classification Report:")
    print(classification_report(y_true, y_pred))

# %%
METRICS = [
    tf.keras.metrics.TruePositives(name="tp"),
    tf.keras.metrics.FalsePositives(name="fp"),
    tf.keras.metrics.TrueNegatives(name="tn"),
    tf.keras.metrics.FalseNegatives(name="fn"),
    tf.keras.metrics.BinaryAccuracy(name="binary_acc"),
    tf.keras.metrics.Precision(name="precision"),
    tf.keras.metrics.Recall(name="recall"),
    F1Score(name="f1_score"),
    tf.keras.metrics.AUC(name="roc_auc", curve="ROC"),
    tf.keras.metrics.AUC(name="pr_auc", curve="PR"),
    tfa.metrics.CohenKappa(name="cohen_kappa", num_classes=2),
]

# %%
vgg = tf.keras.applications.vgg16.VGG16(include_top=include_top,
                                                 weights="imagenet",
                                                 input_shape=(IMAGE_WIDTH, IMAGE_HEIGHT, 3),
                                                # pooling="max",  # pooling mode for feature extraction
                                                 classes=2)

def make_vgg16_model(base_model: tf.keras.applications.vgg16.VGG16,) -> tf.keras.Model:

    # freeze base model
    base_model.trainable = False#trainable

    inputs = tf.keras.Input(shape=(IMAGE_WIDTH, IMAGE_HEIGHT, 3))
    x = base_model(inputs, training=training)
    x = tf.keras.layers.Flatten()(x)
    #x = tf.keras.layers.Dense(4096, activation='relu')(x)
    x = tf.keras.layers.Dense(1024, activation='relu')(x)
    x = tf.keras.layers.Dropout(rate=dropout)(x)
    x = tf.keras.layers.Dense(512, activation='relu')(x)
   # x = tf.keras.layers.Dropout(rate=dropout)(x)

    output = tf.keras.layers.Dense(units=1, activation="sigmoid")(x)

    model = tf.keras.Model(inputs, output)

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
        loss=loss_function,
        metrics=METRICS,
    )

    return model


new_model = make_vgg16_model(base_model=vgg)

new_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 1024)              25691136
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  dense_2 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 40,931,137
# Trainable params: 26,216,449
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
"""import matplotlib.pyplot as plt
from tensorflow.keras.utils import plot_model
tf.keras.utils.plot_model(new_model,
                          show_shapes=True,  # show_dtype=False,
                          show_layer_names=True,
                          layer_range=None,
                          show_layer_activations=True)"""
# Out:
# 'import matplotlib.pyplot as plt\nfrom tensorflow.keras.utils import plot_model\ntf.keras.utils.plot_model(new_model,\n                          show_shapes=True,  # show_dtype=False,\n                          show_layer_names=True,\n                          layer_range=None,\n                          show_layer_activations=True)'

# %%
early_stopping = EarlyStopping(monitor="val_cohen_kappa",
                               verbose=1,
                               patience=early_stopping_patience,
                               mode="max",
                               baseline=0.0,
                               restore_best_weights=True)
save_path = main_save_path + target_category + "/"
model_name = architecture + "_" + target_category
model_path = save_path + '_best_' + model_name + '.keras'
model_checkpoint = ModelCheckpoint(filepath=model_path,
                                       monitor="val_cohen_kappa",
                                       save_best_only=True)

# %%
import pandas as pd


old_base_path = 'C:\\Users\\HP\\Documents\\ML\\encadrement Master\\MURA-V1.1\\'

df_train = pd.read_csv(train_file)
df_train['image_path'] = df_train['image_path'].str.replace(old_base_path, mura_location)

df_valid = pd.read_csv(val_file)
df_valid['image_path'] = df_valid['image_path'].str.replace(old_base_path, mura_location)


df_test = load_data(test_file, target_category)

datagen = tf.keras.preprocessing.image.ImageDataGenerator(rotation_range=30,
                                                              horizontal_flip=True,
                                                              fill_mode="constant",
                                                              cval=0.0,
                                                              preprocessing_function=tf.keras.applications.vgg16.preprocess_input)
train_generator = datagen.flow_from_dataframe(df_train,
                                                  directory=None,
                                                  x_col='image_path',
                                                  y_col='label',
                                                  target_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
                                                  batch_size=batch_size,
                                                  class_mode=class_mode,
                                                  )

validation_generator = datagen.flow_from_dataframe(df_valid,
                                                       directory=None,
                                                       x_col='image_path',
                                                       y_col='label',
                                                       target_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
                                                       batch_size=batch_size,
                                                       class_mode=class_mode,
                                                   shuffle=False
                                                       )

test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
        preprocessing_function=tf.keras.applications.vgg16.preprocess_input)
test_generator = test_datagen.flow_from_dataframe(df_test,
                                                      directory=None,
                                                      x_col='image_path',
                                                      y_col='label',
                                                      target_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
                                                      batch_size=batch_size,
                                                      class_mode=class_mode,
                                                  shuffle=False
                                                      )
# Out:
# C:\Users\raouf\AppData\Local\Temp\ipykernel_31612\1983201427.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'positive' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_data.at[index, 'label'] = "positive"
# Found 6703 validated image filenames belonging to 2 classes.
# Found 1676 validated image filenames belonging to 2 classes.
# Found 563 validated image filenames belonging to 2 classes.

# %%
history = new_model.fit(train_generator,
                            # teps_per_epoch=len(df_train) // batch_size,
                            validation_data=validation_generator,
                            # validation_steps=len(df_valid) // batch_size,
                            epochs=num_epochs,
                            shuffle=shuffle,
                            callbacks=[early_stopping, model_checkpoint])  # , reduce_lr_callback])
# Out:
# Epoch 1/100
# 419/419 [==============================] - 85s 187ms/step - loss: 1.3476 - tp: 1961.0000 - fp: 1415.0000 - tn: 1948.0000 - fn: 1379.0000 - binary_acc: 0.5832 - precision: 0.5809 - recall: 0.5871 - f1_score: 0.5840 - roc_auc: 0.6088 - pr_auc: 0.5863 - cohen_kappa: 0.1664 - val_loss: 0.7122 - val_tp: 618.0000 - val_fp: 398.0000 - val_tn: 450.0000 - val_fn: 210.0000 - val_binary_acc: 0.6372 - val_precision: 0.6083 - val_recall: 0.7464 - val_f1_score: 0.6703 - val_roc_auc: 0.7172 - val_pr_auc: 0.7175 - val_cohen_kappa: 0.2763
# Epoch 2/100
# 419/419 [==============================] - 71s 169ms/step - loss: 0.7797 - tp: 2203.0000 - fp: 1134.0000 - tn: 2229.0000 - fn: 1137.0000 - binary_acc: 0.6612 - precision: 0.6602 - recall: 0.6596 - f1_score: 0.6599 - roc_auc: 0.7099 - pr_auc: 0.7102 - cohen_kappa: 0.3224 - val_loss: 0.7078 - val_tp: 357.0000 - val_fp: 104.0000 - val_tn: 744.0000 - val_fn: 471.0000 - val_binary_acc: 0.6569 - val_precision: 0.7744 - val_recall: 0.4312 - val_f1_score: 0.5539 - val_roc_auc: 0.7328 - val_pr_auc: 0.7396 - val_cohen_kappa: 0.3101
# Epoch 3/100
# 419/419 [==============================] - 72s 172ms/step - loss: 0.6873 - tp: 2207.0000 - fp: 1043.0000 - tn: 2320.0000 - fn: 1133.0000 - binary_acc: 0.6754 - precision: 0.6791 - recall: 0.6608 - f1_score: 0.6698 - roc_auc: 0.7378 - pr_auc: 0.7320 - cohen_kappa: 0.3507 - val_loss: 0.5860 - val_tp: 508.0000 - val_fp: 167.0000 - val_tn: 681.0000 - val_fn: 320.0000 - val_binary_acc: 0.7094 - val_precision: 0.7526 - val_recall: 0.6135 - val_f1_score: 0.6760 - val_roc_auc: 0.7821 - val_pr_auc: 0.7854 - val_cohen_kappa: 0.4175
# Epoch 4/100
# 419/419 [==============================] - 71s 170ms/step - loss: 0.6342 - tp: 2306.0000 - fp: 1008.0000 - tn: 2355.0000 - fn: 1034.0000 - binary_acc: 0.6954 - precision: 0.6958 - recall: 0.6904 - f1_score: 0.6931 - roc_auc: 0.7645 - pr_auc: 0.7687 - cohen_kappa: 0.3907 - val_loss: 0.5852 - val_tp: 638.0000 - val_fp: 309.0000 - val_tn: 539.0000 - val_fn: 190.0000 - val_binary_acc: 0.7023 - val_precision: 0.6737 - val_recall: 0.7705 - val_f1_score: 0.7189 - val_roc_auc: 0.7889 - val_pr_auc: 0.7934 - val_cohen_kappa: 0.4055
# Epoch 5/100
# 419/419 [==============================] - 72s 172ms/step - loss: 0.6079 - tp: 2328.0000 - fp: 950.0000 - tn: 2413.0000 - fn: 1012.0000 - binary_acc: 0.7073 - precision: 0.7102 - recall: 0.6970 - f1_score: 0.7035 - roc_auc: 0.7790 - pr_auc: 0.7856 - cohen_kappa: 0.4145 - val_loss: 0.5394 - val_tp: 532.0000 - val_fp: 143.0000 - val_tn: 705.0000 - val_fn: 296.0000 - val_binary_acc: 0.7381 - val_precision: 0.7881 - val_recall: 0.6425 - val_f1_score: 0.7079 - val_roc_auc: 0.8075 - val_pr_auc: 0.8178 - val_cohen_kappa: 0.4749
# Epoch 6/100
# 419/419 [==============================] - 73s 175ms/step - loss: 0.5789 - tp: 2398.0000 - fp: 883.0000 - tn: 2480.0000 - fn: 942.0000 - binary_acc: 0.7277 - precision: 0.7309 - recall: 0.7180 - f1_score: 0.7244 - roc_auc: 0.7968 - pr_auc: 0.8016 - cohen_kappa: 0.4554 - val_loss: 0.5819 - val_tp: 527.0000 - val_fp: 158.0000 - val_tn: 690.0000 - val_fn: 301.0000 - val_binary_acc: 0.7261 - val_precision: 0.7693 - val_recall: 0.6365 - val_f1_score: 0.6966 - val_roc_auc: 0.7881 - val_pr_auc: 0.7964 - val_cohen_kappa: 0.4511
# Epoch 7/100
# 419/419 [==============================] - 73s 175ms/step - loss: 0.5573 - tp: 2431.0000 - fp: 892.0000 - tn: 2471.0000 - fn: 909.0000 - binary_acc: 0.7313 - precision: 0.7316 - recall: 0.7278 - f1_score: 0.7297 - roc_auc: 0.8067 - pr_auc: 0.8109 - cohen_kappa: 0.4626 - val_loss: 0.5492 - val_tp: 558.0000 - val_fp: 166.0000 - val_tn: 682.0000 - val_fn: 270.0000 - val_binary_acc: 0.7399 - val_precision: 0.7707 - val_recall: 0.6739 - val_f1_score: 0.7191 - val_roc_auc: 0.8153 - val_pr_auc: 0.8238 - val_cohen_kappa: 0.4789
# Epoch 8/100
# 419/419 [==============================] - 74s 177ms/step - loss: 0.5438 - tp: 2449.0000 - fp: 825.0000 - tn: 2538.0000 - fn: 891.0000 - binary_acc: 0.7440 - precision: 0.7480 - recall: 0.7332 - f1_score: 0.7406 - roc_auc: 0.8193 - pr_auc: 0.8219 - cohen_kappa: 0.4879 - val_loss: 0.5726 - val_tp: 622.0000 - val_fp: 279.0000 - val_tn: 569.0000 - val_fn: 206.0000 - val_binary_acc: 0.7106 - val_precision: 0.6903 - val_recall: 0.7512 - val_f1_score: 0.7195 - val_roc_auc: 0.7921 - val_pr_auc: 0.7984 - val_cohen_kappa: 0.4218
# Epoch 9/100
# 419/419 [==============================] - 76s 181ms/step - loss: 0.5356 - tp: 2467.0000 - fp: 781.0000 - tn: 2582.0000 - fn: 873.0000 - binary_acc: 0.7532 - precision: 0.7595 - recall: 0.7386 - f1_score: 0.7489 - roc_auc: 0.8237 - pr_auc: 0.8308 - cohen_kappa: 0.5064 - val_loss: 0.5387 - val_tp: 579.0000 - val_fp: 184.0000 - val_tn: 664.0000 - val_fn: 249.0000 - val_binary_acc: 0.7416 - val_precision: 0.7588 - val_recall: 0.6993 - val_f1_score: 0.7278 - val_roc_auc: 0.8144 - val_pr_auc: 0.8228 - val_cohen_kappa: 0.4827
# Epoch 10/100
# 419/419 [==============================] - 75s 179ms/step - loss: 0.5126 - tp: 2494.0000 - fp: 748.0000 - tn: 2615.0000 - fn: 846.0000 - binary_acc: 0.7622 - precision: 0.7693 - recall: 0.7467 - f1_score: 0.7578 - roc_auc: 0.8387 - pr_auc: 0.8392 - cohen_kappa: 0.5243 - val_loss: 0.5593 - val_tp: 575.0000 - val_fp: 205.0000 - val_tn: 643.0000 - val_fn: 253.0000 - val_binary_acc: 0.7267 - val_precision: 0.7372 - val_recall: 0.6944 - val_f1_score: 0.7152 - val_roc_auc: 0.8003 - val_pr_auc: 0.8112 - val_cohen_kappa: 0.4530
# Epoch 11/100
# 419/419 [==============================] - 75s 179ms/step - loss: 0.5017 - tp: 2520.0000 - fp: 749.0000 - tn: 2614.0000 - fn: 820.0000 - binary_acc: 0.7659 - precision: 0.7709 - recall: 0.7545 - f1_score: 0.7626 - roc_auc: 0.8443 - pr_auc: 0.8485 - cohen_kappa: 0.5318 - val_loss: 0.5767 - val_tp: 656.0000 - val_fp: 294.0000 - val_tn: 554.0000 - val_fn: 172.0000 - val_binary_acc: 0.7220 - val_precision: 0.6905 - val_recall: 0.7923 - val_f1_score: 0.7379 - val_roc_auc: 0.8036 - val_pr_auc: 0.8053 - val_cohen_kappa: 0.4448
# Epoch 12/100
# 419/419 [==============================] - 75s 179ms/step - loss: 0.4942 - tp: 2526.0000 - fp: 750.0000 - tn: 2613.0000 - fn: 814.0000 - binary_acc: 0.7667 - precision: 0.7711 - recall: 0.7563 - f1_score: 0.7636 - roc_auc: 0.8480 - pr_auc: 0.8553 - cohen_kappa: 0.5333 - val_loss: 0.5972 - val_tp: 678.0000 - val_fp: 319.0000 - val_tn: 529.0000 - val_fn: 150.0000 - val_binary_acc: 0.7202 - val_precision: 0.6800 - val_recall: 0.8188 - val_f1_score: 0.7430 - val_roc_auc: 0.8064 - val_pr_auc: 0.8107 - val_cohen_kappa: 0.4416
# Epoch 13/100
# 419/419 [==============================] - 74s 177ms/step - loss: 0.4673 - tp: 2532.0000 - fp: 706.0000 - tn: 2657.0000 - fn: 808.0000 - binary_acc: 0.7741 - precision: 0.7820 - recall: 0.7581 - f1_score: 0.7698 - roc_auc: 0.8619 - pr_auc: 0.8707 - cohen_kappa: 0.5482 - val_loss: 0.5767 - val_tp: 535.0000 - val_fp: 171.0000 - val_tn: 677.0000 - val_fn: 293.0000 - val_binary_acc: 0.7232 - val_precision: 0.7578 - val_recall: 0.6461 - val_f1_score: 0.6975 - val_roc_auc: 0.8031 - val_pr_auc: 0.8120 - val_cohen_kappa: 0.4453
# Epoch 14/100
# 419/419 [==============================] - 73s 175ms/step - loss: 0.4632 - tp: 2579.0000 - fp: 688.0000 - tn: 2675.0000 - fn: 761.0000 - binary_acc: 0.7838 - precision: 0.7894 - recall: 0.7722 - f1_score: 0.7807 - roc_auc: 0.8660 - pr_auc: 0.8739 - cohen_kappa: 0.5676 - val_loss: 0.5963 - val_tp: 512.0000 - val_fp: 132.0000 - val_tn: 716.0000 - val_fn: 316.0000 - val_binary_acc: 0.7327 - val_precision: 0.7950 - val_recall: 0.6184 - val_f1_score: 0.6957 - val_roc_auc: 0.8038 - val_pr_auc: 0.8126 - val_cohen_kappa: 0.4639
# Epoch 15/100
# 419/419 [==============================] - 74s 176ms/step - loss: 0.4603 - tp: 2598.0000 - fp: 682.0000 - tn: 2681.0000 - fn: 742.0000 - binary_acc: 0.7876 - precision: 0.7921 - recall: 0.7778 - f1_score: 0.7849 - roc_auc: 0.8684 - pr_auc: 0.8761 - cohen_kappa: 0.5751 - val_loss: 0.5757 - val_tp: 532.0000 - val_fp: 126.0000 - val_tn: 722.0000 - val_fn: 296.0000 - val_binary_acc: 0.7482 - val_precision: 0.8085 - val_recall: 0.6425 - val_f1_score: 0.7160 - val_roc_auc: 0.8095 - val_pr_auc: 0.8224 - val_cohen_kappa: 0.4951
# Epoch 16/100
# 419/419 [==============================] - 76s 181ms/step - loss: 0.4345 - tp: 2630.0000 - fp: 604.0000 - tn: 2759.0000 - fn: 710.0000 - binary_acc: 0.8040 - precision: 0.8132 - recall: 0.7874 - f1_score: 0.8001 - roc_auc: 0.8829 - pr_auc: 0.8900 - cohen_kappa: 0.6079 - val_loss: 0.6319 - val_tp: 651.0000 - val_fp: 270.0000 - val_tn: 578.0000 - val_fn: 177.0000 - val_binary_acc: 0.7333 - val_precision: 0.7068 - val_recall: 0.7862 - val_f1_score: 0.7444 - val_roc_auc: 0.8079 - val_pr_auc: 0.8028 - val_cohen_kappa: 0.4672
# Epoch 17/100
# 419/419 [==============================] - 73s 174ms/step - loss: 0.4438 - tp: 2596.0000 - fp: 649.0000 - tn: 2714.0000 - fn: 744.0000 - binary_acc: 0.7922 - precision: 0.8000 - recall: 0.7772 - f1_score: 0.7885 - roc_auc: 0.8775 - pr_auc: 0.8849 - cohen_kappa: 0.5843 - val_loss: 0.6119 - val_tp: 649.0000 - val_fp: 261.0000 - val_tn: 587.0000 - val_fn: 179.0000 - val_binary_acc: 0.7375 - val_precision: 0.7132 - val_recall: 0.7838 - val_f1_score: 0.7468 - val_roc_auc: 0.8134 - val_pr_auc: 0.8121 - val_cohen_kappa: 0.4755
# Epoch 18/100
# 419/419 [==============================] - 73s 175ms/step - loss: 0.4191 - tp: 2670.0000 - fp: 600.0000 - tn: 2763.0000 - fn: 670.0000 - binary_acc: 0.8105 - precision: 0.8165 - recall: 0.7994 - f1_score: 0.8079 - roc_auc: 0.8926 - pr_auc: 0.8969 - cohen_kappa: 0.6210 - val_loss: 0.6059 - val_tp: 537.0000 - val_fp: 151.0000 - val_tn: 697.0000 - val_fn: 291.0000 - val_binary_acc: 0.7363 - val_precision: 0.7805 - val_recall: 0.6486 - val_f1_score: 0.7084 - val_roc_auc: 0.8098 - val_pr_auc: 0.8085 - val_cohen_kappa: 0.4714
# Epoch 19/100
# 419/419 [==============================] - 74s 176ms/step - loss: 0.4265 - tp: 2621.0000 - fp: 596.0000 - tn: 2767.0000 - fn: 719.0000 - binary_acc: 0.8038 - precision: 0.8147 - recall: 0.7847 - f1_score: 0.7995 - roc_auc: 0.8874 - pr_auc: 0.8930 - cohen_kappa: 0.6076 - val_loss: 0.5749 - val_tp: 498.0000 - val_fp: 113.0000 - val_tn: 735.0000 - val_fn: 330.0000 - val_binary_acc: 0.7357 - val_precision: 0.8151 - val_recall: 0.6014 - val_f1_score: 0.6921 - val_roc_auc: 0.8170 - val_pr_auc: 0.8259 - val_cohen_kappa: 0.4696
# Epoch 20/100
# 419/419 [==============================] - 74s 177ms/step - loss: 0.4017 - tp: 2690.0000 - fp: 558.0000 - tn: 2805.0000 - fn: 650.0000 - binary_acc: 0.8198 - precision: 0.8282 - recall: 0.8054 - f1_score: 0.8166 - roc_auc: 0.8992 - pr_auc: 0.9055 - cohen_kappa: 0.6395 - val_loss: 0.6100 - val_tp: 686.0000 - val_fp: 313.0000 - val_tn: 535.0000 - val_fn: 142.0000 - val_binary_acc: 0.7285 - val_precision: 0.6867 - val_recall: 0.8285 - val_f1_score: 0.7510 - val_roc_auc: 0.8173 - val_pr_auc: 0.8085 - val_cohen_kappa: 0.4583
# Epoch 21/100
# 419/419 [==============================] - 74s 176ms/step - loss: 0.3960 - tp: 2700.0000 - fp: 579.0000 - tn: 2784.0000 - fn: 640.0000 - binary_acc: 0.8181 - precision: 0.8234 - recall: 0.8084 - f1_score: 0.8158 - roc_auc: 0.9031 - pr_auc: 0.9080 - cohen_kappa: 0.6363 - val_loss: 0.6146 - val_tp: 549.0000 - val_fp: 166.0000 - val_tn: 682.0000 - val_fn: 279.0000 - val_binary_acc: 0.7345 - val_precision: 0.7678 - val_recall: 0.6630 - val_f1_score: 0.7116 - val_roc_auc: 0.8016 - val_pr_auc: 0.8003 - val_cohen_kappa: 0.4680
# Epoch 22/100
# 419/419 [==============================] - 73s 175ms/step - loss: 0.3854 - tp: 2694.0000 - fp: 543.0000 - tn: 2820.0000 - fn: 646.0000 - binary_acc: 0.8226 - precision: 0.8323 - recall: 0.8066 - f1_score: 0.8192 - roc_auc: 0.9073 - pr_auc: 0.9134 - cohen_kappa: 0.6452 - val_loss: 0.6076 - val_tp: 646.0000 - val_fp: 258.0000 - val_tn: 590.0000 - val_fn: 182.0000 - val_binary_acc: 0.7375 - val_precision: 0.7146 - val_recall: 0.7802 - val_f1_score: 0.7460 - val_roc_auc: 0.8067 - val_pr_auc: 0.7987 - val_cohen_kappa: 0.4754
# Epoch 23/100
# 419/419 [==============================] - 73s 175ms/step - loss: 0.3880 - tp: 2720.0000 - fp: 522.0000 - tn: 2841.0000 - fn: 620.0000 - binary_acc: 0.8296 - precision: 0.8390 - recall: 0.8144 - f1_score: 0.8265 - roc_auc: 0.9066 - pr_auc: 0.9147 - cohen_kappa: 0.6592 - val_loss: 0.6200 - val_tp: 594.0000 - val_fp: 192.0000 - val_tn: 656.0000 - val_fn: 234.0000 - val_binary_acc: 0.7458 - val_precision: 0.7557 - val_recall: 0.7174 - val_f1_score: 0.7361 - val_roc_auc: 0.8033 - val_pr_auc: 0.8034 - val_cohen_kappa: 0.4913
# Epoch 24/100
# 419/419 [==============================] - 73s 174ms/step - loss: 0.3734 - tp: 2728.0000 - fp: 515.0000 - tn: 2848.0000 - fn: 612.0000 - binary_acc: 0.8319 - precision: 0.8412 - recall: 0.8168 - f1_score: 0.8288 - roc_auc: 0.9146 - pr_auc: 0.9182 - cohen_kappa: 0.6637 - val_loss: 0.6469 - val_tp: 569.0000 - val_fp: 207.0000 - val_tn: 641.0000 - val_fn: 259.0000 - val_binary_acc: 0.7220 - val_precision: 0.7332 - val_recall: 0.6872 - val_f1_score: 0.7095 - val_roc_auc: 0.7895 - val_pr_auc: 0.7902 - val_cohen_kappa: 0.4434
# Epoch 25/100
# 419/419 [==============================] - 73s 174ms/step - loss: 0.3600 - tp: 2752.0000 - fp: 513.0000 - tn: 2850.0000 - fn: 588.0000 - binary_acc: 0.8357 - precision: 0.8429 - recall: 0.8240 - f1_score: 0.8333 - roc_auc: 0.9189 - pr_auc: 0.9250 - cohen_kappa: 0.6715 - val_loss: 0.6687 - val_tp: 650.0000 - val_fp: 283.0000 - val_tn: 565.0000 - val_fn: 178.0000 - val_binary_acc: 0.7249 - val_precision: 0.6967 - val_recall: 0.7850 - val_f1_score: 0.7382 - val_roc_auc: 0.8049 - val_pr_auc: 0.7969 - val_cohen_kappa: 0.4506
# Epoch 26/100
# 419/419 [==============================] - 73s 174ms/step - loss: 0.3639 - tp: 2766.0000 - fp: 484.0000 - tn: 2879.0000 - fn: 574.0000 - binary_acc: 0.8422 - precision: 0.8511 - recall: 0.8281 - f1_score: 0.8395 - roc_auc: 0.9194 - pr_auc: 0.9255 - cohen_kappa: 0.6843 - val_loss: 0.6197 - val_tp: 625.0000 - val_fp: 225.0000 - val_tn: 623.0000 - val_fn: 203.0000 - val_binary_acc: 0.7446 - val_precision: 0.7353 - val_recall: 0.7548 - val_f1_score: 0.7449 - val_roc_auc: 0.8167 - val_pr_auc: 0.8169 - val_cohen_kappa: 0.4893
# Epoch 27/100
# 419/419 [==============================] - 74s 176ms/step - loss: 0.3485 - tp: 2776.0000 - fp: 463.0000 - tn: 2900.0000 - fn: 564.0000 - binary_acc: 0.8468 - precision: 0.8571 - recall: 0.8311 - f1_score: 0.8439 - roc_auc: 0.9251 - pr_auc: 0.9306 - cohen_kappa: 0.6935 - val_loss: 0.6311 - val_tp: 569.0000 - val_fp: 179.0000 - val_tn: 669.0000 - val_fn: 259.0000 - val_binary_acc: 0.7387 - val_precision: 0.7607 - val_recall: 0.6872 - val_f1_score: 0.7221 - val_roc_auc: 0.8048 - val_pr_auc: 0.8171 - val_cohen_kappa: 0.4767
# Epoch 28/100
# 419/419 [==============================] - 73s 173ms/step - loss: 0.3422 - tp: 2808.0000 - fp: 481.0000 - tn: 2882.0000 - fn: 532.0000 - binary_acc: 0.8489 - precision: 0.8538 - recall: 0.8407 - f1_score: 0.8472 - roc_auc: 0.9278 - pr_auc: 0.9327 - cohen_kappa: 0.6977 - val_loss: 0.6557 - val_tp: 602.0000 - val_fp: 210.0000 - val_tn: 638.0000 - val_fn: 226.0000 - val_binary_acc: 0.7399 - val_precision: 0.7414 - val_recall: 0.7271 - val_f1_score: 0.7341 - val_roc_auc: 0.8036 - val_pr_auc: 0.8070 - val_cohen_kappa: 0.4795
# Epoch 29/100
# 419/419 [==============================] - 73s 174ms/step - loss: 0.3313 - tp: 2798.0000 - fp: 450.0000 - tn: 2913.0000 - fn: 542.0000 - binary_acc: 0.8520 - precision: 0.8615 - recall: 0.8377 - f1_score: 0.8494 - roc_auc: 0.9315 - pr_auc: 0.9377 - cohen_kappa: 0.7040 - val_loss: 0.6352 - val_tp: 588.0000 - val_fp: 179.0000 - val_tn: 669.0000 - val_fn: 240.0000 - val_binary_acc: 0.7500 - val_precision: 0.7666 - val_recall: 0.7101 - val_f1_score: 0.7373 - val_roc_auc: 0.8121 - val_pr_auc: 0.8058 - val_cohen_kappa: 0.4995
# Epoch 30/100
# 419/419 [==============================] - 73s 174ms/step - loss: 0.3246 - tp: 2829.0000 - fp: 444.0000 - tn: 2919.0000 - fn: 511.0000 - binary_acc: 0.8575 - precision: 0.8643 - recall: 0.8470 - f1_score: 0.8556 - roc_auc: 0.9350 - pr_auc: 0.9395 - cohen_kappa: 0.7150 - val_loss: 0.6355 - val_tp: 564.0000 - val_fp: 138.0000 - val_tn: 710.0000 - val_fn: 264.0000 - val_binary_acc: 0.7601 - val_precision: 0.8034 - val_recall: 0.6812 - val_f1_score: 0.7373 - val_roc_auc: 0.8197 - val_pr_auc: 0.8209 - val_cohen_kappa: 0.5194
# Epoch 31/100
# 419/419 [==============================] - 72s 173ms/step - loss: 0.3186 - tp: 2829.0000 - fp: 447.0000 - tn: 2916.0000 - fn: 511.0000 - binary_acc: 0.8571 - precision: 0.8636 - recall: 0.8470 - f1_score: 0.8552 - roc_auc: 0.9377 - pr_auc: 0.9413 - cohen_kappa: 0.7141 - val_loss: 0.6407 - val_tp: 570.0000 - val_fp: 156.0000 - val_tn: 692.0000 - val_fn: 258.0000 - val_binary_acc: 0.7530 - val_precision: 0.7851 - val_recall: 0.6884 - val_f1_score: 0.7336 - val_roc_auc: 0.8173 - val_pr_auc: 0.8193 - val_cohen_kappa: 0.5052
# Epoch 32/100
# 419/419 [==============================] - 72s 172ms/step - loss: 0.3176 - tp: 2845.0000 - fp: 439.0000 - tn: 2924.0000 - fn: 495.0000 - binary_acc: 0.8607 - precision: 0.8663 - recall: 0.8518 - f1_score: 0.8590 - roc_auc: 0.9374 - pr_auc: 0.9418 - cohen_kappa: 0.7213 - val_loss: 0.6306 - val_tp: 586.0000 - val_fp: 195.0000 - val_tn: 653.0000 - val_fn: 242.0000 - val_binary_acc: 0.7393 - val_precision: 0.7503 - val_recall: 0.7077 - val_f1_score: 0.7284 - val_roc_auc: 0.8158 - val_pr_auc: 0.8104 - val_cohen_kappa: 0.4781
# Epoch 33/100
# 419/419 [==============================] - 73s 173ms/step - loss: 0.3119 - tp: 2833.0000 - fp: 395.0000 - tn: 2968.0000 - fn: 507.0000 - binary_acc: 0.8654 - precision: 0.8776 - recall: 0.8482 - f1_score: 0.8627 - roc_auc: 0.9411 - pr_auc: 0.9454 - cohen_kappa: 0.7308 - val_loss: 0.6880 - val_tp: 620.0000 - val_fp: 230.0000 - val_tn: 618.0000 - val_fn: 208.0000 - val_binary_acc: 0.7387 - val_precision: 0.7294 - val_recall: 0.7488 - val_f1_score: 0.7390 - val_roc_auc: 0.8039 - val_pr_auc: 0.7963 - val_cohen_kappa: 0.4774
# Epoch 34/100
# 419/419 [==============================] - 73s 173ms/step - loss: 0.3071 - tp: 2855.0000 - fp: 411.0000 - tn: 2952.0000 - fn: 485.0000 - binary_acc: 0.8663 - precision: 0.8742 - recall: 0.8548 - f1_score: 0.8644 - roc_auc: 0.9431 - pr_auc: 0.9454 - cohen_kappa: 0.7326 - val_loss: 0.6782 - val_tp: 604.0000 - val_fp: 227.0000 - val_tn: 621.0000 - val_fn: 224.0000 - val_binary_acc: 0.7309 - val_precision: 0.7268 - val_recall: 0.7295 - val_f1_score: 0.7281 - val_roc_auc: 0.8094 - val_pr_auc: 0.8004 - val_cohen_kappa: 0.4618
# Epoch 35/100
# 419/419 [==============================] - 74s 176ms/step - loss: 0.2955 - tp: 2888.0000 - fp: 412.0000 - tn: 2951.0000 - fn: 452.0000 - binary_acc: 0.8711 - precision: 0.8752 - recall: 0.8647 - f1_score: 0.8699 - roc_auc: 0.9465 - pr_auc: 0.9479 - cohen_kappa: 0.7422 - val_loss: 0.7109 - val_tp: 549.0000 - val_fp: 141.0000 - val_tn: 707.0000 - val_fn: 279.0000 - val_binary_acc: 0.7494 - val_precision: 0.7957 - val_recall: 0.6630 - val_f1_score: 0.7233 - val_roc_auc: 0.8167 - val_pr_auc: 0.8165 - val_cohen_kappa: 0.4977
# Epoch 36/100
# 419/419 [==============================] - 72s 172ms/step - loss: 0.2869 - tp: 2891.0000 - fp: 396.0000 - tn: 2967.0000 - fn: 449.0000 - binary_acc: 0.8739 - precision: 0.8795 - recall: 0.8656 - f1_score: 0.8725 - roc_auc: 0.9491 - pr_auc: 0.9542 - cohen_kappa: 0.7479 - val_loss: 0.6279 - val_tp: 594.0000 - val_fp: 188.0000 - val_tn: 660.0000 - val_fn: 234.0000 - val_binary_acc: 0.7482 - val_precision: 0.7596 - val_recall: 0.7174 - val_f1_score: 0.7379 - val_roc_auc: 0.8250 - val_pr_auc: 0.8153 - val_cohen_kappa: 0.4960
# Epoch 37/100
# 419/419 [==============================] - 73s 173ms/step - loss: 0.2827 - tp: 2888.0000 - fp: 367.0000 - tn: 2996.0000 - fn: 452.0000 - binary_acc: 0.8778 - precision: 0.8873 - recall: 0.8647 - f1_score: 0.8758 - roc_auc: 0.9505 - pr_auc: 0.9543 - cohen_kappa: 0.7556 - val_loss: 0.6851 - val_tp: 565.0000 - val_fp: 154.0000 - val_tn: 694.0000 - val_fn: 263.0000 - val_binary_acc: 0.7512 - val_precision: 0.7858 - val_recall: 0.6824 - val_f1_score: 0.7304 - val_roc_auc: 0.8212 - val_pr_auc: 0.8208 - val_cohen_kappa: 0.5015
# Epoch 38/100
# 419/419 [==============================] - 73s 173ms/step - loss: 0.2780 - tp: 2916.0000 - fp: 393.0000 - tn: 2970.0000 - fn: 424.0000 - binary_acc: 0.8781 - precision: 0.8812 - recall: 0.8731 - f1_score: 0.8771 - roc_auc: 0.9525 - pr_auc: 0.9561 - cohen_kappa: 0.7562 - val_loss: 0.7000 - val_tp: 548.0000 - val_fp: 152.0000 - val_tn: 696.0000 - val_fn: 280.0000 - val_binary_acc: 0.7422 - val_precision: 0.7829 - val_recall: 0.6618 - val_f1_score: 0.7173 - val_roc_auc: 0.8177 - val_pr_auc: 0.8098 - val_cohen_kappa: 0.4835
# Epoch 39/100
# 419/419 [==============================] - 73s 173ms/step - loss: 0.2758 - tp: 2913.0000 - fp: 364.0000 - tn: 2999.0000 - fn: 427.0000 - binary_acc: 0.8820 - precision: 0.8889 - recall: 0.8722 - f1_score: 0.8805 - roc_auc: 0.9533 - pr_auc: 0.9559 - cohen_kappa: 0.7640 - val_loss: 0.7121 - val_tp: 577.0000 - val_fp: 168.0000 - val_tn: 680.0000 - val_fn: 251.0000 - val_binary_acc: 0.7500 - val_precision: 0.7745 - val_recall: 0.6969 - val_f1_score: 0.7336 - val_roc_auc: 0.8155 - val_pr_auc: 0.8181 - val_cohen_kappa: 0.4993
# Epoch 40/100
# 419/419 [==============================] - 73s 173ms/step - loss: 0.2683 - tp: 2923.0000 - fp: 361.0000 - tn: 3002.0000 - fn: 417.0000 - binary_acc: 0.8839 - precision: 0.8901 - recall: 0.8751 - f1_score: 0.8825 - roc_auc: 0.9557 - pr_auc: 0.9584 - cohen_kappa: 0.7678 - val_loss: 0.7487 - val_tp: 572.0000 - val_fp: 174.0000 - val_tn: 674.0000 - val_fn: 256.0000 - val_binary_acc: 0.7434 - val_precision: 0.7668 - val_recall: 0.6908 - val_f1_score: 0.7268 - val_roc_auc: 0.8085 - val_pr_auc: 0.8039 - val_cohen_kappa: 0.4862
# Epoch 41/100
# 419/419 [==============================] - 73s 174ms/step - loss: 0.2588 - tp: 2940.0000 - fp: 327.0000 - tn: 3036.0000 - fn: 400.0000 - binary_acc: 0.8915 - precision: 0.8999 - recall: 0.8802 - f1_score: 0.8900 - roc_auc: 0.9592 - pr_auc: 0.9617 - cohen_kappa: 0.7831 - val_loss: 0.7475 - val_tp: 631.0000 - val_fp: 222.0000 - val_tn: 626.0000 - val_fn: 197.0000 - val_binary_acc: 0.7500 - val_precision: 0.7397 - val_recall: 0.7621 - val_f1_score: 0.7507 - val_roc_auc: 0.8143 - val_pr_auc: 0.8020 - val_cohen_kappa: 0.5001
# Epoch 42/100
# 419/419 [==============================] - 73s 174ms/step - loss: 0.2501 - tp: 2977.0000 - fp: 357.0000 - tn: 3006.0000 - fn: 363.0000 - binary_acc: 0.8926 - precision: 0.8929 - recall: 0.8913 - f1_score: 0.8921 - roc_auc: 0.9616 - pr_auc: 0.9641 - cohen_kappa: 0.7852 - val_loss: 0.6701 - val_tp: 619.0000 - val_fp: 207.0000 - val_tn: 641.0000 - val_fn: 209.0000 - val_binary_acc: 0.7518 - val_precision: 0.7494 - val_recall: 0.7476 - val_f1_score: 0.7485 - val_roc_auc: 0.8165 - val_pr_auc: 0.8169 - val_cohen_kappa: 0.5035
# Epoch 43/100
# 419/419 [==============================] - 73s 174ms/step - loss: 0.2576 - tp: 2941.0000 - fp: 349.0000 - tn: 3014.0000 - fn: 399.0000 - binary_acc: 0.8884 - precision: 0.8939 - recall: 0.8805 - f1_score: 0.8872 - roc_auc: 0.9598 - pr_auc: 0.9627 - cohen_kappa: 0.7768 - val_loss: 0.8015 - val_tp: 610.0000 - val_fp: 228.0000 - val_tn: 620.0000 - val_fn: 218.0000 - val_binary_acc: 0.7339 - val_precision: 0.7279 - val_recall: 0.7367 - val_f1_score: 0.7323 - val_roc_auc: 0.8032 - val_pr_auc: 0.8008 - val_cohen_kappa: 0.4678
# Epoch 44/100
# 419/419 [==============================] - 73s 173ms/step - loss: 0.2493 - tp: 2947.0000 - fp: 337.0000 - tn: 3026.0000 - fn: 393.0000 - binary_acc: 0.8911 - precision: 0.8974 - recall: 0.8823 - f1_score: 0.8898 - roc_auc: 0.9619 - pr_auc: 0.9639 - cohen_kappa: 0.7822 - val_loss: 0.7560 - val_tp: 558.0000 - val_fp: 186.0000 - val_tn: 662.0000 - val_fn: 270.0000 - val_binary_acc: 0.7279 - val_precision: 0.7500 - val_recall: 0.6739 - val_f1_score: 0.7099 - val_roc_auc: 0.8013 - val_pr_auc: 0.8083 - val_cohen_kappa: 0.4551
# Epoch 45/100
# 419/419 [==============================] - ETA: 0s - loss: 0.2330 - tp: 2990.0000 - fp: 313.0000 - tn: 3050.0000 - fn: 350.0000 - binary_acc: 0.9011 - precision: 0.9052 - recall: 0.8952 - f1_score: 0.9002 - roc_auc: 0.9664 - pr_auc: 0.9694 - cohen_kappa: 0.8022Restoring model weights from the end of the best epoch: 30.
# 419/419 [==============================] - 73s 175ms/step - loss: 0.2330 - tp: 2990.0000 - fp: 313.0000 - tn: 3050.0000 - fn: 350.0000 - binary_acc: 0.9011 - precision: 0.9052 - recall: 0.8952 - f1_score: 0.9002 - roc_auc: 0.9664 - pr_auc: 0.9694 - cohen_kappa: 0.8022 - val_loss: 0.7365 - val_tp: 585.0000 - val_fp: 179.0000 - val_tn: 669.0000 - val_fn: 243.0000 - val_binary_acc: 0.7482 - val_precision: 0.7657 - val_recall: 0.7065 - val_f1_score: 0.7349 - val_roc_auc: 0.8135 - val_pr_auc: 0.8129 - val_cohen_kappa: 0.4959
# Epoch 45: early stopping

# %%
new_model.save(save_path + model_name + '.keras')

plot_metrics(history)

# %%
new_model.evaluate(validation_generator)
new_model.evaluate(test_generator)

    # Make predictions using the validation generator
y_valid_pred_prob = new_model.predict(validation_generator)
y_valid_pred = (y_valid_pred_prob > 0.5).astype(int)
y_valid = validation_generator.classes
print("Classification Report:")
print(classification_report(y_valid, y_valid_pred))

y_pred_prob = new_model.predict(test_generator)
y_pred = (y_pred_prob > 0.5).astype(int)
y_test = test_generator.classes
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# 105/105 [==============================] - 14s 134ms/step - loss: 0.6358 - tp: 559.0000 - fp: 154.0000 - tn: 694.0000 - fn: 269.0000 - binary_acc: 0.7476 - precision: 0.7840 - recall: 0.6751 - f1_score: 0.7255 - roc_auc: 0.8208 - pr_auc: 0.8117 - cohen_kappa: 0.4943
# 36/36 [==============================] - 3s 75ms/step - loss: 0.7613 - tp: 206.0000 - fp: 83.0000 - tn: 202.0000 - fn: 72.0000 - binary_acc: 0.7247 - precision: 0.7128 - recall: 0.7410 - f1_score: 0.7266 - roc_auc: 0.8040 - pr_auc: 0.8209 - cohen_kappa: 0.4496
# 105/105 [==============================] - 14s 135ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.72      0.82      0.77       848
#            1       0.78      0.68      0.73       828
#
#     accuracy                           0.75      1676
#    macro avg       0.75      0.75      0.75      1676
# weighted avg       0.75      0.75      0.75      1676
#
# 36/36 [==============================] - 2s 46ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.74      0.71      0.72       285
#            1       0.71      0.74      0.73       278
#
#     accuracy                           0.72       563
#    macro avg       0.73      0.72      0.72       563
# weighted avg       0.73      0.72      0.72       563

# %%
conf_matrix = confusion_matrix(y_test, y_pred)

# Create ConfusionMatrixDisplay object
cm_display = ConfusionMatrixDisplay(confusion_matrix=conf_matrix)

# Plot the confusion matrix
plt.figure(figsize=(4, 6))  # Adjust the figure size as needed
cm_display.plot(cmap=plt.cm.Blues)  # You can choose any colormap you prefer
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.grid(False)  # Turn off grid
plt.savefig(save_path + model_name + "_confusion_matrix.jpg")
plt.show()

# %%
history_df = pd.DataFrame(history.history)
save_history(model_name, history_df)

new_model.save(save_path + model_name + "_pt_imagenet-{new_model.count_params()}.h5")
vgg.save(save_path + model_name + ".h5")

vgg.trainable = True

new_model.compile(
        optimizer=tf.keras.optimizers.Adam(
            1e-5
        ),  # we need small learning rate to avoid catastrophic forgetting
        loss=tf.keras.losses.BinaryCrossentropy(),
        metrics=METRICS,
    )

model_name = 'finetuned_' + architecture + "_" + target_category

model_path = save_path + '_best_' + model_name + '.keras'
model_checkpoint = ModelCheckpoint(filepath=model_path,
                                       monitor="val_cohen_kappa",
                                       save_best_only=True)

reduce_lr_on_plateau = tf.keras.callbacks.ReduceLROnPlateau(
        monitor="val_cohen_kappa",
        verbose=1,
        patience=4,
        mode="max",
        factor=0.2,
        min_lr=1e-10,
    )
# Out:
# Training history saved to: C:/Users/raouf/Desktop/pfe/history/final/vgg/XR_SHOULDER/VGG_XR_SHOULDER_history.xlsx
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
history = new_model.fit(train_generator,
                            # steps_per_epoch=len(df_train) // batch_size,
                            validation_data=validation_generator,
                            # validation_steps=len(df_valid) // batch_size,
                            epochs=fine_tuning_epochs,
                            shuffle=shuffle,
                            callbacks=[early_stopping, model_checkpoint, reduce_lr_on_plateau])
# Out:
# Epoch 1/50
# 419/419 [==============================] - 117s 259ms/step - loss: 0.3683 - tp: 2938.0000 - fp: 583.0000 - tn: 3065.0000 - fn: 680.0000 - binary_acc: 0.8262 - precision: 0.8344 - recall: 0.8121 - f1_score: 0.8231 - roc_auc: 0.9059 - pr_auc: 0.9114 - cohen_kappa: 0.6523 - val_loss: 0.6800 - val_tp: 686.0000 - val_fp: 309.0000 - val_tn: 539.0000 - val_fn: 142.0000 - val_binary_acc: 0.7309 - val_precision: 0.6894 - val_recall: 0.8285 - val_f1_score: 0.7526 - val_roc_auc: 0.8119 - val_pr_auc: 0.7997 - val_cohen_kappa: 0.4630 - lr: 1.0000e-05
# Epoch 2/50
# 419/419 [==============================] - 103s 246ms/step - loss: 0.3299 - tp: 2774.0000 - fp: 414.0000 - tn: 2949.0000 - fn: 566.0000 - binary_acc: 0.8538 - precision: 0.8701 - recall: 0.8305 - f1_score: 0.8499 - roc_auc: 0.9330 - pr_auc: 0.9369 - cohen_kappa: 0.7075 - val_loss: 0.6345 - val_tp: 686.0000 - val_fp: 276.0000 - val_tn: 572.0000 - val_fn: 142.0000 - val_binary_acc: 0.7506 - val_precision: 0.7131 - val_recall: 0.8285 - val_f1_score: 0.7665 - val_roc_auc: 0.8314 - val_pr_auc: 0.8320 - val_cohen_kappa: 0.5021 - lr: 1.0000e-05
# Epoch 3/50
# 419/419 [==============================] - 105s 249ms/step - loss: 0.3245 - tp: 2783.0000 - fp: 405.0000 - tn: 2958.0000 - fn: 557.0000 - binary_acc: 0.8565 - precision: 0.8730 - recall: 0.8332 - f1_score: 0.8526 - roc_auc: 0.9341 - pr_auc: 0.9402 - cohen_kappa: 0.7129 - val_loss: 0.6348 - val_tp: 632.0000 - val_fp: 231.0000 - val_tn: 617.0000 - val_fn: 196.0000 - val_binary_acc: 0.7452 - val_precision: 0.7323 - val_recall: 0.7633 - val_f1_score: 0.7475 - val_roc_auc: 0.8201 - val_pr_auc: 0.8136 - val_cohen_kappa: 0.4906 - lr: 1.0000e-05
# Epoch 4/50
# 419/419 [==============================] - 104s 249ms/step - loss: 0.3086 - tp: 2833.0000 - fp: 392.0000 - tn: 2971.0000 - fn: 507.0000 - binary_acc: 0.8659 - precision: 0.8784 - recall: 0.8482 - f1_score: 0.8631 - roc_auc: 0.9409 - pr_auc: 0.9445 - cohen_kappa: 0.7317 - val_loss: 0.5915 - val_tp: 560.0000 - val_fp: 138.0000 - val_tn: 710.0000 - val_fn: 268.0000 - val_binary_acc: 0.7578 - val_precision: 0.8023 - val_recall: 0.6763 - val_f1_score: 0.7339 - val_roc_auc: 0.8249 - val_pr_auc: 0.8250 - val_cohen_kappa: 0.5145 - lr: 1.0000e-05
# Epoch 5/50
# 419/419 [==============================] - 105s 251ms/step - loss: 0.2882 - tp: 2893.0000 - fp: 367.0000 - tn: 2996.0000 - fn: 447.0000 - binary_acc: 0.8786 - precision: 0.8874 - recall: 0.8662 - f1_score: 0.8767 - roc_auc: 0.9490 - pr_auc: 0.9524 - cohen_kappa: 0.7571 - val_loss: 0.7361 - val_tp: 462.0000 - val_fp: 85.0000 - val_tn: 763.0000 - val_fn: 366.0000 - val_binary_acc: 0.7309 - val_precision: 0.8446 - val_recall: 0.5580 - val_f1_score: 0.6720 - val_roc_auc: 0.8189 - val_pr_auc: 0.8201 - val_cohen_kappa: 0.4596 - lr: 1.0000e-05
# Epoch 6/50
# 419/419 [==============================] - 104s 249ms/step - loss: 0.2849 - tp: 2901.0000 - fp: 365.0000 - tn: 2998.0000 - fn: 439.0000 - binary_acc: 0.8801 - precision: 0.8882 - recall: 0.8686 - f1_score: 0.8783 - roc_auc: 0.9497 - pr_auc: 0.9530 - cohen_kappa: 0.7601 - val_loss: 0.5715 - val_tp: 618.0000 - val_fp: 183.0000 - val_tn: 665.0000 - val_fn: 210.0000 - val_binary_acc: 0.7655 - val_precision: 0.7715 - val_recall: 0.7464 - val_f1_score: 0.7587 - val_roc_auc: 0.8368 - val_pr_auc: 0.8416 - val_cohen_kappa: 0.5308 - lr: 1.0000e-05
# Epoch 7/50
# 419/419 [==============================] - 104s 249ms/step - loss: 0.2621 - tp: 2938.0000 - fp: 328.0000 - tn: 3035.0000 - fn: 402.0000 - binary_acc: 0.8911 - precision: 0.8996 - recall: 0.8796 - f1_score: 0.8895 - roc_auc: 0.9579 - pr_auc: 0.9610 - cohen_kappa: 0.7822 - val_loss: 0.5892 - val_tp: 603.0000 - val_fp: 177.0000 - val_tn: 671.0000 - val_fn: 225.0000 - val_binary_acc: 0.7601 - val_precision: 0.7731 - val_recall: 0.7283 - val_f1_score: 0.7500 - val_roc_auc: 0.8282 - val_pr_auc: 0.8354 - val_cohen_kappa: 0.5199 - lr: 1.0000e-05
# Epoch 8/50
# 419/419 [==============================] - 104s 249ms/step - loss: 0.2704 - tp: 2906.0000 - fp: 355.0000 - tn: 3008.0000 - fn: 434.0000 - binary_acc: 0.8823 - precision: 0.8911 - recall: 0.8701 - f1_score: 0.8805 - roc_auc: 0.9554 - pr_auc: 0.9579 - cohen_kappa: 0.7646 - val_loss: 0.6431 - val_tp: 609.0000 - val_fp: 186.0000 - val_tn: 662.0000 - val_fn: 219.0000 - val_binary_acc: 0.7584 - val_precision: 0.7660 - val_recall: 0.7355 - val_f1_score: 0.7505 - val_roc_auc: 0.8281 - val_pr_auc: 0.8278 - val_cohen_kappa: 0.5164 - lr: 1.0000e-05
# Epoch 9/50
# 419/419 [==============================] - 103s 245ms/step - loss: 0.2518 - tp: 2934.0000 - fp: 304.0000 - tn: 3059.0000 - fn: 406.0000 - binary_acc: 0.8941 - precision: 0.9061 - recall: 0.8784 - f1_score: 0.8921 - roc_auc: 0.9606 - pr_auc: 0.9638 - cohen_kappa: 0.7881 - val_loss: 0.6570 - val_tp: 677.0000 - val_fp: 302.0000 - val_tn: 546.0000 - val_fn: 151.0000 - val_binary_acc: 0.7297 - val_precision: 0.6915 - val_recall: 0.8176 - val_f1_score: 0.7493 - val_roc_auc: 0.8196 - val_pr_auc: 0.8185 - val_cohen_kappa: 0.4605 - lr: 1.0000e-05
# Epoch 10/50
# 419/419 [==============================] - ETA: 0s - loss: 0.2496 - tp: 2931.0000 - fp: 314.0000 - tn: 3049.0000 - fn: 409.0000 - binary_acc: 0.8921 - precision: 0.9032 - recall: 0.8775 - f1_score: 0.8902 - roc_auc: 0.9618 - pr_auc: 0.9641 - cohen_kappa: 0.7843
# Epoch 10: ReduceLROnPlateau reducing learning rate to 1.9999999494757505e-06.
# 419/419 [==============================] - 103s 246ms/step - loss: 0.2496 - tp: 2931.0000 - fp: 314.0000 - tn: 3049.0000 - fn: 409.0000 - binary_acc: 0.8921 - precision: 0.9032 - recall: 0.8775 - f1_score: 0.8902 - roc_auc: 0.9618 - pr_auc: 0.9641 - cohen_kappa: 0.7843 - val_loss: 0.6780 - val_tp: 530.0000 - val_fp: 115.0000 - val_tn: 733.0000 - val_fn: 298.0000 - val_binary_acc: 0.7536 - val_precision: 0.8217 - val_recall: 0.6401 - val_f1_score: 0.7196 - val_roc_auc: 0.8235 - val_pr_auc: 0.8292 - val_cohen_kappa: 0.5058 - lr: 1.0000e-05
# Epoch 11/50
# 419/419 [==============================] - 103s 245ms/step - loss: 0.1975 - tp: 3029.0000 - fp: 217.0000 - tn: 3146.0000 - fn: 311.0000 - binary_acc: 0.9212 - precision: 0.9331 - recall: 0.9069 - f1_score: 0.9198 - roc_auc: 0.9762 - pr_auc: 0.9777 - cohen_kappa: 0.8424 - val_loss: 0.6807 - val_tp: 613.0000 - val_fp: 173.0000 - val_tn: 675.0000 - val_fn: 215.0000 - val_binary_acc: 0.7685 - val_precision: 0.7799 - val_recall: 0.7403 - val_f1_score: 0.7596 - val_roc_auc: 0.8370 - val_pr_auc: 0.8393 - val_cohen_kappa: 0.5366 - lr: 2.0000e-06
# Epoch 12/50
# 419/419 [==============================] - 103s 245ms/step - loss: 0.1681 - tp: 3077.0000 - fp: 180.0000 - tn: 3183.0000 - fn: 263.0000 - binary_acc: 0.9339 - precision: 0.9447 - recall: 0.9213 - f1_score: 0.9328 - roc_auc: 0.9827 - pr_auc: 0.9843 - cohen_kappa: 0.8678 - val_loss: 0.7182 - val_tp: 621.0000 - val_fp: 173.0000 - val_tn: 675.0000 - val_fn: 207.0000 - val_binary_acc: 0.7733 - val_precision: 0.7821 - val_recall: 0.7500 - val_f1_score: 0.7657 - val_roc_auc: 0.8324 - val_pr_auc: 0.8228 - val_cohen_kappa: 0.5463 - lr: 2.0000e-06
# Epoch 13/50
# 419/419 [==============================] - 103s 245ms/step - loss: 0.1604 - tp: 3084.0000 - fp: 188.0000 - tn: 3175.0000 - fn: 256.0000 - binary_acc: 0.9338 - precision: 0.9425 - recall: 0.9234 - f1_score: 0.9328 - roc_auc: 0.9845 - pr_auc: 0.9852 - cohen_kappa: 0.8675 - val_loss: 0.7238 - val_tp: 631.0000 - val_fp: 190.0000 - val_tn: 658.0000 - val_fn: 197.0000 - val_binary_acc: 0.7691 - val_precision: 0.7686 - val_recall: 0.7621 - val_f1_score: 0.7653 - val_roc_auc: 0.8346 - val_pr_auc: 0.8264 - val_cohen_kappa: 0.5381 - lr: 2.0000e-06
# Epoch 14/50
# 419/419 [==============================] - 103s 245ms/step - loss: 0.1413 - tp: 3133.0000 - fp: 170.0000 - tn: 3193.0000 - fn: 207.0000 - binary_acc: 0.9438 - precision: 0.9485 - recall: 0.9380 - f1_score: 0.9432 - roc_auc: 0.9878 - pr_auc: 0.9886 - cohen_kappa: 0.8875 - val_loss: 0.7267 - val_tp: 623.0000 - val_fp: 178.0000 - val_tn: 670.0000 - val_fn: 205.0000 - val_binary_acc: 0.7715 - val_precision: 0.7778 - val_recall: 0.7524 - val_f1_score: 0.7649 - val_roc_auc: 0.8334 - val_pr_auc: 0.8302 - val_cohen_kappa: 0.5427 - lr: 2.0000e-06
# Epoch 15/50
# 419/419 [==============================] - 103s 245ms/step - loss: 0.1372 - tp: 3136.0000 - fp: 146.0000 - tn: 3217.0000 - fn: 204.0000 - binary_acc: 0.9478 - precision: 0.9555 - recall: 0.9389 - f1_score: 0.9471 - roc_auc: 0.9885 - pr_auc: 0.9888 - cohen_kappa: 0.8956 - val_loss: 0.7850 - val_tp: 638.0000 - val_fp: 193.0000 - val_tn: 655.0000 - val_fn: 190.0000 - val_binary_acc: 0.7715 - val_precision: 0.7677 - val_recall: 0.7705 - val_f1_score: 0.7691 - val_roc_auc: 0.8310 - val_pr_auc: 0.8240 - val_cohen_kappa: 0.5429 - lr: 2.0000e-06
# Epoch 16/50
# 419/419 [==============================] - ETA: 0s - loss: 0.1372 - tp: 3148.0000 - fp: 179.0000 - tn: 3184.0000 - fn: 192.0000 - binary_acc: 0.9447 - precision: 0.9462 - recall: 0.9425 - f1_score: 0.9444 - roc_auc: 0.9885 - pr_auc: 0.9892 - cohen_kappa: 0.8893
# Epoch 16: ReduceLROnPlateau reducing learning rate to 3.999999989900971e-07.
# 419/419 [==============================] - 103s 246ms/step - loss: 0.1372 - tp: 3148.0000 - fp: 179.0000 - tn: 3184.0000 - fn: 192.0000 - binary_acc: 0.9447 - precision: 0.9462 - recall: 0.9425 - f1_score: 0.9444 - roc_auc: 0.9885 - pr_auc: 0.9892 - cohen_kappa: 0.8893 - val_loss: 0.7735 - val_tp: 615.0000 - val_fp: 173.0000 - val_tn: 675.0000 - val_fn: 213.0000 - val_binary_acc: 0.7697 - val_precision: 0.7805 - val_recall: 0.7428 - val_f1_score: 0.7611 - val_roc_auc: 0.8373 - val_pr_auc: 0.8319 - val_cohen_kappa: 0.5391 - lr: 2.0000e-06
# Epoch 17/50
# 419/419 [==============================] - 103s 245ms/step - loss: 0.1260 - tp: 3131.0000 - fp: 132.0000 - tn: 3231.0000 - fn: 209.0000 - binary_acc: 0.9491 - precision: 0.9595 - recall: 0.9374 - f1_score: 0.9484 - roc_auc: 0.9904 - pr_auc: 0.9912 - cohen_kappa: 0.8982 - val_loss: 0.7779 - val_tp: 616.0000 - val_fp: 171.0000 - val_tn: 677.0000 - val_fn: 212.0000 - val_binary_acc: 0.7715 - val_precision: 0.7827 - val_recall: 0.7440 - val_f1_score: 0.7628 - val_roc_auc: 0.8358 - val_pr_auc: 0.8276 - val_cohen_kappa: 0.5426 - lr: 4.0000e-07
# Epoch 18/50
# 419/419 [==============================] - 103s 246ms/step - loss: 0.1237 - tp: 3145.0000 - fp: 143.0000 - tn: 3220.0000 - fn: 195.0000 - binary_acc: 0.9496 - precision: 0.9565 - recall: 0.9416 - f1_score: 0.9490 - roc_auc: 0.9906 - pr_auc: 0.9912 - cohen_kappa: 0.8991 - val_loss: 0.7906 - val_tp: 632.0000 - val_fp: 188.0000 - val_tn: 660.0000 - val_fn: 196.0000 - val_binary_acc: 0.7709 - val_precision: 0.7707 - val_recall: 0.7633 - val_f1_score: 0.7670 - val_roc_auc: 0.8422 - val_pr_auc: 0.8281 - val_cohen_kappa: 0.5416 - lr: 4.0000e-07
# Epoch 19/50
# 419/419 [==============================] - 103s 245ms/step - loss: 0.1217 - tp: 3158.0000 - fp: 158.0000 - tn: 3205.0000 - fn: 182.0000 - binary_acc: 0.9493 - precision: 0.9524 - recall: 0.9455 - f1_score: 0.9489 - roc_auc: 0.9912 - pr_auc: 0.9917 - cohen_kappa: 0.8985 - val_loss: 0.8007 - val_tp: 626.0000 - val_fp: 190.0000 - val_tn: 658.0000 - val_fn: 202.0000 - val_binary_acc: 0.7661 - val_precision: 0.7672 - val_recall: 0.7560 - val_f1_score: 0.7616 - val_roc_auc: 0.8378 - val_pr_auc: 0.8338 - val_cohen_kappa: 0.5321 - lr: 4.0000e-07
# Epoch 20/50
# 419/419 [==============================] - ETA: 0s - loss: 0.1274 - tp: 3147.0000 - fp: 156.0000 - tn: 3207.0000 - fn: 193.0000 - binary_acc: 0.9479 - precision: 0.9528 - recall: 0.9422 - f1_score: 0.9475 - roc_auc: 0.9900 - pr_auc: 0.9903 - cohen_kappa: 0.8959
# Epoch 20: ReduceLROnPlateau reducing learning rate to 8.00000009348878e-08.
# 419/419 [==============================] - 103s 245ms/step - loss: 0.1274 - tp: 3147.0000 - fp: 156.0000 - tn: 3207.0000 - fn: 193.0000 - binary_acc: 0.9479 - precision: 0.9528 - recall: 0.9422 - f1_score: 0.9475 - roc_auc: 0.9900 - pr_auc: 0.9903 - cohen_kappa: 0.8959 - val_loss: 0.7732 - val_tp: 613.0000 - val_fp: 180.0000 - val_tn: 668.0000 - val_fn: 215.0000 - val_binary_acc: 0.7643 - val_precision: 0.7730 - val_recall: 0.7403 - val_f1_score: 0.7563 - val_roc_auc: 0.8368 - val_pr_auc: 0.8315 - val_cohen_kappa: 0.5283 - lr: 4.0000e-07
# Epoch 21/50
# 419/419 [==============================] - 103s 245ms/step - loss: 0.1090 - tp: 3178.0000 - fp: 120.0000 - tn: 3243.0000 - fn: 162.0000 - binary_acc: 0.9579 - precision: 0.9636 - recall: 0.9515 - f1_score: 0.9575 - roc_auc: 0.9932 - pr_auc: 0.9936 - cohen_kappa: 0.9159 - val_loss: 0.7996 - val_tp: 624.0000 - val_fp: 163.0000 - val_tn: 685.0000 - val_fn: 204.0000 - val_binary_acc: 0.7810 - val_precision: 0.7929 - val_recall: 0.7536 - val_f1_score: 0.7728 - val_roc_auc: 0.8369 - val_pr_auc: 0.8247 - val_cohen_kappa: 0.5617 - lr: 8.0000e-08
# Epoch 22/50
# 419/419 [==============================] - 103s 245ms/step - loss: 0.1151 - tp: 3174.0000 - fp: 132.0000 - tn: 3231.0000 - fn: 166.0000 - binary_acc: 0.9555 - precision: 0.9601 - recall: 0.9503 - f1_score: 0.9552 - roc_auc: 0.9920 - pr_auc: 0.9924 - cohen_kappa: 0.9111 - val_loss: 0.7751 - val_tp: 615.0000 - val_fp: 174.0000 - val_tn: 674.0000 - val_fn: 213.0000 - val_binary_acc: 0.7691 - val_precision: 0.7795 - val_recall: 0.7428 - val_f1_score: 0.7607 - val_roc_auc: 0.8404 - val_pr_auc: 0.8383 - val_cohen_kappa: 0.5379 - lr: 8.0000e-08
# Epoch 23/50
# 419/419 [==============================] - 103s 245ms/step - loss: 0.1161 - tp: 3167.0000 - fp: 128.0000 - tn: 3235.0000 - fn: 173.0000 - binary_acc: 0.9551 - precision: 0.9612 - recall: 0.9482 - f1_score: 0.9546 - roc_auc: 0.9920 - pr_auc: 0.9925 - cohen_kappa: 0.9102 - val_loss: 0.7743 - val_tp: 617.0000 - val_fp: 171.0000 - val_tn: 677.0000 - val_fn: 211.0000 - val_binary_acc: 0.7721 - val_precision: 0.7830 - val_recall: 0.7452 - val_f1_score: 0.7636 - val_roc_auc: 0.8402 - val_pr_auc: 0.8328 - val_cohen_kappa: 0.5438 - lr: 8.0000e-08
# Epoch 24/50
# 419/419 [==============================] - 103s 245ms/step - loss: 0.1168 - tp: 3156.0000 - fp: 132.0000 - tn: 3231.0000 - fn: 184.0000 - binary_acc: 0.9529 - precision: 0.9599 - recall: 0.9449 - f1_score: 0.9523 - roc_auc: 0.9917 - pr_auc: 0.9920 - cohen_kappa: 0.9057 - val_loss: 0.7693 - val_tp: 609.0000 - val_fp: 184.0000 - val_tn: 664.0000 - val_fn: 219.0000 - val_binary_acc: 0.7595 - val_precision: 0.7680 - val_recall: 0.7355 - val_f1_score: 0.7514 - val_roc_auc: 0.8386 - val_pr_auc: 0.8329 - val_cohen_kappa: 0.5188 - lr: 8.0000e-08
# Epoch 25/50
# 419/419 [==============================] - ETA: 0s - loss: 0.1188 - tp: 3158.0000 - fp: 136.0000 - tn: 3227.0000 - fn: 182.0000 - binary_acc: 0.9526 - precision: 0.9587 - recall: 0.9455 - f1_score: 0.9521 - roc_auc: 0.9914 - pr_auc: 0.9917 - cohen_kappa: 0.9051
# Epoch 25: ReduceLROnPlateau reducing learning rate to 1.5999999902760466e-08.
# 419/419 [==============================] - 103s 245ms/step - loss: 0.1188 - tp: 3158.0000 - fp: 136.0000 - tn: 3227.0000 - fn: 182.0000 - binary_acc: 0.9526 - precision: 0.9587 - recall: 0.9455 - f1_score: 0.9521 - roc_auc: 0.9914 - pr_auc: 0.9917 - cohen_kappa: 0.9051 - val_loss: 0.7829 - val_tp: 618.0000 - val_fp: 161.0000 - val_tn: 687.0000 - val_fn: 210.0000 - val_binary_acc: 0.7786 - val_precision: 0.7933 - val_recall: 0.7464 - val_f1_score: 0.7691 - val_roc_auc: 0.8387 - val_pr_auc: 0.8349 - val_cohen_kappa: 0.5569 - lr: 8.0000e-08
# Epoch 26/50
# 419/419 [==============================] - 103s 246ms/step - loss: 0.1138 - tp: 3156.0000 - fp: 118.0000 - tn: 3245.0000 - fn: 184.0000 - binary_acc: 0.9549 - precision: 0.9640 - recall: 0.9449 - f1_score: 0.9543 - roc_auc: 0.9925 - pr_auc: 0.9929 - cohen_kappa: 0.9099 - val_loss: 0.7659 - val_tp: 631.0000 - val_fp: 179.0000 - val_tn: 669.0000 - val_fn: 197.0000 - val_binary_acc: 0.7757 - val_precision: 0.7790 - val_recall: 0.7621 - val_f1_score: 0.7705 - val_roc_auc: 0.8463 - val_pr_auc: 0.8396 - val_cohen_kappa: 0.5511 - lr: 1.6000e-08
# Epoch 27/50
# 419/419 [==============================] - 103s 245ms/step - loss: 0.1060 - tp: 3183.0000 - fp: 135.0000 - tn: 3228.0000 - fn: 157.0000 - binary_acc: 0.9564 - precision: 0.9593 - recall: 0.9530 - f1_score: 0.9561 - roc_auc: 0.9935 - pr_auc: 0.9940 - cohen_kappa: 0.9129 - val_loss: 0.7894 - val_tp: 613.0000 - val_fp: 180.0000 - val_tn: 668.0000 - val_fn: 215.0000 - val_binary_acc: 0.7643 - val_precision: 0.7730 - val_recall: 0.7403 - val_f1_score: 0.7563 - val_roc_auc: 0.8362 - val_pr_auc: 0.8338 - val_cohen_kappa: 0.5283 - lr: 1.6000e-08
# Epoch 28/50
# 419/419 [==============================] - 103s 245ms/step - loss: 0.1121 - tp: 3182.0000 - fp: 130.0000 - tn: 3233.0000 - fn: 158.0000 - binary_acc: 0.9570 - precision: 0.9607 - recall: 0.9527 - f1_score: 0.9567 - roc_auc: 0.9926 - pr_auc: 0.9931 - cohen_kappa: 0.9141 - val_loss: 0.8033 - val_tp: 621.0000 - val_fp: 181.0000 - val_tn: 667.0000 - val_fn: 207.0000 - val_binary_acc: 0.7685 - val_precision: 0.7743 - val_recall: 0.7500 - val_f1_score: 0.7620 - val_roc_auc: 0.8378 - val_pr_auc: 0.8302 - val_cohen_kappa: 0.5368 - lr: 1.6000e-08
# Epoch 29/50
# 419/419 [==============================] - ETA: 0s - loss: 0.1074 - tp: 3168.0000 - fp: 117.0000 - tn: 3246.0000 - fn: 172.0000 - binary_acc: 0.9569 - precision: 0.9644 - recall: 0.9485 - f1_score: 0.9564 - roc_auc: 0.9933 - pr_auc: 0.9938 - cohen_kappa: 0.9138
# Epoch 29: ReduceLROnPlateau reducing learning rate to 3.1999999094978194e-09.
# 419/419 [==============================] - 103s 245ms/step - loss: 0.1074 - tp: 3168.0000 - fp: 117.0000 - tn: 3246.0000 - fn: 172.0000 - binary_acc: 0.9569 - precision: 0.9644 - recall: 0.9485 - f1_score: 0.9564 - roc_auc: 0.9933 - pr_auc: 0.9938 - cohen_kappa: 0.9138 - val_loss: 0.7878 - val_tp: 622.0000 - val_fp: 183.0000 - val_tn: 665.0000 - val_fn: 206.0000 - val_binary_acc: 0.7679 - val_precision: 0.7727 - val_recall: 0.7512 - val_f1_score: 0.7618 - val_roc_auc: 0.8401 - val_pr_auc: 0.8316 - val_cohen_kappa: 0.5356 - lr: 1.6000e-08
# Epoch 30/50
# 419/419 [==============================] - 103s 246ms/step - loss: 0.1104 - tp: 3172.0000 - fp: 134.0000 - tn: 3229.0000 - fn: 168.0000 - binary_acc: 0.9549 - precision: 0.9595 - recall: 0.9497 - f1_score: 0.9546 - roc_auc: 0.9929 - pr_auc: 0.9933 - cohen_kappa: 0.9099 - val_loss: 0.7839 - val_tp: 624.0000 - val_fp: 181.0000 - val_tn: 667.0000 - val_fn: 204.0000 - val_binary_acc: 0.7703 - val_precision: 0.7752 - val_recall: 0.7536 - val_f1_score: 0.7642 - val_roc_auc: 0.8424 - val_pr_auc: 0.8357 - val_cohen_kappa: 0.5404 - lr: 3.2000e-09
# Epoch 31/50
# 419/419 [==============================] - 103s 245ms/step - loss: 0.1130 - tp: 3183.0000 - fp: 149.0000 - tn: 3214.0000 - fn: 157.0000 - binary_acc: 0.9543 - precision: 0.9553 - recall: 0.9530 - f1_score: 0.9541 - roc_auc: 0.9926 - pr_auc: 0.9925 - cohen_kappa: 0.9087 - val_loss: 0.8128 - val_tp: 621.0000 - val_fp: 174.0000 - val_tn: 674.0000 - val_fn: 207.0000 - val_binary_acc: 0.7727 - val_precision: 0.7811 - val_recall: 0.7500 - val_f1_score: 0.7652 - val_roc_auc: 0.8371 - val_pr_auc: 0.8231 - val_cohen_kappa: 0.5451 - lr: 3.2000e-09
# Epoch 32/50
# 419/419 [==============================] - 103s 245ms/step - loss: 0.1156 - tp: 3160.0000 - fp: 148.0000 - tn: 3215.0000 - fn: 180.0000 - binary_acc: 0.9511 - precision: 0.9553 - recall: 0.9461 - f1_score: 0.9507 - roc_auc: 0.9921 - pr_auc: 0.9925 - cohen_kappa: 0.9021 - val_loss: 0.8097 - val_tp: 610.0000 - val_fp: 171.0000 - val_tn: 677.0000 - val_fn: 218.0000 - val_binary_acc: 0.7679 - val_precision: 0.7810 - val_recall: 0.7367 - val_f1_score: 0.7582 - val_roc_auc: 0.8397 - val_pr_auc: 0.8334 - val_cohen_kappa: 0.5354 - lr: 3.2000e-09
# Epoch 33/50
# 419/419 [==============================] - 103s 245ms/step - loss: 0.1146 - tp: 3177.0000 - fp: 122.0000 - tn: 3241.0000 - fn: 163.0000 - binary_acc: 0.9575 - precision: 0.9630 - recall: 0.9512 - f1_score: 0.9571 - roc_auc: 0.9921 - pr_auc: 0.9921 - cohen_kappa: 0.9150 - val_loss: 0.7593 - val_tp: 632.0000 - val_fp: 159.0000 - val_tn: 689.0000 - val_fn: 196.0000 - val_binary_acc: 0.7882 - val_precision: 0.7990 - val_recall: 0.7633 - val_f1_score: 0.7807 - val_roc_auc: 0.8455 - val_pr_auc: 0.8320 - val_cohen_kappa: 0.5761 - lr: 3.2000e-09
# Epoch 34/50
# 419/419 [==============================] - 103s 246ms/step - loss: 0.1121 - tp: 3164.0000 - fp: 121.0000 - tn: 3242.0000 - fn: 176.0000 - binary_acc: 0.9557 - precision: 0.9632 - recall: 0.9473 - f1_score: 0.9552 - roc_auc: 0.9925 - pr_auc: 0.9932 - cohen_kappa: 0.9114 - val_loss: 0.8084 - val_tp: 616.0000 - val_fp: 167.0000 - val_tn: 681.0000 - val_fn: 212.0000 - val_binary_acc: 0.7739 - val_precision: 0.7867 - val_recall: 0.7440 - val_f1_score: 0.7647 - val_roc_auc: 0.8362 - val_pr_auc: 0.8279 - val_cohen_kappa: 0.5474 - lr: 3.2000e-09
# Epoch 35/50
# 419/419 [==============================] - 103s 245ms/step - loss: 0.1147 - tp: 3172.0000 - fp: 145.0000 - tn: 3218.0000 - fn: 168.0000 - binary_acc: 0.9533 - precision: 0.9563 - recall: 0.9497 - f1_score: 0.9530 - roc_auc: 0.9922 - pr_auc: 0.9928 - cohen_kappa: 0.9066 - val_loss: 0.7496 - val_tp: 621.0000 - val_fp: 171.0000 - val_tn: 677.0000 - val_fn: 207.0000 - val_binary_acc: 0.7745 - val_precision: 0.7841 - val_recall: 0.7500 - val_f1_score: 0.7667 - val_roc_auc: 0.8437 - val_pr_auc: 0.8340 - val_cohen_kappa: 0.5486 - lr: 3.2000e-09
# Epoch 36/50
# 419/419 [==============================] - 103s 245ms/step - loss: 0.1149 - tp: 3171.0000 - fp: 115.0000 - tn: 3248.0000 - fn: 169.0000 - binary_acc: 0.9576 - precision: 0.9650 - recall: 0.9494 - f1_score: 0.9571 - roc_auc: 0.9919 - pr_auc: 0.9923 - cohen_kappa: 0.9153 - val_loss: 0.7509 - val_tp: 614.0000 - val_fp: 165.0000 - val_tn: 683.0000 - val_fn: 214.0000 - val_binary_acc: 0.7739 - val_precision: 0.7882 - val_recall: 0.7415 - val_f1_score: 0.7642 - val_roc_auc: 0.8476 - val_pr_auc: 0.8447 - val_cohen_kappa: 0.5474 - lr: 3.2000e-09
# Epoch 37/50
# 419/419 [==============================] - ETA: 0s - loss: 0.1111 - tp: 3183.0000 - fp: 130.0000 - tn: 3233.0000 - fn: 157.0000 - binary_acc: 0.9572 - precision: 0.9608 - recall: 0.9530 - f1_score: 0.9569 - roc_auc: 0.9928 - pr_auc: 0.9932 - cohen_kappa: 0.9144
# Epoch 37: ReduceLROnPlateau reducing learning rate to 6.399999641359955e-10.
# 419/419 [==============================] - 103s 245ms/step - loss: 0.1111 - tp: 3183.0000 - fp: 130.0000 - tn: 3233.0000 - fn: 157.0000 - binary_acc: 0.9572 - precision: 0.9608 - recall: 0.9530 - f1_score: 0.9569 - roc_auc: 0.9928 - pr_auc: 0.9932 - cohen_kappa: 0.9144 - val_loss: 0.7599 - val_tp: 612.0000 - val_fp: 160.0000 - val_tn: 688.0000 - val_fn: 216.0000 - val_binary_acc: 0.7757 - val_precision: 0.7927 - val_recall: 0.7391 - val_f1_score: 0.7650 - val_roc_auc: 0.8421 - val_pr_auc: 0.8329 - val_cohen_kappa: 0.5509 - lr: 3.2000e-09
# Epoch 38/50
# 419/419 [==============================] - 103s 246ms/step - loss: 0.1079 - tp: 3177.0000 - fp: 118.0000 - tn: 3245.0000 - fn: 163.0000 - binary_acc: 0.9581 - precision: 0.9642 - recall: 0.9512 - f1_score: 0.9576 - roc_auc: 0.9932 - pr_auc: 0.9936 - cohen_kappa: 0.9162 - val_loss: 0.7834 - val_tp: 622.0000 - val_fp: 175.0000 - val_tn: 673.0000 - val_fn: 206.0000 - val_binary_acc: 0.7727 - val_precision: 0.7804 - val_recall: 0.7512 - val_f1_score: 0.7655 - val_roc_auc: 0.8360 - val_pr_auc: 0.8266 - val_cohen_kappa: 0.5451 - lr: 6.4000e-10
# Epoch 39/50
# 419/419 [==============================] - 103s 245ms/step - loss: 0.1147 - tp: 3161.0000 - fp: 132.0000 - tn: 3231.0000 - fn: 179.0000 - binary_acc: 0.9536 - precision: 0.9599 - recall: 0.9464 - f1_score: 0.9531 - roc_auc: 0.9924 - pr_auc: 0.9927 - cohen_kappa: 0.9072 - val_loss: 0.8200 - val_tp: 607.0000 - val_fp: 162.0000 - val_tn: 686.0000 - val_fn: 221.0000 - val_binary_acc: 0.7715 - val_precision: 0.7893 - val_recall: 0.7331 - val_f1_score: 0.7602 - val_roc_auc: 0.8332 - val_pr_auc: 0.8272 - val_cohen_kappa: 0.5425 - lr: 6.4000e-10
# Epoch 40/50
# 419/419 [==============================] - 103s 245ms/step - loss: 0.1135 - tp: 3185.0000 - fp: 123.0000 - tn: 3240.0000 - fn: 155.0000 - binary_acc: 0.9585 - precision: 0.9628 - recall: 0.9536 - f1_score: 0.9582 - roc_auc: 0.9922 - pr_auc: 0.9928 - cohen_kappa: 0.9170 - val_loss: 0.7664 - val_tp: 616.0000 - val_fp: 170.0000 - val_tn: 678.0000 - val_fn: 212.0000 - val_binary_acc: 0.7721 - val_precision: 0.7837 - val_recall: 0.7440 - val_f1_score: 0.7633 - val_roc_auc: 0.8482 - val_pr_auc: 0.8409 - val_cohen_kappa: 0.5438 - lr: 6.4000e-10
# Epoch 41/50
# 419/419 [==============================] - ETA: 0s - loss: 0.1117 - tp: 3171.0000 - fp: 124.0000 - tn: 3239.0000 - fn: 169.0000 - binary_acc: 0.9563 - precision: 0.9624 - recall: 0.9494 - f1_score: 0.9558 - roc_auc: 0.9925 - pr_auc: 0.9928 - cohen_kappa: 0.9126
# Epoch 41: ReduceLROnPlateau reducing learning rate to 1.27999988386307e-10.
# 419/419 [==============================] - 103s 245ms/step - loss: 0.1117 - tp: 3171.0000 - fp: 124.0000 - tn: 3239.0000 - fn: 169.0000 - binary_acc: 0.9563 - precision: 0.9624 - recall: 0.9494 - f1_score: 0.9558 - roc_auc: 0.9925 - pr_auc: 0.9928 - cohen_kappa: 0.9126 - val_loss: 0.7752 - val_tp: 618.0000 - val_fp: 155.0000 - val_tn: 693.0000 - val_fn: 210.0000 - val_binary_acc: 0.7822 - val_precision: 0.7995 - val_recall: 0.7464 - val_f1_score: 0.7720 - val_roc_auc: 0.8403 - val_pr_auc: 0.8314 - val_cohen_kappa: 0.5640 - lr: 6.4000e-10
# Epoch 42/50
# 419/419 [==============================] - 103s 246ms/step - loss: 0.1126 - tp: 3190.0000 - fp: 142.0000 - tn: 3221.0000 - fn: 150.0000 - binary_acc: 0.9564 - precision: 0.9574 - recall: 0.9551 - f1_score: 0.9562 - roc_auc: 0.9924 - pr_auc: 0.9927 - cohen_kappa: 0.9129 - val_loss: 0.7875 - val_tp: 622.0000 - val_fp: 162.0000 - val_tn: 686.0000 - val_fn: 206.0000 - val_binary_acc: 0.7804 - val_precision: 0.7934 - val_recall: 0.7512 - val_f1_score: 0.7717 - val_roc_auc: 0.8386 - val_pr_auc: 0.8296 - val_cohen_kappa: 0.5605 - lr: 1.2800e-10
# Epoch 43/50
# 419/419 [==============================] - 103s 245ms/step - loss: 0.1117 - tp: 3175.0000 - fp: 125.0000 - tn: 3238.0000 - fn: 165.0000 - binary_acc: 0.9567 - precision: 0.9621 - recall: 0.9506 - f1_score: 0.9563 - roc_auc: 0.9928 - pr_auc: 0.9931 - cohen_kappa: 0.9135 - val_loss: 0.8097 - val_tp: 617.0000 - val_fp: 183.0000 - val_tn: 665.0000 - val_fn: 211.0000 - val_binary_acc: 0.7649 - val_precision: 0.7713 - val_recall: 0.7452 - val_f1_score: 0.7580 - val_roc_auc: 0.8377 - val_pr_auc: 0.8304 - val_cohen_kappa: 0.5296 - lr: 1.2800e-10
# Epoch 44/50
# 419/419 [==============================] - 103s 245ms/step - loss: 0.1111 - tp: 3183.0000 - fp: 126.0000 - tn: 3237.0000 - fn: 157.0000 - binary_acc: 0.9578 - precision: 0.9619 - recall: 0.9530 - f1_score: 0.9574 - roc_auc: 0.9927 - pr_auc: 0.9933 - cohen_kappa: 0.9156 - val_loss: 0.7898 - val_tp: 621.0000 - val_fp: 170.0000 - val_tn: 678.0000 - val_fn: 207.0000 - val_binary_acc: 0.7751 - val_precision: 0.7851 - val_recall: 0.7500 - val_f1_score: 0.7671 - val_roc_auc: 0.8378 - val_pr_auc: 0.8252 - val_cohen_kappa: 0.5498 - lr: 1.2800e-10
# Epoch 45/50
# 419/419 [==============================] - ETA: 0s - loss: 0.1144 - tp: 3152.0000 - fp: 123.0000 - tn: 3240.0000 - fn: 188.0000 - binary_acc: 0.9536 - precision: 0.9624 - recall: 0.9437 - f1_score: 0.9530 - roc_auc: 0.9924 - pr_auc: 0.9927 - cohen_kappa: 0.9072
# Epoch 45: ReduceLROnPlateau reducing learning rate to 1e-10.
# 419/419 [==============================] - 103s 245ms/step - loss: 0.1144 - tp: 3152.0000 - fp: 123.0000 - tn: 3240.0000 - fn: 188.0000 - binary_acc: 0.9536 - precision: 0.9624 - recall: 0.9437 - f1_score: 0.9530 - roc_auc: 0.9924 - pr_auc: 0.9927 - cohen_kappa: 0.9072 - val_loss: 0.7840 - val_tp: 627.0000 - val_fp: 171.0000 - val_tn: 677.0000 - val_fn: 201.0000 - val_binary_acc: 0.7780 - val_precision: 0.7857 - val_recall: 0.7572 - val_f1_score: 0.7712 - val_roc_auc: 0.8407 - val_pr_auc: 0.8325 - val_cohen_kappa: 0.5558 - lr: 1.2800e-10
# Epoch 46/50
# 419/419 [==============================] - 103s 245ms/step - loss: 0.1071 - tp: 3197.0000 - fp: 111.0000 - tn: 3252.0000 - fn: 143.0000 - binary_acc: 0.9621 - precision: 0.9664 - recall: 0.9572 - f1_score: 0.9618 - roc_auc: 0.9931 - pr_auc: 0.9936 - cohen_kappa: 0.9242 - val_loss: 0.7560 - val_tp: 627.0000 - val_fp: 160.0000 - val_tn: 688.0000 - val_fn: 201.0000 - val_binary_acc: 0.7846 - val_precision: 0.7967 - val_recall: 0.7572 - val_f1_score: 0.7765 - val_roc_auc: 0.8474 - val_pr_auc: 0.8390 - val_cohen_kappa: 0.5689 - lr: 1.0000e-10
# Epoch 47/50
# 419/419 [==============================] - 103s 246ms/step - loss: 0.1120 - tp: 3176.0000 - fp: 131.0000 - tn: 3232.0000 - fn: 164.0000 - binary_acc: 0.9560 - precision: 0.9604 - recall: 0.9509 - f1_score: 0.9556 - roc_auc: 0.9924 - pr_auc: 0.9930 - cohen_kappa: 0.9120 - val_loss: 0.7751 - val_tp: 618.0000 - val_fp: 174.0000 - val_tn: 674.0000 - val_fn: 210.0000 - val_binary_acc: 0.7709 - val_precision: 0.7803 - val_recall: 0.7464 - val_f1_score: 0.7630 - val_roc_auc: 0.8397 - val_pr_auc: 0.8288 - val_cohen_kappa: 0.5415 - lr: 1.0000e-10
# Epoch 48/50
# 419/419 [==============================] - ETA: 0s - loss: 0.1191 - tp: 3153.0000 - fp: 128.0000 - tn: 3235.0000 - fn: 187.0000 - binary_acc: 0.9530 - precision: 0.9610 - recall: 0.9440 - f1_score: 0.9524 - roc_auc: 0.9913 - pr_auc: 0.9917 - cohen_kappa: 0.9060Restoring model weights from the end of the best epoch: 33.
# 419/419 [==============================] - 103s 245ms/step - loss: 0.1191 - tp: 3153.0000 - fp: 128.0000 - tn: 3235.0000 - fn: 187.0000 - binary_acc: 0.9530 - precision: 0.9610 - recall: 0.9440 - f1_score: 0.9524 - roc_auc: 0.9913 - pr_auc: 0.9917 - cohen_kappa: 0.9060 - val_loss: 0.7415 - val_tp: 644.0000 - val_fp: 174.0000 - val_tn: 674.0000 - val_fn: 184.0000 - val_binary_acc: 0.7864 - val_precision: 0.7873 - val_recall: 0.7778 - val_f1_score: 0.7825 - val_roc_auc: 0.8454 - val_pr_auc: 0.8375 - val_cohen_kappa: 0.5727 - lr: 1.0000e-10
# Epoch 48: early stopping

# %%
new_model.save(save_path + model_name + '.keras')
plot_metrics(history)

# %%
new_model.evaluate(validation_generator)
new_model.evaluate(test_generator)

# Make predictions using the validation generator
y_valid_pred_prob = new_model.predict(validation_generator)
y_valid_pred = (y_valid_pred_prob > 0.5).astype(int)
y_valid = validation_generator.classes
print("Classification Report:")
print(classification_report(y_valid, y_valid_pred))

# Make predictions using the test generator
y_pred_prob = new_model.predict(test_generator)
y_pred = (y_pred_prob > 0.5).astype(int)
y_test = test_generator.classes
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# 105/105 [==============================] - 15s 145ms/step - loss: 0.7759 - tp: 613.0000 - fp: 170.0000 - tn: 678.0000 - fn: 215.0000 - binary_acc: 0.7703 - precision: 0.7829 - recall: 0.7403 - f1_score: 0.7610 - roc_auc: 0.8419 - pr_auc: 0.8372 - cohen_kappa: 0.5402
# 36/36 [==============================] - 2s 54ms/step - loss: 1.1066 - tp: 204.0000 - fp: 70.0000 - tn: 215.0000 - fn: 74.0000 - binary_acc: 0.7442 - precision: 0.7445 - recall: 0.7338 - f1_score: 0.7391 - roc_auc: 0.8132 - pr_auc: 0.8100 - cohen_kappa: 0.4883
# 105/105 [==============================] - 15s 140ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.76      0.79      0.78       848
#            1       0.78      0.75      0.76       828
#
#     accuracy                           0.77      1676
#    macro avg       0.77      0.77      0.77      1676
# weighted avg       0.77      0.77      0.77      1676
#
# 36/36 [==============================] - 2s 47ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.74      0.75      0.75       285
#            1       0.74      0.73      0.74       278
#
#     accuracy                           0.74       563
#    macro avg       0.74      0.74      0.74       563
# weighted avg       0.74      0.74      0.74       563

# %%
conf_matrix = confusion_matrix(y_test, y_pred)

# Create ConfusionMatrixDisplay object
cm_display = ConfusionMatrixDisplay(confusion_matrix=conf_matrix)

# Plot the confusion matrix
plt.figure(figsize=(4, 6))  # Adjust the figure size as needed
cm_display.plot(cmap=plt.cm.Blues)  # You can choose any colormap you prefer
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.grid(False)  # Turn off grid
plt.savefig(save_path + model_name + "_confusion_matrix.jpg")
plt.show()

# %%
history_df = pd.DataFrame(history.history)
save_history(model_name, history_df)
# Out:
# Training history saved to: C:/Users/raouf/Desktop/pfe/history/final/vgg/XR_SHOULDER/finetuned_VGG_XR_SHOULDER_history.xlsx
