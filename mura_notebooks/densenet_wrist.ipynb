# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
import tensorflow as tf
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras import layers, models
from keras.layers import concatenate, Dense, Conv2D, MaxPooling2D, Flatten, Activation, BatchNormalization, Dropout, \
    Attention
from keras import *
from keras.applications import MobileNet
from keras.applications import VGG16
from keras.applications.resnet import ResNet50
from keras import backend as K
from keras.layers import Layer
import keras.layers as kl
import pandas as pd
from keras.applications import EfficientNetB0
import keras.applications
import numpy as np
import os
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from sklearn.metrics import cohen_kappa_score
import seaborn as sns
import pickle
import tensorflow_addons as tfa
from sklearn import metrics
from tensorflow.keras.applications.resnet import preprocess_input as preprocess_input_resnet
from tensorflow.keras.applications.densenet import preprocess_input as preprocess_input_densenet
from tensorflow.keras.models import load_model
import os
import glob

# %%
main_save_path = "C:/Users/raouf/Desktop/pfe/history/final/densenet/"
mura_location = "C:/Users/raouf/Desktop/pfe/"
data_path = 'C:/Users/raouf/Desktop/pfe/MURA-v1.1/'
train_path = 'C:/Users/raouf/Desktop/pfe/MURA-v1.1/train'
test_path = 'C:/Users/raouf/Desktop/pfe/MURA-v1.1/valid'

train_file = "C:/Users/raouf/Desktop/pfe/datasets/XR_WRIST_df_train.csv"
val_file = "C:/Users/raouf/Desktop/pfe/datasets/XR_WRIST_df_valid.csv"

test_file = "C:/Users/raouf/Desktop/pfe/MURA-v1.1/valid_image_paths.csv"

target_category = "XR_WRIST"
batch_size = 16
num_epochs = 100
fine_tuning_epochs=50
validation_split = 0.2
loss_function = tf.keras.losses.BinaryCrossentropy()
learning_rate = 0.0001
input_shape = (224, 224, 3)
architecture = 'DenseNet'

include_top = False
# metrics=["accuracy"] #, tf.keras.metrics.Precision(), tf.keras.metrics.Recall()
early_stopping_patience = 15
shuffle = True
class_mode = 'binary'  # 'categorical'
IMAGE_WIDTH = 224
IMAGE_HEIGHT = 224
trainable = False
training = False
dropout = 0.2

# %%
def load_data(file, part):
    train_data = pd.read_csv(file)
    train_data = train_data.rename(columns={train_data.columns[0]: 'image_path'})
    train_data['label'] = 2
    string_to_add = mura_location
    train_data['image_path'] = string_to_add + train_data['image_path'].astype(str)
    for index, row in train_data.iterrows():
        if 'positive' in str(row['image_path']).lower():
            train_data.at[index, 'label'] = "positive"
        else:
            train_data.at[index, 'label'] = "negative"

    if part == 0:
        pass
    else:
        train_data = train_data[train_data['image_path'].str.contains(part)]
    return train_data


class CustomCallback(keras.callbacks.Callback):
    def on_test_end(self, logs=None):
        keys = list(logs.keys())
        print(f"tp          :", logs["tp"])
        print(f"fp          :", logs["fp"])
        print(f"tn          :", logs["tn"])
        print(f"fn          :", logs["fn"])
        print(f"binary_acc  :", logs["binary_acc"])
        print(f"precision   :", logs["precision"])
        print(f"recall      :", logs["recall"])
        print(f"f1_score    :", logs["f1_score"])
        print(f"roc_auc     :", logs["roc_auc"])
        print(f"pr_auc      :", logs["pr_auc"])
        print(f"cohen_kappa :", logs["cohen_kappa"])

class F1Score(tf.keras.metrics.Metric):

    def __init__(self, name="f1_score", **kwargs):
        super().__init__(name=name, **kwargs)
        self.f1 = self.add_weight(name="f1", initializer="zeros")
        self.precision_fn = tf.keras.metrics.Precision()
        self.recall_fn = tf.keras.metrics.Recall()

    def update_state(self, y_true, y_pred, sample_weight=None):
        p = self.precision_fn(y_true, y_pred)
        r = self.recall_fn(y_true, y_pred)
        self.f1.assign(2 * ((p * r) / (p + r + 1e-10)))

    def result(self):
        return self.f1

    def reset_state(self):
        # we also need to reset the state of the precision and recall objects
        self.precision_fn.reset_state()
        self.recall_fn.reset_state()
        self.f1.assign(0)


def save_history(name,history_df):

    history_excel_path = (
            save_path +
            name +
            '_history'
            '.xlsx'
    )

    history_df.to_excel(history_excel_path, index=False)
    print("Training history saved to:", history_excel_path)






def plot_metrics(history: tf.keras.callbacks.History,
                 metrics: list = ["loss", "cohen_kappa", "precision", "recall"],
                 ) -> None:
    plt.rcParams["figure.figsize"] = (18, 15)

    for n, metric in enumerate(metrics):
        name = metric.replace("_", " ").capitalize()
        plt.subplot(2, 2, n + 1)
        plt.plot(
            history.epoch, history.history[metric], linewidth=1.8, label="training"
        )
        plt.plot(
            history.epoch,
            history.history["val_" + metric],
            linestyle="--",
            linewidth=1.8,
            label="validation",
        )
        plt.xlabel("epoch")
        plt.ylabel(name)
        if metric == "loss":
            plt.ylim([0, plt.ylim()[1]])
        elif metric == "cohen_kappa":
            plt.ylim([-1, 1])
        else:
            plt.ylim([0, 1])

        plt.legend()



class CustomCallback(keras.callbacks.Callback):
    def on_test_end(self, logs=None):
        keys = list(logs.keys())
        print(f"tp          :", logs["tp"])
        print(f"fp          :", logs["fp"])
        print(f"tn          :", logs["tn"])
        print(f"fn          :", logs["fn"])
        print(f"binary_acc  :", logs["binary_acc"])
        print(f"precision   :", logs["precision"])
        print(f"recall      :", logs["recall"])
        print(f"f1_score    :", logs["f1_score"])
        print(f"roc_auc     :", logs["roc_auc"])
        print(f"pr_auc      :", logs["pr_auc"])
        print(f"cohen_kappa :", logs["cohen_kappa"])


def save_history(name,history_df):

    # Constructing the file name with metric values
    history_excel_path = (
            save_path +
            name +
            '_history'
            '.xlsx'
    )

    history_df.to_excel(history_excel_path, index=False)
    print("Training history saved to:", history_excel_path)




class F1Score(tf.keras.metrics.Metric):

    def __init__(self, name="f1_score", **kwargs):
        super().__init__(name=name, **kwargs)
        self.f1 = self.add_weight(name="f1", initializer="zeros")
        self.precision_fn = tf.keras.metrics.Precision()
        self.recall_fn = tf.keras.metrics.Recall()

    def update_state(self, y_true, y_pred, sample_weight=None):
        p = self.precision_fn(y_true, y_pred)
        r = self.recall_fn(y_true, y_pred)
        self.f1.assign(2 * ((p * r) / (p + r + 1e-10)))

    def result(self):
        return self.f1

    def reset_state(self):
        # we also need to reset the state of the precision and recall objects
        self.precision_fn.reset_state()
        self.recall_fn.reset_state()
        self.f1.assign(0)

def plot_metrics(history: tf.keras.callbacks.History,
                 metrics: list = ["loss", "cohen_kappa", "precision", "recall"],
                 ) -> None:
    plt.rcParams["figure.figsize"] = (18, 15)

    for n, metric in enumerate(metrics):
        name = metric.replace("_", " ").capitalize()
        plt.subplot(2, 2, n + 1)
        plt.plot(
            history.epoch, history.history[metric], linewidth=1.8, label="training"
        )
        plt.plot(
            history.epoch,
            history.history["val_" + metric],
            linestyle="--",
            linewidth=1.8,
            label="validation",
        )
        plt.xlabel("epoch")
        plt.ylabel(name)
        if metric == "loss":
            plt.ylim([0, plt.ylim()[1]])
        elif metric == "cohen_kappa":
            plt.ylim([-1, 1])
        else:
            plt.ylim([0, 1])

        plt.legend()


def my_func(model, data_generator, threshold=0.5):
    y_pred_prob = model.predict(data_generator)
    y_pred = (y_pred_prob > threshold).astype(int)
    y_true = data_generator.classes
    print("Classification Report:")
    print(classification_report(y_true, y_pred))

# %%
METRICS = [
    tf.keras.metrics.TruePositives(name="tp"),
    tf.keras.metrics.FalsePositives(name="fp"),
    tf.keras.metrics.TrueNegatives(name="tn"),
    tf.keras.metrics.FalseNegatives(name="fn"),
    tf.keras.metrics.BinaryAccuracy(name="binary_acc"),
    tf.keras.metrics.Precision(name="precision"),
    tf.keras.metrics.Recall(name="recall"),
    F1Score(name="f1_score"),
    tf.keras.metrics.AUC(name="roc_auc", curve="ROC"),
    tf.keras.metrics.AUC(name="pr_auc", curve="PR"),
    tfa.metrics.CohenKappa(name="cohen_kappa", num_classes=2),
]

# %%
densenet = tf.keras.applications.densenet.DenseNet201(
    include_top=False,  # do not include the fully-connected layer at the top of the network
    weights="imagenet",
    input_shape=(IMAGE_WIDTH, IMAGE_HEIGHT, 3),
    pooling="max",  # pooling mode for feature extraction
    classes=2,
)

def make_densenet_model(base_model: tf.keras.applications.densenet.DenseNet201) -> tf.keras.Model:

    # freeze base model
    base_model.trainable = trainable

    inputs = tf.keras.Input(shape=(IMAGE_WIDTH, IMAGE_HEIGHT, 3))
    x = base_model(inputs, training=training)
    x = tf.keras.layers.Dense(1024, activation='relu')(x)
    x = tf.keras.layers.Dropout(rate=dropout)(x)
    x = tf.keras.layers.Dense(512, activation='relu')(x)

    output = tf.keras.layers.Dense(units=1, activation="sigmoid")(x)

    model = tf.keras.Model(inputs, output)

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
        loss=tf.keras.losses.BinaryCrossentropy(),
        metrics=METRICS,
    )


    return model


new_model = make_densenet_model(base_model=densenet)

new_model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  densenet201 (Functional)    (None, 1920)              18321984
#
#  dense_3 (Dense)             (None, 1024)              1967104
#
#  dropout_1 (Dropout)         (None, 1024)              0
#
#  dense_4 (Dense)             (None, 512)               524800
#
#  dense_5 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 20,814,401
# Trainable params: 2,492,417
# Non-trainable params: 18,321,984
# _________________________________________________________________

# %%
"""import matplotlib.pyplot as plt
from tensorflow.keras.utils import plot_model
tf.keras.utils.plot_model(new_model,
                          show_shapes=True,  # show_dtype=False,
                          show_layer_names=True,
                          layer_range=None,
                          show_layer_activations=True)"""
# Out:
# 'import matplotlib.pyplot as plt\nfrom tensorflow.keras.utils import plot_model\ntf.keras.utils.plot_model(new_model,\n                          show_shapes=True,  # show_dtype=False,\n                          show_layer_names=True,\n                          layer_range=None,\n                          show_layer_activations=True)'

# %%
early_stopping = EarlyStopping(monitor="val_cohen_kappa",
                               verbose=1,
                               patience=early_stopping_patience,
                               mode="max",
                               baseline=0.0,
                               restore_best_weights=True)
save_path = main_save_path + target_category + "/"
model_name = architecture + "_" + target_category
model_path = save_path + '_best_' + model_name + '.keras'
model_checkpoint = ModelCheckpoint(filepath=model_path,
                                       monitor="val_cohen_kappa",
                                       save_best_only=True)

# %%
import pandas as pd


old_base_path = 'C:\\Users\\HP\\Documents\\ML\\encadrement Master\\MURA-V1.1\\'

df_train = pd.read_csv(train_file)
df_train['image_path'] = df_train['image_path'].str.replace(old_base_path, mura_location)

df_valid = pd.read_csv(val_file)
df_valid['image_path'] = df_valid['image_path'].str.replace(old_base_path, mura_location)


df_test = load_data(test_file, target_category)

datagen = tf.keras.preprocessing.image.ImageDataGenerator(rotation_range=30,
                                                              horizontal_flip=True,
                                                              fill_mode="constant",
                                                              cval=0.0,
                                                              preprocessing_function=tf.keras.applications.densenet.preprocess_input)
train_generator = datagen.flow_from_dataframe(df_train,
                                                  directory=None,
                                                  x_col='image_path',
                                                  y_col='label',
                                                  target_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
                                                  batch_size=batch_size,
                                                  class_mode=class_mode,
                                                  )

validation_generator = datagen.flow_from_dataframe(df_valid,
                                                       directory=None,
                                                       x_col='image_path',
                                                       y_col='label',
                                                       target_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
                                                       batch_size=batch_size,
                                                       class_mode=class_mode,
                                                   shuffle=False
                                                       )

test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
        preprocessing_function=tf.keras.applications.densenet.preprocess_input)
test_generator = test_datagen.flow_from_dataframe(df_test,
                                                      directory=None,
                                                      x_col='image_path',
                                                      y_col='label',
                                                      target_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
                                                      batch_size=batch_size,
                                                      class_mode=class_mode,
                                                  shuffle=False
                                                      )
# Out:
# C:\Users\raouf\AppData\Local\Temp\ipykernel_48008\1983201427.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'positive' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_data.at[index, 'label'] = "positive"
# Found 7800 validated image filenames belonging to 2 classes.
# Found 1952 validated image filenames belonging to 2 classes.
# Found 658 validated image filenames belonging to 2 classes.

# %%
history = new_model.fit(train_generator,
                            # teps_per_epoch=len(df_train) // batch_size,
                            validation_data=validation_generator,
                            # validation_steps=len(df_valid) // batch_size,
                            epochs=num_epochs,
                            shuffle=shuffle,
                            callbacks=[early_stopping, model_checkpoint])  # , reduce_lr_callback])
# Out:
# Epoch 1/100
# 488/488 [==============================] - 99s 186ms/step - loss: 0.6030 - tp: 1943.0000 - fp: 995.0000 - tn: 3638.0000 - fn: 1224.0000 - binary_acc: 0.7155 - precision: 0.6613 - recall: 0.6135 - f1_score: 0.6365 - roc_auc: 0.7648 - pr_auc: 0.7074 - cohen_kappa: 0.4034 - val_loss: 0.5327 - val_tp: 414.0000 - val_fp: 62.0000 - val_tn: 1070.0000 - val_fn: 406.0000 - val_binary_acc: 0.7602 - val_precision: 0.8697 - val_recall: 0.5049 - val_f1_score: 0.6389 - val_roc_auc: 0.8308 - val_pr_auc: 0.8152 - val_cohen_kappa: 0.4777
# Epoch 2/100
# 488/488 [==============================] - 93s 190ms/step - loss: 0.5257 - tp: 2031.0000 - fp: 799.0000 - tn: 3834.0000 - fn: 1136.0000 - binary_acc: 0.7519 - precision: 0.7177 - recall: 0.6413 - f1_score: 0.6773 - roc_auc: 0.8089 - pr_auc: 0.7688 - cohen_kappa: 0.4769 - val_loss: 0.4939 - val_tp: 506.0000 - val_fp: 115.0000 - val_tn: 1017.0000 - val_fn: 314.0000 - val_binary_acc: 0.7802 - val_precision: 0.8148 - val_recall: 0.6171 - val_f1_score: 0.7023 - val_roc_auc: 0.8384 - val_pr_auc: 0.8174 - val_cohen_kappa: 0.5333
# Epoch 3/100
# 488/488 [==============================] - 93s 191ms/step - loss: 0.4913 - tp: 2077.0000 - fp: 722.0000 - tn: 3911.0000 - fn: 1090.0000 - binary_acc: 0.7677 - precision: 0.7421 - recall: 0.6558 - f1_score: 0.6963 - roc_auc: 0.8322 - pr_auc: 0.7955 - cohen_kappa: 0.5094 - val_loss: 0.4813 - val_tp: 505.0000 - val_fp: 116.0000 - val_tn: 1016.0000 - val_fn: 315.0000 - val_binary_acc: 0.7792 - val_precision: 0.8132 - val_recall: 0.6159 - val_f1_score: 0.7009 - val_roc_auc: 0.8399 - val_pr_auc: 0.8235 - val_cohen_kappa: 0.5311
# Epoch 4/100
# 488/488 [==============================] - 89s 183ms/step - loss: 0.4746 - tp: 2120.0000 - fp: 666.0000 - tn: 3967.0000 - fn: 1047.0000 - binary_acc: 0.7804 - precision: 0.7609 - recall: 0.6694 - f1_score: 0.7122 - roc_auc: 0.8421 - pr_auc: 0.8128 - cohen_kappa: 0.5359 - val_loss: 0.4907 - val_tp: 460.0000 - val_fp: 70.0000 - val_tn: 1062.0000 - val_fn: 360.0000 - val_binary_acc: 0.7797 - val_precision: 0.8679 - val_recall: 0.5610 - val_f1_score: 0.6815 - val_roc_auc: 0.8511 - val_pr_auc: 0.8355 - val_cohen_kappa: 0.5247
# Epoch 5/100
# 488/488 [==============================] - 89s 181ms/step - loss: 0.4671 - tp: 2125.0000 - fp: 687.0000 - tn: 3946.0000 - fn: 1042.0000 - binary_acc: 0.7783 - precision: 0.7557 - recall: 0.6710 - f1_score: 0.7108 - roc_auc: 0.8482 - pr_auc: 0.8167 - cohen_kappa: 0.5321 - val_loss: 0.4575 - val_tp: 567.0000 - val_fp: 148.0000 - val_tn: 984.0000 - val_fn: 253.0000 - val_binary_acc: 0.7946 - val_precision: 0.7930 - val_recall: 0.6915 - val_f1_score: 0.7388 - val_roc_auc: 0.8536 - val_pr_auc: 0.8372 - val_cohen_kappa: 0.5708
# Epoch 6/100
# 488/488 [==============================] - 87s 178ms/step - loss: 0.4573 - tp: 2141.0000 - fp: 616.0000 - tn: 4017.0000 - fn: 1026.0000 - binary_acc: 0.7895 - precision: 0.7766 - recall: 0.6760 - f1_score: 0.7228 - roc_auc: 0.8549 - pr_auc: 0.8236 - cohen_kappa: 0.5544 - val_loss: 0.5107 - val_tp: 433.0000 - val_fp: 44.0000 - val_tn: 1088.0000 - val_fn: 387.0000 - val_binary_acc: 0.7792 - val_precision: 0.9078 - val_recall: 0.5280 - val_f1_score: 0.6677 - val_roc_auc: 0.8506 - val_pr_auc: 0.8374 - val_cohen_kappa: 0.5191
# Epoch 7/100
# 488/488 [==============================] - 87s 179ms/step - loss: 0.4468 - tp: 2168.0000 - fp: 594.0000 - tn: 4039.0000 - fn: 999.0000 - binary_acc: 0.7958 - precision: 0.7849 - recall: 0.6846 - f1_score: 0.7313 - roc_auc: 0.8621 - pr_auc: 0.8325 - cohen_kappa: 0.5678 - val_loss: 0.4683 - val_tp: 588.0000 - val_fp: 197.0000 - val_tn: 935.0000 - val_fn: 232.0000 - val_binary_acc: 0.7802 - val_precision: 0.7490 - val_recall: 0.7171 - val_f1_score: 0.7327 - val_roc_auc: 0.8500 - val_pr_auc: 0.8326 - val_cohen_kappa: 0.5463
# Epoch 8/100
# 488/488 [==============================] - 86s 177ms/step - loss: 0.4389 - tp: 2171.0000 - fp: 592.0000 - tn: 4041.0000 - fn: 996.0000 - binary_acc: 0.7964 - precision: 0.7857 - recall: 0.6855 - f1_score: 0.7322 - roc_auc: 0.8672 - pr_auc: 0.8400 - cohen_kappa: 0.5692 - val_loss: 0.5585 - val_tp: 404.0000 - val_fp: 28.0000 - val_tn: 1104.0000 - val_fn: 416.0000 - val_binary_acc: 0.7725 - val_precision: 0.9352 - val_recall: 0.4927 - val_f1_score: 0.6454 - val_roc_auc: 0.8552 - val_pr_auc: 0.8383 - val_cohen_kappa: 0.5006
# Epoch 9/100
# 488/488 [==============================] - 87s 178ms/step - loss: 0.4349 - tp: 2175.0000 - fp: 595.0000 - tn: 4038.0000 - fn: 992.0000 - binary_acc: 0.7965 - precision: 0.7852 - recall: 0.6868 - f1_score: 0.7327 - roc_auc: 0.8686 - pr_auc: 0.8443 - cohen_kappa: 0.5696 - val_loss: 0.4645 - val_tp: 605.0000 - val_fp: 190.0000 - val_tn: 942.0000 - val_fn: 215.0000 - val_binary_acc: 0.7925 - val_precision: 0.7610 - val_recall: 0.7378 - val_f1_score: 0.7492 - val_roc_auc: 0.8548 - val_pr_auc: 0.8392 - val_cohen_kappa: 0.5724
# Epoch 10/100
# 488/488 [==============================] - 88s 180ms/step - loss: 0.4359 - tp: 2193.0000 - fp: 552.0000 - tn: 4081.0000 - fn: 974.0000 - binary_acc: 0.8044 - precision: 0.7989 - recall: 0.6925 - f1_score: 0.7419 - roc_auc: 0.8672 - pr_auc: 0.8427 - cohen_kappa: 0.5857 - val_loss: 0.4681 - val_tp: 613.0000 - val_fp: 211.0000 - val_tn: 921.0000 - val_fn: 207.0000 - val_binary_acc: 0.7859 - val_precision: 0.7439 - val_recall: 0.7476 - val_f1_score: 0.7457 - val_roc_auc: 0.8534 - val_pr_auc: 0.8356 - val_cohen_kappa: 0.5608
# Epoch 11/100
# 488/488 [==============================] - 89s 181ms/step - loss: 0.4252 - tp: 2201.0000 - fp: 552.0000 - tn: 4081.0000 - fn: 966.0000 - binary_acc: 0.8054 - precision: 0.7995 - recall: 0.6950 - f1_score: 0.7436 - roc_auc: 0.8746 - pr_auc: 0.8498 - cohen_kappa: 0.5880 - val_loss: 0.4793 - val_tp: 483.0000 - val_fp: 83.0000 - val_tn: 1049.0000 - val_fn: 337.0000 - val_binary_acc: 0.7848 - val_precision: 0.8534 - val_recall: 0.5890 - val_f1_score: 0.6970 - val_roc_auc: 0.8548 - val_pr_auc: 0.8357 - val_cohen_kappa: 0.5387
# Epoch 12/100
# 488/488 [==============================] - 89s 183ms/step - loss: 0.4222 - tp: 2214.0000 - fp: 547.0000 - tn: 4086.0000 - fn: 953.0000 - binary_acc: 0.8077 - precision: 0.8019 - recall: 0.6991 - f1_score: 0.7470 - roc_auc: 0.8756 - pr_auc: 0.8532 - cohen_kappa: 0.5930 - val_loss: 0.5112 - val_tp: 681.0000 - val_fp: 371.0000 - val_tn: 761.0000 - val_fn: 139.0000 - val_binary_acc: 0.7387 - val_precision: 0.6473 - val_recall: 0.8305 - val_f1_score: 0.7276 - val_roc_auc: 0.8530 - val_pr_auc: 0.8384 - val_cohen_kappa: 0.4839
# Epoch 13/100
# 488/488 [==============================] - 89s 182ms/step - loss: 0.4159 - tp: 2227.0000 - fp: 536.0000 - tn: 4097.0000 - fn: 940.0000 - binary_acc: 0.8108 - precision: 0.8060 - recall: 0.7032 - f1_score: 0.7511 - roc_auc: 0.8793 - pr_auc: 0.8595 - cohen_kappa: 0.5996 - val_loss: 0.4806 - val_tp: 456.0000 - val_fp: 54.0000 - val_tn: 1078.0000 - val_fn: 364.0000 - val_binary_acc: 0.7859 - val_precision: 0.8941 - val_recall: 0.5561 - val_f1_score: 0.6857 - val_roc_auc: 0.8582 - val_pr_auc: 0.8462 - val_cohen_kappa: 0.5363
# Epoch 14/100
# 488/488 [==============================] - 92s 188ms/step - loss: 0.4079 - tp: 2230.0000 - fp: 506.0000 - tn: 4127.0000 - fn: 937.0000 - binary_acc: 0.8150 - precision: 0.8151 - recall: 0.7041 - f1_score: 0.7555 - roc_auc: 0.8840 - pr_auc: 0.8651 - cohen_kappa: 0.6080 - val_loss: 0.4654 - val_tp: 604.0000 - val_fp: 178.0000 - val_tn: 954.0000 - val_fn: 216.0000 - val_binary_acc: 0.7982 - val_precision: 0.7724 - val_recall: 0.7366 - val_f1_score: 0.7541 - val_roc_auc: 0.8555 - val_pr_auc: 0.8396 - val_cohen_kappa: 0.5831
# Epoch 15/100
# 488/488 [==============================] - 88s 180ms/step - loss: 0.4073 - tp: 2243.0000 - fp: 511.0000 - tn: 4122.0000 - fn: 924.0000 - binary_acc: 0.8160 - precision: 0.8145 - recall: 0.7082 - f1_score: 0.7576 - roc_auc: 0.8848 - pr_auc: 0.8629 - cohen_kappa: 0.6105 - val_loss: 0.4924 - val_tp: 459.0000 - val_fp: 49.0000 - val_tn: 1083.0000 - val_fn: 361.0000 - val_binary_acc: 0.7900 - val_precision: 0.9035 - val_recall: 0.5598 - val_f1_score: 0.6913 - val_roc_auc: 0.8573 - val_pr_auc: 0.8381 - val_cohen_kappa: 0.5450
# Epoch 16/100
# 488/488 [==============================] - 89s 182ms/step - loss: 0.4038 - tp: 2251.0000 - fp: 495.0000 - tn: 4138.0000 - fn: 916.0000 - binary_acc: 0.8191 - precision: 0.8197 - recall: 0.7108 - f1_score: 0.7614 - roc_auc: 0.8873 - pr_auc: 0.8670 - cohen_kappa: 0.6169 - val_loss: 0.4591 - val_tp: 542.0000 - val_fp: 129.0000 - val_tn: 1003.0000 - val_fn: 278.0000 - val_binary_acc: 0.7915 - val_precision: 0.8077 - val_recall: 0.6610 - val_f1_score: 0.7270 - val_roc_auc: 0.8526 - val_pr_auc: 0.8427 - val_cohen_kappa: 0.5611
# Epoch 17/100
# 488/488 [==============================] - 88s 180ms/step - loss: 0.4006 - tp: 2273.0000 - fp: 486.0000 - tn: 4147.0000 - fn: 894.0000 - binary_acc: 0.8231 - precision: 0.8238 - recall: 0.7177 - f1_score: 0.7671 - roc_auc: 0.8900 - pr_auc: 0.8674 - cohen_kappa: 0.6256 - val_loss: 0.4476 - val_tp: 600.0000 - val_fp: 165.0000 - val_tn: 967.0000 - val_fn: 220.0000 - val_binary_acc: 0.8028 - val_precision: 0.7843 - val_recall: 0.7317 - val_f1_score: 0.7571 - val_roc_auc: 0.8635 - val_pr_auc: 0.8480 - val_cohen_kappa: 0.5914
# Epoch 18/100
# 488/488 [==============================] - 90s 184ms/step - loss: 0.3939 - tp: 2280.0000 - fp: 504.0000 - tn: 4129.0000 - fn: 887.0000 - binary_acc: 0.8217 - precision: 0.8190 - recall: 0.7199 - f1_score: 0.7663 - roc_auc: 0.8926 - pr_auc: 0.8730 - cohen_kappa: 0.6231 - val_loss: 0.4690 - val_tp: 611.0000 - val_fp: 187.0000 - val_tn: 945.0000 - val_fn: 209.0000 - val_binary_acc: 0.7971 - val_precision: 0.7657 - val_recall: 0.7451 - val_f1_score: 0.7553 - val_roc_auc: 0.8599 - val_pr_auc: 0.8465 - val_cohen_kappa: 0.5821
# Epoch 19/100
# 488/488 [==============================] - 88s 180ms/step - loss: 0.3939 - tp: 2296.0000 - fp: 495.0000 - tn: 4138.0000 - fn: 871.0000 - binary_acc: 0.8249 - precision: 0.8226 - recall: 0.7250 - f1_score: 0.7707 - roc_auc: 0.8940 - pr_auc: 0.8730 - cohen_kappa: 0.6300 - val_loss: 0.4722 - val_tp: 635.0000 - val_fp: 239.0000 - val_tn: 893.0000 - val_fn: 185.0000 - val_binary_acc: 0.7828 - val_precision: 0.7265 - val_recall: 0.7744 - val_f1_score: 0.7497 - val_roc_auc: 0.8560 - val_pr_auc: 0.8444 - val_cohen_kappa: 0.5582
# Epoch 20/100
# 488/488 [==============================] - 89s 182ms/step - loss: 0.3934 - tp: 2279.0000 - fp: 471.0000 - tn: 4162.0000 - fn: 888.0000 - binary_acc: 0.8258 - precision: 0.8287 - recall: 0.7196 - f1_score: 0.7703 - roc_auc: 0.8934 - pr_auc: 0.8731 - cohen_kappa: 0.6311 - val_loss: 0.4653 - val_tp: 532.0000 - val_fp: 110.0000 - val_tn: 1022.0000 - val_fn: 288.0000 - val_binary_acc: 0.7961 - val_precision: 0.8287 - val_recall: 0.6488 - val_f1_score: 0.7278 - val_roc_auc: 0.8542 - val_pr_auc: 0.8345 - val_cohen_kappa: 0.5686
# Epoch 21/100
# 488/488 [==============================] - 88s 180ms/step - loss: 0.3878 - tp: 2279.0000 - fp: 470.0000 - tn: 4163.0000 - fn: 888.0000 - binary_acc: 0.8259 - precision: 0.8290 - recall: 0.7196 - f1_score: 0.7705 - roc_auc: 0.8966 - pr_auc: 0.8775 - cohen_kappa: 0.6313 - val_loss: 0.4606 - val_tp: 610.0000 - val_fp: 203.0000 - val_tn: 929.0000 - val_fn: 210.0000 - val_binary_acc: 0.7884 - val_precision: 0.7503 - val_recall: 0.7439 - val_f1_score: 0.7471 - val_roc_auc: 0.8608 - val_pr_auc: 0.8479 - val_cohen_kappa: 0.5652
# Epoch 22/100
# 488/488 [==============================] - 90s 185ms/step - loss: 0.3789 - tp: 2297.0000 - fp: 492.0000 - tn: 4141.0000 - fn: 870.0000 - binary_acc: 0.8254 - precision: 0.8236 - recall: 0.7253 - f1_score: 0.7713 - roc_auc: 0.9018 - pr_auc: 0.8810 - cohen_kappa: 0.6310 - val_loss: 0.4572 - val_tp: 600.0000 - val_fp: 183.0000 - val_tn: 949.0000 - val_fn: 220.0000 - val_binary_acc: 0.7935 - val_precision: 0.7663 - val_recall: 0.7317 - val_f1_score: 0.7486 - val_roc_auc: 0.8618 - val_pr_auc: 0.8442 - val_cohen_kappa: 0.5736
# Epoch 23/100
# 488/488 [==============================] - 88s 181ms/step - loss: 0.3768 - tp: 2308.0000 - fp: 496.0000 - tn: 4137.0000 - fn: 859.0000 - binary_acc: 0.8263 - precision: 0.8231 - recall: 0.7288 - f1_score: 0.7731 - roc_auc: 0.9020 - pr_auc: 0.8848 - cohen_kappa: 0.6332 - val_loss: 0.4486 - val_tp: 568.0000 - val_fp: 115.0000 - val_tn: 1017.0000 - val_fn: 252.0000 - val_binary_acc: 0.8120 - val_precision: 0.8316 - val_recall: 0.6927 - val_f1_score: 0.7558 - val_roc_auc: 0.8667 - val_pr_auc: 0.8539 - val_cohen_kappa: 0.6050
# Epoch 24/100
# 488/488 [==============================] - 89s 182ms/step - loss: 0.3799 - tp: 2313.0000 - fp: 455.0000 - tn: 4178.0000 - fn: 854.0000 - binary_acc: 0.8322 - precision: 0.8356 - recall: 0.7303 - f1_score: 0.7794 - roc_auc: 0.9005 - pr_auc: 0.8837 - cohen_kappa: 0.6450 - val_loss: 0.4629 - val_tp: 555.0000 - val_fp: 134.0000 - val_tn: 998.0000 - val_fn: 265.0000 - val_binary_acc: 0.7956 - val_precision: 0.8055 - val_recall: 0.6768 - val_f1_score: 0.7356 - val_roc_auc: 0.8531 - val_pr_auc: 0.8385 - val_cohen_kappa: 0.5710
# Epoch 25/100
# 488/488 [==============================] - 87s 179ms/step - loss: 0.3701 - tp: 2344.0000 - fp: 469.0000 - tn: 4164.0000 - fn: 823.0000 - binary_acc: 0.8344 - precision: 0.8333 - recall: 0.7401 - f1_score: 0.7839 - roc_auc: 0.9062 - pr_auc: 0.8892 - cohen_kappa: 0.6504 - val_loss: 0.4431 - val_tp: 580.0000 - val_fp: 144.0000 - val_tn: 988.0000 - val_fn: 240.0000 - val_binary_acc: 0.8033 - val_precision: 0.8011 - val_recall: 0.7073 - val_f1_score: 0.7513 - val_roc_auc: 0.8657 - val_pr_auc: 0.8531 - val_cohen_kappa: 0.5896
# Epoch 26/100
# 488/488 [==============================] - 88s 180ms/step - loss: 0.3659 - tp: 2325.0000 - fp: 461.0000 - tn: 4172.0000 - fn: 842.0000 - binary_acc: 0.8329 - precision: 0.8345 - recall: 0.7341 - f1_score: 0.7811 - roc_auc: 0.9087 - pr_auc: 0.8901 - cohen_kappa: 0.6469 - val_loss: 0.4531 - val_tp: 572.0000 - val_fp: 145.0000 - val_tn: 987.0000 - val_fn: 248.0000 - val_binary_acc: 0.7987 - val_precision: 0.7978 - val_recall: 0.6976 - val_f1_score: 0.7443 - val_roc_auc: 0.8670 - val_pr_auc: 0.8479 - val_cohen_kappa: 0.5795
# Epoch 27/100
# 488/488 [==============================] - 85s 175ms/step - loss: 0.3627 - tp: 2342.0000 - fp: 471.0000 - tn: 4162.0000 - fn: 825.0000 - binary_acc: 0.8338 - precision: 0.8326 - recall: 0.7395 - f1_score: 0.7833 - roc_auc: 0.9096 - pr_auc: 0.8940 - cohen_kappa: 0.6493 - val_loss: 0.4663 - val_tp: 543.0000 - val_fp: 127.0000 - val_tn: 1005.0000 - val_fn: 277.0000 - val_binary_acc: 0.7930 - val_precision: 0.8104 - val_recall: 0.6622 - val_f1_score: 0.7289 - val_roc_auc: 0.8564 - val_pr_auc: 0.8403 - val_cohen_kappa: 0.5642
# Epoch 28/100
# 488/488 [==============================] - 85s 174ms/step - loss: 0.3673 - tp: 2350.0000 - fp: 453.0000 - tn: 4180.0000 - fn: 817.0000 - binary_acc: 0.8372 - precision: 0.8384 - recall: 0.7420 - f1_score: 0.7873 - roc_auc: 0.9062 - pr_auc: 0.8920 - cohen_kappa: 0.6562 - val_loss: 0.4440 - val_tp: 580.0000 - val_fp: 137.0000 - val_tn: 995.0000 - val_fn: 240.0000 - val_binary_acc: 0.8069 - val_precision: 0.8089 - val_recall: 0.7073 - val_f1_score: 0.7547 - val_roc_auc: 0.8683 - val_pr_auc: 0.8517 - val_cohen_kappa: 0.5966
# Epoch 29/100
# 488/488 [==============================] - 85s 174ms/step - loss: 0.3541 - tp: 2365.0000 - fp: 452.0000 - tn: 4181.0000 - fn: 802.0000 - binary_acc: 0.8392 - precision: 0.8395 - recall: 0.7468 - f1_score: 0.7904 - roc_auc: 0.9135 - pr_auc: 0.8981 - cohen_kappa: 0.6608 - val_loss: 0.4695 - val_tp: 561.0000 - val_fp: 141.0000 - val_tn: 991.0000 - val_fn: 259.0000 - val_binary_acc: 0.7951 - val_precision: 0.7991 - val_recall: 0.6841 - val_f1_score: 0.7372 - val_roc_auc: 0.8622 - val_pr_auc: 0.8492 - val_cohen_kappa: 0.5709
# Epoch 30/100
# 488/488 [==============================] - 87s 178ms/step - loss: 0.3614 - tp: 2360.0000 - fp: 452.0000 - tn: 4181.0000 - fn: 807.0000 - binary_acc: 0.8386 - precision: 0.8393 - recall: 0.7452 - f1_score: 0.7894 - roc_auc: 0.9101 - pr_auc: 0.8932 - cohen_kappa: 0.6593 - val_loss: 0.4447 - val_tp: 563.0000 - val_fp: 103.0000 - val_tn: 1029.0000 - val_fn: 257.0000 - val_binary_acc: 0.8156 - val_precision: 0.8453 - val_recall: 0.6866 - val_f1_score: 0.7577 - val_roc_auc: 0.8678 - val_pr_auc: 0.8508 - val_cohen_kappa: 0.6114
# Epoch 31/100
# 488/488 [==============================] - 84s 173ms/step - loss: 0.3514 - tp: 2389.0000 - fp: 440.0000 - tn: 4193.0000 - fn: 778.0000 - binary_acc: 0.8438 - precision: 0.8445 - recall: 0.7543 - f1_score: 0.7969 - roc_auc: 0.9163 - pr_auc: 0.8988 - cohen_kappa: 0.6707 - val_loss: 0.4934 - val_tp: 512.0000 - val_fp: 92.0000 - val_tn: 1040.0000 - val_fn: 308.0000 - val_binary_acc: 0.7951 - val_precision: 0.8477 - val_recall: 0.6244 - val_f1_score: 0.7191 - val_roc_auc: 0.8676 - val_pr_auc: 0.8504 - val_cohen_kappa: 0.5636
# Epoch 32/100
# 488/488 [==============================] - 85s 174ms/step - loss: 0.3519 - tp: 2387.0000 - fp: 439.0000 - tn: 4194.0000 - fn: 780.0000 - binary_acc: 0.8437 - precision: 0.8447 - recall: 0.7537 - f1_score: 0.7966 - roc_auc: 0.9153 - pr_auc: 0.9003 - cohen_kappa: 0.6704 - val_loss: 0.4506 - val_tp: 577.0000 - val_fp: 135.0000 - val_tn: 997.0000 - val_fn: 243.0000 - val_binary_acc: 0.8064 - val_precision: 0.8104 - val_recall: 0.7037 - val_f1_score: 0.7533 - val_roc_auc: 0.8703 - val_pr_auc: 0.8560 - val_cohen_kappa: 0.5952
# Epoch 33/100
# 488/488 [==============================] - 86s 177ms/step - loss: 0.3442 - tp: 2374.0000 - fp: 418.0000 - tn: 4215.0000 - fn: 793.0000 - binary_acc: 0.8447 - precision: 0.8503 - recall: 0.7496 - f1_score: 0.7968 - roc_auc: 0.9183 - pr_auc: 0.9042 - cohen_kappa: 0.6720 - val_loss: 0.4637 - val_tp: 587.0000 - val_fp: 171.0000 - val_tn: 961.0000 - val_fn: 233.0000 - val_binary_acc: 0.7930 - val_precision: 0.7744 - val_recall: 0.7159 - val_f1_score: 0.7440 - val_roc_auc: 0.8606 - val_pr_auc: 0.8456 - val_cohen_kappa: 0.5707
# Epoch 34/100
# 488/488 [==============================] - 88s 180ms/step - loss: 0.3422 - tp: 2406.0000 - fp: 417.0000 - tn: 4216.0000 - fn: 761.0000 - binary_acc: 0.8490 - precision: 0.8523 - recall: 0.7597 - f1_score: 0.8033 - roc_auc: 0.9206 - pr_auc: 0.9055 - cohen_kappa: 0.6814 - val_loss: 0.4524 - val_tp: 561.0000 - val_fp: 117.0000 - val_tn: 1015.0000 - val_fn: 259.0000 - val_binary_acc: 0.8074 - val_precision: 0.8274 - val_recall: 0.6841 - val_f1_score: 0.7490 - val_roc_auc: 0.8728 - val_pr_auc: 0.8582 - val_cohen_kappa: 0.5950
# Epoch 35/100
# 488/488 [==============================] - 85s 173ms/step - loss: 0.3325 - tp: 2450.0000 - fp: 416.0000 - tn: 4217.0000 - fn: 717.0000 - binary_acc: 0.8547 - precision: 0.8548 - recall: 0.7736 - f1_score: 0.8122 - roc_auc: 0.9247 - pr_auc: 0.9110 - cohen_kappa: 0.6943 - val_loss: 0.4780 - val_tp: 556.0000 - val_fp: 134.0000 - val_tn: 998.0000 - val_fn: 264.0000 - val_binary_acc: 0.7961 - val_precision: 0.8058 - val_recall: 0.6780 - val_f1_score: 0.7364 - val_roc_auc: 0.8593 - val_pr_auc: 0.8414 - val_cohen_kappa: 0.5722
# Epoch 36/100
# 488/488 [==============================] - 86s 176ms/step - loss: 0.3376 - tp: 2413.0000 - fp: 408.0000 - tn: 4225.0000 - fn: 754.0000 - binary_acc: 0.8510 - precision: 0.8554 - recall: 0.7619 - f1_score: 0.8059 - roc_auc: 0.9212 - pr_auc: 0.9073 - cohen_kappa: 0.6857 - val_loss: 0.4742 - val_tp: 611.0000 - val_fp: 177.0000 - val_tn: 955.0000 - val_fn: 209.0000 - val_binary_acc: 0.8023 - val_precision: 0.7754 - val_recall: 0.7451 - val_f1_score: 0.7600 - val_roc_auc: 0.8638 - val_pr_auc: 0.8458 - val_cohen_kappa: 0.5919
# Epoch 37/100
# 488/488 [==============================] - 87s 179ms/step - loss: 0.3325 - tp: 2431.0000 - fp: 405.0000 - tn: 4228.0000 - fn: 736.0000 - binary_acc: 0.8537 - precision: 0.8572 - recall: 0.7676 - f1_score: 0.8099 - roc_auc: 0.9245 - pr_auc: 0.9109 - cohen_kappa: 0.6916 - val_loss: 0.4957 - val_tp: 473.0000 - val_fp: 44.0000 - val_tn: 1088.0000 - val_fn: 347.0000 - val_binary_acc: 0.7997 - val_precision: 0.9149 - val_recall: 0.5768 - val_f1_score: 0.7076 - val_roc_auc: 0.8720 - val_pr_auc: 0.8573 - val_cohen_kappa: 0.5668
# Epoch 38/100
# 488/488 [==============================] - 88s 181ms/step - loss: 0.3276 - tp: 2427.0000 - fp: 403.0000 - tn: 4230.0000 - fn: 740.0000 - binary_acc: 0.8535 - precision: 0.8576 - recall: 0.7663 - f1_score: 0.8094 - roc_auc: 0.9267 - pr_auc: 0.9131 - cohen_kappa: 0.6910 - val_loss: 0.4895 - val_tp: 552.0000 - val_fp: 104.0000 - val_tn: 1028.0000 - val_fn: 268.0000 - val_binary_acc: 0.8094 - val_precision: 0.8415 - val_recall: 0.6732 - val_f1_score: 0.7480 - val_roc_auc: 0.8671 - val_pr_auc: 0.8485 - val_cohen_kappa: 0.5978
# Epoch 39/100
# 488/488 [==============================] - 88s 180ms/step - loss: 0.3266 - tp: 2455.0000 - fp: 424.0000 - tn: 4209.0000 - fn: 712.0000 - binary_acc: 0.8544 - precision: 0.8527 - recall: 0.7752 - f1_score: 0.8121 - roc_auc: 0.9273 - pr_auc: 0.9132 - cohen_kappa: 0.6936 - val_loss: 0.4905 - val_tp: 540.0000 - val_fp: 115.0000 - val_tn: 1017.0000 - val_fn: 280.0000 - val_binary_acc: 0.7976 - val_precision: 0.8244 - val_recall: 0.6585 - val_f1_score: 0.7322 - val_roc_auc: 0.8629 - val_pr_auc: 0.8432 - val_cohen_kappa: 0.5728
# Epoch 40/100
# 488/488 [==============================] - 90s 184ms/step - loss: 0.3221 - tp: 2466.0000 - fp: 384.0000 - tn: 4249.0000 - fn: 701.0000 - binary_acc: 0.8609 - precision: 0.8653 - recall: 0.7787 - f1_score: 0.8197 - roc_auc: 0.9291 - pr_auc: 0.9167 - cohen_kappa: 0.7070 - val_loss: 0.5172 - val_tp: 477.0000 - val_fp: 66.0000 - val_tn: 1066.0000 - val_fn: 343.0000 - val_binary_acc: 0.7905 - val_precision: 0.8785 - val_recall: 0.5817 - val_f1_score: 0.6999 - val_roc_auc: 0.8559 - val_pr_auc: 0.8345 - val_cohen_kappa: 0.5490
# Epoch 41/100
# 488/488 [==============================] - 89s 183ms/step - loss: 0.3266 - tp: 2425.0000 - fp: 391.0000 - tn: 4242.0000 - fn: 742.0000 - binary_acc: 0.8547 - precision: 0.8612 - recall: 0.7657 - f1_score: 0.8106 - roc_auc: 0.9280 - pr_auc: 0.9123 - cohen_kappa: 0.6935 - val_loss: 0.5209 - val_tp: 500.0000 - val_fp: 90.0000 - val_tn: 1042.0000 - val_fn: 320.0000 - val_binary_acc: 0.7900 - val_precision: 0.8475 - val_recall: 0.6098 - val_f1_score: 0.7092 - val_roc_auc: 0.8527 - val_pr_auc: 0.8378 - val_cohen_kappa: 0.5516
# Epoch 42/100
# 488/488 [==============================] - 89s 182ms/step - loss: 0.3194 - tp: 2449.0000 - fp: 404.0000 - tn: 4229.0000 - fn: 718.0000 - binary_acc: 0.8562 - precision: 0.8584 - recall: 0.7733 - f1_score: 0.8136 - roc_auc: 0.9308 - pr_auc: 0.9164 - cohen_kappa: 0.6970 - val_loss: 0.4664 - val_tp: 635.0000 - val_fp: 211.0000 - val_tn: 921.0000 - val_fn: 185.0000 - val_binary_acc: 0.7971 - val_precision: 0.7506 - val_recall: 0.7744 - val_f1_score: 0.7623 - val_roc_auc: 0.8672 - val_pr_auc: 0.8453 - val_cohen_kappa: 0.5854
# Epoch 43/100
# 488/488 [==============================] - 91s 187ms/step - loss: 0.3171 - tp: 2467.0000 - fp: 400.0000 - tn: 4233.0000 - fn: 700.0000 - binary_acc: 0.8590 - precision: 0.8605 - recall: 0.7790 - f1_score: 0.8177 - roc_auc: 0.9318 - pr_auc: 0.9187 - cohen_kappa: 0.7032 - val_loss: 0.4939 - val_tp: 500.0000 - val_fp: 64.0000 - val_tn: 1068.0000 - val_fn: 320.0000 - val_binary_acc: 0.8033 - val_precision: 0.8865 - val_recall: 0.6098 - val_f1_score: 0.7225 - val_roc_auc: 0.8680 - val_pr_auc: 0.8540 - val_cohen_kappa: 0.5781
# Epoch 44/100
# 488/488 [==============================] - 91s 185ms/step - loss: 0.3145 - tp: 2482.0000 - fp: 372.0000 - tn: 4261.0000 - fn: 685.0000 - binary_acc: 0.8645 - precision: 0.8697 - recall: 0.7837 - f1_score: 0.8244 - roc_auc: 0.9325 - pr_auc: 0.9206 - cohen_kappa: 0.7146 - val_loss: 0.4843 - val_tp: 598.0000 - val_fp: 177.0000 - val_tn: 955.0000 - val_fn: 222.0000 - val_binary_acc: 0.7956 - val_precision: 0.7716 - val_recall: 0.7293 - val_f1_score: 0.7498 - val_roc_auc: 0.8631 - val_pr_auc: 0.8487 - val_cohen_kappa: 0.5773
# Epoch 45/100
# 488/488 [==============================] - ETA: 0s - loss: 0.3060 - tp: 2509.0000 - fp: 400.0000 - tn: 4233.0000 - fn: 658.0000 - binary_acc: 0.8644 - precision: 0.8625 - recall: 0.7922 - f1_score: 0.8259 - roc_auc: 0.9369 - pr_auc: 0.9235 - cohen_kappa: 0.7151Restoring model weights from the end of the best epoch: 30.
# 488/488 [==============================] - 91s 186ms/step - loss: 0.3060 - tp: 2509.0000 - fp: 400.0000 - tn: 4233.0000 - fn: 658.0000 - binary_acc: 0.8644 - precision: 0.8625 - recall: 0.7922 - f1_score: 0.8259 - roc_auc: 0.9369 - pr_auc: 0.9235 - cohen_kappa: 0.7151 - val_loss: 0.4935 - val_tp: 624.0000 - val_fp: 214.0000 - val_tn: 918.0000 - val_fn: 196.0000 - val_binary_acc: 0.7900 - val_precision: 0.7446 - val_recall: 0.7610 - val_f1_score: 0.7527 - val_roc_auc: 0.8604 - val_pr_auc: 0.8461 - val_cohen_kappa: 0.5702
# Epoch 45: early stopping

# %%
new_model.save(save_path + model_name + '.keras')

plot_metrics(history)

# %%
new_model.evaluate(validation_generator)
new_model.evaluate(test_generator)

    # Make predictions using the validation generator
y_valid_pred_prob = new_model.predict(validation_generator)
y_valid_pred = (y_valid_pred_prob > 0.5).astype(int)
y_valid = validation_generator.classes
print("Classification Report:")
print(classification_report(y_valid, y_valid_pred))

y_pred_prob = new_model.predict(test_generator)
y_pred = (y_pred_prob > 0.5).astype(int)
y_test = test_generator.classes
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# 122/122 [==============================] - 18s 143ms/step - loss: 0.4446 - tp: 539.0000 - fp: 109.0000 - tn: 1023.0000 - fn: 281.0000 - binary_acc: 0.8002 - precision: 0.8318 - recall: 0.6573 - f1_score: 0.7343 - roc_auc: 0.8670 - pr_auc: 0.8540 - cohen_kappa: 0.5777
# 42/42 [==============================] - 3s 73ms/step - loss: 0.4505 - tp: 195.0000 - fp: 30.0000 - tn: 334.0000 - fn: 99.0000 - binary_acc: 0.8040 - precision: 0.8667 - recall: 0.6633 - f1_score: 0.7514 - roc_auc: 0.8636 - pr_auc: 0.8698 - cohen_kappa: 0.5943
# 122/122 [==============================] - 20s 142ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.79      0.91      0.85      1132
#            1       0.84      0.67      0.74       820
#
#     accuracy                           0.81      1952
#    macro avg       0.82      0.79      0.79      1952
# weighted avg       0.81      0.81      0.80      1952
#
# 42/42 [==============================] - 3s 66ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      0.92      0.84       364
#            1       0.87      0.66      0.75       294
#
#     accuracy                           0.80       658
#    macro avg       0.82      0.79      0.79       658
# weighted avg       0.81      0.80      0.80       658

# %%
conf_matrix = confusion_matrix(y_test, y_pred)

# Create ConfusionMatrixDisplay object
cm_display = ConfusionMatrixDisplay(confusion_matrix=conf_matrix)

# Plot the confusion matrix
plt.figure(figsize=(4, 6))  # Adjust the figure size as needed
cm_display.plot(cmap=plt.cm.Blues)  # You can choose any colormap you prefer
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.grid(False)  # Turn off grid
plt.savefig(save_path + model_name + "_confusion_matrix.jpg")
plt.show()

# %%
history_df = pd.DataFrame(history.history)
save_history(model_name, history_df)

new_model.save(save_path + model_name + "_pt_imagenet-{new_model.count_params()}.h5")
densenet.save(save_path + model_name + ".h5")

densenet.trainable = True

new_model.compile(
        optimizer=tf.keras.optimizers.Adam(
            1e-5
        ),  # we need small learning rate to avoid catastrophic forgetting
        loss=tf.keras.losses.BinaryCrossentropy(),
        metrics=METRICS,
    )

model_name = 'finetuned_' + architecture + "_" + target_category

model_path = save_path + '_best_' + model_name + '.keras'
model_checkpoint = ModelCheckpoint(filepath=model_path,
                                       monitor="val_cohen_kappa",
                                       save_best_only=True)

reduce_lr_on_plateau = tf.keras.callbacks.ReduceLROnPlateau(
        monitor="val_cohen_kappa",
        verbose=1,
        patience=4,
        mode="max",
        factor=0.2,
        min_lr=1e-10,
    )
# Out:
# Training history saved to: C:/Users/raouf/Desktop/pfe/history/final/densenet/XR_WRIST/DenseNet_XR_WRIST_history.xlsx
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
history = new_model.fit(train_generator,
                            # steps_per_epoch=len(df_train) // batch_size,
                            validation_data=validation_generator,
                            # validation_steps=len(df_valid) // batch_size,
                            epochs=fine_tuning_epochs,
                            shuffle=shuffle,
                            callbacks=[early_stopping, model_checkpoint, reduce_lr_on_plateau])
# Out:
# Epoch 1/50
# 488/488 [==============================] - 138s 255ms/step - loss: 0.3813 - tp: 2465.0000 - fp: 454.0000 - tn: 4543.0000 - fn: 996.0000 - binary_acc: 0.8286 - precision: 0.8445 - recall: 0.7122 - f1_score: 0.7727 - roc_auc: 0.8957 - pr_auc: 0.8804 - cohen_kappa: 0.6367 - val_loss: 0.4226 - val_tp: 524.0000 - val_fp: 57.0000 - val_tn: 1075.0000 - val_fn: 296.0000 - val_binary_acc: 0.8192 - val_precision: 0.9019 - val_recall: 0.6390 - val_f1_score: 0.7480 - val_roc_auc: 0.8781 - val_pr_auc: 0.8669 - val_cohen_kappa: 0.6133 - lr: 1.0000e-05
# Epoch 2/50
# 488/488 [==============================] - 119s 244ms/step - loss: 0.3382 - tp: 2384.0000 - fp: 359.0000 - tn: 4274.0000 - fn: 783.0000 - binary_acc: 0.8536 - precision: 0.8691 - recall: 0.7528 - f1_score: 0.8068 - roc_auc: 0.9199 - pr_auc: 0.9077 - cohen_kappa: 0.6899 - val_loss: 0.4134 - val_tp: 626.0000 - val_fp: 148.0000 - val_tn: 984.0000 - val_fn: 194.0000 - val_binary_acc: 0.8248 - val_precision: 0.8088 - val_recall: 0.7634 - val_f1_score: 0.7854 - val_roc_auc: 0.8885 - val_pr_auc: 0.8792 - val_cohen_kappa: 0.6376 - lr: 1.0000e-05
# Epoch 3/50
# 488/488 [==============================] - 120s 245ms/step - loss: 0.3304 - tp: 2375.0000 - fp: 345.0000 - tn: 4288.0000 - fn: 792.0000 - binary_acc: 0.8542 - precision: 0.8732 - recall: 0.7499 - f1_score: 0.8069 - roc_auc: 0.9231 - pr_auc: 0.9124 - cohen_kappa: 0.6909 - val_loss: 0.4295 - val_tp: 610.0000 - val_fp: 152.0000 - val_tn: 980.0000 - val_fn: 210.0000 - val_binary_acc: 0.8145 - val_precision: 0.8005 - val_recall: 0.7439 - val_f1_score: 0.7712 - val_roc_auc: 0.8848 - val_pr_auc: 0.8743 - val_cohen_kappa: 0.6156 - lr: 1.0000e-05
# Epoch 4/50
# 488/488 [==============================] - 122s 249ms/step - loss: 0.3164 - tp: 2424.0000 - fp: 324.0000 - tn: 4309.0000 - fn: 743.0000 - binary_acc: 0.8632 - precision: 0.8821 - recall: 0.7654 - f1_score: 0.8196 - roc_auc: 0.9286 - pr_auc: 0.9204 - cohen_kappa: 0.7103 - val_loss: 0.4628 - val_tp: 529.0000 - val_fp: 77.0000 - val_tn: 1055.0000 - val_fn: 291.0000 - val_binary_acc: 0.8115 - val_precision: 0.8729 - val_recall: 0.6451 - val_f1_score: 0.7419 - val_roc_auc: 0.8602 - val_pr_auc: 0.8521 - val_cohen_kappa: 0.5986 - lr: 1.0000e-05
# Epoch 5/50
# 488/488 [==============================] - 120s 246ms/step - loss: 0.2938 - tp: 2473.0000 - fp: 292.0000 - tn: 4341.0000 - fn: 694.0000 - binary_acc: 0.8736 - precision: 0.8944 - recall: 0.7809 - f1_score: 0.8338 - roc_auc: 0.9400 - pr_auc: 0.9302 - cohen_kappa: 0.7326 - val_loss: 0.3994 - val_tp: 584.0000 - val_fp: 68.0000 - val_tn: 1064.0000 - val_fn: 236.0000 - val_binary_acc: 0.8443 - val_precision: 0.8957 - val_recall: 0.7122 - val_f1_score: 0.7935 - val_roc_auc: 0.8976 - val_pr_auc: 0.8933 - val_cohen_kappa: 0.6711 - lr: 1.0000e-05
# Epoch 6/50
# 488/488 [==============================] - 121s 248ms/step - loss: 0.2777 - tp: 2514.0000 - fp: 282.0000 - tn: 4351.0000 - fn: 653.0000 - binary_acc: 0.8801 - precision: 0.8991 - recall: 0.7938 - f1_score: 0.8432 - roc_auc: 0.9454 - pr_auc: 0.9370 - cohen_kappa: 0.7468 - val_loss: 0.4157 - val_tp: 606.0000 - val_fp: 99.0000 - val_tn: 1033.0000 - val_fn: 214.0000 - val_binary_acc: 0.8397 - val_precision: 0.8596 - val_recall: 0.7390 - val_f1_score: 0.7948 - val_roc_auc: 0.8939 - val_pr_auc: 0.8863 - val_cohen_kappa: 0.6644 - lr: 1.0000e-05
# Epoch 7/50
# 488/488 [==============================] - 120s 246ms/step - loss: 0.2662 - tp: 2550.0000 - fp: 266.0000 - tn: 4367.0000 - fn: 617.0000 - binary_acc: 0.8868 - precision: 0.9055 - recall: 0.8052 - f1_score: 0.8524 - roc_auc: 0.9501 - pr_auc: 0.9424 - cohen_kappa: 0.7611 - val_loss: 0.4070 - val_tp: 557.0000 - val_fp: 67.0000 - val_tn: 1065.0000 - val_fn: 263.0000 - val_binary_acc: 0.8309 - val_precision: 0.8926 - val_recall: 0.6793 - val_f1_score: 0.7715 - val_roc_auc: 0.8890 - val_pr_auc: 0.8806 - val_cohen_kappa: 0.6412 - lr: 1.0000e-05
# Epoch 8/50
# 488/488 [==============================] - 117s 239ms/step - loss: 0.2511 - tp: 2584.0000 - fp: 264.0000 - tn: 4369.0000 - fn: 583.0000 - binary_acc: 0.8914 - precision: 0.9073 - recall: 0.8159 - f1_score: 0.8592 - roc_auc: 0.9563 - pr_auc: 0.9488 - cohen_kappa: 0.7712 - val_loss: 0.4172 - val_tp: 583.0000 - val_fp: 87.0000 - val_tn: 1045.0000 - val_fn: 237.0000 - val_binary_acc: 0.8340 - val_precision: 0.8701 - val_recall: 0.7110 - val_f1_score: 0.7826 - val_roc_auc: 0.8968 - val_pr_auc: 0.8850 - val_cohen_kappa: 0.6505 - lr: 1.0000e-05
# Epoch 9/50
# 488/488 [==============================] - ETA: 0s - loss: 0.2381 - tp: 2639.0000 - fp: 255.0000 - tn: 4378.0000 - fn: 528.0000 - binary_acc: 0.8996 - precision: 0.9119 - recall: 0.8333 - f1_score: 0.8708 - roc_auc: 0.9605 - pr_auc: 0.9544 - cohen_kappa: 0.7890
# Epoch 9: ReduceLROnPlateau reducing learning rate to 1.9999999494757505e-06.
# 488/488 [==============================] - 117s 240ms/step - loss: 0.2381 - tp: 2639.0000 - fp: 255.0000 - tn: 4378.0000 - fn: 528.0000 - binary_acc: 0.8996 - precision: 0.9119 - recall: 0.8333 - f1_score: 0.8708 - roc_auc: 0.9605 - pr_auc: 0.9544 - cohen_kappa: 0.7890 - val_loss: 0.4526 - val_tp: 617.0000 - val_fp: 139.0000 - val_tn: 993.0000 - val_fn: 203.0000 - val_binary_acc: 0.8248 - val_precision: 0.8161 - val_recall: 0.7524 - val_f1_score: 0.7830 - val_roc_auc: 0.8950 - val_pr_auc: 0.8814 - val_cohen_kappa: 0.6365 - lr: 1.0000e-05
# Epoch 10/50
# 488/488 [==============================] - 117s 239ms/step - loss: 0.1821 - tp: 2771.0000 - fp: 167.0000 - tn: 4466.0000 - fn: 396.0000 - binary_acc: 0.9278 - precision: 0.9432 - recall: 0.8750 - f1_score: 0.9078 - roc_auc: 0.9774 - pr_auc: 0.9733 - cohen_kappa: 0.8486 - val_loss: 0.4348 - val_tp: 618.0000 - val_fp: 91.0000 - val_tn: 1041.0000 - val_fn: 202.0000 - val_binary_acc: 0.8499 - val_precision: 0.8717 - val_recall: 0.7537 - val_f1_score: 0.8084 - val_roc_auc: 0.9071 - val_pr_auc: 0.8979 - val_cohen_kappa: 0.6861 - lr: 2.0000e-06
# Epoch 11/50
# 488/488 [==============================] - 119s 243ms/step - loss: 0.1616 - tp: 2824.0000 - fp: 149.0000 - tn: 4484.0000 - fn: 343.0000 - binary_acc: 0.9369 - precision: 0.9499 - recall: 0.8917 - f1_score: 0.9199 - roc_auc: 0.9820 - pr_auc: 0.9786 - cohen_kappa: 0.8679 - val_loss: 0.4415 - val_tp: 615.0000 - val_fp: 83.0000 - val_tn: 1049.0000 - val_fn: 205.0000 - val_binary_acc: 0.8525 - val_precision: 0.8811 - val_recall: 0.7500 - val_f1_score: 0.8103 - val_roc_auc: 0.9074 - val_pr_auc: 0.8949 - val_cohen_kappa: 0.6908 - lr: 2.0000e-06
# Epoch 12/50
# 488/488 [==============================] - 117s 239ms/step - loss: 0.1485 - tp: 2848.0000 - fp: 148.0000 - tn: 4485.0000 - fn: 319.0000 - binary_acc: 0.9401 - precision: 0.9506 - recall: 0.8993 - f1_score: 0.9242 - roc_auc: 0.9852 - pr_auc: 0.9819 - cohen_kappa: 0.8748 - val_loss: 0.4487 - val_tp: 617.0000 - val_fp: 103.0000 - val_tn: 1029.0000 - val_fn: 203.0000 - val_binary_acc: 0.8432 - val_precision: 0.8569 - val_recall: 0.7524 - val_f1_score: 0.8013 - val_roc_auc: 0.9062 - val_pr_auc: 0.8984 - val_cohen_kappa: 0.6728 - lr: 2.0000e-06
# Epoch 13/50
# 488/488 [==============================] - 118s 241ms/step - loss: 0.1450 - tp: 2856.0000 - fp: 152.0000 - tn: 4481.0000 - fn: 311.0000 - binary_acc: 0.9406 - precision: 0.9495 - recall: 0.9018 - f1_score: 0.9250 - roc_auc: 0.9866 - pr_auc: 0.9828 - cohen_kappa: 0.8759 - val_loss: 0.4481 - val_tp: 617.0000 - val_fp: 95.0000 - val_tn: 1037.0000 - val_fn: 203.0000 - val_binary_acc: 0.8473 - val_precision: 0.8666 - val_recall: 0.7524 - val_f1_score: 0.8055 - val_roc_auc: 0.9039 - val_pr_auc: 0.8933 - val_cohen_kappa: 0.6809 - lr: 2.0000e-06
# Epoch 14/50
# 488/488 [==============================] - 118s 241ms/step - loss: 0.1376 - tp: 2873.0000 - fp: 142.0000 - tn: 4491.0000 - fn: 294.0000 - binary_acc: 0.9441 - precision: 0.9529 - recall: 0.9072 - f1_score: 0.9295 - roc_auc: 0.9874 - pr_auc: 0.9842 - cohen_kappa: 0.8832 - val_loss: 0.4644 - val_tp: 621.0000 - val_fp: 89.0000 - val_tn: 1043.0000 - val_fn: 199.0000 - val_binary_acc: 0.8525 - val_precision: 0.8746 - val_recall: 0.7573 - val_f1_score: 0.8118 - val_roc_auc: 0.9073 - val_pr_auc: 0.8978 - val_cohen_kappa: 0.6915 - lr: 2.0000e-06
# Epoch 15/50
# 488/488 [==============================] - 120s 245ms/step - loss: 0.1239 - tp: 2908.0000 - fp: 128.0000 - tn: 4505.0000 - fn: 259.0000 - binary_acc: 0.9504 - precision: 0.9578 - recall: 0.9182 - f1_score: 0.9376 - roc_auc: 0.9900 - pr_auc: 0.9874 - cohen_kappa: 0.8965 - val_loss: 0.4690 - val_tp: 645.0000 - val_fp: 101.0000 - val_tn: 1031.0000 - val_fn: 175.0000 - val_binary_acc: 0.8586 - val_precision: 0.8646 - val_recall: 0.7866 - val_f1_score: 0.8238 - val_roc_auc: 0.9110 - val_pr_auc: 0.8984 - val_cohen_kappa: 0.7061 - lr: 2.0000e-06
# Epoch 16/50
# 488/488 [==============================] - 118s 241ms/step - loss: 0.1237 - tp: 2914.0000 - fp: 135.0000 - tn: 4498.0000 - fn: 253.0000 - binary_acc: 0.9503 - precision: 0.9557 - recall: 0.9201 - f1_score: 0.9376 - roc_auc: 0.9900 - pr_auc: 0.9874 - cohen_kappa: 0.8963 - val_loss: 0.4764 - val_tp: 633.0000 - val_fp: 109.0000 - val_tn: 1023.0000 - val_fn: 187.0000 - val_binary_acc: 0.8484 - val_precision: 0.8531 - val_recall: 0.7720 - val_f1_score: 0.8105 - val_roc_auc: 0.9058 - val_pr_auc: 0.8939 - val_cohen_kappa: 0.6846 - lr: 2.0000e-06
# Epoch 17/50
# 488/488 [==============================] - 118s 241ms/step - loss: 0.1150 - tp: 2933.0000 - fp: 104.0000 - tn: 4529.0000 - fn: 234.0000 - binary_acc: 0.9567 - precision: 0.9658 - recall: 0.9261 - f1_score: 0.9455 - roc_auc: 0.9912 - pr_auc: 0.9891 - cohen_kappa: 0.9096 - val_loss: 0.4972 - val_tp: 625.0000 - val_fp: 91.0000 - val_tn: 1041.0000 - val_fn: 195.0000 - val_binary_acc: 0.8535 - val_precision: 0.8729 - val_recall: 0.7622 - val_f1_score: 0.8138 - val_roc_auc: 0.9057 - val_pr_auc: 0.8942 - val_cohen_kappa: 0.6939 - lr: 2.0000e-06
# Epoch 18/50
# 488/488 [==============================] - 117s 240ms/step - loss: 0.1133 - tp: 2933.0000 - fp: 121.0000 - tn: 4512.0000 - fn: 234.0000 - binary_acc: 0.9545 - precision: 0.9604 - recall: 0.9261 - f1_score: 0.9429 - roc_auc: 0.9915 - pr_auc: 0.9894 - cohen_kappa: 0.9051 - val_loss: 0.4781 - val_tp: 650.0000 - val_fp: 127.0000 - val_tn: 1005.0000 - val_fn: 170.0000 - val_binary_acc: 0.8478 - val_precision: 0.8366 - val_recall: 0.7927 - val_f1_score: 0.8140 - val_roc_auc: 0.9110 - val_pr_auc: 0.8965 - val_cohen_kappa: 0.6854 - lr: 2.0000e-06
# Epoch 19/50
# 488/488 [==============================] - ETA: 0s - loss: 0.1054 - tp: 2966.0000 - fp: 106.0000 - tn: 4527.0000 - fn: 201.0000 - binary_acc: 0.9606 - precision: 0.9655 - recall: 0.9365 - f1_score: 0.9508 - roc_auc: 0.9924 - pr_auc: 0.9907 - cohen_kappa: 0.9180
# Epoch 19: ReduceLROnPlateau reducing learning rate to 3.999999989900971e-07.
# 488/488 [==============================] - 120s 245ms/step - loss: 0.1054 - tp: 2966.0000 - fp: 106.0000 - tn: 4527.0000 - fn: 201.0000 - binary_acc: 0.9606 - precision: 0.9655 - recall: 0.9365 - f1_score: 0.9508 - roc_auc: 0.9924 - pr_auc: 0.9907 - cohen_kappa: 0.9180 - val_loss: 0.4927 - val_tp: 656.0000 - val_fp: 137.0000 - val_tn: 995.0000 - val_fn: 164.0000 - val_binary_acc: 0.8458 - val_precision: 0.8272 - val_recall: 0.8000 - val_f1_score: 0.8134 - val_roc_auc: 0.9073 - val_pr_auc: 0.8969 - val_cohen_kappa: 0.6821 - lr: 2.0000e-06
# Epoch 20/50
# 488/488 [==============================] - 117s 240ms/step - loss: 0.0863 - tp: 3013.0000 - fp: 83.0000 - tn: 4550.0000 - fn: 154.0000 - binary_acc: 0.9696 - precision: 0.9732 - recall: 0.9514 - f1_score: 0.9622 - roc_auc: 0.9957 - pr_auc: 0.9943 - cohen_kappa: 0.9368 - val_loss: 0.5040 - val_tp: 640.0000 - val_fp: 115.0000 - val_tn: 1017.0000 - val_fn: 180.0000 - val_binary_acc: 0.8489 - val_precision: 0.8477 - val_recall: 0.7805 - val_f1_score: 0.8127 - val_roc_auc: 0.9080 - val_pr_auc: 0.8957 - val_cohen_kappa: 0.6864 - lr: 4.0000e-07
# Epoch 21/50
# 488/488 [==============================] - 118s 241ms/step - loss: 0.0865 - tp: 2993.0000 - fp: 80.0000 - tn: 4553.0000 - fn: 174.0000 - binary_acc: 0.9674 - precision: 0.9740 - recall: 0.9451 - f1_score: 0.9593 - roc_auc: 0.9954 - pr_auc: 0.9940 - cohen_kappa: 0.9322 - val_loss: 0.5155 - val_tp: 630.0000 - val_fp: 90.0000 - val_tn: 1042.0000 - val_fn: 190.0000 - val_binary_acc: 0.8566 - val_precision: 0.8750 - val_recall: 0.7683 - val_f1_score: 0.8182 - val_roc_auc: 0.9089 - val_pr_auc: 0.8952 - val_cohen_kappa: 0.7006 - lr: 4.0000e-07
# Epoch 22/50
# 488/488 [==============================] - 118s 241ms/step - loss: 0.0858 - tp: 2998.0000 - fp: 91.0000 - tn: 4542.0000 - fn: 169.0000 - binary_acc: 0.9667 - precision: 0.9705 - recall: 0.9466 - f1_score: 0.9584 - roc_auc: 0.9954 - pr_auc: 0.9941 - cohen_kappa: 0.9306 - val_loss: 0.5025 - val_tp: 630.0000 - val_fp: 101.0000 - val_tn: 1031.0000 - val_fn: 190.0000 - val_binary_acc: 0.8509 - val_precision: 0.8618 - val_recall: 0.7683 - val_f1_score: 0.8124 - val_roc_auc: 0.9092 - val_pr_auc: 0.8961 - val_cohen_kappa: 0.6894 - lr: 4.0000e-07
# Epoch 23/50
# 488/488 [==============================] - 118s 241ms/step - loss: 0.0815 - tp: 3003.0000 - fp: 84.0000 - tn: 4549.0000 - fn: 164.0000 - binary_acc: 0.9682 - precision: 0.9728 - recall: 0.9482 - f1_score: 0.9603 - roc_auc: 0.9958 - pr_auc: 0.9948 - cohen_kappa: 0.9338 - val_loss: 0.5216 - val_tp: 638.0000 - val_fp: 90.0000 - val_tn: 1042.0000 - val_fn: 182.0000 - val_binary_acc: 0.8607 - val_precision: 0.8764 - val_recall: 0.7780 - val_f1_score: 0.8243 - val_roc_auc: 0.9139 - val_pr_auc: 0.9005 - val_cohen_kappa: 0.7095 - lr: 4.0000e-07
# Epoch 24/50
# 488/488 [==============================] - 117s 239ms/step - loss: 0.0806 - tp: 3011.0000 - fp: 73.0000 - tn: 4560.0000 - fn: 156.0000 - binary_acc: 0.9706 - precision: 0.9763 - recall: 0.9507 - f1_score: 0.9634 - roc_auc: 0.9961 - pr_auc: 0.9949 - cohen_kappa: 0.9389 - val_loss: 0.5156 - val_tp: 655.0000 - val_fp: 119.0000 - val_tn: 1013.0000 - val_fn: 165.0000 - val_binary_acc: 0.8545 - val_precision: 0.8463 - val_recall: 0.7988 - val_f1_score: 0.8218 - val_roc_auc: 0.9094 - val_pr_auc: 0.8979 - val_cohen_kappa: 0.6991 - lr: 4.0000e-07
# Epoch 25/50
# 488/488 [==============================] - 117s 240ms/step - loss: 0.0816 - tp: 3014.0000 - fp: 77.0000 - tn: 4556.0000 - fn: 153.0000 - binary_acc: 0.9705 - precision: 0.9751 - recall: 0.9517 - f1_score: 0.9632 - roc_auc: 0.9958 - pr_auc: 0.9945 - cohen_kappa: 0.9386 - val_loss: 0.5243 - val_tp: 639.0000 - val_fp: 100.0000 - val_tn: 1032.0000 - val_fn: 181.0000 - val_binary_acc: 0.8560 - val_precision: 0.8647 - val_recall: 0.7793 - val_f1_score: 0.8198 - val_roc_auc: 0.9100 - val_pr_auc: 0.8993 - val_cohen_kappa: 0.7005 - lr: 4.0000e-07
# Epoch 26/50
# 488/488 [==============================] - 118s 241ms/step - loss: 0.0815 - tp: 3012.0000 - fp: 73.0000 - tn: 4560.0000 - fn: 155.0000 - binary_acc: 0.9708 - precision: 0.9763 - recall: 0.9511 - f1_score: 0.9635 - roc_auc: 0.9958 - pr_auc: 0.9943 - cohen_kappa: 0.9391 - val_loss: 0.5440 - val_tp: 630.0000 - val_fp: 104.0000 - val_tn: 1028.0000 - val_fn: 190.0000 - val_binary_acc: 0.8494 - val_precision: 0.8583 - val_recall: 0.7683 - val_f1_score: 0.8108 - val_roc_auc: 0.9069 - val_pr_auc: 0.8934 - val_cohen_kappa: 0.6863 - lr: 4.0000e-07
# Epoch 27/50
# 488/488 [==============================] - ETA: 0s - loss: 0.0780 - tp: 3014.0000 - fp: 75.0000 - tn: 4558.0000 - fn: 153.0000 - binary_acc: 0.9708 - precision: 0.9757 - recall: 0.9517 - f1_score: 0.9636 - roc_auc: 0.9961 - pr_auc: 0.9951 - cohen_kappa: 0.9392
# Epoch 27: ReduceLROnPlateau reducing learning rate to 8.00000009348878e-08.
# 488/488 [==============================] - 116s 238ms/step - loss: 0.0780 - tp: 3014.0000 - fp: 75.0000 - tn: 4558.0000 - fn: 153.0000 - binary_acc: 0.9708 - precision: 0.9757 - recall: 0.9517 - f1_score: 0.9636 - roc_auc: 0.9961 - pr_auc: 0.9951 - cohen_kappa: 0.9392 - val_loss: 0.5218 - val_tp: 633.0000 - val_fp: 101.0000 - val_tn: 1031.0000 - val_fn: 187.0000 - val_binary_acc: 0.8525 - val_precision: 0.8624 - val_recall: 0.7720 - val_f1_score: 0.8147 - val_roc_auc: 0.9121 - val_pr_auc: 0.8966 - val_cohen_kappa: 0.6927 - lr: 4.0000e-07
# Epoch 28/50
# 488/488 [==============================] - 115s 236ms/step - loss: 0.0742 - tp: 3027.0000 - fp: 69.0000 - tn: 4564.0000 - fn: 140.0000 - binary_acc: 0.9732 - precision: 0.9777 - recall: 0.9558 - f1_score: 0.9666 - roc_auc: 0.9966 - pr_auc: 0.9957 - cohen_kappa: 0.9443 - val_loss: 0.5130 - val_tp: 644.0000 - val_fp: 118.0000 - val_tn: 1014.0000 - val_fn: 176.0000 - val_binary_acc: 0.8494 - val_precision: 0.8451 - val_recall: 0.7854 - val_f1_score: 0.8142 - val_roc_auc: 0.9122 - val_pr_auc: 0.9009 - val_cohen_kappa: 0.6878 - lr: 8.0000e-08
# Epoch 29/50
# 488/488 [==============================] - 118s 241ms/step - loss: 0.0730 - tp: 3034.0000 - fp: 72.0000 - tn: 4561.0000 - fn: 133.0000 - binary_acc: 0.9737 - precision: 0.9768 - recall: 0.9580 - f1_score: 0.9673 - roc_auc: 0.9968 - pr_auc: 0.9959 - cohen_kappa: 0.9453 - val_loss: 0.5336 - val_tp: 646.0000 - val_fp: 126.0000 - val_tn: 1006.0000 - val_fn: 174.0000 - val_binary_acc: 0.8463 - val_precision: 0.8368 - val_recall: 0.7878 - val_f1_score: 0.8116 - val_roc_auc: 0.9096 - val_pr_auc: 0.8887 - val_cohen_kappa: 0.6820 - lr: 8.0000e-08
# Epoch 30/50
# 488/488 [==============================] - 119s 243ms/step - loss: 0.0720 - tp: 3043.0000 - fp: 89.0000 - tn: 4544.0000 - fn: 124.0000 - binary_acc: 0.9727 - precision: 0.9716 - recall: 0.9608 - f1_score: 0.9662 - roc_auc: 0.9969 - pr_auc: 0.9959 - cohen_kappa: 0.9433 - val_loss: 0.5442 - val_tp: 623.0000 - val_fp: 101.0000 - val_tn: 1031.0000 - val_fn: 197.0000 - val_binary_acc: 0.8473 - val_precision: 0.8605 - val_recall: 0.7598 - val_f1_score: 0.8070 - val_roc_auc: 0.9041 - val_pr_auc: 0.8923 - val_cohen_kappa: 0.6815 - lr: 8.0000e-08
# Epoch 31/50
# 488/488 [==============================] - ETA: 0s - loss: 0.0727 - tp: 3030.0000 - fp: 73.0000 - tn: 4560.0000 - fn: 137.0000 - binary_acc: 0.9731 - precision: 0.9765 - recall: 0.9567 - f1_score: 0.9665 - roc_auc: 0.9969 - pr_auc: 0.9959 - cohen_kappa: 0.9440
# Epoch 31: ReduceLROnPlateau reducing learning rate to 1.5999999902760466e-08.
# 488/488 [==============================] - 120s 245ms/step - loss: 0.0727 - tp: 3030.0000 - fp: 73.0000 - tn: 4560.0000 - fn: 137.0000 - binary_acc: 0.9731 - precision: 0.9765 - recall: 0.9567 - f1_score: 0.9665 - roc_auc: 0.9969 - pr_auc: 0.9959 - cohen_kappa: 0.9440 - val_loss: 0.5645 - val_tp: 629.0000 - val_fp: 110.0000 - val_tn: 1022.0000 - val_fn: 191.0000 - val_binary_acc: 0.8458 - val_precision: 0.8512 - val_recall: 0.7671 - val_f1_score: 0.8069 - val_roc_auc: 0.9069 - val_pr_auc: 0.8905 - val_cohen_kappa: 0.6791 - lr: 8.0000e-08
# Epoch 32/50
# 488/488 [==============================] - 122s 250ms/step - loss: 0.0758 - tp: 3015.0000 - fp: 65.0000 - tn: 4568.0000 - fn: 152.0000 - binary_acc: 0.9722 - precision: 0.9789 - recall: 0.9520 - f1_score: 0.9653 - roc_auc: 0.9963 - pr_auc: 0.9954 - cohen_kappa: 0.9421 - val_loss: 0.5518 - val_tp: 629.0000 - val_fp: 106.0000 - val_tn: 1026.0000 - val_fn: 191.0000 - val_binary_acc: 0.8478 - val_precision: 0.8558 - val_recall: 0.7671 - val_f1_score: 0.8090 - val_roc_auc: 0.9055 - val_pr_auc: 0.8886 - val_cohen_kappa: 0.6832 - lr: 1.6000e-08
# Epoch 33/50
# 488/488 [==============================] - 120s 246ms/step - loss: 0.0685 - tp: 3043.0000 - fp: 73.0000 - tn: 4560.0000 - fn: 124.0000 - binary_acc: 0.9747 - precision: 0.9766 - recall: 0.9608 - f1_score: 0.9686 - roc_auc: 0.9973 - pr_auc: 0.9965 - cohen_kappa: 0.9475 - val_loss: 0.5477 - val_tp: 639.0000 - val_fp: 106.0000 - val_tn: 1026.0000 - val_fn: 181.0000 - val_binary_acc: 0.8530 - val_precision: 0.8577 - val_recall: 0.7793 - val_f1_score: 0.8166 - val_roc_auc: 0.9098 - val_pr_auc: 0.8977 - val_cohen_kappa: 0.6944 - lr: 1.6000e-08
# Epoch 34/50
# 488/488 [==============================] - 121s 247ms/step - loss: 0.0778 - tp: 3023.0000 - fp: 78.0000 - tn: 4555.0000 - fn: 144.0000 - binary_acc: 0.9715 - precision: 0.9748 - recall: 0.9545 - f1_score: 0.9646 - roc_auc: 0.9960 - pr_auc: 0.9950 - cohen_kappa: 0.9408 - val_loss: 0.5563 - val_tp: 637.0000 - val_fp: 104.0000 - val_tn: 1028.0000 - val_fn: 183.0000 - val_binary_acc: 0.8530 - val_precision: 0.8596 - val_recall: 0.7768 - val_f1_score: 0.8161 - val_roc_auc: 0.9040 - val_pr_auc: 0.8905 - val_cohen_kappa: 0.6942 - lr: 1.6000e-08
# Epoch 35/50
# 488/488 [==============================] - ETA: 0s - loss: 0.0707 - tp: 3036.0000 - fp: 67.0000 - tn: 4566.0000 - fn: 131.0000 - binary_acc: 0.9746 - precision: 0.9784 - recall: 0.9586 - f1_score: 0.9684 - roc_auc: 0.9970 - pr_auc: 0.9961 - cohen_kappa: 0.9472
# Epoch 35: ReduceLROnPlateau reducing learning rate to 3.1999999094978194e-09.
# 488/488 [==============================] - 120s 245ms/step - loss: 0.0707 - tp: 3036.0000 - fp: 67.0000 - tn: 4566.0000 - fn: 131.0000 - binary_acc: 0.9746 - precision: 0.9784 - recall: 0.9586 - f1_score: 0.9684 - roc_auc: 0.9970 - pr_auc: 0.9961 - cohen_kappa: 0.9472 - val_loss: 0.5521 - val_tp: 634.0000 - val_fp: 108.0000 - val_tn: 1024.0000 - val_fn: 186.0000 - val_binary_acc: 0.8494 - val_precision: 0.8544 - val_recall: 0.7732 - val_f1_score: 0.8118 - val_roc_auc: 0.9055 - val_pr_auc: 0.8945 - val_cohen_kappa: 0.6868 - lr: 1.6000e-08
# Epoch 36/50
# 488/488 [==============================] - 119s 243ms/step - loss: 0.0743 - tp: 3029.0000 - fp: 71.0000 - tn: 4562.0000 - fn: 138.0000 - binary_acc: 0.9732 - precision: 0.9771 - recall: 0.9564 - f1_score: 0.9667 - roc_auc: 0.9967 - pr_auc: 0.9958 - cohen_kappa: 0.9443 - val_loss: 0.5478 - val_tp: 628.0000 - val_fp: 105.0000 - val_tn: 1027.0000 - val_fn: 192.0000 - val_binary_acc: 0.8478 - val_precision: 0.8568 - val_recall: 0.7659 - val_f1_score: 0.8088 - val_roc_auc: 0.9104 - val_pr_auc: 0.8970 - val_cohen_kappa: 0.6831 - lr: 3.2000e-09
# Epoch 37/50
# 488/488 [==============================] - 117s 240ms/step - loss: 0.0703 - tp: 3043.0000 - fp: 68.0000 - tn: 4565.0000 - fn: 124.0000 - binary_acc: 0.9754 - precision: 0.9781 - recall: 0.9608 - f1_score: 0.9694 - roc_auc: 0.9970 - pr_auc: 0.9961 - cohen_kappa: 0.9488 - val_loss: 0.5426 - val_tp: 646.0000 - val_fp: 108.0000 - val_tn: 1024.0000 - val_fn: 174.0000 - val_binary_acc: 0.8555 - val_precision: 0.8568 - val_recall: 0.7878 - val_f1_score: 0.8208 - val_roc_auc: 0.9086 - val_pr_auc: 0.8914 - val_cohen_kappa: 0.7002 - lr: 3.2000e-09
# Epoch 38/50
# 488/488 [==============================] - ETA: 0s - loss: 0.0722 - tp: 3032.0000 - fp: 69.0000 - tn: 4564.0000 - fn: 135.0000 - binary_acc: 0.9738 - precision: 0.9777 - recall: 0.9574 - f1_score: 0.9675 - roc_auc: 0.9969 - pr_auc: 0.9959 - cohen_kappa: 0.9456Restoring model weights from the end of the best epoch: 23.
# 488/488 [==============================] - 118s 242ms/step - loss: 0.0722 - tp: 3032.0000 - fp: 69.0000 - tn: 4564.0000 - fn: 135.0000 - binary_acc: 0.9738 - precision: 0.9777 - recall: 0.9574 - f1_score: 0.9675 - roc_auc: 0.9969 - pr_auc: 0.9959 - cohen_kappa: 0.9456 - val_loss: 0.5411 - val_tp: 633.0000 - val_fp: 100.0000 - val_tn: 1032.0000 - val_fn: 187.0000 - val_binary_acc: 0.8530 - val_precision: 0.8636 - val_recall: 0.7720 - val_f1_score: 0.8152 - val_roc_auc: 0.9089 - val_pr_auc: 0.8978 - val_cohen_kappa: 0.6938 - lr: 3.2000e-09
# Epoch 38: early stopping

# %%
new_model.save(save_path + model_name + '.keras')
plot_metrics(history)

# %%
new_model.evaluate(validation_generator)
new_model.evaluate(test_generator)

# Make predictions using the validation generator
y_valid_pred_prob = new_model.predict(validation_generator)
y_valid_pred = (y_valid_pred_prob > 0.5).astype(int)
y_valid = validation_generator.classes
print("Classification Report:")
print(classification_report(y_valid, y_valid_pred))

# Make predictions using the test generator
y_pred_prob = new_model.predict(test_generator)
y_pred = (y_pred_prob > 0.5).astype(int)
y_test = test_generator.classes
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# 122/122 [==============================] - 19s 156ms/step - loss: 0.5347 - tp: 613.0000 - fp: 89.0000 - tn: 1043.0000 - fn: 207.0000 - binary_acc: 0.8484 - precision: 0.8732 - recall: 0.7476 - f1_score: 0.8055 - roc_auc: 0.9069 - pr_auc: 0.8922 - cohen_kappa: 0.6825
# 42/42 [==============================] - 3s 73ms/step - loss: 0.6091 - tp: 216.0000 - fp: 19.0000 - tn: 345.0000 - fn: 78.0000 - binary_acc: 0.8526 - precision: 0.9191 - recall: 0.7347 - f1_score: 0.8166 - roc_auc: 0.9009 - pr_auc: 0.8918 - cohen_kappa: 0.6959
# 122/122 [==============================] - 21s 155ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.92      0.88      1132
#            1       0.88      0.77      0.82       820
#
#     accuracy                           0.86      1952
#    macro avg       0.86      0.85      0.85      1952
# weighted avg       0.86      0.86      0.86      1952
#
# 42/42 [==============================] - 3s 63ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.82      0.95      0.88       364
#            1       0.92      0.73      0.82       294
#
#     accuracy                           0.85       658
#    macro avg       0.87      0.84      0.85       658
# weighted avg       0.86      0.85      0.85       658

# %%
conf_matrix = confusion_matrix(y_test, y_pred)

# Create ConfusionMatrixDisplay object
cm_display = ConfusionMatrixDisplay(confusion_matrix=conf_matrix)

# Plot the confusion matrix
plt.figure(figsize=(4, 6))  # Adjust the figure size as needed
cm_display.plot(cmap=plt.cm.Blues)  # You can choose any colormap you prefer
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.grid(False)  # Turn off grid
plt.savefig(save_path + model_name + "_confusion_matrix.jpg")
plt.show()

# %%
history_df = pd.DataFrame(history.history)
save_history(model_name, history_df)
# Out:
# Training history saved to: C:/Users/raouf/Desktop/pfe/history/final/densenet/XR_WRIST/finetuned_DenseNet_XR_WRIST_history.xlsx
