# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
import tensorflow as tf
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras import layers, models
from keras.layers import concatenate, Dense, Conv2D, MaxPooling2D, Flatten, Activation, BatchNormalization, Dropout, \
    Attention
from keras import *
from keras.applications import MobileNet
from keras.applications import VGG16
from keras.applications.resnet import ResNet50
from keras import backend as K
from keras.layers import Layer
import keras.layers as kl
import pandas as pd
from keras.applications import EfficientNetB0
import keras.applications
import numpy as np
import os
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from sklearn.metrics import cohen_kappa_score
import seaborn as sns
import pickle
import tensorflow_addons as tfa
from sklearn import metrics
from tensorflow.keras.applications.resnet import preprocess_input as preprocess_input_resnet
from tensorflow.keras.applications.densenet import preprocess_input as preprocess_input_densenet
from tensorflow.keras.models import load_model
import os
import glob

# %%
main_save_path = "C:/Users/raouf/Desktop/pfe/history/final/resnet/"
mura_location = "C:/Users/raouf/Desktop/pfe/"
data_path = 'C:/Users/raouf/Desktop/pfe/MURA-v1.1/'
train_path = 'C:/Users/raouf/Desktop/pfe/MURA-v1.1/train'
test_path = 'C:/Users/raouf/Desktop/pfe/MURA-v1.1/valid'

train_file = "C:/Users/raouf/Desktop/pfe/datasets/shoulder_df_train.csv"
val_file = "C:/Users/raouf/Desktop/pfe/datasets/shoulder_df_valid.csv"

test_file = "C:/Users/raouf/Desktop/pfe/MURA-v1.1/valid_image_paths.csv"

target_category = "XR_SHOULDER"
batch_size = 16
num_epochs = 100
fine_tuning_epochs=50
validation_split = 0.2
loss_function = tf.keras.losses.BinaryCrossentropy()
learning_rate = 0.0001
input_shape = (224, 224, 3)
architecture = 'ResNet'

include_top = False
# metrics=["accuracy"] #, tf.keras.metrics.Precision(), tf.keras.metrics.Recall()
early_stopping_patience = 15
shuffle = True
class_mode = 'binary'  # 'categorical'
IMAGE_WIDTH = 224
IMAGE_HEIGHT = 224
trainable = False
training = False
dropout = 0.2

# %%
def load_data(file, part):
    train_data = pd.read_csv(file)
    train_data = train_data.rename(columns={train_data.columns[0]: 'image_path'})
    train_data['label'] = 2
    string_to_add = mura_location
    train_data['image_path'] = string_to_add + train_data['image_path'].astype(str)
    for index, row in train_data.iterrows():
        if 'positive' in str(row['image_path']).lower():
            train_data.at[index, 'label'] = "positive"
        else:
            train_data.at[index, 'label'] = "negative"

    if part == 0:
        pass
    else:
        train_data = train_data[train_data['image_path'].str.contains(part)]
    return train_data


class CustomCallback(keras.callbacks.Callback):
    def on_test_end(self, logs=None):
        keys = list(logs.keys())
        print(f"tp          :", logs["tp"])
        print(f"fp          :", logs["fp"])
        print(f"tn          :", logs["tn"])
        print(f"fn          :", logs["fn"])
        print(f"binary_acc  :", logs["binary_acc"])
        print(f"precision   :", logs["precision"])
        print(f"recall      :", logs["recall"])
        print(f"f1_score    :", logs["f1_score"])
        print(f"roc_auc     :", logs["roc_auc"])
        print(f"pr_auc      :", logs["pr_auc"])
        print(f"cohen_kappa :", logs["cohen_kappa"])

class F1Score(tf.keras.metrics.Metric):

    def __init__(self, name="f1_score", **kwargs):
        super().__init__(name=name, **kwargs)
        self.f1 = self.add_weight(name="f1", initializer="zeros")
        self.precision_fn = tf.keras.metrics.Precision()
        self.recall_fn = tf.keras.metrics.Recall()

    def update_state(self, y_true, y_pred, sample_weight=None):
        p = self.precision_fn(y_true, y_pred)
        r = self.recall_fn(y_true, y_pred)
        self.f1.assign(2 * ((p * r) / (p + r + 1e-10)))

    def result(self):
        return self.f1

    def reset_state(self):
        # we also need to reset the state of the precision and recall objects
        self.precision_fn.reset_state()
        self.recall_fn.reset_state()
        self.f1.assign(0)


def save_history(name,history_df):

    history_excel_path = (
            save_path +
            name +
            '_history'
            '.xlsx'
    )

    history_df.to_excel(history_excel_path, index=False)
    print("Training history saved to:", history_excel_path)






def plot_metrics(history: tf.keras.callbacks.History,
                 metrics: list = ["loss", "cohen_kappa", "precision", "recall"],
                 ) -> None:
    plt.rcParams["figure.figsize"] = (18, 15)

    for n, metric in enumerate(metrics):
        name = metric.replace("_", " ").capitalize()
        plt.subplot(2, 2, n + 1)
        plt.plot(
            history.epoch, history.history[metric], linewidth=1.8, label="training"
        )
        plt.plot(
            history.epoch,
            history.history["val_" + metric],
            linestyle="--",
            linewidth=1.8,
            label="validation",
        )
        plt.xlabel("epoch")
        plt.ylabel(name)
        if metric == "loss":
            plt.ylim([0, plt.ylim()[1]])
        elif metric == "cohen_kappa":
            plt.ylim([-1, 1])
        else:
            plt.ylim([0, 1])

        plt.legend()



class CustomCallback(keras.callbacks.Callback):
    def on_test_end(self, logs=None):
        keys = list(logs.keys())
        print(f"tp          :", logs["tp"])
        print(f"fp          :", logs["fp"])
        print(f"tn          :", logs["tn"])
        print(f"fn          :", logs["fn"])
        print(f"binary_acc  :", logs["binary_acc"])
        print(f"precision   :", logs["precision"])
        print(f"recall      :", logs["recall"])
        print(f"f1_score    :", logs["f1_score"])
        print(f"roc_auc     :", logs["roc_auc"])
        print(f"pr_auc      :", logs["pr_auc"])
        print(f"cohen_kappa :", logs["cohen_kappa"])

def build_ensemble_model():
    inputs = tf.keras.Input(shape=input_shape)

    resnet_preprocess_input = preprocess_input_resnet(inputs)
    resnet_base_output = resnet_base(resnet_preprocess_input)

    densenet_preprocess_input = preprocess_input_densenet(inputs)
    densenet_base_output = densenet_base(densenet_preprocess_input)

    concat_output = tf.keras.layers.Concatenate(axis=-1)([resnet_base_output, densenet_base_output])

    x = Dense(2048, activation="relu")(concat_output)
    x = Dropout(0.8)(x)
    x = Dense(1024, activation="relu")(x)
    x = Dropout(0.6)(x)
    x = Dense(512, activation="relu")(x)
    x = Dropout(0.4)(x)
    x = Dense(64, activation="relu")(x)
    x = Dropout(0.2)(x)
    prediction = Dense(1, activation="sigmoid")(x)

    model = Model(inputs, prediction)
    model._name = "Ensemble_model"

    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
                  loss=tf.keras.losses.BinaryCrossentropy(),
                  metrics=METRICS)
    return model


def save_history(name,history_df):

    # Constructing the file name with metric values
    history_excel_path = (
            save_path +
            name +
            '_history'
            '.xlsx'
    )

    history_df.to_excel(history_excel_path, index=False)
    print("Training history saved to:", history_excel_path)




class F1Score(tf.keras.metrics.Metric):

    def __init__(self, name="f1_score", **kwargs):
        super().__init__(name=name, **kwargs)
        self.f1 = self.add_weight(name="f1", initializer="zeros")
        self.precision_fn = tf.keras.metrics.Precision()
        self.recall_fn = tf.keras.metrics.Recall()

    def update_state(self, y_true, y_pred, sample_weight=None):
        p = self.precision_fn(y_true, y_pred)
        r = self.recall_fn(y_true, y_pred)
        self.f1.assign(2 * ((p * r) / (p + r + 1e-10)))

    def result(self):
        return self.f1

    def reset_state(self):
        # we also need to reset the state of the precision and recall objects
        self.precision_fn.reset_state()
        self.recall_fn.reset_state()
        self.f1.assign(0)

def plot_metrics(history: tf.keras.callbacks.History,
                 metrics: list = ["loss", "cohen_kappa", "precision", "recall"],
                 ) -> None:
    plt.rcParams["figure.figsize"] = (18, 15)

    for n, metric in enumerate(metrics):
        name = metric.replace("_", " ").capitalize()
        plt.subplot(2, 2, n + 1)
        plt.plot(
            history.epoch, history.history[metric], linewidth=1.8, label="training"
        )
        plt.plot(
            history.epoch,
            history.history["val_" + metric],
            linestyle="--",
            linewidth=1.8,
            label="validation",
        )
        plt.xlabel("epoch")
        plt.ylabel(name)
        if metric == "loss":
            plt.ylim([0, plt.ylim()[1]])
        elif metric == "cohen_kappa":
            plt.ylim([-1, 1])
        else:
            plt.ylim([0, 1])

        plt.legend()


def my_func(model, data_generator, threshold=0.5):
    y_pred_prob = model.predict(data_generator)
    y_pred = (y_pred_prob > threshold).astype(int)
    y_true = data_generator.classes
    print("Classification Report:")
    print(classification_report(y_true, y_pred))

# %%
METRICS = [
    tf.keras.metrics.TruePositives(name="tp"),
    tf.keras.metrics.FalsePositives(name="fp"),
    tf.keras.metrics.TrueNegatives(name="tn"),
    tf.keras.metrics.FalseNegatives(name="fn"),
    tf.keras.metrics.BinaryAccuracy(name="binary_acc"),
    tf.keras.metrics.Precision(name="precision"),
    tf.keras.metrics.Recall(name="recall"),
    F1Score(name="f1_score"),
    tf.keras.metrics.AUC(name="roc_auc", curve="ROC"),
    tf.keras.metrics.AUC(name="pr_auc", curve="PR"),
    tfa.metrics.CohenKappa(name="cohen_kappa", num_classes=2),
]

# %%
resnet = tf.keras.applications.resnet50.ResNet50(include_top=include_top,
                                                 weights="imagenet",
                                                 input_shape=(IMAGE_WIDTH, IMAGE_HEIGHT, 3),
                                                 pooling="max",  # pooling mode for feature extraction
                                                 classes=2)


def make_resnet_model(base_model: tf.keras.applications.resnet50.ResNet50, ) -> tf.keras.Model:
    # freeze base model
    base_model.trainable = False  # trainable

    inputs = tf.keras.Input(shape=(IMAGE_WIDTH, IMAGE_HEIGHT, 3))
    x = base_model(inputs, training=training)

    # x = tf.keras.layers.Dense(4096, activation='relu')(x)
    x = tf.keras.layers.Dense(1024, activation='relu')(x)
    x = tf.keras.layers.Dropout(rate=dropout)(x)
    x = tf.keras.layers.Dense(512, activation='relu')(x)
    # x = tf.keras.layers.Dropout(rate=dropout)(x)

    output = tf.keras.layers.Dense(units=1, activation="sigmoid")(x)

    model = tf.keras.Model(inputs, output)

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
        loss=loss_function,
        metrics=METRICS,
    )

    return model

# %%
new_model = make_resnet_model(base_model=resnet)

new_model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  resnet50 (Functional)       (None, 2048)              23587712
#
#  dense_6 (Dense)             (None, 1024)              2098176
#
#  dropout_2 (Dropout)         (None, 1024)              0
#
#  dense_7 (Dense)             (None, 512)               524800
#
#  dense_8 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 26,211,201
# Trainable params: 2,623,489
# Non-trainable params: 23,587,712
# _________________________________________________________________

# %%
"""import matplotlib.pyplot as plt
from tensorflow.keras.utils import plot_model
tf.keras.utils.plot_model(new_model,
                          show_shapes=True,  # show_dtype=False,
                          show_layer_names=True,
                          layer_range=None,
                          show_layer_activations=True)"""
# Out:
# 'import matplotlib.pyplot as plt\nfrom tensorflow.keras.utils import plot_model\ntf.keras.utils.plot_model(new_model,\n                          show_shapes=True,  # show_dtype=False,\n                          show_layer_names=True,\n                          layer_range=None,\n                          show_layer_activations=True)'

# %%
early_stopping = EarlyStopping(monitor="val_cohen_kappa",
                               verbose=1,
                               patience=early_stopping_patience,
                               mode="max",
                               baseline=0.0,
                               restore_best_weights=True)
save_path = main_save_path + target_category + "/"
model_name = architecture + "_" + target_category
model_path = save_path + '_best_' + model_name + '.keras'
model_checkpoint = ModelCheckpoint(filepath=model_path,
                                       monitor="val_cohen_kappa",
                                       save_best_only=True)

# %%
import pandas as pd


old_base_path = 'C:\\Users\\HP\\Documents\\ML\\encadrement Master\\MURA-V1.1\\'

df_train = pd.read_csv(train_file)
df_train['image_path'] = df_train['image_path'].str.replace(old_base_path, mura_location)

df_valid = pd.read_csv(val_file)
df_valid['image_path'] = df_valid['image_path'].str.replace(old_base_path, mura_location)


df_test = load_data(test_file, target_category)

datagen = tf.keras.preprocessing.image.ImageDataGenerator(rotation_range=30,
                                                              horizontal_flip=True,
                                                              fill_mode="constant",
                                                              cval=0.0,
                                                              preprocessing_function=tf.keras.applications.resnet50.preprocess_input)
train_generator = datagen.flow_from_dataframe(df_train,
                                                  directory=None,
                                                  x_col='image_path',
                                                  y_col='label',
                                                  target_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
                                                  batch_size=batch_size,
                                                  class_mode=class_mode,
                                                  )

validation_generator = datagen.flow_from_dataframe(df_valid,
                                                       directory=None,
                                                       x_col='image_path',
                                                       y_col='label',
                                                       target_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
                                                       batch_size=batch_size,
                                                       class_mode=class_mode,
                                                   shuffle=False
                                                       )

test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
        preprocessing_function=tf.keras.applications.resnet50.preprocess_input)
test_generator = test_datagen.flow_from_dataframe(df_test,
                                                      directory=None,
                                                      x_col='image_path',
                                                      y_col='label',
                                                      target_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
                                                      batch_size=batch_size,
                                                      class_mode=class_mode,
                                                  shuffle=False
                                                      )
# Out:
# C:\Users\raouf\AppData\Local\Temp\ipykernel_124936\982068502.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'positive' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_data.at[index, 'label'] = "positive"
# Found 6703 validated image filenames belonging to 2 classes.
# Found 1676 validated image filenames belonging to 2 classes.
# Found 563 validated image filenames belonging to 2 classes.

# %%
history = new_model.fit(train_generator,
                            # teps_per_epoch=len(df_train) // batch_size,
                            validation_data=validation_generator,
                            # validation_steps=len(df_valid) // batch_size,
                            epochs=num_epochs,
                            shuffle=shuffle,
                            callbacks=[early_stopping, model_checkpoint])  # , reduce_lr_callback])
# Out:
# Epoch 1/100
# 419/419 [==============================] - 77s 176ms/step - loss: 0.9884 - tp: 1932.0000 - fp: 1374.0000 - tn: 1989.0000 - fn: 1408.0000 - binary_acc: 0.5850 - precision: 0.5844 - recall: 0.5784 - f1_score: 0.5814 - roc_auc: 0.6056 - pr_auc: 0.5915 - cohen_kappa: 0.1699 - val_loss: 0.6235 - val_tp: 403.0000 - val_fp: 122.0000 - val_tn: 726.0000 - val_fn: 425.0000 - val_binary_acc: 0.6736 - val_precision: 0.7676 - val_recall: 0.4867 - val_f1_score: 0.5957 - val_roc_auc: 0.7454 - val_pr_auc: 0.7490 - val_cohen_kappa: 0.3443
# Epoch 2/100
# 419/419 [==============================] - 69s 164ms/step - loss: 0.6804 - tp: 2089.0000 - fp: 1148.0000 - tn: 2215.0000 - fn: 1251.0000 - binary_acc: 0.6421 - precision: 0.6454 - recall: 0.6254 - f1_score: 0.6352 - roc_auc: 0.6940 - pr_auc: 0.6918 - cohen_kappa: 0.2841 - val_loss: 0.5942 - val_tp: 465.0000 - val_fp: 153.0000 - val_tn: 695.0000 - val_fn: 363.0000 - val_binary_acc: 0.6921 - val_precision: 0.7524 - val_recall: 0.5616 - val_f1_score: 0.6432 - val_roc_auc: 0.7571 - val_pr_auc: 0.7621 - val_cohen_kappa: 0.3823
# Epoch 3/100
# 419/419 [==============================] - 69s 165ms/step - loss: 0.6541 - tp: 2154.0000 - fp: 1090.0000 - tn: 2273.0000 - fn: 1186.0000 - binary_acc: 0.6605 - precision: 0.6640 - recall: 0.6449 - f1_score: 0.6543 - roc_auc: 0.7126 - pr_auc: 0.7114 - cohen_kappa: 0.3208 - val_loss: 0.5790 - val_tp: 542.0000 - val_fp: 213.0000 - val_tn: 635.0000 - val_fn: 286.0000 - val_binary_acc: 0.7023 - val_precision: 0.7179 - val_recall: 0.6546 - val_f1_score: 0.6848 - val_roc_auc: 0.7643 - val_pr_auc: 0.7648 - val_cohen_kappa: 0.4038
# Epoch 4/100
# 419/419 [==============================] - 72s 172ms/step - loss: 0.6144 - tp: 2179.0000 - fp: 1044.0000 - tn: 2319.0000 - fn: 1161.0000 - binary_acc: 0.6710 - precision: 0.6761 - recall: 0.6524 - f1_score: 0.6640 - roc_auc: 0.7375 - pr_auc: 0.7374 - cohen_kappa: 0.3420 - val_loss: 0.5849 - val_tp: 541.0000 - val_fp: 240.0000 - val_tn: 608.0000 - val_fn: 287.0000 - val_binary_acc: 0.6856 - val_precision: 0.6927 - val_recall: 0.6534 - val_f1_score: 0.6725 - val_roc_auc: 0.7547 - val_pr_auc: 0.7674 - val_cohen_kappa: 0.3706
# Epoch 5/100
# 419/419 [==============================] - 71s 171ms/step - loss: 0.6071 - tp: 2211.0000 - fp: 982.0000 - tn: 2381.0000 - fn: 1129.0000 - binary_acc: 0.6851 - precision: 0.6925 - recall: 0.6620 - f1_score: 0.6769 - roc_auc: 0.7466 - pr_auc: 0.7503 - cohen_kappa: 0.3700 - val_loss: 0.5691 - val_tp: 597.0000 - val_fp: 253.0000 - val_tn: 595.0000 - val_fn: 231.0000 - val_binary_acc: 0.7112 - val_precision: 0.7024 - val_recall: 0.7210 - val_f1_score: 0.7116 - val_roc_auc: 0.7766 - val_pr_auc: 0.7871 - val_cohen_kappa: 0.4225
# Epoch 6/100
# 419/419 [==============================] - 72s 171ms/step - loss: 0.5912 - tp: 2266.0000 - fp: 958.0000 - tn: 2405.0000 - fn: 1074.0000 - binary_acc: 0.6969 - precision: 0.7029 - recall: 0.6784 - f1_score: 0.6904 - roc_auc: 0.7628 - pr_auc: 0.7656 - cohen_kappa: 0.3936 - val_loss: 0.6075 - val_tp: 673.0000 - val_fp: 387.0000 - val_tn: 461.0000 - val_fn: 155.0000 - val_binary_acc: 0.6766 - val_precision: 0.6349 - val_recall: 0.8128 - val_f1_score: 0.7129 - val_roc_auc: 0.7714 - val_pr_auc: 0.7691 - val_cohen_kappa: 0.3553
# Epoch 7/100
# 419/419 [==============================] - 71s 169ms/step - loss: 0.5792 - tp: 2265.0000 - fp: 926.0000 - tn: 2437.0000 - fn: 1075.0000 - binary_acc: 0.7015 - precision: 0.7098 - recall: 0.6781 - f1_score: 0.6936 - roc_auc: 0.7686 - pr_auc: 0.7734 - cohen_kappa: 0.4029 - val_loss: 0.5585 - val_tp: 463.0000 - val_fp: 83.0000 - val_tn: 765.0000 - val_fn: 365.0000 - val_binary_acc: 0.7327 - val_precision: 0.8480 - val_recall: 0.5592 - val_f1_score: 0.6739 - val_roc_auc: 0.8107 - val_pr_auc: 0.8203 - val_cohen_kappa: 0.4632
# Epoch 8/100
# 419/419 [==============================] - 71s 170ms/step - loss: 0.5716 - tp: 2287.0000 - fp: 892.0000 - tn: 2471.0000 - fn: 1053.0000 - binary_acc: 0.7098 - precision: 0.7194 - recall: 0.6847 - f1_score: 0.7016 - roc_auc: 0.7786 - pr_auc: 0.7839 - cohen_kappa: 0.4196 - val_loss: 0.5545 - val_tp: 462.0000 - val_fp: 91.0000 - val_tn: 757.0000 - val_fn: 366.0000 - val_binary_acc: 0.7273 - val_precision: 0.8354 - val_recall: 0.5580 - val_f1_score: 0.6691 - val_roc_auc: 0.8045 - val_pr_auc: 0.8090 - val_cohen_kappa: 0.4524
# Epoch 9/100
# 419/419 [==============================] - 71s 170ms/step - loss: 0.5633 - tp: 2310.0000 - fp: 850.0000 - tn: 2513.0000 - fn: 1030.0000 - binary_acc: 0.7195 - precision: 0.7310 - recall: 0.6916 - f1_score: 0.7108 - roc_auc: 0.7849 - pr_auc: 0.7892 - cohen_kappa: 0.4389 - val_loss: 0.5481 - val_tp: 566.0000 - val_fp: 199.0000 - val_tn: 649.0000 - val_fn: 262.0000 - val_binary_acc: 0.7249 - val_precision: 0.7399 - val_recall: 0.6836 - val_f1_score: 0.7106 - val_roc_auc: 0.7948 - val_pr_auc: 0.7983 - val_cohen_kappa: 0.4493
# Epoch 10/100
# 419/419 [==============================] - 75s 178ms/step - loss: 0.5474 - tp: 2322.0000 - fp: 840.0000 - tn: 2523.0000 - fn: 1018.0000 - binary_acc: 0.7228 - precision: 0.7343 - recall: 0.6952 - f1_score: 0.7142 - roc_auc: 0.7963 - pr_auc: 0.8038 - cohen_kappa: 0.4455 - val_loss: 0.5383 - val_tp: 630.0000 - val_fp: 247.0000 - val_tn: 601.0000 - val_fn: 198.0000 - val_binary_acc: 0.7345 - val_precision: 0.7184 - val_recall: 0.7609 - val_f1_score: 0.7390 - val_roc_auc: 0.8113 - val_pr_auc: 0.8144 - val_cohen_kappa: 0.4693
# Epoch 11/100
# 419/419 [==============================] - 72s 172ms/step - loss: 0.5478 - tp: 2325.0000 - fp: 837.0000 - tn: 2526.0000 - fn: 1015.0000 - binary_acc: 0.7237 - precision: 0.7353 - recall: 0.6961 - f1_score: 0.7152 - roc_auc: 0.7969 - pr_auc: 0.8049 - cohen_kappa: 0.4473 - val_loss: 0.5912 - val_tp: 711.0000 - val_fp: 406.0000 - val_tn: 442.0000 - val_fn: 117.0000 - val_binary_acc: 0.6879 - val_precision: 0.6365 - val_recall: 0.8587 - val_f1_score: 0.7311 - val_roc_auc: 0.8069 - val_pr_auc: 0.8051 - val_cohen_kappa: 0.3784
# Epoch 12/100
# 419/419 [==============================] - 74s 175ms/step - loss: 0.5375 - tp: 2368.0000 - fp: 807.0000 - tn: 2556.0000 - fn: 972.0000 - binary_acc: 0.7346 - precision: 0.7458 - recall: 0.7090 - f1_score: 0.7269 - roc_auc: 0.8065 - pr_auc: 0.8101 - cohen_kappa: 0.4691 - val_loss: 0.5296 - val_tp: 579.0000 - val_fp: 187.0000 - val_tn: 661.0000 - val_fn: 249.0000 - val_binary_acc: 0.7399 - val_precision: 0.7559 - val_recall: 0.6993 - val_f1_score: 0.7265 - val_roc_auc: 0.8109 - val_pr_auc: 0.8112 - val_cohen_kappa: 0.4792
# Epoch 13/100
# 419/419 [==============================] - 71s 170ms/step - loss: 0.5384 - tp: 2367.0000 - fp: 830.0000 - tn: 2533.0000 - fn: 973.0000 - binary_acc: 0.7310 - precision: 0.7404 - recall: 0.7087 - f1_score: 0.7242 - roc_auc: 0.8050 - pr_auc: 0.8115 - cohen_kappa: 0.4619 - val_loss: 0.5833 - val_tp: 690.0000 - val_fp: 376.0000 - val_tn: 472.0000 - val_fn: 138.0000 - val_binary_acc: 0.6933 - val_precision: 0.6473 - val_recall: 0.8333 - val_f1_score: 0.7286 - val_roc_auc: 0.7990 - val_pr_auc: 0.8024 - val_cohen_kappa: 0.3886
# Epoch 14/100
# 419/419 [==============================] - 72s 173ms/step - loss: 0.5279 - tp: 2368.0000 - fp: 768.0000 - tn: 2595.0000 - fn: 972.0000 - binary_acc: 0.7404 - precision: 0.7551 - recall: 0.7090 - f1_score: 0.7313 - roc_auc: 0.8127 - pr_auc: 0.8228 - cohen_kappa: 0.4807 - val_loss: 0.5284 - val_tp: 569.0000 - val_fp: 173.0000 - val_tn: 675.0000 - val_fn: 259.0000 - val_binary_acc: 0.7422 - val_precision: 0.7668 - val_recall: 0.6872 - val_f1_score: 0.7248 - val_roc_auc: 0.8162 - val_pr_auc: 0.8125 - val_cohen_kappa: 0.4838
# Epoch 15/100
# 419/419 [==============================] - 71s 169ms/step - loss: 0.5239 - tp: 2376.0000 - fp: 777.0000 - tn: 2586.0000 - fn: 964.0000 - binary_acc: 0.7403 - precision: 0.7536 - recall: 0.7114 - f1_score: 0.7319 - roc_auc: 0.8161 - pr_auc: 0.8239 - cohen_kappa: 0.4804 - val_loss: 0.5446 - val_tp: 672.0000 - val_fp: 294.0000 - val_tn: 554.0000 - val_fn: 156.0000 - val_binary_acc: 0.7315 - val_precision: 0.6957 - val_recall: 0.8116 - val_f1_score: 0.7492 - val_roc_auc: 0.8196 - val_pr_auc: 0.8251 - val_cohen_kappa: 0.4640
# Epoch 16/100
# 419/419 [==============================] - 73s 174ms/step - loss: 0.5196 - tp: 2405.0000 - fp: 751.0000 - tn: 2612.0000 - fn: 935.0000 - binary_acc: 0.7485 - precision: 0.7620 - recall: 0.7201 - f1_score: 0.7405 - roc_auc: 0.8210 - pr_auc: 0.8259 - cohen_kappa: 0.4968 - val_loss: 0.5274 - val_tp: 633.0000 - val_fp: 239.0000 - val_tn: 609.0000 - val_fn: 195.0000 - val_binary_acc: 0.7411 - val_precision: 0.7259 - val_recall: 0.7645 - val_f1_score: 0.7447 - val_roc_auc: 0.8155 - val_pr_auc: 0.8195 - val_cohen_kappa: 0.4824
# Epoch 17/100
# 419/419 [==============================] - 71s 170ms/step - loss: 0.5211 - tp: 2381.0000 - fp: 732.0000 - tn: 2631.0000 - fn: 959.0000 - binary_acc: 0.7477 - precision: 0.7649 - recall: 0.7129 - f1_score: 0.7380 - roc_auc: 0.8192 - pr_auc: 0.8266 - cohen_kappa: 0.4953 - val_loss: 0.5224 - val_tp: 556.0000 - val_fp: 148.0000 - val_tn: 700.0000 - val_fn: 272.0000 - val_binary_acc: 0.7494 - val_precision: 0.7898 - val_recall: 0.6715 - val_f1_score: 0.7258 - val_roc_auc: 0.8190 - val_pr_auc: 0.8240 - val_cohen_kappa: 0.4978
# Epoch 18/100
# 419/419 [==============================] - 74s 178ms/step - loss: 0.5114 - tp: 2415.0000 - fp: 751.0000 - tn: 2612.0000 - fn: 925.0000 - binary_acc: 0.7500 - precision: 0.7628 - recall: 0.7231 - f1_score: 0.7424 - roc_auc: 0.8275 - pr_auc: 0.8335 - cohen_kappa: 0.4998 - val_loss: 0.5381 - val_tp: 642.0000 - val_fp: 276.0000 - val_tn: 572.0000 - val_fn: 186.0000 - val_binary_acc: 0.7243 - val_precision: 0.6993 - val_recall: 0.7754 - val_f1_score: 0.7354 - val_roc_auc: 0.8133 - val_pr_auc: 0.8197 - val_cohen_kappa: 0.4493
# Epoch 19/100
# 419/419 [==============================] - 71s 171ms/step - loss: 0.5049 - tp: 2445.0000 - fp: 741.0000 - tn: 2622.0000 - fn: 895.0000 - binary_acc: 0.7559 - precision: 0.7674 - recall: 0.7320 - f1_score: 0.7493 - roc_auc: 0.8314 - pr_auc: 0.8380 - cohen_kappa: 0.5118 - val_loss: 0.5759 - val_tp: 478.0000 - val_fp: 108.0000 - val_tn: 740.0000 - val_fn: 350.0000 - val_binary_acc: 0.7267 - val_precision: 0.8157 - val_recall: 0.5773 - val_f1_score: 0.6761 - val_roc_auc: 0.8038 - val_pr_auc: 0.8158 - val_cohen_kappa: 0.4515
# Epoch 20/100
# 419/419 [==============================] - 74s 177ms/step - loss: 0.4943 - tp: 2436.0000 - fp: 704.0000 - tn: 2659.0000 - fn: 904.0000 - binary_acc: 0.7601 - precision: 0.7758 - recall: 0.7293 - f1_score: 0.7519 - roc_auc: 0.8386 - pr_auc: 0.8497 - cohen_kappa: 0.5201 - val_loss: 0.5573 - val_tp: 463.0000 - val_fp: 94.0000 - val_tn: 754.0000 - val_fn: 365.0000 - val_binary_acc: 0.7261 - val_precision: 0.8312 - val_recall: 0.5592 - val_f1_score: 0.6686 - val_roc_auc: 0.8080 - val_pr_auc: 0.8140 - val_cohen_kappa: 0.4501
# Epoch 21/100
# 419/419 [==============================] - 72s 171ms/step - loss: 0.4998 - tp: 2443.0000 - fp: 694.0000 - tn: 2669.0000 - fn: 897.0000 - binary_acc: 0.7626 - precision: 0.7788 - recall: 0.7314 - f1_score: 0.7544 - roc_auc: 0.8357 - pr_auc: 0.8443 - cohen_kappa: 0.5252 - val_loss: 0.5516 - val_tp: 638.0000 - val_fp: 288.0000 - val_tn: 560.0000 - val_fn: 190.0000 - val_binary_acc: 0.7148 - val_precision: 0.6890 - val_recall: 0.7705 - val_f1_score: 0.7275 - val_roc_auc: 0.8039 - val_pr_auc: 0.8066 - val_cohen_kappa: 0.4303
# Epoch 22/100
# 419/419 [==============================] - 72s 173ms/step - loss: 0.4900 - tp: 2441.0000 - fp: 689.0000 - tn: 2674.0000 - fn: 899.0000 - binary_acc: 0.7631 - precision: 0.7799 - recall: 0.7308 - f1_score: 0.7546 - roc_auc: 0.8413 - pr_auc: 0.8533 - cohen_kappa: 0.5261 - val_loss: 0.5151 - val_tp: 619.0000 - val_fp: 205.0000 - val_tn: 643.0000 - val_fn: 209.0000 - val_binary_acc: 0.7530 - val_precision: 0.7512 - val_recall: 0.7476 - val_f1_score: 0.7494 - val_roc_auc: 0.8229 - val_pr_auc: 0.8323 - val_cohen_kappa: 0.5059
# Epoch 23/100
# 419/419 [==============================] - 73s 174ms/step - loss: 0.4983 - tp: 2409.0000 - fp: 714.0000 - tn: 2649.0000 - fn: 931.0000 - binary_acc: 0.7546 - precision: 0.7714 - recall: 0.7213 - f1_score: 0.7455 - roc_auc: 0.8348 - pr_auc: 0.8462 - cohen_kappa: 0.5091 - val_loss: 0.5289 - val_tp: 514.0000 - val_fp: 106.0000 - val_tn: 742.0000 - val_fn: 314.0000 - val_binary_acc: 0.7494 - val_precision: 0.8290 - val_recall: 0.6208 - val_f1_score: 0.7099 - val_roc_auc: 0.8184 - val_pr_auc: 0.8265 - val_cohen_kappa: 0.4972
# Epoch 24/100
# 419/419 [==============================] - 75s 180ms/step - loss: 0.4903 - tp: 2455.0000 - fp: 674.0000 - tn: 2689.0000 - fn: 885.0000 - binary_acc: 0.7674 - precision: 0.7846 - recall: 0.7350 - f1_score: 0.7590 - roc_auc: 0.8428 - pr_auc: 0.8488 - cohen_kappa: 0.5347 - val_loss: 0.5610 - val_tp: 677.0000 - val_fp: 325.0000 - val_tn: 523.0000 - val_fn: 151.0000 - val_binary_acc: 0.7160 - val_precision: 0.6756 - val_recall: 0.8176 - val_f1_score: 0.7399 - val_roc_auc: 0.8124 - val_pr_auc: 0.8141 - val_cohen_kappa: 0.4333
# Epoch 25/100
# 419/419 [==============================] - 74s 177ms/step - loss: 0.4874 - tp: 2474.0000 - fp: 711.0000 - tn: 2652.0000 - fn: 866.0000 - binary_acc: 0.7647 - precision: 0.7768 - recall: 0.7407 - f1_score: 0.7583 - roc_auc: 0.8432 - pr_auc: 0.8526 - cohen_kappa: 0.5294 - val_loss: 0.5202 - val_tp: 595.0000 - val_fp: 180.0000 - val_tn: 668.0000 - val_fn: 233.0000 - val_binary_acc: 0.7536 - val_precision: 0.7677 - val_recall: 0.7186 - val_f1_score: 0.7424 - val_roc_auc: 0.8167 - val_pr_auc: 0.8276 - val_cohen_kappa: 0.5067
# Epoch 26/100
# 419/419 [==============================] - 74s 177ms/step - loss: 0.4773 - tp: 2506.0000 - fp: 656.0000 - tn: 2707.0000 - fn: 834.0000 - binary_acc: 0.7777 - precision: 0.7925 - recall: 0.7503 - f1_score: 0.7708 - roc_auc: 0.8505 - pr_auc: 0.8611 - cohen_kappa: 0.5553 - val_loss: 0.5286 - val_tp: 566.0000 - val_fp: 167.0000 - val_tn: 681.0000 - val_fn: 262.0000 - val_binary_acc: 0.7440 - val_precision: 0.7722 - val_recall: 0.6836 - val_f1_score: 0.7252 - val_roc_auc: 0.8159 - val_pr_auc: 0.8232 - val_cohen_kappa: 0.4873
# Epoch 27/100
# 419/419 [==============================] - 73s 173ms/step - loss: 0.4770 - tp: 2463.0000 - fp: 645.0000 - tn: 2718.0000 - fn: 877.0000 - binary_acc: 0.7729 - precision: 0.7925 - recall: 0.7374 - f1_score: 0.7640 - roc_auc: 0.8497 - pr_auc: 0.8619 - cohen_kappa: 0.5458 - val_loss: 0.5204 - val_tp: 583.0000 - val_fp: 162.0000 - val_tn: 686.0000 - val_fn: 245.0000 - val_binary_acc: 0.7572 - val_precision: 0.7826 - val_recall: 0.7041 - val_f1_score: 0.7413 - val_roc_auc: 0.8235 - val_pr_auc: 0.8194 - val_cohen_kappa: 0.5137
# Epoch 28/100
# 419/419 [==============================] - 73s 174ms/step - loss: 0.4722 - tp: 2515.0000 - fp: 643.0000 - tn: 2720.0000 - fn: 825.0000 - binary_acc: 0.7810 - precision: 0.7964 - recall: 0.7530 - f1_score: 0.7741 - roc_auc: 0.8533 - pr_auc: 0.8644 - cohen_kappa: 0.5619 - val_loss: 0.5379 - val_tp: 656.0000 - val_fp: 273.0000 - val_tn: 575.0000 - val_fn: 172.0000 - val_binary_acc: 0.7345 - val_precision: 0.7061 - val_recall: 0.7923 - val_f1_score: 0.7467 - val_roc_auc: 0.8185 - val_pr_auc: 0.8242 - val_cohen_kappa: 0.4697
# Epoch 29/100
# 419/419 [==============================] - 73s 173ms/step - loss: 0.4807 - tp: 2490.0000 - fp: 673.0000 - tn: 2690.0000 - fn: 850.0000 - binary_acc: 0.7728 - precision: 0.7872 - recall: 0.7455 - f1_score: 0.7658 - roc_auc: 0.8483 - pr_auc: 0.8572 - cohen_kappa: 0.5455 - val_loss: 0.5394 - val_tp: 511.0000 - val_fp: 112.0000 - val_tn: 736.0000 - val_fn: 317.0000 - val_binary_acc: 0.7440 - val_precision: 0.8202 - val_recall: 0.6171 - val_f1_score: 0.7043 - val_roc_auc: 0.8152 - val_pr_auc: 0.8218 - val_cohen_kappa: 0.4865
# Epoch 30/100
# 419/419 [==============================] - 74s 176ms/step - loss: 0.4734 - tp: 2462.0000 - fp: 638.0000 - tn: 2725.0000 - fn: 878.0000 - binary_acc: 0.7738 - precision: 0.7942 - recall: 0.7371 - f1_score: 0.7646 - roc_auc: 0.8534 - pr_auc: 0.8624 - cohen_kappa: 0.5475 - val_loss: 0.5231 - val_tp: 565.0000 - val_fp: 165.0000 - val_tn: 683.0000 - val_fn: 263.0000 - val_binary_acc: 0.7446 - val_precision: 0.7740 - val_recall: 0.6824 - val_f1_score: 0.7253 - val_roc_auc: 0.8205 - val_pr_auc: 0.8212 - val_cohen_kappa: 0.4885
# Epoch 31/100
# 419/419 [==============================] - 72s 173ms/step - loss: 0.4759 - tp: 2495.0000 - fp: 674.0000 - tn: 2689.0000 - fn: 845.0000 - binary_acc: 0.7734 - precision: 0.7873 - recall: 0.7470 - f1_score: 0.7666 - roc_auc: 0.8513 - pr_auc: 0.8613 - cohen_kappa: 0.5467 - val_loss: 0.5265 - val_tp: 528.0000 - val_fp: 126.0000 - val_tn: 722.0000 - val_fn: 300.0000 - val_binary_acc: 0.7458 - val_precision: 0.8073 - val_recall: 0.6377 - val_f1_score: 0.7126 - val_roc_auc: 0.8230 - val_pr_auc: 0.8278 - val_cohen_kappa: 0.4903
# Epoch 32/100
# 419/419 [==============================] - 74s 176ms/step - loss: 0.4645 - tp: 2496.0000 - fp: 641.0000 - tn: 2722.0000 - fn: 844.0000 - binary_acc: 0.7785 - precision: 0.7957 - recall: 0.7473 - f1_score: 0.7707 - roc_auc: 0.8591 - pr_auc: 0.8690 - cohen_kappa: 0.5568 - val_loss: 0.5353 - val_tp: 541.0000 - val_fp: 148.0000 - val_tn: 700.0000 - val_fn: 287.0000 - val_binary_acc: 0.7405 - val_precision: 0.7852 - val_recall: 0.6534 - val_f1_score: 0.7132 - val_roc_auc: 0.8166 - val_pr_auc: 0.8268 - val_cohen_kappa: 0.4798
# Epoch 33/100
# 419/419 [==============================] - 73s 175ms/step - loss: 0.4595 - tp: 2526.0000 - fp: 616.0000 - tn: 2747.0000 - fn: 814.0000 - binary_acc: 0.7867 - precision: 0.8039 - recall: 0.7563 - f1_score: 0.7794 - roc_auc: 0.8632 - pr_auc: 0.8716 - cohen_kappa: 0.5732 - val_loss: 0.5512 - val_tp: 494.0000 - val_fp: 108.0000 - val_tn: 740.0000 - val_fn: 334.0000 - val_binary_acc: 0.7363 - val_precision: 0.8206 - val_recall: 0.5966 - val_f1_score: 0.6909 - val_roc_auc: 0.8150 - val_pr_auc: 0.8192 - val_cohen_kappa: 0.4708
# Epoch 34/100
# 419/419 [==============================] - 72s 171ms/step - loss: 0.4557 - tp: 2523.0000 - fp: 587.0000 - tn: 2776.0000 - fn: 817.0000 - binary_acc: 0.7905 - precision: 0.8113 - recall: 0.7554 - f1_score: 0.7823 - roc_auc: 0.8654 - pr_auc: 0.8755 - cohen_kappa: 0.5810 - val_loss: 0.5192 - val_tp: 619.0000 - val_fp: 209.0000 - val_tn: 639.0000 - val_fn: 209.0000 - val_binary_acc: 0.7506 - val_precision: 0.7476 - val_recall: 0.7476 - val_f1_score: 0.7476 - val_roc_auc: 0.8220 - val_pr_auc: 0.8335 - val_cohen_kappa: 0.5011
# Epoch 35/100
# 419/419 [==============================] - 71s 168ms/step - loss: 0.4624 - tp: 2527.0000 - fp: 623.0000 - tn: 2740.0000 - fn: 813.0000 - binary_acc: 0.7858 - precision: 0.8022 - recall: 0.7566 - f1_score: 0.7787 - roc_auc: 0.8601 - pr_auc: 0.8705 - cohen_kappa: 0.5714 - val_loss: 0.5383 - val_tp: 654.0000 - val_fp: 259.0000 - val_tn: 589.0000 - val_fn: 174.0000 - val_binary_acc: 0.7416 - val_precision: 0.7163 - val_recall: 0.7899 - val_f1_score: 0.7513 - val_roc_auc: 0.8204 - val_pr_auc: 0.8331 - val_cohen_kappa: 0.4838
# Epoch 36/100
# 419/419 [==============================] - 70s 167ms/step - loss: 0.4584 - tp: 2532.0000 - fp: 628.0000 - tn: 2735.0000 - fn: 808.0000 - binary_acc: 0.7858 - precision: 0.8013 - recall: 0.7581 - f1_score: 0.7791 - roc_auc: 0.8636 - pr_auc: 0.8724 - cohen_kappa: 0.5715 - val_loss: 0.5670 - val_tp: 456.0000 - val_fp: 87.0000 - val_tn: 761.0000 - val_fn: 372.0000 - val_binary_acc: 0.7261 - val_precision: 0.8398 - val_recall: 0.5507 - val_f1_score: 0.6652 - val_roc_auc: 0.8211 - val_pr_auc: 0.8234 - val_cohen_kappa: 0.4500
# Epoch 37/100
# 419/419 [==============================] - 70s 167ms/step - loss: 0.4566 - tp: 2509.0000 - fp: 615.0000 - tn: 2748.0000 - fn: 831.0000 - binary_acc: 0.7843 - precision: 0.8031 - recall: 0.7512 - f1_score: 0.7763 - roc_auc: 0.8643 - pr_auc: 0.8741 - cohen_kappa: 0.5685 - val_loss: 0.5292 - val_tp: 629.0000 - val_fp: 237.0000 - val_tn: 611.0000 - val_fn: 199.0000 - val_binary_acc: 0.7399 - val_precision: 0.7263 - val_recall: 0.7597 - val_f1_score: 0.7426 - val_roc_auc: 0.8177 - val_pr_auc: 0.8231 - val_cohen_kappa: 0.4799
# Epoch 38/100
# 419/419 [==============================] - 71s 169ms/step - loss: 0.4599 - tp: 2510.0000 - fp: 652.0000 - tn: 2711.0000 - fn: 830.0000 - binary_acc: 0.7789 - precision: 0.7938 - recall: 0.7515 - f1_score: 0.7721 - roc_auc: 0.8611 - pr_auc: 0.8717 - cohen_kappa: 0.5577 - val_loss: 0.5203 - val_tp: 545.0000 - val_fp: 133.0000 - val_tn: 715.0000 - val_fn: 283.0000 - val_binary_acc: 0.7518 - val_precision: 0.8038 - val_recall: 0.6582 - val_f1_score: 0.7238 - val_roc_auc: 0.8270 - val_pr_auc: 0.8366 - val_cohen_kappa: 0.5024
# Epoch 39/100
# 419/419 [==============================] - 69s 166ms/step - loss: 0.4495 - tp: 2536.0000 - fp: 609.0000 - tn: 2754.0000 - fn: 804.0000 - binary_acc: 0.7892 - precision: 0.8064 - recall: 0.7593 - f1_score: 0.7821 - roc_auc: 0.8689 - pr_auc: 0.8784 - cohen_kappa: 0.5783 - val_loss: 0.5178 - val_tp: 619.0000 - val_fp: 200.0000 - val_tn: 648.0000 - val_fn: 209.0000 - val_binary_acc: 0.7560 - val_precision: 0.7558 - val_recall: 0.7476 - val_f1_score: 0.7517 - val_roc_auc: 0.8226 - val_pr_auc: 0.8355 - val_cohen_kappa: 0.5118
# Epoch 40/100
# 419/419 [==============================] - 71s 168ms/step - loss: 0.4543 - tp: 2484.0000 - fp: 586.0000 - tn: 2777.0000 - fn: 856.0000 - binary_acc: 0.7849 - precision: 0.8091 - recall: 0.7437 - f1_score: 0.7750 - roc_auc: 0.8649 - pr_auc: 0.8756 - cohen_kappa: 0.5696 - val_loss: 0.5175 - val_tp: 540.0000 - val_fp: 116.0000 - val_tn: 732.0000 - val_fn: 288.0000 - val_binary_acc: 0.7589 - val_precision: 0.8232 - val_recall: 0.6522 - val_f1_score: 0.7278 - val_roc_auc: 0.8311 - val_pr_auc: 0.8424 - val_cohen_kappa: 0.5166
# Epoch 41/100
# 419/419 [==============================] - 70s 166ms/step - loss: 0.4365 - tp: 2553.0000 - fp: 598.0000 - tn: 2765.0000 - fn: 787.0000 - binary_acc: 0.7934 - precision: 0.8102 - recall: 0.7644 - f1_score: 0.7866 - roc_auc: 0.8758 - pr_auc: 0.8855 - cohen_kappa: 0.5867 - val_loss: 0.5307 - val_tp: 541.0000 - val_fp: 157.0000 - val_tn: 691.0000 - val_fn: 287.0000 - val_binary_acc: 0.7351 - val_precision: 0.7751 - val_recall: 0.6534 - val_f1_score: 0.7090 - val_roc_auc: 0.8192 - val_pr_auc: 0.8207 - val_cohen_kappa: 0.4691
# Epoch 42/100
# 419/419 [==============================] - 70s 167ms/step - loss: 0.4410 - tp: 2532.0000 - fp: 597.0000 - tn: 2766.0000 - fn: 808.0000 - binary_acc: 0.7904 - precision: 0.8092 - recall: 0.7581 - f1_score: 0.7828 - roc_auc: 0.8738 - pr_auc: 0.8842 - cohen_kappa: 0.5807 - val_loss: 0.5103 - val_tp: 544.0000 - val_fp: 114.0000 - val_tn: 734.0000 - val_fn: 284.0000 - val_binary_acc: 0.7625 - val_precision: 0.8267 - val_recall: 0.6570 - val_f1_score: 0.7322 - val_roc_auc: 0.8343 - val_pr_auc: 0.8385 - val_cohen_kappa: 0.5238
# Epoch 43/100
# 419/419 [==============================] - 67s 161ms/step - loss: 0.4416 - tp: 2518.0000 - fp: 588.0000 - tn: 2775.0000 - fn: 822.0000 - binary_acc: 0.7896 - precision: 0.8107 - recall: 0.7539 - f1_score: 0.7813 - roc_auc: 0.8731 - pr_auc: 0.8825 - cohen_kappa: 0.5792 - val_loss: 0.5284 - val_tp: 606.0000 - val_fp: 178.0000 - val_tn: 670.0000 - val_fn: 222.0000 - val_binary_acc: 0.7613 - val_precision: 0.7730 - val_recall: 0.7319 - val_f1_score: 0.7519 - val_roc_auc: 0.8227 - val_pr_auc: 0.8245 - val_cohen_kappa: 0.5223
# Epoch 44/100
# 419/419 [==============================] - 68s 163ms/step - loss: 0.4372 - tp: 2553.0000 - fp: 572.0000 - tn: 2791.0000 - fn: 787.0000 - binary_acc: 0.7973 - precision: 0.8170 - recall: 0.7644 - f1_score: 0.7898 - roc_auc: 0.8771 - pr_auc: 0.8838 - cohen_kappa: 0.5944 - val_loss: 0.5294 - val_tp: 602.0000 - val_fp: 195.0000 - val_tn: 653.0000 - val_fn: 226.0000 - val_binary_acc: 0.7488 - val_precision: 0.7553 - val_recall: 0.7271 - val_f1_score: 0.7409 - val_roc_auc: 0.8280 - val_pr_auc: 0.8268 - val_cohen_kappa: 0.4973
# Epoch 45/100
# 419/419 [==============================] - 72s 171ms/step - loss: 0.4329 - tp: 2547.0000 - fp: 583.0000 - tn: 2780.0000 - fn: 793.0000 - binary_acc: 0.7947 - precision: 0.8137 - recall: 0.7626 - f1_score: 0.7873 - roc_auc: 0.8778 - pr_auc: 0.8886 - cohen_kappa: 0.5893 - val_loss: 0.5385 - val_tp: 563.0000 - val_fp: 157.0000 - val_tn: 691.0000 - val_fn: 265.0000 - val_binary_acc: 0.7482 - val_precision: 0.7819 - val_recall: 0.6800 - val_f1_score: 0.7274 - val_roc_auc: 0.8152 - val_pr_auc: 0.8135 - val_cohen_kappa: 0.4956
# Epoch 46/100
# 419/419 [==============================] - 70s 167ms/step - loss: 0.4289 - tp: 2571.0000 - fp: 578.0000 - tn: 2785.0000 - fn: 769.0000 - binary_acc: 0.7990 - precision: 0.8164 - recall: 0.7698 - f1_score: 0.7924 - roc_auc: 0.8818 - pr_auc: 0.8908 - cohen_kappa: 0.5980 - val_loss: 0.5949 - val_tp: 510.0000 - val_fp: 94.0000 - val_tn: 754.0000 - val_fn: 318.0000 - val_binary_acc: 0.7542 - val_precision: 0.8444 - val_recall: 0.6159 - val_f1_score: 0.7123 - val_roc_auc: 0.8118 - val_pr_auc: 0.8267 - val_cohen_kappa: 0.5067
# Epoch 47/100
# 419/419 [==============================] - 69s 164ms/step - loss: 0.4276 - tp: 2570.0000 - fp: 572.0000 - tn: 2791.0000 - fn: 770.0000 - binary_acc: 0.7998 - precision: 0.8180 - recall: 0.7695 - f1_score: 0.7930 - roc_auc: 0.8813 - pr_auc: 0.8913 - cohen_kappa: 0.5995 - val_loss: 0.5190 - val_tp: 532.0000 - val_fp: 117.0000 - val_tn: 731.0000 - val_fn: 296.0000 - val_binary_acc: 0.7536 - val_precision: 0.8197 - val_recall: 0.6425 - val_f1_score: 0.7204 - val_roc_auc: 0.8310 - val_pr_auc: 0.8387 - val_cohen_kappa: 0.5058
# Epoch 48/100
# 419/419 [==============================] - 68s 163ms/step - loss: 0.4275 - tp: 2545.0000 - fp: 552.0000 - tn: 2811.0000 - fn: 795.0000 - binary_acc: 0.7990 - precision: 0.8218 - recall: 0.7620 - f1_score: 0.7907 - roc_auc: 0.8811 - pr_auc: 0.8906 - cohen_kappa: 0.5980 - val_loss: 0.5158 - val_tp: 566.0000 - val_fp: 144.0000 - val_tn: 704.0000 - val_fn: 262.0000 - val_binary_acc: 0.7578 - val_precision: 0.7972 - val_recall: 0.6836 - val_f1_score: 0.7360 - val_roc_auc: 0.8252 - val_pr_auc: 0.8310 - val_cohen_kappa: 0.5146
# Epoch 49/100
# 419/419 [==============================] - 68s 162ms/step - loss: 0.4214 - tp: 2592.0000 - fp: 533.0000 - tn: 2830.0000 - fn: 748.0000 - binary_acc: 0.8089 - precision: 0.8294 - recall: 0.7760 - f1_score: 0.8019 - roc_auc: 0.8853 - pr_auc: 0.8948 - cohen_kappa: 0.6177 - val_loss: 0.5357 - val_tp: 515.0000 - val_fp: 124.0000 - val_tn: 724.0000 - val_fn: 313.0000 - val_binary_acc: 0.7393 - val_precision: 0.8059 - val_recall: 0.6220 - val_f1_score: 0.7021 - val_roc_auc: 0.8173 - val_pr_auc: 0.8253 - val_cohen_kappa: 0.4770
# Epoch 50/100
# 419/419 [==============================] - 68s 161ms/step - loss: 0.4174 - tp: 2567.0000 - fp: 534.0000 - tn: 2829.0000 - fn: 773.0000 - binary_acc: 0.8050 - precision: 0.8278 - recall: 0.7686 - f1_score: 0.7971 - roc_auc: 0.8861 - pr_auc: 0.8982 - cohen_kappa: 0.6099 - val_loss: 0.5346 - val_tp: 589.0000 - val_fp: 173.0000 - val_tn: 675.0000 - val_fn: 239.0000 - val_binary_acc: 0.7542 - val_precision: 0.7730 - val_recall: 0.7114 - val_f1_score: 0.7409 - val_roc_auc: 0.8224 - val_pr_auc: 0.8291 - val_cohen_kappa: 0.5078
# Epoch 51/100
# 419/419 [==============================] - 67s 161ms/step - loss: 0.4258 - tp: 2586.0000 - fp: 550.0000 - tn: 2813.0000 - fn: 754.0000 - binary_acc: 0.8055 - precision: 0.8246 - recall: 0.7743 - f1_score: 0.7986 - roc_auc: 0.8839 - pr_auc: 0.8919 - cohen_kappa: 0.6108 - val_loss: 0.5531 - val_tp: 547.0000 - val_fp: 161.0000 - val_tn: 687.0000 - val_fn: 281.0000 - val_binary_acc: 0.7363 - val_precision: 0.7726 - val_recall: 0.6606 - val_f1_score: 0.7122 - val_roc_auc: 0.8068 - val_pr_auc: 0.8091 - val_cohen_kappa: 0.4716
# Epoch 52/100
# 419/419 [==============================] - 69s 164ms/step - loss: 0.4152 - tp: 2591.0000 - fp: 513.0000 - tn: 2850.0000 - fn: 749.0000 - binary_acc: 0.8117 - precision: 0.8347 - recall: 0.7757 - f1_score: 0.8042 - roc_auc: 0.8886 - pr_auc: 0.8986 - cohen_kappa: 0.6234 - val_loss: 0.5456 - val_tp: 654.0000 - val_fp: 261.0000 - val_tn: 587.0000 - val_fn: 174.0000 - val_binary_acc: 0.7405 - val_precision: 0.7148 - val_recall: 0.7899 - val_f1_score: 0.7504 - val_roc_auc: 0.8217 - val_pr_auc: 0.8208 - val_cohen_kappa: 0.4815
# Epoch 53/100
# 419/419 [==============================] - 67s 160ms/step - loss: 0.4145 - tp: 2560.0000 - fp: 533.0000 - tn: 2830.0000 - fn: 780.0000 - binary_acc: 0.8041 - precision: 0.8277 - recall: 0.7665 - f1_score: 0.7959 - roc_auc: 0.8883 - pr_auc: 0.8991 - cohen_kappa: 0.6081 - val_loss: 0.5507 - val_tp: 662.0000 - val_fp: 279.0000 - val_tn: 569.0000 - val_fn: 166.0000 - val_binary_acc: 0.7345 - val_precision: 0.7035 - val_recall: 0.7995 - val_f1_score: 0.7484 - val_roc_auc: 0.8243 - val_pr_auc: 0.8349 - val_cohen_kappa: 0.4698
# Epoch 54/100
# 419/419 [==============================] - 68s 163ms/step - loss: 0.4163 - tp: 2573.0000 - fp: 541.0000 - tn: 2822.0000 - fn: 767.0000 - binary_acc: 0.8049 - precision: 0.8263 - recall: 0.7704 - f1_score: 0.7973 - roc_auc: 0.8881 - pr_auc: 0.8988 - cohen_kappa: 0.6096 - val_loss: 0.5549 - val_tp: 550.0000 - val_fp: 146.0000 - val_tn: 702.0000 - val_fn: 278.0000 - val_binary_acc: 0.7470 - val_precision: 0.7902 - val_recall: 0.6643 - val_f1_score: 0.7218 - val_roc_auc: 0.8109 - val_pr_auc: 0.8182 - val_cohen_kappa: 0.4930
# Epoch 55/100
# 419/419 [==============================] - 72s 172ms/step - loss: 0.4110 - tp: 2608.0000 - fp: 541.0000 - tn: 2822.0000 - fn: 732.0000 - binary_acc: 0.8101 - precision: 0.8282 - recall: 0.7808 - f1_score: 0.8038 - roc_auc: 0.8916 - pr_auc: 0.8994 - cohen_kappa: 0.6201 - val_loss: 0.5638 - val_tp: 523.0000 - val_fp: 109.0000 - val_tn: 739.0000 - val_fn: 305.0000 - val_binary_acc: 0.7530 - val_precision: 0.8275 - val_recall: 0.6316 - val_f1_score: 0.7164 - val_roc_auc: 0.8198 - val_pr_auc: 0.8162 - val_cohen_kappa: 0.5045
# Epoch 56/100
# 419/419 [==============================] - 73s 173ms/step - loss: 0.4165 - tp: 2599.0000 - fp: 549.0000 - tn: 2814.0000 - fn: 741.0000 - binary_acc: 0.8075 - precision: 0.8256 - recall: 0.7781 - f1_score: 0.8012 - roc_auc: 0.8889 - pr_auc: 0.8976 - cohen_kappa: 0.6150 - val_loss: 0.5120 - val_tp: 564.0000 - val_fp: 141.0000 - val_tn: 707.0000 - val_fn: 264.0000 - val_binary_acc: 0.7584 - val_precision: 0.8000 - val_recall: 0.6812 - val_f1_score: 0.7358 - val_roc_auc: 0.8290 - val_pr_auc: 0.8388 - val_cohen_kappa: 0.5158
# Epoch 57/100
# 419/419 [==============================] - ETA: 0s - loss: 0.4072 - tp: 2604.0000 - fp: 517.0000 - tn: 2846.0000 - fn: 736.0000 - binary_acc: 0.8131 - precision: 0.8343 - recall: 0.7796 - f1_score: 0.8061 - roc_auc: 0.8928 - pr_auc: 0.9026 - cohen_kappa: 0.6260Restoring model weights from the end of the best epoch: 42.
# 419/419 [==============================] - 73s 175ms/step - loss: 0.4072 - tp: 2604.0000 - fp: 517.0000 - tn: 2846.0000 - fn: 736.0000 - binary_acc: 0.8131 - precision: 0.8343 - recall: 0.7796 - f1_score: 0.8061 - roc_auc: 0.8928 - pr_auc: 0.9026 - cohen_kappa: 0.6260 - val_loss: 0.5312 - val_tp: 627.0000 - val_fp: 223.0000 - val_tn: 625.0000 - val_fn: 201.0000 - val_binary_acc: 0.7470 - val_precision: 0.7376 - val_recall: 0.7572 - val_f1_score: 0.7473 - val_roc_auc: 0.8238 - val_pr_auc: 0.8335 - val_cohen_kappa: 0.4941
# Epoch 57: early stopping

# %%
new_model.save(save_path + model_name + '.keras')

plot_metrics(history)

# %%
new_model.evaluate(validation_generator)
new_model.evaluate(test_generator)

    # Make predictions using the validation generator
y_valid_pred_prob = new_model.predict(validation_generator)
y_valid_pred = (y_valid_pred_prob > 0.5).astype(int)
y_valid = validation_generator.classes
print("Classification Report:")
print(classification_report(y_valid, y_valid_pred))

y_pred_prob = new_model.predict(test_generator)
y_pred = (y_pred_prob > 0.5).astype(int)
y_test = test_generator.classes
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# 105/105 [==============================] - 14s 137ms/step - loss: 0.5167 - tp: 531.0000 - fp: 111.0000 - tn: 737.0000 - fn: 297.0000 - binary_acc: 0.7566 - precision: 0.8271 - recall: 0.6413 - f1_score: 0.7224 - roc_auc: 0.8284 - pr_auc: 0.8411 - cohen_kappa: 0.5118
# 36/36 [==============================] - 2s 53ms/step - loss: 0.6483 - tp: 217.0000 - fp: 99.0000 - tn: 186.0000 - fn: 61.0000 - binary_acc: 0.7158 - precision: 0.6867 - recall: 0.7806 - f1_score: 0.7306 - roc_auc: 0.7807 - pr_auc: 0.7818 - cohen_kappa: 0.4325
# 105/105 [==============================] - 15s 136ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.72      0.86      0.78       848
#            1       0.82      0.65      0.73       828
#
#     accuracy                           0.76      1676
#    macro avg       0.77      0.76      0.75      1676
# weighted avg       0.77      0.76      0.75      1676
#
# 36/36 [==============================] - 2s 45ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.75      0.65      0.70       285
#            1       0.69      0.78      0.73       278
#
#     accuracy                           0.72       563
#    macro avg       0.72      0.72      0.71       563
# weighted avg       0.72      0.72      0.71       563

# %%
conf_matrix = confusion_matrix(y_test, y_pred)

# Create ConfusionMatrixDisplay object
cm_display = ConfusionMatrixDisplay(confusion_matrix=conf_matrix)

# Plot the confusion matrix
plt.figure(figsize=(4, 6))  # Adjust the figure size as needed
cm_display.plot(cmap=plt.cm.Blues)  # You can choose any colormap you prefer
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.grid(False)  # Turn off grid
plt.savefig(save_path + model_name + "_confusion_matrix.jpg")
plt.show()

# %%
history_df = pd.DataFrame(history.history)
save_history(model_name, history_df)

new_model.save(save_path + model_name + "_pt_imagenet-{new_model.count_params()}.h5")
resnet.save(save_path + model_name + ".h5")

resnet.trainable = True

new_model.compile(
        optimizer=tf.keras.optimizers.Adam(
            1e-5
        ),  # we need small learning rate to avoid catastrophic forgetting
        loss=tf.keras.losses.BinaryCrossentropy(),
        metrics=METRICS,
    )

model_name = 'finetuned_' + architecture + "_" + target_category

model_path = save_path + '_best_' + model_name + '.keras'
model_checkpoint = ModelCheckpoint(filepath=model_path,
                                       monitor="val_cohen_kappa",
                                       save_best_only=True)

reduce_lr_on_plateau = tf.keras.callbacks.ReduceLROnPlateau(
        monitor="val_cohen_kappa",
        verbose=1,
        patience=4,
        mode="max",
        factor=0.2,
        min_lr=1e-10,
    )
# Out:
# Training history saved to: C:/Users/raouf/Desktop/pfe/history/final/resnet/XR_SHOULDER/ResNet_XR_SHOULDER_history.xlsx
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
history = new_model.fit(train_generator,
                            # steps_per_epoch=len(df_train) // batch_size,
                            validation_data=validation_generator,
                            # validation_steps=len(df_valid) // batch_size,
                            epochs=fine_tuning_epochs,
                            shuffle=shuffle,
                            callbacks=[early_stopping, model_checkpoint, reduce_lr_on_plateau])
# Out:
# Epoch 1/50
# 419/419 [==============================] - 93s 209ms/step - loss: 0.4647 - tp: 2717.0000 - fp: 730.0000 - tn: 2918.0000 - fn: 901.0000 - binary_acc: 0.7755 - precision: 0.7882 - recall: 0.7510 - f1_score: 0.7691 - roc_auc: 0.8522 - pr_auc: 0.8580 - cohen_kappa: 0.5510 - val_loss: 0.5001 - val_tp: 605.0000 - val_fp: 168.0000 - val_tn: 680.0000 - val_fn: 223.0000 - val_binary_acc: 0.7667 - val_precision: 0.7827 - val_recall: 0.7307 - val_f1_score: 0.7558 - val_roc_auc: 0.8349 - val_pr_auc: 0.8473 - val_cohen_kappa: 0.5330 - lr: 1.0000e-05
# Epoch 2/50
# 419/419 [==============================] - 83s 197ms/step - loss: 0.4396 - tp: 2508.0000 - fp: 552.0000 - tn: 2811.0000 - fn: 832.0000 - binary_acc: 0.7935 - precision: 0.8196 - recall: 0.7509 - f1_score: 0.7837 - roc_auc: 0.8737 - pr_auc: 0.8876 - cohen_kappa: 0.5869 - val_loss: 0.5040 - val_tp: 633.0000 - val_fp: 192.0000 - val_tn: 656.0000 - val_fn: 195.0000 - val_binary_acc: 0.7691 - val_precision: 0.7673 - val_recall: 0.7645 - val_f1_score: 0.7659 - val_roc_auc: 0.8415 - val_pr_auc: 0.8423 - val_cohen_kappa: 0.5381 - lr: 1.0000e-05
# Epoch 3/50
# 419/419 [==============================] - 84s 201ms/step - loss: 0.4178 - tp: 2597.0000 - fp: 515.0000 - tn: 2848.0000 - fn: 743.0000 - binary_acc: 0.8123 - precision: 0.8345 - recall: 0.7775 - f1_score: 0.8050 - roc_auc: 0.8877 - pr_auc: 0.8980 - cohen_kappa: 0.6246 - val_loss: 0.5384 - val_tp: 493.0000 - val_fp: 84.0000 - val_tn: 764.0000 - val_fn: 335.0000 - val_binary_acc: 0.7500 - val_precision: 0.8544 - val_recall: 0.5954 - val_f1_score: 0.7018 - val_roc_auc: 0.8330 - val_pr_auc: 0.8435 - val_cohen_kappa: 0.4981 - lr: 1.0000e-05
# Epoch 4/50
# 419/419 [==============================] - 85s 204ms/step - loss: 0.4022 - tp: 2597.0000 - fp: 489.0000 - tn: 2874.0000 - fn: 743.0000 - binary_acc: 0.8162 - precision: 0.8415 - recall: 0.7775 - f1_score: 0.8083 - roc_auc: 0.8965 - pr_auc: 0.9059 - cohen_kappa: 0.6323 - val_loss: 0.5049 - val_tp: 558.0000 - val_fp: 135.0000 - val_tn: 713.0000 - val_fn: 270.0000 - val_binary_acc: 0.7584 - val_precision: 0.8052 - val_recall: 0.6739 - val_f1_score: 0.7337 - val_roc_auc: 0.8400 - val_pr_auc: 0.8400 - val_cohen_kappa: 0.5157 - lr: 1.0000e-05
# Epoch 5/50
# 419/419 [==============================] - 121s 288ms/step - loss: 0.4031 - tp: 2586.0000 - fp: 513.0000 - tn: 2850.0000 - fn: 754.0000 - binary_acc: 0.8110 - precision: 0.8345 - recall: 0.7743 - f1_score: 0.8032 - roc_auc: 0.8959 - pr_auc: 0.9041 - cohen_kappa: 0.6219 - val_loss: 0.5189 - val_tp: 601.0000 - val_fp: 160.0000 - val_tn: 688.0000 - val_fn: 227.0000 - val_binary_acc: 0.7691 - val_precision: 0.7898 - val_recall: 0.7258 - val_f1_score: 0.7565 - val_roc_auc: 0.8324 - val_pr_auc: 0.8361 - val_cohen_kappa: 0.5377 - lr: 1.0000e-05
# Epoch 6/50
# 419/419 [==============================] - 85s 203ms/step - loss: 0.3878 - tp: 2666.0000 - fp: 464.0000 - tn: 2899.0000 - fn: 674.0000 - binary_acc: 0.8302 - precision: 0.8518 - recall: 0.7982 - f1_score: 0.8241 - roc_auc: 0.9050 - pr_auc: 0.9109 - cohen_kappa: 0.6604 - val_loss: 0.5137 - val_tp: 634.0000 - val_fp: 189.0000 - val_tn: 659.0000 - val_fn: 194.0000 - val_binary_acc: 0.7715 - val_precision: 0.7704 - val_recall: 0.7657 - val_f1_score: 0.7680 - val_roc_auc: 0.8400 - val_pr_auc: 0.8482 - val_cohen_kappa: 0.5429 - lr: 1.0000e-05
# Epoch 7/50
# 419/419 [==============================] - 84s 200ms/step - loss: 0.3610 - tp: 2709.0000 - fp: 450.0000 - tn: 2913.0000 - fn: 631.0000 - binary_acc: 0.8387 - precision: 0.8575 - recall: 0.8111 - f1_score: 0.8337 - roc_auc: 0.9171 - pr_auc: 0.9264 - cohen_kappa: 0.6774 - val_loss: 0.4816 - val_tp: 583.0000 - val_fp: 121.0000 - val_tn: 727.0000 - val_fn: 245.0000 - val_binary_acc: 0.7816 - val_precision: 0.8281 - val_recall: 0.7041 - val_f1_score: 0.7611 - val_roc_auc: 0.8537 - val_pr_auc: 0.8621 - val_cohen_kappa: 0.5624 - lr: 1.0000e-05
# Epoch 8/50
# 419/419 [==============================] - 82s 195ms/step - loss: 0.3495 - tp: 2731.0000 - fp: 423.0000 - tn: 2940.0000 - fn: 609.0000 - binary_acc: 0.8460 - precision: 0.8659 - recall: 0.8177 - f1_score: 0.8411 - roc_auc: 0.9226 - pr_auc: 0.9301 - cohen_kappa: 0.6920 - val_loss: 0.5117 - val_tp: 634.0000 - val_fp: 197.0000 - val_tn: 651.0000 - val_fn: 194.0000 - val_binary_acc: 0.7667 - val_precision: 0.7629 - val_recall: 0.7657 - val_f1_score: 0.7643 - val_roc_auc: 0.8410 - val_pr_auc: 0.8525 - val_cohen_kappa: 0.5334 - lr: 1.0000e-05
# Epoch 9/50
# 419/419 [==============================] - 82s 197ms/step - loss: 0.3374 - tp: 2744.0000 - fp: 419.0000 - tn: 2944.0000 - fn: 596.0000 - binary_acc: 0.8486 - precision: 0.8675 - recall: 0.8216 - f1_score: 0.8439 - roc_auc: 0.9287 - pr_auc: 0.9349 - cohen_kappa: 0.6971 - val_loss: 0.5166 - val_tp: 628.0000 - val_fp: 173.0000 - val_tn: 675.0000 - val_fn: 200.0000 - val_binary_acc: 0.7774 - val_precision: 0.7840 - val_recall: 0.7585 - val_f1_score: 0.7710 - val_roc_auc: 0.8405 - val_pr_auc: 0.8514 - val_cohen_kappa: 0.5547 - lr: 1.0000e-05
# Epoch 10/50
# 419/419 [==============================] - 87s 207ms/step - loss: 0.3161 - tp: 2795.0000 - fp: 369.0000 - tn: 2994.0000 - fn: 545.0000 - binary_acc: 0.8636 - precision: 0.8834 - recall: 0.8368 - f1_score: 0.8595 - roc_auc: 0.9366 - pr_auc: 0.9442 - cohen_kappa: 0.7272 - val_loss: 0.5234 - val_tp: 625.0000 - val_fp: 176.0000 - val_tn: 672.0000 - val_fn: 203.0000 - val_binary_acc: 0.7739 - val_precision: 0.7803 - val_recall: 0.7548 - val_f1_score: 0.7673 - val_roc_auc: 0.8448 - val_pr_auc: 0.8528 - val_cohen_kappa: 0.5475 - lr: 1.0000e-05
# Epoch 11/50
# 419/419 [==============================] - ETA: 0s - loss: 0.3060 - tp: 2803.0000 - fp: 370.0000 - tn: 2993.0000 - fn: 537.0000 - binary_acc: 0.8647 - precision: 0.8834 - recall: 0.8392 - f1_score: 0.8607 - roc_auc: 0.9411 - pr_auc: 0.9480 - cohen_kappa: 0.7293
# Epoch 11: ReduceLROnPlateau reducing learning rate to 1.9999999494757505e-06.
# 419/419 [==============================] - 81s 192ms/step - loss: 0.3060 - tp: 2803.0000 - fp: 370.0000 - tn: 2993.0000 - fn: 537.0000 - binary_acc: 0.8647 - precision: 0.8834 - recall: 0.8392 - f1_score: 0.8607 - roc_auc: 0.9411 - pr_auc: 0.9480 - cohen_kappa: 0.7293 - val_loss: 0.5532 - val_tp: 605.0000 - val_fp: 145.0000 - val_tn: 703.0000 - val_fn: 223.0000 - val_binary_acc: 0.7804 - val_precision: 0.8067 - val_recall: 0.7307 - val_f1_score: 0.7668 - val_roc_auc: 0.8417 - val_pr_auc: 0.8443 - val_cohen_kappa: 0.5603 - lr: 1.0000e-05
# Epoch 12/50
# 419/419 [==============================] - 82s 196ms/step - loss: 0.2542 - tp: 2918.0000 - fp: 279.0000 - tn: 3084.0000 - fn: 422.0000 - binary_acc: 0.8954 - precision: 0.9127 - recall: 0.8737 - f1_score: 0.8928 - roc_auc: 0.9605 - pr_auc: 0.9647 - cohen_kappa: 0.7908 - val_loss: 0.5498 - val_tp: 633.0000 - val_fp: 169.0000 - val_tn: 679.0000 - val_fn: 195.0000 - val_binary_acc: 0.7828 - val_precision: 0.7893 - val_recall: 0.7645 - val_f1_score: 0.7767 - val_roc_auc: 0.8512 - val_pr_auc: 0.8498 - val_cohen_kappa: 0.5654 - lr: 2.0000e-06
# Epoch 13/50
# 419/419 [==============================] - 84s 201ms/step - loss: 0.2412 - tp: 2953.0000 - fp: 270.0000 - tn: 3093.0000 - fn: 387.0000 - binary_acc: 0.9020 - precision: 0.9162 - recall: 0.8841 - f1_score: 0.8999 - roc_auc: 0.9645 - pr_auc: 0.9679 - cohen_kappa: 0.8039 - val_loss: 0.5737 - val_tp: 654.0000 - val_fp: 209.0000 - val_tn: 639.0000 - val_fn: 174.0000 - val_binary_acc: 0.7715 - val_precision: 0.7578 - val_recall: 0.7899 - val_f1_score: 0.7735 - val_roc_auc: 0.8457 - val_pr_auc: 0.8522 - val_cohen_kappa: 0.5431 - lr: 2.0000e-06
# Epoch 14/50
# 419/419 [==============================] - 85s 202ms/step - loss: 0.2294 - tp: 2958.0000 - fp: 249.0000 - tn: 3114.0000 - fn: 382.0000 - binary_acc: 0.9059 - precision: 0.9224 - recall: 0.8856 - f1_score: 0.9036 - roc_auc: 0.9673 - pr_auc: 0.9712 - cohen_kappa: 0.8117 - val_loss: 0.5523 - val_tp: 629.0000 - val_fp: 169.0000 - val_tn: 679.0000 - val_fn: 199.0000 - val_binary_acc: 0.7804 - val_precision: 0.7882 - val_recall: 0.7597 - val_f1_score: 0.7737 - val_roc_auc: 0.8519 - val_pr_auc: 0.8542 - val_cohen_kappa: 0.5606 - lr: 2.0000e-06
# Epoch 15/50
# 419/419 [==============================] - 81s 194ms/step - loss: 0.2193 - tp: 2973.0000 - fp: 240.0000 - tn: 3123.0000 - fn: 367.0000 - binary_acc: 0.9094 - precision: 0.9253 - recall: 0.8901 - f1_score: 0.9074 - roc_auc: 0.9708 - pr_auc: 0.9735 - cohen_kappa: 0.8189 - val_loss: 0.5561 - val_tp: 611.0000 - val_fp: 132.0000 - val_tn: 716.0000 - val_fn: 217.0000 - val_binary_acc: 0.7918 - val_precision: 0.8223 - val_recall: 0.7379 - val_f1_score: 0.7778 - val_roc_auc: 0.8569 - val_pr_auc: 0.8542 - val_cohen_kappa: 0.5830 - lr: 2.0000e-06
# Epoch 16/50
# 419/419 [==============================] - 81s 192ms/step - loss: 0.2184 - tp: 2982.0000 - fp: 248.0000 - tn: 3115.0000 - fn: 358.0000 - binary_acc: 0.9096 - precision: 0.9232 - recall: 0.8928 - f1_score: 0.9078 - roc_auc: 0.9708 - pr_auc: 0.9735 - cohen_kappa: 0.8192 - val_loss: 0.5792 - val_tp: 618.0000 - val_fp: 154.0000 - val_tn: 694.0000 - val_fn: 210.0000 - val_binary_acc: 0.7828 - val_precision: 0.8005 - val_recall: 0.7464 - val_f1_score: 0.7725 - val_roc_auc: 0.8485 - val_pr_auc: 0.8518 - val_cohen_kappa: 0.5652 - lr: 2.0000e-06
# Epoch 17/50
# 419/419 [==============================] - 81s 193ms/step - loss: 0.2124 - tp: 2985.0000 - fp: 243.0000 - tn: 3120.0000 - fn: 355.0000 - binary_acc: 0.9108 - precision: 0.9247 - recall: 0.8937 - f1_score: 0.9090 - roc_auc: 0.9723 - pr_auc: 0.9748 - cohen_kappa: 0.8215 - val_loss: 0.5713 - val_tp: 623.0000 - val_fp: 144.0000 - val_tn: 704.0000 - val_fn: 205.0000 - val_binary_acc: 0.7918 - val_precision: 0.8123 - val_recall: 0.7524 - val_f1_score: 0.7812 - val_roc_auc: 0.8539 - val_pr_auc: 0.8482 - val_cohen_kappa: 0.5831 - lr: 2.0000e-06
# Epoch 18/50
# 419/419 [==============================] - 80s 191ms/step - loss: 0.2042 - tp: 3013.0000 - fp: 214.0000 - tn: 3149.0000 - fn: 327.0000 - binary_acc: 0.9193 - precision: 0.9337 - recall: 0.9021 - f1_score: 0.9176 - roc_auc: 0.9745 - pr_auc: 0.9769 - cohen_kappa: 0.8386 - val_loss: 0.5833 - val_tp: 636.0000 - val_fp: 172.0000 - val_tn: 676.0000 - val_fn: 192.0000 - val_binary_acc: 0.7828 - val_precision: 0.7871 - val_recall: 0.7681 - val_f1_score: 0.7775 - val_roc_auc: 0.8498 - val_pr_auc: 0.8533 - val_cohen_kappa: 0.5654 - lr: 2.0000e-06
# Epoch 19/50
# 419/419 [==============================] - 80s 192ms/step - loss: 0.1946 - tp: 3039.0000 - fp: 232.0000 - tn: 3131.0000 - fn: 301.0000 - binary_acc: 0.9205 - precision: 0.9291 - recall: 0.9099 - f1_score: 0.9194 - roc_auc: 0.9767 - pr_auc: 0.9788 - cohen_kappa: 0.8410 - val_loss: 0.5976 - val_tp: 623.0000 - val_fp: 155.0000 - val_tn: 693.0000 - val_fn: 205.0000 - val_binary_acc: 0.7852 - val_precision: 0.8008 - val_recall: 0.7524 - val_f1_score: 0.7758 - val_roc_auc: 0.8493 - val_pr_auc: 0.8521 - val_cohen_kappa: 0.5700 - lr: 2.0000e-06
# Epoch 20/50
# 419/419 [==============================] - 80s 191ms/step - loss: 0.1860 - tp: 3050.0000 - fp: 215.0000 - tn: 3148.0000 - fn: 290.0000 - binary_acc: 0.9247 - precision: 0.9342 - recall: 0.9132 - f1_score: 0.9235 - roc_auc: 0.9789 - pr_auc: 0.9811 - cohen_kappa: 0.8493 - val_loss: 0.6389 - val_tp: 623.0000 - val_fp: 175.0000 - val_tn: 673.0000 - val_fn: 205.0000 - val_binary_acc: 0.7733 - val_precision: 0.7807 - val_recall: 0.7524 - val_f1_score: 0.7663 - val_roc_auc: 0.8434 - val_pr_auc: 0.8400 - val_cohen_kappa: 0.5463 - lr: 2.0000e-06
# Epoch 21/50
# 419/419 [==============================] - ETA: 0s - loss: 0.1879 - tp: 3041.0000 - fp: 216.0000 - tn: 3147.0000 - fn: 299.0000 - binary_acc: 0.9232 - precision: 0.9337 - recall: 0.9105 - f1_score: 0.9219 - roc_auc: 0.9783 - pr_auc: 0.9805 - cohen_kappa: 0.8463
# Epoch 21: ReduceLROnPlateau reducing learning rate to 3.999999989900971e-07.
# 419/419 [==============================] - 81s 192ms/step - loss: 0.1879 - tp: 3041.0000 - fp: 216.0000 - tn: 3147.0000 - fn: 299.0000 - binary_acc: 0.9232 - precision: 0.9337 - recall: 0.9105 - f1_score: 0.9219 - roc_auc: 0.9783 - pr_auc: 0.9805 - cohen_kappa: 0.8463 - val_loss: 0.6448 - val_tp: 626.0000 - val_fp: 174.0000 - val_tn: 674.0000 - val_fn: 202.0000 - val_binary_acc: 0.7757 - val_precision: 0.7825 - val_recall: 0.7560 - val_f1_score: 0.7690 - val_roc_auc: 0.8387 - val_pr_auc: 0.8432 - val_cohen_kappa: 0.5511 - lr: 2.0000e-06
# Epoch 22/50
# 419/419 [==============================] - 83s 199ms/step - loss: 0.1719 - tp: 3073.0000 - fp: 175.0000 - tn: 3188.0000 - fn: 267.0000 - binary_acc: 0.9341 - precision: 0.9461 - recall: 0.9201 - f1_score: 0.9329 - roc_auc: 0.9815 - pr_auc: 0.9839 - cohen_kappa: 0.8681 - val_loss: 0.6326 - val_tp: 626.0000 - val_fp: 170.0000 - val_tn: 678.0000 - val_fn: 202.0000 - val_binary_acc: 0.7780 - val_precision: 0.7864 - val_recall: 0.7560 - val_f1_score: 0.7709 - val_roc_auc: 0.8476 - val_pr_auc: 0.8498 - val_cohen_kappa: 0.5558 - lr: 4.0000e-07
# Epoch 23/50
# 419/419 [==============================] - 82s 195ms/step - loss: 0.1697 - tp: 3060.0000 - fp: 189.0000 - tn: 3174.0000 - fn: 280.0000 - binary_acc: 0.9300 - precision: 0.9418 - recall: 0.9162 - f1_score: 0.9288 - roc_auc: 0.9828 - pr_auc: 0.9843 - cohen_kappa: 0.8600 - val_loss: 0.6451 - val_tp: 627.0000 - val_fp: 161.0000 - val_tn: 687.0000 - val_fn: 201.0000 - val_binary_acc: 0.7840 - val_precision: 0.7957 - val_recall: 0.7572 - val_f1_score: 0.7760 - val_roc_auc: 0.8474 - val_pr_auc: 0.8507 - val_cohen_kappa: 0.5677 - lr: 4.0000e-07
# Epoch 24/50
# 419/419 [==============================] - 82s 196ms/step - loss: 0.1630 - tp: 3066.0000 - fp: 168.0000 - tn: 3195.0000 - fn: 274.0000 - binary_acc: 0.9341 - precision: 0.9481 - recall: 0.9180 - f1_score: 0.9328 - roc_auc: 0.9841 - pr_auc: 0.9854 - cohen_kappa: 0.8681 - val_loss: 0.6177 - val_tp: 628.0000 - val_fp: 173.0000 - val_tn: 675.0000 - val_fn: 200.0000 - val_binary_acc: 0.7774 - val_precision: 0.7840 - val_recall: 0.7585 - val_f1_score: 0.7710 - val_roc_auc: 0.8494 - val_pr_auc: 0.8537 - val_cohen_kappa: 0.5547 - lr: 4.0000e-07
# Epoch 25/50
# 419/419 [==============================] - ETA: 0s - loss: 0.1622 - tp: 3076.0000 - fp: 163.0000 - tn: 3200.0000 - fn: 264.0000 - binary_acc: 0.9363 - precision: 0.9497 - recall: 0.9210 - f1_score: 0.9351 - roc_auc: 0.9840 - pr_auc: 0.9855 - cohen_kappa: 0.8726
# Epoch 25: ReduceLROnPlateau reducing learning rate to 8.00000009348878e-08.
# 419/419 [==============================] - 81s 194ms/step - loss: 0.1622 - tp: 3076.0000 - fp: 163.0000 - tn: 3200.0000 - fn: 264.0000 - binary_acc: 0.9363 - precision: 0.9497 - recall: 0.9210 - f1_score: 0.9351 - roc_auc: 0.9840 - pr_auc: 0.9855 - cohen_kappa: 0.8726 - val_loss: 0.6429 - val_tp: 616.0000 - val_fp: 155.0000 - val_tn: 693.0000 - val_fn: 212.0000 - val_binary_acc: 0.7810 - val_precision: 0.7990 - val_recall: 0.7440 - val_f1_score: 0.7705 - val_roc_auc: 0.8465 - val_pr_auc: 0.8493 - val_cohen_kappa: 0.5616 - lr: 4.0000e-07
# Epoch 26/50
# 419/419 [==============================] - 80s 191ms/step - loss: 0.1560 - tp: 3087.0000 - fp: 149.0000 - tn: 3214.0000 - fn: 253.0000 - binary_acc: 0.9400 - precision: 0.9540 - recall: 0.9243 - f1_score: 0.9389 - roc_auc: 0.9854 - pr_auc: 0.9869 - cohen_kappa: 0.8800 - val_loss: 0.6537 - val_tp: 628.0000 - val_fp: 175.0000 - val_tn: 673.0000 - val_fn: 200.0000 - val_binary_acc: 0.7763 - val_precision: 0.7821 - val_recall: 0.7585 - val_f1_score: 0.7701 - val_roc_auc: 0.8448 - val_pr_auc: 0.8434 - val_cohen_kappa: 0.5523 - lr: 8.0000e-08
# Epoch 27/50
# 419/419 [==============================] - 83s 197ms/step - loss: 0.1588 - tp: 3091.0000 - fp: 169.0000 - tn: 3194.0000 - fn: 249.0000 - binary_acc: 0.9376 - precision: 0.9482 - recall: 0.9254 - f1_score: 0.9367 - roc_auc: 0.9849 - pr_auc: 0.9863 - cohen_kappa: 0.8753 - val_loss: 0.6428 - val_tp: 636.0000 - val_fp: 165.0000 - val_tn: 683.0000 - val_fn: 192.0000 - val_binary_acc: 0.7870 - val_precision: 0.7940 - val_recall: 0.7681 - val_f1_score: 0.7808 - val_roc_auc: 0.8489 - val_pr_auc: 0.8488 - val_cohen_kappa: 0.5738 - lr: 8.0000e-08
# Epoch 28/50
# 419/419 [==============================] - 89s 212ms/step - loss: 0.1621 - tp: 3090.0000 - fp: 168.0000 - tn: 3195.0000 - fn: 250.0000 - binary_acc: 0.9376 - precision: 0.9484 - recall: 0.9251 - f1_score: 0.9366 - roc_auc: 0.9841 - pr_auc: 0.9854 - cohen_kappa: 0.8753 - val_loss: 0.6593 - val_tp: 622.0000 - val_fp: 176.0000 - val_tn: 672.0000 - val_fn: 206.0000 - val_binary_acc: 0.7721 - val_precision: 0.7794 - val_recall: 0.7512 - val_f1_score: 0.7651 - val_roc_auc: 0.8415 - val_pr_auc: 0.8406 - val_cohen_kappa: 0.5439 - lr: 8.0000e-08
# Epoch 29/50
# 419/419 [==============================] - ETA: 0s - loss: 0.1587 - tp: 3093.0000 - fp: 162.0000 - tn: 3201.0000 - fn: 247.0000 - binary_acc: 0.9390 - precision: 0.9502 - recall: 0.9260 - f1_score: 0.9380 - roc_auc: 0.9846 - pr_auc: 0.9862 - cohen_kappa: 0.8780
# Epoch 29: ReduceLROnPlateau reducing learning rate to 1.5999999902760466e-08.
# 419/419 [==============================] - 84s 201ms/step - loss: 0.1587 - tp: 3093.0000 - fp: 162.0000 - tn: 3201.0000 - fn: 247.0000 - binary_acc: 0.9390 - precision: 0.9502 - recall: 0.9260 - f1_score: 0.9380 - roc_auc: 0.9846 - pr_auc: 0.9862 - cohen_kappa: 0.8780 - val_loss: 0.6336 - val_tp: 632.0000 - val_fp: 154.0000 - val_tn: 694.0000 - val_fn: 196.0000 - val_binary_acc: 0.7912 - val_precision: 0.8041 - val_recall: 0.7633 - val_f1_score: 0.7831 - val_roc_auc: 0.8477 - val_pr_auc: 0.8518 - val_cohen_kappa: 0.5820 - lr: 8.0000e-08
# Epoch 30/50
# 419/419 [==============================] - 84s 199ms/step - loss: 0.1556 - tp: 3117.0000 - fp: 186.0000 - tn: 3177.0000 - fn: 223.0000 - binary_acc: 0.9390 - precision: 0.9437 - recall: 0.9332 - f1_score: 0.9384 - roc_auc: 0.9857 - pr_auc: 0.9870 - cohen_kappa: 0.8780 - val_loss: 0.6462 - val_tp: 622.0000 - val_fp: 167.0000 - val_tn: 681.0000 - val_fn: 206.0000 - val_binary_acc: 0.7774 - val_precision: 0.7883 - val_recall: 0.7512 - val_f1_score: 0.7693 - val_roc_auc: 0.8479 - val_pr_auc: 0.8483 - val_cohen_kappa: 0.5546 - lr: 1.6000e-08
# Epoch 31/50
# 419/419 [==============================] - 85s 202ms/step - loss: 0.1564 - tp: 3101.0000 - fp: 168.0000 - tn: 3195.0000 - fn: 239.0000 - binary_acc: 0.9393 - precision: 0.9486 - recall: 0.9284 - f1_score: 0.9384 - roc_auc: 0.9854 - pr_auc: 0.9869 - cohen_kappa: 0.8786 - val_loss: 0.6513 - val_tp: 620.0000 - val_fp: 153.0000 - val_tn: 695.0000 - val_fn: 208.0000 - val_binary_acc: 0.7846 - val_precision: 0.8021 - val_recall: 0.7488 - val_f1_score: 0.7745 - val_roc_auc: 0.8424 - val_pr_auc: 0.8389 - val_cohen_kappa: 0.5688 - lr: 1.6000e-08
# Epoch 32/50
# 419/419 [==============================] - ETA: 0s - loss: 0.1579 - tp: 3082.0000 - fp: 164.0000 - tn: 3199.0000 - fn: 258.0000 - binary_acc: 0.9370 - precision: 0.9495 - recall: 0.9228 - f1_score: 0.9359 - roc_auc: 0.9850 - pr_auc: 0.9862 - cohen_kappa: 0.8741Restoring model weights from the end of the best epoch: 17.
# 419/419 [==============================] - 82s 195ms/step - loss: 0.1579 - tp: 3082.0000 - fp: 164.0000 - tn: 3199.0000 - fn: 258.0000 - binary_acc: 0.9370 - precision: 0.9495 - recall: 0.9228 - f1_score: 0.9359 - roc_auc: 0.9850 - pr_auc: 0.9862 - cohen_kappa: 0.8741 - val_loss: 0.6436 - val_tp: 630.0000 - val_fp: 169.0000 - val_tn: 679.0000 - val_fn: 198.0000 - val_binary_acc: 0.7810 - val_precision: 0.7885 - val_recall: 0.7609 - val_f1_score: 0.7744 - val_roc_auc: 0.8460 - val_pr_auc: 0.8459 - val_cohen_kappa: 0.5618 - lr: 1.6000e-08
# Epoch 32: early stopping

# %%
new_model.save(save_path + model_name + '.keras')
plot_metrics(history)

# %%
new_model.evaluate(validation_generator)
new_model.evaluate(test_generator)

# Make predictions using the validation generator
y_valid_pred_prob = new_model.predict(validation_generator)
y_valid_pred = (y_valid_pred_prob > 0.5).astype(int)
y_valid = validation_generator.classes
print("Classification Report:")
print(classification_report(y_valid, y_valid_pred))

# Make predictions using the test generator
y_pred_prob = new_model.predict(test_generator)
y_pred = (y_pred_prob > 0.5).astype(int)
y_test = test_generator.classes
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# 105/105 [==============================] - 15s 145ms/step - loss: 0.5775 - tp: 625.0000 - fp: 146.0000 - tn: 702.0000 - fn: 203.0000 - binary_acc: 0.7918 - precision: 0.8106 - recall: 0.7548 - f1_score: 0.7817 - roc_auc: 0.8545 - pr_auc: 0.8519 - cohen_kappa: 0.5831
# 36/36 [==============================] - 2s 59ms/step - loss: 0.6746 - tp: 215.0000 - fp: 74.0000 - tn: 211.0000 - fn: 63.0000 - binary_acc: 0.7567 - precision: 0.7439 - recall: 0.7734 - f1_score: 0.7584 - roc_auc: 0.8235 - pr_auc: 0.8401 - cohen_kappa: 0.5135
# 105/105 [==============================] - 16s 142ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.76      0.83      0.80       848
#            1       0.81      0.74      0.77       828
#
#     accuracy                           0.78      1676
#    macro avg       0.79      0.78      0.78      1676
# weighted avg       0.79      0.78      0.78      1676
#
# 36/36 [==============================] - 2s 46ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      0.74      0.75       285
#            1       0.74      0.77      0.76       278
#
#     accuracy                           0.76       563
#    macro avg       0.76      0.76      0.76       563
# weighted avg       0.76      0.76      0.76       563

# %%
conf_matrix = confusion_matrix(y_test, y_pred)

# Create ConfusionMatrixDisplay object
cm_display = ConfusionMatrixDisplay(confusion_matrix=conf_matrix)

# Plot the confusion matrix
plt.figure(figsize=(4, 6))  # Adjust the figure size as needed
cm_display.plot(cmap=plt.cm.Blues)  # You can choose any colormap you prefer
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.grid(False)  # Turn off grid
plt.savefig(save_path + model_name + "_confusion_matrix.jpg")
plt.show()

# %%
history_df = pd.DataFrame(history.history)
save_history(model_name, history_df)
# Out:
# Training history saved to: C:/Users/raouf/Desktop/pfe/history/final/resnet/XR_SHOULDER/finetuned_ResNet_XR_SHOULDER_history.xlsx
