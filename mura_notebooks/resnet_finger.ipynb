# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
import tensorflow as tf
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras import layers, models
from keras.layers import concatenate, Dense, Conv2D, MaxPooling2D, Flatten, Activation, BatchNormalization, Dropout, \
    Attention
from keras import *
from keras.applications import MobileNet
from keras.applications import VGG16
from keras.applications.resnet import ResNet50
from keras import backend as K
from keras.layers import Layer
import keras.layers as kl
import pandas as pd
from keras.applications import EfficientNetB0
import keras.applications
import numpy as np
import os
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from sklearn.metrics import cohen_kappa_score
import seaborn as sns
import pickle
import tensorflow_addons as tfa
from sklearn import metrics
from tensorflow.keras.applications.resnet import preprocess_input as preprocess_input_resnet
from tensorflow.keras.applications.densenet import preprocess_input as preprocess_input_densenet
from tensorflow.keras.models import load_model
import os
import glob
# Out:
# c:\Users\raouf\miniconda3\envs\tensorflowgpu\lib\site-packages\tensorflow_addons\utils\tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# c:\Users\raouf\miniconda3\envs\tensorflowgpu\lib\site-packages\tensorflow_addons\utils\ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.12.0 and strictly below 2.15.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.10.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %%
main_save_path = "C:/Users/raouf/Desktop/pfe/history/final/resnet/"
mura_location = "C:/Users/raouf/Desktop/pfe/"
data_path = 'C:/Users/raouf/Desktop/pfe/MURA-v1.1/'
train_path = 'C:/Users/raouf/Desktop/pfe/MURA-v1.1/train'
test_path = 'C:/Users/raouf/Desktop/pfe/MURA-v1.1/valid'

train_file = "C:/Users/raouf/Desktop/pfe/datasets/XR_FINGER_df_train.csv"
val_file = "C:/Users/raouf/Desktop/pfe/datasets/XR_FINGER_df_valid.csv"

test_file = "C:/Users/raouf/Desktop/pfe/MURA-v1.1/valid_image_paths.csv"

target_category = "XR_FINGER"
batch_size = 16
num_epochs = 100
fine_tuning_epochs=50
validation_split = 0.2
loss_function = tf.keras.losses.BinaryCrossentropy()
learning_rate = 0.0001
input_shape = (224, 224, 3)
architecture = 'ResNet'

include_top = False
# metrics=["accuracy"] #, tf.keras.metrics.Precision(), tf.keras.metrics.Recall()
early_stopping_patience = 15
shuffle = True
class_mode = 'binary'  # 'categorical'
IMAGE_WIDTH = 224
IMAGE_HEIGHT = 224
trainable = False
training = False
dropout = 0.2

# %%
def load_data(file, part):
    train_data = pd.read_csv(file)
    train_data = train_data.rename(columns={train_data.columns[0]: 'image_path'})
    train_data['label'] = 2
    string_to_add = mura_location
    train_data['image_path'] = string_to_add + train_data['image_path'].astype(str)
    for index, row in train_data.iterrows():
        if 'positive' in str(row['image_path']).lower():
            train_data.at[index, 'label'] = "positive"
        else:
            train_data.at[index, 'label'] = "negative"

    if part == 0:
        pass
    else:
        train_data = train_data[train_data['image_path'].str.contains(part)]
    return train_data


class CustomCallback(keras.callbacks.Callback):
    def on_test_end(self, logs=None):
        keys = list(logs.keys())
        print(f"tp          :", logs["tp"])
        print(f"fp          :", logs["fp"])
        print(f"tn          :", logs["tn"])
        print(f"fn          :", logs["fn"])
        print(f"binary_acc  :", logs["binary_acc"])
        print(f"precision   :", logs["precision"])
        print(f"recall      :", logs["recall"])
        print(f"f1_score    :", logs["f1_score"])
        print(f"roc_auc     :", logs["roc_auc"])
        print(f"pr_auc      :", logs["pr_auc"])
        print(f"cohen_kappa :", logs["cohen_kappa"])

class F1Score(tf.keras.metrics.Metric):

    def __init__(self, name="f1_score", **kwargs):
        super().__init__(name=name, **kwargs)
        self.f1 = self.add_weight(name="f1", initializer="zeros")
        self.precision_fn = tf.keras.metrics.Precision()
        self.recall_fn = tf.keras.metrics.Recall()

    def update_state(self, y_true, y_pred, sample_weight=None):
        p = self.precision_fn(y_true, y_pred)
        r = self.recall_fn(y_true, y_pred)
        self.f1.assign(2 * ((p * r) / (p + r + 1e-10)))

    def result(self):
        return self.f1

    def reset_state(self):
        # we also need to reset the state of the precision and recall objects
        self.precision_fn.reset_state()
        self.recall_fn.reset_state()
        self.f1.assign(0)


def save_history(name,history_df):

    history_excel_path = (
            save_path +
            name +
            '_history'
            '.xlsx'
    )

    history_df.to_excel(history_excel_path, index=False)
    print("Training history saved to:", history_excel_path)






def plot_metrics(history: tf.keras.callbacks.History,
                 metrics: list = ["loss", "cohen_kappa", "precision", "recall"],
                 ) -> None:
    plt.rcParams["figure.figsize"] = (18, 15)

    for n, metric in enumerate(metrics):
        name = metric.replace("_", " ").capitalize()
        plt.subplot(2, 2, n + 1)
        plt.plot(
            history.epoch, history.history[metric], linewidth=1.8, label="training"
        )
        plt.plot(
            history.epoch,
            history.history["val_" + metric],
            linestyle="--",
            linewidth=1.8,
            label="validation",
        )
        plt.xlabel("epoch")
        plt.ylabel(name)
        if metric == "loss":
            plt.ylim([0, plt.ylim()[1]])
        elif metric == "cohen_kappa":
            plt.ylim([-1, 1])
        else:
            plt.ylim([0, 1])

        plt.legend()



class CustomCallback(keras.callbacks.Callback):
    def on_test_end(self, logs=None):
        keys = list(logs.keys())
        print(f"tp          :", logs["tp"])
        print(f"fp          :", logs["fp"])
        print(f"tn          :", logs["tn"])
        print(f"fn          :", logs["fn"])
        print(f"binary_acc  :", logs["binary_acc"])
        print(f"precision   :", logs["precision"])
        print(f"recall      :", logs["recall"])
        print(f"f1_score    :", logs["f1_score"])
        print(f"roc_auc     :", logs["roc_auc"])
        print(f"pr_auc      :", logs["pr_auc"])
        print(f"cohen_kappa :", logs["cohen_kappa"])

def build_ensemble_model():
    inputs = tf.keras.Input(shape=input_shape)

    resnet_preprocess_input = preprocess_input_resnet(inputs)
    resnet_base_output = resnet_base(resnet_preprocess_input)

    densenet_preprocess_input = preprocess_input_densenet(inputs)
    densenet_base_output = densenet_base(densenet_preprocess_input)

    concat_output = tf.keras.layers.Concatenate(axis=-1)([resnet_base_output, densenet_base_output])

    x = Dense(2048, activation="relu")(concat_output)
    x = Dropout(0.8)(x)
    x = Dense(1024, activation="relu")(x)
    x = Dropout(0.6)(x)
    x = Dense(512, activation="relu")(x)
    x = Dropout(0.4)(x)
    x = Dense(64, activation="relu")(x)
    x = Dropout(0.2)(x)
    prediction = Dense(1, activation="sigmoid")(x)

    model = Model(inputs, prediction)
    model._name = "Ensemble_model"

    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
                  loss=tf.keras.losses.BinaryCrossentropy(),
                  metrics=METRICS)
    return model


def save_history(name,history_df):

    # Constructing the file name with metric values
    history_excel_path = (
            save_path +
            name +
            '_history'
            '.xlsx'
    )

    history_df.to_excel(history_excel_path, index=False)
    print("Training history saved to:", history_excel_path)




class F1Score(tf.keras.metrics.Metric):

    def __init__(self, name="f1_score", **kwargs):
        super().__init__(name=name, **kwargs)
        self.f1 = self.add_weight(name="f1", initializer="zeros")
        self.precision_fn = tf.keras.metrics.Precision()
        self.recall_fn = tf.keras.metrics.Recall()

    def update_state(self, y_true, y_pred, sample_weight=None):
        p = self.precision_fn(y_true, y_pred)
        r = self.recall_fn(y_true, y_pred)
        self.f1.assign(2 * ((p * r) / (p + r + 1e-10)))

    def result(self):
        return self.f1

    def reset_state(self):
        # we also need to reset the state of the precision and recall objects
        self.precision_fn.reset_state()
        self.recall_fn.reset_state()
        self.f1.assign(0)

def plot_metrics(history: tf.keras.callbacks.History,
                 metrics: list = ["loss", "cohen_kappa", "precision", "recall"],
                 ) -> None:
    plt.rcParams["figure.figsize"] = (18, 15)

    for n, metric in enumerate(metrics):
        name = metric.replace("_", " ").capitalize()
        plt.subplot(2, 2, n + 1)
        plt.plot(
            history.epoch, history.history[metric], linewidth=1.8, label="training"
        )
        plt.plot(
            history.epoch,
            history.history["val_" + metric],
            linestyle="--",
            linewidth=1.8,
            label="validation",
        )
        plt.xlabel("epoch")
        plt.ylabel(name)
        if metric == "loss":
            plt.ylim([0, plt.ylim()[1]])
        elif metric == "cohen_kappa":
            plt.ylim([-1, 1])
        else:
            plt.ylim([0, 1])

        plt.legend()


def my_func(model, data_generator, threshold=0.5):
    y_pred_prob = model.predict(data_generator)
    y_pred = (y_pred_prob > threshold).astype(int)
    y_true = data_generator.classes
    print("Classification Report:")
    print(classification_report(y_true, y_pred))

# %%
METRICS = [
    tf.keras.metrics.TruePositives(name="tp"),
    tf.keras.metrics.FalsePositives(name="fp"),
    tf.keras.metrics.TrueNegatives(name="tn"),
    tf.keras.metrics.FalseNegatives(name="fn"),
    tf.keras.metrics.BinaryAccuracy(name="binary_acc"),
    tf.keras.metrics.Precision(name="precision"),
    tf.keras.metrics.Recall(name="recall"),
    F1Score(name="f1_score"),
    tf.keras.metrics.AUC(name="roc_auc", curve="ROC"),
    tf.keras.metrics.AUC(name="pr_auc", curve="PR"),
    tfa.metrics.CohenKappa(name="cohen_kappa", num_classes=2),
]

# %%
resnet = tf.keras.applications.resnet50.ResNet50(include_top=include_top,
                                                 weights="imagenet",
                                                 input_shape=(IMAGE_WIDTH, IMAGE_HEIGHT, 3),
                                                 pooling="max",  # pooling mode for feature extraction
                                                 classes=2)


def make_resnet_model(base_model: tf.keras.applications.resnet50.ResNet50, ) -> tf.keras.Model:
    # freeze base model
    base_model.trainable = False  # trainable

    inputs = tf.keras.Input(shape=(IMAGE_WIDTH, IMAGE_HEIGHT, 3))
    x = base_model(inputs, training=training)

    # x = tf.keras.layers.Dense(4096, activation='relu')(x)
    x = tf.keras.layers.Dense(1024, activation='relu')(x)
    x = tf.keras.layers.Dropout(rate=dropout)(x)
    x = tf.keras.layers.Dense(512, activation='relu')(x)
    # x = tf.keras.layers.Dropout(rate=dropout)(x)

    output = tf.keras.layers.Dense(units=1, activation="sigmoid")(x)

    model = tf.keras.Model(inputs, output)

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
        loss=loss_function,
        metrics=METRICS,
    )

    return model

# %%
new_model = make_resnet_model(base_model=resnet)

new_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  resnet50 (Functional)       (None, 2048)              23587712
#
#  dense (Dense)               (None, 1024)              2098176
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  dense_2 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 26,211,201
# Trainable params: 2,623,489
# Non-trainable params: 23,587,712
# _________________________________________________________________

# %%
"""import matplotlib.pyplot as plt
from tensorflow.keras.utils import plot_model
tf.keras.utils.plot_model(new_model,
                          show_shapes=True,  # show_dtype=False,
                          show_layer_names=True,
                          layer_range=None,
                          show_layer_activations=True)"""
# Out:
# 'import matplotlib.pyplot as plt\nfrom tensorflow.keras.utils import plot_model\ntf.keras.utils.plot_model(new_model,\n                          show_shapes=True,  # show_dtype=False,\n                          show_layer_names=True,\n                          layer_range=None,\n                          show_layer_activations=True)'

# %%
early_stopping = EarlyStopping(monitor="val_cohen_kappa",
                               verbose=1,
                               patience=early_stopping_patience,
                               mode="max",
                               baseline=0.0,
                               restore_best_weights=True)
save_path = main_save_path + target_category + "/"
model_name = architecture + "_" + target_category
model_path = save_path + '_best_' + model_name + '.keras'
model_checkpoint = ModelCheckpoint(filepath=model_path,
                                       monitor="val_cohen_kappa",
                                       save_best_only=True)

# %%
import pandas as pd


old_base_path = 'C:\\Users\\HP\\Documents\\ML\\encadrement Master\\MURA-V1.1\\'

df_train = pd.read_csv(train_file)
df_train['image_path'] = df_train['image_path'].str.replace(old_base_path, mura_location)

df_valid = pd.read_csv(val_file)
df_valid['image_path'] = df_valid['image_path'].str.replace(old_base_path, mura_location)


df_test = load_data(test_file, target_category)

datagen = tf.keras.preprocessing.image.ImageDataGenerator(rotation_range=30,
                                                              horizontal_flip=True,
                                                              fill_mode="constant",
                                                              cval=0.0,
                                                              preprocessing_function=tf.keras.applications.resnet50.preprocess_input)
train_generator = datagen.flow_from_dataframe(df_train,
                                                  directory=None,
                                                  x_col='image_path',
                                                  y_col='label',
                                                  target_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
                                                  batch_size=batch_size,
                                                  class_mode=class_mode,
                                                  )

validation_generator = datagen.flow_from_dataframe(df_valid,
                                                       directory=None,
                                                       x_col='image_path',
                                                       y_col='label',
                                                       target_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
                                                       batch_size=batch_size,
                                                       class_mode=class_mode,
                                                   shuffle=False
                                                       )

test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
        preprocessing_function=tf.keras.applications.resnet50.preprocess_input)
test_generator = test_datagen.flow_from_dataframe(df_test,
                                                      directory=None,
                                                      x_col='image_path',
                                                      y_col='label',
                                                      target_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
                                                      batch_size=batch_size,
                                                      class_mode=class_mode,
                                                  shuffle=False
                                                      )
# Out:
# C:\Users\raouf\AppData\Local\Temp\ipykernel_3184\982068502.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'positive' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_data.at[index, 'label'] = "positive"
# Found 4084 validated image filenames belonging to 2 classes.
# Found 1022 validated image filenames belonging to 2 classes.
# Found 461 validated image filenames belonging to 2 classes.

# %%
history = new_model.fit(train_generator,
                            # teps_per_epoch=len(df_train) // batch_size,
                            validation_data=validation_generator,
                            # validation_steps=len(df_valid) // batch_size,
                            epochs=num_epochs,
                            shuffle=shuffle,
                            callbacks=[early_stopping, model_checkpoint])  # , reduce_lr_callback])
# Out:
# Epoch 1/100
# 256/256 [==============================] - 50s 166ms/step - loss: 0.9810 - tp: 832.0000 - fp: 674.0000 - tn: 1850.0000 - fn: 728.0000 - binary_acc: 0.6567 - precision: 0.5525 - recall: 0.5333 - f1_score: 0.5427 - roc_auc: 0.6826 - pr_auc: 0.5487 - cohen_kappa: 0.2681 - val_loss: 0.6188 - val_tp: 163.0000 - val_fp: 51.0000 - val_tn: 563.0000 - val_fn: 245.0000 - val_binary_acc: 0.7104 - val_precision: 0.7617 - val_recall: 0.3995 - val_f1_score: 0.5241 - val_roc_auc: 0.7851 - val_pr_auc: 0.7256 - val_cohen_kappa: 0.3439
# Epoch 2/100
# 256/256 [==============================] - 40s 158ms/step - loss: 0.6984 - tp: 828.0000 - fp: 598.0000 - tn: 1926.0000 - fn: 732.0000 - binary_acc: 0.6743 - precision: 0.5806 - recall: 0.5308 - f1_score: 0.5546 - roc_auc: 0.7217 - pr_auc: 0.6060 - cohen_kappa: 0.2987 - val_loss: 0.5710 - val_tp: 260.0000 - val_fp: 154.0000 - val_tn: 460.0000 - val_fn: 148.0000 - val_binary_acc: 0.7045 - val_precision: 0.6280 - val_recall: 0.6373 - val_f1_score: 0.6326 - val_roc_auc: 0.7723 - val_pr_auc: 0.6988 - val_cohen_kappa: 0.3855
# Epoch 3/100
# 256/256 [==============================] - 40s 156ms/step - loss: 0.6126 - tp: 889.0000 - fp: 560.0000 - tn: 1964.0000 - fn: 671.0000 - binary_acc: 0.6986 - precision: 0.6135 - recall: 0.5699 - f1_score: 0.5909 - roc_auc: 0.7588 - pr_auc: 0.6463 - cohen_kappa: 0.3528 - val_loss: 0.6273 - val_tp: 359.0000 - val_fp: 297.0000 - val_tn: 317.0000 - val_fn: 49.0000 - val_binary_acc: 0.6614 - val_precision: 0.5473 - val_recall: 0.8799 - val_f1_score: 0.6748 - val_roc_auc: 0.7911 - val_pr_auc: 0.7217 - val_cohen_kappa: 0.3595
# Epoch 4/100
# 256/256 [==============================] - 41s 159ms/step - loss: 0.5783 - tp: 902.0000 - fp: 535.0000 - tn: 1989.0000 - fn: 658.0000 - binary_acc: 0.7079 - precision: 0.6277 - recall: 0.5782 - f1_score: 0.6019 - roc_auc: 0.7690 - pr_auc: 0.6721 - cohen_kappa: 0.3718 - val_loss: 0.5405 - val_tp: 242.0000 - val_fp: 107.0000 - val_tn: 507.0000 - val_fn: 166.0000 - val_binary_acc: 0.7329 - val_precision: 0.6934 - val_recall: 0.5931 - val_f1_score: 0.6394 - val_roc_auc: 0.8003 - val_pr_auc: 0.7294 - val_cohen_kappa: 0.4293
# Epoch 5/100
# 256/256 [==============================] - 41s 160ms/step - loss: 0.5501 - tp: 933.0000 - fp: 517.0000 - tn: 2007.0000 - fn: 627.0000 - binary_acc: 0.7199 - precision: 0.6434 - recall: 0.5981 - f1_score: 0.6199 - roc_auc: 0.7885 - pr_auc: 0.6839 - cohen_kappa: 0.3986 - val_loss: 0.5932 - val_tp: 144.0000 - val_fp: 36.0000 - val_tn: 578.0000 - val_fn: 264.0000 - val_binary_acc: 0.7065 - val_precision: 0.8000 - val_recall: 0.3529 - val_f1_score: 0.4898 - val_roc_auc: 0.8013 - val_pr_auc: 0.7385 - val_cohen_kappa: 0.3248
# Epoch 6/100
# 256/256 [==============================] - 43s 167ms/step - loss: 0.5522 - tp: 905.0000 - fp: 481.0000 - tn: 2043.0000 - fn: 655.0000 - binary_acc: 0.7218 - precision: 0.6530 - recall: 0.5801 - f1_score: 0.6144 - roc_auc: 0.7887 - pr_auc: 0.6854 - cohen_kappa: 0.3980 - val_loss: 0.5283 - val_tp: 283.0000 - val_fp: 133.0000 - val_tn: 481.0000 - val_fn: 125.0000 - val_binary_acc: 0.7476 - val_precision: 0.6803 - val_recall: 0.6936 - val_f1_score: 0.6869 - val_roc_auc: 0.8089 - val_pr_auc: 0.7269 - val_cohen_kappa: 0.4755
# Epoch 7/100
# 256/256 [==============================] - 41s 161ms/step - loss: 0.5271 - tp: 961.0000 - fp: 476.0000 - tn: 2048.0000 - fn: 599.0000 - binary_acc: 0.7368 - precision: 0.6688 - recall: 0.6160 - f1_score: 0.6413 - roc_auc: 0.8039 - pr_auc: 0.7266 - cohen_kappa: 0.4340 - val_loss: 0.5403 - val_tp: 177.0000 - val_fp: 31.0000 - val_tn: 583.0000 - val_fn: 231.0000 - val_binary_acc: 0.7436 - val_precision: 0.8510 - val_recall: 0.4338 - val_f1_score: 0.5747 - val_roc_auc: 0.8182 - val_pr_auc: 0.7719 - val_cohen_kappa: 0.4177
# Epoch 8/100
# 256/256 [==============================] - 41s 161ms/step - loss: 0.5191 - tp: 985.0000 - fp: 460.0000 - tn: 2064.0000 - fn: 575.0000 - binary_acc: 0.7466 - precision: 0.6817 - recall: 0.6314 - f1_score: 0.6556 - roc_auc: 0.8112 - pr_auc: 0.7272 - cohen_kappa: 0.4556 - val_loss: 0.5106 - val_tp: 292.0000 - val_fp: 150.0000 - val_tn: 464.0000 - val_fn: 116.0000 - val_binary_acc: 0.7397 - val_precision: 0.6606 - val_recall: 0.7157 - val_f1_score: 0.6871 - val_roc_auc: 0.8200 - val_pr_auc: 0.7658 - val_cohen_kappa: 0.4649
# Epoch 9/100
# 256/256 [==============================] - 41s 161ms/step - loss: 0.5101 - tp: 947.0000 - fp: 448.0000 - tn: 2076.0000 - fn: 613.0000 - binary_acc: 0.7402 - precision: 0.6789 - recall: 0.6071 - f1_score: 0.6409 - roc_auc: 0.8167 - pr_auc: 0.7306 - cohen_kappa: 0.4384 - val_loss: 0.5079 - val_tp: 239.0000 - val_fp: 87.0000 - val_tn: 527.0000 - val_fn: 169.0000 - val_binary_acc: 0.7495 - val_precision: 0.7331 - val_recall: 0.5858 - val_f1_score: 0.6512 - val_roc_auc: 0.8221 - val_pr_auc: 0.7769 - val_cohen_kappa: 0.4596
# Epoch 10/100
# 256/256 [==============================] - 41s 161ms/step - loss: 0.5146 - tp: 979.0000 - fp: 468.0000 - tn: 2056.0000 - fn: 581.0000 - binary_acc: 0.7431 - precision: 0.6766 - recall: 0.6276 - f1_score: 0.6511 - roc_auc: 0.8130 - pr_auc: 0.7252 - cohen_kappa: 0.4483 - val_loss: 0.5242 - val_tp: 236.0000 - val_fp: 89.0000 - val_tn: 525.0000 - val_fn: 172.0000 - val_binary_acc: 0.7446 - val_precision: 0.7262 - val_recall: 0.5784 - val_f1_score: 0.6439 - val_roc_auc: 0.8157 - val_pr_auc: 0.7668 - val_cohen_kappa: 0.4488
# Epoch 11/100
# 256/256 [==============================] - 41s 161ms/step - loss: 0.5014 - tp: 973.0000 - fp: 439.0000 - tn: 2085.0000 - fn: 587.0000 - binary_acc: 0.7488 - precision: 0.6891 - recall: 0.6237 - f1_score: 0.6548 - roc_auc: 0.8204 - pr_auc: 0.7424 - cohen_kappa: 0.4581 - val_loss: 0.5137 - val_tp: 229.0000 - val_fp: 75.0000 - val_tn: 539.0000 - val_fn: 179.0000 - val_binary_acc: 0.7515 - val_precision: 0.7533 - val_recall: 0.5613 - val_f1_score: 0.6433 - val_roc_auc: 0.8284 - val_pr_auc: 0.7818 - val_cohen_kappa: 0.4587
# Epoch 12/100
# 256/256 [==============================] - 42s 164ms/step - loss: 0.4956 - tp: 978.0000 - fp: 429.0000 - tn: 2095.0000 - fn: 582.0000 - binary_acc: 0.7524 - precision: 0.6951 - recall: 0.6269 - f1_score: 0.6593 - roc_auc: 0.8261 - pr_auc: 0.7494 - cohen_kappa: 0.4657 - val_loss: 0.7177 - val_tp: 68.0000 - val_fp: 5.0000 - val_tn: 609.0000 - val_fn: 340.0000 - val_binary_acc: 0.6624 - val_precision: 0.9315 - val_recall: 0.1667 - val_f1_score: 0.2827 - val_roc_auc: 0.8310 - val_pr_auc: 0.7729 - val_cohen_kappa: 0.1838
# Epoch 13/100
# 256/256 [==============================] - 42s 163ms/step - loss: 0.4972 - tp: 956.0000 - fp: 445.0000 - tn: 2079.0000 - fn: 604.0000 - binary_acc: 0.7431 - precision: 0.6824 - recall: 0.6128 - f1_score: 0.6457 - roc_auc: 0.8222 - pr_auc: 0.7515 - cohen_kappa: 0.4452 - val_loss: 0.5184 - val_tp: 254.0000 - val_fp: 97.0000 - val_tn: 517.0000 - val_fn: 154.0000 - val_binary_acc: 0.7544 - val_precision: 0.7236 - val_recall: 0.6225 - val_f1_score: 0.6693 - val_roc_auc: 0.8215 - val_pr_auc: 0.7630 - val_cohen_kappa: 0.4757
# Epoch 14/100
# 256/256 [==============================] - 42s 166ms/step - loss: 0.4911 - tp: 1010.0000 - fp: 419.0000 - tn: 2105.0000 - fn: 550.0000 - binary_acc: 0.7627 - precision: 0.7068 - recall: 0.6474 - f1_score: 0.6758 - roc_auc: 0.8304 - pr_auc: 0.7567 - cohen_kappa: 0.4893 - val_loss: 0.5132 - val_tp: 276.0000 - val_fp: 136.0000 - val_tn: 478.0000 - val_fn: 132.0000 - val_binary_acc: 0.7378 - val_precision: 0.6699 - val_recall: 0.6765 - val_f1_score: 0.6732 - val_roc_auc: 0.8168 - val_pr_auc: 0.7514 - val_cohen_kappa: 0.4542
# Epoch 15/100
# 256/256 [==============================] - 42s 163ms/step - loss: 0.4764 - tp: 1005.0000 - fp: 415.0000 - tn: 2109.0000 - fn: 555.0000 - binary_acc: 0.7625 - precision: 0.7077 - recall: 0.6442 - f1_score: 0.6745 - roc_auc: 0.8396 - pr_auc: 0.7747 - cohen_kappa: 0.4882 - val_loss: 0.5443 - val_tp: 322.0000 - val_fp: 200.0000 - val_tn: 414.0000 - val_fn: 86.0000 - val_binary_acc: 0.7202 - val_precision: 0.6169 - val_recall: 0.7892 - val_f1_score: 0.6925 - val_roc_auc: 0.8214 - val_pr_auc: 0.7675 - val_cohen_kappa: 0.4427
# Epoch 16/100
# 256/256 [==============================] - 42s 164ms/step - loss: 0.4711 - tp: 1022.0000 - fp: 420.0000 - tn: 2104.0000 - fn: 538.0000 - binary_acc: 0.7654 - precision: 0.7087 - recall: 0.6551 - f1_score: 0.6809 - roc_auc: 0.8423 - pr_auc: 0.7759 - cohen_kappa: 0.4959 - val_loss: 0.5136 - val_tp: 220.0000 - val_fp: 59.0000 - val_tn: 555.0000 - val_fn: 188.0000 - val_binary_acc: 0.7583 - val_precision: 0.7885 - val_recall: 0.5392 - val_f1_score: 0.6405 - val_roc_auc: 0.8301 - val_pr_auc: 0.7803 - val_cohen_kappa: 0.4679
# Epoch 17/100
# 256/256 [==============================] - 42s 163ms/step - loss: 0.4610 - tp: 1031.0000 - fp: 380.0000 - tn: 2144.0000 - fn: 529.0000 - binary_acc: 0.7774 - precision: 0.7307 - recall: 0.6609 - f1_score: 0.6940 - roc_auc: 0.8499 - pr_auc: 0.7910 - cohen_kappa: 0.5198 - val_loss: 0.5171 - val_tp: 214.0000 - val_fp: 57.0000 - val_tn: 557.0000 - val_fn: 194.0000 - val_binary_acc: 0.7544 - val_precision: 0.7897 - val_recall: 0.5245 - val_f1_score: 0.6303 - val_roc_auc: 0.8315 - val_pr_auc: 0.7776 - val_cohen_kappa: 0.4574
# Epoch 18/100
# 256/256 [==============================] - 42s 165ms/step - loss: 0.4580 - tp: 1043.0000 - fp: 401.0000 - tn: 2123.0000 - fn: 517.0000 - binary_acc: 0.7752 - precision: 0.7223 - recall: 0.6686 - f1_score: 0.6944 - roc_auc: 0.8524 - pr_auc: 0.7876 - cohen_kappa: 0.5171 - val_loss: 0.4971 - val_tp: 293.0000 - val_fp: 127.0000 - val_tn: 487.0000 - val_fn: 115.0000 - val_binary_acc: 0.7632 - val_precision: 0.6976 - val_recall: 0.7181 - val_f1_score: 0.7077 - val_roc_auc: 0.8338 - val_pr_auc: 0.7867 - val_cohen_kappa: 0.5088
# Epoch 19/100
# 256/256 [==============================] - 42s 164ms/step - loss: 0.4448 - tp: 1046.0000 - fp: 390.0000 - tn: 2134.0000 - fn: 514.0000 - binary_acc: 0.7786 - precision: 0.7284 - recall: 0.6705 - f1_score: 0.6983 - roc_auc: 0.8606 - pr_auc: 0.7963 - cohen_kappa: 0.5239 - val_loss: 0.4919 - val_tp: 279.0000 - val_fp: 117.0000 - val_tn: 497.0000 - val_fn: 129.0000 - val_binary_acc: 0.7593 - val_precision: 0.7045 - val_recall: 0.6838 - val_f1_score: 0.6940 - val_roc_auc: 0.8376 - val_pr_auc: 0.7951 - val_cohen_kappa: 0.4957
# Epoch 20/100
# 256/256 [==============================] - 42s 165ms/step - loss: 0.4436 - tp: 1060.0000 - fp: 373.0000 - tn: 2151.0000 - fn: 500.0000 - binary_acc: 0.7862 - precision: 0.7397 - recall: 0.6795 - f1_score: 0.7083 - roc_auc: 0.8626 - pr_auc: 0.8062 - cohen_kappa: 0.5401 - val_loss: 0.4873 - val_tp: 287.0000 - val_fp: 109.0000 - val_tn: 505.0000 - val_fn: 121.0000 - val_binary_acc: 0.7750 - val_precision: 0.7247 - val_recall: 0.7034 - val_f1_score: 0.7139 - val_roc_auc: 0.8455 - val_pr_auc: 0.8054 - val_cohen_kappa: 0.5285
# Epoch 21/100
# 256/256 [==============================] - 41s 160ms/step - loss: 0.4481 - tp: 1064.0000 - fp: 390.0000 - tn: 2134.0000 - fn: 496.0000 - binary_acc: 0.7831 - precision: 0.7318 - recall: 0.6821 - f1_score: 0.7060 - roc_auc: 0.8593 - pr_auc: 0.8031 - cohen_kappa: 0.5345 - val_loss: 0.4778 - val_tp: 303.0000 - val_fp: 136.0000 - val_tn: 478.0000 - val_fn: 105.0000 - val_binary_acc: 0.7642 - val_precision: 0.6902 - val_recall: 0.7426 - val_f1_score: 0.7155 - val_roc_auc: 0.8493 - val_pr_auc: 0.8124 - val_cohen_kappa: 0.5146
# Epoch 22/100
# 256/256 [==============================] - 41s 158ms/step - loss: 0.4496 - tp: 1024.0000 - fp: 391.0000 - tn: 2133.0000 - fn: 536.0000 - binary_acc: 0.7730 - precision: 0.7237 - recall: 0.6564 - f1_score: 0.6884 - roc_auc: 0.8572 - pr_auc: 0.7959 - cohen_kappa: 0.5106 - val_loss: 0.5033 - val_tp: 263.0000 - val_fp: 108.0000 - val_tn: 506.0000 - val_fn: 145.0000 - val_binary_acc: 0.7524 - val_precision: 0.7089 - val_recall: 0.6446 - val_f1_score: 0.6752 - val_roc_auc: 0.8236 - val_pr_auc: 0.7851 - val_cohen_kappa: 0.4760
# Epoch 23/100
# 256/256 [==============================] - 40s 157ms/step - loss: 0.4174 - tp: 1089.0000 - fp: 360.0000 - tn: 2164.0000 - fn: 471.0000 - binary_acc: 0.7965 - precision: 0.7516 - recall: 0.6981 - f1_score: 0.7238 - roc_auc: 0.8793 - pr_auc: 0.8246 - cohen_kappa: 0.5631 - val_loss: 0.5125 - val_tp: 317.0000 - val_fp: 155.0000 - val_tn: 459.0000 - val_fn: 91.0000 - val_binary_acc: 0.7593 - val_precision: 0.6716 - val_recall: 0.7770 - val_f1_score: 0.7205 - val_roc_auc: 0.8358 - val_pr_auc: 0.7889 - val_cohen_kappa: 0.5111
# Epoch 24/100
# 256/256 [==============================] - 40s 158ms/step - loss: 0.4241 - tp: 1086.0000 - fp: 363.0000 - tn: 2161.0000 - fn: 474.0000 - binary_acc: 0.7951 - precision: 0.7495 - recall: 0.6962 - f1_score: 0.7218 - roc_auc: 0.8744 - pr_auc: 0.8225 - cohen_kappa: 0.5599 - val_loss: 0.5381 - val_tp: 198.0000 - val_fp: 27.0000 - val_tn: 587.0000 - val_fn: 210.0000 - val_binary_acc: 0.7681 - val_precision: 0.8800 - val_recall: 0.4853 - val_f1_score: 0.6256 - val_roc_auc: 0.8414 - val_pr_auc: 0.8083 - val_cohen_kappa: 0.4772
# Epoch 25/100
# 256/256 [==============================] - 40s 158ms/step - loss: 0.4273 - tp: 1075.0000 - fp: 358.0000 - tn: 2166.0000 - fn: 485.0000 - binary_acc: 0.7936 - precision: 0.7502 - recall: 0.6891 - f1_score: 0.7183 - roc_auc: 0.8715 - pr_auc: 0.8224 - cohen_kappa: 0.5559 - val_loss: 0.5146 - val_tp: 199.0000 - val_fp: 38.0000 - val_tn: 576.0000 - val_fn: 209.0000 - val_binary_acc: 0.7583 - val_precision: 0.8397 - val_recall: 0.4877 - val_f1_score: 0.6171 - val_roc_auc: 0.8379 - val_pr_auc: 0.8005 - val_cohen_kappa: 0.4581
# Epoch 26/100
# 256/256 [==============================] - 41s 160ms/step - loss: 0.4178 - tp: 1082.0000 - fp: 344.0000 - tn: 2180.0000 - fn: 478.0000 - binary_acc: 0.7987 - precision: 0.7588 - recall: 0.6936 - f1_score: 0.7247 - roc_auc: 0.8786 - pr_auc: 0.8264 - cohen_kappa: 0.5666 - val_loss: 0.5106 - val_tp: 332.0000 - val_fp: 179.0000 - val_tn: 435.0000 - val_fn: 76.0000 - val_binary_acc: 0.7505 - val_precision: 0.6497 - val_recall: 0.8137 - val_f1_score: 0.7225 - val_roc_auc: 0.8419 - val_pr_auc: 0.7933 - val_cohen_kappa: 0.5010
# Epoch 27/100
# 256/256 [==============================] - 40s 158ms/step - loss: 0.4000 - tp: 1107.0000 - fp: 334.0000 - tn: 2190.0000 - fn: 453.0000 - binary_acc: 0.8073 - precision: 0.7682 - recall: 0.7096 - f1_score: 0.7378 - roc_auc: 0.8880 - pr_auc: 0.8463 - cohen_kappa: 0.5858 - val_loss: 0.5191 - val_tp: 334.0000 - val_fp: 195.0000 - val_tn: 419.0000 - val_fn: 74.0000 - val_binary_acc: 0.7368 - val_precision: 0.6314 - val_recall: 0.8186 - val_f1_score: 0.7129 - val_roc_auc: 0.8478 - val_pr_auc: 0.8073 - val_cohen_kappa: 0.4773
# Epoch 28/100
# 256/256 [==============================] - 41s 160ms/step - loss: 0.4076 - tp: 1096.0000 - fp: 336.0000 - tn: 2188.0000 - fn: 464.0000 - binary_acc: 0.8041 - precision: 0.7654 - recall: 0.7026 - f1_score: 0.7326 - roc_auc: 0.8860 - pr_auc: 0.8363 - cohen_kappa: 0.5785 - val_loss: 0.4671 - val_tp: 306.0000 - val_fp: 106.0000 - val_tn: 508.0000 - val_fn: 102.0000 - val_binary_acc: 0.7965 - val_precision: 0.7427 - val_recall: 0.7500 - val_f1_score: 0.7463 - val_roc_auc: 0.8584 - val_pr_auc: 0.8191 - val_cohen_kappa: 0.5764
# Epoch 29/100
# 256/256 [==============================] - 40s 157ms/step - loss: 0.4066 - tp: 1099.0000 - fp: 339.0000 - tn: 2185.0000 - fn: 461.0000 - binary_acc: 0.8041 - precision: 0.7643 - recall: 0.7045 - f1_score: 0.7332 - roc_auc: 0.8866 - pr_auc: 0.8364 - cohen_kappa: 0.5788 - val_loss: 0.4803 - val_tp: 271.0000 - val_fp: 101.0000 - val_tn: 513.0000 - val_fn: 137.0000 - val_binary_acc: 0.7671 - val_precision: 0.7285 - val_recall: 0.6642 - val_f1_score: 0.6949 - val_roc_auc: 0.8433 - val_pr_auc: 0.8032 - val_cohen_kappa: 0.5072
# Epoch 30/100
# 256/256 [==============================] - 41s 159ms/step - loss: 0.3985 - tp: 1118.0000 - fp: 316.0000 - tn: 2208.0000 - fn: 442.0000 - binary_acc: 0.8144 - precision: 0.7796 - recall: 0.7167 - f1_score: 0.7468 - roc_auc: 0.8908 - pr_auc: 0.8430 - cohen_kappa: 0.6007 - val_loss: 0.4710 - val_tp: 256.0000 - val_fp: 84.0000 - val_tn: 530.0000 - val_fn: 152.0000 - val_binary_acc: 0.7691 - val_precision: 0.7529 - val_recall: 0.6275 - val_f1_score: 0.6845 - val_roc_auc: 0.8518 - val_pr_auc: 0.8159 - val_cohen_kappa: 0.5048
# Epoch 31/100
# 256/256 [==============================] - 41s 158ms/step - loss: 0.3908 - tp: 1120.0000 - fp: 311.0000 - tn: 2213.0000 - fn: 440.0000 - binary_acc: 0.8161 - precision: 0.7827 - recall: 0.7179 - f1_score: 0.7489 - roc_auc: 0.8957 - pr_auc: 0.8488 - cohen_kappa: 0.6043 - val_loss: 0.5262 - val_tp: 320.0000 - val_fp: 145.0000 - val_tn: 469.0000 - val_fn: 88.0000 - val_binary_acc: 0.7720 - val_precision: 0.6882 - val_recall: 0.7843 - val_f1_score: 0.7331 - val_roc_auc: 0.8455 - val_pr_auc: 0.7906 - val_cohen_kappa: 0.5356
# Epoch 32/100
# 256/256 [==============================] - 40s 157ms/step - loss: 0.3882 - tp: 1125.0000 - fp: 338.0000 - tn: 2186.0000 - fn: 435.0000 - binary_acc: 0.8107 - precision: 0.7690 - recall: 0.7212 - f1_score: 0.7443 - roc_auc: 0.8954 - pr_auc: 0.8541 - cohen_kappa: 0.5943 - val_loss: 0.4929 - val_tp: 277.0000 - val_fp: 98.0000 - val_tn: 516.0000 - val_fn: 131.0000 - val_binary_acc: 0.7759 - val_precision: 0.7387 - val_recall: 0.6789 - val_f1_score: 0.7075 - val_roc_auc: 0.8489 - val_pr_auc: 0.8046 - val_cohen_kappa: 0.5265
# Epoch 33/100
# 256/256 [==============================] - 40s 158ms/step - loss: 0.3890 - tp: 1134.0000 - fp: 317.0000 - tn: 2207.0000 - fn: 426.0000 - binary_acc: 0.8181 - precision: 0.7815 - recall: 0.7269 - f1_score: 0.7532 - roc_auc: 0.8957 - pr_auc: 0.8523 - cohen_kappa: 0.6095 - val_loss: 0.5062 - val_tp: 252.0000 - val_fp: 65.0000 - val_tn: 549.0000 - val_fn: 156.0000 - val_binary_acc: 0.7838 - val_precision: 0.7950 - val_recall: 0.6176 - val_f1_score: 0.6952 - val_roc_auc: 0.8497 - val_pr_auc: 0.8084 - val_cohen_kappa: 0.5317
# Epoch 34/100
# 256/256 [==============================] - 40s 158ms/step - loss: 0.3712 - tp: 1153.0000 - fp: 310.0000 - tn: 2214.0000 - fn: 407.0000 - binary_acc: 0.8244 - precision: 0.7881 - recall: 0.7391 - f1_score: 0.7628 - roc_auc: 0.9056 - pr_auc: 0.8671 - cohen_kappa: 0.6237 - val_loss: 0.5349 - val_tp: 204.0000 - val_fp: 51.0000 - val_tn: 563.0000 - val_fn: 204.0000 - val_binary_acc: 0.7505 - val_precision: 0.8000 - val_recall: 0.5000 - val_f1_score: 0.6154 - val_roc_auc: 0.8354 - val_pr_auc: 0.7870 - val_cohen_kappa: 0.4449
# Epoch 35/100
# 256/256 [==============================] - 40s 157ms/step - loss: 0.3623 - tp: 1174.0000 - fp: 305.0000 - tn: 2219.0000 - fn: 386.0000 - binary_acc: 0.8308 - precision: 0.7938 - recall: 0.7526 - f1_score: 0.7726 - roc_auc: 0.9110 - pr_auc: 0.8703 - cohen_kappa: 0.6381 - val_loss: 0.4961 - val_tp: 316.0000 - val_fp: 169.0000 - val_tn: 445.0000 - val_fn: 92.0000 - val_binary_acc: 0.7446 - val_precision: 0.6515 - val_recall: 0.7745 - val_f1_score: 0.7077 - val_roc_auc: 0.8477 - val_pr_auc: 0.8140 - val_cohen_kappa: 0.4839
# Epoch 36/100
# 256/256 [==============================] - 40s 156ms/step - loss: 0.3525 - tp: 1176.0000 - fp: 291.0000 - tn: 2233.0000 - fn: 384.0000 - binary_acc: 0.8347 - precision: 0.8016 - recall: 0.7538 - f1_score: 0.7770 - roc_auc: 0.9169 - pr_auc: 0.8779 - cohen_kappa: 0.6459 - val_loss: 0.5097 - val_tp: 305.0000 - val_fp: 140.0000 - val_tn: 474.0000 - val_fn: 103.0000 - val_binary_acc: 0.7622 - val_precision: 0.6854 - val_recall: 0.7475 - val_f1_score: 0.7151 - val_roc_auc: 0.8475 - val_pr_auc: 0.8031 - val_cohen_kappa: 0.5118
# Epoch 37/100
# 256/256 [==============================] - 40s 157ms/step - loss: 0.3590 - tp: 1183.0000 - fp: 308.0000 - tn: 2216.0000 - fn: 377.0000 - binary_acc: 0.8323 - precision: 0.7934 - recall: 0.7583 - f1_score: 0.7755 - roc_auc: 0.9131 - pr_auc: 0.8744 - cohen_kappa: 0.6417 - val_loss: 0.4821 - val_tp: 300.0000 - val_fp: 126.0000 - val_tn: 488.0000 - val_fn: 108.0000 - val_binary_acc: 0.7710 - val_precision: 0.7042 - val_recall: 0.7353 - val_f1_score: 0.7194 - val_roc_auc: 0.8491 - val_pr_auc: 0.8100 - val_cohen_kappa: 0.5262
# Epoch 38/100
# 256/256 [==============================] - 40s 158ms/step - loss: 0.3639 - tp: 1165.0000 - fp: 309.0000 - tn: 2215.0000 - fn: 395.0000 - binary_acc: 0.8276 - precision: 0.7904 - recall: 0.7468 - f1_score: 0.7680 - roc_auc: 0.9100 - pr_auc: 0.8702 - cohen_kappa: 0.6310 - val_loss: 0.5101 - val_tp: 244.0000 - val_fp: 68.0000 - val_tn: 546.0000 - val_fn: 164.0000 - val_binary_acc: 0.7730 - val_precision: 0.7821 - val_recall: 0.5980 - val_f1_score: 0.6778 - val_roc_auc: 0.8465 - val_pr_auc: 0.8044 - val_cohen_kappa: 0.5073
# Epoch 39/100
# 256/256 [==============================] - 40s 157ms/step - loss: 0.3635 - tp: 1188.0000 - fp: 294.0000 - tn: 2230.0000 - fn: 372.0000 - binary_acc: 0.8369 - precision: 0.8016 - recall: 0.7615 - f1_score: 0.7811 - roc_auc: 0.9116 - pr_auc: 0.8691 - cohen_kappa: 0.6513 - val_loss: 0.5032 - val_tp: 260.0000 - val_fp: 69.0000 - val_tn: 545.0000 - val_fn: 148.0000 - val_binary_acc: 0.7877 - val_precision: 0.7903 - val_recall: 0.6373 - val_f1_score: 0.7056 - val_roc_auc: 0.8589 - val_pr_auc: 0.8222 - val_cohen_kappa: 0.5425
# Epoch 40/100
# 256/256 [==============================] - 40s 158ms/step - loss: 0.3535 - tp: 1195.0000 - fp: 301.0000 - tn: 2223.0000 - fn: 365.0000 - binary_acc: 0.8369 - precision: 0.7988 - recall: 0.7660 - f1_score: 0.7821 - roc_auc: 0.9158 - pr_auc: 0.8726 - cohen_kappa: 0.6519 - val_loss: 0.4718 - val_tp: 270.0000 - val_fp: 75.0000 - val_tn: 539.0000 - val_fn: 138.0000 - val_binary_acc: 0.7916 - val_precision: 0.7826 - val_recall: 0.6618 - val_f1_score: 0.7171 - val_roc_auc: 0.8571 - val_pr_auc: 0.8171 - val_cohen_kappa: 0.5540
# Epoch 41/100
# 256/256 [==============================] - 40s 157ms/step - loss: 0.3518 - tp: 1190.0000 - fp: 317.0000 - tn: 2207.0000 - fn: 370.0000 - binary_acc: 0.8318 - precision: 0.7896 - recall: 0.7628 - f1_score: 0.7760 - roc_auc: 0.9155 - pr_auc: 0.8792 - cohen_kappa: 0.6414 - val_loss: 0.4757 - val_tp: 317.0000 - val_fp: 140.0000 - val_tn: 474.0000 - val_fn: 91.0000 - val_binary_acc: 0.7740 - val_precision: 0.6937 - val_recall: 0.7770 - val_f1_score: 0.7329 - val_roc_auc: 0.8612 - val_pr_auc: 0.8265 - val_cohen_kappa: 0.5381
# Epoch 42/100
# 256/256 [==============================] - 41s 159ms/step - loss: 0.3424 - tp: 1193.0000 - fp: 280.0000 - tn: 2244.0000 - fn: 367.0000 - binary_acc: 0.8416 - precision: 0.8099 - recall: 0.7647 - f1_score: 0.7867 - roc_auc: 0.9210 - pr_auc: 0.8841 - cohen_kappa: 0.6608 - val_loss: 0.4909 - val_tp: 261.0000 - val_fp: 69.0000 - val_tn: 545.0000 - val_fn: 147.0000 - val_binary_acc: 0.7886 - val_precision: 0.7909 - val_recall: 0.6397 - val_f1_score: 0.7073 - val_roc_auc: 0.8534 - val_pr_auc: 0.8014 - val_cohen_kappa: 0.5448
# Epoch 43/100
# 256/256 [==============================] - ETA: 0s - loss: 0.3366 - tp: 1180.0000 - fp: 276.0000 - tn: 2248.0000 - fn: 380.0000 - binary_acc: 0.8394 - precision: 0.8104 - recall: 0.7564 - f1_score: 0.7825 - roc_auc: 0.9230 - pr_auc: 0.8888 - cohen_kappa: 0.6554Restoring model weights from the end of the best epoch: 28.
# 256/256 [==============================] - 40s 157ms/step - loss: 0.3366 - tp: 1180.0000 - fp: 276.0000 - tn: 2248.0000 - fn: 380.0000 - binary_acc: 0.8394 - precision: 0.8104 - recall: 0.7564 - f1_score: 0.7825 - roc_auc: 0.9230 - pr_auc: 0.8888 - cohen_kappa: 0.6554 - val_loss: 0.5237 - val_tp: 303.0000 - val_fp: 125.0000 - val_tn: 489.0000 - val_fn: 105.0000 - val_binary_acc: 0.7750 - val_precision: 0.7079 - val_recall: 0.7426 - val_f1_score: 0.7249 - val_roc_auc: 0.8455 - val_pr_auc: 0.8003 - val_cohen_kappa: 0.5347
# Epoch 43: early stopping

# %%
new_model.save(save_path + model_name + '.keras')

plot_metrics(history)

# %%
new_model.evaluate(validation_generator)
new_model.evaluate(test_generator)

    # Make predictions using the validation generator
y_valid_pred_prob = new_model.predict(validation_generator)
y_valid_pred = (y_valid_pred_prob > 0.5).astype(int)
y_valid = validation_generator.classes
print("Classification Report:")
print(classification_report(y_valid, y_valid_pred))

y_pred_prob = new_model.predict(test_generator)
y_pred = (y_pred_prob > 0.5).astype(int)
y_test = test_generator.classes
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# 64/64 [==============================] - 8s 125ms/step - loss: 0.4815 - tp: 301.0000 - fp: 135.0000 - tn: 479.0000 - fn: 107.0000 - binary_acc: 0.7632 - precision: 0.6904 - recall: 0.7377 - f1_score: 0.7133 - roc_auc: 0.8494 - pr_auc: 0.8096 - cohen_kappa: 0.5120
# 29/29 [==============================] - 1s 47ms/step - loss: 0.6279 - tp: 162.0000 - fp: 56.0000 - tn: 158.0000 - fn: 85.0000 - binary_acc: 0.6941 - precision: 0.7431 - recall: 0.6559 - f1_score: 0.6968 - roc_auc: 0.7704 - pr_auc: 0.8054 - cohen_kappa: 0.3907
# 64/64 [==============================] - 9s 123ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.81      0.81       614
#            1       0.71      0.71      0.71       408
#
#     accuracy                           0.77      1022
#    macro avg       0.76      0.76      0.76      1022
# weighted avg       0.77      0.77      0.77      1022
#
# 29/29 [==============================] - 1s 38ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.65      0.74      0.69       214
#            1       0.74      0.66      0.70       247
#
#     accuracy                           0.69       461
#    macro avg       0.70      0.70      0.69       461
# weighted avg       0.70      0.69      0.69       461

# %%
conf_matrix = confusion_matrix(y_test, y_pred)

# Create ConfusionMatrixDisplay object
cm_display = ConfusionMatrixDisplay(confusion_matrix=conf_matrix)

# Plot the confusion matrix
plt.figure(figsize=(4, 6))  # Adjust the figure size as needed
cm_display.plot(cmap=plt.cm.Blues)  # You can choose any colormap you prefer
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.grid(False)  # Turn off grid
plt.savefig(save_path + model_name + "_confusion_matrix.jpg")
plt.show()

# %%
history_df = pd.DataFrame(history.history)
save_history(model_name, history_df)

new_model.save(save_path + model_name + "_pt_imagenet-{new_model.count_params()}.h5")
resnet.save(save_path + model_name + ".h5")

resnet.trainable = True

new_model.compile(
        optimizer=tf.keras.optimizers.Adam(
            1e-5
        ),  # we need small learning rate to avoid catastrophic forgetting
        loss=tf.keras.losses.BinaryCrossentropy(),
        metrics=METRICS,
    )

model_name = 'finetuned_' + architecture + "_" + target_category

model_path = save_path + '_best_' + model_name + '.keras'
model_checkpoint = ModelCheckpoint(filepath=model_path,
                                       monitor="val_cohen_kappa",
                                       save_best_only=True)

reduce_lr_on_plateau = tf.keras.callbacks.ReduceLROnPlateau(
        monitor="val_cohen_kappa",
        verbose=1,
        patience=4,
        mode="max",
        factor=0.2,
        min_lr=1e-10,
    )
# Out:
# Training history saved to: C:/Users/raouf/Desktop/pfe/history/final/resnet/XR_FINGER/ResNet_XR_FINGER_history.xlsx
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
history = new_model.fit(train_generator,
                            # steps_per_epoch=len(df_train) // batch_size,
                            validation_data=validation_generator,
                            # validation_steps=len(df_valid) // batch_size,
                            epochs=fine_tuning_epochs,
                            shuffle=shuffle,
                            callbacks=[early_stopping, model_checkpoint, reduce_lr_on_plateau])
# Out:
# Epoch 1/50
# 256/256 [==============================] - 51s 172ms/step - loss: 0.4065 - tp: 1269.0000 - fp: 394.0000 - tn: 2344.0000 - fn: 538.0000 - binary_acc: 0.7949 - precision: 0.7631 - recall: 0.7023 - f1_score: 0.7314 - roc_auc: 0.8760 - pr_auc: 0.8293 - cohen_kappa: 0.5660 - val_loss: 0.4630 - val_tp: 244.0000 - val_fp: 48.0000 - val_tn: 566.0000 - val_fn: 164.0000 - val_binary_acc: 0.7926 - val_precision: 0.8356 - val_recall: 0.5980 - val_f1_score: 0.6971 - val_roc_auc: 0.8633 - val_pr_auc: 0.8264 - val_cohen_kappa: 0.5459 - lr: 1.0000e-05
# Epoch 2/50
# 256/256 [==============================] - 43s 168ms/step - loss: 0.3714 - tp: 1123.0000 - fp: 277.0000 - tn: 2247.0000 - fn: 437.0000 - binary_acc: 0.8252 - precision: 0.8021 - recall: 0.7199 - f1_score: 0.7588 - roc_auc: 0.9060 - pr_auc: 0.8679 - cohen_kappa: 0.6223 - val_loss: 0.4425 - val_tp: 276.0000 - val_fp: 62.0000 - val_tn: 552.0000 - val_fn: 132.0000 - val_binary_acc: 0.8102 - val_precision: 0.8166 - val_recall: 0.6765 - val_f1_score: 0.7399 - val_roc_auc: 0.8688 - val_pr_auc: 0.8423 - val_cohen_kappa: 0.5925 - lr: 1.0000e-05
# Epoch 3/50
# 256/256 [==============================] - 43s 166ms/step - loss: 0.3510 - tp: 1171.0000 - fp: 266.0000 - tn: 2258.0000 - fn: 389.0000 - binary_acc: 0.8396 - precision: 0.8149 - recall: 0.7506 - f1_score: 0.7814 - roc_auc: 0.9159 - pr_auc: 0.8833 - cohen_kappa: 0.6551 - val_loss: 0.4391 - val_tp: 322.0000 - val_fp: 117.0000 - val_tn: 497.0000 - val_fn: 86.0000 - val_binary_acc: 0.8014 - val_precision: 0.7335 - val_recall: 0.7892 - val_f1_score: 0.7603 - val_roc_auc: 0.8773 - val_pr_auc: 0.8420 - val_cohen_kappa: 0.5911 - lr: 1.0000e-05
# Epoch 4/50
# 256/256 [==============================] - 45s 174ms/step - loss: 0.3462 - tp: 1176.0000 - fp: 270.0000 - tn: 2254.0000 - fn: 384.0000 - binary_acc: 0.8399 - precision: 0.8133 - recall: 0.7538 - f1_score: 0.7824 - roc_auc: 0.9182 - pr_auc: 0.8858 - cohen_kappa: 0.6560 - val_loss: 0.4462 - val_tp: 232.0000 - val_fp: 42.0000 - val_tn: 572.0000 - val_fn: 176.0000 - val_binary_acc: 0.7867 - val_precision: 0.8467 - val_recall: 0.5686 - val_f1_score: 0.6804 - val_roc_auc: 0.8747 - val_pr_auc: 0.8387 - val_cohen_kappa: 0.5294 - lr: 1.0000e-05
# Epoch 5/50
# 256/256 [==============================] - 43s 168ms/step - loss: 0.3168 - tp: 1207.0000 - fp: 234.0000 - tn: 2290.0000 - fn: 353.0000 - binary_acc: 0.8563 - precision: 0.8376 - recall: 0.7737 - f1_score: 0.8044 - roc_auc: 0.9334 - pr_auc: 0.9041 - cohen_kappa: 0.6911 - val_loss: 0.5086 - val_tp: 262.0000 - val_fp: 47.0000 - val_tn: 567.0000 - val_fn: 146.0000 - val_binary_acc: 0.8112 - val_precision: 0.8479 - val_recall: 0.6422 - val_f1_score: 0.7308 - val_roc_auc: 0.8623 - val_pr_auc: 0.8360 - val_cohen_kappa: 0.5896 - lr: 1.0000e-05
# Epoch 6/50
# 256/256 [==============================] - ETA: 0s - loss: 0.3036 - tp: 1239.0000 - fp: 233.0000 - tn: 2291.0000 - fn: 321.0000 - binary_acc: 0.8643 - precision: 0.8417 - recall: 0.7942 - f1_score: 0.8173 - roc_auc: 0.9388 - pr_auc: 0.9121 - cohen_kappa: 0.7096
# Epoch 6: ReduceLROnPlateau reducing learning rate to 1.9999999494757505e-06.
# 256/256 [==============================] - 43s 168ms/step - loss: 0.3036 - tp: 1239.0000 - fp: 233.0000 - tn: 2291.0000 - fn: 321.0000 - binary_acc: 0.8643 - precision: 0.8417 - recall: 0.7942 - f1_score: 0.8173 - roc_auc: 0.9388 - pr_auc: 0.9121 - cohen_kappa: 0.7096 - val_loss: 0.4571 - val_tp: 247.0000 - val_fp: 46.0000 - val_tn: 568.0000 - val_fn: 161.0000 - val_binary_acc: 0.7975 - val_precision: 0.8430 - val_recall: 0.6054 - val_f1_score: 0.7047 - val_roc_auc: 0.8710 - val_pr_auc: 0.8477 - val_cohen_kappa: 0.5568 - lr: 1.0000e-05
# Epoch 7/50
# 256/256 [==============================] - 44s 171ms/step - loss: 0.2447 - tp: 1298.0000 - fp: 166.0000 - tn: 2358.0000 - fn: 262.0000 - binary_acc: 0.8952 - precision: 0.8866 - recall: 0.8321 - f1_score: 0.8585 - roc_auc: 0.9631 - pr_auc: 0.9461 - cohen_kappa: 0.7754 - val_loss: 0.4449 - val_tp: 302.0000 - val_fp: 69.0000 - val_tn: 545.0000 - val_fn: 106.0000 - val_binary_acc: 0.8288 - val_precision: 0.8140 - val_recall: 0.7402 - val_f1_score: 0.7754 - val_roc_auc: 0.8786 - val_pr_auc: 0.8518 - val_cohen_kappa: 0.6375 - lr: 2.0000e-06
# Epoch 8/50
# 256/256 [==============================] - 44s 170ms/step - loss: 0.2193 - tp: 1327.0000 - fp: 144.0000 - tn: 2380.0000 - fn: 233.0000 - binary_acc: 0.9077 - precision: 0.9021 - recall: 0.8506 - f1_score: 0.8756 - roc_auc: 0.9700 - pr_auc: 0.9583 - cohen_kappa: 0.8023 - val_loss: 0.4356 - val_tp: 284.0000 - val_fp: 67.0000 - val_tn: 547.0000 - val_fn: 124.0000 - val_binary_acc: 0.8131 - val_precision: 0.8091 - val_recall: 0.6961 - val_f1_score: 0.7484 - val_roc_auc: 0.8841 - val_pr_auc: 0.8637 - val_cohen_kappa: 0.6010 - lr: 2.0000e-06
# Epoch 9/50
# 256/256 [==============================] - 44s 171ms/step - loss: 0.2133 - tp: 1334.0000 - fp: 135.0000 - tn: 2389.0000 - fn: 226.0000 - binary_acc: 0.9116 - precision: 0.9081 - recall: 0.8551 - f1_score: 0.8808 - roc_auc: 0.9713 - pr_auc: 0.9591 - cohen_kappa: 0.8107 - val_loss: 0.4591 - val_tp: 301.0000 - val_fp: 92.0000 - val_tn: 522.0000 - val_fn: 107.0000 - val_binary_acc: 0.8053 - val_precision: 0.7659 - val_recall: 0.7377 - val_f1_score: 0.7516 - val_roc_auc: 0.8817 - val_pr_auc: 0.8581 - val_cohen_kappa: 0.5916 - lr: 2.0000e-06
# Epoch 10/50
# 256/256 [==============================] - 44s 171ms/step - loss: 0.1957 - tp: 1359.0000 - fp: 128.0000 - tn: 2396.0000 - fn: 201.0000 - binary_acc: 0.9194 - precision: 0.9139 - recall: 0.8712 - f1_score: 0.8920 - roc_auc: 0.9767 - pr_auc: 0.9666 - cohen_kappa: 0.8278 - val_loss: 0.4512 - val_tp: 272.0000 - val_fp: 55.0000 - val_tn: 559.0000 - val_fn: 136.0000 - val_binary_acc: 0.8131 - val_precision: 0.8318 - val_recall: 0.6667 - val_f1_score: 0.7401 - val_roc_auc: 0.8888 - val_pr_auc: 0.8631 - val_cohen_kappa: 0.5970 - lr: 2.0000e-06
# Epoch 11/50
# 256/256 [==============================] - ETA: 0s - loss: 0.1914 - tp: 1373.0000 - fp: 126.0000 - tn: 2398.0000 - fn: 187.0000 - binary_acc: 0.9234 - precision: 0.9159 - recall: 0.8801 - f1_score: 0.8977 - roc_auc: 0.9775 - pr_auc: 0.9670 - cohen_kappa: 0.8365
# Epoch 11: ReduceLROnPlateau reducing learning rate to 3.999999989900971e-07.
# 256/256 [==============================] - 45s 174ms/step - loss: 0.1914 - tp: 1373.0000 - fp: 126.0000 - tn: 2398.0000 - fn: 187.0000 - binary_acc: 0.9234 - precision: 0.9159 - recall: 0.8801 - f1_score: 0.8977 - roc_auc: 0.9775 - pr_auc: 0.9670 - cohen_kappa: 0.8365 - val_loss: 0.4743 - val_tp: 301.0000 - val_fp: 95.0000 - val_tn: 519.0000 - val_fn: 107.0000 - val_binary_acc: 0.8023 - val_precision: 0.7601 - val_recall: 0.7377 - val_f1_score: 0.7488 - val_roc_auc: 0.8782 - val_pr_auc: 0.8528 - val_cohen_kappa: 0.5859 - lr: 2.0000e-06
# Epoch 12/50
# 256/256 [==============================] - 44s 171ms/step - loss: 0.1695 - tp: 1394.0000 - fp: 112.0000 - tn: 2412.0000 - fn: 166.0000 - binary_acc: 0.9319 - precision: 0.9256 - recall: 0.8936 - f1_score: 0.9093 - roc_auc: 0.9832 - pr_auc: 0.9753 - cohen_kappa: 0.8549 - val_loss: 0.4632 - val_tp: 286.0000 - val_fp: 82.0000 - val_tn: 532.0000 - val_fn: 122.0000 - val_binary_acc: 0.8004 - val_precision: 0.7772 - val_recall: 0.7010 - val_f1_score: 0.7371 - val_roc_auc: 0.8845 - val_pr_auc: 0.8608 - val_cohen_kappa: 0.5769 - lr: 4.0000e-07
# Epoch 13/50
# 256/256 [==============================] - 45s 177ms/step - loss: 0.1788 - tp: 1396.0000 - fp: 128.0000 - tn: 2396.0000 - fn: 164.0000 - binary_acc: 0.9285 - precision: 0.9160 - recall: 0.8949 - f1_score: 0.9053 - roc_auc: 0.9811 - pr_auc: 0.9717 - cohen_kappa: 0.8479 - val_loss: 0.4643 - val_tp: 290.0000 - val_fp: 82.0000 - val_tn: 532.0000 - val_fn: 118.0000 - val_binary_acc: 0.8043 - val_precision: 0.7796 - val_recall: 0.7108 - val_f1_score: 0.7436 - val_roc_auc: 0.8815 - val_pr_auc: 0.8544 - val_cohen_kappa: 0.5859 - lr: 4.0000e-07
# Epoch 14/50
# 256/256 [==============================] - 44s 171ms/step - loss: 0.1692 - tp: 1386.0000 - fp: 106.0000 - tn: 2418.0000 - fn: 174.0000 - binary_acc: 0.9314 - precision: 0.9290 - recall: 0.8885 - f1_score: 0.9083 - roc_auc: 0.9833 - pr_auc: 0.9757 - cohen_kappa: 0.8536 - val_loss: 0.4336 - val_tp: 298.0000 - val_fp: 73.0000 - val_tn: 541.0000 - val_fn: 110.0000 - val_binary_acc: 0.8209 - val_precision: 0.8032 - val_recall: 0.7304 - val_f1_score: 0.7651 - val_roc_auc: 0.8921 - val_pr_auc: 0.8705 - val_cohen_kappa: 0.6209 - lr: 4.0000e-07
# Epoch 15/50
# 256/256 [==============================] - ETA: 0s - loss: 0.1728 - tp: 1392.0000 - fp: 116.0000 - tn: 2408.0000 - fn: 168.0000 - binary_acc: 0.9305 - precision: 0.9231 - recall: 0.8923 - f1_score: 0.9074 - roc_auc: 0.9822 - pr_auc: 0.9733 - cohen_kappa: 0.8518
# Epoch 15: ReduceLROnPlateau reducing learning rate to 8.00000009348878e-08.
# 256/256 [==============================] - 45s 174ms/step - loss: 0.1728 - tp: 1392.0000 - fp: 116.0000 - tn: 2408.0000 - fn: 168.0000 - binary_acc: 0.9305 - precision: 0.9231 - recall: 0.8923 - f1_score: 0.9074 - roc_auc: 0.9822 - pr_auc: 0.9733 - cohen_kappa: 0.8518 - val_loss: 0.4781 - val_tp: 299.0000 - val_fp: 82.0000 - val_tn: 532.0000 - val_fn: 109.0000 - val_binary_acc: 0.8131 - val_precision: 0.7848 - val_recall: 0.7328 - val_f1_score: 0.7579 - val_roc_auc: 0.8777 - val_pr_auc: 0.8586 - val_cohen_kappa: 0.6060 - lr: 4.0000e-07
# Epoch 16/50
# 256/256 [==============================] - 44s 171ms/step - loss: 0.1709 - tp: 1401.0000 - fp: 120.0000 - tn: 2404.0000 - fn: 159.0000 - binary_acc: 0.9317 - precision: 0.9211 - recall: 0.8981 - f1_score: 0.9094 - roc_auc: 0.9827 - pr_auc: 0.9744 - cohen_kappa: 0.8546 - val_loss: 0.4641 - val_tp: 302.0000 - val_fp: 76.0000 - val_tn: 538.0000 - val_fn: 106.0000 - val_binary_acc: 0.8219 - val_precision: 0.7989 - val_recall: 0.7402 - val_f1_score: 0.7684 - val_roc_auc: 0.8815 - val_pr_auc: 0.8597 - val_cohen_kappa: 0.6241 - lr: 8.0000e-08
# Epoch 17/50
# 256/256 [==============================] - 44s 173ms/step - loss: 0.1685 - tp: 1406.0000 - fp: 105.0000 - tn: 2419.0000 - fn: 154.0000 - binary_acc: 0.9366 - precision: 0.9305 - recall: 0.9013 - f1_score: 0.9157 - roc_auc: 0.9829 - pr_auc: 0.9750 - cohen_kappa: 0.8649 - val_loss: 0.4628 - val_tp: 290.0000 - val_fp: 61.0000 - val_tn: 553.0000 - val_fn: 118.0000 - val_binary_acc: 0.8249 - val_precision: 0.8262 - val_recall: 0.7108 - val_f1_score: 0.7642 - val_roc_auc: 0.8868 - val_pr_auc: 0.8657 - val_cohen_kappa: 0.6261 - lr: 8.0000e-08
# Epoch 18/50
# 256/256 [==============================] - 45s 176ms/step - loss: 0.1678 - tp: 1402.0000 - fp: 101.0000 - tn: 2423.0000 - fn: 158.0000 - binary_acc: 0.9366 - precision: 0.9328 - recall: 0.8987 - f1_score: 0.9154 - roc_auc: 0.9834 - pr_auc: 0.9748 - cohen_kappa: 0.8647 - val_loss: 0.4664 - val_tp: 296.0000 - val_fp: 82.0000 - val_tn: 532.0000 - val_fn: 112.0000 - val_binary_acc: 0.8102 - val_precision: 0.7831 - val_recall: 0.7255 - val_f1_score: 0.7532 - val_roc_auc: 0.8856 - val_pr_auc: 0.8587 - val_cohen_kappa: 0.5993 - lr: 8.0000e-08
# Epoch 19/50
# 256/256 [==============================] - ETA: 0s - loss: 0.1704 - tp: 1379.0000 - fp: 116.0000 - tn: 2408.0000 - fn: 181.0000 - binary_acc: 0.9273 - precision: 0.9224 - recall: 0.8840 - f1_score: 0.9028 - roc_auc: 0.9825 - pr_auc: 0.9749 - cohen_kappa: 0.8447
# Epoch 19: ReduceLROnPlateau reducing learning rate to 1.5999999902760466e-08.
# 256/256 [==============================] - 45s 174ms/step - loss: 0.1704 - tp: 1379.0000 - fp: 116.0000 - tn: 2408.0000 - fn: 181.0000 - binary_acc: 0.9273 - precision: 0.9224 - recall: 0.8840 - f1_score: 0.9028 - roc_auc: 0.9825 - pr_auc: 0.9749 - cohen_kappa: 0.8447 - val_loss: 0.4501 - val_tp: 301.0000 - val_fp: 75.0000 - val_tn: 539.0000 - val_fn: 107.0000 - val_binary_acc: 0.8219 - val_precision: 0.8005 - val_recall: 0.7377 - val_f1_score: 0.7679 - val_roc_auc: 0.8892 - val_pr_auc: 0.8611 - val_cohen_kappa: 0.6238 - lr: 8.0000e-08
# Epoch 20/50
# 256/256 [==============================] - 44s 172ms/step - loss: 0.1712 - tp: 1389.0000 - fp: 101.0000 - tn: 2423.0000 - fn: 171.0000 - binary_acc: 0.9334 - precision: 0.9322 - recall: 0.8904 - f1_score: 0.9108 - roc_auc: 0.9818 - pr_auc: 0.9742 - cohen_kappa: 0.8577 - val_loss: 0.4601 - val_tp: 299.0000 - val_fp: 75.0000 - val_tn: 539.0000 - val_fn: 109.0000 - val_binary_acc: 0.8200 - val_precision: 0.7995 - val_recall: 0.7328 - val_f1_score: 0.7647 - val_roc_auc: 0.8881 - val_pr_auc: 0.8598 - val_cohen_kappa: 0.6194 - lr: 1.6000e-08
# Epoch 21/50
# 256/256 [==============================] - 44s 170ms/step - loss: 0.1759 - tp: 1392.0000 - fp: 112.0000 - tn: 2412.0000 - fn: 168.0000 - binary_acc: 0.9314 - precision: 0.9255 - recall: 0.8923 - f1_score: 0.9086 - roc_auc: 0.9808 - pr_auc: 0.9720 - cohen_kappa: 0.8538 - val_loss: 0.4650 - val_tp: 293.0000 - val_fp: 70.0000 - val_tn: 544.0000 - val_fn: 115.0000 - val_binary_acc: 0.8190 - val_precision: 0.8072 - val_recall: 0.7181 - val_f1_score: 0.7601 - val_roc_auc: 0.8834 - val_pr_auc: 0.8598 - val_cohen_kappa: 0.6155 - lr: 1.6000e-08
# Epoch 22/50
# 256/256 [==============================] - ETA: 0s - loss: 0.1642 - tp: 1386.0000 - fp: 97.0000 - tn: 2427.0000 - fn: 174.0000 - binary_acc: 0.9336 - precision: 0.9346 - recall: 0.8885 - f1_score: 0.9109 - roc_auc: 0.9846 - pr_auc: 0.9766 - cohen_kappa: 0.8581Restoring model weights from the end of the best epoch: 7.
# 256/256 [==============================] - 44s 172ms/step - loss: 0.1642 - tp: 1386.0000 - fp: 97.0000 - tn: 2427.0000 - fn: 174.0000 - binary_acc: 0.9336 - precision: 0.9346 - recall: 0.8885 - f1_score: 0.9109 - roc_auc: 0.9846 - pr_auc: 0.9766 - cohen_kappa: 0.8581 - val_loss: 0.4444 - val_tp: 299.0000 - val_fp: 70.0000 - val_tn: 544.0000 - val_fn: 109.0000 - val_binary_acc: 0.8249 - val_precision: 0.8103 - val_recall: 0.7328 - val_f1_score: 0.7696 - val_roc_auc: 0.8908 - val_pr_auc: 0.8686 - val_cohen_kappa: 0.6289 - lr: 1.6000e-08
# Epoch 22: early stopping

# %%
new_model.save(save_path + model_name + '.keras')
plot_metrics(history)

# %%
new_model.evaluate(validation_generator)
new_model.evaluate(test_generator)

# Make predictions using the validation generator
y_valid_pred_prob = new_model.predict(validation_generator)
y_valid_pred = (y_valid_pred_prob > 0.5).astype(int)
y_valid = validation_generator.classes
print("Classification Report:")
print(classification_report(y_valid, y_valid_pred))

# Make predictions using the test generator
y_pred_prob = new_model.predict(test_generator)
y_pred = (y_pred_prob > 0.5).astype(int)
y_test = test_generator.classes
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# 64/64 [==============================] - 8s 130ms/step - loss: 0.4541 - tp: 282.0000 - fp: 86.0000 - tn: 528.0000 - fn: 126.0000 - binary_acc: 0.7926 - precision: 0.7663 - recall: 0.6912 - f1_score: 0.7268 - roc_auc: 0.8759 - pr_auc: 0.8434 - cohen_kappa: 0.5603
# 29/29 [==============================] - 1s 42ms/step - loss: 0.6561 - tp: 158.0000 - fp: 33.0000 - tn: 181.0000 - fn: 89.0000 - binary_acc: 0.7354 - precision: 0.8272 - recall: 0.6397 - f1_score: 0.7215 - roc_auc: 0.8213 - pr_auc: 0.8602 - cohen_kappa: 0.4771
# 64/64 [==============================] - 9s 127ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.87      0.85       614
#            1       0.79      0.73      0.76       408
#
#     accuracy                           0.82      1022
#    macro avg       0.81      0.80      0.80      1022
# weighted avg       0.81      0.82      0.81      1022
#
# 29/29 [==============================] - 1s 38ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.67      0.85      0.75       214
#            1       0.83      0.64      0.72       247
#
#     accuracy                           0.74       461
#    macro avg       0.75      0.74      0.73       461
# weighted avg       0.75      0.74      0.73       461

# %%
conf_matrix = confusion_matrix(y_test, y_pred)

# Create ConfusionMatrixDisplay object
cm_display = ConfusionMatrixDisplay(confusion_matrix=conf_matrix)

# Plot the confusion matrix
plt.figure(figsize=(4, 6))  # Adjust the figure size as needed
cm_display.plot(cmap=plt.cm.Blues)  # You can choose any colormap you prefer
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.grid(False)  # Turn off grid
plt.savefig(save_path + model_name + "_confusion_matrix.jpg")
plt.show()

# %%
history_df = pd.DataFrame(history.history)
save_history(model_name, history_df)
# Out:
# Training history saved to: C:/Users/raouf/Desktop/pfe/history/final/resnet/XR_FINGER/finetuned_ResNet_XR_FINGER_history.xlsx
