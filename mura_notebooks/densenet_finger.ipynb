# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
import tensorflow as tf
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras import layers, models
from keras.layers import concatenate, Dense, Conv2D, MaxPooling2D, Flatten, Activation, BatchNormalization, Dropout, \
    Attention
from keras import *
from keras.applications import MobileNet
from keras.applications import VGG16
from keras.applications.resnet import ResNet50
from keras import backend as K
from keras.layers import Layer
import keras.layers as kl
import pandas as pd
from keras.applications import EfficientNetB0
import keras.applications
import numpy as np
import os
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from sklearn.metrics import cohen_kappa_score
import seaborn as sns
import pickle
import tensorflow_addons as tfa
from sklearn import metrics
from tensorflow.keras.applications.resnet import preprocess_input as preprocess_input_resnet
from tensorflow.keras.applications.densenet import preprocess_input as preprocess_input_densenet
from tensorflow.keras.models import load_model
import os
import glob
# Out:
# c:\Users\raouf\miniconda3\envs\tensorflowgpu\lib\site-packages\tensorflow_addons\utils\tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# c:\Users\raouf\miniconda3\envs\tensorflowgpu\lib\site-packages\tensorflow_addons\utils\ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.12.0 and strictly below 2.15.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.10.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %%
main_save_path = "C:/Users/raouf/Desktop/pfe/history/final/densenet/"
mura_location = "C:/Users/raouf/Desktop/pfe/"
data_path = 'C:/Users/raouf/Desktop/pfe/MURA-v1.1/'
train_path = 'C:/Users/raouf/Desktop/pfe/MURA-v1.1/train'
test_path = 'C:/Users/raouf/Desktop/pfe/MURA-v1.1/valid'

train_file = "C:/Users/raouf/Desktop/pfe/datasets/XR_FINGER_df_train.csv"
val_file = "C:/Users/raouf/Desktop/pfe/datasets/XR_FINGER_df_valid.csv"

test_file = "C:/Users/raouf/Desktop/pfe/MURA-v1.1/valid_image_paths.csv"

target_category = "XR_FINGER"
batch_size = 16
num_epochs = 100
fine_tuning_epochs=50
validation_split = 0.2
loss_function = tf.keras.losses.BinaryCrossentropy()
learning_rate = 0.0001
input_shape = (224, 224, 3)
architecture = 'DenseNet'

include_top = False
# metrics=["accuracy"] #, tf.keras.metrics.Precision(), tf.keras.metrics.Recall()
early_stopping_patience = 15
shuffle = True
class_mode = 'binary'  # 'categorical'
IMAGE_WIDTH = 224
IMAGE_HEIGHT = 224
trainable = False
training = False
dropout = 0.2

# %%
def load_data(file, part):
    train_data = pd.read_csv(file)
    train_data = train_data.rename(columns={train_data.columns[0]: 'image_path'})
    train_data['label'] = 2
    string_to_add = mura_location
    train_data['image_path'] = string_to_add + train_data['image_path'].astype(str)
    for index, row in train_data.iterrows():
        if 'positive' in str(row['image_path']).lower():
            train_data.at[index, 'label'] = "positive"
        else:
            train_data.at[index, 'label'] = "negative"

    if part == 0:
        pass
    else:
        train_data = train_data[train_data['image_path'].str.contains(part)]
    return train_data


class CustomCallback(keras.callbacks.Callback):
    def on_test_end(self, logs=None):
        keys = list(logs.keys())
        print(f"tp          :", logs["tp"])
        print(f"fp          :", logs["fp"])
        print(f"tn          :", logs["tn"])
        print(f"fn          :", logs["fn"])
        print(f"binary_acc  :", logs["binary_acc"])
        print(f"precision   :", logs["precision"])
        print(f"recall      :", logs["recall"])
        print(f"f1_score    :", logs["f1_score"])
        print(f"roc_auc     :", logs["roc_auc"])
        print(f"pr_auc      :", logs["pr_auc"])
        print(f"cohen_kappa :", logs["cohen_kappa"])

class F1Score(tf.keras.metrics.Metric):

    def __init__(self, name="f1_score", **kwargs):
        super().__init__(name=name, **kwargs)
        self.f1 = self.add_weight(name="f1", initializer="zeros")
        self.precision_fn = tf.keras.metrics.Precision()
        self.recall_fn = tf.keras.metrics.Recall()

    def update_state(self, y_true, y_pred, sample_weight=None):
        p = self.precision_fn(y_true, y_pred)
        r = self.recall_fn(y_true, y_pred)
        self.f1.assign(2 * ((p * r) / (p + r + 1e-10)))

    def result(self):
        return self.f1

    def reset_state(self):
        # we also need to reset the state of the precision and recall objects
        self.precision_fn.reset_state()
        self.recall_fn.reset_state()
        self.f1.assign(0)


def save_history(name,history_df):

    history_excel_path = (
            save_path +
            name +
            '_history'
            '.xlsx'
    )

    history_df.to_excel(history_excel_path, index=False)
    print("Training history saved to:", history_excel_path)






def plot_metrics(history: tf.keras.callbacks.History,
                 metrics: list = ["loss", "cohen_kappa", "precision", "recall"],
                 ) -> None:
    plt.rcParams["figure.figsize"] = (18, 15)

    for n, metric in enumerate(metrics):
        name = metric.replace("_", " ").capitalize()
        plt.subplot(2, 2, n + 1)
        plt.plot(
            history.epoch, history.history[metric], linewidth=1.8, label="training"
        )
        plt.plot(
            history.epoch,
            history.history["val_" + metric],
            linestyle="--",
            linewidth=1.8,
            label="validation",
        )
        plt.xlabel("epoch")
        plt.ylabel(name)
        if metric == "loss":
            plt.ylim([0, plt.ylim()[1]])
        elif metric == "cohen_kappa":
            plt.ylim([-1, 1])
        else:
            plt.ylim([0, 1])

        plt.legend()



class CustomCallback(keras.callbacks.Callback):
    def on_test_end(self, logs=None):
        keys = list(logs.keys())
        print(f"tp          :", logs["tp"])
        print(f"fp          :", logs["fp"])
        print(f"tn          :", logs["tn"])
        print(f"fn          :", logs["fn"])
        print(f"binary_acc  :", logs["binary_acc"])
        print(f"precision   :", logs["precision"])
        print(f"recall      :", logs["recall"])
        print(f"f1_score    :", logs["f1_score"])
        print(f"roc_auc     :", logs["roc_auc"])
        print(f"pr_auc      :", logs["pr_auc"])
        print(f"cohen_kappa :", logs["cohen_kappa"])


def save_history(name,history_df):

    # Constructing the file name with metric values
    history_excel_path = (
            save_path +
            name +
            '_history'
            '.xlsx'
    )

    history_df.to_excel(history_excel_path, index=False)
    print("Training history saved to:", history_excel_path)




class F1Score(tf.keras.metrics.Metric):

    def __init__(self, name="f1_score", **kwargs):
        super().__init__(name=name, **kwargs)
        self.f1 = self.add_weight(name="f1", initializer="zeros")
        self.precision_fn = tf.keras.metrics.Precision()
        self.recall_fn = tf.keras.metrics.Recall()

    def update_state(self, y_true, y_pred, sample_weight=None):
        p = self.precision_fn(y_true, y_pred)
        r = self.recall_fn(y_true, y_pred)
        self.f1.assign(2 * ((p * r) / (p + r + 1e-10)))

    def result(self):
        return self.f1

    def reset_state(self):
        # we also need to reset the state of the precision and recall objects
        self.precision_fn.reset_state()
        self.recall_fn.reset_state()
        self.f1.assign(0)

def plot_metrics(history: tf.keras.callbacks.History,
                 metrics: list = ["loss", "cohen_kappa", "precision", "recall"],
                 ) -> None:
    plt.rcParams["figure.figsize"] = (18, 15)

    for n, metric in enumerate(metrics):
        name = metric.replace("_", " ").capitalize()
        plt.subplot(2, 2, n + 1)
        plt.plot(
            history.epoch, history.history[metric], linewidth=1.8, label="training"
        )
        plt.plot(
            history.epoch,
            history.history["val_" + metric],
            linestyle="--",
            linewidth=1.8,
            label="validation",
        )
        plt.xlabel("epoch")
        plt.ylabel(name)
        if metric == "loss":
            plt.ylim([0, plt.ylim()[1]])
        elif metric == "cohen_kappa":
            plt.ylim([-1, 1])
        else:
            plt.ylim([0, 1])

        plt.legend()


def my_func(model, data_generator, threshold=0.5):
    y_pred_prob = model.predict(data_generator)
    y_pred = (y_pred_prob > threshold).astype(int)
    y_true = data_generator.classes
    print("Classification Report:")
    print(classification_report(y_true, y_pred))

# %%
METRICS = [
    tf.keras.metrics.TruePositives(name="tp"),
    tf.keras.metrics.FalsePositives(name="fp"),
    tf.keras.metrics.TrueNegatives(name="tn"),
    tf.keras.metrics.FalseNegatives(name="fn"),
    tf.keras.metrics.BinaryAccuracy(name="binary_acc"),
    tf.keras.metrics.Precision(name="precision"),
    tf.keras.metrics.Recall(name="recall"),
    F1Score(name="f1_score"),
    tf.keras.metrics.AUC(name="roc_auc", curve="ROC"),
    tf.keras.metrics.AUC(name="pr_auc", curve="PR"),
    tfa.metrics.CohenKappa(name="cohen_kappa", num_classes=2),
]

# %%
densenet = tf.keras.applications.densenet.DenseNet201(
    include_top=False,  # do not include the fully-connected layer at the top of the network
    weights="imagenet",
    input_shape=(IMAGE_WIDTH, IMAGE_HEIGHT, 3),
    pooling="max",  # pooling mode for feature extraction
    classes=2,
)

def make_densenet_model(base_model: tf.keras.applications.densenet.DenseNet201) -> tf.keras.Model:

    # freeze base model
    base_model.trainable = trainable

    inputs = tf.keras.Input(shape=(IMAGE_WIDTH, IMAGE_HEIGHT, 3))
    x = base_model(inputs, training=training)
    x = tf.keras.layers.Dense(1024, activation='relu')(x)
    x = tf.keras.layers.Dropout(rate=dropout)(x)
    x = tf.keras.layers.Dense(512, activation='relu')(x)

    output = tf.keras.layers.Dense(units=1, activation="sigmoid")(x)

    model = tf.keras.Model(inputs, output)

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
        loss=tf.keras.losses.BinaryCrossentropy(),
        metrics=METRICS,
    )


    return model


new_model = make_densenet_model(base_model=densenet)

new_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  densenet201 (Functional)    (None, 1920)              18321984
#
#  dense (Dense)               (None, 1024)              1967104
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  dense_2 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 20,814,401
# Trainable params: 2,492,417
# Non-trainable params: 18,321,984
# _________________________________________________________________

# %%
"""import matplotlib.pyplot as plt
from tensorflow.keras.utils import plot_model
tf.keras.utils.plot_model(new_model,
                          show_shapes=True,  # show_dtype=False,
                          show_layer_names=True,
                          layer_range=None,
                          show_layer_activations=True)"""
# Out:
# 'import matplotlib.pyplot as plt\nfrom tensorflow.keras.utils import plot_model\ntf.keras.utils.plot_model(new_model,\n                          show_shapes=True,  # show_dtype=False,\n                          show_layer_names=True,\n                          layer_range=None,\n                          show_layer_activations=True)'

# %%
early_stopping = EarlyStopping(monitor="val_cohen_kappa",
                               verbose=1,
                               patience=early_stopping_patience,
                               mode="max",
                               baseline=0.0,
                               restore_best_weights=True)
save_path = main_save_path + target_category + "/"
model_name = architecture + "_" + target_category
model_path = save_path + '_best_' + model_name + '.keras'
model_checkpoint = ModelCheckpoint(filepath=model_path,
                                       monitor="val_cohen_kappa",
                                       save_best_only=True)

# %%
import pandas as pd


old_base_path = 'C:\\Users\\HP\\Documents\\ML\\encadrement Master\\MURA-V1.1\\'

df_train = pd.read_csv(train_file)
df_train['image_path'] = df_train['image_path'].str.replace(old_base_path, mura_location)

df_valid = pd.read_csv(val_file)
df_valid['image_path'] = df_valid['image_path'].str.replace(old_base_path, mura_location)


df_test = load_data(test_file, target_category)

datagen = tf.keras.preprocessing.image.ImageDataGenerator(rotation_range=30,
                                                              horizontal_flip=True,
                                                              fill_mode="constant",
                                                              cval=0.0,
                                                              preprocessing_function=tf.keras.applications.densenet.preprocess_input)
train_generator = datagen.flow_from_dataframe(df_train,
                                                  directory=None,
                                                  x_col='image_path',
                                                  y_col='label',
                                                  target_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
                                                  batch_size=batch_size,
                                                  class_mode=class_mode,
                                                  )

validation_generator = datagen.flow_from_dataframe(df_valid,
                                                       directory=None,
                                                       x_col='image_path',
                                                       y_col='label',
                                                       target_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
                                                       batch_size=batch_size,
                                                       class_mode=class_mode,
                                                   shuffle=False
                                                       )

test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
        preprocessing_function=tf.keras.applications.densenet.preprocess_input)
test_generator = test_datagen.flow_from_dataframe(df_test,
                                                      directory=None,
                                                      x_col='image_path',
                                                      y_col='label',
                                                      target_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
                                                      batch_size=batch_size,
                                                      class_mode=class_mode,
                                                  shuffle=False
                                                      )
# Out:
# C:\Users\raouf\AppData\Local\Temp\ipykernel_11660\1983201427.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'positive' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_data.at[index, 'label'] = "positive"
# Found 4084 validated image filenames belonging to 2 classes.
# Found 1022 validated image filenames belonging to 2 classes.
# Found 461 validated image filenames belonging to 2 classes.

# %%
history = new_model.fit(train_generator,
                            # teps_per_epoch=len(df_train) // batch_size,
                            validation_data=validation_generator,
                            # validation_steps=len(df_valid) // batch_size,
                            epochs=num_epochs,
                            shuffle=shuffle,
                            callbacks=[early_stopping, model_checkpoint])  # , reduce_lr_callback])
# Out:
# Epoch 1/100
# 256/256 [==============================] - 57s 180ms/step - loss: 0.6837 - tp: 803.0000 - fp: 612.0000 - tn: 1912.0000 - fn: 757.0000 - binary_acc: 0.6648 - precision: 0.5675 - recall: 0.5147 - f1_score: 0.5398 - roc_auc: 0.7048 - pr_auc: 0.5783 - cohen_kappa: 0.2772 - val_loss: 0.6356 - val_tp: 356.0000 - val_fp: 288.0000 - val_tn: 326.0000 - val_fn: 52.0000 - val_binary_acc: 0.6673 - val_precision: 0.5528 - val_recall: 0.8725 - val_f1_score: 0.6768 - val_roc_auc: 0.7950 - val_pr_auc: 0.7295 - val_cohen_kappa: 0.3678
# Epoch 2/100
# 256/256 [==============================] - 41s 162ms/step - loss: 0.5704 - tp: 880.0000 - fp: 523.0000 - tn: 2001.0000 - fn: 680.0000 - binary_acc: 0.7054 - precision: 0.6272 - recall: 0.5641 - f1_score: 0.5940 - roc_auc: 0.7671 - pr_auc: 0.6590 - cohen_kappa: 0.3639 - val_loss: 0.5546 - val_tp: 156.0000 - val_fp: 27.0000 - val_tn: 587.0000 - val_fn: 252.0000 - val_binary_acc: 0.7270 - val_precision: 0.8525 - val_recall: 0.3824 - val_f1_score: 0.5279 - val_roc_auc: 0.8181 - val_pr_auc: 0.7675 - val_cohen_kappa: 0.3729
# Epoch 3/100
# 256/256 [==============================] - 42s 165ms/step - loss: 0.5621 - tp: 892.0000 - fp: 506.0000 - tn: 2018.0000 - fn: 668.0000 - binary_acc: 0.7125 - precision: 0.6381 - recall: 0.5718 - f1_score: 0.6031 - roc_auc: 0.7722 - pr_auc: 0.6841 - cohen_kappa: 0.3788 - val_loss: 0.4968 - val_tp: 266.0000 - val_fp: 119.0000 - val_tn: 495.0000 - val_fn: 142.0000 - val_binary_acc: 0.7446 - val_precision: 0.6909 - val_recall: 0.6520 - val_f1_score: 0.6709 - val_roc_auc: 0.8256 - val_pr_auc: 0.7679 - val_cohen_kappa: 0.4625
# Epoch 4/100
# 256/256 [==============================] - 43s 170ms/step - loss: 0.5239 - tp: 929.0000 - fp: 439.0000 - tn: 2085.0000 - fn: 631.0000 - binary_acc: 0.7380 - precision: 0.6791 - recall: 0.5955 - f1_score: 0.6346 - roc_auc: 0.8027 - pr_auc: 0.7045 - cohen_kappa: 0.4317 - val_loss: 0.5380 - val_tp: 343.0000 - val_fp: 232.0000 - val_tn: 382.0000 - val_fn: 65.0000 - val_binary_acc: 0.7094 - val_precision: 0.5965 - val_recall: 0.8407 - val_f1_score: 0.6979 - val_roc_auc: 0.8234 - val_pr_auc: 0.7734 - val_cohen_kappa: 0.4331
# Epoch 5/100
# 256/256 [==============================] - 43s 168ms/step - loss: 0.5137 - tp: 953.0000 - fp: 462.0000 - tn: 2062.0000 - fn: 607.0000 - binary_acc: 0.7382 - precision: 0.6735 - recall: 0.6109 - f1_score: 0.6407 - roc_auc: 0.8090 - pr_auc: 0.7265 - cohen_kappa: 0.4356 - val_loss: 0.5027 - val_tp: 268.0000 - val_fp: 116.0000 - val_tn: 498.0000 - val_fn: 140.0000 - val_binary_acc: 0.7495 - val_precision: 0.6979 - val_recall: 0.6569 - val_f1_score: 0.6768 - val_roc_auc: 0.8199 - val_pr_auc: 0.7664 - val_cohen_kappa: 0.4726
# Epoch 6/100
# 256/256 [==============================] - 45s 174ms/step - loss: 0.5037 - tp: 958.0000 - fp: 448.0000 - tn: 2076.0000 - fn: 602.0000 - binary_acc: 0.7429 - precision: 0.6814 - recall: 0.6141 - f1_score: 0.6460 - roc_auc: 0.8166 - pr_auc: 0.7381 - cohen_kappa: 0.4450 - val_loss: 0.5427 - val_tp: 338.0000 - val_fp: 239.0000 - val_tn: 375.0000 - val_fn: 70.0000 - val_binary_acc: 0.6977 - val_precision: 0.5858 - val_recall: 0.8284 - val_f1_score: 0.6863 - val_roc_auc: 0.8279 - val_pr_auc: 0.7797 - val_cohen_kappa: 0.4106
# Epoch 7/100
# 256/256 [==============================] - 43s 169ms/step - loss: 0.4924 - tp: 974.0000 - fp: 409.0000 - tn: 2115.0000 - fn: 586.0000 - binary_acc: 0.7564 - precision: 0.7043 - recall: 0.6244 - f1_score: 0.6619 - roc_auc: 0.8261 - pr_auc: 0.7586 - cohen_kappa: 0.4726 - val_loss: 0.5098 - val_tp: 315.0000 - val_fp: 175.0000 - val_tn: 439.0000 - val_fn: 93.0000 - val_binary_acc: 0.7378 - val_precision: 0.6429 - val_recall: 0.7721 - val_f1_score: 0.7016 - val_roc_auc: 0.8283 - val_pr_auc: 0.7809 - val_cohen_kappa: 0.4712
# Epoch 8/100
# 256/256 [==============================] - 44s 172ms/step - loss: 0.5006 - tp: 960.0000 - fp: 439.0000 - tn: 2085.0000 - fn: 600.0000 - binary_acc: 0.7456 - precision: 0.6862 - recall: 0.6154 - f1_score: 0.6489 - roc_auc: 0.8205 - pr_auc: 0.7424 - cohen_kappa: 0.4503 - val_loss: 0.4839 - val_tp: 270.0000 - val_fp: 103.0000 - val_tn: 511.0000 - val_fn: 138.0000 - val_binary_acc: 0.7642 - val_precision: 0.7239 - val_recall: 0.6618 - val_f1_score: 0.6914 - val_roc_auc: 0.8381 - val_pr_auc: 0.7939 - val_cohen_kappa: 0.5012
# Epoch 9/100
# 256/256 [==============================] - 44s 170ms/step - loss: 0.4753 - tp: 989.0000 - fp: 390.0000 - tn: 2134.0000 - fn: 571.0000 - binary_acc: 0.7647 - precision: 0.7172 - recall: 0.6340 - f1_score: 0.6730 - roc_auc: 0.8402 - pr_auc: 0.7715 - cohen_kappa: 0.4903 - val_loss: 0.4981 - val_tp: 249.0000 - val_fp: 83.0000 - val_tn: 531.0000 - val_fn: 159.0000 - val_binary_acc: 0.7632 - val_precision: 0.7500 - val_recall: 0.6103 - val_f1_score: 0.6730 - val_roc_auc: 0.8276 - val_pr_auc: 0.7913 - val_cohen_kappa: 0.4904
# Epoch 10/100
# 256/256 [==============================] - 46s 179ms/step - loss: 0.4791 - tp: 1026.0000 - fp: 417.0000 - tn: 2107.0000 - fn: 534.0000 - binary_acc: 0.7671 - precision: 0.7110 - recall: 0.6577 - f1_score: 0.6833 - roc_auc: 0.8368 - pr_auc: 0.7660 - cohen_kappa: 0.4996 - val_loss: 0.5835 - val_tp: 339.0000 - val_fp: 230.0000 - val_tn: 384.0000 - val_fn: 69.0000 - val_binary_acc: 0.7074 - val_precision: 0.5958 - val_recall: 0.8309 - val_f1_score: 0.6940 - val_roc_auc: 0.8161 - val_pr_auc: 0.7586 - val_cohen_kappa: 0.4280
# Epoch 11/100
# 256/256 [==============================] - 45s 174ms/step - loss: 0.4697 - tp: 1013.0000 - fp: 398.0000 - tn: 2126.0000 - fn: 547.0000 - binary_acc: 0.7686 - precision: 0.7179 - recall: 0.6494 - f1_score: 0.6819 - roc_auc: 0.8428 - pr_auc: 0.7781 - cohen_kappa: 0.5008 - val_loss: 0.5788 - val_tp: 152.0000 - val_fp: 22.0000 - val_tn: 592.0000 - val_fn: 256.0000 - val_binary_acc: 0.7280 - val_precision: 0.8736 - val_recall: 0.3725 - val_f1_score: 0.5223 - val_roc_auc: 0.8312 - val_pr_auc: 0.7872 - val_cohen_kappa: 0.3726
# Epoch 12/100
# 256/256 [==============================] - 45s 176ms/step - loss: 0.4702 - tp: 1000.0000 - fp: 399.0000 - tn: 2125.0000 - fn: 560.0000 - binary_acc: 0.7652 - precision: 0.7148 - recall: 0.6410 - f1_score: 0.6759 - roc_auc: 0.8430 - pr_auc: 0.7776 - cohen_kappa: 0.4927 - val_loss: 0.4953 - val_tp: 271.0000 - val_fp: 116.0000 - val_tn: 498.0000 - val_fn: 137.0000 - val_binary_acc: 0.7524 - val_precision: 0.7003 - val_recall: 0.6642 - val_f1_score: 0.6818 - val_roc_auc: 0.8276 - val_pr_auc: 0.7829 - val_cohen_kappa: 0.4794
# Epoch 13/100
# 256/256 [==============================] - 45s 176ms/step - loss: 0.4536 - tp: 1038.0000 - fp: 364.0000 - tn: 2160.0000 - fn: 522.0000 - binary_acc: 0.7831 - precision: 0.7404 - recall: 0.6654 - f1_score: 0.7009 - roc_auc: 0.8562 - pr_auc: 0.7955 - cohen_kappa: 0.5314 - val_loss: 0.5047 - val_tp: 240.0000 - val_fp: 75.0000 - val_tn: 539.0000 - val_fn: 168.0000 - val_binary_acc: 0.7622 - val_precision: 0.7619 - val_recall: 0.5882 - val_f1_score: 0.6639 - val_roc_auc: 0.8306 - val_pr_auc: 0.7866 - val_cohen_kappa: 0.4846
# Epoch 14/100
# 256/256 [==============================] - 47s 184ms/step - loss: 0.4552 - tp: 1036.0000 - fp: 370.0000 - tn: 2154.0000 - fn: 524.0000 - binary_acc: 0.7811 - precision: 0.7368 - recall: 0.6641 - f1_score: 0.6986 - roc_auc: 0.8554 - pr_auc: 0.7939 - cohen_kappa: 0.5275 - val_loss: 0.5061 - val_tp: 334.0000 - val_fp: 196.0000 - val_tn: 418.0000 - val_fn: 74.0000 - val_binary_acc: 0.7358 - val_precision: 0.6302 - val_recall: 0.8186 - val_f1_score: 0.7122 - val_roc_auc: 0.8432 - val_pr_auc: 0.8043 - val_cohen_kappa: 0.4756
# Epoch 15/100
# 256/256 [==============================] - 46s 179ms/step - loss: 0.4432 - tp: 1059.0000 - fp: 364.0000 - tn: 2160.0000 - fn: 501.0000 - binary_acc: 0.7882 - precision: 0.7442 - recall: 0.6788 - f1_score: 0.7100 - roc_auc: 0.8629 - pr_auc: 0.8051 - cohen_kappa: 0.5437 - val_loss: 0.5125 - val_tp: 185.0000 - val_fp: 39.0000 - val_tn: 575.0000 - val_fn: 223.0000 - val_binary_acc: 0.7436 - val_precision: 0.8259 - val_recall: 0.4534 - val_f1_score: 0.5854 - val_roc_auc: 0.8291 - val_pr_auc: 0.7803 - val_cohen_kappa: 0.4218
# Epoch 16/100
# 256/256 [==============================] - 45s 176ms/step - loss: 0.4344 - tp: 1056.0000 - fp: 364.0000 - tn: 2160.0000 - fn: 504.0000 - binary_acc: 0.7875 - precision: 0.7437 - recall: 0.6769 - f1_score: 0.7087 - roc_auc: 0.8690 - pr_auc: 0.8135 - cohen_kappa: 0.5420 - val_loss: 0.4962 - val_tp: 201.0000 - val_fp: 31.0000 - val_tn: 583.0000 - val_fn: 207.0000 - val_binary_acc: 0.7671 - val_precision: 0.8664 - val_recall: 0.4926 - val_f1_score: 0.6281 - val_roc_auc: 0.8496 - val_pr_auc: 0.8111 - val_cohen_kappa: 0.4767
# Epoch 17/100
# 256/256 [==============================] - 43s 169ms/step - loss: 0.4308 - tp: 1070.0000 - fp: 347.0000 - tn: 2177.0000 - fn: 490.0000 - binary_acc: 0.7951 - precision: 0.7551 - recall: 0.6859 - f1_score: 0.7188 - roc_auc: 0.8715 - pr_auc: 0.8160 - cohen_kappa: 0.5582 - val_loss: 0.4848 - val_tp: 271.0000 - val_fp: 108.0000 - val_tn: 506.0000 - val_fn: 137.0000 - val_binary_acc: 0.7603 - val_precision: 0.7150 - val_recall: 0.6642 - val_f1_score: 0.6887 - val_roc_auc: 0.8366 - val_pr_auc: 0.7959 - val_cohen_kappa: 0.4942
# Epoch 18/100
# 256/256 [==============================] - 45s 177ms/step - loss: 0.4346 - tp: 1056.0000 - fp: 354.0000 - tn: 2170.0000 - fn: 504.0000 - binary_acc: 0.7899 - precision: 0.7489 - recall: 0.6769 - f1_score: 0.7111 - roc_auc: 0.8681 - pr_auc: 0.8145 - cohen_kappa: 0.5467 - val_loss: 0.4743 - val_tp: 251.0000 - val_fp: 67.0000 - val_tn: 547.0000 - val_fn: 157.0000 - val_binary_acc: 0.7808 - val_precision: 0.7893 - val_recall: 0.6152 - val_f1_score: 0.6915 - val_roc_auc: 0.8496 - val_pr_auc: 0.8117 - val_cohen_kappa: 0.5255
# Epoch 19/100
# 256/256 [==============================] - 43s 167ms/step - loss: 0.4263 - tp: 1084.0000 - fp: 356.0000 - tn: 2168.0000 - fn: 476.0000 - binary_acc: 0.7963 - precision: 0.7528 - recall: 0.6949 - f1_score: 0.7227 - roc_auc: 0.8736 - pr_auc: 0.8209 - cohen_kappa: 0.5621 - val_loss: 0.4793 - val_tp: 295.0000 - val_fp: 136.0000 - val_tn: 478.0000 - val_fn: 113.0000 - val_binary_acc: 0.7564 - val_precision: 0.6845 - val_recall: 0.7230 - val_f1_score: 0.7032 - val_roc_auc: 0.8466 - val_pr_auc: 0.8020 - val_cohen_kappa: 0.4968
# Epoch 20/100
# 256/256 [==============================] - 43s 168ms/step - loss: 0.4158 - tp: 1096.0000 - fp: 336.0000 - tn: 2188.0000 - fn: 464.0000 - binary_acc: 0.8041 - precision: 0.7654 - recall: 0.7026 - f1_score: 0.7326 - roc_auc: 0.8813 - pr_auc: 0.8249 - cohen_kappa: 0.5785 - val_loss: 0.4822 - val_tp: 260.0000 - val_fp: 97.0000 - val_tn: 517.0000 - val_fn: 148.0000 - val_binary_acc: 0.7603 - val_precision: 0.7283 - val_recall: 0.6373 - val_f1_score: 0.6797 - val_roc_auc: 0.8388 - val_pr_auc: 0.7935 - val_cohen_kappa: 0.4895
# Epoch 21/100
# 256/256 [==============================] - 43s 168ms/step - loss: 0.4120 - tp: 1100.0000 - fp: 327.0000 - tn: 2197.0000 - fn: 460.0000 - binary_acc: 0.8073 - precision: 0.7708 - recall: 0.7051 - f1_score: 0.7365 - roc_auc: 0.8831 - pr_auc: 0.8341 - cohen_kappa: 0.5851 - val_loss: 0.4919 - val_tp: 315.0000 - val_fp: 141.0000 - val_tn: 473.0000 - val_fn: 93.0000 - val_binary_acc: 0.7710 - val_precision: 0.6908 - val_recall: 0.7721 - val_f1_score: 0.7292 - val_roc_auc: 0.8439 - val_pr_auc: 0.8017 - val_cohen_kappa: 0.5319
# Epoch 22/100
# 256/256 [==============================] - 44s 172ms/step - loss: 0.3969 - tp: 1124.0000 - fp: 318.0000 - tn: 2206.0000 - fn: 436.0000 - binary_acc: 0.8154 - precision: 0.7795 - recall: 0.7205 - f1_score: 0.7488 - roc_auc: 0.8925 - pr_auc: 0.8464 - cohen_kappa: 0.6032 - val_loss: 0.4972 - val_tp: 277.0000 - val_fp: 80.0000 - val_tn: 534.0000 - val_fn: 131.0000 - val_binary_acc: 0.7935 - val_precision: 0.7759 - val_recall: 0.6789 - val_f1_score: 0.7242 - val_roc_auc: 0.8442 - val_pr_auc: 0.8006 - val_cohen_kappa: 0.5604
# Epoch 23/100
# 256/256 [==============================] - 43s 167ms/step - loss: 0.4038 - tp: 1108.0000 - fp: 318.0000 - tn: 2206.0000 - fn: 452.0000 - binary_acc: 0.8115 - precision: 0.7770 - recall: 0.7103 - f1_score: 0.7421 - roc_auc: 0.8875 - pr_auc: 0.8418 - cohen_kappa: 0.5940 - val_loss: 0.4830 - val_tp: 268.0000 - val_fp: 91.0000 - val_tn: 523.0000 - val_fn: 140.0000 - val_binary_acc: 0.7740 - val_precision: 0.7465 - val_recall: 0.6569 - val_f1_score: 0.6988 - val_roc_auc: 0.8484 - val_pr_auc: 0.8035 - val_cohen_kappa: 0.5191
# Epoch 24/100
# 256/256 [==============================] - 44s 171ms/step - loss: 0.3860 - tp: 1142.0000 - fp: 300.0000 - tn: 2224.0000 - fn: 418.0000 - binary_acc: 0.8242 - precision: 0.7920 - recall: 0.7321 - f1_score: 0.7608 - roc_auc: 0.8987 - pr_auc: 0.8573 - cohen_kappa: 0.6222 - val_loss: 0.4752 - val_tp: 289.0000 - val_fp: 125.0000 - val_tn: 489.0000 - val_fn: 119.0000 - val_binary_acc: 0.7613 - val_precision: 0.6981 - val_recall: 0.7083 - val_f1_score: 0.7032 - val_roc_auc: 0.8480 - val_pr_auc: 0.8078 - val_cohen_kappa: 0.5035
# Epoch 25/100
# 256/256 [==============================] - 45s 174ms/step - loss: 0.4023 - tp: 1117.0000 - fp: 340.0000 - tn: 2184.0000 - fn: 443.0000 - binary_acc: 0.8083 - precision: 0.7666 - recall: 0.7160 - f1_score: 0.7405 - roc_auc: 0.8892 - pr_auc: 0.8421 - cohen_kappa: 0.5887 - val_loss: 0.4712 - val_tp: 243.0000 - val_fp: 73.0000 - val_tn: 541.0000 - val_fn: 165.0000 - val_binary_acc: 0.7671 - val_precision: 0.7690 - val_recall: 0.5956 - val_f1_score: 0.6713 - val_roc_auc: 0.8454 - val_pr_auc: 0.8072 - val_cohen_kappa: 0.4954
# Epoch 26/100
# 256/256 [==============================] - 45s 178ms/step - loss: 0.3873 - tp: 1129.0000 - fp: 300.0000 - tn: 2224.0000 - fn: 431.0000 - binary_acc: 0.8210 - precision: 0.7901 - recall: 0.7237 - f1_score: 0.7554 - roc_auc: 0.8975 - pr_auc: 0.8545 - cohen_kappa: 0.6147 - val_loss: 0.5182 - val_tp: 321.0000 - val_fp: 171.0000 - val_tn: 443.0000 - val_fn: 87.0000 - val_binary_acc: 0.7476 - val_precision: 0.6524 - val_recall: 0.7868 - val_f1_score: 0.7133 - val_roc_auc: 0.8369 - val_pr_auc: 0.7861 - val_cohen_kappa: 0.4913
# Epoch 27/100
# 256/256 [==============================] - 44s 171ms/step - loss: 0.3803 - tp: 1137.0000 - fp: 304.0000 - tn: 2220.0000 - fn: 423.0000 - binary_acc: 0.8220 - precision: 0.7890 - recall: 0.7288 - f1_score: 0.7577 - roc_auc: 0.9010 - pr_auc: 0.8594 - cohen_kappa: 0.6174 - val_loss: 0.4845 - val_tp: 308.0000 - val_fp: 135.0000 - val_tn: 479.0000 - val_fn: 100.0000 - val_binary_acc: 0.7701 - val_precision: 0.6953 - val_recall: 0.7549 - val_f1_score: 0.7239 - val_roc_auc: 0.8497 - val_pr_auc: 0.8007 - val_cohen_kappa: 0.5274
# Epoch 28/100
# 256/256 [==============================] - 44s 173ms/step - loss: 0.3736 - tp: 1168.0000 - fp: 312.0000 - tn: 2212.0000 - fn: 392.0000 - binary_acc: 0.8276 - precision: 0.7892 - recall: 0.7487 - f1_score: 0.7684 - roc_auc: 0.9059 - pr_auc: 0.8649 - cohen_kappa: 0.6313 - val_loss: 0.4669 - val_tp: 292.0000 - val_fp: 110.0000 - val_tn: 504.0000 - val_fn: 116.0000 - val_binary_acc: 0.7789 - val_precision: 0.7264 - val_recall: 0.7157 - val_f1_score: 0.7210 - val_roc_auc: 0.8523 - val_pr_auc: 0.8091 - val_cohen_kappa: 0.5379
# Epoch 29/100
# 256/256 [==============================] - 43s 170ms/step - loss: 0.3718 - tp: 1152.0000 - fp: 308.0000 - tn: 2216.0000 - fn: 408.0000 - binary_acc: 0.8247 - precision: 0.7890 - recall: 0.7385 - f1_score: 0.7629 - roc_auc: 0.9047 - pr_auc: 0.8690 - cohen_kappa: 0.6241 - val_loss: 0.4643 - val_tp: 267.0000 - val_fp: 78.0000 - val_tn: 536.0000 - val_fn: 141.0000 - val_binary_acc: 0.7857 - val_precision: 0.7739 - val_recall: 0.6544 - val_f1_score: 0.7092 - val_roc_auc: 0.8608 - val_pr_auc: 0.8184 - val_cohen_kappa: 0.5414
# Epoch 30/100
# 256/256 [==============================] - 45s 176ms/step - loss: 0.3565 - tp: 1172.0000 - fp: 275.0000 - tn: 2249.0000 - fn: 388.0000 - binary_acc: 0.8377 - precision: 0.8100 - recall: 0.7513 - f1_score: 0.7795 - roc_auc: 0.9147 - pr_auc: 0.8763 - cohen_kappa: 0.6513 - val_loss: 0.4740 - val_tp: 273.0000 - val_fp: 93.0000 - val_tn: 521.0000 - val_fn: 135.0000 - val_binary_acc: 0.7769 - val_precision: 0.7459 - val_recall: 0.6691 - val_f1_score: 0.7054 - val_roc_auc: 0.8557 - val_pr_auc: 0.8117 - val_cohen_kappa: 0.5267
# Epoch 31/100
# 256/256 [==============================] - 43s 170ms/step - loss: 0.3431 - tp: 1166.0000 - fp: 266.0000 - tn: 2258.0000 - fn: 394.0000 - binary_acc: 0.8384 - precision: 0.8142 - recall: 0.7474 - f1_score: 0.7794 - roc_auc: 0.9208 - pr_auc: 0.8862 - cohen_kappa: 0.6523 - val_loss: 0.5001 - val_tp: 281.0000 - val_fp: 95.0000 - val_tn: 519.0000 - val_fn: 127.0000 - val_binary_acc: 0.7828 - val_precision: 0.7473 - val_recall: 0.6887 - val_f1_score: 0.7168 - val_roc_auc: 0.8524 - val_pr_auc: 0.8018 - val_cohen_kappa: 0.5411
# Epoch 32/100
# 256/256 [==============================] - 44s 172ms/step - loss: 0.3483 - tp: 1203.0000 - fp: 292.0000 - tn: 2232.0000 - fn: 357.0000 - binary_acc: 0.8411 - precision: 0.8047 - recall: 0.7712 - f1_score: 0.7876 - roc_auc: 0.9184 - pr_auc: 0.8849 - cohen_kappa: 0.6607 - val_loss: 0.5758 - val_tp: 166.0000 - val_fp: 33.0000 - val_tn: 581.0000 - val_fn: 242.0000 - val_binary_acc: 0.7309 - val_precision: 0.8342 - val_recall: 0.4069 - val_f1_score: 0.5470 - val_roc_auc: 0.8406 - val_pr_auc: 0.7968 - val_cohen_kappa: 0.3863
# Epoch 33/100
# 256/256 [==============================] - 44s 171ms/step - loss: 0.3592 - tp: 1180.0000 - fp: 283.0000 - tn: 2241.0000 - fn: 380.0000 - binary_acc: 0.8377 - precision: 0.8066 - recall: 0.7564 - f1_score: 0.7807 - roc_auc: 0.9131 - pr_auc: 0.8733 - cohen_kappa: 0.6520 - val_loss: 0.5160 - val_tp: 226.0000 - val_fp: 59.0000 - val_tn: 555.0000 - val_fn: 182.0000 - val_binary_acc: 0.7642 - val_precision: 0.7930 - val_recall: 0.5539 - val_f1_score: 0.6522 - val_roc_auc: 0.8457 - val_pr_auc: 0.8018 - val_cohen_kappa: 0.4822
# Epoch 34/100
# 256/256 [==============================] - 45s 178ms/step - loss: 0.3490 - tp: 1179.0000 - fp: 284.0000 - tn: 2240.0000 - fn: 381.0000 - binary_acc: 0.8372 - precision: 0.8059 - recall: 0.7558 - f1_score: 0.7800 - roc_auc: 0.9177 - pr_auc: 0.8830 - cohen_kappa: 0.6510 - val_loss: 0.5128 - val_tp: 327.0000 - val_fp: 170.0000 - val_tn: 444.0000 - val_fn: 81.0000 - val_binary_acc: 0.7544 - val_precision: 0.6579 - val_recall: 0.8015 - val_f1_score: 0.7227 - val_roc_auc: 0.8491 - val_pr_auc: 0.8106 - val_cohen_kappa: 0.5061
# Epoch 35/100
# 256/256 [==============================] - 43s 170ms/step - loss: 0.3441 - tp: 1193.0000 - fp: 292.0000 - tn: 2232.0000 - fn: 367.0000 - binary_acc: 0.8386 - precision: 0.8034 - recall: 0.7647 - f1_score: 0.7836 - roc_auc: 0.9207 - pr_auc: 0.8824 - cohen_kappa: 0.6551 - val_loss: 0.4836 - val_tp: 244.0000 - val_fp: 63.0000 - val_tn: 551.0000 - val_fn: 164.0000 - val_binary_acc: 0.7779 - val_precision: 0.7948 - val_recall: 0.5980 - val_f1_score: 0.6825 - val_roc_auc: 0.8511 - val_pr_auc: 0.8114 - val_cohen_kappa: 0.5169
# Epoch 36/100
# 256/256 [==============================] - 44s 173ms/step - loss: 0.3325 - tp: 1207.0000 - fp: 264.0000 - tn: 2260.0000 - fn: 353.0000 - binary_acc: 0.8489 - precision: 0.8205 - recall: 0.7737 - f1_score: 0.7964 - roc_auc: 0.9257 - pr_auc: 0.8933 - cohen_kappa: 0.6765 - val_loss: 0.4970 - val_tp: 295.0000 - val_fp: 116.0000 - val_tn: 498.0000 - val_fn: 113.0000 - val_binary_acc: 0.7759 - val_precision: 0.7178 - val_recall: 0.7230 - val_f1_score: 0.7204 - val_roc_auc: 0.8533 - val_pr_auc: 0.8110 - val_cohen_kappa: 0.5335
# Epoch 37/100
# 256/256 [==============================] - ETA: 0s - loss: 0.3208 - tp: 1229.0000 - fp: 261.0000 - tn: 2263.0000 - fn: 331.0000 - binary_acc: 0.8550 - precision: 0.8248 - recall: 0.7878 - f1_score: 0.8059 - roc_auc: 0.9315 - pr_auc: 0.9010 - cohen_kappa: 0.6903Restoring model weights from the end of the best epoch: 22.
# 256/256 [==============================] - 44s 170ms/step - loss: 0.3208 - tp: 1229.0000 - fp: 261.0000 - tn: 2263.0000 - fn: 331.0000 - binary_acc: 0.8550 - precision: 0.8248 - recall: 0.7878 - f1_score: 0.8059 - roc_auc: 0.9315 - pr_auc: 0.9010 - cohen_kappa: 0.6903 - val_loss: 0.5264 - val_tp: 332.0000 - val_fp: 165.0000 - val_tn: 449.0000 - val_fn: 76.0000 - val_binary_acc: 0.7642 - val_precision: 0.6680 - val_recall: 0.8137 - val_f1_score: 0.7337 - val_roc_auc: 0.8505 - val_pr_auc: 0.8000 - val_cohen_kappa: 0.5258
# Epoch 37: early stopping

# %%
new_model.save(save_path + model_name + '.keras')

plot_metrics(history)

# %%
new_model.evaluate(validation_generator)
new_model.evaluate(test_generator)

    # Make predictions using the validation generator
y_valid_pred_prob = new_model.predict(validation_generator)
y_valid_pred = (y_valid_pred_prob > 0.5).astype(int)
y_valid = validation_generator.classes
print("Classification Report:")
print(classification_report(y_valid, y_valid_pred))

y_pred_prob = new_model.predict(test_generator)
y_pred = (y_pred_prob > 0.5).astype(int)
y_test = test_generator.classes
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# 64/64 [==============================] - 9s 134ms/step - loss: 0.5108 - tp: 268.0000 - fp: 103.0000 - tn: 511.0000 - fn: 140.0000 - binary_acc: 0.7622 - precision: 0.7224 - recall: 0.6569 - f1_score: 0.6881 - roc_auc: 0.8368 - pr_auc: 0.7924 - cohen_kappa: 0.4967
# 29/29 [==============================] - 2s 70ms/step - loss: 0.6673 - tp: 143.0000 - fp: 25.0000 - tn: 189.0000 - fn: 104.0000 - binary_acc: 0.7202 - precision: 0.8512 - recall: 0.5789 - f1_score: 0.6892 - roc_auc: 0.8105 - pr_auc: 0.8454 - cohen_kappa: 0.4510
# 64/64 [==============================] - 11s 136ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.84      0.82       614
#            1       0.74      0.67      0.71       408
#
#     accuracy                           0.77      1022
#    macro avg       0.77      0.76      0.76      1022
# weighted avg       0.77      0.77      0.77      1022
#
# 29/29 [==============================] - 2s 61ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.65      0.88      0.75       214
#            1       0.85      0.58      0.69       247
#
#     accuracy                           0.72       461
#    macro avg       0.75      0.73      0.72       461
# weighted avg       0.76      0.72      0.72       461

# %%
conf_matrix = confusion_matrix(y_test, y_pred)

# Create ConfusionMatrixDisplay object
cm_display = ConfusionMatrixDisplay(confusion_matrix=conf_matrix)

# Plot the confusion matrix
plt.figure(figsize=(4, 6))  # Adjust the figure size as needed
cm_display.plot(cmap=plt.cm.Blues)  # You can choose any colormap you prefer
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.grid(False)  # Turn off grid
plt.savefig(save_path + model_name + "_confusion_matrix.jpg")
plt.show()

# %%
history_df = pd.DataFrame(history.history)
save_history(model_name, history_df)

new_model.save(save_path + model_name + "_pt_imagenet-{new_model.count_params()}.h5")
densenet.save(save_path + model_name + ".h5")

densenet.trainable = True

new_model.compile(
        optimizer=tf.keras.optimizers.Adam(
            1e-5
        ),  # we need small learning rate to avoid catastrophic forgetting
        loss=tf.keras.losses.BinaryCrossentropy(),
        metrics=METRICS,
    )

model_name = 'finetuned_' + architecture + "_" + target_category

model_path = save_path + '_best_' + model_name + '.keras'
model_checkpoint = ModelCheckpoint(filepath=model_path,
                                       monitor="val_cohen_kappa",
                                       save_best_only=True)

reduce_lr_on_plateau = tf.keras.callbacks.ReduceLROnPlateau(
        monitor="val_cohen_kappa",
        verbose=1,
        patience=4,
        mode="max",
        factor=0.2,
        min_lr=1e-10,
    )
# Out:
# Training history saved to: C:/Users/raouf/Desktop/pfe/history/final/densenet/XR_FINGER/DenseNet_XR_FINGER_history.xlsx
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
history = new_model.fit(train_generator,
                            # steps_per_epoch=len(df_train) // batch_size,
                            validation_data=validation_generator,
                            # validation_steps=len(df_valid) // batch_size,
                            epochs=fine_tuning_epochs,
                            shuffle=shuffle,
                            callbacks=[early_stopping, model_checkpoint, reduce_lr_on_plateau])
# Out:
# Epoch 1/50
# 256/256 [==============================] - 78s 248ms/step - loss: 0.4331 - tp: 1196.0000 - fp: 381.0000 - tn: 2357.0000 - fn: 611.0000 - binary_acc: 0.7817 - precision: 0.7584 - recall: 0.6619 - f1_score: 0.7069 - roc_auc: 0.8591 - pr_auc: 0.8156 - cohen_kappa: 0.5343 - val_loss: 0.5084 - val_tp: 342.0000 - val_fp: 187.0000 - val_tn: 427.0000 - val_fn: 66.0000 - val_binary_acc: 0.7524 - val_precision: 0.6465 - val_recall: 0.8382 - val_f1_score: 0.7300 - val_roc_auc: 0.8555 - val_pr_auc: 0.8170 - val_cohen_kappa: 0.5084 - lr: 1.0000e-05
# Epoch 2/50
# 256/256 [==============================] - 62s 241ms/step - loss: 0.3880 - tp: 1133.0000 - fp: 302.0000 - tn: 2222.0000 - fn: 427.0000 - binary_acc: 0.8215 - precision: 0.7895 - recall: 0.7263 - f1_score: 0.7566 - roc_auc: 0.8967 - pr_auc: 0.8563 - cohen_kappa: 0.6161 - val_loss: 0.4529 - val_tp: 312.0000 - val_fp: 125.0000 - val_tn: 489.0000 - val_fn: 96.0000 - val_binary_acc: 0.7838 - val_precision: 0.7140 - val_recall: 0.7647 - val_f1_score: 0.7385 - val_roc_auc: 0.8647 - val_pr_auc: 0.8288 - val_cohen_kappa: 0.5545 - lr: 1.0000e-05
# Epoch 3/50
# 256/256 [==============================] - 60s 234ms/step - loss: 0.3573 - tp: 1170.0000 - fp: 255.0000 - tn: 2269.0000 - fn: 390.0000 - binary_acc: 0.8421 - precision: 0.8211 - recall: 0.7500 - f1_score: 0.7839 - roc_auc: 0.9127 - pr_auc: 0.8793 - cohen_kappa: 0.6599 - val_loss: 0.4736 - val_tp: 305.0000 - val_fp: 118.0000 - val_tn: 496.0000 - val_fn: 103.0000 - val_binary_acc: 0.7838 - val_precision: 0.7210 - val_recall: 0.7475 - val_f1_score: 0.7341 - val_roc_auc: 0.8608 - val_pr_auc: 0.8359 - val_cohen_kappa: 0.5520 - lr: 1.0000e-05
# Epoch 4/50
# 256/256 [==============================] - 60s 233ms/step - loss: 0.3385 - tp: 1175.0000 - fp: 258.0000 - tn: 2266.0000 - fn: 385.0000 - binary_acc: 0.8426 - precision: 0.8200 - recall: 0.7532 - f1_score: 0.7852 - roc_auc: 0.9226 - pr_auc: 0.8933 - cohen_kappa: 0.6613 - val_loss: 0.4353 - val_tp: 282.0000 - val_fp: 88.0000 - val_tn: 526.0000 - val_fn: 126.0000 - val_binary_acc: 0.7906 - val_precision: 0.7622 - val_recall: 0.6912 - val_f1_score: 0.7249 - val_roc_auc: 0.8702 - val_pr_auc: 0.8445 - val_cohen_kappa: 0.5565 - lr: 1.0000e-05
# Epoch 5/50
# 256/256 [==============================] - 59s 232ms/step - loss: 0.3088 - tp: 1222.0000 - fp: 215.0000 - tn: 2309.0000 - fn: 338.0000 - binary_acc: 0.8646 - precision: 0.8504 - recall: 0.7833 - f1_score: 0.8155 - roc_auc: 0.9365 - pr_auc: 0.9120 - cohen_kappa: 0.7088 - val_loss: 0.5008 - val_tp: 261.0000 - val_fp: 59.0000 - val_tn: 555.0000 - val_fn: 147.0000 - val_binary_acc: 0.7984 - val_precision: 0.8156 - val_recall: 0.6397 - val_f1_score: 0.7170 - val_roc_auc: 0.8647 - val_pr_auc: 0.8384 - val_cohen_kappa: 0.5640 - lr: 1.0000e-05
# Epoch 6/50
# 256/256 [==============================] - 59s 231ms/step - loss: 0.2959 - tp: 1249.0000 - fp: 233.0000 - tn: 2291.0000 - fn: 311.0000 - binary_acc: 0.8668 - precision: 0.8428 - recall: 0.8006 - f1_score: 0.8212 - roc_auc: 0.9411 - pr_auc: 0.9181 - cohen_kappa: 0.7152 - val_loss: 0.4631 - val_tp: 304.0000 - val_fp: 106.0000 - val_tn: 508.0000 - val_fn: 104.0000 - val_binary_acc: 0.7945 - val_precision: 0.7415 - val_recall: 0.7451 - val_f1_score: 0.7433 - val_roc_auc: 0.8646 - val_pr_auc: 0.8363 - val_cohen_kappa: 0.5720 - lr: 1.0000e-05
# Epoch 7/50
# 256/256 [==============================] - 60s 232ms/step - loss: 0.2755 - tp: 1277.0000 - fp: 203.0000 - tn: 2321.0000 - fn: 283.0000 - binary_acc: 0.8810 - precision: 0.8628 - recall: 0.8186 - f1_score: 0.8401 - roc_auc: 0.9495 - pr_auc: 0.9297 - cohen_kappa: 0.7455 - val_loss: 0.4888 - val_tp: 259.0000 - val_fp: 59.0000 - val_tn: 555.0000 - val_fn: 149.0000 - val_binary_acc: 0.7965 - val_precision: 0.8145 - val_recall: 0.6348 - val_f1_score: 0.7135 - val_roc_auc: 0.8708 - val_pr_auc: 0.8373 - val_cohen_kappa: 0.5594 - lr: 1.0000e-05
# Epoch 8/50
# 256/256 [==============================] - 59s 232ms/step - loss: 0.2486 - tp: 1280.0000 - fp: 170.0000 - tn: 2354.0000 - fn: 280.0000 - binary_acc: 0.8898 - precision: 0.8828 - recall: 0.8205 - f1_score: 0.8505 - roc_auc: 0.9596 - pr_auc: 0.9429 - cohen_kappa: 0.7634 - val_loss: 0.4463 - val_tp: 283.0000 - val_fp: 64.0000 - val_tn: 550.0000 - val_fn: 125.0000 - val_binary_acc: 0.8151 - val_precision: 0.8156 - val_recall: 0.6936 - val_f1_score: 0.7497 - val_roc_auc: 0.8765 - val_pr_auc: 0.8555 - val_cohen_kappa: 0.6046 - lr: 1.0000e-05
# Epoch 9/50
# 256/256 [==============================] - 60s 233ms/step - loss: 0.2338 - tp: 1328.0000 - fp: 146.0000 - tn: 2378.0000 - fn: 232.0000 - binary_acc: 0.9074 - precision: 0.9009 - recall: 0.8513 - f1_score: 0.8754 - roc_auc: 0.9635 - pr_auc: 0.9504 - cohen_kappa: 0.8019 - val_loss: 0.4687 - val_tp: 280.0000 - val_fp: 72.0000 - val_tn: 542.0000 - val_fn: 128.0000 - val_binary_acc: 0.8043 - val_precision: 0.7955 - val_recall: 0.6863 - val_f1_score: 0.7368 - val_roc_auc: 0.8779 - val_pr_auc: 0.8439 - val_cohen_kappa: 0.5824 - lr: 1.0000e-05
# Epoch 10/50
# 256/256 [==============================] - 59s 231ms/step - loss: 0.2303 - tp: 1325.0000 - fp: 159.0000 - tn: 2365.0000 - fn: 235.0000 - binary_acc: 0.9035 - precision: 0.8929 - recall: 0.8494 - f1_score: 0.8706 - roc_auc: 0.9647 - pr_auc: 0.9515 - cohen_kappa: 0.7937 - val_loss: 0.4520 - val_tp: 282.0000 - val_fp: 68.0000 - val_tn: 546.0000 - val_fn: 126.0000 - val_binary_acc: 0.8102 - val_precision: 0.8057 - val_recall: 0.6912 - val_f1_score: 0.7441 - val_roc_auc: 0.8803 - val_pr_auc: 0.8552 - val_cohen_kappa: 0.5946 - lr: 1.0000e-05
# Epoch 11/50
# 256/256 [==============================] - 60s 233ms/step - loss: 0.2026 - tp: 1356.0000 - fp: 125.0000 - tn: 2399.0000 - fn: 204.0000 - binary_acc: 0.9194 - precision: 0.9156 - recall: 0.8692 - f1_score: 0.8918 - roc_auc: 0.9731 - pr_auc: 0.9627 - cohen_kappa: 0.8277 - val_loss: 0.4588 - val_tp: 330.0000 - val_fp: 119.0000 - val_tn: 495.0000 - val_fn: 78.0000 - val_binary_acc: 0.8072 - val_precision: 0.7350 - val_recall: 0.8088 - val_f1_score: 0.7701 - val_roc_auc: 0.8865 - val_pr_auc: 0.8589 - val_cohen_kappa: 0.6048 - lr: 1.0000e-05
# Epoch 12/50
# 256/256 [==============================] - 59s 231ms/step - loss: 0.1899 - tp: 1376.0000 - fp: 124.0000 - tn: 2400.0000 - fn: 184.0000 - binary_acc: 0.9246 - precision: 0.9173 - recall: 0.8821 - f1_score: 0.8993 - roc_auc: 0.9761 - pr_auc: 0.9663 - cohen_kappa: 0.8391 - val_loss: 0.4643 - val_tp: 268.0000 - val_fp: 57.0000 - val_tn: 557.0000 - val_fn: 140.0000 - val_binary_acc: 0.8072 - val_precision: 0.8246 - val_recall: 0.6569 - val_f1_score: 0.7312 - val_roc_auc: 0.8814 - val_pr_auc: 0.8594 - val_cohen_kappa: 0.5840 - lr: 1.0000e-05
# Epoch 13/50
# 256/256 [==============================] - 60s 233ms/step - loss: 0.1605 - tp: 1406.0000 - fp: 111.0000 - tn: 2413.0000 - fn: 154.0000 - binary_acc: 0.9351 - precision: 0.9268 - recall: 0.9013 - f1_score: 0.9139 - roc_auc: 0.9838 - pr_auc: 0.9769 - cohen_kappa: 0.8618 - val_loss: 0.4880 - val_tp: 281.0000 - val_fp: 56.0000 - val_tn: 558.0000 - val_fn: 127.0000 - val_binary_acc: 0.8209 - val_precision: 0.8338 - val_recall: 0.6887 - val_f1_score: 0.7544 - val_roc_auc: 0.8827 - val_pr_auc: 0.8612 - val_cohen_kappa: 0.6155 - lr: 1.0000e-05
# Epoch 14/50
# 256/256 [==============================] - 61s 237ms/step - loss: 0.1522 - tp: 1417.0000 - fp: 97.0000 - tn: 2427.0000 - fn: 143.0000 - binary_acc: 0.9412 - precision: 0.9359 - recall: 0.9083 - f1_score: 0.9219 - roc_auc: 0.9848 - pr_auc: 0.9791 - cohen_kappa: 0.8748 - val_loss: 0.7686 - val_tp: 363.0000 - val_fp: 233.0000 - val_tn: 381.0000 - val_fn: 45.0000 - val_binary_acc: 0.7280 - val_precision: 0.6091 - val_recall: 0.8897 - val_f1_score: 0.7231 - val_roc_auc: 0.8780 - val_pr_auc: 0.8248 - val_cohen_kappa: 0.4736 - lr: 1.0000e-05
# Epoch 15/50
# 256/256 [==============================] - 60s 233ms/step - loss: 0.1390 - tp: 1430.0000 - fp: 99.0000 - tn: 2425.0000 - fn: 130.0000 - binary_acc: 0.9439 - precision: 0.9353 - recall: 0.9167 - f1_score: 0.9259 - roc_auc: 0.9872 - pr_auc: 0.9821 - cohen_kappa: 0.8808 - val_loss: 0.5304 - val_tp: 332.0000 - val_fp: 119.0000 - val_tn: 495.0000 - val_fn: 76.0000 - val_binary_acc: 0.8092 - val_precision: 0.7361 - val_recall: 0.8137 - val_f1_score: 0.7730 - val_roc_auc: 0.8827 - val_pr_auc: 0.8523 - val_cohen_kappa: 0.6091 - lr: 1.0000e-05
# Epoch 16/50
# 256/256 [==============================] - 60s 233ms/step - loss: 0.1491 - tp: 1417.0000 - fp: 100.0000 - tn: 2424.0000 - fn: 143.0000 - binary_acc: 0.9405 - precision: 0.9341 - recall: 0.9083 - f1_score: 0.9210 - roc_auc: 0.9848 - pr_auc: 0.9792 - cohen_kappa: 0.8733 - val_loss: 0.5176 - val_tp: 302.0000 - val_fp: 93.0000 - val_tn: 521.0000 - val_fn: 106.0000 - val_binary_acc: 0.8053 - val_precision: 0.7646 - val_recall: 0.7402 - val_f1_score: 0.7522 - val_roc_auc: 0.8835 - val_pr_auc: 0.8504 - val_cohen_kappa: 0.5919 - lr: 1.0000e-05
# Epoch 17/50
# 256/256 [==============================] - ETA: 0s - loss: 0.1215 - tp: 1442.0000 - fp: 79.0000 - tn: 2445.0000 - fn: 118.0000 - binary_acc: 0.9518 - precision: 0.9481 - recall: 0.9244 - f1_score: 0.9361 - roc_auc: 0.9903 - pr_auc: 0.9862 - cohen_kappa: 0.8973
# Epoch 17: ReduceLROnPlateau reducing learning rate to 1.9999999494757505e-06.
# 256/256 [==============================] - 60s 234ms/step - loss: 0.1215 - tp: 1442.0000 - fp: 79.0000 - tn: 2445.0000 - fn: 118.0000 - binary_acc: 0.9518 - precision: 0.9481 - recall: 0.9244 - f1_score: 0.9361 - roc_auc: 0.9903 - pr_auc: 0.9862 - cohen_kappa: 0.8973 - val_loss: 0.6860 - val_tp: 218.0000 - val_fp: 26.0000 - val_tn: 588.0000 - val_fn: 190.0000 - val_binary_acc: 0.7886 - val_precision: 0.8934 - val_recall: 0.5343 - val_f1_score: 0.6687 - val_roc_auc: 0.8739 - val_pr_auc: 0.8481 - val_cohen_kappa: 0.5275 - lr: 1.0000e-05
# Epoch 18/50
# 256/256 [==============================] - 60s 233ms/step - loss: 0.0783 - tp: 1489.0000 - fp: 40.0000 - tn: 2484.0000 - fn: 71.0000 - binary_acc: 0.9728 - precision: 0.9738 - recall: 0.9545 - f1_score: 0.9641 - roc_auc: 0.9968 - pr_auc: 0.9951 - cohen_kappa: 0.9422 - val_loss: 0.5606 - val_tp: 288.0000 - val_fp: 67.0000 - val_tn: 547.0000 - val_fn: 120.0000 - val_binary_acc: 0.8170 - val_precision: 0.8113 - val_recall: 0.7059 - val_f1_score: 0.7549 - val_roc_auc: 0.8818 - val_pr_auc: 0.8619 - val_cohen_kappa: 0.6101 - lr: 2.0000e-06
# Epoch 19/50
# 256/256 [==============================] - 60s 236ms/step - loss: 0.0582 - tp: 1509.0000 - fp: 33.0000 - tn: 2491.0000 - fn: 51.0000 - binary_acc: 0.9794 - precision: 0.9786 - recall: 0.9673 - f1_score: 0.9729 - roc_auc: 0.9984 - pr_auc: 0.9975 - cohen_kappa: 0.9563 - val_loss: 0.5988 - val_tp: 291.0000 - val_fp: 68.0000 - val_tn: 546.0000 - val_fn: 117.0000 - val_binary_acc: 0.8190 - val_precision: 0.8106 - val_recall: 0.7132 - val_f1_score: 0.7588 - val_roc_auc: 0.8823 - val_pr_auc: 0.8552 - val_cohen_kappa: 0.6149 - lr: 2.0000e-06
# Epoch 20/50
# 256/256 [==============================] - 60s 235ms/step - loss: 0.0494 - tp: 1520.0000 - fp: 25.0000 - tn: 2499.0000 - fn: 40.0000 - binary_acc: 0.9841 - precision: 0.9838 - recall: 0.9744 - f1_score: 0.9791 - roc_auc: 0.9990 - pr_auc: 0.9984 - cohen_kappa: 0.9662 - val_loss: 0.5858 - val_tp: 298.0000 - val_fp: 73.0000 - val_tn: 541.0000 - val_fn: 110.0000 - val_binary_acc: 0.8209 - val_precision: 0.8032 - val_recall: 0.7304 - val_f1_score: 0.7651 - val_roc_auc: 0.8856 - val_pr_auc: 0.8558 - val_cohen_kappa: 0.6209 - lr: 2.0000e-06
# Epoch 21/50
# 256/256 [==============================] - 60s 235ms/step - loss: 0.0496 - tp: 1517.0000 - fp: 28.0000 - tn: 2496.0000 - fn: 43.0000 - binary_acc: 0.9826 - precision: 0.9819 - recall: 0.9724 - f1_score: 0.9771 - roc_auc: 0.9988 - pr_auc: 0.9981 - cohen_kappa: 0.9631 - val_loss: 0.5581 - val_tp: 296.0000 - val_fp: 68.0000 - val_tn: 546.0000 - val_fn: 112.0000 - val_binary_acc: 0.8239 - val_precision: 0.8132 - val_recall: 0.7255 - val_f1_score: 0.7668 - val_roc_auc: 0.8932 - val_pr_auc: 0.8680 - val_cohen_kappa: 0.6261 - lr: 2.0000e-06
# Epoch 22/50
# 256/256 [==============================] - 60s 233ms/step - loss: 0.0452 - tp: 1529.0000 - fp: 21.0000 - tn: 2503.0000 - fn: 31.0000 - binary_acc: 0.9873 - precision: 0.9865 - recall: 0.9801 - f1_score: 0.9833 - roc_auc: 0.9988 - pr_auc: 0.9983 - cohen_kappa: 0.9730 - val_loss: 0.5933 - val_tp: 304.0000 - val_fp: 79.0000 - val_tn: 535.0000 - val_fn: 104.0000 - val_binary_acc: 0.8209 - val_precision: 0.7937 - val_recall: 0.7451 - val_f1_score: 0.7686 - val_roc_auc: 0.8870 - val_pr_auc: 0.8557 - val_cohen_kappa: 0.6228 - lr: 2.0000e-06
# Epoch 23/50
# 256/256 [==============================] - 60s 235ms/step - loss: 0.0407 - tp: 1533.0000 - fp: 24.0000 - tn: 2500.0000 - fn: 27.0000 - binary_acc: 0.9875 - precision: 0.9846 - recall: 0.9827 - f1_score: 0.9836 - roc_auc: 0.9992 - pr_auc: 0.9987 - cohen_kappa: 0.9735 - val_loss: 0.6484 - val_tp: 296.0000 - val_fp: 62.0000 - val_tn: 552.0000 - val_fn: 112.0000 - val_binary_acc: 0.8297 - val_precision: 0.8268 - val_recall: 0.7255 - val_f1_score: 0.7728 - val_roc_auc: 0.8801 - val_pr_auc: 0.8598 - val_cohen_kappa: 0.6376 - lr: 2.0000e-06
# Epoch 24/50
# 256/256 [==============================] - 60s 235ms/step - loss: 0.0328 - tp: 1541.0000 - fp: 18.0000 - tn: 2506.0000 - fn: 19.0000 - binary_acc: 0.9909 - precision: 0.9885 - recall: 0.9878 - f1_score: 0.9881 - roc_auc: 0.9995 - pr_auc: 0.9993 - cohen_kappa: 0.9808 - val_loss: 0.6182 - val_tp: 309.0000 - val_fp: 93.0000 - val_tn: 521.0000 - val_fn: 99.0000 - val_binary_acc: 0.8121 - val_precision: 0.7687 - val_recall: 0.7574 - val_f1_score: 0.7630 - val_roc_auc: 0.8864 - val_pr_auc: 0.8544 - val_cohen_kappa: 0.6074 - lr: 2.0000e-06
# Epoch 25/50
# 256/256 [==============================] - 60s 235ms/step - loss: 0.0353 - tp: 1529.0000 - fp: 15.0000 - tn: 2509.0000 - fn: 31.0000 - binary_acc: 0.9887 - precision: 0.9903 - recall: 0.9801 - f1_score: 0.9852 - roc_auc: 0.9992 - pr_auc: 0.9988 - cohen_kappa: 0.9761 - val_loss: 0.6416 - val_tp: 314.0000 - val_fp: 99.0000 - val_tn: 515.0000 - val_fn: 94.0000 - val_binary_acc: 0.8112 - val_precision: 0.7603 - val_recall: 0.7696 - val_f1_score: 0.7649 - val_roc_auc: 0.8838 - val_pr_auc: 0.8472 - val_cohen_kappa: 0.6071 - lr: 2.0000e-06
# Epoch 26/50
# 256/256 [==============================] - 59s 232ms/step - loss: 0.0310 - tp: 1538.0000 - fp: 19.0000 - tn: 2505.0000 - fn: 22.0000 - binary_acc: 0.9900 - precision: 0.9878 - recall: 0.9859 - f1_score: 0.9868 - roc_auc: 0.9996 - pr_auc: 0.9994 - cohen_kappa: 0.9787 - val_loss: 0.6350 - val_tp: 296.0000 - val_fp: 66.0000 - val_tn: 548.0000 - val_fn: 112.0000 - val_binary_acc: 0.8258 - val_precision: 0.8177 - val_recall: 0.7255 - val_f1_score: 0.7688 - val_roc_auc: 0.8886 - val_pr_auc: 0.8629 - val_cohen_kappa: 0.6299 - lr: 2.0000e-06
# Epoch 27/50
# 256/256 [==============================] - ETA: 0s - loss: 0.0294 - tp: 1539.0000 - fp: 16.0000 - tn: 2508.0000 - fn: 21.0000 - binary_acc: 0.9909 - precision: 0.9897 - recall: 0.9865 - f1_score: 0.9881 - roc_auc: 0.9996 - pr_auc: 0.9994 - cohen_kappa: 0.9808
# Epoch 27: ReduceLROnPlateau reducing learning rate to 3.999999989900971e-07.
# 256/256 [==============================] - 60s 235ms/step - loss: 0.0294 - tp: 1539.0000 - fp: 16.0000 - tn: 2508.0000 - fn: 21.0000 - binary_acc: 0.9909 - precision: 0.9897 - recall: 0.9865 - f1_score: 0.9881 - roc_auc: 0.9996 - pr_auc: 0.9994 - cohen_kappa: 0.9808 - val_loss: 0.6652 - val_tp: 311.0000 - val_fp: 89.0000 - val_tn: 525.0000 - val_fn: 97.0000 - val_binary_acc: 0.8180 - val_precision: 0.7775 - val_recall: 0.7623 - val_f1_score: 0.7698 - val_roc_auc: 0.8863 - val_pr_auc: 0.8526 - val_cohen_kappa: 0.6193 - lr: 2.0000e-06
# Epoch 28/50
# 256/256 [==============================] - 60s 234ms/step - loss: 0.0274 - tp: 1550.0000 - fp: 15.0000 - tn: 2509.0000 - fn: 10.0000 - binary_acc: 0.9939 - precision: 0.9904 - recall: 0.9936 - f1_score: 0.9920 - roc_auc: 0.9996 - pr_auc: 0.9993 - cohen_kappa: 0.9870 - val_loss: 0.6636 - val_tp: 293.0000 - val_fp: 73.0000 - val_tn: 541.0000 - val_fn: 115.0000 - val_binary_acc: 0.8160 - val_precision: 0.8005 - val_recall: 0.7181 - val_f1_score: 0.7571 - val_roc_auc: 0.8892 - val_pr_auc: 0.8589 - val_cohen_kappa: 0.6098 - lr: 4.0000e-07
# Epoch 29/50
# 256/256 [==============================] - 60s 235ms/step - loss: 0.0246 - tp: 1544.0000 - fp: 12.0000 - tn: 2512.0000 - fn: 16.0000 - binary_acc: 0.9931 - precision: 0.9923 - recall: 0.9897 - f1_score: 0.9910 - roc_auc: 0.9997 - pr_auc: 0.9996 - cohen_kappa: 0.9855 - val_loss: 0.6800 - val_tp: 297.0000 - val_fp: 61.0000 - val_tn: 553.0000 - val_fn: 111.0000 - val_binary_acc: 0.8317 - val_precision: 0.8296 - val_recall: 0.7279 - val_f1_score: 0.7755 - val_roc_auc: 0.8849 - val_pr_auc: 0.8578 - val_cohen_kappa: 0.6418 - lr: 4.0000e-07
# Epoch 30/50
# 256/256 [==============================] - 59s 232ms/step - loss: 0.0219 - tp: 1544.0000 - fp: 6.0000 - tn: 2518.0000 - fn: 16.0000 - binary_acc: 0.9946 - precision: 0.9961 - recall: 0.9897 - f1_score: 0.9929 - roc_auc: 0.9995 - pr_auc: 0.9995 - cohen_kappa: 0.9886 - val_loss: 0.6832 - val_tp: 302.0000 - val_fp: 72.0000 - val_tn: 542.0000 - val_fn: 106.0000 - val_binary_acc: 0.8258 - val_precision: 0.8075 - val_recall: 0.7402 - val_f1_score: 0.7724 - val_roc_auc: 0.8794 - val_pr_auc: 0.8481 - val_cohen_kappa: 0.6318 - lr: 4.0000e-07
# Epoch 31/50
# 256/256 [==============================] - 61s 237ms/step - loss: 0.0213 - tp: 1547.0000 - fp: 11.0000 - tn: 2513.0000 - fn: 13.0000 - binary_acc: 0.9941 - precision: 0.9929 - recall: 0.9917 - f1_score: 0.9923 - roc_auc: 0.9998 - pr_auc: 0.9997 - cohen_kappa: 0.9876 - val_loss: 0.6724 - val_tp: 303.0000 - val_fp: 76.0000 - val_tn: 538.0000 - val_fn: 105.0000 - val_binary_acc: 0.8229 - val_precision: 0.7995 - val_recall: 0.7426 - val_f1_score: 0.7700 - val_roc_auc: 0.8813 - val_pr_auc: 0.8541 - val_cohen_kappa: 0.6263 - lr: 4.0000e-07
# Epoch 32/50
# 256/256 [==============================] - 61s 240ms/step - loss: 0.0215 - tp: 1552.0000 - fp: 12.0000 - tn: 2512.0000 - fn: 8.0000 - binary_acc: 0.9951 - precision: 0.9923 - recall: 0.9949 - f1_score: 0.9936 - roc_auc: 0.9998 - pr_auc: 0.9997 - cohen_kappa: 0.9896 - val_loss: 0.6810 - val_tp: 286.0000 - val_fp: 52.0000 - val_tn: 562.0000 - val_fn: 122.0000 - val_binary_acc: 0.8297 - val_precision: 0.8462 - val_recall: 0.7010 - val_f1_score: 0.7668 - val_roc_auc: 0.8846 - val_pr_auc: 0.8540 - val_cohen_kappa: 0.6346 - lr: 4.0000e-07
# Epoch 33/50
# 256/256 [==============================] - ETA: 0s - loss: 0.0255 - tp: 1540.0000 - fp: 14.0000 - tn: 2510.0000 - fn: 20.0000 - binary_acc: 0.9917 - precision: 0.9910 - recall: 0.9872 - f1_score: 0.9891 - roc_auc: 0.9997 - pr_auc: 0.9995 - cohen_kappa: 0.9824
# Epoch 33: ReduceLROnPlateau reducing learning rate to 8.00000009348878e-08.
# 256/256 [==============================] - 60s 234ms/step - loss: 0.0255 - tp: 1540.0000 - fp: 14.0000 - tn: 2510.0000 - fn: 20.0000 - binary_acc: 0.9917 - precision: 0.9910 - recall: 0.9872 - f1_score: 0.9891 - roc_auc: 0.9997 - pr_auc: 0.9995 - cohen_kappa: 0.9824 - val_loss: 0.6865 - val_tp: 291.0000 - val_fp: 65.0000 - val_tn: 549.0000 - val_fn: 117.0000 - val_binary_acc: 0.8219 - val_precision: 0.8174 - val_recall: 0.7132 - val_f1_score: 0.7618 - val_roc_auc: 0.8825 - val_pr_auc: 0.8462 - val_cohen_kappa: 0.6206 - lr: 4.0000e-07
# Epoch 34/50
# 256/256 [==============================] - 60s 233ms/step - loss: 0.0192 - tp: 1549.0000 - fp: 8.0000 - tn: 2516.0000 - fn: 11.0000 - binary_acc: 0.9953 - precision: 0.9949 - recall: 0.9929 - f1_score: 0.9939 - roc_auc: 0.9998 - pr_auc: 0.9998 - cohen_kappa: 0.9901 - val_loss: 0.6700 - val_tp: 294.0000 - val_fp: 71.0000 - val_tn: 543.0000 - val_fn: 114.0000 - val_binary_acc: 0.8190 - val_precision: 0.8055 - val_recall: 0.7206 - val_f1_score: 0.7607 - val_roc_auc: 0.8850 - val_pr_auc: 0.8563 - val_cohen_kappa: 0.6158 - lr: 8.0000e-08
# Epoch 35/50
# 256/256 [==============================] - 60s 233ms/step - loss: 0.0200 - tp: 1544.0000 - fp: 7.0000 - tn: 2517.0000 - fn: 16.0000 - binary_acc: 0.9944 - precision: 0.9955 - recall: 0.9897 - f1_score: 0.9926 - roc_auc: 0.9999 - pr_auc: 0.9998 - cohen_kappa: 0.9881 - val_loss: 0.6736 - val_tp: 301.0000 - val_fp: 75.0000 - val_tn: 539.0000 - val_fn: 107.0000 - val_binary_acc: 0.8219 - val_precision: 0.8005 - val_recall: 0.7377 - val_f1_score: 0.7679 - val_roc_auc: 0.8832 - val_pr_auc: 0.8543 - val_cohen_kappa: 0.6238 - lr: 8.0000e-08
# Epoch 36/50
# 256/256 [==============================] - 59s 230ms/step - loss: 0.0183 - tp: 1551.0000 - fp: 8.0000 - tn: 2516.0000 - fn: 9.0000 - binary_acc: 0.9958 - precision: 0.9949 - recall: 0.9942 - f1_score: 0.9945 - roc_auc: 0.9999 - pr_auc: 0.9998 - cohen_kappa: 0.9912 - val_loss: 0.6961 - val_tp: 300.0000 - val_fp: 64.0000 - val_tn: 550.0000 - val_fn: 108.0000 - val_binary_acc: 0.8317 - val_precision: 0.8242 - val_recall: 0.7353 - val_f1_score: 0.7772 - val_roc_auc: 0.8800 - val_pr_auc: 0.8501 - val_cohen_kappa: 0.6427 - lr: 8.0000e-08
# Epoch 37/50
# 256/256 [==============================] - 60s 233ms/step - loss: 0.0181 - tp: 1552.0000 - fp: 5.0000 - tn: 2519.0000 - fn: 8.0000 - binary_acc: 0.9968 - precision: 0.9968 - recall: 0.9949 - f1_score: 0.9958 - roc_auc: 0.9995 - pr_auc: 0.9995 - cohen_kappa: 0.9933 - val_loss: 0.6887 - val_tp: 298.0000 - val_fp: 74.0000 - val_tn: 540.0000 - val_fn: 110.0000 - val_binary_acc: 0.8200 - val_precision: 0.8011 - val_recall: 0.7304 - val_f1_score: 0.7641 - val_roc_auc: 0.8841 - val_pr_auc: 0.8593 - val_cohen_kappa: 0.6190 - lr: 8.0000e-08
# Epoch 38/50
# 256/256 [==============================] - 60s 233ms/step - loss: 0.0188 - tp: 1546.0000 - fp: 8.0000 - tn: 2516.0000 - fn: 14.0000 - binary_acc: 0.9946 - precision: 0.9949 - recall: 0.9910 - f1_score: 0.9929 - roc_auc: 0.9999 - pr_auc: 0.9998 - cohen_kappa: 0.9886 - val_loss: 0.6567 - val_tp: 308.0000 - val_fp: 74.0000 - val_tn: 540.0000 - val_fn: 100.0000 - val_binary_acc: 0.8297 - val_precision: 0.8063 - val_recall: 0.7549 - val_f1_score: 0.7797 - val_roc_auc: 0.8871 - val_pr_auc: 0.8605 - val_cohen_kappa: 0.6412 - lr: 8.0000e-08
# Epoch 39/50
# 256/256 [==============================] - 59s 232ms/step - loss: 0.0190 - tp: 1546.0000 - fp: 7.0000 - tn: 2517.0000 - fn: 14.0000 - binary_acc: 0.9949 - precision: 0.9955 - recall: 0.9910 - f1_score: 0.9933 - roc_auc: 0.9999 - pr_auc: 0.9998 - cohen_kappa: 0.9891 - val_loss: 0.7220 - val_tp: 303.0000 - val_fp: 77.0000 - val_tn: 537.0000 - val_fn: 105.0000 - val_binary_acc: 0.8219 - val_precision: 0.7974 - val_recall: 0.7426 - val_f1_score: 0.7690 - val_roc_auc: 0.8766 - val_pr_auc: 0.8468 - val_cohen_kappa: 0.6244 - lr: 8.0000e-08
# Epoch 40/50
# 256/256 [==============================] - ETA: 0s - loss: 0.0192 - tp: 1549.0000 - fp: 14.0000 - tn: 2510.0000 - fn: 11.0000 - binary_acc: 0.9939 - precision: 0.9910 - recall: 0.9929 - f1_score: 0.9920 - roc_auc: 0.9999 - pr_auc: 0.9998 - cohen_kappa: 0.9870
# Epoch 40: ReduceLROnPlateau reducing learning rate to 1.5999999902760466e-08.
# 256/256 [==============================] - 59s 229ms/step - loss: 0.0192 - tp: 1549.0000 - fp: 14.0000 - tn: 2510.0000 - fn: 11.0000 - binary_acc: 0.9939 - precision: 0.9910 - recall: 0.9929 - f1_score: 0.9920 - roc_auc: 0.9999 - pr_auc: 0.9998 - cohen_kappa: 0.9870 - val_loss: 0.7379 - val_tp: 298.0000 - val_fp: 74.0000 - val_tn: 540.0000 - val_fn: 110.0000 - val_binary_acc: 0.8200 - val_precision: 0.8011 - val_recall: 0.7304 - val_f1_score: 0.7641 - val_roc_auc: 0.8769 - val_pr_auc: 0.8418 - val_cohen_kappa: 0.6190 - lr: 8.0000e-08
# Epoch 41/50
# 256/256 [==============================] - 59s 231ms/step - loss: 0.0216 - tp: 1544.0000 - fp: 12.0000 - tn: 2512.0000 - fn: 16.0000 - binary_acc: 0.9931 - precision: 0.9923 - recall: 0.9897 - f1_score: 0.9910 - roc_auc: 0.9998 - pr_auc: 0.9997 - cohen_kappa: 0.9855 - val_loss: 0.6949 - val_tp: 302.0000 - val_fp: 85.0000 - val_tn: 529.0000 - val_fn: 106.0000 - val_binary_acc: 0.8131 - val_precision: 0.7804 - val_recall: 0.7402 - val_f1_score: 0.7597 - val_roc_auc: 0.8797 - val_pr_auc: 0.8487 - val_cohen_kappa: 0.6070 - lr: 1.6000e-08
# Epoch 42/50
# 256/256 [==============================] - 59s 231ms/step - loss: 0.0208 - tp: 1548.0000 - fp: 9.0000 - tn: 2515.0000 - fn: 12.0000 - binary_acc: 0.9949 - precision: 0.9942 - recall: 0.9923 - f1_score: 0.9933 - roc_auc: 0.9998 - pr_auc: 0.9997 - cohen_kappa: 0.9891 - val_loss: 0.7014 - val_tp: 306.0000 - val_fp: 73.0000 - val_tn: 541.0000 - val_fn: 102.0000 - val_binary_acc: 0.8288 - val_precision: 0.8074 - val_recall: 0.7500 - val_f1_score: 0.7776 - val_roc_auc: 0.8793 - val_pr_auc: 0.8382 - val_cohen_kappa: 0.6387 - lr: 1.6000e-08
# Epoch 43/50
# 256/256 [==============================] - 60s 234ms/step - loss: 0.0192 - tp: 1545.0000 - fp: 9.0000 - tn: 2515.0000 - fn: 15.0000 - binary_acc: 0.9941 - precision: 0.9942 - recall: 0.9904 - f1_score: 0.9923 - roc_auc: 0.9999 - pr_auc: 0.9998 - cohen_kappa: 0.9875 - val_loss: 0.7231 - val_tp: 294.0000 - val_fp: 80.0000 - val_tn: 534.0000 - val_fn: 114.0000 - val_binary_acc: 0.8102 - val_precision: 0.7861 - val_recall: 0.7206 - val_f1_score: 0.7519 - val_roc_auc: 0.8808 - val_pr_auc: 0.8475 - val_cohen_kappa: 0.5987 - lr: 1.6000e-08
# Epoch 44/50
# 256/256 [==============================] - ETA: 0s - loss: 0.0186 - tp: 1546.0000 - fp: 7.0000 - tn: 2517.0000 - fn: 14.0000 - binary_acc: 0.9949 - precision: 0.9955 - recall: 0.9910 - f1_score: 0.9933 - roc_auc: 0.9999 - pr_auc: 0.9998 - cohen_kappa: 0.9891
# Epoch 44: ReduceLROnPlateau reducing learning rate to 3.1999999094978194e-09.
# 256/256 [==============================] - 59s 231ms/step - loss: 0.0186 - tp: 1546.0000 - fp: 7.0000 - tn: 2517.0000 - fn: 14.0000 - binary_acc: 0.9949 - precision: 0.9955 - recall: 0.9910 - f1_score: 0.9933 - roc_auc: 0.9999 - pr_auc: 0.9998 - cohen_kappa: 0.9891 - val_loss: 0.6944 - val_tp: 305.0000 - val_fp: 78.0000 - val_tn: 536.0000 - val_fn: 103.0000 - val_binary_acc: 0.8229 - val_precision: 0.7963 - val_recall: 0.7475 - val_f1_score: 0.7712 - val_roc_auc: 0.8845 - val_pr_auc: 0.8584 - val_cohen_kappa: 0.6270 - lr: 1.6000e-08
# Epoch 45/50
# 256/256 [==============================] - 59s 229ms/step - loss: 0.0162 - tp: 1554.0000 - fp: 7.0000 - tn: 2517.0000 - fn: 6.0000 - binary_acc: 0.9968 - precision: 0.9955 - recall: 0.9962 - f1_score: 0.9958 - roc_auc: 0.9999 - pr_auc: 0.9999 - cohen_kappa: 0.9933 - val_loss: 0.6831 - val_tp: 300.0000 - val_fp: 69.0000 - val_tn: 545.0000 - val_fn: 108.0000 - val_binary_acc: 0.8268 - val_precision: 0.8130 - val_recall: 0.7353 - val_f1_score: 0.7722 - val_roc_auc: 0.8896 - val_pr_auc: 0.8571 - val_cohen_kappa: 0.6331 - lr: 3.2000e-09
# Epoch 46/50
# 256/256 [==============================] - 59s 229ms/step - loss: 0.0193 - tp: 1546.0000 - fp: 9.0000 - tn: 2515.0000 - fn: 14.0000 - binary_acc: 0.9944 - precision: 0.9942 - recall: 0.9910 - f1_score: 0.9926 - roc_auc: 0.9999 - pr_auc: 0.9998 - cohen_kappa: 0.9881 - val_loss: 0.6734 - val_tp: 304.0000 - val_fp: 74.0000 - val_tn: 540.0000 - val_fn: 104.0000 - val_binary_acc: 0.8258 - val_precision: 0.8042 - val_recall: 0.7451 - val_f1_score: 0.7735 - val_roc_auc: 0.8843 - val_pr_auc: 0.8477 - val_cohen_kappa: 0.6324 - lr: 3.2000e-09
# Epoch 47/50
# 256/256 [==============================] - 59s 232ms/step - loss: 0.0206 - tp: 1548.0000 - fp: 11.0000 - tn: 2513.0000 - fn: 12.0000 - binary_acc: 0.9944 - precision: 0.9929 - recall: 0.9923 - f1_score: 0.9926 - roc_auc: 0.9998 - pr_auc: 0.9997 - cohen_kappa: 0.9881 - val_loss: 0.7222 - val_tp: 300.0000 - val_fp: 75.0000 - val_tn: 539.0000 - val_fn: 108.0000 - val_binary_acc: 0.8209 - val_precision: 0.8000 - val_recall: 0.7353 - val_f1_score: 0.7663 - val_roc_auc: 0.8762 - val_pr_auc: 0.8416 - val_cohen_kappa: 0.6216 - lr: 3.2000e-09
# Epoch 48/50
# 256/256 [==============================] - ETA: 0s - loss: 0.0171 - tp: 1547.0000 - fp: 8.0000 - tn: 2516.0000 - fn: 13.0000 - binary_acc: 0.9949 - precision: 0.9949 - recall: 0.9917 - f1_score: 0.9933 - roc_auc: 0.9999 - pr_auc: 0.9999 - cohen_kappa: 0.9891
# Epoch 48: ReduceLROnPlateau reducing learning rate to 6.399999641359955e-10.
# 256/256 [==============================] - 60s 233ms/step - loss: 0.0171 - tp: 1547.0000 - fp: 8.0000 - tn: 2516.0000 - fn: 13.0000 - binary_acc: 0.9949 - precision: 0.9949 - recall: 0.9917 - f1_score: 0.9933 - roc_auc: 0.9999 - pr_auc: 0.9999 - cohen_kappa: 0.9891 - val_loss: 0.6630 - val_tp: 303.0000 - val_fp: 78.0000 - val_tn: 536.0000 - val_fn: 105.0000 - val_binary_acc: 0.8209 - val_precision: 0.7953 - val_recall: 0.7426 - val_f1_score: 0.7681 - val_roc_auc: 0.8926 - val_pr_auc: 0.8666 - val_cohen_kappa: 0.6225 - lr: 3.2000e-09
# Epoch 49/50
# 256/256 [==============================] - 60s 233ms/step - loss: 0.0208 - tp: 1540.0000 - fp: 5.0000 - tn: 2519.0000 - fn: 20.0000 - binary_acc: 0.9939 - precision: 0.9968 - recall: 0.9872 - f1_score: 0.9919 - roc_auc: 0.9998 - pr_auc: 0.9997 - cohen_kappa: 0.9870 - val_loss: 0.7147 - val_tp: 297.0000 - val_fp: 69.0000 - val_tn: 545.0000 - val_fn: 111.0000 - val_binary_acc: 0.8239 - val_precision: 0.8115 - val_recall: 0.7279 - val_f1_score: 0.7674 - val_roc_auc: 0.8787 - val_pr_auc: 0.8445 - val_cohen_kappa: 0.6264 - lr: 6.4000e-10
# Epoch 50/50
# 256/256 [==============================] - 60s 234ms/step - loss: 0.0181 - tp: 1547.0000 - fp: 8.0000 - tn: 2516.0000 - fn: 13.0000 - binary_acc: 0.9949 - precision: 0.9949 - recall: 0.9917 - f1_score: 0.9933 - roc_auc: 0.9999 - pr_auc: 0.9999 - cohen_kappa: 0.9891 - val_loss: 0.6912 - val_tp: 296.0000 - val_fp: 73.0000 - val_tn: 541.0000 - val_fn: 112.0000 - val_binary_acc: 0.8190 - val_precision: 0.8022 - val_recall: 0.7255 - val_f1_score: 0.7619 - val_roc_auc: 0.8829 - val_pr_auc: 0.8543 - val_cohen_kappa: 0.6165 - lr: 6.4000e-10

# %%
new_model.save(save_path + model_name + '.keras')
plot_metrics(history)

# %%
new_model.evaluate(validation_generator)
new_model.evaluate(test_generator)

# Make predictions using the validation generator
y_valid_pred_prob = new_model.predict(validation_generator)
y_valid_pred = (y_valid_pred_prob > 0.5).astype(int)
y_valid = validation_generator.classes
print("Classification Report:")
print(classification_report(y_valid, y_valid_pred))

# Make predictions using the test generator
y_pred_prob = new_model.predict(test_generator)
y_pred = (y_pred_prob > 0.5).astype(int)
y_test = test_generator.classes
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# 64/64 [==============================] - 10s 146ms/step - loss: 0.6849 - tp: 305.0000 - fp: 73.0000 - tn: 541.0000 - fn: 103.0000 - binary_acc: 0.8278 - precision: 0.8069 - recall: 0.7475 - f1_score: 0.7761 - roc_auc: 0.8849 - pr_auc: 0.8592 - cohen_kappa: 0.6365
# 29/29 [==============================] - 2s 67ms/step - loss: 1.1032 - tp: 173.0000 - fp: 34.0000 - tn: 180.0000 - fn: 74.0000 - binary_acc: 0.7657 - precision: 0.8357 - recall: 0.7004 - f1_score: 0.7621 - roc_auc: 0.8253 - pr_auc: 0.8512 - cohen_kappa: 0.5348
# 64/64 [==============================] - 12s 147ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.88      0.85       614
#            1       0.80      0.73      0.76       408
#
#     accuracy                           0.82      1022
#    macro avg       0.81      0.80      0.81      1022
# weighted avg       0.82      0.82      0.82      1022
#
# 29/29 [==============================] - 2s 61ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.71      0.84      0.77       214
#            1       0.84      0.70      0.76       247
#
#     accuracy                           0.77       461
#    macro avg       0.77      0.77      0.77       461
# weighted avg       0.78      0.77      0.77       461

# %%
conf_matrix = confusion_matrix(y_test, y_pred)

# Create ConfusionMatrixDisplay object
cm_display = ConfusionMatrixDisplay(confusion_matrix=conf_matrix)

# Plot the confusion matrix
plt.figure(figsize=(4, 6))  # Adjust the figure size as needed
cm_display.plot(cmap=plt.cm.Blues)  # You can choose any colormap you prefer
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.grid(False)  # Turn off grid
plt.savefig(save_path + model_name + "_confusion_matrix.jpg")
plt.show()

# %%
history_df = pd.DataFrame(history.history)
save_history(model_name, history_df)
# Out:
# Training history saved to: C:/Users/raouf/Desktop/pfe/history/final/densenet/XR_FINGER/finetuned_DenseNet_XR_FINGER_history.xlsx
