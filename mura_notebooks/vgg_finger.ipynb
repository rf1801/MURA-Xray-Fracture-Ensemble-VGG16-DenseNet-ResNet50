# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
import tensorflow as tf
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras import layers, models
from keras.layers import concatenate, Dense, Conv2D, MaxPooling2D, Flatten, Activation, BatchNormalization, Dropout, \
    Attention
from keras import *
from keras.applications import MobileNet
from keras.applications import VGG16
from keras.applications.resnet import ResNet50
from keras import backend as K
from keras.layers import Layer
import keras.layers as kl
import pandas as pd
from keras.applications import EfficientNetB0
import keras.applications
import numpy as np
import os
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from sklearn.metrics import cohen_kappa_score
import seaborn as sns
import pickle
import tensorflow_addons as tfa
from sklearn import metrics
from tensorflow.keras.applications.resnet import preprocess_input as preprocess_input_resnet
from tensorflow.keras.applications.densenet import preprocess_input as preprocess_input_densenet
from tensorflow.keras.models import load_model
import os
import glob
# Out:
# c:\Users\raouf\miniconda3\envs\tensorflowgpu\lib\site-packages\tensorflow_addons\utils\tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# c:\Users\raouf\miniconda3\envs\tensorflowgpu\lib\site-packages\tensorflow_addons\utils\ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.12.0 and strictly below 2.15.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.10.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %%
main_save_path = "C:/Users/raouf/Desktop/pfe/history/final/vgg/"
mura_location = "C:/Users/raouf/Desktop/pfe/"
data_path = 'C:/Users/raouf/Desktop/pfe/MURA-v1.1/'
train_path = 'C:/Users/raouf/Desktop/pfe/MURA-v1.1/train'
test_path = 'C:/Users/raouf/Desktop/pfe/MURA-v1.1/valid'

train_file = "C:/Users/raouf/Desktop/pfe/datasets/XR_FINGER_df_train.csv"
val_file = "C:/Users/raouf/Desktop/pfe/datasets/XR_FINGER_df_valid.csv"

test_file = "C:/Users/raouf/Desktop/pfe/MURA-v1.1/valid_image_paths.csv"

target_category = "XR_FINGER"
batch_size = 16
num_epochs = 100
fine_tuning_epochs=50
validation_split = 0.2
loss_function = tf.keras.losses.BinaryCrossentropy()
learning_rate = 0.0001
input_shape = (224, 224, 3)
architecture = 'VGG'

include_top = False
# metrics=["accuracy"] #, tf.keras.metrics.Precision(), tf.keras.metrics.Recall()
early_stopping_patience = 15
shuffle = True
class_mode = 'binary'  # 'categorical'
IMAGE_WIDTH = 224
IMAGE_HEIGHT = 224
trainable = False
training = False
dropout = 0.2

# %%
def load_data(file, part):
    train_data = pd.read_csv(file)
    train_data = train_data.rename(columns={train_data.columns[0]: 'image_path'})
    train_data['label'] = 2
    string_to_add = mura_location
    train_data['image_path'] = string_to_add + train_data['image_path'].astype(str)
    for index, row in train_data.iterrows():
        if 'positive' in str(row['image_path']).lower():
            train_data.at[index, 'label'] = "positive"
        else:
            train_data.at[index, 'label'] = "negative"

    if part == 0:
        pass
    else:
        train_data = train_data[train_data['image_path'].str.contains(part)]
    return train_data


class CustomCallback(keras.callbacks.Callback):
    def on_test_end(self, logs=None):
        keys = list(logs.keys())
        print(f"tp          :", logs["tp"])
        print(f"fp          :", logs["fp"])
        print(f"tn          :", logs["tn"])
        print(f"fn          :", logs["fn"])
        print(f"binary_acc  :", logs["binary_acc"])
        print(f"precision   :", logs["precision"])
        print(f"recall      :", logs["recall"])
        print(f"f1_score    :", logs["f1_score"])
        print(f"roc_auc     :", logs["roc_auc"])
        print(f"pr_auc      :", logs["pr_auc"])
        print(f"cohen_kappa :", logs["cohen_kappa"])

class F1Score(tf.keras.metrics.Metric):

    def __init__(self, name="f1_score", **kwargs):
        super().__init__(name=name, **kwargs)
        self.f1 = self.add_weight(name="f1", initializer="zeros")
        self.precision_fn = tf.keras.metrics.Precision()
        self.recall_fn = tf.keras.metrics.Recall()

    def update_state(self, y_true, y_pred, sample_weight=None):
        p = self.precision_fn(y_true, y_pred)
        r = self.recall_fn(y_true, y_pred)
        self.f1.assign(2 * ((p * r) / (p + r + 1e-10)))

    def result(self):
        return self.f1

    def reset_state(self):
        # we also need to reset the state of the precision and recall objects
        self.precision_fn.reset_state()
        self.recall_fn.reset_state()
        self.f1.assign(0)


def save_history(name,history_df):

    history_excel_path = (
            save_path +
            name +
            '_history'
            '.xlsx'
    )

    history_df.to_excel(history_excel_path, index=False)
    print("Training history saved to:", history_excel_path)






def plot_metrics(history: tf.keras.callbacks.History,
                 metrics: list = ["loss", "cohen_kappa", "precision", "recall"],
                 ) -> None:
    plt.rcParams["figure.figsize"] = (18, 15)

    for n, metric in enumerate(metrics):
        name = metric.replace("_", " ").capitalize()
        plt.subplot(2, 2, n + 1)
        plt.plot(
            history.epoch, history.history[metric], linewidth=1.8, label="training"
        )
        plt.plot(
            history.epoch,
            history.history["val_" + metric],
            linestyle="--",
            linewidth=1.8,
            label="validation",
        )
        plt.xlabel("epoch")
        plt.ylabel(name)
        if metric == "loss":
            plt.ylim([0, plt.ylim()[1]])
        elif metric == "cohen_kappa":
            plt.ylim([-1, 1])
        else:
            plt.ylim([0, 1])

        plt.legend()



class CustomCallback(keras.callbacks.Callback):
    def on_test_end(self, logs=None):
        keys = list(logs.keys())
        print(f"tp          :", logs["tp"])
        print(f"fp          :", logs["fp"])
        print(f"tn          :", logs["tn"])
        print(f"fn          :", logs["fn"])
        print(f"binary_acc  :", logs["binary_acc"])
        print(f"precision   :", logs["precision"])
        print(f"recall      :", logs["recall"])
        print(f"f1_score    :", logs["f1_score"])
        print(f"roc_auc     :", logs["roc_auc"])
        print(f"pr_auc      :", logs["pr_auc"])
        print(f"cohen_kappa :", logs["cohen_kappa"])


def save_history(name,history_df):

    # Constructing the file name with metric values
    history_excel_path = (
            save_path +
            name +
            '_history'
            '.xlsx'
    )

    history_df.to_excel(history_excel_path, index=False)
    print("Training history saved to:", history_excel_path)




class F1Score(tf.keras.metrics.Metric):

    def __init__(self, name="f1_score", **kwargs):
        super().__init__(name=name, **kwargs)
        self.f1 = self.add_weight(name="f1", initializer="zeros")
        self.precision_fn = tf.keras.metrics.Precision()
        self.recall_fn = tf.keras.metrics.Recall()

    def update_state(self, y_true, y_pred, sample_weight=None):
        p = self.precision_fn(y_true, y_pred)
        r = self.recall_fn(y_true, y_pred)
        self.f1.assign(2 * ((p * r) / (p + r + 1e-10)))

    def result(self):
        return self.f1

    def reset_state(self):
        # we also need to reset the state of the precision and recall objects
        self.precision_fn.reset_state()
        self.recall_fn.reset_state()
        self.f1.assign(0)

def plot_metrics(history: tf.keras.callbacks.History,
                 metrics: list = ["loss", "cohen_kappa", "precision", "recall"],
                 ) -> None:
    plt.rcParams["figure.figsize"] = (18, 15)

    for n, metric in enumerate(metrics):
        name = metric.replace("_", " ").capitalize()
        plt.subplot(2, 2, n + 1)
        plt.plot(
            history.epoch, history.history[metric], linewidth=1.8, label="training"
        )
        plt.plot(
            history.epoch,
            history.history["val_" + metric],
            linestyle="--",
            linewidth=1.8,
            label="validation",
        )
        plt.xlabel("epoch")
        plt.ylabel(name)
        if metric == "loss":
            plt.ylim([0, plt.ylim()[1]])
        elif metric == "cohen_kappa":
            plt.ylim([-1, 1])
        else:
            plt.ylim([0, 1])

        plt.legend()


def my_func(model, data_generator, threshold=0.5):
    y_pred_prob = model.predict(data_generator)
    y_pred = (y_pred_prob > threshold).astype(int)
    y_true = data_generator.classes
    print("Classification Report:")
    print(classification_report(y_true, y_pred))

# %%
METRICS = [
    tf.keras.metrics.TruePositives(name="tp"),
    tf.keras.metrics.FalsePositives(name="fp"),
    tf.keras.metrics.TrueNegatives(name="tn"),
    tf.keras.metrics.FalseNegatives(name="fn"),
    tf.keras.metrics.BinaryAccuracy(name="binary_acc"),
    tf.keras.metrics.Precision(name="precision"),
    tf.keras.metrics.Recall(name="recall"),
    F1Score(name="f1_score"),
    tf.keras.metrics.AUC(name="roc_auc", curve="ROC"),
    tf.keras.metrics.AUC(name="pr_auc", curve="PR"),
    tfa.metrics.CohenKappa(name="cohen_kappa", num_classes=2),
]

# %%
vgg = tf.keras.applications.vgg16.VGG16(include_top=include_top,
                                                 weights="imagenet",
                                                 input_shape=(IMAGE_WIDTH, IMAGE_HEIGHT, 3),
                                                # pooling="max",  # pooling mode for feature extraction
                                                 classes=2)

def make_vgg16_model(base_model: tf.keras.applications.vgg16.VGG16,) -> tf.keras.Model:

    # freeze base model
    base_model.trainable = False#trainable

    inputs = tf.keras.Input(shape=(IMAGE_WIDTH, IMAGE_HEIGHT, 3))
    x = base_model(inputs, training=training)
    x = tf.keras.layers.Flatten()(x)
    #x = tf.keras.layers.Dense(4096, activation='relu')(x)
    x = tf.keras.layers.Dense(1024, activation='relu')(x)
    x = tf.keras.layers.Dropout(rate=dropout)(x)
    x = tf.keras.layers.Dense(512, activation='relu')(x)
   # x = tf.keras.layers.Dropout(rate=dropout)(x)

    output = tf.keras.layers.Dense(units=1, activation="sigmoid")(x)

    model = tf.keras.Model(inputs, output)

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
        loss=loss_function,
        metrics=METRICS,
    )

    return model


new_model = make_vgg16_model(base_model=vgg)

new_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 1024)              25691136
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  dense_2 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 40,931,137
# Trainable params: 26,216,449
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
"""import matplotlib.pyplot as plt
from tensorflow.keras.utils import plot_model
tf.keras.utils.plot_model(new_model,
                          show_shapes=True,  # show_dtype=False,
                          show_layer_names=True,
                          layer_range=None,
                          show_layer_activations=True)"""
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
early_stopping = EarlyStopping(monitor="val_cohen_kappa",
                               verbose=1,
                               patience=early_stopping_patience,
                               mode="max",
                               baseline=0.0,
                               restore_best_weights=True)
save_path = main_save_path + target_category + "/"
model_name = architecture + "_" + target_category
model_path = save_path + '_best_' + model_name + '.keras'
model_checkpoint = ModelCheckpoint(filepath=model_path,
                                       monitor="val_cohen_kappa",
                                       save_best_only=True)

# %%
import pandas as pd


old_base_path = 'C:\\Users\\HP\\Documents\\ML\\encadrement Master\\MURA-V1.1\\'

df_train = pd.read_csv(train_file)
df_train['image_path'] = df_train['image_path'].str.replace(old_base_path, mura_location)

df_valid = pd.read_csv(val_file)
df_valid['image_path'] = df_valid['image_path'].str.replace(old_base_path, mura_location)


df_test = load_data(test_file, target_category)

datagen = tf.keras.preprocessing.image.ImageDataGenerator(rotation_range=30,
                                                              horizontal_flip=True,
                                                              fill_mode="constant",
                                                              cval=0.0,
                                                              preprocessing_function=tf.keras.applications.vgg16.preprocess_input)
train_generator = datagen.flow_from_dataframe(df_train,
                                                  directory=None,
                                                  x_col='image_path',
                                                  y_col='label',
                                                  target_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
                                                  batch_size=batch_size,
                                                  class_mode=class_mode,
                                                  )

validation_generator = datagen.flow_from_dataframe(df_valid,
                                                       directory=None,
                                                       x_col='image_path',
                                                       y_col='label',
                                                       target_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
                                                       batch_size=batch_size,
                                                       class_mode=class_mode,
                                                   shuffle=False
                                                       )

test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
        preprocessing_function=tf.keras.applications.vgg16.preprocess_input)
test_generator = test_datagen.flow_from_dataframe(df_test,
                                                      directory=None,
                                                      x_col='image_path',
                                                      y_col='label',
                                                      target_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
                                                      batch_size=batch_size,
                                                      class_mode=class_mode,
                                                  shuffle=False
                                                      )
# Out:
# C:\Users\raouf\AppData\Local\Temp\ipykernel_22500\1983201427.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'positive' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_data.at[index, 'label'] = "positive"
# Found 4084 validated image filenames belonging to 2 classes.
# Found 1022 validated image filenames belonging to 2 classes.
# Found 461 validated image filenames belonging to 2 classes.

# %%
history = new_model.fit(train_generator,
                            # teps_per_epoch=len(df_train) // batch_size,
                            validation_data=validation_generator,
                            # validation_steps=len(df_valid) // batch_size,
                            epochs=num_epochs,
                            shuffle=shuffle,
                            callbacks=[early_stopping, model_checkpoint])  # , reduce_lr_callback])
# Out:
# Epoch 1/100
# 256/256 [==============================] - 55s 181ms/step - loss: 1.3170 - tp: 796.0000 - fp: 721.0000 - tn: 1803.0000 - fn: 764.0000 - binary_acc: 0.6364 - precision: 0.5247 - recall: 0.5103 - f1_score: 0.5174 - roc_auc: 0.6569 - pr_auc: 0.5167 - cohen_kappa: 0.2258 - val_loss: 0.8336 - val_tp: 171.0000 - val_fp: 94.0000 - val_tn: 520.0000 - val_fn: 237.0000 - val_binary_acc: 0.6761 - val_precision: 0.6453 - val_recall: 0.4191 - val_f1_score: 0.5082 - val_roc_auc: 0.7171 - val_pr_auc: 0.6337 - val_cohen_kappa: 0.2826
# Epoch 2/100
# 256/256 [==============================] - 39s 150ms/step - loss: 0.7599 - tp: 895.0000 - fp: 602.0000 - tn: 1922.0000 - fn: 665.0000 - binary_acc: 0.6898 - precision: 0.5979 - recall: 0.5737 - f1_score: 0.5855 - roc_auc: 0.7417 - pr_auc: 0.6281 - cohen_kappa: 0.3378 - val_loss: 0.7243 - val_tp: 321.0000 - val_fp: 225.0000 - val_tn: 389.0000 - val_fn: 87.0000 - val_binary_acc: 0.6947 - val_precision: 0.5879 - val_recall: 0.7868 - val_f1_score: 0.6730 - val_roc_auc: 0.7717 - val_pr_auc: 0.6783 - val_cohen_kappa: 0.3977
# Epoch 3/100
# 256/256 [==============================] - 40s 156ms/step - loss: 0.6483 - tp: 958.0000 - fp: 537.0000 - tn: 1987.0000 - fn: 602.0000 - binary_acc: 0.7211 - precision: 0.6408 - recall: 0.6141 - f1_score: 0.6272 - roc_auc: 0.7776 - pr_auc: 0.6798 - cohen_kappa: 0.4046 - val_loss: 0.6518 - val_tp: 304.0000 - val_fp: 198.0000 - val_tn: 416.0000 - val_fn: 104.0000 - val_binary_acc: 0.7045 - val_precision: 0.6056 - val_recall: 0.7451 - val_f1_score: 0.6681 - val_roc_auc: 0.7965 - val_pr_auc: 0.7180 - val_cohen_kappa: 0.4069
# Epoch 4/100
# 256/256 [==============================] - 40s 155ms/step - loss: 0.5924 - tp: 974.0000 - fp: 512.0000 - tn: 2012.0000 - fn: 586.0000 - binary_acc: 0.7311 - precision: 0.6555 - recall: 0.6244 - f1_score: 0.6395 - roc_auc: 0.7974 - pr_auc: 0.7110 - cohen_kappa: 0.4254 - val_loss: 0.7042 - val_tp: 158.0000 - val_fp: 56.0000 - val_tn: 558.0000 - val_fn: 250.0000 - val_binary_acc: 0.7006 - val_precision: 0.7383 - val_recall: 0.3873 - val_f1_score: 0.5080 - val_roc_auc: 0.7589 - val_pr_auc: 0.6846 - val_cohen_kappa: 0.3217
# Epoch 5/100
# 256/256 [==============================] - 40s 158ms/step - loss: 0.5469 - tp: 1011.0000 - fp: 448.0000 - tn: 2076.0000 - fn: 549.0000 - binary_acc: 0.7559 - precision: 0.6929 - recall: 0.6481 - f1_score: 0.6698 - roc_auc: 0.8235 - pr_auc: 0.7429 - cohen_kappa: 0.4765 - val_loss: 0.6356 - val_tp: 207.0000 - val_fp: 73.0000 - val_tn: 541.0000 - val_fn: 201.0000 - val_binary_acc: 0.7319 - val_precision: 0.7393 - val_recall: 0.5074 - val_f1_score: 0.6017 - val_roc_auc: 0.7876 - val_pr_auc: 0.7309 - val_cohen_kappa: 0.4100
# Epoch 6/100
# 256/256 [==============================] - 41s 159ms/step - loss: 0.5388 - tp: 1027.0000 - fp: 458.0000 - tn: 2066.0000 - fn: 533.0000 - binary_acc: 0.7573 - precision: 0.6916 - recall: 0.6583 - f1_score: 0.6745 - roc_auc: 0.8267 - pr_auc: 0.7561 - cohen_kappa: 0.4813 - val_loss: 0.5643 - val_tp: 265.0000 - val_fp: 119.0000 - val_tn: 495.0000 - val_fn: 143.0000 - val_binary_acc: 0.7436 - val_precision: 0.6901 - val_recall: 0.6495 - val_f1_score: 0.6692 - val_roc_auc: 0.8118 - val_pr_auc: 0.7458 - val_cohen_kappa: 0.4602
# Epoch 7/100
# 256/256 [==============================] - 41s 160ms/step - loss: 0.5192 - tp: 1034.0000 - fp: 431.0000 - tn: 2093.0000 - fn: 526.0000 - binary_acc: 0.7657 - precision: 0.7058 - recall: 0.6628 - f1_score: 0.6836 - roc_auc: 0.8356 - pr_auc: 0.7628 - cohen_kappa: 0.4978 - val_loss: 0.5900 - val_tp: 287.0000 - val_fp: 157.0000 - val_tn: 457.0000 - val_fn: 121.0000 - val_binary_acc: 0.7280 - val_precision: 0.6464 - val_recall: 0.7034 - val_f1_score: 0.6737 - val_roc_auc: 0.8009 - val_pr_auc: 0.7427 - val_cohen_kappa: 0.4412
# Epoch 8/100
# 256/256 [==============================] - 41s 161ms/step - loss: 0.4742 - tp: 1108.0000 - fp: 387.0000 - tn: 2137.0000 - fn: 452.0000 - binary_acc: 0.7946 - precision: 0.7411 - recall: 0.7103 - f1_score: 0.7254 - roc_auc: 0.8633 - pr_auc: 0.8046 - cohen_kappa: 0.5614 - val_loss: 0.5641 - val_tp: 252.0000 - val_fp: 100.0000 - val_tn: 514.0000 - val_fn: 156.0000 - val_binary_acc: 0.7495 - val_precision: 0.7159 - val_recall: 0.6176 - val_f1_score: 0.6632 - val_roc_auc: 0.8250 - val_pr_auc: 0.7592 - val_cohen_kappa: 0.4655
# Epoch 9/100
# 256/256 [==============================] - 42s 162ms/step - loss: 0.4835 - tp: 1098.0000 - fp: 401.0000 - tn: 2123.0000 - fn: 462.0000 - binary_acc: 0.7887 - precision: 0.7325 - recall: 0.7038 - f1_score: 0.7179 - roc_auc: 0.8590 - pr_auc: 0.7954 - cohen_kappa: 0.5491 - val_loss: 0.5276 - val_tp: 274.0000 - val_fp: 100.0000 - val_tn: 514.0000 - val_fn: 134.0000 - val_binary_acc: 0.7710 - val_precision: 0.7326 - val_recall: 0.6716 - val_f1_score: 0.7008 - val_roc_auc: 0.8221 - val_pr_auc: 0.7658 - val_cohen_kappa: 0.5159
# Epoch 10/100
# 256/256 [==============================] - 41s 162ms/step - loss: 0.4376 - tp: 1131.0000 - fp: 344.0000 - tn: 2180.0000 - fn: 429.0000 - binary_acc: 0.8107 - precision: 0.7668 - recall: 0.7250 - f1_score: 0.7453 - roc_auc: 0.8799 - pr_auc: 0.8278 - cohen_kappa: 0.5949 - val_loss: 0.5494 - val_tp: 248.0000 - val_fp: 107.0000 - val_tn: 507.0000 - val_fn: 160.0000 - val_binary_acc: 0.7387 - val_precision: 0.6986 - val_recall: 0.6078 - val_f1_score: 0.6501 - val_roc_auc: 0.8234 - val_pr_auc: 0.7611 - val_cohen_kappa: 0.4432
# Epoch 11/100
# 256/256 [==============================] - 42s 165ms/step - loss: 0.4208 - tp: 1149.0000 - fp: 334.0000 - tn: 2190.0000 - fn: 411.0000 - binary_acc: 0.8176 - precision: 0.7748 - recall: 0.7365 - f1_score: 0.7552 - roc_auc: 0.8884 - pr_auc: 0.8358 - cohen_kappa: 0.6100 - val_loss: 0.5086 - val_tp: 270.0000 - val_fp: 88.0000 - val_tn: 526.0000 - val_fn: 138.0000 - val_binary_acc: 0.7789 - val_precision: 0.7542 - val_recall: 0.6618 - val_f1_score: 0.7050 - val_roc_auc: 0.8466 - val_pr_auc: 0.8014 - val_cohen_kappa: 0.5293
# Epoch 12/100
# 256/256 [==============================] - 45s 178ms/step - loss: 0.4042 - tp: 1156.0000 - fp: 337.0000 - tn: 2187.0000 - fn: 404.0000 - binary_acc: 0.8186 - precision: 0.7743 - recall: 0.7410 - f1_score: 0.7573 - roc_auc: 0.8953 - pr_auc: 0.8502 - cohen_kappa: 0.6125 - val_loss: 0.6460 - val_tp: 185.0000 - val_fp: 42.0000 - val_tn: 572.0000 - val_fn: 223.0000 - val_binary_acc: 0.7407 - val_precision: 0.8150 - val_recall: 0.4534 - val_f1_score: 0.5827 - val_roc_auc: 0.8322 - val_pr_auc: 0.7773 - val_cohen_kappa: 0.4160
# Epoch 13/100
# 256/256 [==============================] - 44s 170ms/step - loss: 0.3952 - tp: 1151.0000 - fp: 315.0000 - tn: 2209.0000 - fn: 409.0000 - binary_acc: 0.8227 - precision: 0.7851 - recall: 0.7378 - f1_score: 0.7607 - roc_auc: 0.9014 - pr_auc: 0.8584 - cohen_kappa: 0.6202 - val_loss: 0.5671 - val_tp: 254.0000 - val_fp: 103.0000 - val_tn: 511.0000 - val_fn: 154.0000 - val_binary_acc: 0.7485 - val_precision: 0.7115 - val_recall: 0.6225 - val_f1_score: 0.6641 - val_roc_auc: 0.8230 - val_pr_auc: 0.7689 - val_cohen_kappa: 0.4645
# Epoch 14/100
# 256/256 [==============================] - 44s 170ms/step - loss: 0.3675 - tp: 1202.0000 - fp: 310.0000 - tn: 2214.0000 - fn: 358.0000 - binary_acc: 0.8364 - precision: 0.7950 - recall: 0.7705 - f1_score: 0.7826 - roc_auc: 0.9134 - pr_auc: 0.8772 - cohen_kappa: 0.6515 - val_loss: 0.6638 - val_tp: 355.0000 - val_fp: 242.0000 - val_tn: 372.0000 - val_fn: 53.0000 - val_binary_acc: 0.7114 - val_precision: 0.5946 - val_recall: 0.8701 - val_f1_score: 0.7065 - val_roc_auc: 0.8381 - val_pr_auc: 0.7842 - val_cohen_kappa: 0.4416
# Epoch 15/100
# 256/256 [==============================] - 48s 186ms/step - loss: 0.3672 - tp: 1224.0000 - fp: 308.0000 - tn: 2216.0000 - fn: 336.0000 - binary_acc: 0.8423 - precision: 0.7990 - recall: 0.7846 - f1_score: 0.7917 - roc_auc: 0.9149 - pr_auc: 0.8769 - cohen_kappa: 0.6649 - val_loss: 0.6501 - val_tp: 194.0000 - val_fp: 41.0000 - val_tn: 573.0000 - val_fn: 214.0000 - val_binary_acc: 0.7505 - val_precision: 0.8255 - val_recall: 0.4755 - val_f1_score: 0.6034 - val_roc_auc: 0.8347 - val_pr_auc: 0.7889 - val_cohen_kappa: 0.4400
# Epoch 16/100
# 256/256 [==============================] - 43s 167ms/step - loss: 0.3325 - tp: 1225.0000 - fp: 272.0000 - tn: 2252.0000 - fn: 335.0000 - binary_acc: 0.8514 - precision: 0.8183 - recall: 0.7853 - f1_score: 0.8014 - roc_auc: 0.9292 - pr_auc: 0.8995 - cohen_kappa: 0.6828 - val_loss: 0.5752 - val_tp: 281.0000 - val_fp: 124.0000 - val_tn: 490.0000 - val_fn: 127.0000 - val_binary_acc: 0.7544 - val_precision: 0.6938 - val_recall: 0.6887 - val_f1_score: 0.6913 - val_roc_auc: 0.8325 - val_pr_auc: 0.7981 - val_cohen_kappa: 0.4874
# Epoch 17/100
# 256/256 [==============================] - 43s 167ms/step - loss: 0.3447 - tp: 1219.0000 - fp: 288.0000 - tn: 2236.0000 - fn: 341.0000 - binary_acc: 0.8460 - precision: 0.8089 - recall: 0.7814 - f1_score: 0.7949 - roc_auc: 0.9261 - pr_auc: 0.8899 - cohen_kappa: 0.6717 - val_loss: 0.5377 - val_tp: 280.0000 - val_fp: 93.0000 - val_tn: 521.0000 - val_fn: 128.0000 - val_binary_acc: 0.7838 - val_precision: 0.7507 - val_recall: 0.6863 - val_f1_score: 0.7170 - val_roc_auc: 0.8479 - val_pr_auc: 0.8025 - val_cohen_kappa: 0.5426
# Epoch 18/100
# 256/256 [==============================] - 43s 168ms/step - loss: 0.3249 - tp: 1267.0000 - fp: 265.0000 - tn: 2259.0000 - fn: 293.0000 - binary_acc: 0.8634 - precision: 0.8270 - recall: 0.8122 - f1_score: 0.8195 - roc_auc: 0.9333 - pr_auc: 0.9057 - cohen_kappa: 0.7096 - val_loss: 0.6000 - val_tp: 236.0000 - val_fp: 78.0000 - val_tn: 536.0000 - val_fn: 172.0000 - val_binary_acc: 0.7554 - val_precision: 0.7516 - val_recall: 0.5784 - val_f1_score: 0.6537 - val_roc_auc: 0.8327 - val_pr_auc: 0.7870 - val_cohen_kappa: 0.4695
# Epoch 19/100
# 256/256 [==============================] - 42s 166ms/step - loss: 0.3229 - tp: 1246.0000 - fp: 260.0000 - tn: 2264.0000 - fn: 314.0000 - binary_acc: 0.8595 - precision: 0.8274 - recall: 0.7987 - f1_score: 0.8128 - roc_auc: 0.9341 - pr_auc: 0.9066 - cohen_kappa: 0.7003 - val_loss: 0.5362 - val_tp: 300.0000 - val_fp: 124.0000 - val_tn: 490.0000 - val_fn: 108.0000 - val_binary_acc: 0.7730 - val_precision: 0.7075 - val_recall: 0.7353 - val_f1_score: 0.7212 - val_roc_auc: 0.8490 - val_pr_auc: 0.8008 - val_cohen_kappa: 0.5299
# Epoch 20/100
# 256/256 [==============================] - 43s 168ms/step - loss: 0.2944 - tp: 1291.0000 - fp: 248.0000 - tn: 2276.0000 - fn: 269.0000 - binary_acc: 0.8734 - precision: 0.8389 - recall: 0.8276 - f1_score: 0.8332 - roc_auc: 0.9450 - pr_auc: 0.9199 - cohen_kappa: 0.7312 - val_loss: 0.6220 - val_tp: 279.0000 - val_fp: 124.0000 - val_tn: 490.0000 - val_fn: 129.0000 - val_binary_acc: 0.7524 - val_precision: 0.6923 - val_recall: 0.6838 - val_f1_score: 0.6880 - val_roc_auc: 0.8263 - val_pr_auc: 0.7751 - val_cohen_kappa: 0.4829
# Epoch 21/100
# 256/256 [==============================] - 43s 169ms/step - loss: 0.2790 - tp: 1284.0000 - fp: 221.0000 - tn: 2303.0000 - fn: 276.0000 - binary_acc: 0.8783 - precision: 0.8532 - recall: 0.8231 - f1_score: 0.8378 - roc_auc: 0.9498 - pr_auc: 0.9279 - cohen_kappa: 0.7405 - val_loss: 0.6679 - val_tp: 316.0000 - val_fp: 167.0000 - val_tn: 447.0000 - val_fn: 92.0000 - val_binary_acc: 0.7466 - val_precision: 0.6542 - val_recall: 0.7745 - val_f1_score: 0.7093 - val_roc_auc: 0.8293 - val_pr_auc: 0.7706 - val_cohen_kappa: 0.4875
# Epoch 22/100
# 256/256 [==============================] - 44s 170ms/step - loss: 0.2686 - tp: 1282.0000 - fp: 217.0000 - tn: 2307.0000 - fn: 278.0000 - binary_acc: 0.8788 - precision: 0.8552 - recall: 0.8218 - f1_score: 0.8382 - roc_auc: 0.9533 - pr_auc: 0.9322 - cohen_kappa: 0.7414 - val_loss: 0.6493 - val_tp: 312.0000 - val_fp: 173.0000 - val_tn: 441.0000 - val_fn: 96.0000 - val_binary_acc: 0.7368 - val_precision: 0.6433 - val_recall: 0.7647 - val_f1_score: 0.6988 - val_roc_auc: 0.8337 - val_pr_auc: 0.7817 - val_cohen_kappa: 0.4681
# Epoch 23/100
# 256/256 [==============================] - 43s 168ms/step - loss: 0.2675 - tp: 1325.0000 - fp: 218.0000 - tn: 2306.0000 - fn: 235.0000 - binary_acc: 0.8891 - precision: 0.8587 - recall: 0.8494 - f1_score: 0.8540 - roc_auc: 0.9544 - pr_auc: 0.9353 - cohen_kappa: 0.7646 - val_loss: 0.6075 - val_tp: 286.0000 - val_fp: 115.0000 - val_tn: 499.0000 - val_fn: 122.0000 - val_binary_acc: 0.7681 - val_precision: 0.7132 - val_recall: 0.7010 - val_f1_score: 0.7070 - val_roc_auc: 0.8448 - val_pr_auc: 0.8006 - val_cohen_kappa: 0.5152
# Epoch 24/100
# 256/256 [==============================] - 44s 171ms/step - loss: 0.2587 - tp: 1314.0000 - fp: 202.0000 - tn: 2322.0000 - fn: 246.0000 - binary_acc: 0.8903 - precision: 0.8668 - recall: 0.8423 - f1_score: 0.8544 - roc_auc: 0.9565 - pr_auc: 0.9391 - cohen_kappa: 0.7664 - val_loss: 0.6668 - val_tp: 236.0000 - val_fp: 59.0000 - val_tn: 555.0000 - val_fn: 172.0000 - val_binary_acc: 0.7740 - val_precision: 0.8000 - val_recall: 0.5784 - val_f1_score: 0.6714 - val_roc_auc: 0.8355 - val_pr_auc: 0.7847 - val_cohen_kappa: 0.5058
# Epoch 25/100
# 256/256 [==============================] - 43s 167ms/step - loss: 0.2430 - tp: 1336.0000 - fp: 178.0000 - tn: 2346.0000 - fn: 224.0000 - binary_acc: 0.9016 - precision: 0.8824 - recall: 0.8564 - f1_score: 0.8692 - roc_auc: 0.9627 - pr_auc: 0.9418 - cohen_kappa: 0.7903 - val_loss: 0.6896 - val_tp: 259.0000 - val_fp: 83.0000 - val_tn: 531.0000 - val_fn: 149.0000 - val_binary_acc: 0.7730 - val_precision: 0.7573 - val_recall: 0.6348 - val_f1_score: 0.6907 - val_roc_auc: 0.8337 - val_pr_auc: 0.7795 - val_cohen_kappa: 0.5136
# Epoch 26/100
# 256/256 [==============================] - 44s 171ms/step - loss: 0.2296 - tp: 1347.0000 - fp: 171.0000 - tn: 2353.0000 - fn: 213.0000 - binary_acc: 0.9060 - precision: 0.8874 - recall: 0.8635 - f1_score: 0.8752 - roc_auc: 0.9659 - pr_auc: 0.9494 - cohen_kappa: 0.7998 - val_loss: 0.6321 - val_tp: 291.0000 - val_fp: 113.0000 - val_tn: 501.0000 - val_fn: 117.0000 - val_binary_acc: 0.7750 - val_precision: 0.7203 - val_recall: 0.7132 - val_f1_score: 0.7167 - val_roc_auc: 0.8439 - val_pr_auc: 0.8004 - val_cohen_kappa: 0.5301
# Epoch 27/100
# 256/256 [==============================] - 44s 172ms/step - loss: 0.2227 - tp: 1361.0000 - fp: 179.0000 - tn: 2345.0000 - fn: 199.0000 - binary_acc: 0.9074 - precision: 0.8838 - recall: 0.8724 - f1_score: 0.8781 - roc_auc: 0.9677 - pr_auc: 0.9548 - cohen_kappa: 0.8035 - val_loss: 0.6619 - val_tp: 268.0000 - val_fp: 92.0000 - val_tn: 522.0000 - val_fn: 140.0000 - val_binary_acc: 0.7730 - val_precision: 0.7444 - val_recall: 0.6569 - val_f1_score: 0.6979 - val_roc_auc: 0.8403 - val_pr_auc: 0.7902 - val_cohen_kappa: 0.5172
# Epoch 28/100
# 256/256 [==============================] - 44s 173ms/step - loss: 0.2265 - tp: 1342.0000 - fp: 184.0000 - tn: 2340.0000 - fn: 218.0000 - binary_acc: 0.9016 - precision: 0.8794 - recall: 0.8603 - f1_score: 0.8697 - roc_auc: 0.9667 - pr_auc: 0.9539 - cohen_kappa: 0.7906 - val_loss: 0.6067 - val_tp: 266.0000 - val_fp: 78.0000 - val_tn: 536.0000 - val_fn: 142.0000 - val_binary_acc: 0.7847 - val_precision: 0.7733 - val_recall: 0.6520 - val_f1_score: 0.7074 - val_roc_auc: 0.8561 - val_pr_auc: 0.8068 - val_cohen_kappa: 0.5391
# Epoch 29/100
# 256/256 [==============================] - 45s 176ms/step - loss: 0.2012 - tp: 1378.0000 - fp: 152.0000 - tn: 2372.0000 - fn: 182.0000 - binary_acc: 0.9182 - precision: 0.9007 - recall: 0.8833 - f1_score: 0.8919 - roc_auc: 0.9735 - pr_auc: 0.9618 - cohen_kappa: 0.8261 - val_loss: 0.7704 - val_tp: 263.0000 - val_fp: 92.0000 - val_tn: 522.0000 - val_fn: 145.0000 - val_binary_acc: 0.7681 - val_precision: 0.7408 - val_recall: 0.6446 - val_f1_score: 0.6894 - val_roc_auc: 0.8344 - val_pr_auc: 0.7916 - val_cohen_kappa: 0.5058
# Epoch 30/100
# 256/256 [==============================] - 43s 169ms/step - loss: 0.2165 - tp: 1384.0000 - fp: 168.0000 - tn: 2356.0000 - fn: 176.0000 - binary_acc: 0.9158 - precision: 0.8918 - recall: 0.8872 - f1_score: 0.8895 - roc_auc: 0.9699 - pr_auc: 0.9566 - cohen_kappa: 0.8214 - val_loss: 0.5871 - val_tp: 306.0000 - val_fp: 108.0000 - val_tn: 506.0000 - val_fn: 102.0000 - val_binary_acc: 0.7945 - val_precision: 0.7391 - val_recall: 0.7500 - val_f1_score: 0.7445 - val_roc_auc: 0.8643 - val_pr_auc: 0.8191 - val_cohen_kappa: 0.5727
# Epoch 31/100
# 256/256 [==============================] - 43s 167ms/step - loss: 0.2104 - tp: 1363.0000 - fp: 158.0000 - tn: 2366.0000 - fn: 197.0000 - binary_acc: 0.9131 - precision: 0.8961 - recall: 0.8737 - f1_score: 0.8848 - roc_auc: 0.9714 - pr_auc: 0.9601 - cohen_kappa: 0.8150 - val_loss: 0.6983 - val_tp: 279.0000 - val_fp: 79.0000 - val_tn: 535.0000 - val_fn: 129.0000 - val_binary_acc: 0.7965 - val_precision: 0.7793 - val_recall: 0.6838 - val_f1_score: 0.7285 - val_roc_auc: 0.8577 - val_pr_auc: 0.8056 - val_cohen_kappa: 0.5668
# Epoch 32/100
# 256/256 [==============================] - 43s 166ms/step - loss: 0.2003 - tp: 1380.0000 - fp: 151.0000 - tn: 2373.0000 - fn: 180.0000 - binary_acc: 0.9190 - precision: 0.9014 - recall: 0.8846 - f1_score: 0.8929 - roc_auc: 0.9748 - pr_auc: 0.9607 - cohen_kappa: 0.8277 - val_loss: 0.7194 - val_tp: 305.0000 - val_fp: 141.0000 - val_tn: 473.0000 - val_fn: 103.0000 - val_binary_acc: 0.7613 - val_precision: 0.6839 - val_recall: 0.7475 - val_f1_score: 0.7143 - val_roc_auc: 0.8431 - val_pr_auc: 0.7881 - val_cohen_kappa: 0.5099
# Epoch 33/100
# 256/256 [==============================] - 44s 171ms/step - loss: 0.1817 - tp: 1398.0000 - fp: 135.0000 - tn: 2389.0000 - fn: 162.0000 - binary_acc: 0.9273 - precision: 0.9119 - recall: 0.8962 - f1_score: 0.9040 - roc_auc: 0.9782 - pr_auc: 0.9690 - cohen_kappa: 0.8455 - val_loss: 0.6968 - val_tp: 310.0000 - val_fp: 134.0000 - val_tn: 480.0000 - val_fn: 98.0000 - val_binary_acc: 0.7730 - val_precision: 0.6982 - val_recall: 0.7598 - val_f1_score: 0.7277 - val_roc_auc: 0.8489 - val_pr_auc: 0.7903 - val_cohen_kappa: 0.5337
# Epoch 34/100
# 256/256 [==============================] - 43s 168ms/step - loss: 0.2059 - tp: 1379.0000 - fp: 151.0000 - tn: 2373.0000 - fn: 181.0000 - binary_acc: 0.9187 - precision: 0.9013 - recall: 0.8840 - f1_score: 0.8926 - roc_auc: 0.9728 - pr_auc: 0.9622 - cohen_kappa: 0.8272 - val_loss: 0.6563 - val_tp: 310.0000 - val_fp: 120.0000 - val_tn: 494.0000 - val_fn: 98.0000 - val_binary_acc: 0.7867 - val_precision: 0.7209 - val_recall: 0.7598 - val_f1_score: 0.7399 - val_roc_auc: 0.8558 - val_pr_auc: 0.8010 - val_cohen_kappa: 0.5593
# Epoch 35/100
# 256/256 [==============================] - 43s 167ms/step - loss: 0.1685 - tp: 1412.0000 - fp: 124.0000 - tn: 2400.0000 - fn: 148.0000 - binary_acc: 0.9334 - precision: 0.9193 - recall: 0.9051 - f1_score: 0.9121 - roc_auc: 0.9808 - pr_auc: 0.9738 - cohen_kappa: 0.8585 - val_loss: 0.6732 - val_tp: 287.0000 - val_fp: 127.0000 - val_tn: 487.0000 - val_fn: 121.0000 - val_binary_acc: 0.7573 - val_precision: 0.6932 - val_recall: 0.7034 - val_f1_score: 0.6983 - val_roc_auc: 0.8395 - val_pr_auc: 0.7910 - val_cohen_kappa: 0.4954
# Epoch 36/100
# 256/256 [==============================] - 43s 169ms/step - loss: 0.1774 - tp: 1407.0000 - fp: 127.0000 - tn: 2397.0000 - fn: 153.0000 - binary_acc: 0.9314 - precision: 0.9172 - recall: 0.9019 - f1_score: 0.9095 - roc_auc: 0.9793 - pr_auc: 0.9706 - cohen_kappa: 0.8543 - val_loss: 0.7047 - val_tp: 290.0000 - val_fp: 105.0000 - val_tn: 509.0000 - val_fn: 118.0000 - val_binary_acc: 0.7818 - val_precision: 0.7342 - val_recall: 0.7108 - val_f1_score: 0.7223 - val_roc_auc: 0.8449 - val_pr_auc: 0.7917 - val_cohen_kappa: 0.5427
# Epoch 37/100
# 256/256 [==============================] - 43s 167ms/step - loss: 0.1553 - tp: 1437.0000 - fp: 125.0000 - tn: 2399.0000 - fn: 123.0000 - binary_acc: 0.9393 - precision: 0.9200 - recall: 0.9212 - f1_score: 0.9206 - roc_auc: 0.9844 - pr_auc: 0.9756 - cohen_kappa: 0.8714 - val_loss: 0.7512 - val_tp: 252.0000 - val_fp: 67.0000 - val_tn: 547.0000 - val_fn: 156.0000 - val_binary_acc: 0.7818 - val_precision: 0.7900 - val_recall: 0.6176 - val_f1_score: 0.6933 - val_roc_auc: 0.8391 - val_pr_auc: 0.8008 - val_cohen_kappa: 0.5278
# Epoch 38/100
# 256/256 [==============================] - 43s 167ms/step - loss: 0.1666 - tp: 1423.0000 - fp: 129.0000 - tn: 2395.0000 - fn: 137.0000 - binary_acc: 0.9349 - precision: 0.9169 - recall: 0.9122 - f1_score: 0.9145 - roc_auc: 0.9817 - pr_auc: 0.9745 - cohen_kappa: 0.8619 - val_loss: 0.7576 - val_tp: 249.0000 - val_fp: 66.0000 - val_tn: 548.0000 - val_fn: 159.0000 - val_binary_acc: 0.7798 - val_precision: 0.7905 - val_recall: 0.6103 - val_f1_score: 0.6888 - val_roc_auc: 0.8397 - val_pr_auc: 0.8032 - val_cohen_kappa: 0.5228
# Epoch 39/100
# 256/256 [==============================] - 42s 165ms/step - loss: 0.1503 - tp: 1425.0000 - fp: 109.0000 - tn: 2415.0000 - fn: 135.0000 - binary_acc: 0.9403 - precision: 0.9289 - recall: 0.9135 - f1_score: 0.9211 - roc_auc: 0.9847 - pr_auc: 0.9787 - cohen_kappa: 0.8731 - val_loss: 0.7200 - val_tp: 308.0000 - val_fp: 143.0000 - val_tn: 471.0000 - val_fn: 100.0000 - val_binary_acc: 0.7622 - val_precision: 0.6829 - val_recall: 0.7549 - val_f1_score: 0.7171 - val_roc_auc: 0.8518 - val_pr_auc: 0.7943 - val_cohen_kappa: 0.5129
# Epoch 40/100
# 256/256 [==============================] - 42s 165ms/step - loss: 0.1468 - tp: 1440.0000 - fp: 123.0000 - tn: 2401.0000 - fn: 120.0000 - binary_acc: 0.9405 - precision: 0.9213 - recall: 0.9231 - f1_score: 0.9222 - roc_auc: 0.9855 - pr_auc: 0.9780 - cohen_kappa: 0.8740 - val_loss: 0.7071 - val_tp: 266.0000 - val_fp: 63.0000 - val_tn: 551.0000 - val_fn: 142.0000 - val_binary_acc: 0.7994 - val_precision: 0.8085 - val_recall: 0.6520 - val_f1_score: 0.7218 - val_roc_auc: 0.8652 - val_pr_auc: 0.8323 - val_cohen_kappa: 0.5678
# Epoch 41/100
# 256/256 [==============================] - 42s 164ms/step - loss: 0.1307 - tp: 1450.0000 - fp: 92.0000 - tn: 2432.0000 - fn: 110.0000 - binary_acc: 0.9505 - precision: 0.9403 - recall: 0.9295 - f1_score: 0.9349 - roc_auc: 0.9887 - pr_auc: 0.9822 - cohen_kappa: 0.8950 - val_loss: 0.7085 - val_tp: 277.0000 - val_fp: 88.0000 - val_tn: 526.0000 - val_fn: 131.0000 - val_binary_acc: 0.7857 - val_precision: 0.7589 - val_recall: 0.6789 - val_f1_score: 0.7167 - val_roc_auc: 0.8560 - val_pr_auc: 0.8112 - val_cohen_kappa: 0.5452
# Epoch 42/100
# 256/256 [==============================] - 42s 165ms/step - loss: 0.1406 - tp: 1439.0000 - fp: 99.0000 - tn: 2425.0000 - fn: 121.0000 - binary_acc: 0.9461 - precision: 0.9356 - recall: 0.9224 - f1_score: 0.9290 - roc_auc: 0.9865 - pr_auc: 0.9780 - cohen_kappa: 0.8856 - val_loss: 0.7258 - val_tp: 298.0000 - val_fp: 112.0000 - val_tn: 502.0000 - val_fn: 110.0000 - val_binary_acc: 0.7828 - val_precision: 0.7268 - val_recall: 0.7304 - val_f1_score: 0.7286 - val_roc_auc: 0.8552 - val_pr_auc: 0.8105 - val_cohen_kappa: 0.5475
# Epoch 43/100
# 256/256 [==============================] - 41s 162ms/step - loss: 0.1179 - tp: 1458.0000 - fp: 96.0000 - tn: 2428.0000 - fn: 102.0000 - binary_acc: 0.9515 - precision: 0.9382 - recall: 0.9346 - f1_score: 0.9364 - roc_auc: 0.9903 - pr_auc: 0.9857 - cohen_kappa: 0.8972 - val_loss: 0.9053 - val_tp: 249.0000 - val_fp: 73.0000 - val_tn: 541.0000 - val_fn: 159.0000 - val_binary_acc: 0.7730 - val_precision: 0.7733 - val_recall: 0.6103 - val_f1_score: 0.6822 - val_roc_auc: 0.8298 - val_pr_auc: 0.7835 - val_cohen_kappa: 0.5094
# Epoch 44/100
# 256/256 [==============================] - 42s 166ms/step - loss: 0.1406 - tp: 1450.0000 - fp: 104.0000 - tn: 2420.0000 - fn: 110.0000 - binary_acc: 0.9476 - precision: 0.9331 - recall: 0.9295 - f1_score: 0.9313 - roc_auc: 0.9867 - pr_auc: 0.9804 - cohen_kappa: 0.8889 - val_loss: 0.8402 - val_tp: 290.0000 - val_fp: 112.0000 - val_tn: 502.0000 - val_fn: 118.0000 - val_binary_acc: 0.7750 - val_precision: 0.7214 - val_recall: 0.7108 - val_f1_score: 0.7160 - val_roc_auc: 0.8427 - val_pr_auc: 0.7778 - val_cohen_kappa: 0.5297
# Epoch 45/100
# 256/256 [==============================] - ETA: 0s - loss: 0.1496 - tp: 1435.0000 - fp: 120.0000 - tn: 2404.0000 - fn: 125.0000 - binary_acc: 0.9400 - precision: 0.9228 - recall: 0.9199 - f1_score: 0.9213 - roc_auc: 0.9845 - pr_auc: 0.9783 - cohen_kappa: 0.8729Restoring model weights from the end of the best epoch: 30.
# 256/256 [==============================] - 42s 165ms/step - loss: 0.1496 - tp: 1435.0000 - fp: 120.0000 - tn: 2404.0000 - fn: 125.0000 - binary_acc: 0.9400 - precision: 0.9228 - recall: 0.9199 - f1_score: 0.9213 - roc_auc: 0.9845 - pr_auc: 0.9783 - cohen_kappa: 0.8729 - val_loss: 0.8193 - val_tp: 238.0000 - val_fp: 76.0000 - val_tn: 538.0000 - val_fn: 170.0000 - val_binary_acc: 0.7593 - val_precision: 0.7580 - val_recall: 0.5833 - val_f1_score: 0.6593 - val_roc_auc: 0.8287 - val_pr_auc: 0.7789 - val_cohen_kappa: 0.4780
# Epoch 45: early stopping

# %%
new_model.save(save_path + model_name + '.keras')

plot_metrics(history)

# %%
new_model.evaluate(validation_generator)
new_model.evaluate(test_generator)

    # Make predictions using the validation generator
y_valid_pred_prob = new_model.predict(validation_generator)
y_valid_pred = (y_valid_pred_prob > 0.5).astype(int)
y_valid = validation_generator.classes
print("Classification Report:")
print(classification_report(y_valid, y_valid_pred))

y_pred_prob = new_model.predict(test_generator)
y_pred = (y_pred_prob > 0.5).astype(int)
y_test = test_generator.classes
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# 64/64 [==============================] - 9s 133ms/step - loss: 0.6208 - tp: 296.0000 - fp: 102.0000 - tn: 512.0000 - fn: 112.0000 - binary_acc: 0.7906 - precision: 0.7437 - recall: 0.7255 - f1_score: 0.7345 - roc_auc: 0.8576 - pr_auc: 0.8076 - cohen_kappa: 0.5617
# 29/29 [==============================] - 4s 127ms/step - loss: 1.0747 - tp: 175.0000 - fp: 71.0000 - tn: 143.0000 - fn: 72.0000 - binary_acc: 0.6898 - precision: 0.7114 - recall: 0.7085 - f1_score: 0.7099 - roc_auc: 0.7546 - pr_auc: 0.7693 - cohen_kappa: 0.3766
# 64/64 [==============================] - 8s 128ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.82      0.85      0.83       614
#            1       0.76      0.71      0.74       408
#
#     accuracy                           0.80      1022
#    macro avg       0.79      0.78      0.78      1022
# weighted avg       0.79      0.80      0.79      1022
#
# 29/29 [==============================] - 1s 49ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.67      0.67      0.67       214
#            1       0.71      0.71      0.71       247
#
#     accuracy                           0.69       461
#    macro avg       0.69      0.69      0.69       461
# weighted avg       0.69      0.69      0.69       461

# %%
conf_matrix = confusion_matrix(y_test, y_pred)

# Create ConfusionMatrixDisplay object
cm_display = ConfusionMatrixDisplay(confusion_matrix=conf_matrix)

# Plot the confusion matrix
plt.figure(figsize=(4, 6))  # Adjust the figure size as needed
cm_display.plot(cmap=plt.cm.Blues)  # You can choose any colormap you prefer
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.grid(False)  # Turn off grid
plt.savefig(save_path + model_name + "_confusion_matrix.jpg")
plt.show()

# %%
history_df = pd.DataFrame(history.history)
save_history(model_name, history_df)

new_model.save(save_path + model_name + "_pt_imagenet-{new_model.count_params()}.h5")
vgg.save(save_path + model_name + ".h5")

vgg.trainable = True

new_model.compile(
        optimizer=tf.keras.optimizers.Adam(
            1e-5
        ),  # we need small learning rate to avoid catastrophic forgetting
        loss=tf.keras.losses.BinaryCrossentropy(),
        metrics=METRICS,
    )

model_name = 'finetuned_' + architecture + "_" + target_category

model_path = save_path + '_best_' + model_name + '.keras'
model_checkpoint = ModelCheckpoint(filepath=model_path,
                                       monitor="val_cohen_kappa",
                                       save_best_only=True)

reduce_lr_on_plateau = tf.keras.callbacks.ReduceLROnPlateau(
        monitor="val_cohen_kappa",
        verbose=1,
        patience=4,
        mode="max",
        factor=0.2,
        min_lr=1e-10,
    )
# Out:
# Training history saved to: C:/Users/raouf/Desktop/pfe/history/final/vgg/XR_FINGER/VGG_XR_FINGER_history.xlsx
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
history = new_model.fit(train_generator,
                            # steps_per_epoch=len(df_train) // batch_size,
                            validation_data=validation_generator,
                            # validation_steps=len(df_valid) // batch_size,
                            epochs=fine_tuning_epochs,
                            shuffle=shuffle,
                            callbacks=[early_stopping, model_checkpoint, reduce_lr_on_plateau])
# Out:
# Epoch 1/50
# 256/256 [==============================] - 77s 265ms/step - loss: 0.2056 - tp: 1543.0000 - fp: 216.0000 - tn: 2522.0000 - fn: 264.0000 - binary_acc: 0.8944 - precision: 0.8772 - recall: 0.8539 - f1_score: 0.8654 - roc_auc: 0.9515 - pr_auc: 0.9314 - cohen_kappa: 0.7785 - val_loss: 0.6514 - val_tp: 224.0000 - val_fp: 36.0000 - val_tn: 578.0000 - val_fn: 184.0000 - val_binary_acc: 0.7847 - val_precision: 0.8615 - val_recall: 0.5490 - val_f1_score: 0.6707 - val_roc_auc: 0.8479 - val_pr_auc: 0.8107 - val_cohen_kappa: 0.5222 - lr: 1.0000e-05
# Epoch 2/50
# 256/256 [==============================] - 65s 254ms/step - loss: 0.1916 - tp: 1379.0000 - fp: 130.0000 - tn: 2394.0000 - fn: 181.0000 - binary_acc: 0.9238 - precision: 0.9139 - recall: 0.8840 - f1_score: 0.8987 - roc_auc: 0.9760 - pr_auc: 0.9641 - cohen_kappa: 0.8377 - val_loss: 0.6057 - val_tp: 277.0000 - val_fp: 107.0000 - val_tn: 507.0000 - val_fn: 131.0000 - val_binary_acc: 0.7671 - val_precision: 0.7214 - val_recall: 0.6789 - val_f1_score: 0.6995 - val_roc_auc: 0.8404 - val_pr_auc: 0.8000 - val_cohen_kappa: 0.5097 - lr: 1.0000e-05
# Epoch 3/50
# 256/256 [==============================] - 64s 249ms/step - loss: 0.1834 - tp: 1365.0000 - fp: 137.0000 - tn: 2387.0000 - fn: 195.0000 - binary_acc: 0.9187 - precision: 0.9088 - recall: 0.8750 - f1_score: 0.8916 - roc_auc: 0.9777 - pr_auc: 0.9687 - cohen_kappa: 0.8266 - val_loss: 0.5714 - val_tp: 283.0000 - val_fp: 84.0000 - val_tn: 530.0000 - val_fn: 125.0000 - val_binary_acc: 0.7955 - val_precision: 0.7711 - val_recall: 0.6936 - val_f1_score: 0.7303 - val_roc_auc: 0.8612 - val_pr_auc: 0.8288 - val_cohen_kappa: 0.5664 - lr: 1.0000e-05
# Epoch 4/50
# 256/256 [==============================] - 63s 245ms/step - loss: 0.1471 - tp: 1427.0000 - fp: 110.0000 - tn: 2414.0000 - fn: 133.0000 - binary_acc: 0.9405 - precision: 0.9284 - recall: 0.9147 - f1_score: 0.9215 - roc_auc: 0.9858 - pr_auc: 0.9794 - cohen_kappa: 0.8736 - val_loss: 0.7111 - val_tp: 281.0000 - val_fp: 79.0000 - val_tn: 535.0000 - val_fn: 127.0000 - val_binary_acc: 0.7984 - val_precision: 0.7806 - val_recall: 0.6887 - val_f1_score: 0.7318 - val_roc_auc: 0.8623 - val_pr_auc: 0.8270 - val_cohen_kappa: 0.5713 - lr: 1.0000e-05
# Epoch 5/50
# 256/256 [==============================] - 64s 248ms/step - loss: 0.1740 - tp: 1394.0000 - fp: 125.0000 - tn: 2399.0000 - fn: 166.0000 - binary_acc: 0.9287 - precision: 0.9177 - recall: 0.8936 - f1_score: 0.9055 - roc_auc: 0.9801 - pr_auc: 0.9715 - cohen_kappa: 0.8483 - val_loss: 0.6212 - val_tp: 288.0000 - val_fp: 94.0000 - val_tn: 520.0000 - val_fn: 120.0000 - val_binary_acc: 0.7906 - val_precision: 0.7539 - val_recall: 0.7059 - val_f1_score: 0.7291 - val_roc_auc: 0.8590 - val_pr_auc: 0.8213 - val_cohen_kappa: 0.5588 - lr: 1.0000e-05
# Epoch 6/50
# 256/256 [==============================] - 64s 250ms/step - loss: 0.1314 - tp: 1440.0000 - fp: 85.0000 - tn: 2439.0000 - fn: 120.0000 - binary_acc: 0.9498 - precision: 0.9443 - recall: 0.9231 - f1_score: 0.9335 - roc_auc: 0.9888 - pr_auc: 0.9826 - cohen_kappa: 0.8932 - val_loss: 0.7294 - val_tp: 303.0000 - val_fp: 108.0000 - val_tn: 506.0000 - val_fn: 105.0000 - val_binary_acc: 0.7916 - val_precision: 0.7372 - val_recall: 0.7426 - val_f1_score: 0.7399 - val_roc_auc: 0.8603 - val_pr_auc: 0.8268 - val_cohen_kappa: 0.5661 - lr: 1.0000e-05
# Epoch 7/50
# 256/256 [==============================] - 63s 247ms/step - loss: 0.1646 - tp: 1395.0000 - fp: 105.0000 - tn: 2419.0000 - fn: 165.0000 - binary_acc: 0.9339 - precision: 0.9300 - recall: 0.8942 - f1_score: 0.9118 - roc_auc: 0.9825 - pr_auc: 0.9724 - cohen_kappa: 0.8589 - val_loss: 0.5877 - val_tp: 264.0000 - val_fp: 89.0000 - val_tn: 525.0000 - val_fn: 144.0000 - val_binary_acc: 0.7720 - val_precision: 0.7479 - val_recall: 0.6471 - val_f1_score: 0.6938 - val_roc_auc: 0.8425 - val_pr_auc: 0.8053 - val_cohen_kappa: 0.5137 - lr: 1.0000e-05
# Epoch 8/50
# 256/256 [==============================] - 63s 246ms/step - loss: 0.1199 - tp: 1460.0000 - fp: 82.0000 - tn: 2442.0000 - fn: 100.0000 - binary_acc: 0.9554 - precision: 0.9468 - recall: 0.9359 - f1_score: 0.9413 - roc_auc: 0.9905 - pr_auc: 0.9855 - cohen_kappa: 0.9054 - val_loss: 0.6212 - val_tp: 272.0000 - val_fp: 64.0000 - val_tn: 550.0000 - val_fn: 136.0000 - val_binary_acc: 0.8043 - val_precision: 0.8095 - val_recall: 0.6667 - val_f1_score: 0.7312 - val_roc_auc: 0.8632 - val_pr_auc: 0.8286 - val_cohen_kappa: 0.5796 - lr: 1.0000e-05
# Epoch 9/50
# 256/256 [==============================] - 63s 245ms/step - loss: 0.1156 - tp: 1458.0000 - fp: 83.0000 - tn: 2441.0000 - fn: 102.0000 - binary_acc: 0.9547 - precision: 0.9461 - recall: 0.9346 - f1_score: 0.9403 - roc_auc: 0.9912 - pr_auc: 0.9870 - cohen_kappa: 0.9038 - val_loss: 0.6173 - val_tp: 298.0000 - val_fp: 92.0000 - val_tn: 522.0000 - val_fn: 110.0000 - val_binary_acc: 0.8023 - val_precision: 0.7641 - val_recall: 0.7304 - val_f1_score: 0.7469 - val_roc_auc: 0.8648 - val_pr_auc: 0.8212 - val_cohen_kappa: 0.5849 - lr: 1.0000e-05
# Epoch 10/50
# 256/256 [==============================] - 63s 245ms/step - loss: 0.0962 - tp: 1477.0000 - fp: 69.0000 - tn: 2455.0000 - fn: 83.0000 - binary_acc: 0.9628 - precision: 0.9554 - recall: 0.9468 - f1_score: 0.9511 - roc_auc: 0.9937 - pr_auc: 0.9903 - cohen_kappa: 0.9210 - val_loss: 0.6429 - val_tp: 308.0000 - val_fp: 108.0000 - val_tn: 506.0000 - val_fn: 100.0000 - val_binary_acc: 0.7965 - val_precision: 0.7404 - val_recall: 0.7549 - val_f1_score: 0.7476 - val_roc_auc: 0.8755 - val_pr_auc: 0.8389 - val_cohen_kappa: 0.5771 - lr: 1.0000e-05
# Epoch 11/50
# 256/256 [==============================] - 63s 245ms/step - loss: 0.1314 - tp: 1454.0000 - fp: 99.0000 - tn: 2425.0000 - fn: 106.0000 - binary_acc: 0.9498 - precision: 0.9363 - recall: 0.9321 - f1_score: 0.9341 - roc_auc: 0.9881 - pr_auc: 0.9827 - cohen_kappa: 0.8936 - val_loss: 0.6537 - val_tp: 260.0000 - val_fp: 63.0000 - val_tn: 551.0000 - val_fn: 148.0000 - val_binary_acc: 0.7935 - val_precision: 0.8050 - val_recall: 0.6373 - val_f1_score: 0.7114 - val_roc_auc: 0.8521 - val_pr_auc: 0.8130 - val_cohen_kappa: 0.5540 - lr: 1.0000e-05
# Epoch 12/50
# 256/256 [==============================] - 63s 244ms/step - loss: 0.0893 - tp: 1482.0000 - fp: 53.0000 - tn: 2471.0000 - fn: 78.0000 - binary_acc: 0.9679 - precision: 0.9655 - recall: 0.9500 - f1_score: 0.9577 - roc_auc: 0.9946 - pr_auc: 0.9922 - cohen_kappa: 0.9319 - val_loss: 0.7222 - val_tp: 293.0000 - val_fp: 91.0000 - val_tn: 523.0000 - val_fn: 115.0000 - val_binary_acc: 0.7984 - val_precision: 0.7630 - val_recall: 0.7181 - val_f1_score: 0.7399 - val_roc_auc: 0.8654 - val_pr_auc: 0.8304 - val_cohen_kappa: 0.5756 - lr: 1.0000e-05
# Epoch 13/50
# 256/256 [==============================] - ETA: 0s - loss: 0.0844 - tp: 1487.0000 - fp: 52.0000 - tn: 2472.0000 - fn: 73.0000 - binary_acc: 0.9694 - precision: 0.9662 - recall: 0.9532 - f1_score: 0.9597 - roc_auc: 0.9949 - pr_auc: 0.9920 - cohen_kappa: 0.9350
# Epoch 13: ReduceLROnPlateau reducing learning rate to 1.9999999494757505e-06.
# 256/256 [==============================] - 63s 246ms/step - loss: 0.0844 - tp: 1487.0000 - fp: 52.0000 - tn: 2472.0000 - fn: 73.0000 - binary_acc: 0.9694 - precision: 0.9662 - recall: 0.9532 - f1_score: 0.9597 - roc_auc: 0.9949 - pr_auc: 0.9920 - cohen_kappa: 0.9350 - val_loss: 0.6925 - val_tp: 301.0000 - val_fp: 107.0000 - val_tn: 507.0000 - val_fn: 107.0000 - val_binary_acc: 0.7906 - val_precision: 0.7377 - val_recall: 0.7377 - val_f1_score: 0.7377 - val_roc_auc: 0.8632 - val_pr_auc: 0.8088 - val_cohen_kappa: 0.5635 - lr: 1.0000e-05
# Epoch 14/50
# 256/256 [==============================] - 65s 253ms/step - loss: 0.0635 - tp: 1507.0000 - fp: 44.0000 - tn: 2480.0000 - fn: 53.0000 - binary_acc: 0.9762 - precision: 0.9716 - recall: 0.9660 - f1_score: 0.9688 - roc_auc: 0.9971 - pr_auc: 0.9959 - cohen_kappa: 0.9496 - val_loss: 0.6634 - val_tp: 296.0000 - val_fp: 70.0000 - val_tn: 544.0000 - val_fn: 112.0000 - val_binary_acc: 0.8219 - val_precision: 0.8087 - val_recall: 0.7255 - val_f1_score: 0.7649 - val_roc_auc: 0.8803 - val_pr_auc: 0.8487 - val_cohen_kappa: 0.6222 - lr: 2.0000e-06
# Epoch 15/50
# 256/256 [==============================] - 63s 246ms/step - loss: 0.0455 - tp: 1519.0000 - fp: 22.0000 - tn: 2502.0000 - fn: 41.0000 - binary_acc: 0.9846 - precision: 0.9857 - recall: 0.9737 - f1_score: 0.9797 - roc_auc: 0.9983 - pr_auc: 0.9972 - cohen_kappa: 0.9673 - val_loss: 0.7406 - val_tp: 290.0000 - val_fp: 69.0000 - val_tn: 545.0000 - val_fn: 118.0000 - val_binary_acc: 0.8170 - val_precision: 0.8078 - val_recall: 0.7108 - val_f1_score: 0.7562 - val_roc_auc: 0.8715 - val_pr_auc: 0.8402 - val_cohen_kappa: 0.6107 - lr: 2.0000e-06
# Epoch 16/50
# 256/256 [==============================] - 63s 247ms/step - loss: 0.0463 - tp: 1517.0000 - fp: 36.0000 - tn: 2488.0000 - fn: 43.0000 - binary_acc: 0.9807 - precision: 0.9768 - recall: 0.9724 - f1_score: 0.9746 - roc_auc: 0.9985 - pr_auc: 0.9973 - cohen_kappa: 0.9590 - val_loss: 0.7232 - val_tp: 277.0000 - val_fp: 68.0000 - val_tn: 546.0000 - val_fn: 131.0000 - val_binary_acc: 0.8053 - val_precision: 0.8029 - val_recall: 0.6789 - val_f1_score: 0.7357 - val_roc_auc: 0.8699 - val_pr_auc: 0.8422 - val_cohen_kappa: 0.5833 - lr: 2.0000e-06
# Epoch 17/50
# 256/256 [==============================] - 63s 245ms/step - loss: 0.0472 - tp: 1524.0000 - fp: 29.0000 - tn: 2495.0000 - fn: 36.0000 - binary_acc: 0.9841 - precision: 0.9813 - recall: 0.9769 - f1_score: 0.9791 - roc_auc: 0.9982 - pr_auc: 0.9976 - cohen_kappa: 0.9663 - val_loss: 0.7107 - val_tp: 287.0000 - val_fp: 69.0000 - val_tn: 545.0000 - val_fn: 121.0000 - val_binary_acc: 0.8141 - val_precision: 0.8062 - val_recall: 0.7034 - val_f1_score: 0.7513 - val_roc_auc: 0.8753 - val_pr_auc: 0.8441 - val_cohen_kappa: 0.6040 - lr: 2.0000e-06
# Epoch 18/50
# 256/256 [==============================] - ETA: 0s - loss: 0.0409 - tp: 1524.0000 - fp: 23.0000 - tn: 2501.0000 - fn: 36.0000 - binary_acc: 0.9856 - precision: 0.9851 - recall: 0.9769 - f1_score: 0.9810 - roc_auc: 0.9989 - pr_auc: 0.9983 - cohen_kappa: 0.9694
# Epoch 18: ReduceLROnPlateau reducing learning rate to 3.999999989900971e-07.
# 256/256 [==============================] - 63s 245ms/step - loss: 0.0409 - tp: 1524.0000 - fp: 23.0000 - tn: 2501.0000 - fn: 36.0000 - binary_acc: 0.9856 - precision: 0.9851 - recall: 0.9769 - f1_score: 0.9810 - roc_auc: 0.9989 - pr_auc: 0.9983 - cohen_kappa: 0.9694 - val_loss: 0.7282 - val_tp: 286.0000 - val_fp: 75.0000 - val_tn: 539.0000 - val_fn: 122.0000 - val_binary_acc: 0.8072 - val_precision: 0.7922 - val_recall: 0.7010 - val_f1_score: 0.7438 - val_roc_auc: 0.8771 - val_pr_auc: 0.8445 - val_cohen_kappa: 0.5902 - lr: 2.0000e-06
# Epoch 19/50
# 256/256 [==============================] - 63s 246ms/step - loss: 0.0327 - tp: 1534.0000 - fp: 26.0000 - tn: 2498.0000 - fn: 26.0000 - binary_acc: 0.9873 - precision: 0.9833 - recall: 0.9833 - f1_score: 0.9833 - roc_auc: 0.9994 - pr_auc: 0.9991 - cohen_kappa: 0.9730 - val_loss: 0.7792 - val_tp: 287.0000 - val_fp: 61.0000 - val_tn: 553.0000 - val_fn: 121.0000 - val_binary_acc: 0.8219 - val_precision: 0.8247 - val_recall: 0.7034 - val_f1_score: 0.7593 - val_roc_auc: 0.8771 - val_pr_auc: 0.8529 - val_cohen_kappa: 0.6194 - lr: 4.0000e-07
# Epoch 20/50
# 256/256 [==============================] - 63s 246ms/step - loss: 0.0293 - tp: 1540.0000 - fp: 19.0000 - tn: 2505.0000 - fn: 20.0000 - binary_acc: 0.9905 - precision: 0.9878 - recall: 0.9872 - f1_score: 0.9875 - roc_auc: 0.9995 - pr_auc: 0.9992 - cohen_kappa: 0.9798 - val_loss: 0.7732 - val_tp: 293.0000 - val_fp: 79.0000 - val_tn: 535.0000 - val_fn: 115.0000 - val_binary_acc: 0.8102 - val_precision: 0.7876 - val_recall: 0.7181 - val_f1_score: 0.7513 - val_roc_auc: 0.8740 - val_pr_auc: 0.8513 - val_cohen_kappa: 0.5983 - lr: 4.0000e-07
# Epoch 21/50
# 256/256 [==============================] - 63s 244ms/step - loss: 0.0338 - tp: 1533.0000 - fp: 20.0000 - tn: 2504.0000 - fn: 27.0000 - binary_acc: 0.9885 - precision: 0.9871 - recall: 0.9827 - f1_score: 0.9849 - roc_auc: 0.9989 - pr_auc: 0.9987 - cohen_kappa: 0.9756 - val_loss: 0.7344 - val_tp: 288.0000 - val_fp: 62.0000 - val_tn: 552.0000 - val_fn: 120.0000 - val_binary_acc: 0.8219 - val_precision: 0.8229 - val_recall: 0.7059 - val_f1_score: 0.7599 - val_roc_auc: 0.8779 - val_pr_auc: 0.8534 - val_cohen_kappa: 0.6197 - lr: 4.0000e-07
# Epoch 22/50
# 256/256 [==============================] - ETA: 0s - loss: 0.0254 - tp: 1542.0000 - fp: 15.0000 - tn: 2509.0000 - fn: 18.0000 - binary_acc: 0.9919 - precision: 0.9904 - recall: 0.9885 - f1_score: 0.9894 - roc_auc: 0.9996 - pr_auc: 0.9994 - cohen_kappa: 0.9829
# Epoch 22: ReduceLROnPlateau reducing learning rate to 8.00000009348878e-08.
# 256/256 [==============================] - 63s 245ms/step - loss: 0.0254 - tp: 1542.0000 - fp: 15.0000 - tn: 2509.0000 - fn: 18.0000 - binary_acc: 0.9919 - precision: 0.9904 - recall: 0.9885 - f1_score: 0.9894 - roc_auc: 0.9996 - pr_auc: 0.9994 - cohen_kappa: 0.9829 - val_loss: 0.7635 - val_tp: 287.0000 - val_fp: 74.0000 - val_tn: 540.0000 - val_fn: 121.0000 - val_binary_acc: 0.8092 - val_precision: 0.7950 - val_recall: 0.7034 - val_f1_score: 0.7464 - val_roc_auc: 0.8744 - val_pr_auc: 0.8454 - val_cohen_kappa: 0.5944 - lr: 4.0000e-07
# Epoch 23/50
# 256/256 [==============================] - 63s 246ms/step - loss: 0.0280 - tp: 1538.0000 - fp: 17.0000 - tn: 2507.0000 - fn: 22.0000 - binary_acc: 0.9905 - precision: 0.9891 - recall: 0.9859 - f1_score: 0.9875 - roc_auc: 0.9994 - pr_auc: 0.9992 - cohen_kappa: 0.9798 - val_loss: 0.7466 - val_tp: 293.0000 - val_fp: 68.0000 - val_tn: 546.0000 - val_fn: 115.0000 - val_binary_acc: 0.8209 - val_precision: 0.8116 - val_recall: 0.7181 - val_f1_score: 0.7620 - val_roc_auc: 0.8767 - val_pr_auc: 0.8428 - val_cohen_kappa: 0.6194 - lr: 8.0000e-08
# Epoch 24/50
# 256/256 [==============================] - 63s 246ms/step - loss: 0.0329 - tp: 1536.0000 - fp: 21.0000 - tn: 2503.0000 - fn: 24.0000 - binary_acc: 0.9890 - precision: 0.9865 - recall: 0.9846 - f1_score: 0.9856 - roc_auc: 0.9991 - pr_auc: 0.9988 - cohen_kappa: 0.9767 - val_loss: 0.7889 - val_tp: 288.0000 - val_fp: 69.0000 - val_tn: 545.0000 - val_fn: 120.0000 - val_binary_acc: 0.8151 - val_precision: 0.8067 - val_recall: 0.7059 - val_f1_score: 0.7529 - val_roc_auc: 0.8705 - val_pr_auc: 0.8412 - val_cohen_kappa: 0.6062 - lr: 8.0000e-08
# Epoch 25/50
# 256/256 [==============================] - 63s 246ms/step - loss: 0.0254 - tp: 1542.0000 - fp: 18.0000 - tn: 2506.0000 - fn: 18.0000 - binary_acc: 0.9912 - precision: 0.9885 - recall: 0.9885 - f1_score: 0.9885 - roc_auc: 0.9997 - pr_auc: 0.9995 - cohen_kappa: 0.9813 - val_loss: 0.7835 - val_tp: 292.0000 - val_fp: 71.0000 - val_tn: 543.0000 - val_fn: 116.0000 - val_binary_acc: 0.8170 - val_precision: 0.8044 - val_recall: 0.7157 - val_f1_score: 0.7575 - val_roc_auc: 0.8745 - val_pr_auc: 0.8461 - val_cohen_kappa: 0.6114 - lr: 8.0000e-08
# Epoch 26/50
# 256/256 [==============================] - ETA: 0s - loss: 0.0270 - tp: 1531.0000 - fp: 14.0000 - tn: 2510.0000 - fn: 29.0000 - binary_acc: 0.9895 - precision: 0.9909 - recall: 0.9814 - f1_score: 0.9862 - roc_auc: 0.9996 - pr_auc: 0.9994 - cohen_kappa: 0.9777
# Epoch 26: ReduceLROnPlateau reducing learning rate to 1.5999999902760466e-08.
# 256/256 [==============================] - 63s 245ms/step - loss: 0.0270 - tp: 1531.0000 - fp: 14.0000 - tn: 2510.0000 - fn: 29.0000 - binary_acc: 0.9895 - precision: 0.9909 - recall: 0.9814 - f1_score: 0.9862 - roc_auc: 0.9996 - pr_auc: 0.9994 - cohen_kappa: 0.9777 - val_loss: 0.8078 - val_tp: 286.0000 - val_fp: 67.0000 - val_tn: 547.0000 - val_fn: 122.0000 - val_binary_acc: 0.8151 - val_precision: 0.8102 - val_recall: 0.7010 - val_f1_score: 0.7516 - val_roc_auc: 0.8728 - val_pr_auc: 0.8436 - val_cohen_kappa: 0.6056 - lr: 8.0000e-08
# Epoch 27/50
# 256/256 [==============================] - 63s 247ms/step - loss: 0.0262 - tp: 1538.0000 - fp: 14.0000 - tn: 2510.0000 - fn: 22.0000 - binary_acc: 0.9912 - precision: 0.9910 - recall: 0.9859 - f1_score: 0.9884 - roc_auc: 0.9993 - pr_auc: 0.9991 - cohen_kappa: 0.9813 - val_loss: 0.7783 - val_tp: 292.0000 - val_fp: 59.0000 - val_tn: 555.0000 - val_fn: 116.0000 - val_binary_acc: 0.8288 - val_precision: 0.8319 - val_recall: 0.7157 - val_f1_score: 0.7694 - val_roc_auc: 0.8708 - val_pr_auc: 0.8412 - val_cohen_kappa: 0.6345 - lr: 1.6000e-08
# Epoch 28/50
# 256/256 [==============================] - 63s 245ms/step - loss: 0.0290 - tp: 1534.0000 - fp: 18.0000 - tn: 2506.0000 - fn: 26.0000 - binary_acc: 0.9892 - precision: 0.9884 - recall: 0.9833 - f1_score: 0.9859 - roc_auc: 0.9995 - pr_auc: 0.9992 - cohen_kappa: 0.9772 - val_loss: 0.7860 - val_tp: 289.0000 - val_fp: 69.0000 - val_tn: 545.0000 - val_fn: 119.0000 - val_binary_acc: 0.8160 - val_precision: 0.8073 - val_recall: 0.7083 - val_f1_score: 0.7546 - val_roc_auc: 0.8718 - val_pr_auc: 0.8403 - val_cohen_kappa: 0.6085 - lr: 1.6000e-08
# Epoch 29/50
# 256/256 [==============================] - 63s 244ms/step - loss: 0.0321 - tp: 1533.0000 - fp: 20.0000 - tn: 2504.0000 - fn: 27.0000 - binary_acc: 0.9885 - precision: 0.9871 - recall: 0.9827 - f1_score: 0.9849 - roc_auc: 0.9991 - pr_auc: 0.9983 - cohen_kappa: 0.9756 - val_loss: 0.8118 - val_tp: 279.0000 - val_fp: 70.0000 - val_tn: 544.0000 - val_fn: 129.0000 - val_binary_acc: 0.8053 - val_precision: 0.7994 - val_recall: 0.6838 - val_f1_score: 0.7371 - val_roc_auc: 0.8652 - val_pr_auc: 0.8365 - val_cohen_kappa: 0.5840 - lr: 1.6000e-08
# Epoch 30/50
# 256/256 [==============================] - 63s 246ms/step - loss: 0.0270 - tp: 1533.0000 - fp: 12.0000 - tn: 2512.0000 - fn: 27.0000 - binary_acc: 0.9905 - precision: 0.9922 - recall: 0.9827 - f1_score: 0.9874 - roc_auc: 0.9995 - pr_auc: 0.9993 - cohen_kappa: 0.9797 - val_loss: 0.7716 - val_tp: 289.0000 - val_fp: 61.0000 - val_tn: 553.0000 - val_fn: 119.0000 - val_binary_acc: 0.8239 - val_precision: 0.8257 - val_recall: 0.7083 - val_f1_score: 0.7625 - val_roc_auc: 0.8725 - val_pr_auc: 0.8405 - val_cohen_kappa: 0.6239 - lr: 1.6000e-08
# Epoch 31/50
# 256/256 [==============================] - ETA: 0s - loss: 0.0276 - tp: 1539.0000 - fp: 17.0000 - tn: 2507.0000 - fn: 21.0000 - binary_acc: 0.9907 - precision: 0.9891 - recall: 0.9865 - f1_score: 0.9878 - roc_auc: 0.9995 - pr_auc: 0.9993 - cohen_kappa: 0.9803
# Epoch 31: ReduceLROnPlateau reducing learning rate to 3.1999999094978194e-09.
# 256/256 [==============================] - 63s 245ms/step - loss: 0.0276 - tp: 1539.0000 - fp: 17.0000 - tn: 2507.0000 - fn: 21.0000 - binary_acc: 0.9907 - precision: 0.9891 - recall: 0.9865 - f1_score: 0.9878 - roc_auc: 0.9995 - pr_auc: 0.9993 - cohen_kappa: 0.9803 - val_loss: 0.7838 - val_tp: 286.0000 - val_fp: 73.0000 - val_tn: 541.0000 - val_fn: 122.0000 - val_binary_acc: 0.8092 - val_precision: 0.7967 - val_recall: 0.7010 - val_f1_score: 0.7458 - val_roc_auc: 0.8735 - val_pr_auc: 0.8368 - val_cohen_kappa: 0.5941 - lr: 1.6000e-08
# Epoch 32/50
# 256/256 [==============================] - 62s 244ms/step - loss: 0.0238 - tp: 1537.0000 - fp: 13.0000 - tn: 2511.0000 - fn: 23.0000 - binary_acc: 0.9912 - precision: 0.9916 - recall: 0.9853 - f1_score: 0.9884 - roc_auc: 0.9997 - pr_auc: 0.9996 - cohen_kappa: 0.9813 - val_loss: 0.7761 - val_tp: 298.0000 - val_fp: 66.0000 - val_tn: 548.0000 - val_fn: 110.0000 - val_binary_acc: 0.8278 - val_precision: 0.8187 - val_recall: 0.7304 - val_f1_score: 0.7720 - val_roc_auc: 0.8777 - val_pr_auc: 0.8535 - val_cohen_kappa: 0.6344 - lr: 3.2000e-09
# Epoch 33/50
# 256/256 [==============================] - 63s 245ms/step - loss: 0.0243 - tp: 1542.0000 - fp: 11.0000 - tn: 2513.0000 - fn: 18.0000 - binary_acc: 0.9929 - precision: 0.9929 - recall: 0.9885 - f1_score: 0.9907 - roc_auc: 0.9994 - pr_auc: 0.9993 - cohen_kappa: 0.9849 - val_loss: 0.7701 - val_tp: 299.0000 - val_fp: 76.0000 - val_tn: 538.0000 - val_fn: 109.0000 - val_binary_acc: 0.8190 - val_precision: 0.7973 - val_recall: 0.7328 - val_f1_score: 0.7637 - val_roc_auc: 0.8802 - val_pr_auc: 0.8557 - val_cohen_kappa: 0.6174 - lr: 3.2000e-09
# Epoch 34/50
# 256/256 [==============================] - 63s 244ms/step - loss: 0.0317 - tp: 1537.0000 - fp: 22.0000 - tn: 2502.0000 - fn: 23.0000 - binary_acc: 0.9890 - precision: 0.9859 - recall: 0.9853 - f1_score: 0.9856 - roc_auc: 0.9992 - pr_auc: 0.9984 - cohen_kappa: 0.9767 - val_loss: 0.7444 - val_tp: 294.0000 - val_fp: 76.0000 - val_tn: 538.0000 - val_fn: 114.0000 - val_binary_acc: 0.8141 - val_precision: 0.7946 - val_recall: 0.7206 - val_f1_score: 0.7558 - val_roc_auc: 0.8804 - val_pr_auc: 0.8449 - val_cohen_kappa: 0.6063 - lr: 3.2000e-09
# Epoch 35/50
# 256/256 [==============================] - ETA: 0s - loss: 0.0260 - tp: 1535.0000 - fp: 11.0000 - tn: 2513.0000 - fn: 25.0000 - binary_acc: 0.9912 - precision: 0.9929 - recall: 0.9840 - f1_score: 0.9884 - roc_auc: 0.9995 - pr_auc: 0.9988 - cohen_kappa: 0.9813
# Epoch 35: ReduceLROnPlateau reducing learning rate to 6.399999641359955e-10.
# 256/256 [==============================] - 63s 244ms/step - loss: 0.0260 - tp: 1535.0000 - fp: 11.0000 - tn: 2513.0000 - fn: 25.0000 - binary_acc: 0.9912 - precision: 0.9929 - recall: 0.9840 - f1_score: 0.9884 - roc_auc: 0.9995 - pr_auc: 0.9988 - cohen_kappa: 0.9813 - val_loss: 0.8049 - val_tp: 298.0000 - val_fp: 80.0000 - val_tn: 534.0000 - val_fn: 110.0000 - val_binary_acc: 0.8141 - val_precision: 0.7884 - val_recall: 0.7304 - val_f1_score: 0.7583 - val_roc_auc: 0.8785 - val_pr_auc: 0.8499 - val_cohen_kappa: 0.6076 - lr: 3.2000e-09
# Epoch 36/50
# 256/256 [==============================] - 62s 242ms/step - loss: 0.0259 - tp: 1535.0000 - fp: 11.0000 - tn: 2513.0000 - fn: 25.0000 - binary_acc: 0.9912 - precision: 0.9929 - recall: 0.9840 - f1_score: 0.9884 - roc_auc: 0.9996 - pr_auc: 0.9994 - cohen_kappa: 0.9813 - val_loss: 0.7557 - val_tp: 300.0000 - val_fp: 63.0000 - val_tn: 551.0000 - val_fn: 108.0000 - val_binary_acc: 0.8327 - val_precision: 0.8264 - val_recall: 0.7353 - val_f1_score: 0.7782 - val_roc_auc: 0.8833 - val_pr_auc: 0.8626 - val_cohen_kappa: 0.6446 - lr: 6.4000e-10
# Epoch 37/50
# 256/256 [==============================] - 62s 243ms/step - loss: 0.0222 - tp: 1543.0000 - fp: 9.0000 - tn: 2515.0000 - fn: 17.0000 - binary_acc: 0.9936 - precision: 0.9942 - recall: 0.9891 - f1_score: 0.9916 - roc_auc: 0.9995 - pr_auc: 0.9995 - cohen_kappa: 0.9865 - val_loss: 0.7527 - val_tp: 289.0000 - val_fp: 71.0000 - val_tn: 543.0000 - val_fn: 119.0000 - val_binary_acc: 0.8141 - val_precision: 0.8028 - val_recall: 0.7083 - val_f1_score: 0.7526 - val_roc_auc: 0.8767 - val_pr_auc: 0.8551 - val_cohen_kappa: 0.6046 - lr: 6.4000e-10
# Epoch 38/50
# 256/256 [==============================] - 62s 243ms/step - loss: 0.0277 - tp: 1533.0000 - fp: 14.0000 - tn: 2510.0000 - fn: 27.0000 - binary_acc: 0.9900 - precision: 0.9910 - recall: 0.9827 - f1_score: 0.9868 - roc_auc: 0.9995 - pr_auc: 0.9992 - cohen_kappa: 0.9787 - val_loss: 0.7525 - val_tp: 289.0000 - val_fp: 65.0000 - val_tn: 549.0000 - val_fn: 119.0000 - val_binary_acc: 0.8200 - val_precision: 0.8164 - val_recall: 0.7083 - val_f1_score: 0.7585 - val_roc_auc: 0.8783 - val_pr_auc: 0.8469 - val_cohen_kappa: 0.6162 - lr: 6.4000e-10
# Epoch 39/50
# 256/256 [==============================] - 62s 243ms/step - loss: 0.0265 - tp: 1539.0000 - fp: 11.0000 - tn: 2513.0000 - fn: 21.0000 - binary_acc: 0.9922 - precision: 0.9929 - recall: 0.9865 - f1_score: 0.9897 - roc_auc: 0.9991 - pr_auc: 0.9985 - cohen_kappa: 0.9834 - val_loss: 0.7440 - val_tp: 299.0000 - val_fp: 69.0000 - val_tn: 545.0000 - val_fn: 109.0000 - val_binary_acc: 0.8258 - val_precision: 0.8125 - val_recall: 0.7328 - val_f1_score: 0.7706 - val_roc_auc: 0.8836 - val_pr_auc: 0.8564 - val_cohen_kappa: 0.6308 - lr: 6.4000e-10
# Epoch 40/50
# 256/256 [==============================] - ETA: 0s - loss: 0.0319 - tp: 1531.0000 - fp: 17.0000 - tn: 2507.0000 - fn: 29.0000 - binary_acc: 0.9887 - precision: 0.9890 - recall: 0.9814 - f1_score: 0.9852 - roc_auc: 0.9993 - pr_auc: 0.9990 - cohen_kappa: 0.9761
# Epoch 40: ReduceLROnPlateau reducing learning rate to 1.27999988386307e-10.
# 256/256 [==============================] - 63s 244ms/step - loss: 0.0319 - tp: 1531.0000 - fp: 17.0000 - tn: 2507.0000 - fn: 29.0000 - binary_acc: 0.9887 - precision: 0.9890 - recall: 0.9814 - f1_score: 0.9852 - roc_auc: 0.9993 - pr_auc: 0.9990 - cohen_kappa: 0.9761 - val_loss: 0.7940 - val_tp: 297.0000 - val_fp: 74.0000 - val_tn: 540.0000 - val_fn: 111.0000 - val_binary_acc: 0.8190 - val_precision: 0.8005 - val_recall: 0.7279 - val_f1_score: 0.7625 - val_roc_auc: 0.8738 - val_pr_auc: 0.8351 - val_cohen_kappa: 0.6168 - lr: 6.4000e-10
# Epoch 41/50
# 256/256 [==============================] - 63s 244ms/step - loss: 0.0261 - tp: 1541.0000 - fp: 19.0000 - tn: 2505.0000 - fn: 19.0000 - binary_acc: 0.9907 - precision: 0.9878 - recall: 0.9878 - f1_score: 0.9878 - roc_auc: 0.9996 - pr_auc: 0.9994 - cohen_kappa: 0.9803 - val_loss: 0.7622 - val_tp: 293.0000 - val_fp: 67.0000 - val_tn: 547.0000 - val_fn: 115.0000 - val_binary_acc: 0.8219 - val_precision: 0.8139 - val_recall: 0.7181 - val_f1_score: 0.7630 - val_roc_auc: 0.8735 - val_pr_auc: 0.8490 - val_cohen_kappa: 0.6213 - lr: 1.2800e-10
# Epoch 42/50
# 256/256 [==============================] - 62s 242ms/step - loss: 0.0294 - tp: 1539.0000 - fp: 14.0000 - tn: 2510.0000 - fn: 21.0000 - binary_acc: 0.9914 - precision: 0.9910 - recall: 0.9865 - f1_score: 0.9888 - roc_auc: 0.9989 - pr_auc: 0.9988 - cohen_kappa: 0.9818 - val_loss: 0.7444 - val_tp: 290.0000 - val_fp: 68.0000 - val_tn: 546.0000 - val_fn: 118.0000 - val_binary_acc: 0.8180 - val_precision: 0.8101 - val_recall: 0.7108 - val_f1_score: 0.7572 - val_roc_auc: 0.8823 - val_pr_auc: 0.8586 - val_cohen_kappa: 0.6126 - lr: 1.2800e-10
# Epoch 43/50
# 256/256 [==============================] - 62s 243ms/step - loss: 0.0253 - tp: 1547.0000 - fp: 18.0000 - tn: 2506.0000 - fn: 13.0000 - binary_acc: 0.9924 - precision: 0.9885 - recall: 0.9917 - f1_score: 0.9901 - roc_auc: 0.9996 - pr_auc: 0.9993 - cohen_kappa: 0.9839 - val_loss: 0.7873 - val_tp: 296.0000 - val_fp: 67.0000 - val_tn: 547.0000 - val_fn: 112.0000 - val_binary_acc: 0.8249 - val_precision: 0.8154 - val_recall: 0.7255 - val_f1_score: 0.7678 - val_roc_auc: 0.8756 - val_pr_auc: 0.8431 - val_cohen_kappa: 0.6280 - lr: 1.2800e-10
# Epoch 44/50
# 256/256 [==============================] - ETA: 0s - loss: 0.0277 - tp: 1541.0000 - fp: 15.0000 - tn: 2509.0000 - fn: 19.0000 - binary_acc: 0.9917 - precision: 0.9904 - recall: 0.9878 - f1_score: 0.9891 - roc_auc: 0.9995 - pr_auc: 0.9992 - cohen_kappa: 0.9824
# Epoch 44: ReduceLROnPlateau reducing learning rate to 1e-10.
# 256/256 [==============================] - 62s 244ms/step - loss: 0.0277 - tp: 1541.0000 - fp: 15.0000 - tn: 2509.0000 - fn: 19.0000 - binary_acc: 0.9917 - precision: 0.9904 - recall: 0.9878 - f1_score: 0.9891 - roc_auc: 0.9995 - pr_auc: 0.9992 - cohen_kappa: 0.9824 - val_loss: 0.7755 - val_tp: 295.0000 - val_fp: 78.0000 - val_tn: 536.0000 - val_fn: 113.0000 - val_binary_acc: 0.8131 - val_precision: 0.7909 - val_recall: 0.7230 - val_f1_score: 0.7554 - val_roc_auc: 0.8786 - val_pr_auc: 0.8557 - val_cohen_kappa: 0.6047 - lr: 1.2800e-10
# Epoch 45/50
# 256/256 [==============================] - 63s 244ms/step - loss: 0.0278 - tp: 1534.0000 - fp: 13.0000 - tn: 2511.0000 - fn: 26.0000 - binary_acc: 0.9905 - precision: 0.9916 - recall: 0.9833 - f1_score: 0.9874 - roc_auc: 0.9992 - pr_auc: 0.9991 - cohen_kappa: 0.9797 - val_loss: 0.7860 - val_tp: 292.0000 - val_fp: 74.0000 - val_tn: 540.0000 - val_fn: 116.0000 - val_binary_acc: 0.8141 - val_precision: 0.7978 - val_recall: 0.7157 - val_f1_score: 0.7545 - val_roc_auc: 0.8751 - val_pr_auc: 0.8436 - val_cohen_kappa: 0.6056 - lr: 1.0000e-10
# Epoch 46/50
# 256/256 [==============================] - 63s 244ms/step - loss: 0.0277 - tp: 1541.0000 - fp: 21.0000 - tn: 2503.0000 - fn: 19.0000 - binary_acc: 0.9902 - precision: 0.9866 - recall: 0.9878 - f1_score: 0.9872 - roc_auc: 0.9993 - pr_auc: 0.9986 - cohen_kappa: 0.9793 - val_loss: 0.7810 - val_tp: 294.0000 - val_fp: 73.0000 - val_tn: 541.0000 - val_fn: 114.0000 - val_binary_acc: 0.8170 - val_precision: 0.8011 - val_recall: 0.7206 - val_f1_score: 0.7587 - val_roc_auc: 0.8752 - val_pr_auc: 0.8437 - val_cohen_kappa: 0.6120 - lr: 1.0000e-10
# Epoch 47/50
# 256/256 [==============================] - 62s 243ms/step - loss: 0.0263 - tp: 1538.0000 - fp: 11.0000 - tn: 2513.0000 - fn: 22.0000 - binary_acc: 0.9919 - precision: 0.9929 - recall: 0.9859 - f1_score: 0.9894 - roc_auc: 0.9990 - pr_auc: 0.9990 - cohen_kappa: 0.9829 - val_loss: 0.8032 - val_tp: 291.0000 - val_fp: 62.0000 - val_tn: 552.0000 - val_fn: 117.0000 - val_binary_acc: 0.8249 - val_precision: 0.8244 - val_recall: 0.7132 - val_f1_score: 0.7648 - val_roc_auc: 0.8728 - val_pr_auc: 0.8402 - val_cohen_kappa: 0.6264 - lr: 1.0000e-10
# Epoch 48/50
# 256/256 [==============================] - 62s 241ms/step - loss: 0.0328 - tp: 1528.0000 - fp: 15.0000 - tn: 2509.0000 - fn: 32.0000 - binary_acc: 0.9885 - precision: 0.9903 - recall: 0.9795 - f1_score: 0.9849 - roc_auc: 0.9986 - pr_auc: 0.9980 - cohen_kappa: 0.9756 - val_loss: 0.7796 - val_tp: 295.0000 - val_fp: 73.0000 - val_tn: 541.0000 - val_fn: 113.0000 - val_binary_acc: 0.8180 - val_precision: 0.8016 - val_recall: 0.7230 - val_f1_score: 0.7603 - val_roc_auc: 0.8727 - val_pr_auc: 0.8525 - val_cohen_kappa: 0.6142 - lr: 1.0000e-10
# Epoch 49/50
# 256/256 [==============================] - 62s 243ms/step - loss: 0.0351 - tp: 1529.0000 - fp: 15.0000 - tn: 2509.0000 - fn: 31.0000 - binary_acc: 0.9887 - precision: 0.9903 - recall: 0.9801 - f1_score: 0.9852 - roc_auc: 0.9989 - pr_auc: 0.9974 - cohen_kappa: 0.9761 - val_loss: 0.7142 - val_tp: 287.0000 - val_fp: 74.0000 - val_tn: 540.0000 - val_fn: 121.0000 - val_binary_acc: 0.8092 - val_precision: 0.7950 - val_recall: 0.7034 - val_f1_score: 0.7464 - val_roc_auc: 0.8808 - val_pr_auc: 0.8587 - val_cohen_kappa: 0.5944 - lr: 1.0000e-10
# Epoch 50/50
# 256/256 [==============================] - 62s 243ms/step - loss: 0.0270 - tp: 1532.0000 - fp: 14.0000 - tn: 2510.0000 - fn: 28.0000 - binary_acc: 0.9897 - precision: 0.9909 - recall: 0.9821 - f1_score: 0.9865 - roc_auc: 0.9996 - pr_auc: 0.9993 - cohen_kappa: 0.9782 - val_loss: 0.7814 - val_tp: 290.0000 - val_fp: 69.0000 - val_tn: 545.0000 - val_fn: 118.0000 - val_binary_acc: 0.8170 - val_precision: 0.8078 - val_recall: 0.7108 - val_f1_score: 0.7562 - val_roc_auc: 0.8748 - val_pr_auc: 0.8388 - val_cohen_kappa: 0.6107 - lr: 1.0000e-10

# %%
new_model.save(save_path + model_name + '.keras')
plot_metrics(history)

# %%
new_model.evaluate(validation_generator)
new_model.evaluate(test_generator)

# Make predictions using the validation generator
y_valid_pred_prob = new_model.predict(validation_generator)
y_valid_pred = (y_valid_pred_prob > 0.5).astype(int)
y_valid = validation_generator.classes
print("Classification Report:")
print(classification_report(y_valid, y_valid_pred))

# Make predictions using the test generator
y_pred_prob = new_model.predict(test_generator)
y_pred = (y_pred_prob > 0.5).astype(int)
y_test = test_generator.classes
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# 64/64 [==============================] - 9s 139ms/step - loss: 0.8012 - tp: 291.0000 - fp: 66.0000 - tn: 548.0000 - fn: 117.0000 - binary_acc: 0.8209 - precision: 0.8151 - recall: 0.7132 - f1_score: 0.7608 - roc_auc: 0.8697 - pr_auc: 0.8474 - cohen_kappa: 0.6187
# 29/29 [==============================] - 2s 53ms/step - loss: 1.9805 - tp: 153.0000 - fp: 39.0000 - tn: 175.0000 - fn: 94.0000 - binary_acc: 0.7115 - precision: 0.7969 - recall: 0.6194 - f1_score: 0.6970 - roc_auc: 0.7805 - pr_auc: 0.8056 - cohen_kappa: 0.4298
# 64/64 [==============================] - 9s 135ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.88      0.85       614
#            1       0.80      0.74      0.77       408
#
#     accuracy                           0.82      1022
#    macro avg       0.82      0.81      0.81      1022
# weighted avg       0.82      0.82      0.82      1022
#
# 29/29 [==============================] - 1s 48ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.65      0.82      0.72       214
#            1       0.80      0.62      0.70       247
#
#     accuracy                           0.71       461
#    macro avg       0.72      0.72      0.71       461
# weighted avg       0.73      0.71      0.71       461

# %%
conf_matrix = confusion_matrix(y_test, y_pred)

# Create ConfusionMatrixDisplay object
cm_display = ConfusionMatrixDisplay(confusion_matrix=conf_matrix)

# Plot the confusion matrix
plt.figure(figsize=(4, 6))  # Adjust the figure size as needed
cm_display.plot(cmap=plt.cm.Blues)  # You can choose any colormap you prefer
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.grid(False)  # Turn off grid
plt.savefig(save_path + model_name + "_confusion_matrix.jpg")
plt.show()

# %%
history_df = pd.DataFrame(history.history)
save_history(model_name, history_df)
# Out:
# Training history saved to: C:/Users/raouf/Desktop/pfe/history/final/vgg/XR_FINGER/finetuned_VGG_XR_FINGER_history.xlsx
