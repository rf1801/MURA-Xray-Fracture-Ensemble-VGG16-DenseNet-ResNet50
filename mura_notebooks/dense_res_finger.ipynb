# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
import tensorflow as tf
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras import layers, models
from keras.layers import concatenate, Dense, Conv2D, MaxPooling2D, Flatten, Activation, BatchNormalization, Dropout, \
    Attention, PReLU
from keras import *
from keras.applications import MobileNet
from keras.applications import VGG16
from keras.applications.resnet import ResNet50
from keras import backend as K
from keras.layers import Layer
import keras.layers as kl
import pandas as pd
from keras.applications import EfficientNetB0
import keras.applications
import numpy as np
import os
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from sklearn.metrics import cohen_kappa_score
import seaborn as sns
import pickle
import tensorflow_addons as tfa
from sklearn import metrics
from tensorflow.keras.applications.resnet import preprocess_input as preprocess_input_resnet
from tensorflow.keras.applications.densenet import preprocess_input as preprocess_input_densenet
from tensorflow.keras.models import load_model
import os
import glob
# Out:
# c:\Users\raouf\miniconda3\envs\tensorflowgpu\lib\site-packages\tensorflow_addons\utils\tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# c:\Users\raouf\miniconda3\envs\tensorflowgpu\lib\site-packages\tensorflow_addons\utils\ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.12.0 and strictly below 2.15.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.10.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %%
main_save_path = "C:/Users/raouf/Desktop/pfe/history/final/dense_res/"
mura_location = "C:/Users/raouf/Desktop/pfe/"
data_path = 'C:/Users/raouf/Desktop/pfe/MURA-v1.1/'
train_path = 'C:/Users/raouf/Desktop/pfe/MURA-v1.1/train'
test_path = 'C:/Users/raouf/Desktop/pfe/MURA-v1.1/valid'



train_file = "C:/Users/raouf/Desktop/pfe/datasets/XR_FINGER_df_train.csv"
val_file = "C:/Users/raouf/Desktop/pfe/datasets/XR_FINGER_df_valid.csv"

test_file = "C:/Users/raouf/Desktop/pfe/MURA-v1.1/valid_image_paths.csv"

target_category = "XR_FINGER"

architecture = 'DenseRes'

densenet_path = "C:/Users/raouf/Desktop/pfe/history/all_prof_mura/densenet/" + target_category + "/best/"
resnet_path = "C:/Users/raouf/Desktop/pfe/history/all_prof_mura/resnet/" + target_category + "/best/"



batch_size = 16
num_epochs = 100
fine_tuning_epochs=1
validation_split = 0.2
loss_function = tf.keras.losses.BinaryCrossentropy()
learning_rate = 0.0001
input_shape = (224, 224, 3)


include_top = False
# metrics=["accuracy"] #, tf.keras.metrics.Precision(), tf.keras.metrics.Recall()
early_stopping_patience = 15
shuffle = True
class_mode = 'binary'  # 'categorical'
IMAGE_WIDTH = 224
IMAGE_HEIGHT = 224
trainable = False
training = False
dropout = 0.2

# %%
def load_data(file, part):
    train_data = pd.read_csv(file)
    train_data = train_data.rename(columns={train_data.columns[0]: 'image_path'})
    train_data['label'] = 2
    string_to_add = mura_location
    train_data['image_path'] = string_to_add + train_data['image_path'].astype(str)
    for index, row in train_data.iterrows():
        if 'positive' in str(row['image_path']).lower():
            train_data.at[index, 'label'] = "positive"
        else:
            train_data.at[index, 'label'] = "negative"

    if part == 0:
        pass
    else:
        train_data = train_data[train_data['image_path'].str.contains(part)]
    return train_data


class CustomCallback(keras.callbacks.Callback):
    def on_test_end(self, logs=None):
        keys = list(logs.keys())
        print(f"tp          :", logs["tp"])
        print(f"fp          :", logs["fp"])
        print(f"tn          :", logs["tn"])
        print(f"fn          :", logs["fn"])
        print(f"binary_acc  :", logs["binary_acc"])
        print(f"precision   :", logs["precision"])
        print(f"recall      :", logs["recall"])
        print(f"f1_score    :", logs["f1_score"])
        print(f"roc_auc     :", logs["roc_auc"])
        print(f"pr_auc      :", logs["pr_auc"])
        print(f"cohen_kappa :", logs["cohen_kappa"])

class F1Score(tf.keras.metrics.Metric):

    def __init__(self, name="f1_score", **kwargs):
        super().__init__(name=name, **kwargs)
        self.f1 = self.add_weight(name="f1", initializer="zeros")
        self.precision_fn = tf.keras.metrics.Precision()
        self.recall_fn = tf.keras.metrics.Recall()

    def update_state(self, y_true, y_pred, sample_weight=None):
        p = self.precision_fn(y_true, y_pred)
        r = self.recall_fn(y_true, y_pred)
        self.f1.assign(2 * ((p * r) / (p + r + 1e-10)))

    def result(self):
        return self.f1

    def reset_state(self):
        # we also need to reset the state of the precision and recall objects
        self.precision_fn.reset_state()
        self.recall_fn.reset_state()
        self.f1.assign(0)


def save_history(name,history_df):

    history_excel_path = (
            save_path +
            name +
            '_history'
            '.xlsx'
    )

    history_df.to_excel(history_excel_path, index=False)
    print("Training history saved to:", history_excel_path)






def plot_metrics(history: tf.keras.callbacks.History,
                 metrics: list = ["loss", "cohen_kappa", "precision", "recall"],
                 ) -> None:
    plt.rcParams["figure.figsize"] = (18, 15)

    for n, metric in enumerate(metrics):
        name = metric.replace("_", " ").capitalize()
        plt.subplot(2, 2, n + 1)
        plt.plot(
            history.epoch, history.history[metric], linewidth=1.8, label="training"
        )
        plt.plot(
            history.epoch,
            history.history["val_" + metric],
            linestyle="--",
            linewidth=1.8,
            label="validation",
        )
        plt.xlabel("epoch")
        plt.ylabel(name)
        if metric == "loss":
            plt.ylim([0, plt.ylim()[1]])
        elif metric == "cohen_kappa":
            plt.ylim([-1, 1])
        else:
            plt.ylim([0, 1])

        plt.legend()



class CustomCallback(keras.callbacks.Callback):
    def on_test_end(self, logs=None):
        keys = list(logs.keys())
        print(f"tp          :", logs["tp"])
        print(f"fp          :", logs["fp"])
        print(f"tn          :", logs["tn"])
        print(f"fn          :", logs["fn"])
        print(f"binary_acc  :", logs["binary_acc"])
        print(f"precision   :", logs["precision"])
        print(f"recall      :", logs["recall"])
        print(f"f1_score    :", logs["f1_score"])
        print(f"roc_auc     :", logs["roc_auc"])
        print(f"pr_auc      :", logs["pr_auc"])
        print(f"cohen_kappa :", logs["cohen_kappa"])


def save_history(name,history_df):

    # Constructing the file name with metric values
    history_excel_path = (
            save_path +
            name +
            '_history'
            '.xlsx'
    )

    history_df.to_excel(history_excel_path, index=False)
    print("Training history saved to:", history_excel_path)




class F1Score(tf.keras.metrics.Metric):

    def __init__(self, name="f1_score", **kwargs):
        super().__init__(name=name, **kwargs)
        self.f1 = self.add_weight(name="f1", initializer="zeros")
        self.precision_fn = tf.keras.metrics.Precision()
        self.recall_fn = tf.keras.metrics.Recall()

    def update_state(self, y_true, y_pred, sample_weight=None):
        p = self.precision_fn(y_true, y_pred)
        r = self.recall_fn(y_true, y_pred)
        self.f1.assign(2 * ((p * r) / (p + r + 1e-10)))

    def result(self):
        return self.f1

    def reset_state(self):
        # we also need to reset the state of the precision and recall objects
        self.precision_fn.reset_state()
        self.recall_fn.reset_state()
        self.f1.assign(0)

def plot_metrics(history: tf.keras.callbacks.History,
                 metrics: list = ["loss", "cohen_kappa", "precision", "recall"],
                 ) -> None:
    plt.rcParams["figure.figsize"] = (18, 15)

    for n, metric in enumerate(metrics):
        name = metric.replace("_", " ").capitalize()
        plt.subplot(2, 2, n + 1)
        plt.plot(
            history.epoch, history.history[metric], linewidth=1.8, label="training"
        )
        plt.plot(
            history.epoch,
            history.history["val_" + metric],
            linestyle="--",
            linewidth=1.8,
            label="validation",
        )
        plt.xlabel("epoch")
        plt.ylabel(name)
        if metric == "loss":
            plt.ylim([0, plt.ylim()[1]])
        elif metric == "cohen_kappa":
            plt.ylim([-1, 1])
        else:
            plt.ylim([0, 1])

        plt.legend()


def my_func(model, data_generator, threshold=0.5):
    y_pred_prob = model.predict(data_generator)
    y_pred = (y_pred_prob > threshold).astype(int)
    y_true = data_generator.classes
    print("Classification Report:")
    print(classification_report(y_true, y_pred))

# %%
METRICS = [
    tf.keras.metrics.TruePositives(name="tp"),
    tf.keras.metrics.FalsePositives(name="fp"),
    tf.keras.metrics.TrueNegatives(name="tn"),
    tf.keras.metrics.FalseNegatives(name="fn"),
    tf.keras.metrics.BinaryAccuracy(name="binary_acc"),
    tf.keras.metrics.Precision(name="precision"),
    tf.keras.metrics.Recall(name="recall"),
    F1Score(name="f1_score"),
    tf.keras.metrics.AUC(name="roc_auc", curve="ROC"),
    tf.keras.metrics.AUC(name="pr_auc", curve="PR"),
    tfa.metrics.CohenKappa(name="cohen_kappa", num_classes=2),
]

# %%
files = glob.glob(os.path.join(densenet_path, "*"))
densenet_path = files[0]
densenet_model = load_model(densenet_path, custom_objects={'F1Score': F1Score})
densenet_model.trainable = False
densenet_base = densenet_model.get_layer(name="densenet201")



files = glob.glob(os.path.join(resnet_path, "*"))
resnet_path = files[0]
resnet_model = load_model(resnet_path, custom_objects={"F1Score": F1Score})
resnet_model.trainable = False
resnet_base = resnet_model.get_layer(name="resnet50")



def build_ensemble_model():
    inputs = tf.keras.Input(shape=input_shape)

    resnet_preprocess_input = preprocess_input_resnet(inputs)
    resnet_base_output = resnet_base(resnet_preprocess_input)

    densenet_preprocess_input = preprocess_input_densenet(inputs)
    densenet_base_output = densenet_base(densenet_preprocess_input)

    concat_output = tf.keras.layers.Concatenate(axis=-1)([resnet_base_output, densenet_base_output])

    x = Dense(2048, activation="relu")(concat_output)
    x = Dropout(0.8)(x)
    x = Dense(1024, activation="relu")(x)
    x = Dropout(0.6)(x)
    x = Dense(512, activation="relu")(x)
    x = Dropout(0.4)(x)
    x = Dense(64, activation="relu")(x)
    x = Dropout(0.2)(x)

    prediction = Dense(1, activation="sigmoid")(x)

    model = Model(inputs, prediction)
    model._name = "Ensemble_model"

    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
                  loss=tf.keras.losses.BinaryCrossentropy(),
                  metrics=METRICS)
    return model


new_model = build_ensemble_model()

new_model.summary()
# Out:
# Model: "Ensemble_model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  tf.math.truediv (TFOpLambda)   (None, 224, 224, 3)  0           ['input_1[0][0]']
#
#  tf.__operators__.getitem (Slic  (None, 224, 224, 3)  0          ['input_1[0][0]']
#  ingOpLambda)
#
#  tf.nn.bias_add_1 (TFOpLambda)  (None, 224, 224, 3)  0           ['tf.math.truediv[0][0]']
#
#  tf.nn.bias_add (TFOpLambda)    (None, 224, 224, 3)  0           ['tf.__operators__.getitem[0][0]'
#                                                                  ]
#
#  tf.math.truediv_1 (TFOpLambda)  (None, 224, 224, 3)  0          ['tf.nn.bias_add_1[0][0]']
#
#  resnet50 (Functional)          (None, 2048)         23587712    ['tf.nn.bias_add[0][0]']
#
#  densenet201 (Functional)       (None, 1920)         18321984    ['tf.math.truediv_1[0][0]']
#
#  concatenate (Concatenate)      (None, 3968)         0           ['resnet50[1][0]',
#                                                                   'densenet201[1][0]']
#
#  dense (Dense)                  (None, 2048)         8128512     ['concatenate[0][0]']
#
#  dropout (Dropout)              (None, 2048)         0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 1024)         2098176     ['dropout[0][0]']
#
#  dropout_1 (Dropout)            (None, 1024)         0           ['dense_1[0][0]']
#
#  dense_2 (Dense)                (None, 512)          524800      ['dropout_1[0][0]']
#
#  dropout_2 (Dropout)            (None, 512)          0           ['dense_2[0][0]']
#
#  dense_3 (Dense)                (None, 64)           32832       ['dropout_2[0][0]']
#
#  dropout_3 (Dropout)            (None, 64)           0           ['dense_3[0][0]']
#
#  dense_4 (Dense)                (None, 1)            65          ['dropout_3[0][0]']
#
# ==================================================================================================
# Total params: 52,694,081
# Trainable params: 10,784,385
# Non-trainable params: 41,909,696
# __________________________________________________________________________________________________

# %%
"""import matplotlib.pyplot as plt
from tensorflow.keras.utils import plot_model
tf.keras.utils.plot_model(new_model,
                          show_shapes=True,  # show_dtype=False,
                          show_layer_names=True,
                          layer_range=None,
                          show_layer_activations=True)"""
# Out:
# 'import matplotlib.pyplot as plt\nfrom tensorflow.keras.utils import plot_model\ntf.keras.utils.plot_model(new_model,\n                          show_shapes=True,  # show_dtype=False,\n                          show_layer_names=True,\n                          layer_range=None,\n                          show_layer_activations=True)'

# %%
early_stopping = EarlyStopping(monitor="val_cohen_kappa",
                               verbose=1,
                               patience=early_stopping_patience,
                               mode="max",
                               baseline=0.0,
                               restore_best_weights=True)
save_path = main_save_path + target_category + "/"
model_name = architecture + "_" + target_category
model_path = save_path + '_best_' + model_name + '.keras'
model_checkpoint = ModelCheckpoint(filepath=model_path,
                                       monitor="val_cohen_kappa",
                                       save_best_only=True)

# %%
import pandas as pd


old_base_path = 'C:\\Users\\HP\\Documents\\ML\\encadrement Master\\MURA-V1.1\\'

df_train = pd.read_csv(train_file)
df_train['image_path'] = df_train['image_path'].str.replace(old_base_path, mura_location)

df_valid = pd.read_csv(val_file)
df_valid['image_path'] = df_valid['image_path'].str.replace(old_base_path, mura_location)


df_test = load_data(test_file, target_category)

datagen = tf.keras.preprocessing.image.ImageDataGenerator(rotation_range=30,
                                                              horizontal_flip=True,
                                                              fill_mode="constant",
                                                              cval=0.0,
                                                              )
train_generator = datagen.flow_from_dataframe(df_train,
                                                  directory=None,
                                                  x_col='image_path',
                                                  y_col='label',
                                                  target_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
                                                  batch_size=batch_size,
                                                  class_mode=class_mode,
                                                  )

validation_generator = datagen.flow_from_dataframe(df_valid,
                                                       directory=None,
                                                       x_col='image_path',
                                                       y_col='label',
                                                       target_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
                                                       batch_size=batch_size,
                                                       class_mode=class_mode,
                                                   shuffle=False
                                                       )

test_datagen = tf.keras.preprocessing.image.ImageDataGenerator()
test_generator = test_datagen.flow_from_dataframe(df_test,
                                                      directory=None,
                                                      x_col='image_path',
                                                      y_col='label',
                                                      target_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
                                                      batch_size=batch_size,
                                                      class_mode=class_mode,
                                                  shuffle=False
                                                      )
# Out:
# C:\Users\raouf\AppData\Local\Temp\ipykernel_167760\1983201427.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'positive' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_data.at[index, 'label'] = "positive"
# Found 4084 validated image filenames belonging to 2 classes.
# Found 1022 validated image filenames belonging to 2 classes.
# Found 461 validated image filenames belonging to 2 classes.

# %%
history = new_model.fit(train_generator,
                            # teps_per_epoch=len(df_train) // batch_size,
                            validation_data=validation_generator,
                            # validation_steps=len(df_valid) // batch_size,
                            epochs=num_epochs,
                            shuffle=shuffle,
                            callbacks=[early_stopping, model_checkpoint])  # , reduce_lr_callback])
# Out:
# Epoch 1/100
# 256/256 [==============================] - 68s 206ms/step - loss: 3.0951 - tp: 714.0000 - fp: 968.0000 - tn: 1556.0000 - fn: 846.0000 - binary_acc: 0.5558 - precision: 0.4245 - recall: 0.4577 - f1_score: 0.4405 - roc_auc: 0.5458 - pr_auc: 0.4317 - cohen_kappa: 0.0731 - val_loss: 0.6479 - val_tp: 386.0000 - val_fp: 405.0000 - val_tn: 209.0000 - val_fn: 22.0000 - val_binary_acc: 0.5822 - val_precision: 0.4880 - val_recall: 0.9461 - val_f1_score: 0.6439 - val_roc_auc: 0.8174 - val_pr_auc: 0.7854 - val_cohen_kappa: 0.2475
# Epoch 2/100
# 256/256 [==============================] - 50s 195ms/step - loss: 1.3078 - tp: 771.0000 - fp: 843.0000 - tn: 1681.0000 - fn: 789.0000 - binary_acc: 0.6004 - precision: 0.4777 - recall: 0.4942 - f1_score: 0.4858 - roc_auc: 0.6050 - pr_auc: 0.4951 - cohen_kappa: 0.1592 - val_loss: 0.6463 - val_tp: 268.0000 - val_fp: 108.0000 - val_tn: 506.0000 - val_fn: 140.0000 - val_binary_acc: 0.7573 - val_precision: 0.7128 - val_recall: 0.6569 - val_f1_score: 0.6837 - val_roc_auc: 0.8339 - val_pr_auc: 0.8116 - val_cohen_kappa: 0.4874
# Epoch 3/100
# 256/256 [==============================] - 54s 211ms/step - loss: 0.8742 - tp: 763.0000 - fp: 682.0000 - tn: 1842.0000 - fn: 797.0000 - binary_acc: 0.6379 - precision: 0.5280 - recall: 0.4891 - f1_score: 0.5078 - roc_auc: 0.6451 - pr_auc: 0.5457 - cohen_kappa: 0.2220 - val_loss: 0.6332 - val_tp: 269.0000 - val_fp: 88.0000 - val_tn: 526.0000 - val_fn: 139.0000 - val_binary_acc: 0.7779 - val_precision: 0.7535 - val_recall: 0.6593 - val_f1_score: 0.7033 - val_roc_auc: 0.8558 - val_pr_auc: 0.8338 - val_cohen_kappa: 0.5270
# Epoch 4/100
# 256/256 [==============================] - 55s 213ms/step - loss: 0.7124 - tp: 784.0000 - fp: 633.0000 - tn: 1891.0000 - fn: 776.0000 - binary_acc: 0.6550 - precision: 0.5533 - recall: 0.5026 - f1_score: 0.5267 - roc_auc: 0.6815 - pr_auc: 0.5944 - cohen_kappa: 0.2563 - val_loss: 0.5781 - val_tp: 266.0000 - val_fp: 75.0000 - val_tn: 539.0000 - val_fn: 142.0000 - val_binary_acc: 0.7877 - val_precision: 0.7801 - val_recall: 0.6520 - val_f1_score: 0.7103 - val_roc_auc: 0.8635 - val_pr_auc: 0.8387 - val_cohen_kappa: 0.5448
# Epoch 5/100
# 256/256 [==============================] - 54s 209ms/step - loss: 0.6300 - tp: 834.0000 - fp: 518.0000 - tn: 2006.0000 - fn: 726.0000 - binary_acc: 0.6954 - precision: 0.6169 - recall: 0.5346 - f1_score: 0.5728 - roc_auc: 0.7208 - pr_auc: 0.6629 - cohen_kappa: 0.3380 - val_loss: 0.5394 - val_tp: 225.0000 - val_fp: 22.0000 - val_tn: 592.0000 - val_fn: 183.0000 - val_binary_acc: 0.7994 - val_precision: 0.9109 - val_recall: 0.5515 - val_f1_score: 0.6870 - val_roc_auc: 0.8752 - val_pr_auc: 0.8543 - val_cohen_kappa: 0.5522
# Epoch 6/100
# 256/256 [==============================] - 53s 205ms/step - loss: 0.5727 - tp: 857.0000 - fp: 424.0000 - tn: 2100.0000 - fn: 703.0000 - binary_acc: 0.7240 - precision: 0.6690 - recall: 0.5494 - f1_score: 0.6033 - roc_auc: 0.7703 - pr_auc: 0.6984 - cohen_kappa: 0.3949 - val_loss: 0.4821 - val_tp: 253.0000 - val_fp: 42.0000 - val_tn: 572.0000 - val_fn: 155.0000 - val_binary_acc: 0.8072 - val_precision: 0.8576 - val_recall: 0.6201 - val_f1_score: 0.7198 - val_roc_auc: 0.8853 - val_pr_auc: 0.8634 - val_cohen_kappa: 0.5786
# Epoch 7/100
# 256/256 [==============================] - 53s 209ms/step - loss: 0.5480 - tp: 888.0000 - fp: 388.0000 - tn: 2136.0000 - fn: 672.0000 - binary_acc: 0.7405 - precision: 0.6959 - recall: 0.5692 - f1_score: 0.6262 - roc_auc: 0.7859 - pr_auc: 0.7308 - cohen_kappa: 0.4305 - val_loss: 0.4411 - val_tp: 229.0000 - val_fp: 21.0000 - val_tn: 593.0000 - val_fn: 179.0000 - val_binary_acc: 0.8043 - val_precision: 0.9160 - val_recall: 0.5613 - val_f1_score: 0.6960 - val_roc_auc: 0.8971 - val_pr_auc: 0.8762 - val_cohen_kappa: 0.5637
# Epoch 8/100
# 256/256 [==============================] - 53s 206ms/step - loss: 0.4996 - tp: 929.0000 - fp: 326.0000 - tn: 2198.0000 - fn: 631.0000 - binary_acc: 0.7657 - precision: 0.7402 - recall: 0.5955 - f1_score: 0.6600 - roc_auc: 0.8213 - pr_auc: 0.7694 - cohen_kappa: 0.4844 - val_loss: 0.4253 - val_tp: 266.0000 - val_fp: 36.0000 - val_tn: 578.0000 - val_fn: 142.0000 - val_binary_acc: 0.8258 - val_precision: 0.8808 - val_recall: 0.6520 - val_f1_score: 0.7493 - val_roc_auc: 0.9028 - val_pr_auc: 0.8885 - val_cohen_kappa: 0.6204
# Epoch 9/100
# 256/256 [==============================] - 57s 224ms/step - loss: 0.4799 - tp: 953.0000 - fp: 313.0000 - tn: 2211.0000 - fn: 607.0000 - binary_acc: 0.7747 - precision: 0.7528 - recall: 0.6109 - f1_score: 0.6745 - roc_auc: 0.8364 - pr_auc: 0.7899 - cohen_kappa: 0.5051 - val_loss: 0.3998 - val_tp: 289.0000 - val_fp: 36.0000 - val_tn: 578.0000 - val_fn: 119.0000 - val_binary_acc: 0.8483 - val_precision: 0.8892 - val_recall: 0.7083 - val_f1_score: 0.7885 - val_roc_auc: 0.9186 - val_pr_auc: 0.9063 - val_cohen_kappa: 0.6727
# Epoch 10/100
# 256/256 [==============================] - 55s 214ms/step - loss: 0.4708 - tp: 980.0000 - fp: 305.0000 - tn: 2219.0000 - fn: 580.0000 - binary_acc: 0.7833 - precision: 0.7626 - recall: 0.6282 - f1_score: 0.6889 - roc_auc: 0.8455 - pr_auc: 0.7992 - cohen_kappa: 0.5250 - val_loss: 0.3861 - val_tp: 287.0000 - val_fp: 25.0000 - val_tn: 589.0000 - val_fn: 121.0000 - val_binary_acc: 0.8571 - val_precision: 0.9199 - val_recall: 0.7034 - val_f1_score: 0.7972 - val_roc_auc: 0.9204 - val_pr_auc: 0.9088 - val_cohen_kappa: 0.6899
# Epoch 11/100
# 256/256 [==============================] - 56s 217ms/step - loss: 0.4370 - tp: 1042.0000 - fp: 264.0000 - tn: 2260.0000 - fn: 518.0000 - binary_acc: 0.8085 - precision: 0.7979 - recall: 0.6679 - f1_score: 0.7271 - roc_auc: 0.8645 - pr_auc: 0.8293 - cohen_kappa: 0.5814 - val_loss: 0.3523 - val_tp: 303.0000 - val_fp: 30.0000 - val_tn: 584.0000 - val_fn: 105.0000 - val_binary_acc: 0.8679 - val_precision: 0.9099 - val_recall: 0.7426 - val_f1_score: 0.8178 - val_roc_auc: 0.9282 - val_pr_auc: 0.9189 - val_cohen_kappa: 0.7159
# Epoch 12/100
# 256/256 [==============================] - 55s 216ms/step - loss: 0.4211 - tp: 1047.0000 - fp: 265.0000 - tn: 2259.0000 - fn: 513.0000 - binary_acc: 0.8095 - precision: 0.7980 - recall: 0.6712 - f1_score: 0.7291 - roc_auc: 0.8772 - pr_auc: 0.8444 - cohen_kappa: 0.5839 - val_loss: 0.3522 - val_tp: 330.0000 - val_fp: 49.0000 - val_tn: 565.0000 - val_fn: 78.0000 - val_binary_acc: 0.8757 - val_precision: 0.8707 - val_recall: 0.8088 - val_f1_score: 0.8386 - val_roc_auc: 0.9322 - val_pr_auc: 0.9211 - val_cohen_kappa: 0.7378
# Epoch 13/100
# 256/256 [==============================] - 56s 219ms/step - loss: 0.3956 - tp: 1097.0000 - fp: 238.0000 - tn: 2286.0000 - fn: 463.0000 - binary_acc: 0.8284 - precision: 0.8217 - recall: 0.7032 - f1_score: 0.7579 - roc_auc: 0.8932 - pr_auc: 0.8585 - cohen_kappa: 0.6262 - val_loss: 0.3104 - val_tp: 314.0000 - val_fp: 36.0000 - val_tn: 578.0000 - val_fn: 94.0000 - val_binary_acc: 0.8728 - val_precision: 0.8971 - val_recall: 0.7696 - val_f1_score: 0.8285 - val_roc_auc: 0.9363 - val_pr_auc: 0.9268 - val_cohen_kappa: 0.7283
# Epoch 14/100
# 256/256 [==============================] - 54s 211ms/step - loss: 0.4037 - tp: 1082.0000 - fp: 242.0000 - tn: 2282.0000 - fn: 478.0000 - binary_acc: 0.8237 - precision: 0.8172 - recall: 0.6936 - f1_score: 0.7503 - roc_auc: 0.8865 - pr_auc: 0.8582 - cohen_kappa: 0.6155 - val_loss: 0.3259 - val_tp: 325.0000 - val_fp: 42.0000 - val_tn: 572.0000 - val_fn: 83.0000 - val_binary_acc: 0.8777 - val_precision: 0.8856 - val_recall: 0.7966 - val_f1_score: 0.8387 - val_roc_auc: 0.9397 - val_pr_auc: 0.9301 - val_cohen_kappa: 0.7407
# Epoch 15/100
# 256/256 [==============================] - 55s 215ms/step - loss: 0.3847 - tp: 1098.0000 - fp: 241.0000 - tn: 2283.0000 - fn: 462.0000 - binary_acc: 0.8279 - precision: 0.8200 - recall: 0.7038 - f1_score: 0.7575 - roc_auc: 0.8966 - pr_auc: 0.8664 - cohen_kappa: 0.6253 - val_loss: 0.3273 - val_tp: 339.0000 - val_fp: 62.0000 - val_tn: 552.0000 - val_fn: 69.0000 - val_binary_acc: 0.8718 - val_precision: 0.8454 - val_recall: 0.8309 - val_f1_score: 0.8381 - val_roc_auc: 0.9411 - val_pr_auc: 0.9336 - val_cohen_kappa: 0.7320
# Epoch 16/100
# 256/256 [==============================] - 54s 211ms/step - loss: 0.3865 - tp: 1112.0000 - fp: 235.0000 - tn: 2289.0000 - fn: 448.0000 - binary_acc: 0.8328 - precision: 0.8255 - recall: 0.7128 - f1_score: 0.7650 - roc_auc: 0.8994 - pr_auc: 0.8648 - cohen_kappa: 0.6363 - val_loss: 0.3081 - val_tp: 315.0000 - val_fp: 29.0000 - val_tn: 585.0000 - val_fn: 93.0000 - val_binary_acc: 0.8806 - val_precision: 0.9157 - val_recall: 0.7721 - val_f1_score: 0.8378 - val_roc_auc: 0.9419 - val_pr_auc: 0.9341 - val_cohen_kappa: 0.7444
# Epoch 17/100
# 256/256 [==============================] - 54s 211ms/step - loss: 0.3636 - tp: 1156.0000 - fp: 227.0000 - tn: 2297.0000 - fn: 404.0000 - binary_acc: 0.8455 - precision: 0.8359 - recall: 0.7410 - f1_score: 0.7856 - roc_auc: 0.9098 - pr_auc: 0.8828 - cohen_kappa: 0.6655 - val_loss: 0.3007 - val_tp: 328.0000 - val_fp: 40.0000 - val_tn: 574.0000 - val_fn: 80.0000 - val_binary_acc: 0.8826 - val_precision: 0.8913 - val_recall: 0.8039 - val_f1_score: 0.8454 - val_roc_auc: 0.9429 - val_pr_auc: 0.9341 - val_cohen_kappa: 0.7511
# Epoch 18/100
# 256/256 [==============================] - 52s 204ms/step - loss: 0.3593 - tp: 1154.0000 - fp: 237.0000 - tn: 2287.0000 - fn: 406.0000 - binary_acc: 0.8426 - precision: 0.8296 - recall: 0.7397 - f1_score: 0.7821 - roc_auc: 0.9143 - pr_auc: 0.8866 - cohen_kappa: 0.6595 - val_loss: 0.2798 - val_tp: 337.0000 - val_fp: 39.0000 - val_tn: 575.0000 - val_fn: 71.0000 - val_binary_acc: 0.8924 - val_precision: 0.8963 - val_recall: 0.8260 - val_f1_score: 0.8597 - val_roc_auc: 0.9528 - val_pr_auc: 0.9447 - val_cohen_kappa: 0.7726
# Epoch 19/100
# 256/256 [==============================] - 51s 199ms/step - loss: 0.3588 - tp: 1147.0000 - fp: 209.0000 - tn: 2315.0000 - fn: 413.0000 - binary_acc: 0.8477 - precision: 0.8459 - recall: 0.7353 - f1_score: 0.7867 - roc_auc: 0.9123 - pr_auc: 0.8854 - cohen_kappa: 0.6692 - val_loss: 0.2929 - val_tp: 343.0000 - val_fp: 45.0000 - val_tn: 569.0000 - val_fn: 65.0000 - val_binary_acc: 0.8924 - val_precision: 0.8840 - val_recall: 0.8407 - val_f1_score: 0.8618 - val_roc_auc: 0.9509 - val_pr_auc: 0.9443 - val_cohen_kappa: 0.7738
# Epoch 20/100
# 256/256 [==============================] - 51s 198ms/step - loss: 0.3409 - tp: 1174.0000 - fp: 206.0000 - tn: 2318.0000 - fn: 386.0000 - binary_acc: 0.8550 - precision: 0.8507 - recall: 0.7526 - f1_score: 0.7986 - roc_auc: 0.9195 - pr_auc: 0.8964 - cohen_kappa: 0.6861 - val_loss: 0.2699 - val_tp: 328.0000 - val_fp: 27.0000 - val_tn: 587.0000 - val_fn: 80.0000 - val_binary_acc: 0.8953 - val_precision: 0.9239 - val_recall: 0.8039 - val_f1_score: 0.8598 - val_roc_auc: 0.9531 - val_pr_auc: 0.9471 - val_cohen_kappa: 0.7769
# Epoch 21/100
# 256/256 [==============================] - 50s 196ms/step - loss: 0.3467 - tp: 1169.0000 - fp: 229.0000 - tn: 2295.0000 - fn: 391.0000 - binary_acc: 0.8482 - precision: 0.8362 - recall: 0.7494 - f1_score: 0.7904 - roc_auc: 0.9187 - pr_auc: 0.8932 - cohen_kappa: 0.6720 - val_loss: 0.2834 - val_tp: 313.0000 - val_fp: 19.0000 - val_tn: 595.0000 - val_fn: 95.0000 - val_binary_acc: 0.8885 - val_precision: 0.9428 - val_recall: 0.7672 - val_f1_score: 0.8459 - val_roc_auc: 0.9521 - val_pr_auc: 0.9452 - val_cohen_kappa: 0.7600
# Epoch 22/100
# 256/256 [==============================] - 51s 201ms/step - loss: 0.3351 - tp: 1186.0000 - fp: 173.0000 - tn: 2351.0000 - fn: 374.0000 - binary_acc: 0.8661 - precision: 0.8727 - recall: 0.7603 - f1_score: 0.8126 - roc_auc: 0.9226 - pr_auc: 0.9036 - cohen_kappa: 0.7092 - val_loss: 0.2751 - val_tp: 333.0000 - val_fp: 34.0000 - val_tn: 580.0000 - val_fn: 75.0000 - val_binary_acc: 0.8933 - val_precision: 0.9074 - val_recall: 0.8162 - val_f1_score: 0.8594 - val_roc_auc: 0.9558 - val_pr_auc: 0.9466 - val_cohen_kappa: 0.7738
# Epoch 23/100
# 256/256 [==============================] - 54s 210ms/step - loss: 0.3292 - tp: 1203.0000 - fp: 201.0000 - tn: 2323.0000 - fn: 357.0000 - binary_acc: 0.8634 - precision: 0.8568 - recall: 0.7712 - f1_score: 0.8117 - roc_auc: 0.9249 - pr_auc: 0.9061 - cohen_kappa: 0.7050 - val_loss: 0.2697 - val_tp: 342.0000 - val_fp: 36.0000 - val_tn: 578.0000 - val_fn: 66.0000 - val_binary_acc: 0.9002 - val_precision: 0.9048 - val_recall: 0.8382 - val_f1_score: 0.8702 - val_roc_auc: 0.9532 - val_pr_auc: 0.9479 - val_cohen_kappa: 0.7893
# Epoch 24/100
# 256/256 [==============================] - 51s 199ms/step - loss: 0.3196 - tp: 1212.0000 - fp: 196.0000 - tn: 2328.0000 - fn: 348.0000 - binary_acc: 0.8668 - precision: 0.8608 - recall: 0.7769 - f1_score: 0.8167 - roc_auc: 0.9282 - pr_auc: 0.9108 - cohen_kappa: 0.7125 - val_loss: 0.2596 - val_tp: 334.0000 - val_fp: 28.0000 - val_tn: 586.0000 - val_fn: 74.0000 - val_binary_acc: 0.9002 - val_precision: 0.9227 - val_recall: 0.8186 - val_f1_score: 0.8675 - val_roc_auc: 0.9549 - val_pr_auc: 0.9504 - val_cohen_kappa: 0.7879
# Epoch 25/100
# 256/256 [==============================] - 52s 203ms/step - loss: 0.3116 - tp: 1225.0000 - fp: 189.0000 - tn: 2335.0000 - fn: 335.0000 - binary_acc: 0.8717 - precision: 0.8663 - recall: 0.7853 - f1_score: 0.8238 - roc_auc: 0.9333 - pr_auc: 0.9149 - cohen_kappa: 0.7233 - val_loss: 0.2817 - val_tp: 364.0000 - val_fp: 57.0000 - val_tn: 557.0000 - val_fn: 44.0000 - val_binary_acc: 0.9012 - val_precision: 0.8646 - val_recall: 0.8922 - val_f1_score: 0.8782 - val_roc_auc: 0.9543 - val_pr_auc: 0.9470 - val_cohen_kappa: 0.7951
# Epoch 26/100
# 256/256 [==============================] - 51s 199ms/step - loss: 0.3156 - tp: 1210.0000 - fp: 185.0000 - tn: 2339.0000 - fn: 350.0000 - binary_acc: 0.8690 - precision: 0.8674 - recall: 0.7756 - f1_score: 0.8190 - roc_auc: 0.9335 - pr_auc: 0.9115 - cohen_kappa: 0.7168 - val_loss: 0.2655 - val_tp: 351.0000 - val_fp: 41.0000 - val_tn: 573.0000 - val_fn: 57.0000 - val_binary_acc: 0.9041 - val_precision: 0.8954 - val_recall: 0.8603 - val_f1_score: 0.8775 - val_roc_auc: 0.9561 - val_pr_auc: 0.9507 - val_cohen_kappa: 0.7988
# Epoch 27/100
# 256/256 [==============================] - 51s 199ms/step - loss: 0.3007 - tp: 1220.0000 - fp: 169.0000 - tn: 2355.0000 - fn: 340.0000 - binary_acc: 0.8754 - precision: 0.8783 - recall: 0.7821 - f1_score: 0.8274 - roc_auc: 0.9401 - pr_auc: 0.9185 - cohen_kappa: 0.7304 - val_loss: 0.2561 - val_tp: 343.0000 - val_fp: 31.0000 - val_tn: 583.0000 - val_fn: 65.0000 - val_binary_acc: 0.9061 - val_precision: 0.9171 - val_recall: 0.8407 - val_f1_score: 0.8772 - val_roc_auc: 0.9572 - val_pr_auc: 0.9506 - val_cohen_kappa: 0.8014
# Epoch 28/100
# 256/256 [==============================] - 51s 197ms/step - loss: 0.3010 - tp: 1232.0000 - fp: 186.0000 - tn: 2338.0000 - fn: 328.0000 - binary_acc: 0.8741 - precision: 0.8688 - recall: 0.7897 - f1_score: 0.8274 - roc_auc: 0.9387 - pr_auc: 0.9182 - cohen_kappa: 0.7287 - val_loss: 0.2478 - val_tp: 331.0000 - val_fp: 18.0000 - val_tn: 596.0000 - val_fn: 77.0000 - val_binary_acc: 0.9070 - val_precision: 0.9484 - val_recall: 0.8113 - val_f1_score: 0.8745 - val_roc_auc: 0.9633 - val_pr_auc: 0.9577 - val_cohen_kappa: 0.8014
# Epoch 29/100
# 256/256 [==============================] - 51s 200ms/step - loss: 0.2949 - tp: 1254.0000 - fp: 161.0000 - tn: 2363.0000 - fn: 306.0000 - binary_acc: 0.8857 - precision: 0.8862 - recall: 0.8038 - f1_score: 0.8430 - roc_auc: 0.9404 - pr_auc: 0.9230 - cohen_kappa: 0.7534 - val_loss: 0.2605 - val_tp: 324.0000 - val_fp: 23.0000 - val_tn: 591.0000 - val_fn: 84.0000 - val_binary_acc: 0.8953 - val_precision: 0.9337 - val_recall: 0.7941 - val_f1_score: 0.8583 - val_roc_auc: 0.9570 - val_pr_auc: 0.9509 - val_cohen_kappa: 0.7761
# Epoch 30/100
# 256/256 [==============================] - 51s 200ms/step - loss: 0.2942 - tp: 1248.0000 - fp: 173.0000 - tn: 2351.0000 - fn: 312.0000 - binary_acc: 0.8812 - precision: 0.8783 - recall: 0.8000 - f1_score: 0.8373 - roc_auc: 0.9408 - pr_auc: 0.9212 - cohen_kappa: 0.7441 - val_loss: 0.2299 - val_tp: 351.0000 - val_fp: 25.0000 - val_tn: 589.0000 - val_fn: 57.0000 - val_binary_acc: 0.9198 - val_precision: 0.9335 - val_recall: 0.8603 - val_f1_score: 0.8954 - val_roc_auc: 0.9657 - val_pr_auc: 0.9615 - val_cohen_kappa: 0.8305
# Epoch 31/100
# 256/256 [==============================] - 51s 199ms/step - loss: 0.3005 - tp: 1230.0000 - fp: 166.0000 - tn: 2358.0000 - fn: 330.0000 - binary_acc: 0.8786 - precision: 0.8811 - recall: 0.7885 - f1_score: 0.8322 - roc_auc: 0.9391 - pr_auc: 0.9197 - cohen_kappa: 0.7375 - val_loss: 0.2526 - val_tp: 325.0000 - val_fp: 14.0000 - val_tn: 600.0000 - val_fn: 83.0000 - val_binary_acc: 0.9051 - val_precision: 0.9587 - val_recall: 0.7966 - val_f1_score: 0.8701 - val_roc_auc: 0.9608 - val_pr_auc: 0.9563 - val_cohen_kappa: 0.7964
# Epoch 32/100
# 256/256 [==============================] - 51s 197ms/step - loss: 0.2895 - tp: 1233.0000 - fp: 174.0000 - tn: 2350.0000 - fn: 327.0000 - binary_acc: 0.8773 - precision: 0.8763 - recall: 0.7904 - f1_score: 0.8311 - roc_auc: 0.9422 - pr_auc: 0.9248 - cohen_kappa: 0.7352 - val_loss: 0.2565 - val_tp: 320.0000 - val_fp: 18.0000 - val_tn: 596.0000 - val_fn: 88.0000 - val_binary_acc: 0.8963 - val_precision: 0.9467 - val_recall: 0.7843 - val_f1_score: 0.8579 - val_roc_auc: 0.9586 - val_pr_auc: 0.9513 - val_cohen_kappa: 0.7774
# Epoch 33/100
# 256/256 [==============================] - 51s 197ms/step - loss: 0.2790 - tp: 1253.0000 - fp: 158.0000 - tn: 2366.0000 - fn: 307.0000 - binary_acc: 0.8861 - precision: 0.8880 - recall: 0.8032 - f1_score: 0.8435 - roc_auc: 0.9472 - pr_auc: 0.9306 - cohen_kappa: 0.7544 - val_loss: 0.2437 - val_tp: 338.0000 - val_fp: 29.0000 - val_tn: 585.0000 - val_fn: 70.0000 - val_binary_acc: 0.9031 - val_precision: 0.9210 - val_recall: 0.8284 - val_f1_score: 0.8723 - val_roc_auc: 0.9585 - val_pr_auc: 0.9535 - val_cohen_kappa: 0.7946
# Epoch 34/100
# 256/256 [==============================] - 51s 199ms/step - loss: 0.2970 - tp: 1250.0000 - fp: 208.0000 - tn: 2316.0000 - fn: 310.0000 - binary_acc: 0.8732 - precision: 0.8573 - recall: 0.8013 - f1_score: 0.8284 - roc_auc: 0.9405 - pr_auc: 0.9211 - cohen_kappa: 0.7280 - val_loss: 0.2414 - val_tp: 353.0000 - val_fp: 25.0000 - val_tn: 589.0000 - val_fn: 55.0000 - val_binary_acc: 0.9217 - val_precision: 0.9339 - val_recall: 0.8652 - val_f1_score: 0.8982 - val_roc_auc: 0.9626 - val_pr_auc: 0.9575 - val_cohen_kappa: 0.8348
# Epoch 35/100
# 256/256 [==============================] - 52s 202ms/step - loss: 0.2856 - tp: 1242.0000 - fp: 171.0000 - tn: 2353.0000 - fn: 318.0000 - binary_acc: 0.8803 - precision: 0.8790 - recall: 0.7962 - f1_score: 0.8355 - roc_auc: 0.9433 - pr_auc: 0.9268 - cohen_kappa: 0.7418 - val_loss: 0.2326 - val_tp: 350.0000 - val_fp: 35.0000 - val_tn: 579.0000 - val_fn: 58.0000 - val_binary_acc: 0.9090 - val_precision: 0.9091 - val_recall: 0.8578 - val_f1_score: 0.8827 - val_roc_auc: 0.9628 - val_pr_auc: 0.9576 - val_cohen_kappa: 0.8085
# Epoch 36/100
# 256/256 [==============================] - 51s 198ms/step - loss: 0.2785 - tp: 1248.0000 - fp: 154.0000 - tn: 2370.0000 - fn: 312.0000 - binary_acc: 0.8859 - precision: 0.8902 - recall: 0.8000 - f1_score: 0.8427 - roc_auc: 0.9482 - pr_auc: 0.9306 - cohen_kappa: 0.7536 - val_loss: 0.2419 - val_tp: 320.0000 - val_fp: 15.0000 - val_tn: 599.0000 - val_fn: 88.0000 - val_binary_acc: 0.8992 - val_precision: 0.9552 - val_recall: 0.7843 - val_f1_score: 0.8614 - val_roc_auc: 0.9657 - val_pr_auc: 0.9597 - val_cohen_kappa: 0.7834
# Epoch 37/100
# 256/256 [==============================] - 51s 200ms/step - loss: 0.2814 - tp: 1259.0000 - fp: 169.0000 - tn: 2355.0000 - fn: 301.0000 - binary_acc: 0.8849 - precision: 0.8817 - recall: 0.8071 - f1_score: 0.8427 - roc_auc: 0.9461 - pr_auc: 0.9291 - cohen_kappa: 0.7522 - val_loss: 0.2310 - val_tp: 331.0000 - val_fp: 12.0000 - val_tn: 602.0000 - val_fn: 77.0000 - val_binary_acc: 0.9129 - val_precision: 0.9650 - val_recall: 0.8113 - val_f1_score: 0.8815 - val_roc_auc: 0.9661 - val_pr_auc: 0.9620 - val_cohen_kappa: 0.8135
# Epoch 38/100
# 256/256 [==============================] - 51s 198ms/step - loss: 0.2597 - tp: 1300.0000 - fp: 155.0000 - tn: 2369.0000 - fn: 260.0000 - binary_acc: 0.8984 - precision: 0.8935 - recall: 0.8333 - f1_score: 0.8624 - roc_auc: 0.9549 - pr_auc: 0.9375 - cohen_kappa: 0.7820 - val_loss: 0.2413 - val_tp: 339.0000 - val_fp: 29.0000 - val_tn: 585.0000 - val_fn: 69.0000 - val_binary_acc: 0.9041 - val_precision: 0.9212 - val_recall: 0.8309 - val_f1_score: 0.8737 - val_roc_auc: 0.9609 - val_pr_auc: 0.9570 - val_cohen_kappa: 0.7968
# Epoch 39/100
# 256/256 [==============================] - 51s 198ms/step - loss: 0.2689 - tp: 1276.0000 - fp: 159.0000 - tn: 2365.0000 - fn: 284.0000 - binary_acc: 0.8915 - precision: 0.8892 - recall: 0.8179 - f1_score: 0.8521 - roc_auc: 0.9517 - pr_auc: 0.9356 - cohen_kappa: 0.7667 - val_loss: 0.2255 - val_tp: 346.0000 - val_fp: 30.0000 - val_tn: 584.0000 - val_fn: 62.0000 - val_binary_acc: 0.9100 - val_precision: 0.9202 - val_recall: 0.8480 - val_f1_score: 0.8827 - val_roc_auc: 0.9670 - val_pr_auc: 0.9599 - val_cohen_kappa: 0.8098
# Epoch 40/100
# 256/256 [==============================] - 51s 199ms/step - loss: 0.2608 - tp: 1279.0000 - fp: 156.0000 - tn: 2368.0000 - fn: 281.0000 - binary_acc: 0.8930 - precision: 0.8913 - recall: 0.8199 - f1_score: 0.8541 - roc_auc: 0.9542 - pr_auc: 0.9375 - cohen_kappa: 0.7698 - val_loss: 0.2314 - val_tp: 340.0000 - val_fp: 24.0000 - val_tn: 590.0000 - val_fn: 68.0000 - val_binary_acc: 0.9100 - val_precision: 0.9341 - val_recall: 0.8333 - val_f1_score: 0.8808 - val_roc_auc: 0.9634 - val_pr_auc: 0.9583 - val_cohen_kappa: 0.8089
# Epoch 41/100
# 256/256 [==============================] - 52s 201ms/step - loss: 0.2697 - tp: 1277.0000 - fp: 169.0000 - tn: 2355.0000 - fn: 283.0000 - binary_acc: 0.8893 - precision: 0.8831 - recall: 0.8186 - f1_score: 0.8496 - roc_auc: 0.9516 - pr_auc: 0.9333 - cohen_kappa: 0.7623 - val_loss: 0.2405 - val_tp: 330.0000 - val_fp: 23.0000 - val_tn: 591.0000 - val_fn: 78.0000 - val_binary_acc: 0.9012 - val_precision: 0.9348 - val_recall: 0.8088 - val_f1_score: 0.8673 - val_roc_auc: 0.9649 - val_pr_auc: 0.9572 - val_cohen_kappa: 0.7892
# Epoch 42/100
# 256/256 [==============================] - 51s 198ms/step - loss: 0.2683 - tp: 1281.0000 - fp: 175.0000 - tn: 2349.0000 - fn: 279.0000 - binary_acc: 0.8888 - precision: 0.8798 - recall: 0.8212 - f1_score: 0.8495 - roc_auc: 0.9509 - pr_auc: 0.9366 - cohen_kappa: 0.7615 - val_loss: 0.2342 - val_tp: 334.0000 - val_fp: 13.0000 - val_tn: 601.0000 - val_fn: 74.0000 - val_binary_acc: 0.9149 - val_precision: 0.9625 - val_recall: 0.8186 - val_f1_score: 0.8848 - val_roc_auc: 0.9656 - val_pr_auc: 0.9612 - val_cohen_kappa: 0.8180
# Epoch 43/100
# 256/256 [==============================] - 51s 199ms/step - loss: 0.2639 - tp: 1295.0000 - fp: 154.0000 - tn: 2370.0000 - fn: 265.0000 - binary_acc: 0.8974 - precision: 0.8937 - recall: 0.8301 - f1_score: 0.8608 - roc_auc: 0.9536 - pr_auc: 0.9375 - cohen_kappa: 0.7797 - val_loss: 0.2276 - val_tp: 336.0000 - val_fp: 22.0000 - val_tn: 592.0000 - val_fn: 72.0000 - val_binary_acc: 0.9080 - val_precision: 0.9385 - val_recall: 0.8235 - val_f1_score: 0.8773 - val_roc_auc: 0.9673 - val_pr_auc: 0.9609 - val_cohen_kappa: 0.8042
# Epoch 44/100
# 256/256 [==============================] - 52s 201ms/step - loss: 0.2496 - tp: 1283.0000 - fp: 151.0000 - tn: 2373.0000 - fn: 277.0000 - binary_acc: 0.8952 - precision: 0.8947 - recall: 0.8224 - f1_score: 0.8570 - roc_auc: 0.9568 - pr_auc: 0.9447 - cohen_kappa: 0.7746 - val_loss: 0.2383 - val_tp: 313.0000 - val_fp: 16.0000 - val_tn: 598.0000 - val_fn: 95.0000 - val_binary_acc: 0.8914 - val_precision: 0.9514 - val_recall: 0.7672 - val_f1_score: 0.8494 - val_roc_auc: 0.9676 - val_pr_auc: 0.9617 - val_cohen_kappa: 0.7660
# Epoch 45/100
# 256/256 [==============================] - 53s 207ms/step - loss: 0.2482 - tp: 1297.0000 - fp: 150.0000 - tn: 2374.0000 - fn: 263.0000 - binary_acc: 0.8989 - precision: 0.8963 - recall: 0.8314 - f1_score: 0.8627 - roc_auc: 0.9580 - pr_auc: 0.9429 - cohen_kappa: 0.7828 - val_loss: 0.2391 - val_tp: 329.0000 - val_fp: 18.0000 - val_tn: 596.0000 - val_fn: 79.0000 - val_binary_acc: 0.9051 - val_precision: 0.9481 - val_recall: 0.8064 - val_f1_score: 0.8715 - val_roc_auc: 0.9643 - val_pr_auc: 0.9578 - val_cohen_kappa: 0.7970
# Epoch 46/100
# 256/256 [==============================] - 51s 200ms/step - loss: 0.2529 - tp: 1304.0000 - fp: 156.0000 - tn: 2368.0000 - fn: 256.0000 - binary_acc: 0.8991 - precision: 0.8932 - recall: 0.8359 - f1_score: 0.8636 - roc_auc: 0.9569 - pr_auc: 0.9418 - cohen_kappa: 0.7837 - val_loss: 0.2200 - val_tp: 335.0000 - val_fp: 19.0000 - val_tn: 595.0000 - val_fn: 73.0000 - val_binary_acc: 0.9100 - val_precision: 0.9463 - val_recall: 0.8211 - val_f1_score: 0.8793 - val_roc_auc: 0.9695 - val_pr_auc: 0.9639 - val_cohen_kappa: 0.8081
# Epoch 47/100
# 256/256 [==============================] - 53s 208ms/step - loss: 0.2466 - tp: 1296.0000 - fp: 141.0000 - tn: 2383.0000 - fn: 264.0000 - binary_acc: 0.9008 - precision: 0.9019 - recall: 0.8308 - f1_score: 0.8649 - roc_auc: 0.9581 - pr_auc: 0.9451 - cohen_kappa: 0.7868 - val_loss: 0.2483 - val_tp: 313.0000 - val_fp: 9.0000 - val_tn: 605.0000 - val_fn: 95.0000 - val_binary_acc: 0.8982 - val_precision: 0.9720 - val_recall: 0.7672 - val_f1_score: 0.8575 - val_roc_auc: 0.9672 - val_pr_auc: 0.9622 - val_cohen_kappa: 0.7801
# Epoch 48/100
# 256/256 [==============================] - 52s 202ms/step - loss: 0.2388 - tp: 1311.0000 - fp: 146.0000 - tn: 2378.0000 - fn: 249.0000 - binary_acc: 0.9033 - precision: 0.8998 - recall: 0.8404 - f1_score: 0.8691 - roc_auc: 0.9606 - pr_auc: 0.9484 - cohen_kappa: 0.7925 - val_loss: 0.2180 - val_tp: 341.0000 - val_fp: 20.0000 - val_tn: 594.0000 - val_fn: 67.0000 - val_binary_acc: 0.9149 - val_precision: 0.9446 - val_recall: 0.8358 - val_f1_score: 0.8869 - val_roc_auc: 0.9686 - val_pr_auc: 0.9641 - val_cohen_kappa: 0.8190
# Epoch 49/100
# 256/256 [==============================] - ETA: 0s - loss: 0.2455 - tp: 1292.0000 - fp: 140.0000 - tn: 2384.0000 - fn: 268.0000 - binary_acc: 0.9001 - precision: 0.9022 - recall: 0.8282 - f1_score: 0.8636 - roc_auc: 0.9592 - pr_auc: 0.9461 - cohen_kappa: 0.7850Restoring model weights from the end of the best epoch: 34.
# 256/256 [==============================] - 54s 210ms/step - loss: 0.2455 - tp: 1292.0000 - fp: 140.0000 - tn: 2384.0000 - fn: 268.0000 - binary_acc: 0.9001 - precision: 0.9022 - recall: 0.8282 - f1_score: 0.8636 - roc_auc: 0.9592 - pr_auc: 0.9461 - cohen_kappa: 0.7850 - val_loss: 0.2307 - val_tp: 335.0000 - val_fp: 16.0000 - val_tn: 598.0000 - val_fn: 73.0000 - val_binary_acc: 0.9129 - val_precision: 0.9544 - val_recall: 0.8211 - val_f1_score: 0.8827 - val_roc_auc: 0.9666 - val_pr_auc: 0.9619 - val_cohen_kappa: 0.8141
# Epoch 49: early stopping

# %%
new_model.save(save_path + model_name + '.keras')

plot_metrics(history)

# %%
"""new_model.evaluate(validation_generator)"""
new_model.evaluate(test_generator)

    # Make predictions using the validation generator
"""y_valid_pred_prob = new_model.predict(validation_generator)
y_valid_pred = (y_valid_pred_prob > 0.5).astype(int)
y_valid = validation_generator.classes
print("Classification Report:")
print(classification_report(y_valid, y_valid_pred))"""

y_pred_prob = new_model.predict(test_generator)
y_pred = (y_pred_prob > 0.5).astype(int)
y_test = test_generator.classes
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# 29/29 [==============================] - 4s 137ms/step - loss: 0.5728 - tp: 174.0000 - fp: 41.0000 - tn: 173.0000 - fn: 73.0000 - binary_acc: 0.7527 - precision: 0.8093 - recall: 0.7045 - f1_score: 0.7532 - roc_auc: 0.8304 - pr_auc: 0.8629 - cohen_kappa: 0.5078
# 29/29 [==============================] - 7s 122ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.70      0.81      0.75       214
#            1       0.81      0.70      0.75       247
#
#     accuracy                           0.75       461
#    macro avg       0.76      0.76      0.75       461
# weighted avg       0.76      0.75      0.75       461

# %%
conf_matrix = confusion_matrix(y_test, y_pred)

# Create ConfusionMatrixDisplay object
cm_display = ConfusionMatrixDisplay(confusion_matrix=conf_matrix)

# Plot the confusion matrix
plt.figure(figsize=(4, 6))  # Adjust the figure size as needed
cm_display.plot(cmap=plt.cm.Blues)  # You can choose any colormap you prefer
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.grid(False)  # Turn off grid
plt.savefig(save_path + model_name + "_confusion_matrix.jpg")
plt.show()

# %%
history_df = pd.DataFrame(history.history)
save_history(model_name, history_df)

new_model.save(save_path + model_name + "_pt_imagenet-{new_model.count_params()}.h5")
new_model.save(save_path + model_name + ".h5")
# Out:
# Training history saved to: C:/Users/raouf/Desktop/pfe/history/final/dense_res/XR_FINGER/DenseRes_XR_FINGER_history.xlsx
