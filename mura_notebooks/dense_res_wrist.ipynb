# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
import tensorflow as tf
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras import layers, models
from keras.layers import concatenate, Dense, Conv2D, MaxPooling2D, Flatten, Activation, BatchNormalization, Dropout, \
    Attention, PReLU
from keras import *
from keras.applications import MobileNet
from keras.applications import VGG16
from keras.applications.resnet import ResNet50
from keras import backend as K
from keras.layers import Layer
import keras.layers as kl
import pandas as pd
from keras.applications import EfficientNetB0
import keras.applications
import numpy as np
import os
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from sklearn.metrics import cohen_kappa_score
import seaborn as sns
import pickle
import tensorflow_addons as tfa
from sklearn import metrics
from tensorflow.keras.applications.resnet import preprocess_input as preprocess_input_resnet
from tensorflow.keras.applications.densenet import preprocess_input as preprocess_input_densenet
from tensorflow.keras.models import load_model
import os
import glob
# Out:
# c:\Users\raouf\miniconda3\envs\tensorflowgpu\lib\site-packages\tensorflow_addons\utils\tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# c:\Users\raouf\miniconda3\envs\tensorflowgpu\lib\site-packages\tensorflow_addons\utils\ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.12.0 and strictly below 2.15.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.10.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %%
main_save_path = "C:/Users/raouf/Desktop/pfe/history/final/dense_res/"
mura_location = "C:/Users/raouf/Desktop/pfe/"
data_path = 'C:/Users/raouf/Desktop/pfe/MURA-v1.1/'
train_path = 'C:/Users/raouf/Desktop/pfe/MURA-v1.1/train'
test_path = 'C:/Users/raouf/Desktop/pfe/MURA-v1.1/valid'



train_file = "C:/Users/raouf/Desktop/pfe/datasets/XR_WRIST_df_train.csv"
val_file = "C:/Users/raouf/Desktop/pfe/datasets/XR_WRIST_df_valid.csv"

test_file = "C:/Users/raouf/Desktop/pfe/MURA-v1.1/valid_image_paths.csv"

target_category = "XR_WRIST"

architecture = 'DenseRes'

densenet_path = "C:/Users/raouf/Desktop/pfe/history/all_prof_mura/densenet/" + target_category + "/best/"
resnet_path = "C:/Users/raouf/Desktop/pfe/history/all_prof_mura/resnet/" + target_category + "/best/"



batch_size = 16
num_epochs = 100
fine_tuning_epochs=1
validation_split = 0.2
loss_function = tf.keras.losses.BinaryCrossentropy()
learning_rate = 0.0001
input_shape = (224, 224, 3)


include_top = False
# metrics=["accuracy"] #, tf.keras.metrics.Precision(), tf.keras.metrics.Recall()
early_stopping_patience = 15
shuffle = True
class_mode = 'binary'  # 'categorical'
IMAGE_WIDTH = 224
IMAGE_HEIGHT = 224
trainable = False
training = False
dropout = 0.2

# %%
def load_data(file, part):
    train_data = pd.read_csv(file)
    train_data = train_data.rename(columns={train_data.columns[0]: 'image_path'})
    train_data['label'] = 2
    string_to_add = mura_location
    train_data['image_path'] = string_to_add + train_data['image_path'].astype(str)
    for index, row in train_data.iterrows():
        if 'positive' in str(row['image_path']).lower():
            train_data.at[index, 'label'] = "positive"
        else:
            train_data.at[index, 'label'] = "negative"

    if part == 0:
        pass
    else:
        train_data = train_data[train_data['image_path'].str.contains(part)]
    return train_data


class CustomCallback(keras.callbacks.Callback):
    def on_test_end(self, logs=None):
        keys = list(logs.keys())
        print(f"tp          :", logs["tp"])
        print(f"fp          :", logs["fp"])
        print(f"tn          :", logs["tn"])
        print(f"fn          :", logs["fn"])
        print(f"binary_acc  :", logs["binary_acc"])
        print(f"precision   :", logs["precision"])
        print(f"recall      :", logs["recall"])
        print(f"f1_score    :", logs["f1_score"])
        print(f"roc_auc     :", logs["roc_auc"])
        print(f"pr_auc      :", logs["pr_auc"])
        print(f"cohen_kappa :", logs["cohen_kappa"])

class F1Score(tf.keras.metrics.Metric):

    def __init__(self, name="f1_score", **kwargs):
        super().__init__(name=name, **kwargs)
        self.f1 = self.add_weight(name="f1", initializer="zeros")
        self.precision_fn = tf.keras.metrics.Precision()
        self.recall_fn = tf.keras.metrics.Recall()

    def update_state(self, y_true, y_pred, sample_weight=None):
        p = self.precision_fn(y_true, y_pred)
        r = self.recall_fn(y_true, y_pred)
        self.f1.assign(2 * ((p * r) / (p + r + 1e-10)))

    def result(self):
        return self.f1

    def reset_state(self):
        # we also need to reset the state of the precision and recall objects
        self.precision_fn.reset_state()
        self.recall_fn.reset_state()
        self.f1.assign(0)


def save_history(name,history_df):

    history_excel_path = (
            save_path +
            name +
            '_history'
            '.xlsx'
    )

    history_df.to_excel(history_excel_path, index=False)
    print("Training history saved to:", history_excel_path)






def plot_metrics(history: tf.keras.callbacks.History,
                 metrics: list = ["loss", "cohen_kappa", "precision", "recall"],
                 ) -> None:
    plt.rcParams["figure.figsize"] = (18, 15)

    for n, metric in enumerate(metrics):
        name = metric.replace("_", " ").capitalize()
        plt.subplot(2, 2, n + 1)
        plt.plot(
            history.epoch, history.history[metric], linewidth=1.8, label="training"
        )
        plt.plot(
            history.epoch,
            history.history["val_" + metric],
            linestyle="--",
            linewidth=1.8,
            label="validation",
        )
        plt.xlabel("epoch")
        plt.ylabel(name)
        if metric == "loss":
            plt.ylim([0, plt.ylim()[1]])
        elif metric == "cohen_kappa":
            plt.ylim([-1, 1])
        else:
            plt.ylim([0, 1])

        plt.legend()



class CustomCallback(keras.callbacks.Callback):
    def on_test_end(self, logs=None):
        keys = list(logs.keys())
        print(f"tp          :", logs["tp"])
        print(f"fp          :", logs["fp"])
        print(f"tn          :", logs["tn"])
        print(f"fn          :", logs["fn"])
        print(f"binary_acc  :", logs["binary_acc"])
        print(f"precision   :", logs["precision"])
        print(f"recall      :", logs["recall"])
        print(f"f1_score    :", logs["f1_score"])
        print(f"roc_auc     :", logs["roc_auc"])
        print(f"pr_auc      :", logs["pr_auc"])
        print(f"cohen_kappa :", logs["cohen_kappa"])


def save_history(name,history_df):

    # Constructing the file name with metric values
    history_excel_path = (
            save_path +
            name +
            '_history'
            '.xlsx'
    )

    history_df.to_excel(history_excel_path, index=False)
    print("Training history saved to:", history_excel_path)




class F1Score(tf.keras.metrics.Metric):

    def __init__(self, name="f1_score", **kwargs):
        super().__init__(name=name, **kwargs)
        self.f1 = self.add_weight(name="f1", initializer="zeros")
        self.precision_fn = tf.keras.metrics.Precision()
        self.recall_fn = tf.keras.metrics.Recall()

    def update_state(self, y_true, y_pred, sample_weight=None):
        p = self.precision_fn(y_true, y_pred)
        r = self.recall_fn(y_true, y_pred)
        self.f1.assign(2 * ((p * r) / (p + r + 1e-10)))

    def result(self):
        return self.f1

    def reset_state(self):
        # we also need to reset the state of the precision and recall objects
        self.precision_fn.reset_state()
        self.recall_fn.reset_state()
        self.f1.assign(0)

def plot_metrics(history: tf.keras.callbacks.History,
                 metrics: list = ["loss", "cohen_kappa", "precision", "recall"],
                 ) -> None:
    plt.rcParams["figure.figsize"] = (18, 15)

    for n, metric in enumerate(metrics):
        name = metric.replace("_", " ").capitalize()
        plt.subplot(2, 2, n + 1)
        plt.plot(
            history.epoch, history.history[metric], linewidth=1.8, label="training"
        )
        plt.plot(
            history.epoch,
            history.history["val_" + metric],
            linestyle="--",
            linewidth=1.8,
            label="validation",
        )
        plt.xlabel("epoch")
        plt.ylabel(name)
        if metric == "loss":
            plt.ylim([0, plt.ylim()[1]])
        elif metric == "cohen_kappa":
            plt.ylim([-1, 1])
        else:
            plt.ylim([0, 1])

        plt.legend()


def my_func(model, data_generator, threshold=0.5):
    y_pred_prob = model.predict(data_generator)
    y_pred = (y_pred_prob > threshold).astype(int)
    y_true = data_generator.classes
    print("Classification Report:")
    print(classification_report(y_true, y_pred))

# %%
METRICS = [
    tf.keras.metrics.TruePositives(name="tp"),
    tf.keras.metrics.FalsePositives(name="fp"),
    tf.keras.metrics.TrueNegatives(name="tn"),
    tf.keras.metrics.FalseNegatives(name="fn"),
    tf.keras.metrics.BinaryAccuracy(name="binary_acc"),
    tf.keras.metrics.Precision(name="precision"),
    tf.keras.metrics.Recall(name="recall"),
    F1Score(name="f1_score"),
    tf.keras.metrics.AUC(name="roc_auc", curve="ROC"),
    tf.keras.metrics.AUC(name="pr_auc", curve="PR"),
    tfa.metrics.CohenKappa(name="cohen_kappa", num_classes=2),
]

# %%
files = glob.glob(os.path.join(densenet_path, "*"))
densenet_path = files[0]
densenet_model = load_model(densenet_path, custom_objects={'F1Score': F1Score})
densenet_model.trainable = False
densenet_base = densenet_model.get_layer(name="densenet201")



files = glob.glob(os.path.join(resnet_path, "*"))
resnet_path = files[0]
resnet_model = load_model(resnet_path, custom_objects={"F1Score": F1Score})
resnet_model.trainable = False
resnet_base = resnet_model.get_layer(name="resnet50")



def build_ensemble_model():
    inputs = tf.keras.Input(shape=input_shape)

    resnet_preprocess_input = preprocess_input_resnet(inputs)
    resnet_base_output = resnet_base(resnet_preprocess_input)

    densenet_preprocess_input = preprocess_input_densenet(inputs)
    densenet_base_output = densenet_base(densenet_preprocess_input)

    concat_output = tf.keras.layers.Concatenate(axis=-1)([resnet_base_output, densenet_base_output])

    x = Dense(2048, activation="relu")(concat_output)
    x = Dropout(0.8)(x)
    x = Dense(1024, activation="relu")(x)
    x = Dropout(0.6)(x)
    x = Dense(512, activation="relu")(x)
    x = Dropout(0.4)(x)
    x = Dense(64, activation="relu")(x)
    x = Dropout(0.2)(x)

    prediction = Dense(1, activation="sigmoid")(x)

    model = Model(inputs, prediction)
    model._name = "Ensemble_model"

    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
                  loss=tf.keras.losses.BinaryCrossentropy(),
                  metrics=METRICS)
    return model


new_model = build_ensemble_model()

new_model.summary()
# Out:
# Model: "Ensemble_model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  tf.math.truediv (TFOpLambda)   (None, 224, 224, 3)  0           ['input_1[0][0]']
#
#  tf.__operators__.getitem (Slic  (None, 224, 224, 3)  0          ['input_1[0][0]']
#  ingOpLambda)
#
#  tf.nn.bias_add_1 (TFOpLambda)  (None, 224, 224, 3)  0           ['tf.math.truediv[0][0]']
#
#  tf.nn.bias_add (TFOpLambda)    (None, 224, 224, 3)  0           ['tf.__operators__.getitem[0][0]'
#                                                                  ]
#
#  tf.math.truediv_1 (TFOpLambda)  (None, 224, 224, 3)  0          ['tf.nn.bias_add_1[0][0]']
#
#  resnet50 (Functional)          (None, 2048)         23587712    ['tf.nn.bias_add[0][0]']
#
#  densenet201 (Functional)       (None, 1920)         18321984    ['tf.math.truediv_1[0][0]']
#
#  concatenate (Concatenate)      (None, 3968)         0           ['resnet50[1][0]',
#                                                                   'densenet201[1][0]']
#
#  dense (Dense)                  (None, 2048)         8128512     ['concatenate[0][0]']
#
#  dropout (Dropout)              (None, 2048)         0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 1024)         2098176     ['dropout[0][0]']
#
#  dropout_1 (Dropout)            (None, 1024)         0           ['dense_1[0][0]']
#
#  dense_2 (Dense)                (None, 512)          524800      ['dropout_1[0][0]']
#
#  dropout_2 (Dropout)            (None, 512)          0           ['dense_2[0][0]']
#
#  dense_3 (Dense)                (None, 64)           32832       ['dropout_2[0][0]']
#
#  dropout_3 (Dropout)            (None, 64)           0           ['dense_3[0][0]']
#
#  dense_4 (Dense)                (None, 1)            65          ['dropout_3[0][0]']
#
# ==================================================================================================
# Total params: 52,694,081
# Trainable params: 10,784,385
# Non-trainable params: 41,909,696
# __________________________________________________________________________________________________

# %%
"""import matplotlib.pyplot as plt
from tensorflow.keras.utils import plot_model
tf.keras.utils.plot_model(new_model,
                          show_shapes=True,  # show_dtype=False,
                          show_layer_names=True,
                          layer_range=None,
                          show_layer_activations=True)"""
# Out:
# 'import matplotlib.pyplot as plt\nfrom tensorflow.keras.utils import plot_model\ntf.keras.utils.plot_model(new_model,\n                          show_shapes=True,  # show_dtype=False,\n                          show_layer_names=True,\n                          layer_range=None,\n                          show_layer_activations=True)'

# %%
early_stopping = EarlyStopping(monitor="val_cohen_kappa",
                               verbose=1,
                               patience=early_stopping_patience,
                               mode="max",
                               baseline=0.0,
                               restore_best_weights=True)
save_path = main_save_path + target_category + "/"
model_name = architecture + "_" + target_category
model_path = save_path + '_best_' + model_name + '.keras'
model_checkpoint = ModelCheckpoint(filepath=model_path,
                                       monitor="val_cohen_kappa",
                                       save_best_only=True)

# %%
import pandas as pd


old_base_path = 'C:\\Users\\HP\\Documents\\ML\\encadrement Master\\MURA-V1.1\\'

df_train = pd.read_csv(train_file)
df_train['image_path'] = df_train['image_path'].str.replace(old_base_path, mura_location)

df_valid = pd.read_csv(val_file)
df_valid['image_path'] = df_valid['image_path'].str.replace(old_base_path, mura_location)


df_test = load_data(test_file, target_category)

datagen = tf.keras.preprocessing.image.ImageDataGenerator(rotation_range=30,
                                                              horizontal_flip=True,
                                                              fill_mode="constant",
                                                              cval=0.0,
                                                              )
train_generator = datagen.flow_from_dataframe(df_train,
                                                  directory=None,
                                                  x_col='image_path',
                                                  y_col='label',
                                                  target_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
                                                  batch_size=batch_size,
                                                  class_mode=class_mode,
                                                  )

validation_generator = datagen.flow_from_dataframe(df_valid,
                                                       directory=None,
                                                       x_col='image_path',
                                                       y_col='label',
                                                       target_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
                                                       batch_size=batch_size,
                                                       class_mode=class_mode,
                                                   shuffle=False
                                                       )

test_datagen = tf.keras.preprocessing.image.ImageDataGenerator()
test_generator = test_datagen.flow_from_dataframe(df_test,
                                                      directory=None,
                                                      x_col='image_path',
                                                      y_col='label',
                                                      target_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
                                                      batch_size=batch_size,
                                                      class_mode=class_mode,
                                                  shuffle=False
                                                      )
# Out:
# C:\Users\raouf\AppData\Local\Temp\ipykernel_159384\1983201427.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'positive' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_data.at[index, 'label'] = "positive"
# Found 7800 validated image filenames belonging to 2 classes.
# Found 1952 validated image filenames belonging to 2 classes.
# Found 658 validated image filenames belonging to 2 classes.

# %%
history = new_model.fit(train_generator,
                            # teps_per_epoch=len(df_train) // batch_size,
                            validation_data=validation_generator,
                            # validation_steps=len(df_valid) // batch_size,
                            epochs=num_epochs,
                            shuffle=shuffle,
                            callbacks=[early_stopping, model_checkpoint])  # , reduce_lr_callback])
# Out:
# Epoch 1/100
# 488/488 [==============================] - 103s 182ms/step - loss: 1.0524 - tp: 1860.0000 - fp: 1321.0000 - tn: 3312.0000 - fn: 1307.0000 - binary_acc: 0.6631 - precision: 0.5847 - recall: 0.5873 - f1_score: 0.5860 - roc_auc: 0.6918 - pr_auc: 0.6399 - cohen_kappa: 0.3020 - val_loss: 0.4703 - val_tp: 465.0000 - val_fp: 10.0000 - val_tn: 1122.0000 - val_fn: 355.0000 - val_binary_acc: 0.8130 - val_precision: 0.9789 - val_recall: 0.5671 - val_f1_score: 0.7181 - val_roc_auc: 0.9246 - val_pr_auc: 0.9192 - val_cohen_kappa: 0.5926
# Epoch 2/100
# 488/488 [==============================] - 91s 187ms/step - loss: 0.5081 - tp: 2189.0000 - fp: 721.0000 - tn: 3912.0000 - fn: 978.0000 - binary_acc: 0.7822 - precision: 0.7522 - recall: 0.6912 - f1_score: 0.7204 - roc_auc: 0.8371 - pr_auc: 0.8255 - cohen_kappa: 0.5425 - val_loss: 0.3655 - val_tp: 528.0000 - val_fp: 17.0000 - val_tn: 1115.0000 - val_fn: 292.0000 - val_binary_acc: 0.8417 - val_precision: 0.9688 - val_recall: 0.6439 - val_f1_score: 0.7736 - val_roc_auc: 0.9375 - val_pr_auc: 0.9328 - val_cohen_kappa: 0.6594
# Epoch 3/100
# 488/488 [==============================] - 92s 188ms/step - loss: 0.4062 - tp: 2328.0000 - fp: 511.0000 - tn: 4122.0000 - fn: 839.0000 - binary_acc: 0.8269 - precision: 0.8200 - recall: 0.7351 - f1_score: 0.7752 - roc_auc: 0.8875 - pr_auc: 0.8779 - cohen_kappa: 0.6352 - val_loss: 0.3249 - val_tp: 581.0000 - val_fp: 23.0000 - val_tn: 1109.0000 - val_fn: 239.0000 - val_binary_acc: 0.8658 - val_precision: 0.9619 - val_recall: 0.7085 - val_f1_score: 0.8160 - val_roc_auc: 0.9496 - val_pr_auc: 0.9450 - val_cohen_kappa: 0.7141
# Epoch 4/100
# 488/488 [==============================] - 96s 197ms/step - loss: 0.3697 - tp: 2411.0000 - fp: 398.0000 - tn: 4235.0000 - fn: 756.0000 - binary_acc: 0.8521 - precision: 0.8583 - recall: 0.7613 - f1_score: 0.8069 - roc_auc: 0.9056 - pr_auc: 0.8995 - cohen_kappa: 0.6877 - val_loss: 0.3080 - val_tp: 608.0000 - val_fp: 31.0000 - val_tn: 1101.0000 - val_fn: 212.0000 - val_binary_acc: 0.8755 - val_precision: 0.9515 - val_recall: 0.7415 - val_f1_score: 0.8334 - val_roc_auc: 0.9521 - val_pr_auc: 0.9470 - val_cohen_kappa: 0.7365
# Epoch 5/100
# 488/488 [==============================] - 98s 201ms/step - loss: 0.3320 - tp: 2480.0000 - fp: 314.0000 - tn: 4319.0000 - fn: 687.0000 - binary_acc: 0.8717 - precision: 0.8876 - recall: 0.7831 - f1_score: 0.8321 - roc_auc: 0.9231 - pr_auc: 0.9155 - cohen_kappa: 0.7289 - val_loss: 0.2780 - val_tp: 643.0000 - val_fp: 34.0000 - val_tn: 1098.0000 - val_fn: 177.0000 - val_binary_acc: 0.8919 - val_precision: 0.9498 - val_recall: 0.7841 - val_f1_score: 0.8591 - val_roc_auc: 0.9557 - val_pr_auc: 0.9517 - val_cohen_kappa: 0.7727
# Epoch 6/100
# 488/488 [==============================] - 104s 213ms/step - loss: 0.3124 - tp: 2504.0000 - fp: 332.0000 - tn: 4301.0000 - fn: 663.0000 - binary_acc: 0.8724 - precision: 0.8829 - recall: 0.7907 - f1_score: 0.8342 - roc_auc: 0.9314 - pr_auc: 0.9229 - cohen_kappa: 0.7311 - val_loss: 0.2580 - val_tp: 636.0000 - val_fp: 28.0000 - val_tn: 1104.0000 - val_fn: 184.0000 - val_binary_acc: 0.8914 - val_precision: 0.9578 - val_recall: 0.7756 - val_f1_score: 0.8571 - val_roc_auc: 0.9615 - val_pr_auc: 0.9585 - val_cohen_kappa: 0.7711
# Epoch 7/100
# 488/488 [==============================] - 100s 205ms/step - loss: 0.2925 - tp: 2560.0000 - fp: 286.0000 - tn: 4347.0000 - fn: 607.0000 - binary_acc: 0.8855 - precision: 0.8995 - recall: 0.8083 - f1_score: 0.8515 - roc_auc: 0.9397 - pr_auc: 0.9345 - cohen_kappa: 0.7588 - val_loss: 0.2501 - val_tp: 644.0000 - val_fp: 34.0000 - val_tn: 1098.0000 - val_fn: 176.0000 - val_binary_acc: 0.8924 - val_precision: 0.9499 - val_recall: 0.7854 - val_f1_score: 0.8598 - val_roc_auc: 0.9641 - val_pr_auc: 0.9604 - val_cohen_kappa: 0.7738
# Epoch 8/100
# 488/488 [==============================] - 104s 213ms/step - loss: 0.2800 - tp: 2597.0000 - fp: 278.0000 - tn: 4355.0000 - fn: 570.0000 - binary_acc: 0.8913 - precision: 0.9033 - recall: 0.8200 - f1_score: 0.8596 - roc_auc: 0.9461 - pr_auc: 0.9390 - cohen_kappa: 0.7713 - val_loss: 0.2446 - val_tp: 711.0000 - val_fp: 57.0000 - val_tn: 1075.0000 - val_fn: 109.0000 - val_binary_acc: 0.9150 - val_precision: 0.9258 - val_recall: 0.8671 - val_f1_score: 0.8955 - val_roc_auc: 0.9676 - val_pr_auc: 0.9652 - val_cohen_kappa: 0.8239
# Epoch 9/100
# 488/488 [==============================] - 100s 205ms/step - loss: 0.2710 - tp: 2633.0000 - fp: 277.0000 - tn: 4356.0000 - fn: 534.0000 - binary_acc: 0.8960 - precision: 0.9048 - recall: 0.8314 - f1_score: 0.8665 - roc_auc: 0.9495 - pr_auc: 0.9418 - cohen_kappa: 0.7816 - val_loss: 0.2365 - val_tp: 648.0000 - val_fp: 22.0000 - val_tn: 1110.0000 - val_fn: 172.0000 - val_binary_acc: 0.9006 - val_precision: 0.9672 - val_recall: 0.7902 - val_f1_score: 0.8698 - val_roc_auc: 0.9673 - val_pr_auc: 0.9641 - val_cohen_kappa: 0.7907
# Epoch 10/100
# 488/488 [==============================] - 105s 215ms/step - loss: 0.2525 - tp: 2648.0000 - fp: 257.0000 - tn: 4376.0000 - fn: 519.0000 - binary_acc: 0.9005 - precision: 0.9115 - recall: 0.8361 - f1_score: 0.8722 - roc_auc: 0.9553 - pr_auc: 0.9501 - cohen_kappa: 0.7910 - val_loss: 0.2247 - val_tp: 669.0000 - val_fp: 29.0000 - val_tn: 1103.0000 - val_fn: 151.0000 - val_binary_acc: 0.9078 - val_precision: 0.9585 - val_recall: 0.8159 - val_f1_score: 0.8814 - val_roc_auc: 0.9704 - val_pr_auc: 0.9677 - val_cohen_kappa: 0.8068
# Epoch 11/100
# 488/488 [==============================] - 102s 210ms/step - loss: 0.2488 - tp: 2668.0000 - fp: 246.0000 - tn: 4387.0000 - fn: 499.0000 - binary_acc: 0.9045 - precision: 0.9156 - recall: 0.8424 - f1_score: 0.8775 - roc_auc: 0.9554 - pr_auc: 0.9511 - cohen_kappa: 0.7994 - val_loss: 0.2238 - val_tp: 703.0000 - val_fp: 48.0000 - val_tn: 1084.0000 - val_fn: 117.0000 - val_binary_acc: 0.9155 - val_precision: 0.9361 - val_recall: 0.8573 - val_f1_score: 0.8950 - val_roc_auc: 0.9692 - val_pr_auc: 0.9645 - val_cohen_kappa: 0.8245
# Epoch 12/100
# 488/488 [==============================] - 104s 213ms/step - loss: 0.2537 - tp: 2650.0000 - fp: 256.0000 - tn: 4377.0000 - fn: 517.0000 - binary_acc: 0.9009 - precision: 0.9119 - recall: 0.8368 - f1_score: 0.8727 - roc_auc: 0.9562 - pr_auc: 0.9498 - cohen_kappa: 0.7918 - val_loss: 0.2204 - val_tp: 737.0000 - val_fp: 68.0000 - val_tn: 1064.0000 - val_fn: 83.0000 - val_binary_acc: 0.9226 - val_precision: 0.9155 - val_recall: 0.8988 - val_f1_score: 0.9071 - val_roc_auc: 0.9712 - val_pr_auc: 0.9685 - val_cohen_kappa: 0.8408
# Epoch 13/100
# 488/488 [==============================] - 101s 207ms/step - loss: 0.2439 - tp: 2678.0000 - fp: 228.0000 - tn: 4405.0000 - fn: 489.0000 - binary_acc: 0.9081 - precision: 0.9215 - recall: 0.8456 - f1_score: 0.8819 - roc_auc: 0.9576 - pr_auc: 0.9537 - cohen_kappa: 0.8069 - val_loss: 0.2186 - val_tp: 671.0000 - val_fp: 29.0000 - val_tn: 1103.0000 - val_fn: 149.0000 - val_binary_acc: 0.9088 - val_precision: 0.9586 - val_recall: 0.8183 - val_f1_score: 0.8829 - val_roc_auc: 0.9719 - val_pr_auc: 0.9689 - val_cohen_kappa: 0.8090
# Epoch 14/100
# 488/488 [==============================] - 106s 218ms/step - loss: 0.2294 - tp: 2689.0000 - fp: 238.0000 - tn: 4395.0000 - fn: 478.0000 - binary_acc: 0.9082 - precision: 0.9187 - recall: 0.8491 - f1_score: 0.8825 - roc_auc: 0.9633 - pr_auc: 0.9577 - cohen_kappa: 0.8074 - val_loss: 0.2010 - val_tp: 713.0000 - val_fp: 35.0000 - val_tn: 1097.0000 - val_fn: 107.0000 - val_binary_acc: 0.9273 - val_precision: 0.9532 - val_recall: 0.8695 - val_f1_score: 0.9094 - val_roc_auc: 0.9749 - val_pr_auc: 0.9715 - val_cohen_kappa: 0.8489
# Epoch 15/100
# 488/488 [==============================] - 104s 212ms/step - loss: 0.2313 - tp: 2702.0000 - fp: 223.0000 - tn: 4410.0000 - fn: 465.0000 - binary_acc: 0.9118 - precision: 0.9238 - recall: 0.8532 - f1_score: 0.8871 - roc_auc: 0.9623 - pr_auc: 0.9577 - cohen_kappa: 0.8149 - val_loss: 0.2074 - val_tp: 730.0000 - val_fp: 58.0000 - val_tn: 1074.0000 - val_fn: 90.0000 - val_binary_acc: 0.9242 - val_precision: 0.9264 - val_recall: 0.8902 - val_f1_score: 0.9080 - val_roc_auc: 0.9727 - val_pr_auc: 0.9681 - val_cohen_kappa: 0.8435
# Epoch 16/100
# 488/488 [==============================] - 103s 211ms/step - loss: 0.2211 - tp: 2738.0000 - fp: 225.0000 - tn: 4408.0000 - fn: 429.0000 - binary_acc: 0.9162 - precision: 0.9241 - recall: 0.8645 - f1_score: 0.8933 - roc_auc: 0.9653 - pr_auc: 0.9606 - cohen_kappa: 0.8244 - val_loss: 0.2021 - val_tp: 723.0000 - val_fp: 52.0000 - val_tn: 1080.0000 - val_fn: 97.0000 - val_binary_acc: 0.9237 - val_precision: 0.9329 - val_recall: 0.8817 - val_f1_score: 0.9066 - val_roc_auc: 0.9726 - val_pr_auc: 0.9685 - val_cohen_kappa: 0.8421
# Epoch 17/100
# 488/488 [==============================] - 103s 211ms/step - loss: 0.2218 - tp: 2725.0000 - fp: 214.0000 - tn: 4419.0000 - fn: 442.0000 - binary_acc: 0.9159 - precision: 0.9272 - recall: 0.8604 - f1_score: 0.8926 - roc_auc: 0.9661 - pr_auc: 0.9605 - cohen_kappa: 0.8236 - val_loss: 0.1961 - val_tp: 733.0000 - val_fp: 45.0000 - val_tn: 1087.0000 - val_fn: 87.0000 - val_binary_acc: 0.9324 - val_precision: 0.9422 - val_recall: 0.8939 - val_f1_score: 0.9174 - val_roc_auc: 0.9760 - val_pr_auc: 0.9733 - val_cohen_kappa: 0.8602
# Epoch 18/100
# 488/488 [==============================] - 106s 217ms/step - loss: 0.2166 - tp: 2759.0000 - fp: 233.0000 - tn: 4400.0000 - fn: 408.0000 - binary_acc: 0.9178 - precision: 0.9221 - recall: 0.8712 - f1_score: 0.8959 - roc_auc: 0.9670 - pr_auc: 0.9625 - cohen_kappa: 0.8281 - val_loss: 0.1899 - val_tp: 738.0000 - val_fp: 48.0000 - val_tn: 1084.0000 - val_fn: 82.0000 - val_binary_acc: 0.9334 - val_precision: 0.9389 - val_recall: 0.9000 - val_f1_score: 0.9191 - val_roc_auc: 0.9758 - val_pr_auc: 0.9734 - val_cohen_kappa: 0.8625
# Epoch 19/100
# 488/488 [==============================] - 102s 210ms/step - loss: 0.2146 - tp: 2770.0000 - fp: 227.0000 - tn: 4406.0000 - fn: 397.0000 - binary_acc: 0.9200 - precision: 0.9243 - recall: 0.8746 - f1_score: 0.8988 - roc_auc: 0.9664 - pr_auc: 0.9627 - cohen_kappa: 0.8327 - val_loss: 0.1951 - val_tp: 715.0000 - val_fp: 34.0000 - val_tn: 1098.0000 - val_fn: 105.0000 - val_binary_acc: 0.9288 - val_precision: 0.9546 - val_recall: 0.8720 - val_f1_score: 0.9114 - val_roc_auc: 0.9769 - val_pr_auc: 0.9747 - val_cohen_kappa: 0.8521
# Epoch 20/100
# 488/488 [==============================] - 103s 211ms/step - loss: 0.2126 - tp: 2793.0000 - fp: 204.0000 - tn: 4429.0000 - fn: 374.0000 - binary_acc: 0.9259 - precision: 0.9319 - recall: 0.8819 - f1_score: 0.9062 - roc_auc: 0.9678 - pr_auc: 0.9641 - cohen_kappa: 0.8451 - val_loss: 0.1920 - val_tp: 701.0000 - val_fp: 24.0000 - val_tn: 1108.0000 - val_fn: 119.0000 - val_binary_acc: 0.9267 - val_precision: 0.9669 - val_recall: 0.8549 - val_f1_score: 0.9074 - val_roc_auc: 0.9769 - val_pr_auc: 0.9746 - val_cohen_kappa: 0.8472
# Epoch 21/100
# 488/488 [==============================] - 102s 208ms/step - loss: 0.2091 - tp: 2767.0000 - fp: 189.0000 - tn: 4444.0000 - fn: 400.0000 - binary_acc: 0.9245 - precision: 0.9361 - recall: 0.8737 - f1_score: 0.9038 - roc_auc: 0.9685 - pr_auc: 0.9645 - cohen_kappa: 0.8418 - val_loss: 0.1935 - val_tp: 733.0000 - val_fp: 53.0000 - val_tn: 1079.0000 - val_fn: 87.0000 - val_binary_acc: 0.9283 - val_precision: 0.9326 - val_recall: 0.8939 - val_f1_score: 0.9128 - val_roc_auc: 0.9759 - val_pr_auc: 0.9739 - val_cohen_kappa: 0.8520
# Epoch 22/100
# 488/488 [==============================] - 106s 218ms/step - loss: 0.2035 - tp: 2780.0000 - fp: 199.0000 - tn: 4434.0000 - fn: 387.0000 - binary_acc: 0.9249 - precision: 0.9332 - recall: 0.8778 - f1_score: 0.9047 - roc_auc: 0.9709 - pr_auc: 0.9665 - cohen_kappa: 0.8428 - val_loss: 0.1851 - val_tp: 737.0000 - val_fp: 43.0000 - val_tn: 1089.0000 - val_fn: 83.0000 - val_binary_acc: 0.9355 - val_precision: 0.9449 - val_recall: 0.8988 - val_f1_score: 0.9212 - val_roc_auc: 0.9764 - val_pr_auc: 0.9736 - val_cohen_kappa: 0.8666
# Epoch 23/100
# 488/488 [==============================] - 101s 207ms/step - loss: 0.2046 - tp: 2769.0000 - fp: 199.0000 - tn: 4434.0000 - fn: 398.0000 - binary_acc: 0.9235 - precision: 0.9330 - recall: 0.8743 - f1_score: 0.9027 - roc_auc: 0.9696 - pr_auc: 0.9655 - cohen_kappa: 0.8397 - val_loss: 0.1889 - val_tp: 719.0000 - val_fp: 44.0000 - val_tn: 1088.0000 - val_fn: 101.0000 - val_binary_acc: 0.9257 - val_precision: 0.9423 - val_recall: 0.8768 - val_f1_score: 0.9084 - val_roc_auc: 0.9769 - val_pr_auc: 0.9718 - val_cohen_kappa: 0.8461
# Epoch 24/100
# 488/488 [==============================] - 103s 211ms/step - loss: 0.1969 - tp: 2803.0000 - fp: 198.0000 - tn: 4435.0000 - fn: 364.0000 - binary_acc: 0.9279 - precision: 0.9340 - recall: 0.8851 - f1_score: 0.9089 - roc_auc: 0.9726 - pr_auc: 0.9684 - cohen_kappa: 0.8494 - val_loss: 0.1886 - val_tp: 718.0000 - val_fp: 36.0000 - val_tn: 1096.0000 - val_fn: 102.0000 - val_binary_acc: 0.9293 - val_precision: 0.9523 - val_recall: 0.8756 - val_f1_score: 0.9123 - val_roc_auc: 0.9773 - val_pr_auc: 0.9737 - val_cohen_kappa: 0.8533
# Epoch 25/100
# 488/488 [==============================] - 101s 206ms/step - loss: 0.2003 - tp: 2797.0000 - fp: 196.0000 - tn: 4437.0000 - fn: 370.0000 - binary_acc: 0.9274 - precision: 0.9345 - recall: 0.8832 - f1_score: 0.9081 - roc_auc: 0.9703 - pr_auc: 0.9671 - cohen_kappa: 0.8482 - val_loss: 0.1941 - val_tp: 741.0000 - val_fp: 62.0000 - val_tn: 1070.0000 - val_fn: 79.0000 - val_binary_acc: 0.9278 - val_precision: 0.9228 - val_recall: 0.9037 - val_f1_score: 0.9131 - val_roc_auc: 0.9768 - val_pr_auc: 0.9735 - val_cohen_kappa: 0.8513
# Epoch 26/100
# 488/488 [==============================] - 103s 211ms/step - loss: 0.1949 - tp: 2822.0000 - fp: 196.0000 - tn: 4437.0000 - fn: 345.0000 - binary_acc: 0.9306 - precision: 0.9351 - recall: 0.8911 - f1_score: 0.9125 - roc_auc: 0.9733 - pr_auc: 0.9700 - cohen_kappa: 0.8551 - val_loss: 0.1859 - val_tp: 725.0000 - val_fp: 31.0000 - val_tn: 1101.0000 - val_fn: 95.0000 - val_binary_acc: 0.9355 - val_precision: 0.9590 - val_recall: 0.8841 - val_f1_score: 0.9201 - val_roc_auc: 0.9775 - val_pr_auc: 0.9760 - val_cohen_kappa: 0.8661
# Epoch 27/100
# 488/488 [==============================] - 102s 208ms/step - loss: 0.1892 - tp: 2804.0000 - fp: 191.0000 - tn: 4442.0000 - fn: 363.0000 - binary_acc: 0.9290 - precision: 0.9362 - recall: 0.8854 - f1_score: 0.9101 - roc_auc: 0.9751 - pr_auc: 0.9711 - cohen_kappa: 0.8515 - val_loss: 0.1819 - val_tp: 746.0000 - val_fp: 49.0000 - val_tn: 1083.0000 - val_fn: 74.0000 - val_binary_acc: 0.9370 - val_precision: 0.9384 - val_recall: 0.9098 - val_f1_score: 0.9238 - val_roc_auc: 0.9766 - val_pr_auc: 0.9755 - val_cohen_kappa: 0.8701
# Epoch 28/100
# 488/488 [==============================] - 107s 219ms/step - loss: 0.1909 - tp: 2826.0000 - fp: 182.0000 - tn: 4451.0000 - fn: 341.0000 - binary_acc: 0.9329 - precision: 0.9395 - recall: 0.8923 - f1_score: 0.9153 - roc_auc: 0.9734 - pr_auc: 0.9705 - cohen_kappa: 0.8599 - val_loss: 0.1716 - val_tp: 729.0000 - val_fp: 25.0000 - val_tn: 1107.0000 - val_fn: 91.0000 - val_binary_acc: 0.9406 - val_precision: 0.9668 - val_recall: 0.8890 - val_f1_score: 0.9263 - val_roc_auc: 0.9812 - val_pr_auc: 0.9780 - val_cohen_kappa: 0.8767
# Epoch 29/100
# 488/488 [==============================] - 103s 212ms/step - loss: 0.1954 - tp: 2816.0000 - fp: 208.0000 - tn: 4425.0000 - fn: 351.0000 - binary_acc: 0.9283 - precision: 0.9312 - recall: 0.8892 - f1_score: 0.9097 - roc_auc: 0.9730 - pr_auc: 0.9686 - cohen_kappa: 0.8503 - val_loss: 0.1868 - val_tp: 731.0000 - val_fp: 38.0000 - val_tn: 1094.0000 - val_fn: 89.0000 - val_binary_acc: 0.9349 - val_precision: 0.9506 - val_recall: 0.8915 - val_f1_score: 0.9201 - val_roc_auc: 0.9771 - val_pr_auc: 0.9751 - val_cohen_kappa: 0.8653
# Epoch 30/100
# 488/488 [==============================] - 106s 218ms/step - loss: 0.1956 - tp: 2808.0000 - fp: 228.0000 - tn: 4405.0000 - fn: 359.0000 - binary_acc: 0.9247 - precision: 0.9249 - recall: 0.8866 - f1_score: 0.9054 - roc_auc: 0.9726 - pr_auc: 0.9680 - cohen_kappa: 0.8429 - val_loss: 0.1901 - val_tp: 728.0000 - val_fp: 29.0000 - val_tn: 1103.0000 - val_fn: 92.0000 - val_binary_acc: 0.9380 - val_precision: 0.9617 - val_recall: 0.8878 - val_f1_score: 0.9233 - val_roc_auc: 0.9785 - val_pr_auc: 0.9764 - val_cohen_kappa: 0.8714
# Epoch 31/100
# 488/488 [==============================] - 103s 211ms/step - loss: 0.1911 - tp: 2819.0000 - fp: 180.0000 - tn: 4453.0000 - fn: 348.0000 - binary_acc: 0.9323 - precision: 0.9400 - recall: 0.8901 - f1_score: 0.9144 - roc_auc: 0.9726 - pr_auc: 0.9698 - cohen_kappa: 0.8585 - val_loss: 0.1762 - val_tp: 760.0000 - val_fp: 53.0000 - val_tn: 1079.0000 - val_fn: 60.0000 - val_binary_acc: 0.9421 - val_precision: 0.9348 - val_recall: 0.9268 - val_f1_score: 0.9308 - val_roc_auc: 0.9812 - val_pr_auc: 0.9781 - val_cohen_kappa: 0.8810
# Epoch 32/100
# 488/488 [==============================] - 104s 212ms/step - loss: 0.1874 - tp: 2824.0000 - fp: 184.0000 - tn: 4449.0000 - fn: 343.0000 - binary_acc: 0.9324 - precision: 0.9388 - recall: 0.8917 - f1_score: 0.9147 - roc_auc: 0.9743 - pr_auc: 0.9707 - cohen_kappa: 0.8588 - val_loss: 0.1787 - val_tp: 740.0000 - val_fp: 43.0000 - val_tn: 1089.0000 - val_fn: 80.0000 - val_binary_acc: 0.9370 - val_precision: 0.9451 - val_recall: 0.9024 - val_f1_score: 0.9233 - val_roc_auc: 0.9780 - val_pr_auc: 0.9741 - val_cohen_kappa: 0.8699
# Epoch 33/100
# 488/488 [==============================] - 105s 216ms/step - loss: 0.1910 - tp: 2833.0000 - fp: 200.0000 - tn: 4433.0000 - fn: 334.0000 - binary_acc: 0.9315 - precision: 0.9341 - recall: 0.8945 - f1_score: 0.9139 - roc_auc: 0.9736 - pr_auc: 0.9703 - cohen_kappa: 0.8571 - val_loss: 0.1823 - val_tp: 716.0000 - val_fp: 25.0000 - val_tn: 1107.0000 - val_fn: 104.0000 - val_binary_acc: 0.9339 - val_precision: 0.9663 - val_recall: 0.8732 - val_f1_score: 0.9174 - val_roc_auc: 0.9776 - val_pr_auc: 0.9750 - val_cohen_kappa: 0.8625
# Epoch 34/100
# 488/488 [==============================] - 103s 211ms/step - loss: 0.1909 - tp: 2821.0000 - fp: 180.0000 - tn: 4453.0000 - fn: 346.0000 - binary_acc: 0.9326 - precision: 0.9400 - recall: 0.8907 - f1_score: 0.9147 - roc_auc: 0.9734 - pr_auc: 0.9697 - cohen_kappa: 0.8590 - val_loss: 0.1866 - val_tp: 727.0000 - val_fp: 40.0000 - val_tn: 1092.0000 - val_fn: 93.0000 - val_binary_acc: 0.9319 - val_precision: 0.9478 - val_recall: 0.8866 - val_f1_score: 0.9162 - val_roc_auc: 0.9768 - val_pr_auc: 0.9751 - val_cohen_kappa: 0.8589
# Epoch 35/100
# 488/488 [==============================] - 103s 212ms/step - loss: 0.1954 - tp: 2792.0000 - fp: 170.0000 - tn: 4463.0000 - fn: 375.0000 - binary_acc: 0.9301 - precision: 0.9426 - recall: 0.8816 - f1_score: 0.9111 - roc_auc: 0.9728 - pr_auc: 0.9693 - cohen_kappa: 0.8536 - val_loss: 0.1853 - val_tp: 717.0000 - val_fp: 36.0000 - val_tn: 1096.0000 - val_fn: 103.0000 - val_binary_acc: 0.9288 - val_precision: 0.9522 - val_recall: 0.8744 - val_f1_score: 0.9116 - val_roc_auc: 0.9783 - val_pr_auc: 0.9749 - val_cohen_kappa: 0.8522
# Epoch 36/100
# 488/488 [==============================] - 104s 213ms/step - loss: 0.1769 - tp: 2851.0000 - fp: 163.0000 - tn: 4470.0000 - fn: 316.0000 - binary_acc: 0.9386 - precision: 0.9459 - recall: 0.9002 - f1_score: 0.9225 - roc_auc: 0.9758 - pr_auc: 0.9740 - cohen_kappa: 0.8717 - val_loss: 0.1857 - val_tp: 751.0000 - val_fp: 63.0000 - val_tn: 1069.0000 - val_fn: 69.0000 - val_binary_acc: 0.9324 - val_precision: 0.9226 - val_recall: 0.9159 - val_f1_score: 0.9192 - val_roc_auc: 0.9766 - val_pr_auc: 0.9725 - val_cohen_kappa: 0.8611
# Epoch 37/100
# 488/488 [==============================] - 105s 214ms/step - loss: 0.1795 - tp: 2842.0000 - fp: 181.0000 - tn: 4452.0000 - fn: 325.0000 - binary_acc: 0.9351 - precision: 0.9401 - recall: 0.8974 - f1_score: 0.9183 - roc_auc: 0.9772 - pr_auc: 0.9735 - cohen_kappa: 0.8645 - val_loss: 0.1937 - val_tp: 704.0000 - val_fp: 32.0000 - val_tn: 1100.0000 - val_fn: 116.0000 - val_binary_acc: 0.9242 - val_precision: 0.9565 - val_recall: 0.8585 - val_f1_score: 0.9049 - val_roc_auc: 0.9777 - val_pr_auc: 0.9751 - val_cohen_kappa: 0.8422
# Epoch 38/100
# 488/488 [==============================] - 103s 212ms/step - loss: 0.1829 - tp: 2851.0000 - fp: 188.0000 - tn: 4445.0000 - fn: 316.0000 - binary_acc: 0.9354 - precision: 0.9381 - recall: 0.9002 - f1_score: 0.9188 - roc_auc: 0.9756 - pr_auc: 0.9726 - cohen_kappa: 0.8652 - val_loss: 0.1863 - val_tp: 762.0000 - val_fp: 72.0000 - val_tn: 1060.0000 - val_fn: 58.0000 - val_binary_acc: 0.9334 - val_precision: 0.9137 - val_recall: 0.9293 - val_f1_score: 0.9214 - val_roc_auc: 0.9785 - val_pr_auc: 0.9746 - val_cohen_kappa: 0.8636
# Epoch 39/100
# 488/488 [==============================] - 106s 217ms/step - loss: 0.1791 - tp: 2822.0000 - fp: 179.0000 - tn: 4454.0000 - fn: 345.0000 - binary_acc: 0.9328 - precision: 0.9404 - recall: 0.8911 - f1_score: 0.9150 - roc_auc: 0.9756 - pr_auc: 0.9728 - cohen_kappa: 0.8596 - val_loss: 0.1875 - val_tp: 737.0000 - val_fp: 47.0000 - val_tn: 1085.0000 - val_fn: 83.0000 - val_binary_acc: 0.9334 - val_precision: 0.9401 - val_recall: 0.8988 - val_f1_score: 0.9190 - val_roc_auc: 0.9755 - val_pr_auc: 0.9700 - val_cohen_kappa: 0.8625
# Epoch 40/100
# 488/488 [==============================] - 105s 215ms/step - loss: 0.1784 - tp: 2823.0000 - fp: 156.0000 - tn: 4477.0000 - fn: 344.0000 - binary_acc: 0.9359 - precision: 0.9476 - recall: 0.8914 - f1_score: 0.9186 - roc_auc: 0.9766 - pr_auc: 0.9734 - cohen_kappa: 0.8658 - val_loss: 0.1821 - val_tp: 716.0000 - val_fp: 25.0000 - val_tn: 1107.0000 - val_fn: 104.0000 - val_binary_acc: 0.9339 - val_precision: 0.9663 - val_recall: 0.8732 - val_f1_score: 0.9174 - val_roc_auc: 0.9796 - val_pr_auc: 0.9779 - val_cohen_kappa: 0.8625
# Epoch 41/100
# 488/488 [==============================] - 108s 222ms/step - loss: 0.1814 - tp: 2830.0000 - fp: 175.0000 - tn: 4458.0000 - fn: 337.0000 - binary_acc: 0.9344 - precision: 0.9418 - recall: 0.8936 - f1_score: 0.9170 - roc_auc: 0.9762 - pr_auc: 0.9717 - cohen_kappa: 0.8628 - val_loss: 0.1724 - val_tp: 713.0000 - val_fp: 24.0000 - val_tn: 1108.0000 - val_fn: 107.0000 - val_binary_acc: 0.9329 - val_precision: 0.9674 - val_recall: 0.8695 - val_f1_score: 0.9159 - val_roc_auc: 0.9809 - val_pr_auc: 0.9774 - val_cohen_kappa: 0.8603
# Epoch 42/100
# 488/488 [==============================] - 107s 219ms/step - loss: 0.1804 - tp: 2851.0000 - fp: 176.0000 - tn: 4457.0000 - fn: 316.0000 - binary_acc: 0.9369 - precision: 0.9419 - recall: 0.9002 - f1_score: 0.9206 - roc_auc: 0.9759 - pr_auc: 0.9729 - cohen_kappa: 0.8683 - val_loss: 0.1812 - val_tp: 746.0000 - val_fp: 65.0000 - val_tn: 1067.0000 - val_fn: 74.0000 - val_binary_acc: 0.9288 - val_precision: 0.9199 - val_recall: 0.9098 - val_f1_score: 0.9148 - val_roc_auc: 0.9783 - val_pr_auc: 0.9756 - val_cohen_kappa: 0.8536
# Epoch 43/100
# 488/488 [==============================] - 105s 216ms/step - loss: 0.1783 - tp: 2836.0000 - fp: 171.0000 - tn: 4462.0000 - fn: 331.0000 - binary_acc: 0.9356 - precision: 0.9431 - recall: 0.8955 - f1_score: 0.9187 - roc_auc: 0.9766 - pr_auc: 0.9738 - cohen_kappa: 0.8655 - val_loss: 0.1706 - val_tp: 726.0000 - val_fp: 30.0000 - val_tn: 1102.0000 - val_fn: 94.0000 - val_binary_acc: 0.9365 - val_precision: 0.9603 - val_recall: 0.8854 - val_f1_score: 0.9213 - val_roc_auc: 0.9800 - val_pr_auc: 0.9772 - val_cohen_kappa: 0.8682
# Epoch 44/100
# 488/488 [==============================] - 107s 218ms/step - loss: 0.1835 - tp: 2838.0000 - fp: 193.0000 - tn: 4440.0000 - fn: 329.0000 - binary_acc: 0.9331 - precision: 0.9363 - recall: 0.8961 - f1_score: 0.9158 - roc_auc: 0.9757 - pr_auc: 0.9720 - cohen_kappa: 0.8603 - val_loss: 0.1681 - val_tp: 735.0000 - val_fp: 33.0000 - val_tn: 1099.0000 - val_fn: 85.0000 - val_binary_acc: 0.9395 - val_precision: 0.9570 - val_recall: 0.8963 - val_f1_score: 0.9257 - val_roc_auc: 0.9810 - val_pr_auc: 0.9773 - val_cohen_kappa: 0.8748
# Epoch 45/100
# 488/488 [==============================] - 110s 226ms/step - loss: 0.1724 - tp: 2850.0000 - fp: 187.0000 - tn: 4446.0000 - fn: 317.0000 - binary_acc: 0.9354 - precision: 0.9384 - recall: 0.8999 - f1_score: 0.9188 - roc_auc: 0.9780 - pr_auc: 0.9750 - cohen_kappa: 0.8652 - val_loss: 0.1795 - val_tp: 708.0000 - val_fp: 19.0000 - val_tn: 1113.0000 - val_fn: 112.0000 - val_binary_acc: 0.9329 - val_precision: 0.9739 - val_recall: 0.8634 - val_f1_score: 0.9153 - val_roc_auc: 0.9804 - val_pr_auc: 0.9774 - val_cohen_kappa: 0.8601
# Epoch 46/100
# 488/488 [==============================] - ETA: 0s - loss: 0.1707 - tp: 2858.0000 - fp: 173.0000 - tn: 4460.0000 - fn: 309.0000 - binary_acc: 0.9382 - precision: 0.9429 - recall: 0.9024 - f1_score: 0.9222 - roc_auc: 0.9782 - pr_auc: 0.9750 - cohen_kappa: 0.8710Restoring model weights from the end of the best epoch: 31.
# 488/488 [==============================] - 105s 216ms/step - loss: 0.1707 - tp: 2858.0000 - fp: 173.0000 - tn: 4460.0000 - fn: 309.0000 - binary_acc: 0.9382 - precision: 0.9429 - recall: 0.9024 - f1_score: 0.9222 - roc_auc: 0.9782 - pr_auc: 0.9750 - cohen_kappa: 0.8710 - val_loss: 0.1866 - val_tp: 720.0000 - val_fp: 30.0000 - val_tn: 1102.0000 - val_fn: 100.0000 - val_binary_acc: 0.9334 - val_precision: 0.9600 - val_recall: 0.8780 - val_f1_score: 0.9172 - val_roc_auc: 0.9775 - val_pr_auc: 0.9727 - val_cohen_kappa: 0.8617
# Epoch 46: early stopping

# %%
new_model.save(save_path + model_name + '.keras')

plot_metrics(history)

# %%
"""new_model.evaluate(validation_generator)"""
new_model.evaluate(test_generator)

    # Make predictions using the validation generator
"""y_valid_pred_prob = new_model.predict(validation_generator)
y_valid_pred = (y_valid_pred_prob > 0.5).astype(int)
y_valid = validation_generator.classes
print("Classification Report:")
print(classification_report(y_valid, y_valid_pred))"""

y_pred_prob = new_model.predict(test_generator)
y_pred = (y_pred_prob > 0.5).astype(int)
y_test = test_generator.classes
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# 42/42 [==============================] - 5s 123ms/step - loss: 0.4457 - tp: 219.0000 - fp: 27.0000 - tn: 337.0000 - fn: 75.0000 - binary_acc: 0.8450 - precision: 0.8902 - recall: 0.7449 - f1_score: 0.8111 - roc_auc: 0.8981 - pr_auc: 0.8911 - cohen_kappa: 0.6814
# 42/42 [==============================] - 9s 113ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.82      0.93      0.87       364
#            1       0.89      0.74      0.81       294
#
#     accuracy                           0.84       658
#    macro avg       0.85      0.84      0.84       658
# weighted avg       0.85      0.84      0.84       658

# %%
conf_matrix = confusion_matrix(y_test, y_pred)

# Create ConfusionMatrixDisplay object
cm_display = ConfusionMatrixDisplay(confusion_matrix=conf_matrix)

# Plot the confusion matrix
plt.figure(figsize=(4, 6))  # Adjust the figure size as needed
cm_display.plot(cmap=plt.cm.Blues)  # You can choose any colormap you prefer
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.grid(False)  # Turn off grid
plt.savefig(save_path + model_name + "_confusion_matrix.jpg")
plt.show()

# %%
history_df = pd.DataFrame(history.history)
save_history(model_name, history_df)

new_model.save(save_path + model_name + "_pt_imagenet-{new_model.count_params()}.h5")
new_model.save(save_path + model_name + ".h5")
# Out:
# Training history saved to: C:/Users/raouf/Desktop/pfe/history/final/dense_res/XR_WRIST/DenseRes_XR_WRIST_history.xlsx
