# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
import tensorflow as tf
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras import layers, models
from keras.layers import concatenate, Dense, Conv2D, MaxPooling2D, Flatten, Activation, BatchNormalization, Dropout, \
    Attention, PReLU
from keras import *
from keras.applications import MobileNet
from keras.applications import VGG16
from keras.applications.resnet import ResNet50
from keras import backend as K
from keras.layers import Layer
import keras.layers as kl
import pandas as pd
from keras.applications import EfficientNetB0
import keras.applications
import numpy as np
import os
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from sklearn.metrics import cohen_kappa_score
import seaborn as sns
import pickle
import tensorflow_addons as tfa
from sklearn import metrics
from tensorflow.keras.applications.resnet import preprocess_input as preprocess_input_resnet
from tensorflow.keras.applications.densenet import preprocess_input as preprocess_input_densenet
from tensorflow.keras.models import load_model
import os
import glob
# Out:
# c:\Users\raouf\miniconda3\envs\tensorflowgpu\lib\site-packages\tensorflow_addons\utils\tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# c:\Users\raouf\miniconda3\envs\tensorflowgpu\lib\site-packages\tensorflow_addons\utils\ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.12.0 and strictly below 2.15.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.10.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %%
main_save_path = "C:/Users/raouf/Desktop/pfe/history/final/dense_res/"
mura_location = "C:/Users/raouf/Desktop/pfe/"
data_path = 'C:/Users/raouf/Desktop/pfe/MURA-v1.1/'
train_path = 'C:/Users/raouf/Desktop/pfe/MURA-v1.1/train'
test_path = 'C:/Users/raouf/Desktop/pfe/MURA-v1.1/valid'



train_file = "C:/Users/raouf/Desktop/pfe/datasets/shoulder_df_train.csv"
val_file = "C:/Users/raouf/Desktop/pfe/datasets/shoulder_df_valid.csv"

test_file = "C:/Users/raouf/Desktop/pfe/MURA-v1.1/valid_image_paths.csv"

target_category = "XR_SHOULDER"

architecture = 'DenseRes'

densenet_path = "C:/Users/raouf/Desktop/pfe/history/all_prof_mura/densenet/" + target_category + "/best/"
resnet_path = "C:/Users/raouf/Desktop/pfe/history/all_prof_mura/resnet/" + target_category + "/best/"



batch_size = 16
num_epochs = 100
fine_tuning_epochs=1
validation_split = 0.2
loss_function = tf.keras.losses.BinaryCrossentropy()
learning_rate = 0.0001
input_shape = (224, 224, 3)


include_top = False
# metrics=["accuracy"] #, tf.keras.metrics.Precision(), tf.keras.metrics.Recall()
early_stopping_patience = 15
shuffle = True
class_mode = 'binary'  # 'categorical'
IMAGE_WIDTH = 224
IMAGE_HEIGHT = 224
trainable = False
training = False
dropout = 0.2

# %%
def load_data(file, part):
    train_data = pd.read_csv(file)
    train_data = train_data.rename(columns={train_data.columns[0]: 'image_path'})
    train_data['label'] = 2
    string_to_add = mura_location
    train_data['image_path'] = string_to_add + train_data['image_path'].astype(str)
    for index, row in train_data.iterrows():
        if 'positive' in str(row['image_path']).lower():
            train_data.at[index, 'label'] = "positive"
        else:
            train_data.at[index, 'label'] = "negative"

    if part == 0:
        pass
    else:
        train_data = train_data[train_data['image_path'].str.contains(part)]
    return train_data


class CustomCallback(keras.callbacks.Callback):
    def on_test_end(self, logs=None):
        keys = list(logs.keys())
        print(f"tp          :", logs["tp"])
        print(f"fp          :", logs["fp"])
        print(f"tn          :", logs["tn"])
        print(f"fn          :", logs["fn"])
        print(f"binary_acc  :", logs["binary_acc"])
        print(f"precision   :", logs["precision"])
        print(f"recall      :", logs["recall"])
        print(f"f1_score    :", logs["f1_score"])
        print(f"roc_auc     :", logs["roc_auc"])
        print(f"pr_auc      :", logs["pr_auc"])
        print(f"cohen_kappa :", logs["cohen_kappa"])

class F1Score(tf.keras.metrics.Metric):

    def __init__(self, name="f1_score", **kwargs):
        super().__init__(name=name, **kwargs)
        self.f1 = self.add_weight(name="f1", initializer="zeros")
        self.precision_fn = tf.keras.metrics.Precision()
        self.recall_fn = tf.keras.metrics.Recall()

    def update_state(self, y_true, y_pred, sample_weight=None):
        p = self.precision_fn(y_true, y_pred)
        r = self.recall_fn(y_true, y_pred)
        self.f1.assign(2 * ((p * r) / (p + r + 1e-10)))

    def result(self):
        return self.f1

    def reset_state(self):
        # we also need to reset the state of the precision and recall objects
        self.precision_fn.reset_state()
        self.recall_fn.reset_state()
        self.f1.assign(0)


def save_history(name,history_df):

    history_excel_path = (
            save_path +
            name +
            '_history'
            '.xlsx'
    )

    history_df.to_excel(history_excel_path, index=False)
    print("Training history saved to:", history_excel_path)






def plot_metrics(history: tf.keras.callbacks.History,
                 metrics: list = ["loss", "cohen_kappa", "precision", "recall"],
                 ) -> None:
    plt.rcParams["figure.figsize"] = (18, 15)

    for n, metric in enumerate(metrics):
        name = metric.replace("_", " ").capitalize()
        plt.subplot(2, 2, n + 1)
        plt.plot(
            history.epoch, history.history[metric], linewidth=1.8, label="training"
        )
        plt.plot(
            history.epoch,
            history.history["val_" + metric],
            linestyle="--",
            linewidth=1.8,
            label="validation",
        )
        plt.xlabel("epoch")
        plt.ylabel(name)
        if metric == "loss":
            plt.ylim([0, plt.ylim()[1]])
        elif metric == "cohen_kappa":
            plt.ylim([-1, 1])
        else:
            plt.ylim([0, 1])

        plt.legend()



class CustomCallback(keras.callbacks.Callback):
    def on_test_end(self, logs=None):
        keys = list(logs.keys())
        print(f"tp          :", logs["tp"])
        print(f"fp          :", logs["fp"])
        print(f"tn          :", logs["tn"])
        print(f"fn          :", logs["fn"])
        print(f"binary_acc  :", logs["binary_acc"])
        print(f"precision   :", logs["precision"])
        print(f"recall      :", logs["recall"])
        print(f"f1_score    :", logs["f1_score"])
        print(f"roc_auc     :", logs["roc_auc"])
        print(f"pr_auc      :", logs["pr_auc"])
        print(f"cohen_kappa :", logs["cohen_kappa"])


def save_history(name,history_df):

    # Constructing the file name with metric values
    history_excel_path = (
            save_path +
            name +
            '_history'
            '.xlsx'
    )

    history_df.to_excel(history_excel_path, index=False)
    print("Training history saved to:", history_excel_path)




class F1Score(tf.keras.metrics.Metric):

    def __init__(self, name="f1_score", **kwargs):
        super().__init__(name=name, **kwargs)
        self.f1 = self.add_weight(name="f1", initializer="zeros")
        self.precision_fn = tf.keras.metrics.Precision()
        self.recall_fn = tf.keras.metrics.Recall()

    def update_state(self, y_true, y_pred, sample_weight=None):
        p = self.precision_fn(y_true, y_pred)
        r = self.recall_fn(y_true, y_pred)
        self.f1.assign(2 * ((p * r) / (p + r + 1e-10)))

    def result(self):
        return self.f1

    def reset_state(self):
        # we also need to reset the state of the precision and recall objects
        self.precision_fn.reset_state()
        self.recall_fn.reset_state()
        self.f1.assign(0)

def plot_metrics(history: tf.keras.callbacks.History,
                 metrics: list = ["loss", "cohen_kappa", "precision", "recall"],
                 ) -> None:
    plt.rcParams["figure.figsize"] = (18, 15)

    for n, metric in enumerate(metrics):
        name = metric.replace("_", " ").capitalize()
        plt.subplot(2, 2, n + 1)
        plt.plot(
            history.epoch, history.history[metric], linewidth=1.8, label="training"
        )
        plt.plot(
            history.epoch,
            history.history["val_" + metric],
            linestyle="--",
            linewidth=1.8,
            label="validation",
        )
        plt.xlabel("epoch")
        plt.ylabel(name)
        if metric == "loss":
            plt.ylim([0, plt.ylim()[1]])
        elif metric == "cohen_kappa":
            plt.ylim([-1, 1])
        else:
            plt.ylim([0, 1])

        plt.legend()


def my_func(model, data_generator, threshold=0.5):
    y_pred_prob = model.predict(data_generator)
    y_pred = (y_pred_prob > threshold).astype(int)
    y_true = data_generator.classes
    print("Classification Report:")
    print(classification_report(y_true, y_pred))

# %%
METRICS = [
    tf.keras.metrics.TruePositives(name="tp"),
    tf.keras.metrics.FalsePositives(name="fp"),
    tf.keras.metrics.TrueNegatives(name="tn"),
    tf.keras.metrics.FalseNegatives(name="fn"),
    tf.keras.metrics.BinaryAccuracy(name="binary_acc"),
    tf.keras.metrics.Precision(name="precision"),
    tf.keras.metrics.Recall(name="recall"),
    F1Score(name="f1_score"),
    tf.keras.metrics.AUC(name="roc_auc", curve="ROC"),
    tf.keras.metrics.AUC(name="pr_auc", curve="PR"),
    tfa.metrics.CohenKappa(name="cohen_kappa", num_classes=2),
]

# %%
files = glob.glob(os.path.join(densenet_path, "*"))
densenet_path = files[0]
densenet_model = load_model(densenet_path, custom_objects={'F1Score': F1Score})
densenet_model.trainable = False
densenet_base = densenet_model.get_layer(name="densenet201")



files = glob.glob(os.path.join(resnet_path, "*"))
resnet_path = files[0]
resnet_model = load_model(resnet_path, custom_objects={"F1Score": F1Score})
resnet_model.trainable = False
resnet_base = resnet_model.get_layer(name="resnet50")



def build_ensemble_model():
    inputs = tf.keras.Input(shape=input_shape)

    resnet_preprocess_input = preprocess_input_resnet(inputs)
    resnet_base_output = resnet_base(resnet_preprocess_input)

    densenet_preprocess_input = preprocess_input_densenet(inputs)
    densenet_base_output = densenet_base(densenet_preprocess_input)

    concat_output = tf.keras.layers.Concatenate(axis=-1)([resnet_base_output, densenet_base_output])

    x = Dense(2048, activation="relu")(concat_output)
    x = Dropout(0.8)(x)
    x = Dense(1024, activation="relu")(x)
    x = Dropout(0.6)(x)
    x = Dense(512, activation="relu")(x)
    x = Dropout(0.4)(x)
    x = Dense(64, activation="relu")(x)
    x = Dropout(0.2)(x)

    prediction = Dense(1, activation="sigmoid")(x)

    model = Model(inputs, prediction)
    model._name = "Ensemble_model"

    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
                  loss=tf.keras.losses.BinaryCrossentropy(),
                  metrics=METRICS)
    return model


new_model = build_ensemble_model()

new_model.summary()
# Out:
# Model: "Ensemble_model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  tf.math.truediv (TFOpLambda)   (None, 224, 224, 3)  0           ['input_1[0][0]']
#
#  tf.__operators__.getitem (Slic  (None, 224, 224, 3)  0          ['input_1[0][0]']
#  ingOpLambda)
#
#  tf.nn.bias_add_1 (TFOpLambda)  (None, 224, 224, 3)  0           ['tf.math.truediv[0][0]']
#
#  tf.nn.bias_add (TFOpLambda)    (None, 224, 224, 3)  0           ['tf.__operators__.getitem[0][0]'
#                                                                  ]
#
#  tf.math.truediv_1 (TFOpLambda)  (None, 224, 224, 3)  0          ['tf.nn.bias_add_1[0][0]']
#
#  resnet50 (Functional)          (None, 2048)         23587712    ['tf.nn.bias_add[0][0]']
#
#  densenet201 (Functional)       (None, 1920)         18321984    ['tf.math.truediv_1[0][0]']
#
#  concatenate (Concatenate)      (None, 3968)         0           ['resnet50[1][0]',
#                                                                   'densenet201[1][0]']
#
#  dense (Dense)                  (None, 2048)         8128512     ['concatenate[0][0]']
#
#  dropout (Dropout)              (None, 2048)         0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 1024)         2098176     ['dropout[0][0]']
#
#  dropout_1 (Dropout)            (None, 1024)         0           ['dense_1[0][0]']
#
#  dense_2 (Dense)                (None, 512)          524800      ['dropout_1[0][0]']
#
#  dropout_2 (Dropout)            (None, 512)          0           ['dense_2[0][0]']
#
#  dense_3 (Dense)                (None, 64)           32832       ['dropout_2[0][0]']
#
#  dropout_3 (Dropout)            (None, 64)           0           ['dense_3[0][0]']
#
#  dense_4 (Dense)                (None, 1)            65          ['dropout_3[0][0]']
#
# ==================================================================================================
# Total params: 52,694,081
# Trainable params: 10,784,385
# Non-trainable params: 41,909,696
# __________________________________________________________________________________________________

# %%
"""import matplotlib.pyplot as plt
from tensorflow.keras.utils import plot_model
tf.keras.utils.plot_model(new_model,
                          show_shapes=True,  # show_dtype=False,
                          show_layer_names=True,
                          layer_range=None,
                          show_layer_activations=True)"""
# Out:
# 'import matplotlib.pyplot as plt\nfrom tensorflow.keras.utils import plot_model\ntf.keras.utils.plot_model(new_model,\n                          show_shapes=True,  # show_dtype=False,\n                          show_layer_names=True,\n                          layer_range=None,\n                          show_layer_activations=True)'

# %%
early_stopping = EarlyStopping(monitor="val_cohen_kappa",
                               verbose=1,
                               patience=early_stopping_patience,
                               mode="max",
                               baseline=0.0,
                               restore_best_weights=True)
save_path = main_save_path + target_category + "/"
model_name = architecture + "_" + target_category
model_path = save_path + '_best_' + model_name + '.keras'
model_checkpoint = ModelCheckpoint(filepath=model_path,
                                       monitor="val_cohen_kappa",
                                       save_best_only=True)

# %%
import pandas as pd


old_base_path = 'C:\\Users\\HP\\Documents\\ML\\encadrement Master\\MURA-V1.1\\'

df_train = pd.read_csv(train_file)
df_train['image_path'] = df_train['image_path'].str.replace(old_base_path, mura_location)

df_valid = pd.read_csv(val_file)
df_valid['image_path'] = df_valid['image_path'].str.replace(old_base_path, mura_location)


df_test = load_data(test_file, target_category)

datagen = tf.keras.preprocessing.image.ImageDataGenerator(rotation_range=30,
                                                              horizontal_flip=True,
                                                              fill_mode="constant",
                                                              cval=0.0,
                                                              )
train_generator = datagen.flow_from_dataframe(df_train,
                                                  directory=None,
                                                  x_col='image_path',
                                                  y_col='label',
                                                  target_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
                                                  batch_size=batch_size,
                                                  class_mode=class_mode,
                                                  )

validation_generator = datagen.flow_from_dataframe(df_valid,
                                                       directory=None,
                                                       x_col='image_path',
                                                       y_col='label',
                                                       target_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
                                                       batch_size=batch_size,
                                                       class_mode=class_mode,
                                                   shuffle=False
                                                       )

test_datagen = tf.keras.preprocessing.image.ImageDataGenerator()
test_generator = test_datagen.flow_from_dataframe(df_test,
                                                      directory=None,
                                                      x_col='image_path',
                                                      y_col='label',
                                                      target_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
                                                      batch_size=batch_size,
                                                      class_mode=class_mode,
                                                  shuffle=False
                                                      )
# Out:
# C:\Users\raouf\AppData\Local\Temp\ipykernel_179924\1983201427.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'positive' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_data.at[index, 'label'] = "positive"
# Found 6703 validated image filenames belonging to 2 classes.
# Found 1676 validated image filenames belonging to 2 classes.
# Found 563 validated image filenames belonging to 2 classes.

# %%
history = new_model.fit(train_generator,
                            # teps_per_epoch=len(df_train) // batch_size,
                            validation_data=validation_generator,
                            # validation_steps=len(df_valid) // batch_size,
                            epochs=num_epochs,
                            shuffle=shuffle,
                            callbacks=[early_stopping, model_checkpoint])  # , reduce_lr_callback])
# Out:
# Epoch 1/100
# 419/419 [==============================] - 92s 185ms/step - loss: 1.4455 - tp: 1981.0000 - fp: 1574.0000 - tn: 1789.0000 - fn: 1359.0000 - binary_acc: 0.5624 - precision: 0.5572 - recall: 0.5931 - f1_score: 0.5746 - roc_auc: 0.5883 - pr_auc: 0.5842 - cohen_kappa: 0.1251 - val_loss: 0.6843 - val_tp: 374.0000 - val_fp: 212.0000 - val_tn: 636.0000 - val_fn: 454.0000 - val_binary_acc: 0.6026 - val_precision: 0.6382 - val_recall: 0.4517 - val_f1_score: 0.5290 - val_roc_auc: 0.6470 - val_pr_auc: 0.6751 - val_cohen_kappa: 0.2024
# Epoch 2/100
# 419/419 [==============================] - 76s 180ms/step - loss: 0.7673 - tp: 2089.0000 - fp: 1432.0000 - tn: 1931.0000 - fn: 1251.0000 - binary_acc: 0.5997 - precision: 0.5933 - recall: 0.6254 - f1_score: 0.6089 - roc_auc: 0.6431 - pr_auc: 0.6550 - cohen_kappa: 0.1996 - val_loss: 0.6539 - val_tp: 514.0000 - val_fp: 130.0000 - val_tn: 718.0000 - val_fn: 314.0000 - val_binary_acc: 0.7351 - val_precision: 0.7981 - val_recall: 0.6208 - val_f1_score: 0.6984 - val_roc_auc: 0.8179 - val_pr_auc: 0.8318 - val_cohen_kappa: 0.4687
# Epoch 3/100
# 419/419 [==============================] - 78s 185ms/step - loss: 0.6403 - tp: 2168.0000 - fp: 1161.0000 - tn: 2202.0000 - fn: 1172.0000 - binary_acc: 0.6519 - precision: 0.6512 - recall: 0.6491 - f1_score: 0.6502 - roc_auc: 0.7105 - pr_auc: 0.7227 - cohen_kappa: 0.3039 - val_loss: 0.5524 - val_tp: 589.0000 - val_fp: 142.0000 - val_tn: 706.0000 - val_fn: 239.0000 - val_binary_acc: 0.7727 - val_precision: 0.8057 - val_recall: 0.7114 - val_f1_score: 0.7556 - val_roc_auc: 0.8521 - val_pr_auc: 0.8560 - val_cohen_kappa: 0.5447
# Epoch 4/100
# 419/419 [==============================] - 82s 195ms/step - loss: 0.5779 - tp: 2271.0000 - fp: 918.0000 - tn: 2445.0000 - fn: 1069.0000 - binary_acc: 0.7036 - precision: 0.7121 - recall: 0.6799 - f1_score: 0.6957 - roc_auc: 0.7746 - pr_auc: 0.7850 - cohen_kappa: 0.4070 - val_loss: 0.4749 - val_tp: 579.0000 - val_fp: 91.0000 - val_tn: 757.0000 - val_fn: 249.0000 - val_binary_acc: 0.7971 - val_precision: 0.8642 - val_recall: 0.6993 - val_f1_score: 0.7730 - val_roc_auc: 0.8755 - val_pr_auc: 0.8775 - val_cohen_kappa: 0.5933
# Epoch 5/100
# 419/419 [==============================] - 83s 197ms/step - loss: 0.5214 - tp: 2432.0000 - fp: 772.0000 - tn: 2591.0000 - fn: 908.0000 - binary_acc: 0.7494 - precision: 0.7591 - recall: 0.7281 - f1_score: 0.7433 - roc_auc: 0.8231 - pr_auc: 0.8340 - cohen_kappa: 0.4987 - val_loss: 0.4640 - val_tp: 658.0000 - val_fp: 124.0000 - val_tn: 724.0000 - val_fn: 170.0000 - val_binary_acc: 0.8246 - val_precision: 0.8414 - val_recall: 0.7947 - val_f1_score: 0.8174 - val_roc_auc: 0.8912 - val_pr_auc: 0.8930 - val_cohen_kappa: 0.6489
# Epoch 6/100
# 419/419 [==============================] - 86s 205ms/step - loss: 0.4882 - tp: 2522.0000 - fp: 669.0000 - tn: 2694.0000 - fn: 818.0000 - binary_acc: 0.7782 - precision: 0.7903 - recall: 0.7551 - f1_score: 0.7723 - roc_auc: 0.8483 - pr_auc: 0.8582 - cohen_kappa: 0.5562 - val_loss: 0.4281 - val_tp: 626.0000 - val_fp: 90.0000 - val_tn: 758.0000 - val_fn: 202.0000 - val_binary_acc: 0.8258 - val_precision: 0.8743 - val_recall: 0.7560 - val_f1_score: 0.8109 - val_roc_auc: 0.9003 - val_pr_auc: 0.9042 - val_cohen_kappa: 0.6509
# Epoch 7/100
# 419/419 [==============================] - 85s 203ms/step - loss: 0.4565 - tp: 2593.0000 - fp: 604.0000 - tn: 2759.0000 - fn: 747.0000 - binary_acc: 0.7984 - precision: 0.8111 - recall: 0.7763 - f1_score: 0.7933 - roc_auc: 0.8693 - pr_auc: 0.8773 - cohen_kappa: 0.5968 - val_loss: 0.3987 - val_tp: 631.0000 - val_fp: 89.0000 - val_tn: 759.0000 - val_fn: 197.0000 - val_binary_acc: 0.8294 - val_precision: 0.8764 - val_recall: 0.7621 - val_f1_score: 0.8152 - val_roc_auc: 0.9079 - val_pr_auc: 0.9121 - val_cohen_kappa: 0.6581
# Epoch 8/100
# 419/419 [==============================] - 87s 208ms/step - loss: 0.4354 - tp: 2604.0000 - fp: 520.0000 - tn: 2843.0000 - fn: 736.0000 - binary_acc: 0.8126 - precision: 0.8335 - recall: 0.7796 - f1_score: 0.8057 - roc_auc: 0.8816 - pr_auc: 0.8925 - cohen_kappa: 0.6252 - val_loss: 0.3845 - val_tp: 664.0000 - val_fp: 112.0000 - val_tn: 736.0000 - val_fn: 164.0000 - val_binary_acc: 0.8353 - val_precision: 0.8557 - val_recall: 0.8019 - val_f1_score: 0.8279 - val_roc_auc: 0.9135 - val_pr_auc: 0.9170 - val_cohen_kappa: 0.6704
# Epoch 9/100
# 419/419 [==============================] - 87s 208ms/step - loss: 0.4030 - tp: 2672.0000 - fp: 511.0000 - tn: 2852.0000 - fn: 668.0000 - binary_acc: 0.8241 - precision: 0.8395 - recall: 0.8000 - f1_score: 0.8193 - roc_auc: 0.8953 - pr_auc: 0.9087 - cohen_kappa: 0.6482 - val_loss: 0.3761 - val_tp: 660.0000 - val_fp: 99.0000 - val_tn: 749.0000 - val_fn: 168.0000 - val_binary_acc: 0.8407 - val_precision: 0.8696 - val_recall: 0.7971 - val_f1_score: 0.8318 - val_roc_auc: 0.9147 - val_pr_auc: 0.9165 - val_cohen_kappa: 0.6810
# Epoch 10/100
# 419/419 [==============================] - 89s 212ms/step - loss: 0.3925 - tp: 2665.0000 - fp: 468.0000 - tn: 2895.0000 - fn: 675.0000 - binary_acc: 0.8295 - precision: 0.8506 - recall: 0.7979 - f1_score: 0.8234 - roc_auc: 0.9025 - pr_auc: 0.9159 - cohen_kappa: 0.6589 - val_loss: 0.3837 - val_tp: 701.0000 - val_fp: 141.0000 - val_tn: 707.0000 - val_fn: 127.0000 - val_binary_acc: 0.8401 - val_precision: 0.8325 - val_recall: 0.8466 - val_f1_score: 0.8395 - val_roc_auc: 0.9150 - val_pr_auc: 0.9184 - val_cohen_kappa: 0.6802
# Epoch 11/100
# 419/419 [==============================] - 87s 207ms/step - loss: 0.3887 - tp: 2679.0000 - fp: 429.0000 - tn: 2934.0000 - fn: 661.0000 - binary_acc: 0.8374 - precision: 0.8620 - recall: 0.8021 - f1_score: 0.8310 - roc_auc: 0.9041 - pr_auc: 0.9167 - cohen_kappa: 0.6747 - val_loss: 0.3777 - val_tp: 668.0000 - val_fp: 95.0000 - val_tn: 753.0000 - val_fn: 160.0000 - val_binary_acc: 0.8479 - val_precision: 0.8755 - val_recall: 0.8068 - val_f1_score: 0.8397 - val_roc_auc: 0.9150 - val_pr_auc: 0.9181 - val_cohen_kappa: 0.6954
# Epoch 12/100
# 419/419 [==============================] - 89s 212ms/step - loss: 0.3731 - tp: 2690.0000 - fp: 395.0000 - tn: 2968.0000 - fn: 650.0000 - binary_acc: 0.8441 - precision: 0.8720 - recall: 0.8054 - f1_score: 0.8374 - roc_auc: 0.9117 - pr_auc: 0.9238 - cohen_kappa: 0.6881 - val_loss: 0.3726 - val_tp: 703.0000 - val_fp: 133.0000 - val_tn: 715.0000 - val_fn: 125.0000 - val_binary_acc: 0.8461 - val_precision: 0.8409 - val_recall: 0.8490 - val_f1_score: 0.8450 - val_roc_auc: 0.9193 - val_pr_auc: 0.9237 - val_cohen_kappa: 0.6921
# Epoch 13/100
# 419/419 [==============================] - 87s 208ms/step - loss: 0.3636 - tp: 2735.0000 - fp: 429.0000 - tn: 2934.0000 - fn: 605.0000 - binary_acc: 0.8457 - precision: 0.8644 - recall: 0.8189 - f1_score: 0.8410 - roc_auc: 0.9162 - pr_auc: 0.9280 - cohen_kappa: 0.6914 - val_loss: 0.3554 - val_tp: 657.0000 - val_fp: 84.0000 - val_tn: 764.0000 - val_fn: 171.0000 - val_binary_acc: 0.8479 - val_precision: 0.8866 - val_recall: 0.7935 - val_f1_score: 0.8375 - val_roc_auc: 0.9209 - val_pr_auc: 0.9265 - val_cohen_kappa: 0.6953
# Epoch 14/100
# 419/419 [==============================] - 91s 218ms/step - loss: 0.3580 - tp: 2720.0000 - fp: 366.0000 - tn: 2997.0000 - fn: 620.0000 - binary_acc: 0.8529 - precision: 0.8814 - recall: 0.8144 - f1_score: 0.8466 - roc_auc: 0.9184 - pr_auc: 0.9285 - cohen_kappa: 0.7057 - val_loss: 0.3718 - val_tp: 707.0000 - val_fp: 139.0000 - val_tn: 709.0000 - val_fn: 121.0000 - val_binary_acc: 0.8449 - val_precision: 0.8357 - val_recall: 0.8539 - val_f1_score: 0.8447 - val_roc_auc: 0.9190 - val_pr_auc: 0.9207 - val_cohen_kappa: 0.6898
# Epoch 15/100
# 419/419 [==============================] - 88s 209ms/step - loss: 0.3432 - tp: 2756.0000 - fp: 363.0000 - tn: 3000.0000 - fn: 584.0000 - binary_acc: 0.8587 - precision: 0.8836 - recall: 0.8251 - f1_score: 0.8534 - roc_auc: 0.9259 - pr_auc: 0.9352 - cohen_kappa: 0.7174 - val_loss: 0.3744 - val_tp: 717.0000 - val_fp: 145.0000 - val_tn: 703.0000 - val_fn: 111.0000 - val_binary_acc: 0.8473 - val_precision: 0.8318 - val_recall: 0.8659 - val_f1_score: 0.8485 - val_roc_auc: 0.9206 - val_pr_auc: 0.9245 - val_cohen_kappa: 0.6946
# Epoch 16/100
# 419/419 [==============================] - 90s 215ms/step - loss: 0.3488 - tp: 2735.0000 - fp: 388.0000 - tn: 2975.0000 - fn: 605.0000 - binary_acc: 0.8519 - precision: 0.8758 - recall: 0.8189 - f1_score: 0.8464 - roc_auc: 0.9243 - pr_auc: 0.9312 - cohen_kappa: 0.7036 - val_loss: 0.3450 - val_tp: 674.0000 - val_fp: 75.0000 - val_tn: 773.0000 - val_fn: 154.0000 - val_binary_acc: 0.8634 - val_precision: 0.8999 - val_recall: 0.8140 - val_f1_score: 0.8548 - val_roc_auc: 0.9263 - val_pr_auc: 0.9311 - val_cohen_kappa: 0.7264
# Epoch 17/100
# 419/419 [==============================] - 87s 209ms/step - loss: 0.3377 - tp: 2796.0000 - fp: 364.0000 - tn: 2999.0000 - fn: 544.0000 - binary_acc: 0.8645 - precision: 0.8848 - recall: 0.8371 - f1_score: 0.8603 - roc_auc: 0.9288 - pr_auc: 0.9377 - cohen_kappa: 0.7290 - val_loss: 0.3549 - val_tp: 700.0000 - val_fp: 120.0000 - val_tn: 728.0000 - val_fn: 128.0000 - val_binary_acc: 0.8520 - val_precision: 0.8537 - val_recall: 0.8454 - val_f1_score: 0.8495 - val_roc_auc: 0.9224 - val_pr_auc: 0.9247 - val_cohen_kappa: 0.7040
# Epoch 18/100
# 419/419 [==============================] - 92s 219ms/step - loss: 0.3368 - tp: 2789.0000 - fp: 358.0000 - tn: 3005.0000 - fn: 551.0000 - binary_acc: 0.8644 - precision: 0.8862 - recall: 0.8350 - f1_score: 0.8599 - roc_auc: 0.9274 - pr_auc: 0.9370 - cohen_kappa: 0.7287 - val_loss: 0.3500 - val_tp: 691.0000 - val_fp: 102.0000 - val_tn: 746.0000 - val_fn: 137.0000 - val_binary_acc: 0.8574 - val_precision: 0.8714 - val_recall: 0.8345 - val_f1_score: 0.8526 - val_roc_auc: 0.9261 - val_pr_auc: 0.9272 - val_cohen_kappa: 0.7146
# Epoch 19/100
# 419/419 [==============================] - 87s 207ms/step - loss: 0.3394 - tp: 2767.0000 - fp: 383.0000 - tn: 2980.0000 - fn: 573.0000 - binary_acc: 0.8574 - precision: 0.8784 - recall: 0.8284 - f1_score: 0.8527 - roc_auc: 0.9266 - pr_auc: 0.9374 - cohen_kappa: 0.7147 - val_loss: 0.3625 - val_tp: 697.0000 - val_fp: 116.0000 - val_tn: 732.0000 - val_fn: 131.0000 - val_binary_acc: 0.8526 - val_precision: 0.8573 - val_recall: 0.8418 - val_f1_score: 0.8495 - val_roc_auc: 0.9219 - val_pr_auc: 0.9259 - val_cohen_kappa: 0.7051
# Epoch 20/100
# 419/419 [==============================] - 90s 215ms/step - loss: 0.3255 - tp: 2795.0000 - fp: 334.0000 - tn: 3029.0000 - fn: 545.0000 - binary_acc: 0.8689 - precision: 0.8933 - recall: 0.8368 - f1_score: 0.8641 - roc_auc: 0.9332 - pr_auc: 0.9425 - cohen_kappa: 0.7377 - val_loss: 0.3606 - val_tp: 652.0000 - val_fp: 68.0000 - val_tn: 780.0000 - val_fn: 176.0000 - val_binary_acc: 0.8544 - val_precision: 0.9056 - val_recall: 0.7874 - val_f1_score: 0.8424 - val_roc_auc: 0.9211 - val_pr_auc: 0.9223 - val_cohen_kappa: 0.7083
# Epoch 21/100
# 419/419 [==============================] - 88s 209ms/step - loss: 0.3182 - tp: 2793.0000 - fp: 323.0000 - tn: 3040.0000 - fn: 547.0000 - binary_acc: 0.8702 - precision: 0.8963 - recall: 0.8362 - f1_score: 0.8652 - roc_auc: 0.9365 - pr_auc: 0.9440 - cohen_kappa: 0.7404 - val_loss: 0.3538 - val_tp: 669.0000 - val_fp: 81.0000 - val_tn: 767.0000 - val_fn: 159.0000 - val_binary_acc: 0.8568 - val_precision: 0.8920 - val_recall: 0.8080 - val_f1_score: 0.8479 - val_roc_auc: 0.9222 - val_pr_auc: 0.9259 - val_cohen_kappa: 0.7132
# Epoch 22/100
# 419/419 [==============================] - 92s 219ms/step - loss: 0.3210 - tp: 2797.0000 - fp: 319.0000 - tn: 3044.0000 - fn: 543.0000 - binary_acc: 0.8714 - precision: 0.8976 - recall: 0.8374 - f1_score: 0.8665 - roc_auc: 0.9333 - pr_auc: 0.9440 - cohen_kappa: 0.7427 - val_loss: 0.3532 - val_tp: 652.0000 - val_fp: 62.0000 - val_tn: 786.0000 - val_fn: 176.0000 - val_binary_acc: 0.8580 - val_precision: 0.9132 - val_recall: 0.7874 - val_f1_score: 0.8457 - val_roc_auc: 0.9246 - val_pr_auc: 0.9258 - val_cohen_kappa: 0.7155
# Epoch 23/100
# 419/419 [==============================] - 87s 209ms/step - loss: 0.3182 - tp: 2811.0000 - fp: 320.0000 - tn: 3043.0000 - fn: 529.0000 - binary_acc: 0.8733 - precision: 0.8978 - recall: 0.8416 - f1_score: 0.8688 - roc_auc: 0.9371 - pr_auc: 0.9433 - cohen_kappa: 0.7466 - val_loss: 0.3635 - val_tp: 717.0000 - val_fp: 143.0000 - val_tn: 705.0000 - val_fn: 111.0000 - val_binary_acc: 0.8484 - val_precision: 0.8337 - val_recall: 0.8659 - val_f1_score: 0.8495 - val_roc_auc: 0.9273 - val_pr_auc: 0.9318 - val_cohen_kappa: 0.6970
# Epoch 24/100
# 419/419 [==============================] - 90s 215ms/step - loss: 0.3163 - tp: 2841.0000 - fp: 328.0000 - tn: 3035.0000 - fn: 499.0000 - binary_acc: 0.8766 - precision: 0.8965 - recall: 0.8506 - f1_score: 0.8729 - roc_auc: 0.9378 - pr_auc: 0.9434 - cohen_kappa: 0.7532 - val_loss: 0.3506 - val_tp: 654.0000 - val_fp: 59.0000 - val_tn: 789.0000 - val_fn: 174.0000 - val_binary_acc: 0.8610 - val_precision: 0.9173 - val_recall: 0.7899 - val_f1_score: 0.8488 - val_roc_auc: 0.9272 - val_pr_auc: 0.9294 - val_cohen_kappa: 0.7215
# Epoch 25/100
# 419/419 [==============================] - 88s 210ms/step - loss: 0.3112 - tp: 2831.0000 - fp: 348.0000 - tn: 3015.0000 - fn: 509.0000 - binary_acc: 0.8721 - precision: 0.8905 - recall: 0.8476 - f1_score: 0.8685 - roc_auc: 0.9384 - pr_auc: 0.9461 - cohen_kappa: 0.7442 - val_loss: 0.3669 - val_tp: 723.0000 - val_fp: 140.0000 - val_tn: 708.0000 - val_fn: 105.0000 - val_binary_acc: 0.8538 - val_precision: 0.8378 - val_recall: 0.8732 - val_f1_score: 0.8551 - val_roc_auc: 0.9253 - val_pr_auc: 0.9288 - val_cohen_kappa: 0.7077
# Epoch 26/100
# 419/419 [==============================] - 89s 212ms/step - loss: 0.3043 - tp: 2854.0000 - fp: 339.0000 - tn: 3024.0000 - fn: 486.0000 - binary_acc: 0.8769 - precision: 0.8938 - recall: 0.8545 - f1_score: 0.8737 - roc_auc: 0.9419 - pr_auc: 0.9481 - cohen_kappa: 0.7538 - val_loss: 0.3445 - val_tp: 691.0000 - val_fp: 91.0000 - val_tn: 757.0000 - val_fn: 137.0000 - val_binary_acc: 0.8640 - val_precision: 0.8836 - val_recall: 0.8345 - val_f1_score: 0.8584 - val_roc_auc: 0.9256 - val_pr_auc: 0.9276 - val_cohen_kappa: 0.7277
# Epoch 27/100
# 419/419 [==============================] - 88s 211ms/step - loss: 0.3139 - tp: 2806.0000 - fp: 342.0000 - tn: 3021.0000 - fn: 534.0000 - binary_acc: 0.8693 - precision: 0.8914 - recall: 0.8401 - f1_score: 0.8650 - roc_auc: 0.9376 - pr_auc: 0.9455 - cohen_kappa: 0.7386 - val_loss: 0.3567 - val_tp: 646.0000 - val_fp: 61.0000 - val_tn: 787.0000 - val_fn: 182.0000 - val_binary_acc: 0.8550 - val_precision: 0.9137 - val_recall: 0.7802 - val_f1_score: 0.8417 - val_roc_auc: 0.9220 - val_pr_auc: 0.9277 - val_cohen_kappa: 0.7095
# Epoch 28/100
# 419/419 [==============================] - 90s 215ms/step - loss: 0.3068 - tp: 2840.0000 - fp: 288.0000 - tn: 3075.0000 - fn: 500.0000 - binary_acc: 0.8824 - precision: 0.9079 - recall: 0.8503 - f1_score: 0.8782 - roc_auc: 0.9407 - pr_auc: 0.9481 - cohen_kappa: 0.7648 - val_loss: 0.3577 - val_tp: 683.0000 - val_fp: 109.0000 - val_tn: 739.0000 - val_fn: 145.0000 - val_binary_acc: 0.8484 - val_precision: 0.8624 - val_recall: 0.8249 - val_f1_score: 0.8432 - val_roc_auc: 0.9226 - val_pr_auc: 0.9267 - val_cohen_kappa: 0.6967
# Epoch 29/100
# 419/419 [==============================] - 93s 221ms/step - loss: 0.3014 - tp: 2857.0000 - fp: 316.0000 - tn: 3047.0000 - fn: 483.0000 - binary_acc: 0.8808 - precision: 0.9004 - recall: 0.8554 - f1_score: 0.8773 - roc_auc: 0.9424 - pr_auc: 0.9498 - cohen_kappa: 0.7616 - val_loss: 0.3554 - val_tp: 698.0000 - val_fp: 107.0000 - val_tn: 741.0000 - val_fn: 130.0000 - val_binary_acc: 0.8586 - val_precision: 0.8671 - val_recall: 0.8430 - val_f1_score: 0.8549 - val_roc_auc: 0.9232 - val_pr_auc: 0.9237 - val_cohen_kappa: 0.7171
# Epoch 30/100
# 419/419 [==============================] - 88s 210ms/step - loss: 0.2945 - tp: 2833.0000 - fp: 276.0000 - tn: 3087.0000 - fn: 507.0000 - binary_acc: 0.8832 - precision: 0.9112 - recall: 0.8482 - f1_score: 0.8786 - roc_auc: 0.9440 - pr_auc: 0.9517 - cohen_kappa: 0.7663 - val_loss: 0.3556 - val_tp: 711.0000 - val_fp: 120.0000 - val_tn: 728.0000 - val_fn: 117.0000 - val_binary_acc: 0.8586 - val_precision: 0.8556 - val_recall: 0.8587 - val_f1_score: 0.8571 - val_roc_auc: 0.9286 - val_pr_auc: 0.9313 - val_cohen_kappa: 0.7172
# Epoch 31/100
# 419/419 [==============================] - 89s 212ms/step - loss: 0.2952 - tp: 2855.0000 - fp: 306.0000 - tn: 3057.0000 - fn: 485.0000 - binary_acc: 0.8820 - precision: 0.9032 - recall: 0.8548 - f1_score: 0.8783 - roc_auc: 0.9454 - pr_auc: 0.9523 - cohen_kappa: 0.7639 - val_loss: 0.3514 - val_tp: 690.0000 - val_fp: 101.0000 - val_tn: 747.0000 - val_fn: 138.0000 - val_binary_acc: 0.8574 - val_precision: 0.8723 - val_recall: 0.8333 - val_f1_score: 0.8524 - val_roc_auc: 0.9250 - val_pr_auc: 0.9258 - val_cohen_kappa: 0.7146
# Epoch 32/100
# 419/419 [==============================] - 89s 213ms/step - loss: 0.2936 - tp: 2867.0000 - fp: 311.0000 - tn: 3052.0000 - fn: 473.0000 - binary_acc: 0.8830 - precision: 0.9021 - recall: 0.8584 - f1_score: 0.8797 - roc_auc: 0.9465 - pr_auc: 0.9512 - cohen_kappa: 0.7660 - val_loss: 0.3426 - val_tp: 694.0000 - val_fp: 104.0000 - val_tn: 744.0000 - val_fn: 134.0000 - val_binary_acc: 0.8580 - val_precision: 0.8697 - val_recall: 0.8382 - val_f1_score: 0.8536 - val_roc_auc: 0.9263 - val_pr_auc: 0.9284 - val_cohen_kappa: 0.7158
# Epoch 33/100
# 419/419 [==============================] - 89s 213ms/step - loss: 0.2911 - tp: 2888.0000 - fp: 342.0000 - tn: 3021.0000 - fn: 452.0000 - binary_acc: 0.8815 - precision: 0.8941 - recall: 0.8647 - f1_score: 0.8791 - roc_auc: 0.9469 - pr_auc: 0.9522 - cohen_kappa: 0.7631 - val_loss: 0.3376 - val_tp: 691.0000 - val_fp: 91.0000 - val_tn: 757.0000 - val_fn: 137.0000 - val_binary_acc: 0.8640 - val_precision: 0.8836 - val_recall: 0.8345 - val_f1_score: 0.8584 - val_roc_auc: 0.9287 - val_pr_auc: 0.9333 - val_cohen_kappa: 0.7277
# Epoch 34/100
# 419/419 [==============================] - 89s 211ms/step - loss: 0.2884 - tp: 2880.0000 - fp: 315.0000 - tn: 3048.0000 - fn: 460.0000 - binary_acc: 0.8844 - precision: 0.9014 - recall: 0.8623 - f1_score: 0.8814 - roc_auc: 0.9468 - pr_auc: 0.9539 - cohen_kappa: 0.7687 - val_loss: 0.3594 - val_tp: 707.0000 - val_fp: 109.0000 - val_tn: 739.0000 - val_fn: 121.0000 - val_binary_acc: 0.8628 - val_precision: 0.8664 - val_recall: 0.8539 - val_f1_score: 0.8601 - val_roc_auc: 0.9250 - val_pr_auc: 0.9261 - val_cohen_kappa: 0.7255
# Epoch 35/100
# 419/419 [==============================] - 88s 211ms/step - loss: 0.2992 - tp: 2851.0000 - fp: 300.0000 - tn: 3063.0000 - fn: 489.0000 - binary_acc: 0.8823 - precision: 0.9048 - recall: 0.8536 - f1_score: 0.8784 - roc_auc: 0.9443 - pr_auc: 0.9516 - cohen_kappa: 0.7645 - val_loss: 0.3541 - val_tp: 716.0000 - val_fp: 136.0000 - val_tn: 712.0000 - val_fn: 112.0000 - val_binary_acc: 0.8520 - val_precision: 0.8404 - val_recall: 0.8647 - val_f1_score: 0.8524 - val_roc_auc: 0.9253 - val_pr_auc: 0.9273 - val_cohen_kappa: 0.7041
# Epoch 36/100
# 419/419 [==============================] - 89s 213ms/step - loss: 0.2895 - tp: 2869.0000 - fp: 296.0000 - tn: 3067.0000 - fn: 471.0000 - binary_acc: 0.8856 - precision: 0.9065 - recall: 0.8590 - f1_score: 0.8821 - roc_auc: 0.9479 - pr_auc: 0.9526 - cohen_kappa: 0.7711 - val_loss: 0.3579 - val_tp: 683.0000 - val_fp: 98.0000 - val_tn: 750.0000 - val_fn: 145.0000 - val_binary_acc: 0.8550 - val_precision: 0.8745 - val_recall: 0.8249 - val_f1_score: 0.8490 - val_roc_auc: 0.9219 - val_pr_auc: 0.9233 - val_cohen_kappa: 0.7098
# Epoch 37/100
# 419/419 [==============================] - 89s 212ms/step - loss: 0.2946 - tp: 2876.0000 - fp: 310.0000 - tn: 3053.0000 - fn: 464.0000 - binary_acc: 0.8845 - precision: 0.9027 - recall: 0.8611 - f1_score: 0.8814 - roc_auc: 0.9472 - pr_auc: 0.9517 - cohen_kappa: 0.7690 - val_loss: 0.3424 - val_tp: 698.0000 - val_fp: 106.0000 - val_tn: 742.0000 - val_fn: 130.0000 - val_binary_acc: 0.8592 - val_precision: 0.8682 - val_recall: 0.8430 - val_f1_score: 0.8554 - val_roc_auc: 0.9286 - val_pr_auc: 0.9317 - val_cohen_kappa: 0.7182
# Epoch 38/100
# 419/419 [==============================] - 88s 211ms/step - loss: 0.2860 - tp: 2889.0000 - fp: 323.0000 - tn: 3040.0000 - fn: 451.0000 - binary_acc: 0.8845 - precision: 0.8994 - recall: 0.8650 - f1_score: 0.8819 - roc_auc: 0.9494 - pr_auc: 0.9539 - cohen_kappa: 0.7690 - val_loss: 0.3472 - val_tp: 701.0000 - val_fp: 117.0000 - val_tn: 731.0000 - val_fn: 127.0000 - val_binary_acc: 0.8544 - val_precision: 0.8570 - val_recall: 0.8466 - val_f1_score: 0.8518 - val_roc_auc: 0.9265 - val_pr_auc: 0.9307 - val_cohen_kappa: 0.7087
# Epoch 39/100
# 419/419 [==============================] - 89s 211ms/step - loss: 0.2780 - tp: 2871.0000 - fp: 274.0000 - tn: 3089.0000 - fn: 469.0000 - binary_acc: 0.8892 - precision: 0.9129 - recall: 0.8596 - f1_score: 0.8854 - roc_auc: 0.9500 - pr_auc: 0.9570 - cohen_kappa: 0.7783 - val_loss: 0.3406 - val_tp: 660.0000 - val_fp: 56.0000 - val_tn: 792.0000 - val_fn: 168.0000 - val_binary_acc: 0.8663 - val_precision: 0.9218 - val_recall: 0.7971 - val_f1_score: 0.8549 - val_roc_auc: 0.9310 - val_pr_auc: 0.9334 - val_cohen_kappa: 0.7322
# Epoch 40/100
# 419/419 [==============================] - 90s 214ms/step - loss: 0.2804 - tp: 2865.0000 - fp: 288.0000 - tn: 3075.0000 - fn: 475.0000 - binary_acc: 0.8862 - precision: 0.9087 - recall: 0.8578 - f1_score: 0.8825 - roc_auc: 0.9493 - pr_auc: 0.9568 - cohen_kappa: 0.7723 - val_loss: 0.3450 - val_tp: 689.0000 - val_fp: 88.0000 - val_tn: 760.0000 - val_fn: 139.0000 - val_binary_acc: 0.8646 - val_precision: 0.8867 - val_recall: 0.8321 - val_f1_score: 0.8586 - val_roc_auc: 0.9259 - val_pr_auc: 0.9296 - val_cohen_kappa: 0.7289
# Epoch 41/100
# 419/419 [==============================] - 88s 210ms/step - loss: 0.2742 - tp: 2873.0000 - fp: 282.0000 - tn: 3081.0000 - fn: 467.0000 - binary_acc: 0.8883 - precision: 0.9106 - recall: 0.8602 - f1_score: 0.8847 - roc_auc: 0.9521 - pr_auc: 0.9581 - cohen_kappa: 0.7765 - val_loss: 0.3550 - val_tp: 692.0000 - val_fp: 99.0000 - val_tn: 749.0000 - val_fn: 136.0000 - val_binary_acc: 0.8598 - val_precision: 0.8748 - val_recall: 0.8357 - val_f1_score: 0.8548 - val_roc_auc: 0.9249 - val_pr_auc: 0.9237 - val_cohen_kappa: 0.7194
# Epoch 42/100
# 419/419 [==============================] - 90s 215ms/step - loss: 0.2774 - tp: 2892.0000 - fp: 293.0000 - tn: 3070.0000 - fn: 448.0000 - binary_acc: 0.8895 - precision: 0.9080 - recall: 0.8659 - f1_score: 0.8864 - roc_auc: 0.9518 - pr_auc: 0.9586 - cohen_kappa: 0.7789 - val_loss: 0.3509 - val_tp: 690.0000 - val_fp: 95.0000 - val_tn: 753.0000 - val_fn: 138.0000 - val_binary_acc: 0.8610 - val_precision: 0.8790 - val_recall: 0.8333 - val_f1_score: 0.8555 - val_roc_auc: 0.9253 - val_pr_auc: 0.9267 - val_cohen_kappa: 0.7217
# Epoch 43/100
# 419/419 [==============================] - 89s 213ms/step - loss: 0.2797 - tp: 2882.0000 - fp: 274.0000 - tn: 3089.0000 - fn: 458.0000 - binary_acc: 0.8908 - precision: 0.9132 - recall: 0.8629 - f1_score: 0.8873 - roc_auc: 0.9505 - pr_auc: 0.9570 - cohen_kappa: 0.7815 - val_loss: 0.3469 - val_tp: 700.0000 - val_fp: 92.0000 - val_tn: 756.0000 - val_fn: 128.0000 - val_binary_acc: 0.8687 - val_precision: 0.8838 - val_recall: 0.8454 - val_f1_score: 0.8642 - val_roc_auc: 0.9262 - val_pr_auc: 0.9302 - val_cohen_kappa: 0.7373
# Epoch 44/100
# 419/419 [==============================] - 89s 212ms/step - loss: 0.2795 - tp: 2882.0000 - fp: 280.0000 - tn: 3083.0000 - fn: 458.0000 - binary_acc: 0.8899 - precision: 0.9114 - recall: 0.8629 - f1_score: 0.8865 - roc_auc: 0.9508 - pr_auc: 0.9566 - cohen_kappa: 0.7798 - val_loss: 0.3402 - val_tp: 687.0000 - val_fp: 79.0000 - val_tn: 769.0000 - val_fn: 141.0000 - val_binary_acc: 0.8687 - val_precision: 0.8969 - val_recall: 0.8297 - val_f1_score: 0.8620 - val_roc_auc: 0.9286 - val_pr_auc: 0.9331 - val_cohen_kappa: 0.7372
# Epoch 45/100
# 419/419 [==============================] - 90s 214ms/step - loss: 0.2744 - tp: 2906.0000 - fp: 293.0000 - tn: 3070.0000 - fn: 434.0000 - binary_acc: 0.8915 - precision: 0.9084 - recall: 0.8701 - f1_score: 0.8888 - roc_auc: 0.9536 - pr_auc: 0.9582 - cohen_kappa: 0.7830 - val_loss: 0.3583 - val_tp: 674.0000 - val_fp: 94.0000 - val_tn: 754.0000 - val_fn: 154.0000 - val_binary_acc: 0.8520 - val_precision: 0.8776 - val_recall: 0.8140 - val_f1_score: 0.8446 - val_roc_auc: 0.9224 - val_pr_auc: 0.9240 - val_cohen_kappa: 0.7038
# Epoch 46/100
# 419/419 [==============================] - 92s 219ms/step - loss: 0.2857 - tp: 2897.0000 - fp: 318.0000 - tn: 3045.0000 - fn: 443.0000 - binary_acc: 0.8865 - precision: 0.9011 - recall: 0.8674 - f1_score: 0.8839 - roc_auc: 0.9491 - pr_auc: 0.9543 - cohen_kappa: 0.7729 - val_loss: 0.3338 - val_tp: 726.0000 - val_fp: 116.0000 - val_tn: 732.0000 - val_fn: 102.0000 - val_binary_acc: 0.8699 - val_precision: 0.8622 - val_recall: 0.8768 - val_f1_score: 0.8695 - val_roc_auc: 0.9322 - val_pr_auc: 0.9348 - val_cohen_kappa: 0.7399
# Epoch 47/100
# 419/419 [==============================] - 90s 215ms/step - loss: 0.2687 - tp: 2913.0000 - fp: 288.0000 - tn: 3075.0000 - fn: 427.0000 - binary_acc: 0.8933 - precision: 0.9100 - recall: 0.8722 - f1_score: 0.8907 - roc_auc: 0.9551 - pr_auc: 0.9598 - cohen_kappa: 0.7866 - val_loss: 0.3426 - val_tp: 697.0000 - val_fp: 102.0000 - val_tn: 746.0000 - val_fn: 131.0000 - val_binary_acc: 0.8610 - val_precision: 0.8723 - val_recall: 0.8418 - val_f1_score: 0.8568 - val_roc_auc: 0.9283 - val_pr_auc: 0.9322 - val_cohen_kappa: 0.7218
# Epoch 48/100
# 419/419 [==============================] - 89s 211ms/step - loss: 0.2670 - tp: 2912.0000 - fp: 286.0000 - tn: 3077.0000 - fn: 428.0000 - binary_acc: 0.8935 - precision: 0.9106 - recall: 0.8719 - f1_score: 0.8908 - roc_auc: 0.9548 - pr_auc: 0.9602 - cohen_kappa: 0.7869 - val_loss: 0.3485 - val_tp: 699.0000 - val_fp: 106.0000 - val_tn: 742.0000 - val_fn: 129.0000 - val_binary_acc: 0.8598 - val_precision: 0.8683 - val_recall: 0.8442 - val_f1_score: 0.8561 - val_roc_auc: 0.9247 - val_pr_auc: 0.9308 - val_cohen_kappa: 0.7194
# Epoch 49/100
# 419/419 [==============================] - 92s 219ms/step - loss: 0.2708 - tp: 2903.0000 - fp: 307.0000 - tn: 3056.0000 - fn: 437.0000 - binary_acc: 0.8890 - precision: 0.9044 - recall: 0.8692 - f1_score: 0.8864 - roc_auc: 0.9536 - pr_auc: 0.9596 - cohen_kappa: 0.7780 - val_loss: 0.3574 - val_tp: 669.0000 - val_fp: 84.0000 - val_tn: 764.0000 - val_fn: 159.0000 - val_binary_acc: 0.8550 - val_precision: 0.8884 - val_recall: 0.8080 - val_f1_score: 0.8463 - val_roc_auc: 0.9272 - val_pr_auc: 0.9292 - val_cohen_kappa: 0.7097
# Epoch 50/100
# 419/419 [==============================] - 89s 212ms/step - loss: 0.2717 - tp: 2888.0000 - fp: 277.0000 - tn: 3086.0000 - fn: 452.0000 - binary_acc: 0.8912 - precision: 0.9125 - recall: 0.8647 - f1_score: 0.8879 - roc_auc: 0.9533 - pr_auc: 0.9579 - cohen_kappa: 0.7824 - val_loss: 0.3398 - val_tp: 686.0000 - val_fp: 79.0000 - val_tn: 769.0000 - val_fn: 142.0000 - val_binary_acc: 0.8681 - val_precision: 0.8967 - val_recall: 0.8285 - val_f1_score: 0.8613 - val_roc_auc: 0.9285 - val_pr_auc: 0.9330 - val_cohen_kappa: 0.7360
# Epoch 51/100
# 419/419 [==============================] - 93s 222ms/step - loss: 0.2663 - tp: 2902.0000 - fp: 258.0000 - tn: 3105.0000 - fn: 438.0000 - binary_acc: 0.8962 - precision: 0.9184 - recall: 0.8689 - f1_score: 0.8929 - roc_auc: 0.9556 - pr_auc: 0.9603 - cohen_kappa: 0.7923 - val_loss: 0.3354 - val_tp: 684.0000 - val_fp: 79.0000 - val_tn: 769.0000 - val_fn: 144.0000 - val_binary_acc: 0.8669 - val_precision: 0.8965 - val_recall: 0.8261 - val_f1_score: 0.8598 - val_roc_auc: 0.9285 - val_pr_auc: 0.9359 - val_cohen_kappa: 0.7336
# Epoch 52/100
# 419/419 [==============================] - 91s 217ms/step - loss: 0.2709 - tp: 2923.0000 - fp: 301.0000 - tn: 3062.0000 - fn: 417.0000 - binary_acc: 0.8929 - precision: 0.9066 - recall: 0.8751 - f1_score: 0.8906 - roc_auc: 0.9538 - pr_auc: 0.9596 - cohen_kappa: 0.7857 - val_loss: 0.3496 - val_tp: 711.0000 - val_fp: 107.0000 - val_tn: 741.0000 - val_fn: 117.0000 - val_binary_acc: 0.8663 - val_precision: 0.8692 - val_recall: 0.8587 - val_f1_score: 0.8639 - val_roc_auc: 0.9274 - val_pr_auc: 0.9309 - val_cohen_kappa: 0.7326
# Epoch 53/100
# 419/419 [==============================] - 95s 226ms/step - loss: 0.2660 - tp: 2916.0000 - fp: 298.0000 - tn: 3065.0000 - fn: 424.0000 - binary_acc: 0.8923 - precision: 0.9073 - recall: 0.8731 - f1_score: 0.8898 - roc_auc: 0.9557 - pr_auc: 0.9604 - cohen_kappa: 0.7845 - val_loss: 0.3499 - val_tp: 701.0000 - val_fp: 114.0000 - val_tn: 734.0000 - val_fn: 127.0000 - val_binary_acc: 0.8562 - val_precision: 0.8601 - val_recall: 0.8466 - val_f1_score: 0.8533 - val_roc_auc: 0.9265 - val_pr_auc: 0.9313 - val_cohen_kappa: 0.7123
# Epoch 54/100
# 419/419 [==============================] - 92s 218ms/step - loss: 0.2664 - tp: 2907.0000 - fp: 274.0000 - tn: 3089.0000 - fn: 433.0000 - binary_acc: 0.8945 - precision: 0.9139 - recall: 0.8704 - f1_score: 0.8916 - roc_auc: 0.9551 - pr_auc: 0.9602 - cohen_kappa: 0.7890 - val_loss: 0.3338 - val_tp: 700.0000 - val_fp: 80.0000 - val_tn: 768.0000 - val_fn: 128.0000 - val_binary_acc: 0.8759 - val_precision: 0.8974 - val_recall: 0.8454 - val_f1_score: 0.8706 - val_roc_auc: 0.9298 - val_pr_auc: 0.9357 - val_cohen_kappa: 0.7516
# Epoch 55/100
# 419/419 [==============================] - 94s 224ms/step - loss: 0.2704 - tp: 2892.0000 - fp: 281.0000 - tn: 3082.0000 - fn: 448.0000 - binary_acc: 0.8912 - precision: 0.9114 - recall: 0.8659 - f1_score: 0.8881 - roc_auc: 0.9546 - pr_auc: 0.9589 - cohen_kappa: 0.7824 - val_loss: 0.3407 - val_tp: 716.0000 - val_fp: 106.0000 - val_tn: 742.0000 - val_fn: 112.0000 - val_binary_acc: 0.8699 - val_precision: 0.8710 - val_recall: 0.8647 - val_f1_score: 0.8679 - val_roc_auc: 0.9288 - val_pr_auc: 0.9341 - val_cohen_kappa: 0.7398
# Epoch 56/100
# 419/419 [==============================] - 92s 219ms/step - loss: 0.2581 - tp: 2930.0000 - fp: 290.0000 - tn: 3073.0000 - fn: 410.0000 - binary_acc: 0.8956 - precision: 0.9099 - recall: 0.8772 - f1_score: 0.8933 - roc_auc: 0.9582 - pr_auc: 0.9633 - cohen_kappa: 0.7911 - val_loss: 0.3651 - val_tp: 701.0000 - val_fp: 94.0000 - val_tn: 754.0000 - val_fn: 127.0000 - val_binary_acc: 0.8681 - val_precision: 0.8818 - val_recall: 0.8466 - val_f1_score: 0.8638 - val_roc_auc: 0.9271 - val_pr_auc: 0.9270 - val_cohen_kappa: 0.7361
# Epoch 57/100
# 419/419 [==============================] - 96s 228ms/step - loss: 0.2611 - tp: 2889.0000 - fp: 251.0000 - tn: 3112.0000 - fn: 451.0000 - binary_acc: 0.8953 - precision: 0.9201 - recall: 0.8650 - f1_score: 0.8917 - roc_auc: 0.9574 - pr_auc: 0.9614 - cohen_kappa: 0.7905 - val_loss: 0.3383 - val_tp: 701.0000 - val_fp: 96.0000 - val_tn: 752.0000 - val_fn: 127.0000 - val_binary_acc: 0.8669 - val_precision: 0.8795 - val_recall: 0.8466 - val_f1_score: 0.8628 - val_roc_auc: 0.9301 - val_pr_auc: 0.9349 - val_cohen_kappa: 0.7337
# Epoch 58/100
# 419/419 [==============================] - 90s 215ms/step - loss: 0.2650 - tp: 2912.0000 - fp: 276.0000 - tn: 3087.0000 - fn: 428.0000 - binary_acc: 0.8950 - precision: 0.9134 - recall: 0.8719 - f1_score: 0.8922 - roc_auc: 0.9553 - pr_auc: 0.9604 - cohen_kappa: 0.7899 - val_loss: 0.3468 - val_tp: 679.0000 - val_fp: 78.0000 - val_tn: 770.0000 - val_fn: 149.0000 - val_binary_acc: 0.8646 - val_precision: 0.8970 - val_recall: 0.8200 - val_f1_score: 0.8568 - val_roc_auc: 0.9244 - val_pr_auc: 0.9283 - val_cohen_kappa: 0.7288
# Epoch 59/100
# 419/419 [==============================] - 92s 219ms/step - loss: 0.2635 - tp: 2919.0000 - fp: 271.0000 - tn: 3092.0000 - fn: 421.0000 - binary_acc: 0.8968 - precision: 0.9150 - recall: 0.8740 - f1_score: 0.8940 - roc_auc: 0.9561 - pr_auc: 0.9609 - cohen_kappa: 0.7935 - val_loss: 0.3380 - val_tp: 702.0000 - val_fp: 86.0000 - val_tn: 762.0000 - val_fn: 126.0000 - val_binary_acc: 0.8735 - val_precision: 0.8909 - val_recall: 0.8478 - val_f1_score: 0.8688 - val_roc_auc: 0.9294 - val_pr_auc: 0.9336 - val_cohen_kappa: 0.7468
# Epoch 60/100
# 419/419 [==============================] - 90s 214ms/step - loss: 0.2582 - tp: 2909.0000 - fp: 260.0000 - tn: 3103.0000 - fn: 431.0000 - binary_acc: 0.8969 - precision: 0.9180 - recall: 0.8710 - f1_score: 0.8938 - roc_auc: 0.9571 - pr_auc: 0.9627 - cohen_kappa: 0.7938 - val_loss: 0.3718 - val_tp: 700.0000 - val_fp: 123.0000 - val_tn: 725.0000 - val_fn: 128.0000 - val_binary_acc: 0.8502 - val_precision: 0.8505 - val_recall: 0.8454 - val_f1_score: 0.8480 - val_roc_auc: 0.9235 - val_pr_auc: 0.9240 - val_cohen_kappa: 0.7004
# Epoch 61/100
# 419/419 [==============================] - 93s 222ms/step - loss: 0.2505 - tp: 2942.0000 - fp: 271.0000 - tn: 3092.0000 - fn: 398.0000 - binary_acc: 0.9002 - precision: 0.9157 - recall: 0.8808 - f1_score: 0.8979 - roc_auc: 0.9607 - pr_auc: 0.9651 - cohen_kappa: 0.8004 - val_loss: 0.3404 - val_tp: 684.0000 - val_fp: 76.0000 - val_tn: 772.0000 - val_fn: 144.0000 - val_binary_acc: 0.8687 - val_precision: 0.9000 - val_recall: 0.8261 - val_f1_score: 0.8615 - val_roc_auc: 0.9317 - val_pr_auc: 0.9346 - val_cohen_kappa: 0.7372
# Epoch 62/100
# 419/419 [==============================] - 90s 215ms/step - loss: 0.2587 - tp: 2910.0000 - fp: 263.0000 - tn: 3100.0000 - fn: 430.0000 - binary_acc: 0.8966 - precision: 0.9171 - recall: 0.8713 - f1_score: 0.8936 - roc_auc: 0.9575 - pr_auc: 0.9611 - cohen_kappa: 0.7932 - val_loss: 0.3394 - val_tp: 672.0000 - val_fp: 76.0000 - val_tn: 772.0000 - val_fn: 156.0000 - val_binary_acc: 0.8616 - val_precision: 0.8984 - val_recall: 0.8116 - val_f1_score: 0.8528 - val_roc_auc: 0.9293 - val_pr_auc: 0.9346 - val_cohen_kappa: 0.7228
# Epoch 63/100
# 419/419 [==============================] - 92s 219ms/step - loss: 0.2614 - tp: 2917.0000 - fp: 282.0000 - tn: 3081.0000 - fn: 423.0000 - binary_acc: 0.8948 - precision: 0.9118 - recall: 0.8734 - f1_score: 0.8922 - roc_auc: 0.9579 - pr_auc: 0.9623 - cohen_kappa: 0.7896 - val_loss: 0.3620 - val_tp: 674.0000 - val_fp: 79.0000 - val_tn: 769.0000 - val_fn: 154.0000 - val_binary_acc: 0.8610 - val_precision: 0.8951 - val_recall: 0.8140 - val_f1_score: 0.8526 - val_roc_auc: 0.9235 - val_pr_auc: 0.9243 - val_cohen_kappa: 0.7216
# Epoch 64/100
# 419/419 [==============================] - 90s 214ms/step - loss: 0.2586 - tp: 2920.0000 - fp: 276.0000 - tn: 3087.0000 - fn: 420.0000 - binary_acc: 0.8962 - precision: 0.9136 - recall: 0.8743 - f1_score: 0.8935 - roc_auc: 0.9585 - pr_auc: 0.9628 - cohen_kappa: 0.7923 - val_loss: 0.3525 - val_tp: 704.0000 - val_fp: 109.0000 - val_tn: 739.0000 - val_fn: 124.0000 - val_binary_acc: 0.8610 - val_precision: 0.8659 - val_recall: 0.8502 - val_f1_score: 0.8580 - val_roc_auc: 0.9280 - val_pr_auc: 0.9288 - val_cohen_kappa: 0.7219
# Epoch 65/100
# 419/419 [==============================] - 94s 224ms/step - loss: 0.2634 - tp: 2914.0000 - fp: 258.0000 - tn: 3105.0000 - fn: 426.0000 - binary_acc: 0.8980 - precision: 0.9187 - recall: 0.8725 - f1_score: 0.8950 - roc_auc: 0.9564 - pr_auc: 0.9614 - cohen_kappa: 0.7959 - val_loss: 0.3314 - val_tp: 687.0000 - val_fp: 65.0000 - val_tn: 783.0000 - val_fn: 141.0000 - val_binary_acc: 0.8771 - val_precision: 0.9136 - val_recall: 0.8297 - val_f1_score: 0.8696 - val_roc_auc: 0.9337 - val_pr_auc: 0.9376 - val_cohen_kappa: 0.7539
# Epoch 66/100
# 419/419 [==============================] - 90s 214ms/step - loss: 0.2630 - tp: 2906.0000 - fp: 263.0000 - tn: 3100.0000 - fn: 434.0000 - binary_acc: 0.8960 - precision: 0.9170 - recall: 0.8701 - f1_score: 0.8929 - roc_auc: 0.9567 - pr_auc: 0.9607 - cohen_kappa: 0.7920 - val_loss: 0.3473 - val_tp: 715.0000 - val_fp: 125.0000 - val_tn: 723.0000 - val_fn: 113.0000 - val_binary_acc: 0.8580 - val_precision: 0.8512 - val_recall: 0.8635 - val_f1_score: 0.8573 - val_roc_auc: 0.9274 - val_pr_auc: 0.9334 - val_cohen_kappa: 0.7160
# Epoch 67/100
# 419/419 [==============================] - 91s 217ms/step - loss: 0.2507 - tp: 2928.0000 - fp: 284.0000 - tn: 3079.0000 - fn: 412.0000 - binary_acc: 0.8962 - precision: 0.9116 - recall: 0.8766 - f1_score: 0.8938 - roc_auc: 0.9605 - pr_auc: 0.9651 - cohen_kappa: 0.7923 - val_loss: 0.3517 - val_tp: 698.0000 - val_fp: 90.0000 - val_tn: 758.0000 - val_fn: 130.0000 - val_binary_acc: 0.8687 - val_precision: 0.8858 - val_recall: 0.8430 - val_f1_score: 0.8639 - val_roc_auc: 0.9264 - val_pr_auc: 0.9329 - val_cohen_kappa: 0.7373
# Epoch 68/100
# 419/419 [==============================] - 90s 214ms/step - loss: 0.2563 - tp: 2935.0000 - fp: 249.0000 - tn: 3114.0000 - fn: 405.0000 - binary_acc: 0.9024 - precision: 0.9218 - recall: 0.8787 - f1_score: 0.8998 - roc_auc: 0.9590 - pr_auc: 0.9627 - cohen_kappa: 0.8048 - val_loss: 0.3416 - val_tp: 698.0000 - val_fp: 87.0000 - val_tn: 761.0000 - val_fn: 130.0000 - val_binary_acc: 0.8705 - val_precision: 0.8892 - val_recall: 0.8430 - val_f1_score: 0.8655 - val_roc_auc: 0.9289 - val_pr_auc: 0.9338 - val_cohen_kappa: 0.7409
# Epoch 69/100
# 419/419 [==============================] - 94s 224ms/step - loss: 0.2496 - tp: 2933.0000 - fp: 276.0000 - tn: 3087.0000 - fn: 407.0000 - binary_acc: 0.8981 - precision: 0.9140 - recall: 0.8781 - f1_score: 0.8957 - roc_auc: 0.9608 - pr_auc: 0.9650 - cohen_kappa: 0.7962 - val_loss: 0.3470 - val_tp: 714.0000 - val_fp: 110.0000 - val_tn: 738.0000 - val_fn: 114.0000 - val_binary_acc: 0.8663 - val_precision: 0.8665 - val_recall: 0.8623 - val_f1_score: 0.8644 - val_roc_auc: 0.9306 - val_pr_auc: 0.9317 - val_cohen_kappa: 0.7326
# Epoch 70/100
# 419/419 [==============================] - 90s 215ms/step - loss: 0.2558 - tp: 2934.0000 - fp: 255.0000 - tn: 3108.0000 - fn: 406.0000 - binary_acc: 0.9014 - precision: 0.9200 - recall: 0.8784 - f1_score: 0.8988 - roc_auc: 0.9584 - pr_auc: 0.9628 - cohen_kappa: 0.8027 - val_loss: 0.3497 - val_tp: 708.0000 - val_fp: 95.0000 - val_tn: 753.0000 - val_fn: 120.0000 - val_binary_acc: 0.8717 - val_precision: 0.8817 - val_recall: 0.8551 - val_f1_score: 0.8682 - val_roc_auc: 0.9263 - val_pr_auc: 0.9289 - val_cohen_kappa: 0.7433
# Epoch 71/100
# 419/419 [==============================] - 92s 220ms/step - loss: 0.2487 - tp: 2919.0000 - fp: 270.0000 - tn: 3093.0000 - fn: 421.0000 - binary_acc: 0.8969 - precision: 0.9153 - recall: 0.8740 - f1_score: 0.8942 - roc_auc: 0.9604 - pr_auc: 0.9658 - cohen_kappa: 0.7938 - val_loss: 0.3438 - val_tp: 715.0000 - val_fp: 96.0000 - val_tn: 752.0000 - val_fn: 113.0000 - val_binary_acc: 0.8753 - val_precision: 0.8816 - val_recall: 0.8635 - val_f1_score: 0.8725 - val_roc_auc: 0.9292 - val_pr_auc: 0.9326 - val_cohen_kappa: 0.7505
# Epoch 72/100
# 419/419 [==============================] - 91s 217ms/step - loss: 0.2545 - tp: 2923.0000 - fp: 267.0000 - tn: 3096.0000 - fn: 417.0000 - binary_acc: 0.8980 - precision: 0.9163 - recall: 0.8751 - f1_score: 0.8953 - roc_auc: 0.9591 - pr_auc: 0.9634 - cohen_kappa: 0.7959 - val_loss: 0.3532 - val_tp: 721.0000 - val_fp: 109.0000 - val_tn: 739.0000 - val_fn: 107.0000 - val_binary_acc: 0.8711 - val_precision: 0.8687 - val_recall: 0.8708 - val_f1_score: 0.8697 - val_roc_auc: 0.9289 - val_pr_auc: 0.9304 - val_cohen_kappa: 0.7422
# Epoch 73/100
# 419/419 [==============================] - 91s 218ms/step - loss: 0.2533 - tp: 2935.0000 - fp: 265.0000 - tn: 3098.0000 - fn: 405.0000 - binary_acc: 0.9000 - precision: 0.9172 - recall: 0.8787 - f1_score: 0.8976 - roc_auc: 0.9594 - pr_auc: 0.9642 - cohen_kappa: 0.8001 - val_loss: 0.3455 - val_tp: 687.0000 - val_fp: 77.0000 - val_tn: 771.0000 - val_fn: 141.0000 - val_binary_acc: 0.8699 - val_precision: 0.8992 - val_recall: 0.8297 - val_f1_score: 0.8631 - val_roc_auc: 0.9272 - val_pr_auc: 0.9291 - val_cohen_kappa: 0.7396
# Epoch 74/100
# 419/419 [==============================] - 91s 217ms/step - loss: 0.2422 - tp: 2945.0000 - fp: 252.0000 - tn: 3111.0000 - fn: 395.0000 - binary_acc: 0.9035 - precision: 0.9212 - recall: 0.8817 - f1_score: 0.9010 - roc_auc: 0.9627 - pr_auc: 0.9671 - cohen_kappa: 0.8069 - val_loss: 0.3482 - val_tp: 706.0000 - val_fp: 105.0000 - val_tn: 743.0000 - val_fn: 122.0000 - val_binary_acc: 0.8646 - val_precision: 0.8705 - val_recall: 0.8527 - val_f1_score: 0.8615 - val_roc_auc: 0.9311 - val_pr_auc: 0.9331 - val_cohen_kappa: 0.7290
# Epoch 75/100
# 419/419 [==============================] - 91s 217ms/step - loss: 0.2583 - tp: 2903.0000 - fp: 247.0000 - tn: 3116.0000 - fn: 437.0000 - binary_acc: 0.8980 - precision: 0.9216 - recall: 0.8692 - f1_score: 0.8946 - roc_auc: 0.9589 - pr_auc: 0.9638 - cohen_kappa: 0.7959 - val_loss: 0.3487 - val_tp: 695.0000 - val_fp: 98.0000 - val_tn: 750.0000 - val_fn: 133.0000 - val_binary_acc: 0.8622 - val_precision: 0.8764 - val_recall: 0.8394 - val_f1_score: 0.8575 - val_roc_auc: 0.9254 - val_pr_auc: 0.9308 - val_cohen_kappa: 0.7242
# Epoch 76/100
# 419/419 [==============================] - 91s 216ms/step - loss: 0.2485 - tp: 2916.0000 - fp: 231.0000 - tn: 3132.0000 - fn: 424.0000 - binary_acc: 0.9023 - precision: 0.9266 - recall: 0.8731 - f1_score: 0.8990 - roc_auc: 0.9610 - pr_auc: 0.9659 - cohen_kappa: 0.8045 - val_loss: 0.3401 - val_tp: 692.0000 - val_fp: 83.0000 - val_tn: 765.0000 - val_fn: 136.0000 - val_binary_acc: 0.8693 - val_precision: 0.8929 - val_recall: 0.8357 - val_f1_score: 0.8634 - val_roc_auc: 0.9304 - val_pr_auc: 0.9322 - val_cohen_kappa: 0.7384
# Epoch 77/100
# 419/419 [==============================] - 91s 218ms/step - loss: 0.2496 - tp: 2948.0000 - fp: 259.0000 - tn: 3104.0000 - fn: 392.0000 - binary_acc: 0.9029 - precision: 0.9192 - recall: 0.8826 - f1_score: 0.9006 - roc_auc: 0.9609 - pr_auc: 0.9645 - cohen_kappa: 0.8057 - val_loss: 0.3621 - val_tp: 721.0000 - val_fp: 127.0000 - val_tn: 721.0000 - val_fn: 107.0000 - val_binary_acc: 0.8604 - val_precision: 0.8502 - val_recall: 0.8708 - val_f1_score: 0.8604 - val_roc_auc: 0.9289 - val_pr_auc: 0.9318 - val_cohen_kappa: 0.7208
# Epoch 78/100
# 419/419 [==============================] - 90s 215ms/step - loss: 0.2458 - tp: 2945.0000 - fp: 244.0000 - tn: 3119.0000 - fn: 395.0000 - binary_acc: 0.9047 - precision: 0.9235 - recall: 0.8817 - f1_score: 0.9021 - roc_auc: 0.9617 - pr_auc: 0.9667 - cohen_kappa: 0.8093 - val_loss: 0.3655 - val_tp: 671.0000 - val_fp: 83.0000 - val_tn: 765.0000 - val_fn: 157.0000 - val_binary_acc: 0.8568 - val_precision: 0.8899 - val_recall: 0.8104 - val_f1_score: 0.8483 - val_roc_auc: 0.9246 - val_pr_auc: 0.9262 - val_cohen_kappa: 0.7133
# Epoch 79/100
# 419/419 [==============================] - 91s 217ms/step - loss: 0.2529 - tp: 2926.0000 - fp: 262.0000 - tn: 3101.0000 - fn: 414.0000 - binary_acc: 0.8991 - precision: 0.9178 - recall: 0.8760 - f1_score: 0.8964 - roc_auc: 0.9598 - pr_auc: 0.9642 - cohen_kappa: 0.7983 - val_loss: 0.3495 - val_tp: 713.0000 - val_fp: 111.0000 - val_tn: 737.0000 - val_fn: 115.0000 - val_binary_acc: 0.8652 - val_precision: 0.8653 - val_recall: 0.8611 - val_f1_score: 0.8632 - val_roc_auc: 0.9317 - val_pr_auc: 0.9323 - val_cohen_kappa: 0.7303
# Epoch 80/100
# 419/419 [==============================] - ETA: 0s - loss: 0.2494 - tp: 2934.0000 - fp: 243.0000 - tn: 3120.0000 - fn: 406.0000 - binary_acc: 0.9032 - precision: 0.9235 - recall: 0.8784 - f1_score: 0.9004 - roc_auc: 0.9608 - pr_auc: 0.9651 - cohen_kappa: 0.8063Restoring model weights from the end of the best epoch: 65.
# 419/419 [==============================] - 91s 218ms/step - loss: 0.2494 - tp: 2934.0000 - fp: 243.0000 - tn: 3120.0000 - fn: 406.0000 - binary_acc: 0.9032 - precision: 0.9235 - recall: 0.8784 - f1_score: 0.9004 - roc_auc: 0.9608 - pr_auc: 0.9651 - cohen_kappa: 0.8063 - val_loss: 0.3420 - val_tp: 699.0000 - val_fp: 96.0000 - val_tn: 752.0000 - val_fn: 129.0000 - val_binary_acc: 0.8658 - val_precision: 0.8792 - val_recall: 0.8442 - val_f1_score: 0.8614 - val_roc_auc: 0.9297 - val_pr_auc: 0.9348 - val_cohen_kappa: 0.7313
# Epoch 80: early stopping

# %%
new_model.save(save_path + model_name + '.keras')

plot_metrics(history)

# %%
"""new_model.evaluate(validation_generator)"""
new_model.evaluate(test_generator)

    # Make predictions using the validation generator
"""y_valid_pred_prob = new_model.predict(validation_generator)
y_valid_pred = (y_valid_pred_prob > 0.5).astype(int)
y_valid = validation_generator.classes
print("Classification Report:")
print(classification_report(y_valid, y_valid_pred))"""

y_pred_prob = new_model.predict(test_generator)
y_pred = (y_pred_prob > 0.5).astype(int)
y_test = test_generator.classes
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# 36/36 [==============================] - 4s 118ms/step - loss: 0.6198 - tp: 214.0000 - fp: 67.0000 - tn: 218.0000 - fn: 64.0000 - binary_acc: 0.7673 - precision: 0.7616 - recall: 0.7698 - f1_score: 0.7657 - roc_auc: 0.8294 - pr_auc: 0.8594 - cohen_kappa: 0.5346
# 36/36 [==============================] - 7s 106ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      0.76      0.77       285
#            1       0.76      0.77      0.77       278
#
#     accuracy                           0.77       563
#    macro avg       0.77      0.77      0.77       563
# weighted avg       0.77      0.77      0.77       563

# %%
conf_matrix = confusion_matrix(y_test, y_pred)

# Create ConfusionMatrixDisplay object
cm_display = ConfusionMatrixDisplay(confusion_matrix=conf_matrix)

# Plot the confusion matrix
plt.figure(figsize=(4, 6))  # Adjust the figure size as needed
cm_display.plot(cmap=plt.cm.Blues)  # You can choose any colormap you prefer
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.grid(False)  # Turn off grid
plt.savefig(save_path + model_name + "_confusion_matrix.jpg")
plt.show()

# %%
history_df = pd.DataFrame(history.history)
save_history(model_name, history_df)

new_model.save(save_path + model_name + "_pt_imagenet-{new_model.count_params()}.h5")
new_model.save(save_path + model_name + ".h5")
# Out:
# Training history saved to: C:/Users/raouf/Desktop/pfe/history/final/dense_res/XR_SHOULDER/DenseRes_XR_SHOULDER_history.xlsx
