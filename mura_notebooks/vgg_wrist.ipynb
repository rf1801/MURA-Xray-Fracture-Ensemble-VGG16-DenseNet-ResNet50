# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
import tensorflow as tf
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras import layers, models
from keras.layers import concatenate, Dense, Conv2D, MaxPooling2D, Flatten, Activation, BatchNormalization, Dropout, \
    Attention
from keras import *
from keras.applications import MobileNet
from keras.applications import VGG16
from keras.applications.resnet import ResNet50
from keras import backend as K
from keras.layers import Layer
import keras.layers as kl
import pandas as pd
from keras.applications import EfficientNetB0
import keras.applications
import numpy as np
import os
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from sklearn.metrics import cohen_kappa_score
import seaborn as sns
import pickle
import tensorflow_addons as tfa
from sklearn import metrics
from tensorflow.keras.applications.resnet import preprocess_input as preprocess_input_resnet
from tensorflow.keras.applications.densenet import preprocess_input as preprocess_input_densenet
from tensorflow.keras.models import load_model
import os
import glob
# Out:
# c:\Users\raouf\miniconda3\envs\tensorflowgpu\lib\site-packages\tensorflow_addons\utils\tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# c:\Users\raouf\miniconda3\envs\tensorflowgpu\lib\site-packages\tensorflow_addons\utils\ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.12.0 and strictly below 2.15.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.10.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %%
main_save_path = "C:/Users/raouf/Desktop/pfe/history/final/vgg/"
mura_location = "C:/Users/raouf/Desktop/pfe/"
data_path = 'C:/Users/raouf/Desktop/pfe/MURA-v1.1/'
train_path = 'C:/Users/raouf/Desktop/pfe/MURA-v1.1/train'
test_path = 'C:/Users/raouf/Desktop/pfe/MURA-v1.1/valid'

train_file = "C:/Users/raouf/Desktop/pfe/datasets/XR_WRIST_df_train.csv"
val_file = "C:/Users/raouf/Desktop/pfe/datasets/XR_WRIST_df_valid.csv"

test_file = "C:/Users/raouf/Desktop/pfe/MURA-v1.1/valid_image_paths.csv"

target_category = "XR_WRIST"
batch_size = 16
num_epochs = 100
fine_tuning_epochs=50
validation_split = 0.2
loss_function = tf.keras.losses.BinaryCrossentropy()
learning_rate = 0.0001
input_shape = (224, 224, 3)
architecture = 'VGG'

include_top = False
# metrics=["accuracy"] #, tf.keras.metrics.Precision(), tf.keras.metrics.Recall()
early_stopping_patience = 15
shuffle = True
class_mode = 'binary'  # 'categorical'
IMAGE_WIDTH = 224
IMAGE_HEIGHT = 224
trainable = False
training = False
dropout = 0.2

# %%
def load_data(file, part):
    train_data = pd.read_csv(file)
    train_data = train_data.rename(columns={train_data.columns[0]: 'image_path'})
    train_data['label'] = 2
    string_to_add = mura_location
    train_data['image_path'] = string_to_add + train_data['image_path'].astype(str)
    for index, row in train_data.iterrows():
        if 'positive' in str(row['image_path']).lower():
            train_data.at[index, 'label'] = "positive"
        else:
            train_data.at[index, 'label'] = "negative"

    if part == 0:
        pass
    else:
        train_data = train_data[train_data['image_path'].str.contains(part)]
    return train_data


class CustomCallback(keras.callbacks.Callback):
    def on_test_end(self, logs=None):
        keys = list(logs.keys())
        print(f"tp          :", logs["tp"])
        print(f"fp          :", logs["fp"])
        print(f"tn          :", logs["tn"])
        print(f"fn          :", logs["fn"])
        print(f"binary_acc  :", logs["binary_acc"])
        print(f"precision   :", logs["precision"])
        print(f"recall      :", logs["recall"])
        print(f"f1_score    :", logs["f1_score"])
        print(f"roc_auc     :", logs["roc_auc"])
        print(f"pr_auc      :", logs["pr_auc"])
        print(f"cohen_kappa :", logs["cohen_kappa"])

class F1Score(tf.keras.metrics.Metric):

    def __init__(self, name="f1_score", **kwargs):
        super().__init__(name=name, **kwargs)
        self.f1 = self.add_weight(name="f1", initializer="zeros")
        self.precision_fn = tf.keras.metrics.Precision()
        self.recall_fn = tf.keras.metrics.Recall()

    def update_state(self, y_true, y_pred, sample_weight=None):
        p = self.precision_fn(y_true, y_pred)
        r = self.recall_fn(y_true, y_pred)
        self.f1.assign(2 * ((p * r) / (p + r + 1e-10)))

    def result(self):
        return self.f1

    def reset_state(self):
        # we also need to reset the state of the precision and recall objects
        self.precision_fn.reset_state()
        self.recall_fn.reset_state()
        self.f1.assign(0)


def save_history(name,history_df):

    history_excel_path = (
            save_path +
            name +
            '_history'
            '.xlsx'
    )

    history_df.to_excel(history_excel_path, index=False)
    print("Training history saved to:", history_excel_path)






def plot_metrics(history: tf.keras.callbacks.History,
                 metrics: list = ["loss", "cohen_kappa", "precision", "recall"],
                 ) -> None:
    plt.rcParams["figure.figsize"] = (18, 15)

    for n, metric in enumerate(metrics):
        name = metric.replace("_", " ").capitalize()
        plt.subplot(2, 2, n + 1)
        plt.plot(
            history.epoch, history.history[metric], linewidth=1.8, label="training"
        )
        plt.plot(
            history.epoch,
            history.history["val_" + metric],
            linestyle="--",
            linewidth=1.8,
            label="validation",
        )
        plt.xlabel("epoch")
        plt.ylabel(name)
        if metric == "loss":
            plt.ylim([0, plt.ylim()[1]])
        elif metric == "cohen_kappa":
            plt.ylim([-1, 1])
        else:
            plt.ylim([0, 1])

        plt.legend()



class CustomCallback(keras.callbacks.Callback):
    def on_test_end(self, logs=None):
        keys = list(logs.keys())
        print(f"tp          :", logs["tp"])
        print(f"fp          :", logs["fp"])
        print(f"tn          :", logs["tn"])
        print(f"fn          :", logs["fn"])
        print(f"binary_acc  :", logs["binary_acc"])
        print(f"precision   :", logs["precision"])
        print(f"recall      :", logs["recall"])
        print(f"f1_score    :", logs["f1_score"])
        print(f"roc_auc     :", logs["roc_auc"])
        print(f"pr_auc      :", logs["pr_auc"])
        print(f"cohen_kappa :", logs["cohen_kappa"])


def save_history(name,history_df):

    # Constructing the file name with metric values
    history_excel_path = (
            save_path +
            name +
            '_history'
            '.xlsx'
    )

    history_df.to_excel(history_excel_path, index=False)
    print("Training history saved to:", history_excel_path)




class F1Score(tf.keras.metrics.Metric):

    def __init__(self, name="f1_score", **kwargs):
        super().__init__(name=name, **kwargs)
        self.f1 = self.add_weight(name="f1", initializer="zeros")
        self.precision_fn = tf.keras.metrics.Precision()
        self.recall_fn = tf.keras.metrics.Recall()

    def update_state(self, y_true, y_pred, sample_weight=None):
        p = self.precision_fn(y_true, y_pred)
        r = self.recall_fn(y_true, y_pred)
        self.f1.assign(2 * ((p * r) / (p + r + 1e-10)))

    def result(self):
        return self.f1

    def reset_state(self):
        # we also need to reset the state of the precision and recall objects
        self.precision_fn.reset_state()
        self.recall_fn.reset_state()
        self.f1.assign(0)

def plot_metrics(history: tf.keras.callbacks.History,
                 metrics: list = ["loss", "cohen_kappa", "precision", "recall"],
                 ) -> None:
    plt.rcParams["figure.figsize"] = (18, 15)

    for n, metric in enumerate(metrics):
        name = metric.replace("_", " ").capitalize()
        plt.subplot(2, 2, n + 1)
        plt.plot(
            history.epoch, history.history[metric], linewidth=1.8, label="training"
        )
        plt.plot(
            history.epoch,
            history.history["val_" + metric],
            linestyle="--",
            linewidth=1.8,
            label="validation",
        )
        plt.xlabel("epoch")
        plt.ylabel(name)
        if metric == "loss":
            plt.ylim([0, plt.ylim()[1]])
        elif metric == "cohen_kappa":
            plt.ylim([-1, 1])
        else:
            plt.ylim([0, 1])

        plt.legend()


def my_func(model, data_generator, threshold=0.5):
    y_pred_prob = model.predict(data_generator)
    y_pred = (y_pred_prob > threshold).astype(int)
    y_true = data_generator.classes
    print("Classification Report:")
    print(classification_report(y_true, y_pred))

# %%
METRICS = [
    tf.keras.metrics.TruePositives(name="tp"),
    tf.keras.metrics.FalsePositives(name="fp"),
    tf.keras.metrics.TrueNegatives(name="tn"),
    tf.keras.metrics.FalseNegatives(name="fn"),
    tf.keras.metrics.BinaryAccuracy(name="binary_acc"),
    tf.keras.metrics.Precision(name="precision"),
    tf.keras.metrics.Recall(name="recall"),
    F1Score(name="f1_score"),
    tf.keras.metrics.AUC(name="roc_auc", curve="ROC"),
    tf.keras.metrics.AUC(name="pr_auc", curve="PR"),
    tfa.metrics.CohenKappa(name="cohen_kappa", num_classes=2),
]

# %%
vgg = tf.keras.applications.vgg16.VGG16(include_top=include_top,
                                                 weights="imagenet",
                                                 input_shape=(IMAGE_WIDTH, IMAGE_HEIGHT, 3),
                                                # pooling="max",  # pooling mode for feature extraction
                                                 classes=2)

def make_vgg16_model(base_model: tf.keras.applications.vgg16.VGG16,) -> tf.keras.Model:

    # freeze base model
    base_model.trainable = False#trainable

    inputs = tf.keras.Input(shape=(IMAGE_WIDTH, IMAGE_HEIGHT, 3))
    x = base_model(inputs, training=training)
    x = tf.keras.layers.Flatten()(x)
    #x = tf.keras.layers.Dense(4096, activation='relu')(x)
    x = tf.keras.layers.Dense(1024, activation='relu')(x)
    x = tf.keras.layers.Dropout(rate=dropout)(x)
    x = tf.keras.layers.Dense(512, activation='relu')(x)
   # x = tf.keras.layers.Dropout(rate=dropout)(x)

    output = tf.keras.layers.Dense(units=1, activation="sigmoid")(x)

    model = tf.keras.Model(inputs, output)

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
        loss=loss_function,
        metrics=METRICS,
    )

    return model


new_model = make_vgg16_model(base_model=vgg)

new_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 1024)              25691136
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  dense_2 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 40,931,137
# Trainable params: 26,216,449
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
"""import matplotlib.pyplot as plt
from tensorflow.keras.utils import plot_model
tf.keras.utils.plot_model(new_model,
                          show_shapes=True,  # show_dtype=False,
                          show_layer_names=True,
                          layer_range=None,
                          show_layer_activations=True)"""
# Out:
# 'import matplotlib.pyplot as plt\nfrom tensorflow.keras.utils import plot_model\ntf.keras.utils.plot_model(new_model,\n                          show_shapes=True,  # show_dtype=False,\n                          show_layer_names=True,\n                          layer_range=None,\n                          show_layer_activations=True)'

# %%
early_stopping = EarlyStopping(monitor="val_cohen_kappa",
                               verbose=1,
                               patience=early_stopping_patience,
                               mode="max",
                               baseline=0.0,
                               restore_best_weights=True)
save_path = main_save_path + target_category + "/"
model_name = architecture + "_" + target_category
model_path = save_path + '_best_' + model_name + '.keras'
model_checkpoint = ModelCheckpoint(filepath=model_path,
                                       monitor="val_cohen_kappa",
                                       save_best_only=True)

# %%
import pandas as pd


old_base_path = 'C:\\Users\\HP\\Documents\\ML\\encadrement Master\\MURA-V1.1\\'

df_train = pd.read_csv(train_file)
df_train['image_path'] = df_train['image_path'].str.replace(old_base_path, mura_location)

df_valid = pd.read_csv(val_file)
df_valid['image_path'] = df_valid['image_path'].str.replace(old_base_path, mura_location)


df_test = load_data(test_file, target_category)

datagen = tf.keras.preprocessing.image.ImageDataGenerator(rotation_range=30,
                                                              horizontal_flip=True,
                                                              fill_mode="constant",
                                                              cval=0.0,
                                                              preprocessing_function=tf.keras.applications.vgg16.preprocess_input)
train_generator = datagen.flow_from_dataframe(df_train,
                                                  directory=None,
                                                  x_col='image_path',
                                                  y_col='label',
                                                  target_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
                                                  batch_size=batch_size,
                                                  class_mode=class_mode,
                                                  )

validation_generator = datagen.flow_from_dataframe(df_valid,
                                                       directory=None,
                                                       x_col='image_path',
                                                       y_col='label',
                                                       target_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
                                                       batch_size=batch_size,
                                                       class_mode=class_mode,
                                                   shuffle=False
                                                       )

test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
        preprocessing_function=tf.keras.applications.vgg16.preprocess_input)
test_generator = test_datagen.flow_from_dataframe(df_test,
                                                      directory=None,
                                                      x_col='image_path',
                                                      y_col='label',
                                                      target_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
                                                      batch_size=batch_size,
                                                      class_mode=class_mode,
                                                  shuffle=False
                                                      )
# Out:
# C:\Users\raouf\AppData\Local\Temp\ipykernel_31376\1983201427.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'positive' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_data.at[index, 'label'] = "positive"
# Found 7800 validated image filenames belonging to 2 classes.
# Found 1952 validated image filenames belonging to 2 classes.
# Found 658 validated image filenames belonging to 2 classes.

# %%
history = new_model.fit(train_generator,
                            # teps_per_epoch=len(df_train) // batch_size,
                            validation_data=validation_generator,
                            # validation_steps=len(df_valid) // batch_size,
                            epochs=num_epochs,
                            shuffle=shuffle,
                            callbacks=[early_stopping, model_checkpoint])  # , reduce_lr_callback])
# Out:
# Epoch 1/100
# 488/488 [==============================] - 90s 170ms/step - loss: 1.1165 - tp: 1832.0000 - fp: 1251.0000 - tn: 3382.0000 - fn: 1335.0000 - binary_acc: 0.6685 - precision: 0.5942 - recall: 0.5785 - f1_score: 0.5862 - roc_auc: 0.7086 - pr_auc: 0.6129 - cohen_kappa: 0.3097 - val_loss: 0.6256 - val_tp: 473.0000 - val_fp: 219.0000 - val_tn: 913.0000 - val_fn: 347.0000 - val_binary_acc: 0.7100 - val_precision: 0.6835 - val_recall: 0.5768 - val_f1_score: 0.6257 - val_roc_auc: 0.7755 - val_pr_auc: 0.7317 - val_cohen_kappa: 0.3918
# Epoch 2/100
# 488/488 [==============================] - 78s 160ms/step - loss: 0.6653 - tp: 1995.0000 - fp: 980.0000 - tn: 3653.0000 - fn: 1172.0000 - binary_acc: 0.7241 - precision: 0.6706 - recall: 0.6299 - f1_score: 0.6496 - roc_auc: 0.7769 - pr_auc: 0.7197 - cohen_kappa: 0.4225 - val_loss: 0.5189 - val_tp: 514.0000 - val_fp: 146.0000 - val_tn: 986.0000 - val_fn: 306.0000 - val_binary_acc: 0.7684 - val_precision: 0.7788 - val_recall: 0.6268 - val_f1_score: 0.6946 - val_roc_auc: 0.8288 - val_pr_auc: 0.8006 - val_cohen_kappa: 0.5116
# Epoch 3/100
# 488/488 [==============================] - 80s 164ms/step - loss: 0.5551 - tp: 2053.0000 - fp: 857.0000 - tn: 3776.0000 - fn: 1114.0000 - binary_acc: 0.7473 - precision: 0.7055 - recall: 0.6482 - f1_score: 0.6757 - roc_auc: 0.8147 - pr_auc: 0.7739 - cohen_kappa: 0.4693 - val_loss: 0.5659 - val_tp: 530.0000 - val_fp: 203.0000 - val_tn: 929.0000 - val_fn: 290.0000 - val_binary_acc: 0.7474 - val_precision: 0.7231 - val_recall: 0.6463 - val_f1_score: 0.6825 - val_roc_auc: 0.8143 - val_pr_auc: 0.7859 - val_cohen_kappa: 0.4739
# Epoch 4/100
# 488/488 [==============================] - 81s 165ms/step - loss: 0.5240 - tp: 2106.0000 - fp: 800.0000 - tn: 3833.0000 - fn: 1061.0000 - binary_acc: 0.7614 - precision: 0.7247 - recall: 0.6650 - f1_score: 0.6936 - roc_auc: 0.8326 - pr_auc: 0.7969 - cohen_kappa: 0.4988 - val_loss: 0.5443 - val_tp: 524.0000 - val_fp: 158.0000 - val_tn: 974.0000 - val_fn: 296.0000 - val_binary_acc: 0.7674 - val_precision: 0.7683 - val_recall: 0.6390 - val_f1_score: 0.6977 - val_roc_auc: 0.8348 - val_pr_auc: 0.8153 - val_cohen_kappa: 0.5113
# Epoch 5/100
# 488/488 [==============================] - 82s 168ms/step - loss: 0.5037 - tp: 2146.0000 - fp: 759.0000 - tn: 3874.0000 - fn: 1021.0000 - binary_acc: 0.7718 - precision: 0.7387 - recall: 0.6776 - f1_score: 0.7069 - roc_auc: 0.8403 - pr_auc: 0.8116 - cohen_kappa: 0.5206 - val_loss: 0.5270 - val_tp: 456.0000 - val_fp: 84.0000 - val_tn: 1048.0000 - val_fn: 364.0000 - val_binary_acc: 0.7705 - val_precision: 0.8444 - val_recall: 0.5561 - val_f1_score: 0.6706 - val_roc_auc: 0.8390 - val_pr_auc: 0.8212 - val_cohen_kappa: 0.5057
# Epoch 6/100
# 488/488 [==============================] - 81s 167ms/step - loss: 0.4806 - tp: 2170.0000 - fp: 679.0000 - tn: 3954.0000 - fn: 997.0000 - binary_acc: 0.7851 - precision: 0.7617 - recall: 0.6852 - f1_score: 0.7214 - roc_auc: 0.8536 - pr_auc: 0.8241 - cohen_kappa: 0.5473 - val_loss: 0.5446 - val_tp: 459.0000 - val_fp: 79.0000 - val_tn: 1053.0000 - val_fn: 361.0000 - val_binary_acc: 0.7746 - val_precision: 0.8532 - val_recall: 0.5598 - val_f1_score: 0.6760 - val_roc_auc: 0.8435 - val_pr_auc: 0.8186 - val_cohen_kappa: 0.5143
# Epoch 7/100
# 488/488 [==============================] - 81s 166ms/step - loss: 0.4621 - tp: 2197.0000 - fp: 635.0000 - tn: 3998.0000 - fn: 970.0000 - binary_acc: 0.7942 - precision: 0.7758 - recall: 0.6937 - f1_score: 0.7325 - roc_auc: 0.8625 - pr_auc: 0.8330 - cohen_kappa: 0.5661 - val_loss: 0.5099 - val_tp: 606.0000 - val_fp: 212.0000 - val_tn: 920.0000 - val_fn: 214.0000 - val_binary_acc: 0.7818 - val_precision: 0.7408 - val_recall: 0.7390 - val_f1_score: 0.7399 - val_roc_auc: 0.8468 - val_pr_auc: 0.8350 - val_cohen_kappa: 0.5519
# Epoch 8/100
# 488/488 [==============================] - 82s 168ms/step - loss: 0.4513 - tp: 2209.0000 - fp: 641.0000 - tn: 3992.0000 - fn: 958.0000 - binary_acc: 0.7950 - precision: 0.7751 - recall: 0.6975 - f1_score: 0.7343 - roc_auc: 0.8672 - pr_auc: 0.8424 - cohen_kappa: 0.5681 - val_loss: 0.4998 - val_tp: 506.0000 - val_fp: 89.0000 - val_tn: 1043.0000 - val_fn: 314.0000 - val_binary_acc: 0.7935 - val_precision: 0.8504 - val_recall: 0.6171 - val_f1_score: 0.7152 - val_roc_auc: 0.8469 - val_pr_auc: 0.8323 - val_cohen_kappa: 0.5596
# Epoch 9/100
# 488/488 [==============================] - 82s 168ms/step - loss: 0.4359 - tp: 2259.0000 - fp: 589.0000 - tn: 4044.0000 - fn: 908.0000 - binary_acc: 0.8081 - precision: 0.7932 - recall: 0.7133 - f1_score: 0.7511 - roc_auc: 0.8757 - pr_auc: 0.8547 - cohen_kappa: 0.5957 - val_loss: 0.5302 - val_tp: 673.0000 - val_fp: 306.0000 - val_tn: 826.0000 - val_fn: 147.0000 - val_binary_acc: 0.7679 - val_precision: 0.6874 - val_recall: 0.8207 - val_f1_score: 0.7482 - val_roc_auc: 0.8548 - val_pr_auc: 0.8348 - val_cohen_kappa: 0.5361
# Epoch 10/100
# 488/488 [==============================] - 83s 169ms/step - loss: 0.4101 - tp: 2340.0000 - fp: 571.0000 - tn: 4062.0000 - fn: 827.0000 - binary_acc: 0.8208 - precision: 0.8038 - recall: 0.7389 - f1_score: 0.7700 - roc_auc: 0.8878 - pr_auc: 0.8695 - cohen_kappa: 0.6236 - val_loss: 0.4748 - val_tp: 558.0000 - val_fp: 174.0000 - val_tn: 958.0000 - val_fn: 262.0000 - val_binary_acc: 0.7766 - val_precision: 0.7623 - val_recall: 0.6805 - val_f1_score: 0.7191 - val_roc_auc: 0.8526 - val_pr_auc: 0.8327 - val_cohen_kappa: 0.5347
# Epoch 11/100
# 488/488 [==============================] - 85s 174ms/step - loss: 0.4117 - tp: 2291.0000 - fp: 532.0000 - tn: 4101.0000 - fn: 876.0000 - binary_acc: 0.8195 - precision: 0.8115 - recall: 0.7234 - f1_score: 0.7649 - roc_auc: 0.8875 - pr_auc: 0.8670 - cohen_kappa: 0.6192 - val_loss: 0.4919 - val_tp: 511.0000 - val_fp: 121.0000 - val_tn: 1011.0000 - val_fn: 309.0000 - val_binary_acc: 0.7797 - val_precision: 0.8085 - val_recall: 0.6232 - val_f1_score: 0.7039 - val_roc_auc: 0.8557 - val_pr_auc: 0.8319 - val_cohen_kappa: 0.5331
# Epoch 12/100
# 488/488 [==============================] - 83s 170ms/step - loss: 0.3968 - tp: 2331.0000 - fp: 528.0000 - tn: 4105.0000 - fn: 836.0000 - binary_acc: 0.8251 - precision: 0.8153 - recall: 0.7360 - f1_score: 0.7736 - roc_auc: 0.8964 - pr_auc: 0.8772 - cohen_kappa: 0.6318 - val_loss: 0.5121 - val_tp: 621.0000 - val_fp: 228.0000 - val_tn: 904.0000 - val_fn: 199.0000 - val_binary_acc: 0.7812 - val_precision: 0.7314 - val_recall: 0.7573 - val_f1_score: 0.7442 - val_roc_auc: 0.8594 - val_pr_auc: 0.8448 - val_cohen_kappa: 0.5532
# Epoch 13/100
# 488/488 [==============================] - 83s 170ms/step - loss: 0.3854 - tp: 2359.0000 - fp: 542.0000 - tn: 4091.0000 - fn: 808.0000 - binary_acc: 0.8269 - precision: 0.8132 - recall: 0.7449 - f1_score: 0.7775 - roc_auc: 0.9022 - pr_auc: 0.8818 - cohen_kappa: 0.6363 - val_loss: 0.5224 - val_tp: 572.0000 - val_fp: 159.0000 - val_tn: 973.0000 - val_fn: 248.0000 - val_binary_acc: 0.7915 - val_precision: 0.7825 - val_recall: 0.6976 - val_f1_score: 0.7376 - val_roc_auc: 0.8514 - val_pr_auc: 0.8306 - val_cohen_kappa: 0.5656
# Epoch 14/100
# 488/488 [==============================] - 83s 170ms/step - loss: 0.3808 - tp: 2375.0000 - fp: 493.0000 - tn: 4140.0000 - fn: 792.0000 - binary_acc: 0.8353 - precision: 0.8281 - recall: 0.7499 - f1_score: 0.7871 - roc_auc: 0.9056 - pr_auc: 0.8873 - cohen_kappa: 0.6533 - val_loss: 0.5359 - val_tp: 556.0000 - val_fp: 149.0000 - val_tn: 983.0000 - val_fn: 264.0000 - val_binary_acc: 0.7884 - val_precision: 0.7887 - val_recall: 0.6780 - val_f1_score: 0.7292 - val_roc_auc: 0.8524 - val_pr_auc: 0.8270 - val_cohen_kappa: 0.5572
# Epoch 15/100
# 488/488 [==============================] - 83s 171ms/step - loss: 0.3644 - tp: 2414.0000 - fp: 483.0000 - tn: 4150.0000 - fn: 753.0000 - binary_acc: 0.8415 - precision: 0.8333 - recall: 0.7622 - f1_score: 0.7962 - roc_auc: 0.9115 - pr_auc: 0.8968 - cohen_kappa: 0.6670 - val_loss: 0.4808 - val_tp: 554.0000 - val_fp: 104.0000 - val_tn: 1028.0000 - val_fn: 266.0000 - val_binary_acc: 0.8105 - val_precision: 0.8419 - val_recall: 0.6756 - val_f1_score: 0.7497 - val_roc_auc: 0.8655 - val_pr_auc: 0.8513 - val_cohen_kappa: 0.6001
# Epoch 16/100
# 488/488 [==============================] - 83s 170ms/step - loss: 0.3521 - tp: 2435.0000 - fp: 467.0000 - tn: 4166.0000 - fn: 732.0000 - binary_acc: 0.8463 - precision: 0.8391 - recall: 0.7689 - f1_score: 0.8024 - roc_auc: 0.9178 - pr_auc: 0.9021 - cohen_kappa: 0.6770 - val_loss: 0.5576 - val_tp: 475.0000 - val_fp: 54.0000 - val_tn: 1078.0000 - val_fn: 345.0000 - val_binary_acc: 0.7956 - val_precision: 0.8979 - val_recall: 0.5793 - val_f1_score: 0.7042 - val_roc_auc: 0.8646 - val_pr_auc: 0.8551 - val_cohen_kappa: 0.5589
# Epoch 17/100
# 488/488 [==============================] - 84s 172ms/step - loss: 0.3451 - tp: 2448.0000 - fp: 442.0000 - tn: 4191.0000 - fn: 719.0000 - binary_acc: 0.8512 - precision: 0.8471 - recall: 0.7730 - f1_score: 0.8083 - roc_auc: 0.9217 - pr_auc: 0.9055 - cohen_kappa: 0.6871 - val_loss: 0.4707 - val_tp: 597.0000 - val_fp: 155.0000 - val_tn: 977.0000 - val_fn: 223.0000 - val_binary_acc: 0.8064 - val_precision: 0.7939 - val_recall: 0.7280 - val_f1_score: 0.7595 - val_roc_auc: 0.8722 - val_pr_auc: 0.8576 - val_cohen_kappa: 0.5980
# Epoch 18/100
# 488/488 [==============================] - 84s 171ms/step - loss: 0.3344 - tp: 2499.0000 - fp: 431.0000 - tn: 4202.0000 - fn: 668.0000 - binary_acc: 0.8591 - precision: 0.8529 - recall: 0.7891 - f1_score: 0.8197 - roc_auc: 0.9253 - pr_auc: 0.9115 - cohen_kappa: 0.7044 - val_loss: 0.5435 - val_tp: 565.0000 - val_fp: 158.0000 - val_tn: 974.0000 - val_fn: 255.0000 - val_binary_acc: 0.7884 - val_precision: 0.7815 - val_recall: 0.6890 - val_f1_score: 0.7323 - val_roc_auc: 0.8544 - val_pr_auc: 0.8315 - val_cohen_kappa: 0.5586
# Epoch 19/100
# 488/488 [==============================] - 83s 171ms/step - loss: 0.3287 - tp: 2499.0000 - fp: 432.0000 - tn: 4201.0000 - fn: 668.0000 - binary_acc: 0.8590 - precision: 0.8526 - recall: 0.7891 - f1_score: 0.8196 - roc_auc: 0.9284 - pr_auc: 0.9146 - cohen_kappa: 0.7041 - val_loss: 0.5216 - val_tp: 556.0000 - val_fp: 116.0000 - val_tn: 1016.0000 - val_fn: 264.0000 - val_binary_acc: 0.8053 - val_precision: 0.8274 - val_recall: 0.6780 - val_f1_score: 0.7453 - val_roc_auc: 0.8617 - val_pr_auc: 0.8437 - val_cohen_kappa: 0.5903
# Epoch 20/100
# 488/488 [==============================] - 83s 170ms/step - loss: 0.3215 - tp: 2510.0000 - fp: 441.0000 - tn: 4192.0000 - fn: 657.0000 - binary_acc: 0.8592 - precision: 0.8506 - recall: 0.7925 - f1_score: 0.8205 - roc_auc: 0.9319 - pr_auc: 0.9187 - cohen_kappa: 0.7050 - val_loss: 0.5345 - val_tp: 617.0000 - val_fp: 195.0000 - val_tn: 937.0000 - val_fn: 203.0000 - val_binary_acc: 0.7961 - val_precision: 0.7599 - val_recall: 0.7524 - val_f1_score: 0.7561 - val_roc_auc: 0.8646 - val_pr_auc: 0.8481 - val_cohen_kappa: 0.5810
# Epoch 21/100
# 488/488 [==============================] - 84s 172ms/step - loss: 0.3125 - tp: 2557.0000 - fp: 411.0000 - tn: 4222.0000 - fn: 610.0000 - binary_acc: 0.8691 - precision: 0.8615 - recall: 0.8074 - f1_score: 0.8336 - roc_auc: 0.9363 - pr_auc: 0.9225 - cohen_kappa: 0.7259 - val_loss: 0.5118 - val_tp: 566.0000 - val_fp: 122.0000 - val_tn: 1010.0000 - val_fn: 254.0000 - val_binary_acc: 0.8074 - val_precision: 0.8227 - val_recall: 0.6902 - val_f1_score: 0.7507 - val_roc_auc: 0.8668 - val_pr_auc: 0.8467 - val_cohen_kappa: 0.5957
# Epoch 22/100
# 488/488 [==============================] - 84s 173ms/step - loss: 0.3145 - tp: 2546.0000 - fp: 413.0000 - tn: 4220.0000 - fn: 621.0000 - binary_acc: 0.8674 - precision: 0.8604 - recall: 0.8039 - f1_score: 0.8312 - roc_auc: 0.9364 - pr_auc: 0.9223 - cohen_kappa: 0.7223 - val_loss: 0.5040 - val_tp: 517.0000 - val_fp: 93.0000 - val_tn: 1039.0000 - val_fn: 303.0000 - val_binary_acc: 0.7971 - val_precision: 0.8475 - val_recall: 0.6305 - val_f1_score: 0.7231 - val_roc_auc: 0.8755 - val_pr_auc: 0.8544 - val_cohen_kappa: 0.5684
# Epoch 23/100
# 488/488 [==============================] - 83s 171ms/step - loss: 0.2974 - tp: 2576.0000 - fp: 391.0000 - tn: 4242.0000 - fn: 591.0000 - binary_acc: 0.8741 - precision: 0.8682 - recall: 0.8134 - f1_score: 0.8399 - roc_auc: 0.9416 - pr_auc: 0.9306 - cohen_kappa: 0.7364 - val_loss: 0.5052 - val_tp: 584.0000 - val_fp: 139.0000 - val_tn: 993.0000 - val_fn: 236.0000 - val_binary_acc: 0.8079 - val_precision: 0.8077 - val_recall: 0.7122 - val_f1_score: 0.7570 - val_roc_auc: 0.8746 - val_pr_auc: 0.8530 - val_cohen_kappa: 0.5992
# Epoch 24/100
# 488/488 [==============================] - 84s 171ms/step - loss: 0.2862 - tp: 2612.0000 - fp: 388.0000 - tn: 4245.0000 - fn: 555.0000 - binary_acc: 0.8791 - precision: 0.8707 - recall: 0.8248 - f1_score: 0.8471 - roc_auc: 0.9459 - pr_auc: 0.9342 - cohen_kappa: 0.7472 - val_loss: 0.5035 - val_tp: 582.0000 - val_fp: 147.0000 - val_tn: 985.0000 - val_fn: 238.0000 - val_binary_acc: 0.8028 - val_precision: 0.7984 - val_recall: 0.7098 - val_f1_score: 0.7515 - val_roc_auc: 0.8702 - val_pr_auc: 0.8531 - val_cohen_kappa: 0.5889
# Epoch 25/100
# 488/488 [==============================] - 84s 172ms/step - loss: 0.2773 - tp: 2595.0000 - fp: 376.0000 - tn: 4257.0000 - fn: 572.0000 - binary_acc: 0.8785 - precision: 0.8734 - recall: 0.8194 - f1_score: 0.8456 - roc_auc: 0.9492 - pr_auc: 0.9381 - cohen_kappa: 0.7455 - val_loss: 0.5032 - val_tp: 620.0000 - val_fp: 192.0000 - val_tn: 940.0000 - val_fn: 200.0000 - val_binary_acc: 0.7992 - val_precision: 0.7635 - val_recall: 0.7561 - val_f1_score: 0.7598 - val_roc_auc: 0.8734 - val_pr_auc: 0.8506 - val_cohen_kappa: 0.5873
# Epoch 26/100
# 488/488 [==============================] - 84s 173ms/step - loss: 0.2721 - tp: 2647.0000 - fp: 354.0000 - tn: 4279.0000 - fn: 520.0000 - binary_acc: 0.8879 - precision: 0.8820 - recall: 0.8358 - f1_score: 0.8583 - roc_auc: 0.9527 - pr_auc: 0.9413 - cohen_kappa: 0.7657 - val_loss: 0.4948 - val_tp: 593.0000 - val_fp: 149.0000 - val_tn: 983.0000 - val_fn: 227.0000 - val_binary_acc: 0.8074 - val_precision: 0.7992 - val_recall: 0.7232 - val_f1_score: 0.7593 - val_roc_auc: 0.8814 - val_pr_auc: 0.8600 - val_cohen_kappa: 0.5994
# Epoch 27/100
# 488/488 [==============================] - 83s 169ms/step - loss: 0.2581 - tp: 2670.0000 - fp: 339.0000 - tn: 4294.0000 - fn: 497.0000 - binary_acc: 0.8928 - precision: 0.8873 - recall: 0.8431 - f1_score: 0.8646 - roc_auc: 0.9562 - pr_auc: 0.9458 - cohen_kappa: 0.7760 - val_loss: 0.5072 - val_tp: 555.0000 - val_fp: 129.0000 - val_tn: 1003.0000 - val_fn: 265.0000 - val_binary_acc: 0.7982 - val_precision: 0.8114 - val_recall: 0.6768 - val_f1_score: 0.7380 - val_roc_auc: 0.8632 - val_pr_auc: 0.8466 - val_cohen_kappa: 0.5760
# Epoch 28/100
# 488/488 [==============================] - 83s 170ms/step - loss: 0.2567 - tp: 2647.0000 - fp: 310.0000 - tn: 4323.0000 - fn: 520.0000 - binary_acc: 0.8936 - precision: 0.8952 - recall: 0.8358 - f1_score: 0.8645 - roc_auc: 0.9565 - pr_auc: 0.9468 - cohen_kappa: 0.7770 - val_loss: 0.5376 - val_tp: 578.0000 - val_fp: 135.0000 - val_tn: 997.0000 - val_fn: 242.0000 - val_binary_acc: 0.8069 - val_precision: 0.8107 - val_recall: 0.7049 - val_f1_score: 0.7541 - val_roc_auc: 0.8745 - val_pr_auc: 0.8584 - val_cohen_kappa: 0.5963
# Epoch 29/100
# 488/488 [==============================] - 83s 171ms/step - loss: 0.2510 - tp: 2675.0000 - fp: 313.0000 - tn: 4320.0000 - fn: 492.0000 - binary_acc: 0.8968 - precision: 0.8952 - recall: 0.8446 - f1_score: 0.8692 - roc_auc: 0.9584 - pr_auc: 0.9486 - cohen_kappa: 0.7841 - val_loss: 0.5510 - val_tp: 544.0000 - val_fp: 80.0000 - val_tn: 1052.0000 - val_fn: 276.0000 - val_binary_acc: 0.8176 - val_precision: 0.8718 - val_recall: 0.6634 - val_f1_score: 0.7535 - val_roc_auc: 0.8791 - val_pr_auc: 0.8680 - val_cohen_kappa: 0.6129
# Epoch 30/100
# 488/488 [==============================] - 83s 170ms/step - loss: 0.2486 - tp: 2678.0000 - fp: 322.0000 - tn: 4311.0000 - fn: 489.0000 - binary_acc: 0.8960 - precision: 0.8927 - recall: 0.8456 - f1_score: 0.8685 - roc_auc: 0.9592 - pr_auc: 0.9501 - cohen_kappa: 0.7826 - val_loss: 0.5030 - val_tp: 620.0000 - val_fp: 146.0000 - val_tn: 986.0000 - val_fn: 200.0000 - val_binary_acc: 0.8227 - val_precision: 0.8094 - val_recall: 0.7561 - val_f1_score: 0.7818 - val_roc_auc: 0.8772 - val_pr_auc: 0.8607 - val_cohen_kappa: 0.6329
# Epoch 31/100
# 488/488 [==============================] - 84s 171ms/step - loss: 0.2391 - tp: 2711.0000 - fp: 310.0000 - tn: 4323.0000 - fn: 456.0000 - binary_acc: 0.9018 - precision: 0.8974 - recall: 0.8560 - f1_score: 0.8762 - roc_auc: 0.9626 - pr_auc: 0.9546 - cohen_kappa: 0.7949 - val_loss: 0.5577 - val_tp: 561.0000 - val_fp: 120.0000 - val_tn: 1012.0000 - val_fn: 259.0000 - val_binary_acc: 0.8058 - val_precision: 0.8238 - val_recall: 0.6841 - val_f1_score: 0.7475 - val_roc_auc: 0.8662 - val_pr_auc: 0.8527 - val_cohen_kappa: 0.5920
# Epoch 32/100
# 488/488 [==============================] - 82s 169ms/step - loss: 0.2390 - tp: 2706.0000 - fp: 300.0000 - tn: 4333.0000 - fn: 461.0000 - binary_acc: 0.9024 - precision: 0.9002 - recall: 0.8544 - f1_score: 0.8767 - roc_auc: 0.9628 - pr_auc: 0.9544 - cohen_kappa: 0.7961 - val_loss: 0.5641 - val_tp: 600.0000 - val_fp: 181.0000 - val_tn: 951.0000 - val_fn: 220.0000 - val_binary_acc: 0.7946 - val_precision: 0.7682 - val_recall: 0.7317 - val_f1_score: 0.7495 - val_roc_auc: 0.8640 - val_pr_auc: 0.8336 - val_cohen_kappa: 0.5756
# Epoch 33/100
# 488/488 [==============================] - 82s 168ms/step - loss: 0.2168 - tp: 2758.0000 - fp: 284.0000 - tn: 4349.0000 - fn: 409.0000 - binary_acc: 0.9112 - precision: 0.9066 - recall: 0.8709 - f1_score: 0.8884 - roc_auc: 0.9694 - pr_auc: 0.9606 - cohen_kappa: 0.8146 - val_loss: 0.5748 - val_tp: 568.0000 - val_fp: 109.0000 - val_tn: 1023.0000 - val_fn: 252.0000 - val_binary_acc: 0.8151 - val_precision: 0.8390 - val_recall: 0.6927 - val_f1_score: 0.7589 - val_roc_auc: 0.8805 - val_pr_auc: 0.8585 - val_cohen_kappa: 0.6111
# Epoch 34/100
# 488/488 [==============================] - 83s 170ms/step - loss: 0.2259 - tp: 2752.0000 - fp: 293.0000 - tn: 4340.0000 - fn: 415.0000 - binary_acc: 0.9092 - precision: 0.9038 - recall: 0.8690 - f1_score: 0.8860 - roc_auc: 0.9665 - pr_auc: 0.9580 - cohen_kappa: 0.8107 - val_loss: 0.5796 - val_tp: 589.0000 - val_fp: 144.0000 - val_tn: 988.0000 - val_fn: 231.0000 - val_binary_acc: 0.8079 - val_precision: 0.8035 - val_recall: 0.7183 - val_f1_score: 0.7585 - val_roc_auc: 0.8781 - val_pr_auc: 0.8569 - val_cohen_kappa: 0.5999
# Epoch 35/100
# 488/488 [==============================] - 82s 169ms/step - loss: 0.2163 - tp: 2755.0000 - fp: 278.0000 - tn: 4355.0000 - fn: 412.0000 - binary_acc: 0.9115 - precision: 0.9083 - recall: 0.8699 - f1_score: 0.8887 - roc_auc: 0.9695 - pr_auc: 0.9603 - cohen_kappa: 0.8154 - val_loss: 0.5594 - val_tp: 590.0000 - val_fp: 122.0000 - val_tn: 1010.0000 - val_fn: 230.0000 - val_binary_acc: 0.8197 - val_precision: 0.8287 - val_recall: 0.7195 - val_f1_score: 0.7702 - val_roc_auc: 0.8807 - val_pr_auc: 0.8575 - val_cohen_kappa: 0.6230
# Epoch 36/100
# 488/488 [==============================] - 83s 170ms/step - loss: 0.2016 - tp: 2778.0000 - fp: 274.0000 - tn: 4359.0000 - fn: 389.0000 - binary_acc: 0.9150 - precision: 0.9102 - recall: 0.8772 - f1_score: 0.8934 - roc_auc: 0.9737 - pr_auc: 0.9655 - cohen_kappa: 0.8228 - val_loss: 0.5927 - val_tp: 593.0000 - val_fp: 158.0000 - val_tn: 974.0000 - val_fn: 227.0000 - val_binary_acc: 0.8028 - val_precision: 0.7896 - val_recall: 0.7232 - val_f1_score: 0.7549 - val_roc_auc: 0.8725 - val_pr_auc: 0.8413 - val_cohen_kappa: 0.5904
# Epoch 37/100
# 488/488 [==============================] - 82s 168ms/step - loss: 0.2087 - tp: 2769.0000 - fp: 285.0000 - tn: 4348.0000 - fn: 398.0000 - binary_acc: 0.9124 - precision: 0.9067 - recall: 0.8743 - f1_score: 0.8902 - roc_auc: 0.9718 - pr_auc: 0.9635 - cohen_kappa: 0.8174 - val_loss: 0.5477 - val_tp: 627.0000 - val_fp: 167.0000 - val_tn: 965.0000 - val_fn: 193.0000 - val_binary_acc: 0.8156 - val_precision: 0.7897 - val_recall: 0.7646 - val_f1_score: 0.7770 - val_roc_auc: 0.8774 - val_pr_auc: 0.8545 - val_cohen_kappa: 0.6198
# Epoch 38/100
# 488/488 [==============================] - 83s 170ms/step - loss: 0.1951 - tp: 2809.0000 - fp: 267.0000 - tn: 4366.0000 - fn: 358.0000 - binary_acc: 0.9199 - precision: 0.9132 - recall: 0.8870 - f1_score: 0.8999 - roc_auc: 0.9743 - pr_auc: 0.9686 - cohen_kappa: 0.8331 - val_loss: 0.5847 - val_tp: 574.0000 - val_fp: 126.0000 - val_tn: 1006.0000 - val_fn: 246.0000 - val_binary_acc: 0.8094 - val_precision: 0.8200 - val_recall: 0.7000 - val_f1_score: 0.7553 - val_roc_auc: 0.8763 - val_pr_auc: 0.8509 - val_cohen_kappa: 0.6008
# Epoch 39/100
# 488/488 [==============================] - 83s 171ms/step - loss: 0.1905 - tp: 2830.0000 - fp: 245.0000 - tn: 4388.0000 - fn: 337.0000 - binary_acc: 0.9254 - precision: 0.9203 - recall: 0.8936 - f1_score: 0.9068 - roc_auc: 0.9766 - pr_auc: 0.9687 - cohen_kappa: 0.8446 - val_loss: 0.5850 - val_tp: 607.0000 - val_fp: 162.0000 - val_tn: 970.0000 - val_fn: 213.0000 - val_binary_acc: 0.8079 - val_precision: 0.7893 - val_recall: 0.7402 - val_f1_score: 0.7640 - val_roc_auc: 0.8760 - val_pr_auc: 0.8503 - val_cohen_kappa: 0.6023
# Epoch 40/100
# 488/488 [==============================] - 84s 173ms/step - loss: 0.1849 - tp: 2829.0000 - fp: 252.0000 - tn: 4381.0000 - fn: 338.0000 - binary_acc: 0.9244 - precision: 0.9182 - recall: 0.8933 - f1_score: 0.9056 - roc_auc: 0.9773 - pr_auc: 0.9713 - cohen_kappa: 0.8425 - val_loss: 0.6276 - val_tp: 628.0000 - val_fp: 189.0000 - val_tn: 943.0000 - val_fn: 192.0000 - val_binary_acc: 0.8048 - val_precision: 0.7687 - val_recall: 0.7659 - val_f1_score: 0.7673 - val_roc_auc: 0.8750 - val_pr_auc: 0.8525 - val_cohen_kappa: 0.5992
# Epoch 41/100
# 488/488 [==============================] - 85s 174ms/step - loss: 0.1800 - tp: 2834.0000 - fp: 247.0000 - tn: 4386.0000 - fn: 333.0000 - binary_acc: 0.9256 - precision: 0.9198 - recall: 0.8949 - f1_score: 0.9072 - roc_auc: 0.9787 - pr_auc: 0.9731 - cohen_kappa: 0.8452 - val_loss: 0.6258 - val_tp: 611.0000 - val_fp: 161.0000 - val_tn: 971.0000 - val_fn: 209.0000 - val_binary_acc: 0.8105 - val_precision: 0.7915 - val_recall: 0.7451 - val_f1_score: 0.7676 - val_roc_auc: 0.8774 - val_pr_auc: 0.8471 - val_cohen_kappa: 0.6078
# Epoch 42/100
# 488/488 [==============================] - 84s 172ms/step - loss: 0.1768 - tp: 2838.0000 - fp: 222.0000 - tn: 4411.0000 - fn: 329.0000 - binary_acc: 0.9294 - precision: 0.9275 - recall: 0.8961 - f1_score: 0.9115 - roc_auc: 0.9792 - pr_auc: 0.9736 - cohen_kappa: 0.8528 - val_loss: 0.6108 - val_tp: 622.0000 - val_fp: 175.0000 - val_tn: 957.0000 - val_fn: 198.0000 - val_binary_acc: 0.8089 - val_precision: 0.7804 - val_recall: 0.7585 - val_f1_score: 0.7693 - val_roc_auc: 0.8742 - val_pr_auc: 0.8489 - val_cohen_kappa: 0.6063
# Epoch 43/100
# 488/488 [==============================] - 87s 179ms/step - loss: 0.1853 - tp: 2837.0000 - fp: 239.0000 - tn: 4394.0000 - fn: 330.0000 - binary_acc: 0.9271 - precision: 0.9223 - recall: 0.8958 - f1_score: 0.9089 - roc_auc: 0.9773 - pr_auc: 0.9714 - cohen_kappa: 0.8481 - val_loss: 0.6029 - val_tp: 583.0000 - val_fp: 118.0000 - val_tn: 1014.0000 - val_fn: 237.0000 - val_binary_acc: 0.8181 - val_precision: 0.8317 - val_recall: 0.7110 - val_f1_score: 0.7666 - val_roc_auc: 0.8752 - val_pr_auc: 0.8532 - val_cohen_kappa: 0.6191
# Epoch 44/100
# 488/488 [==============================] - 91s 186ms/step - loss: 0.1724 - tp: 2850.0000 - fp: 236.0000 - tn: 4397.0000 - fn: 317.0000 - binary_acc: 0.9291 - precision: 0.9235 - recall: 0.8999 - f1_score: 0.9116 - roc_auc: 0.9806 - pr_auc: 0.9751 - cohen_kappa: 0.8524 - val_loss: 0.5837 - val_tp: 581.0000 - val_fp: 110.0000 - val_tn: 1022.0000 - val_fn: 239.0000 - val_binary_acc: 0.8212 - val_precision: 0.8408 - val_recall: 0.7085 - val_f1_score: 0.7690 - val_roc_auc: 0.8810 - val_pr_auc: 0.8599 - val_cohen_kappa: 0.6249
# Epoch 45/100
# 488/488 [==============================] - ETA: 0s - loss: 0.1646 - tp: 2859.0000 - fp: 200.0000 - tn: 4433.0000 - fn: 308.0000 - binary_acc: 0.9349 - precision: 0.9346 - recall: 0.9027 - f1_score: 0.9184 - roc_auc: 0.9821 - pr_auc: 0.9772 - cohen_kappa: 0.8642Restoring model weights from the end of the best epoch: 30.
# 488/488 [==============================] - 89s 181ms/step - loss: 0.1646 - tp: 2859.0000 - fp: 200.0000 - tn: 4433.0000 - fn: 308.0000 - binary_acc: 0.9349 - precision: 0.9346 - recall: 0.9027 - f1_score: 0.9184 - roc_auc: 0.9821 - pr_auc: 0.9772 - cohen_kappa: 0.8642 - val_loss: 0.6011 - val_tp: 578.0000 - val_fp: 127.0000 - val_tn: 1005.0000 - val_fn: 242.0000 - val_binary_acc: 0.8110 - val_precision: 0.8199 - val_recall: 0.7049 - val_f1_score: 0.7580 - val_roc_auc: 0.8790 - val_pr_auc: 0.8567 - val_cohen_kappa: 0.6044
# Epoch 45: early stopping

# %%
new_model.save(save_path + model_name + '.keras')

plot_metrics(history)

# %%
new_model.evaluate(validation_generator)
new_model.evaluate(test_generator)

    # Make predictions using the validation generator
y_valid_pred_prob = new_model.predict(validation_generator)
y_valid_pred = (y_valid_pred_prob > 0.5).astype(int)
y_valid = validation_generator.classes
print("Classification Report:")
print(classification_report(y_valid, y_valid_pred))

y_pred_prob = new_model.predict(test_generator)
y_pred = (y_pred_prob > 0.5).astype(int)
y_test = test_generator.classes
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# 122/122 [==============================] - 17s 141ms/step - loss: 0.5047 - tp: 626.0000 - fp: 166.0000 - tn: 966.0000 - fn: 194.0000 - binary_acc: 0.8156 - precision: 0.7904 - recall: 0.7634 - f1_score: 0.7767 - roc_auc: 0.8774 - pr_auc: 0.8584 - cohen_kappa: 0.6197
# 42/42 [==============================] - 3s 78ms/step - loss: 0.6755 - tp: 196.0000 - fp: 44.0000 - tn: 320.0000 - fn: 98.0000 - binary_acc: 0.7842 - precision: 0.8167 - recall: 0.6667 - f1_score: 0.7341 - roc_auc: 0.8520 - pr_auc: 0.8529 - cohen_kappa: 0.5556
# 122/122 [==============================] - 17s 139ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.85      0.84      1132
#            1       0.78      0.75      0.77       820
#
#     accuracy                           0.81      1952
#    macro avg       0.80      0.80      0.80      1952
# weighted avg       0.81      0.81      0.81      1952
#
# 42/42 [==============================] - 2s 46ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      0.88      0.82       364
#            1       0.82      0.67      0.73       294
#
#     accuracy                           0.78       658
#    macro avg       0.79      0.77      0.78       658
# weighted avg       0.79      0.78      0.78       658

# %%
conf_matrix = confusion_matrix(y_test, y_pred)

# Create ConfusionMatrixDisplay object
cm_display = ConfusionMatrixDisplay(confusion_matrix=conf_matrix)

# Plot the confusion matrix
plt.figure(figsize=(4, 6))  # Adjust the figure size as needed
cm_display.plot(cmap=plt.cm.Blues)  # You can choose any colormap you prefer
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.grid(False)  # Turn off grid
plt.savefig(save_path + model_name + "_confusion_matrix.jpg")
plt.show()

# %%
history_df = pd.DataFrame(history.history)
save_history(model_name, history_df)

new_model.save(save_path + model_name + "_pt_imagenet-{new_model.count_params()}.h5")
vgg.save(save_path + model_name + ".h5")

vgg.trainable = True

new_model.compile(
        optimizer=tf.keras.optimizers.Adam(
            1e-5
        ),  # we need small learning rate to avoid catastrophic forgetting
        loss=tf.keras.losses.BinaryCrossentropy(),
        metrics=METRICS,
    )

model_name = 'finetuned_' + architecture + "_" + target_category

model_path = save_path + '_best_' + model_name + '.keras'
model_checkpoint = ModelCheckpoint(filepath=model_path,
                                       monitor="val_cohen_kappa",
                                       save_best_only=True)

reduce_lr_on_plateau = tf.keras.callbacks.ReduceLROnPlateau(
        monitor="val_cohen_kappa",
        verbose=1,
        patience=4,
        mode="max",
        factor=0.2,
        min_lr=1e-10,
    )
# Out:
# Training history saved to: C:/Users/raouf/Desktop/pfe/history/final/vgg/XR_WRIST/VGG_XR_WRIST_history.xlsx
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
history = new_model.fit(train_generator,
                            # steps_per_epoch=len(df_train) // batch_size,
                            validation_data=validation_generator,
                            # validation_steps=len(df_valid) // batch_size,
                            epochs=fine_tuning_epochs,
                            shuffle=shuffle,
                            callbacks=[early_stopping, model_checkpoint, reduce_lr_on_plateau])
# Out:
# Epoch 1/50
# 488/488 [==============================] - 134s 256ms/step - loss: 0.2738 - tp: 2783.0000 - fp: 370.0000 - tn: 4627.0000 - fn: 678.0000 - binary_acc: 0.8761 - precision: 0.8827 - recall: 0.8041 - f1_score: 0.8415 - roc_auc: 0.9421 - pr_auc: 0.9297 - cohen_kappa: 0.7402 - val_loss: 0.5676 - val_tp: 531.0000 - val_fp: 85.0000 - val_tn: 1047.0000 - val_fn: 289.0000 - val_binary_acc: 0.8084 - val_precision: 0.8620 - val_recall: 0.6476 - val_f1_score: 0.7396 - val_roc_auc: 0.8714 - val_pr_auc: 0.8541 - val_cohen_kappa: 0.5928 - lr: 1.0000e-05
# Epoch 2/50
# 488/488 [==============================] - 118s 241ms/step - loss: 0.2533 - tp: 2626.0000 - fp: 291.0000 - tn: 4342.0000 - fn: 541.0000 - binary_acc: 0.8933 - precision: 0.9002 - recall: 0.8292 - f1_score: 0.8632 - roc_auc: 0.9581 - pr_auc: 0.9484 - cohen_kappa: 0.7761 - val_loss: 0.5204 - val_tp: 628.0000 - val_fp: 163.0000 - val_tn: 969.0000 - val_fn: 192.0000 - val_binary_acc: 0.8181 - val_precision: 0.7939 - val_recall: 0.7659 - val_f1_score: 0.7796 - val_roc_auc: 0.8826 - val_pr_auc: 0.8659 - val_cohen_kappa: 0.6249 - lr: 1.0000e-05
# Epoch 3/50
# 488/488 [==============================] - 117s 240ms/step - loss: 0.2365 - tp: 2664.0000 - fp: 270.0000 - tn: 4363.0000 - fn: 503.0000 - binary_acc: 0.9009 - precision: 0.9080 - recall: 0.8412 - f1_score: 0.8733 - roc_auc: 0.9631 - pr_auc: 0.9544 - cohen_kappa: 0.7921 - val_loss: 0.4571 - val_tp: 594.0000 - val_fp: 122.0000 - val_tn: 1010.0000 - val_fn: 226.0000 - val_binary_acc: 0.8217 - val_precision: 0.8296 - val_recall: 0.7244 - val_f1_score: 0.7734 - val_roc_auc: 0.8857 - val_pr_auc: 0.8766 - val_cohen_kappa: 0.6276 - lr: 1.0000e-05
# Epoch 4/50
# 488/488 [==============================] - 117s 240ms/step - loss: 0.2316 - tp: 2660.0000 - fp: 283.0000 - tn: 4350.0000 - fn: 507.0000 - binary_acc: 0.8987 - precision: 0.9038 - recall: 0.8399 - f1_score: 0.8707 - roc_auc: 0.9651 - pr_auc: 0.9550 - cohen_kappa: 0.7876 - val_loss: 0.5876 - val_tp: 569.0000 - val_fp: 91.0000 - val_tn: 1041.0000 - val_fn: 251.0000 - val_binary_acc: 0.8248 - val_precision: 0.8621 - val_recall: 0.6939 - val_f1_score: 0.7689 - val_roc_auc: 0.8784 - val_pr_auc: 0.8685 - val_cohen_kappa: 0.6305 - lr: 1.0000e-05
# Epoch 5/50
# 488/488 [==============================] - 120s 245ms/step - loss: 0.2197 - tp: 2706.0000 - fp: 246.0000 - tn: 4387.0000 - fn: 461.0000 - binary_acc: 0.9094 - precision: 0.9167 - recall: 0.8544 - f1_score: 0.8845 - roc_auc: 0.9680 - pr_auc: 0.9602 - cohen_kappa: 0.8100 - val_loss: 0.5668 - val_tp: 624.0000 - val_fp: 134.0000 - val_tn: 998.0000 - val_fn: 196.0000 - val_binary_acc: 0.8309 - val_precision: 0.8232 - val_recall: 0.7610 - val_f1_score: 0.7909 - val_roc_auc: 0.8884 - val_pr_auc: 0.8762 - val_cohen_kappa: 0.6494 - lr: 1.0000e-05
# Epoch 6/50
# 488/488 [==============================] - 119s 244ms/step - loss: 0.2028 - tp: 2770.0000 - fp: 235.0000 - tn: 4398.0000 - fn: 397.0000 - binary_acc: 0.9190 - precision: 0.9218 - recall: 0.8746 - f1_score: 0.8976 - roc_auc: 0.9728 - pr_auc: 0.9664 - cohen_kappa: 0.8306 - val_loss: 0.4859 - val_tp: 614.0000 - val_fp: 151.0000 - val_tn: 981.0000 - val_fn: 206.0000 - val_binary_acc: 0.8171 - val_precision: 0.8026 - val_recall: 0.7488 - val_f1_score: 0.7748 - val_roc_auc: 0.8851 - val_pr_auc: 0.8680 - val_cohen_kappa: 0.6211 - lr: 1.0000e-05
# Epoch 7/50
# 488/488 [==============================] - 118s 242ms/step - loss: 0.1964 - tp: 2777.0000 - fp: 234.0000 - tn: 4399.0000 - fn: 390.0000 - binary_acc: 0.9200 - precision: 0.9223 - recall: 0.8769 - f1_score: 0.8990 - roc_auc: 0.9744 - pr_auc: 0.9684 - cohen_kappa: 0.8328 - val_loss: 0.5169 - val_tp: 642.0000 - val_fp: 194.0000 - val_tn: 938.0000 - val_fn: 178.0000 - val_binary_acc: 0.8094 - val_precision: 0.7679 - val_recall: 0.7829 - val_f1_score: 0.7754 - val_roc_auc: 0.8793 - val_pr_auc: 0.8656 - val_cohen_kappa: 0.6099 - lr: 1.0000e-05
# Epoch 8/50
# 488/488 [==============================] - 119s 244ms/step - loss: 0.1838 - tp: 2782.0000 - fp: 215.0000 - tn: 4418.0000 - fn: 385.0000 - binary_acc: 0.9231 - precision: 0.9283 - recall: 0.8784 - f1_score: 0.9027 - roc_auc: 0.9770 - pr_auc: 0.9717 - cohen_kappa: 0.8392 - val_loss: 0.6232 - val_tp: 700.0000 - val_fp: 295.0000 - val_tn: 837.0000 - val_fn: 120.0000 - val_binary_acc: 0.7874 - val_precision: 0.7035 - val_recall: 0.8537 - val_f1_score: 0.7713 - val_roc_auc: 0.8912 - val_pr_auc: 0.8677 - val_cohen_kappa: 0.5761 - lr: 1.0000e-05
# Epoch 9/50
# 488/488 [==============================] - 117s 239ms/step - loss: 0.1836 - tp: 2794.0000 - fp: 208.0000 - tn: 4425.0000 - fn: 373.0000 - binary_acc: 0.9255 - precision: 0.9307 - recall: 0.8822 - f1_score: 0.9058 - roc_auc: 0.9774 - pr_auc: 0.9719 - cohen_kappa: 0.8443 - val_loss: 0.5113 - val_tp: 591.0000 - val_fp: 86.0000 - val_tn: 1046.0000 - val_fn: 229.0000 - val_binary_acc: 0.8386 - val_precision: 0.8730 - val_recall: 0.7207 - val_f1_score: 0.7896 - val_roc_auc: 0.8917 - val_pr_auc: 0.8814 - val_cohen_kappa: 0.6606 - lr: 1.0000e-05
# Epoch 10/50
# 488/488 [==============================] - 116s 238ms/step - loss: 0.1738 - tp: 2819.0000 - fp: 202.0000 - tn: 4431.0000 - fn: 348.0000 - binary_acc: 0.9295 - precision: 0.9331 - recall: 0.8901 - f1_score: 0.9111 - roc_auc: 0.9798 - pr_auc: 0.9751 - cohen_kappa: 0.8527 - val_loss: 0.5440 - val_tp: 634.0000 - val_fp: 151.0000 - val_tn: 981.0000 - val_fn: 186.0000 - val_binary_acc: 0.8274 - val_precision: 0.8076 - val_recall: 0.7732 - val_f1_score: 0.7900 - val_roc_auc: 0.8828 - val_pr_auc: 0.8696 - val_cohen_kappa: 0.6436 - lr: 1.0000e-05
# Epoch 11/50
# 488/488 [==============================] - 117s 239ms/step - loss: 0.1656 - tp: 2822.0000 - fp: 185.0000 - tn: 4448.0000 - fn: 345.0000 - binary_acc: 0.9321 - precision: 0.9385 - recall: 0.8911 - f1_score: 0.9142 - roc_auc: 0.9811 - pr_auc: 0.9764 - cohen_kappa: 0.8580 - val_loss: 0.5173 - val_tp: 651.0000 - val_fp: 141.0000 - val_tn: 991.0000 - val_fn: 169.0000 - val_binary_acc: 0.8412 - val_precision: 0.8220 - val_recall: 0.7939 - val_f1_score: 0.8077 - val_roc_auc: 0.8963 - val_pr_auc: 0.8757 - val_cohen_kappa: 0.6725 - lr: 1.0000e-05
# Epoch 12/50
# 488/488 [==============================] - 117s 239ms/step - loss: 0.1455 - tp: 2893.0000 - fp: 170.0000 - tn: 4463.0000 - fn: 274.0000 - binary_acc: 0.9431 - precision: 0.9445 - recall: 0.9135 - f1_score: 0.9287 - roc_auc: 0.9861 - pr_auc: 0.9818 - cohen_kappa: 0.8814 - val_loss: 0.5249 - val_tp: 611.0000 - val_fp: 106.0000 - val_tn: 1026.0000 - val_fn: 209.0000 - val_binary_acc: 0.8386 - val_precision: 0.8522 - val_recall: 0.7451 - val_f1_score: 0.7951 - val_roc_auc: 0.8983 - val_pr_auc: 0.8874 - val_cohen_kappa: 0.6630 - lr: 1.0000e-05
# Epoch 13/50
# 488/488 [==============================] - 116s 238ms/step - loss: 0.1511 - tp: 2866.0000 - fp: 168.0000 - tn: 4465.0000 - fn: 301.0000 - binary_acc: 0.9399 - precision: 0.9446 - recall: 0.9050 - f1_score: 0.9244 - roc_auc: 0.9843 - pr_auc: 0.9800 - cohen_kappa: 0.8745 - val_loss: 0.5326 - val_tp: 609.0000 - val_fp: 152.0000 - val_tn: 980.0000 - val_fn: 211.0000 - val_binary_acc: 0.8140 - val_precision: 0.8003 - val_recall: 0.7427 - val_f1_score: 0.7704 - val_roc_auc: 0.8791 - val_pr_auc: 0.8711 - val_cohen_kappa: 0.6145 - lr: 1.0000e-05
# Epoch 14/50
# 488/488 [==============================] - 116s 238ms/step - loss: 0.1453 - tp: 2882.0000 - fp: 178.0000 - tn: 4455.0000 - fn: 285.0000 - binary_acc: 0.9406 - precision: 0.9418 - recall: 0.9100 - f1_score: 0.9256 - roc_auc: 0.9863 - pr_auc: 0.9821 - cohen_kappa: 0.8763 - val_loss: 0.5320 - val_tp: 539.0000 - val_fp: 48.0000 - val_tn: 1084.0000 - val_fn: 281.0000 - val_binary_acc: 0.8315 - val_precision: 0.9182 - val_recall: 0.6573 - val_f1_score: 0.7662 - val_roc_auc: 0.8939 - val_pr_auc: 0.8826 - val_cohen_kappa: 0.6400 - lr: 1.0000e-05
# Epoch 15/50
# 488/488 [==============================] - ETA: 0s - loss: 0.1440 - tp: 2884.0000 - fp: 159.0000 - tn: 4474.0000 - fn: 283.0000 - binary_acc: 0.9433 - precision: 0.9477 - recall: 0.9106 - f1_score: 0.9288 - roc_auc: 0.9858 - pr_auc: 0.9818 - cohen_kappa: 0.8818
# Epoch 15: ReduceLROnPlateau reducing learning rate to 1.9999999494757505e-06.
# 488/488 [==============================] - 117s 240ms/step - loss: 0.1440 - tp: 2884.0000 - fp: 159.0000 - tn: 4474.0000 - fn: 283.0000 - binary_acc: 0.9433 - precision: 0.9477 - recall: 0.9106 - f1_score: 0.9288 - roc_auc: 0.9858 - pr_auc: 0.9818 - cohen_kappa: 0.8818 - val_loss: 0.5308 - val_tp: 623.0000 - val_fp: 123.0000 - val_tn: 1009.0000 - val_fn: 197.0000 - val_binary_acc: 0.8361 - val_precision: 0.8351 - val_recall: 0.7598 - val_f1_score: 0.7957 - val_roc_auc: 0.8939 - val_pr_auc: 0.8795 - val_cohen_kappa: 0.6593 - lr: 1.0000e-05
# Epoch 16/50
# 488/488 [==============================] - 117s 240ms/step - loss: 0.0990 - tp: 2987.0000 - fp: 91.0000 - tn: 4542.0000 - fn: 180.0000 - binary_acc: 0.9653 - precision: 0.9704 - recall: 0.9432 - f1_score: 0.9566 - roc_auc: 0.9936 - pr_auc: 0.9916 - cohen_kappa: 0.9276 - val_loss: 0.5794 - val_tp: 607.0000 - val_fp: 99.0000 - val_tn: 1033.0000 - val_fn: 213.0000 - val_binary_acc: 0.8402 - val_precision: 0.8598 - val_recall: 0.7402 - val_f1_score: 0.7955 - val_roc_auc: 0.9006 - val_pr_auc: 0.8938 - val_cohen_kappa: 0.6655 - lr: 2.0000e-06
# Epoch 17/50
# 488/488 [==============================] - 118s 242ms/step - loss: 0.0849 - tp: 2999.0000 - fp: 81.0000 - tn: 4552.0000 - fn: 168.0000 - binary_acc: 0.9681 - precision: 0.9737 - recall: 0.9470 - f1_score: 0.9601 - roc_auc: 0.9950 - pr_auc: 0.9937 - cohen_kappa: 0.9335 - val_loss: 0.5669 - val_tp: 658.0000 - val_fp: 135.0000 - val_tn: 997.0000 - val_fn: 162.0000 - val_binary_acc: 0.8478 - val_precision: 0.8298 - val_recall: 0.8024 - val_f1_score: 0.8159 - val_roc_auc: 0.9042 - val_pr_auc: 0.8919 - val_cohen_kappa: 0.6863 - lr: 2.0000e-06
# Epoch 18/50
# 488/488 [==============================] - 118s 241ms/step - loss: 0.0789 - tp: 3019.0000 - fp: 83.0000 - tn: 4550.0000 - fn: 148.0000 - binary_acc: 0.9704 - precision: 0.9732 - recall: 0.9533 - f1_score: 0.9632 - roc_auc: 0.9959 - pr_auc: 0.9944 - cohen_kappa: 0.9384 - val_loss: 0.6242 - val_tp: 636.0000 - val_fp: 95.0000 - val_tn: 1037.0000 - val_fn: 184.0000 - val_binary_acc: 0.8571 - val_precision: 0.8700 - val_recall: 0.7756 - val_f1_score: 0.8201 - val_roc_auc: 0.9051 - val_pr_auc: 0.8934 - val_cohen_kappa: 0.7022 - lr: 2.0000e-06
# Epoch 19/50
# 488/488 [==============================] - 120s 246ms/step - loss: 0.0687 - tp: 3038.0000 - fp: 74.0000 - tn: 4559.0000 - fn: 129.0000 - binary_acc: 0.9740 - precision: 0.9762 - recall: 0.9593 - f1_score: 0.9677 - roc_auc: 0.9967 - pr_auc: 0.9955 - cohen_kappa: 0.9459 - val_loss: 0.6488 - val_tp: 616.0000 - val_fp: 82.0000 - val_tn: 1050.0000 - val_fn: 204.0000 - val_binary_acc: 0.8535 - val_precision: 0.8825 - val_recall: 0.7512 - val_f1_score: 0.8116 - val_roc_auc: 0.9003 - val_pr_auc: 0.8895 - val_cohen_kappa: 0.6930 - lr: 2.0000e-06
# Epoch 20/50
# 488/488 [==============================] - 118s 241ms/step - loss: 0.0723 - tp: 3037.0000 - fp: 66.0000 - tn: 4567.0000 - fn: 130.0000 - binary_acc: 0.9749 - precision: 0.9787 - recall: 0.9590 - f1_score: 0.9687 - roc_auc: 0.9963 - pr_auc: 0.9951 - cohen_kappa: 0.9477 - val_loss: 0.6213 - val_tp: 644.0000 - val_fp: 127.0000 - val_tn: 1005.0000 - val_fn: 176.0000 - val_binary_acc: 0.8448 - val_precision: 0.8353 - val_recall: 0.7854 - val_f1_score: 0.8096 - val_roc_auc: 0.9023 - val_pr_auc: 0.8860 - val_cohen_kappa: 0.6788 - lr: 2.0000e-06
# Epoch 21/50
# 488/488 [==============================] - 117s 239ms/step - loss: 0.0645 - tp: 3046.0000 - fp: 64.0000 - tn: 4569.0000 - fn: 121.0000 - binary_acc: 0.9763 - precision: 0.9794 - recall: 0.9618 - f1_score: 0.9705 - roc_auc: 0.9968 - pr_auc: 0.9961 - cohen_kappa: 0.9507 - val_loss: 0.6538 - val_tp: 626.0000 - val_fp: 99.0000 - val_tn: 1033.0000 - val_fn: 194.0000 - val_binary_acc: 0.8499 - val_precision: 0.8634 - val_recall: 0.7634 - val_f1_score: 0.8104 - val_roc_auc: 0.8976 - val_pr_auc: 0.8870 - val_cohen_kappa: 0.6869 - lr: 2.0000e-06
# Epoch 22/50
# 488/488 [==============================] - ETA: 0s - loss: 0.0584 - tp: 3050.0000 - fp: 61.0000 - tn: 4572.0000 - fn: 117.0000 - binary_acc: 0.9772 - precision: 0.9804 - recall: 0.9631 - f1_score: 0.9716 - roc_auc: 0.9978 - pr_auc: 0.9971 - cohen_kappa: 0.9526
# Epoch 22: ReduceLROnPlateau reducing learning rate to 3.999999989900971e-07.
# 488/488 [==============================] - 117s 240ms/step - loss: 0.0584 - tp: 3050.0000 - fp: 61.0000 - tn: 4572.0000 - fn: 117.0000 - binary_acc: 0.9772 - precision: 0.9804 - recall: 0.9631 - f1_score: 0.9716 - roc_auc: 0.9978 - pr_auc: 0.9971 - cohen_kappa: 0.9526 - val_loss: 0.6507 - val_tp: 637.0000 - val_fp: 110.0000 - val_tn: 1022.0000 - val_fn: 183.0000 - val_binary_acc: 0.8499 - val_precision: 0.8527 - val_recall: 0.7768 - val_f1_score: 0.8130 - val_roc_auc: 0.9053 - val_pr_auc: 0.8908 - val_cohen_kappa: 0.6881 - lr: 2.0000e-06
# Epoch 23/50
# 488/488 [==============================] - 117s 240ms/step - loss: 0.0553 - tp: 3060.0000 - fp: 56.0000 - tn: 4577.0000 - fn: 107.0000 - binary_acc: 0.9791 - precision: 0.9820 - recall: 0.9662 - f1_score: 0.9741 - roc_auc: 0.9978 - pr_auc: 0.9967 - cohen_kappa: 0.9566 - val_loss: 0.6667 - val_tp: 622.0000 - val_fp: 98.0000 - val_tn: 1034.0000 - val_fn: 198.0000 - val_binary_acc: 0.8484 - val_precision: 0.8639 - val_recall: 0.7585 - val_f1_score: 0.8078 - val_roc_auc: 0.9030 - val_pr_auc: 0.8839 - val_cohen_kappa: 0.6835 - lr: 4.0000e-07
# Epoch 24/50
# 488/488 [==============================] - 117s 240ms/step - loss: 0.0523 - tp: 3074.0000 - fp: 52.0000 - tn: 4581.0000 - fn: 93.0000 - binary_acc: 0.9814 - precision: 0.9834 - recall: 0.9706 - f1_score: 0.9770 - roc_auc: 0.9983 - pr_auc: 0.9976 - cohen_kappa: 0.9614 - val_loss: 0.6787 - val_tp: 626.0000 - val_fp: 108.0000 - val_tn: 1024.0000 - val_fn: 194.0000 - val_binary_acc: 0.8453 - val_precision: 0.8529 - val_recall: 0.7634 - val_f1_score: 0.8057 - val_roc_auc: 0.9028 - val_pr_auc: 0.8874 - val_cohen_kappa: 0.6778 - lr: 4.0000e-07
# Epoch 25/50
# 488/488 [==============================] - 117s 239ms/step - loss: 0.0515 - tp: 3075.0000 - fp: 47.0000 - tn: 4586.0000 - fn: 92.0000 - binary_acc: 0.9822 - precision: 0.9849 - recall: 0.9710 - f1_score: 0.9779 - roc_auc: 0.9980 - pr_auc: 0.9975 - cohen_kappa: 0.9630 - val_loss: 0.6574 - val_tp: 636.0000 - val_fp: 112.0000 - val_tn: 1020.0000 - val_fn: 184.0000 - val_binary_acc: 0.8484 - val_precision: 0.8503 - val_recall: 0.7756 - val_f1_score: 0.8112 - val_roc_auc: 0.9035 - val_pr_auc: 0.8882 - val_cohen_kappa: 0.6850 - lr: 4.0000e-07
# Epoch 26/50
# 488/488 [==============================] - ETA: 0s - loss: 0.0458 - tp: 3079.0000 - fp: 44.0000 - tn: 4589.0000 - fn: 88.0000 - binary_acc: 0.9831 - precision: 0.9859 - recall: 0.9722 - f1_score: 0.9790 - roc_auc: 0.9985 - pr_auc: 0.9978 - cohen_kappa: 0.9648
# Epoch 26: ReduceLROnPlateau reducing learning rate to 8.00000009348878e-08.
# 488/488 [==============================] - 117s 239ms/step - loss: 0.0458 - tp: 3079.0000 - fp: 44.0000 - tn: 4589.0000 - fn: 88.0000 - binary_acc: 0.9831 - precision: 0.9859 - recall: 0.9722 - f1_score: 0.9790 - roc_auc: 0.9985 - pr_auc: 0.9978 - cohen_kappa: 0.9648 - val_loss: 0.6825 - val_tp: 641.0000 - val_fp: 115.0000 - val_tn: 1017.0000 - val_fn: 179.0000 - val_binary_acc: 0.8494 - val_precision: 0.8479 - val_recall: 0.7817 - val_f1_score: 0.8135 - val_roc_auc: 0.9043 - val_pr_auc: 0.8870 - val_cohen_kappa: 0.6875 - lr: 4.0000e-07
# Epoch 27/50
# 488/488 [==============================] - 116s 238ms/step - loss: 0.0439 - tp: 3093.0000 - fp: 47.0000 - tn: 4586.0000 - fn: 74.0000 - binary_acc: 0.9845 - precision: 0.9850 - recall: 0.9766 - f1_score: 0.9808 - roc_auc: 0.9988 - pr_auc: 0.9984 - cohen_kappa: 0.9678 - val_loss: 0.6871 - val_tp: 647.0000 - val_fp: 93.0000 - val_tn: 1039.0000 - val_fn: 173.0000 - val_binary_acc: 0.8637 - val_precision: 0.8743 - val_recall: 0.7890 - val_f1_score: 0.8295 - val_roc_auc: 0.9061 - val_pr_auc: 0.8968 - val_cohen_kappa: 0.7165 - lr: 8.0000e-08
# Epoch 28/50
# 488/488 [==============================] - 116s 238ms/step - loss: 0.0485 - tp: 3075.0000 - fp: 43.0000 - tn: 4590.0000 - fn: 92.0000 - binary_acc: 0.9827 - precision: 0.9862 - recall: 0.9710 - f1_score: 0.9785 - roc_auc: 0.9982 - pr_auc: 0.9977 - cohen_kappa: 0.9640 - val_loss: 0.6937 - val_tp: 639.0000 - val_fp: 100.0000 - val_tn: 1032.0000 - val_fn: 181.0000 - val_binary_acc: 0.8560 - val_precision: 0.8647 - val_recall: 0.7793 - val_f1_score: 0.8198 - val_roc_auc: 0.9015 - val_pr_auc: 0.8883 - val_cohen_kappa: 0.7005 - lr: 8.0000e-08
# Epoch 29/50
# 488/488 [==============================] - 116s 238ms/step - loss: 0.0468 - tp: 3081.0000 - fp: 40.0000 - tn: 4593.0000 - fn: 86.0000 - binary_acc: 0.9838 - precision: 0.9872 - recall: 0.9728 - f1_score: 0.9800 - roc_auc: 0.9982 - pr_auc: 0.9978 - cohen_kappa: 0.9664 - val_loss: 0.7122 - val_tp: 639.0000 - val_fp: 112.0000 - val_tn: 1020.0000 - val_fn: 181.0000 - val_binary_acc: 0.8499 - val_precision: 0.8509 - val_recall: 0.7793 - val_f1_score: 0.8135 - val_roc_auc: 0.9023 - val_pr_auc: 0.8874 - val_cohen_kappa: 0.6883 - lr: 8.0000e-08
# Epoch 30/50
# 488/488 [==============================] - 117s 239ms/step - loss: 0.0480 - tp: 3081.0000 - fp: 40.0000 - tn: 4593.0000 - fn: 86.0000 - binary_acc: 0.9838 - precision: 0.9872 - recall: 0.9728 - f1_score: 0.9800 - roc_auc: 0.9983 - pr_auc: 0.9976 - cohen_kappa: 0.9664 - val_loss: 0.6700 - val_tp: 636.0000 - val_fp: 99.0000 - val_tn: 1033.0000 - val_fn: 184.0000 - val_binary_acc: 0.8550 - val_precision: 0.8653 - val_recall: 0.7756 - val_f1_score: 0.8180 - val_roc_auc: 0.9030 - val_pr_auc: 0.8873 - val_cohen_kappa: 0.6981 - lr: 8.0000e-08
# Epoch 31/50
# 488/488 [==============================] - ETA: 0s - loss: 0.0432 - tp: 3098.0000 - fp: 46.0000 - tn: 4587.0000 - fn: 69.0000 - binary_acc: 0.9853 - precision: 0.9854 - recall: 0.9782 - f1_score: 0.9818 - roc_auc: 0.9988 - pr_auc: 0.9981 - cohen_kappa: 0.9694
# Epoch 31: ReduceLROnPlateau reducing learning rate to 1.5999999902760466e-08.
# 488/488 [==============================] - 116s 238ms/step - loss: 0.0432 - tp: 3098.0000 - fp: 46.0000 - tn: 4587.0000 - fn: 69.0000 - binary_acc: 0.9853 - precision: 0.9854 - recall: 0.9782 - f1_score: 0.9818 - roc_auc: 0.9988 - pr_auc: 0.9981 - cohen_kappa: 0.9694 - val_loss: 0.6746 - val_tp: 638.0000 - val_fp: 94.0000 - val_tn: 1038.0000 - val_fn: 182.0000 - val_binary_acc: 0.8586 - val_precision: 0.8716 - val_recall: 0.7780 - val_f1_score: 0.8222 - val_roc_auc: 0.9031 - val_pr_auc: 0.8915 - val_cohen_kappa: 0.7054 - lr: 8.0000e-08
# Epoch 32/50
# 488/488 [==============================] - 116s 238ms/step - loss: 0.0466 - tp: 3065.0000 - fp: 34.0000 - tn: 4599.0000 - fn: 102.0000 - binary_acc: 0.9826 - precision: 0.9890 - recall: 0.9678 - f1_score: 0.9783 - roc_auc: 0.9985 - pr_auc: 0.9981 - cohen_kappa: 0.9637 - val_loss: 0.6731 - val_tp: 641.0000 - val_fp: 101.0000 - val_tn: 1031.0000 - val_fn: 179.0000 - val_binary_acc: 0.8566 - val_precision: 0.8639 - val_recall: 0.7817 - val_f1_score: 0.8207 - val_roc_auc: 0.9057 - val_pr_auc: 0.8902 - val_cohen_kappa: 0.7017 - lr: 1.6000e-08
# Epoch 33/50
# 488/488 [==============================] - 117s 240ms/step - loss: 0.0444 - tp: 3080.0000 - fp: 39.0000 - tn: 4594.0000 - fn: 87.0000 - binary_acc: 0.9838 - precision: 0.9875 - recall: 0.9725 - f1_score: 0.9800 - roc_auc: 0.9987 - pr_auc: 0.9983 - cohen_kappa: 0.9664 - val_loss: 0.6853 - val_tp: 635.0000 - val_fp: 98.0000 - val_tn: 1034.0000 - val_fn: 185.0000 - val_binary_acc: 0.8550 - val_precision: 0.8663 - val_recall: 0.7744 - val_f1_score: 0.8178 - val_roc_auc: 0.9036 - val_pr_auc: 0.8909 - val_cohen_kappa: 0.6980 - lr: 1.6000e-08
# Epoch 34/50
# 488/488 [==============================] - 118s 241ms/step - loss: 0.0477 - tp: 3077.0000 - fp: 43.0000 - tn: 4590.0000 - fn: 90.0000 - binary_acc: 0.9829 - precision: 0.9862 - recall: 0.9716 - f1_score: 0.9788 - roc_auc: 0.9985 - pr_auc: 0.9977 - cohen_kappa: 0.9646 - val_loss: 0.6978 - val_tp: 637.0000 - val_fp: 102.0000 - val_tn: 1030.0000 - val_fn: 183.0000 - val_binary_acc: 0.8540 - val_precision: 0.8620 - val_recall: 0.7768 - val_f1_score: 0.8172 - val_roc_auc: 0.9042 - val_pr_auc: 0.8863 - val_cohen_kappa: 0.6962 - lr: 1.6000e-08
# Epoch 35/50
# 488/488 [==============================] - ETA: 0s - loss: 0.0491 - tp: 3071.0000 - fp: 41.0000 - tn: 4592.0000 - fn: 96.0000 - binary_acc: 0.9824 - precision: 0.9868 - recall: 0.9697 - f1_score: 0.9782 - roc_auc: 0.9981 - pr_auc: 0.9974 - cohen_kappa: 0.9635
# Epoch 35: ReduceLROnPlateau reducing learning rate to 3.1999999094978194e-09.
# 488/488 [==============================] - 118s 241ms/step - loss: 0.0491 - tp: 3071.0000 - fp: 41.0000 - tn: 4592.0000 - fn: 96.0000 - binary_acc: 0.9824 - precision: 0.9868 - recall: 0.9697 - f1_score: 0.9782 - roc_auc: 0.9981 - pr_auc: 0.9974 - cohen_kappa: 0.9635 - val_loss: 0.6769 - val_tp: 639.0000 - val_fp: 112.0000 - val_tn: 1020.0000 - val_fn: 181.0000 - val_binary_acc: 0.8499 - val_precision: 0.8509 - val_recall: 0.7793 - val_f1_score: 0.8135 - val_roc_auc: 0.9056 - val_pr_auc: 0.8903 - val_cohen_kappa: 0.6883 - lr: 1.6000e-08
# Epoch 36/50
# 488/488 [==============================] - 118s 242ms/step - loss: 0.0453 - tp: 3078.0000 - fp: 42.0000 - tn: 4591.0000 - fn: 89.0000 - binary_acc: 0.9832 - precision: 0.9865 - recall: 0.9719 - f1_score: 0.9792 - roc_auc: 0.9982 - pr_auc: 0.9980 - cohen_kappa: 0.9651 - val_loss: 0.6961 - val_tp: 636.0000 - val_fp: 98.0000 - val_tn: 1034.0000 - val_fn: 184.0000 - val_binary_acc: 0.8555 - val_precision: 0.8665 - val_recall: 0.7756 - val_f1_score: 0.8185 - val_roc_auc: 0.9042 - val_pr_auc: 0.8894 - val_cohen_kappa: 0.6991 - lr: 3.2000e-09
# Epoch 37/50
# 488/488 [==============================] - 118s 241ms/step - loss: 0.0459 - tp: 3079.0000 - fp: 44.0000 - tn: 4589.0000 - fn: 88.0000 - binary_acc: 0.9831 - precision: 0.9859 - recall: 0.9722 - f1_score: 0.9790 - roc_auc: 0.9984 - pr_auc: 0.9980 - cohen_kappa: 0.9648 - val_loss: 0.6794 - val_tp: 637.0000 - val_fp: 111.0000 - val_tn: 1021.0000 - val_fn: 183.0000 - val_binary_acc: 0.8494 - val_precision: 0.8516 - val_recall: 0.7768 - val_f1_score: 0.8125 - val_roc_auc: 0.9062 - val_pr_auc: 0.8949 - val_cohen_kappa: 0.6871 - lr: 3.2000e-09
# Epoch 38/50
# 488/488 [==============================] - 118s 241ms/step - loss: 0.0457 - tp: 3089.0000 - fp: 46.0000 - tn: 4587.0000 - fn: 78.0000 - binary_acc: 0.9841 - precision: 0.9853 - recall: 0.9754 - f1_score: 0.9803 - roc_auc: 0.9984 - pr_auc: 0.9977 - cohen_kappa: 0.9670 - val_loss: 0.6911 - val_tp: 646.0000 - val_fp: 107.0000 - val_tn: 1025.0000 - val_fn: 174.0000 - val_binary_acc: 0.8560 - val_precision: 0.8579 - val_recall: 0.7878 - val_f1_score: 0.8214 - val_roc_auc: 0.9050 - val_pr_auc: 0.8971 - val_cohen_kappa: 0.7012 - lr: 3.2000e-09
# Epoch 39/50
# 488/488 [==============================] - ETA: 0s - loss: 0.0444 - tp: 3086.0000 - fp: 45.0000 - tn: 4588.0000 - fn: 81.0000 - binary_acc: 0.9838 - precision: 0.9856 - recall: 0.9744 - f1_score: 0.9800 - roc_auc: 0.9986 - pr_auc: 0.9983 - cohen_kappa: 0.9664
# Epoch 39: ReduceLROnPlateau reducing learning rate to 6.399999641359955e-10.
# 488/488 [==============================] - 117s 240ms/step - loss: 0.0444 - tp: 3086.0000 - fp: 45.0000 - tn: 4588.0000 - fn: 81.0000 - binary_acc: 0.9838 - precision: 0.9856 - recall: 0.9744 - f1_score: 0.9800 - roc_auc: 0.9986 - pr_auc: 0.9983 - cohen_kappa: 0.9664 - val_loss: 0.6534 - val_tp: 647.0000 - val_fp: 103.0000 - val_tn: 1029.0000 - val_fn: 173.0000 - val_binary_acc: 0.8586 - val_precision: 0.8627 - val_recall: 0.7890 - val_f1_score: 0.8242 - val_roc_auc: 0.9112 - val_pr_auc: 0.8922 - val_cohen_kappa: 0.7063 - lr: 3.2000e-09
# Epoch 40/50
# 488/488 [==============================] - 117s 240ms/step - loss: 0.0466 - tp: 3085.0000 - fp: 41.0000 - tn: 4592.0000 - fn: 82.0000 - binary_acc: 0.9842 - precision: 0.9869 - recall: 0.9741 - f1_score: 0.9805 - roc_auc: 0.9981 - pr_auc: 0.9975 - cohen_kappa: 0.9672 - val_loss: 0.6885 - val_tp: 644.0000 - val_fp: 107.0000 - val_tn: 1025.0000 - val_fn: 176.0000 - val_binary_acc: 0.8550 - val_precision: 0.8575 - val_recall: 0.7854 - val_f1_score: 0.8199 - val_roc_auc: 0.9009 - val_pr_auc: 0.8868 - val_cohen_kappa: 0.6989 - lr: 6.4000e-10
# Epoch 41/50
# 488/488 [==============================] - 117s 240ms/step - loss: 0.0485 - tp: 3083.0000 - fp: 49.0000 - tn: 4584.0000 - fn: 84.0000 - binary_acc: 0.9829 - precision: 0.9844 - recall: 0.9735 - f1_score: 0.9789 - roc_auc: 0.9980 - pr_auc: 0.9976 - cohen_kappa: 0.9646 - val_loss: 0.6810 - val_tp: 643.0000 - val_fp: 103.0000 - val_tn: 1029.0000 - val_fn: 177.0000 - val_binary_acc: 0.8566 - val_precision: 0.8619 - val_recall: 0.7841 - val_f1_score: 0.8212 - val_roc_auc: 0.9001 - val_pr_auc: 0.8877 - val_cohen_kappa: 0.7019 - lr: 6.4000e-10
# Epoch 42/50
# 488/488 [==============================] - ETA: 0s - loss: 0.0418 - tp: 3080.0000 - fp: 42.0000 - tn: 4591.0000 - fn: 87.0000 - binary_acc: 0.9835 - precision: 0.9865 - recall: 0.9725 - f1_score: 0.9795 - roc_auc: 0.9988 - pr_auc: 0.9982 - cohen_kappa: 0.9656Restoring model weights from the end of the best epoch: 27.
# 488/488 [==============================] - 117s 239ms/step - loss: 0.0418 - tp: 3080.0000 - fp: 42.0000 - tn: 4591.0000 - fn: 87.0000 - binary_acc: 0.9835 - precision: 0.9865 - recall: 0.9725 - f1_score: 0.9795 - roc_auc: 0.9988 - pr_auc: 0.9982 - cohen_kappa: 0.9656 - val_loss: 0.7006 - val_tp: 630.0000 - val_fp: 114.0000 - val_tn: 1018.0000 - val_fn: 190.0000 - val_binary_acc: 0.8443 - val_precision: 0.8468 - val_recall: 0.7683 - val_f1_score: 0.8056 - val_roc_auc: 0.9017 - val_pr_auc: 0.8898 - val_cohen_kappa: 0.6762 - lr: 6.4000e-10
# Epoch 42: early stopping

# %%
new_model.save(save_path + model_name + '.keras')
plot_metrics(history)

# %%
new_model.evaluate(validation_generator)
new_model.evaluate(test_generator)

# Make predictions using the validation generator
y_valid_pred_prob = new_model.predict(validation_generator)
y_valid_pred = (y_valid_pred_prob > 0.5).astype(int)
y_valid = validation_generator.classes
print("Classification Report:")
print(classification_report(y_valid, y_valid_pred))

# Make predictions using the test generator
y_pred_prob = new_model.predict(test_generator)
y_pred = (y_pred_prob > 0.5).astype(int)
y_test = test_generator.classes
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# 122/122 [==============================] - 17s 140ms/step - loss: 0.6740 - tp: 636.0000 - fp: 109.0000 - tn: 1023.0000 - fn: 184.0000 - binary_acc: 0.8499 - precision: 0.8537 - recall: 0.7756 - f1_score: 0.8128 - roc_auc: 0.9030 - pr_auc: 0.8873 - cohen_kappa: 0.6880
# 42/42 [==============================] - 2s 56ms/step - loss: 1.0375 - tp: 202.0000 - fp: 25.0000 - tn: 339.0000 - fn: 92.0000 - binary_acc: 0.8222 - precision: 0.8899 - recall: 0.6871 - f1_score: 0.7754 - roc_auc: 0.8585 - pr_auc: 0.8677 - cohen_kappa: 0.6322
# 122/122 [==============================] - 17s 136ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.90      0.88      1132
#            1       0.85      0.78      0.81       820
#
#     accuracy                           0.85      1952
#    macro avg       0.85      0.84      0.84      1952
# weighted avg       0.85      0.85      0.85      1952
#
# 42/42 [==============================] - 2s 45ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.79      0.93      0.85       364
#            1       0.89      0.69      0.78       294
#
#     accuracy                           0.82       658
#    macro avg       0.84      0.81      0.81       658
# weighted avg       0.83      0.82      0.82       658

# %%
conf_matrix = confusion_matrix(y_test, y_pred)

# Create ConfusionMatrixDisplay object
cm_display = ConfusionMatrixDisplay(confusion_matrix=conf_matrix)

# Plot the confusion matrix
plt.figure(figsize=(4, 6))  # Adjust the figure size as needed
cm_display.plot(cmap=plt.cm.Blues)  # You can choose any colormap you prefer
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.grid(False)  # Turn off grid
plt.savefig(save_path + model_name + "_confusion_matrix.jpg")
plt.show()

# %%
history_df = pd.DataFrame(history.history)
save_history(model_name, history_df)
# Out:
# Training history saved to: C:/Users/raouf/Desktop/pfe/history/final/vgg/XR_WRIST/finetuned_VGG_XR_WRIST_history.xlsx
